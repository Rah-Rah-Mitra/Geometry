# %% [markdown]
# # Chapter 01: Multilinear Algebra
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [01-multilinear-algebra.ipynb](01-multilinear-algebra.ipynb)

# %% [markdown]
# # Chapter 00: Introduction to Geometric Measure Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [00-introduction-to-geometric-measure-theory.ipynb](00-introduction-to-geometric-measure-theory.ipynb)

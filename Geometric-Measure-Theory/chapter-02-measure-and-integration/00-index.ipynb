# %% [markdown]
# # Chapter 02: Measure and Integration
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [02-measure-and-integration.ipynb](02-measure-and-integration.ipynb)

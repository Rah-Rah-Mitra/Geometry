# %% [markdown]
# # Chapter 03: Differentiation Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [03-differentiation-theory.ipynb](03-differentiation-theory.ipynb)

# %% [markdown]
# # Chapter 5: The Tychonoff Theorem
#
# - Source span: printed pages 228-240; sections §§37-38.
# - Focus: products of compact spaces and Stone-Cech compactification.
# - Canonical notebook: [05-the-tychonoff-theorem.ipynb](05-the-tychonoff-theorem.ipynb)
# - Back to [book index](../00-book-index.ipynb)

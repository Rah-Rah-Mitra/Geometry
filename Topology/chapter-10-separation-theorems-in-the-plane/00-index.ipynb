# %% [markdown]
# # Chapter 10: Separation Theorems in the Plane
#
# - Source span: printed pages 372-402; sections §§61-66.
# - Focus: Jordan separation, invariance of domain, plane graph embeddings, winding number, and Cauchy integral formula.
# - Canonical notebook: [10-separation-theorems-in-the-plane.ipynb](10-separation-theorems-in-the-plane.ipynb)
# - Back to [book index](../00-book-index.ipynb)

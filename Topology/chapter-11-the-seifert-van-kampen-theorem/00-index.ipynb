# %% [markdown]
# # Chapter 11: The Seifert-van Kampen Theorem
#
# - Source span: printed pages 403-442; sections §§67-73.
# - Focus: direct sums, free products, free groups, Seifert-van Kampen, wedges of circles, adjoining two-cells, and group presentations.
# - Canonical notebook: [11-the-seifert-van-kampen-theorem.ipynb](11-the-seifert-van-kampen-theorem.ipynb)
# - Back to [book index](../00-book-index.ipynb)

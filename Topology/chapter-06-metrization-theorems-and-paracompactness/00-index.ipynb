# %% [markdown]
# # Chapter 6: Metrization Theorems and Paracompactness
#
# - Source span: printed pages 241-260; sections §§39-42.
# - Focus: local finiteness, Nagata-Smirnov metrization, Smirnov metrization, and paracompactness.
# - Canonical notebook: [06-metrization-theorems-and-paracompactness.ipynb](06-metrization-theorems-and-paracompactness.ipynb)
# - Back to [book index](../00-book-index.ipynb)

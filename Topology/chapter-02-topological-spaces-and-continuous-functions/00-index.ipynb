# %% [markdown]
# # Chapter 2: Topological Spaces and Continuous Functions
#
# - Source span: printed pages 73-144; sections §§12-22.
# - Focus: bases, product topology, subspaces, quotient topology, and continuity.
# - Canonical notebook: [02-topological-spaces-and-continuous-functions.ipynb](02-topological-spaces-and-continuous-functions.ipynb)
# - Back to [book index](../00-book-index.ipynb)

# %% [markdown]
# # Chapter 4: Countability and Separation Axioms
#
# - Source span: printed pages 187-227; sections §§30-36.
# - Focus: countability axioms, separation axioms, normal spaces, Urysohn's lemma, Tietze extension, and embeddings.
# - Canonical notebook: [04-countability-and-separation-axioms.ipynb](04-countability-and-separation-axioms.ipynb)
# - Back to [book index](../00-book-index.ipynb)

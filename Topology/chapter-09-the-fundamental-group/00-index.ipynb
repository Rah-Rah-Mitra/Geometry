# %% [markdown]
# # Chapter 9: The Fundamental Group
#
# - Source span: printed pages 317-371; sections §§51-60.
# - Focus: path homotopy, the fundamental group, covering spaces, the circle, retractions, fixed points, and surface groups.
# - Canonical notebook: [09-the-fundamental-group.ipynb](09-the-fundamental-group.ipynb)
# - Back to [book index](../00-book-index.ipynb)

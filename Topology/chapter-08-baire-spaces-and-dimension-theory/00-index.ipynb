# %% [markdown]
# # Chapter 8: Baire Spaces and Dimension Theory
#
# - Source span: printed pages 292-316; sections §§48-50.
# - Focus: Baire spaces, nowhere-differentiable functions, and dimension theory.
# - Canonical notebook: [08-baire-spaces-and-dimension-theory.ipynb](08-baire-spaces-and-dimension-theory.ipynb)
# - Back to [book index](../00-book-index.ipynb)

# %% [markdown]
# # Chapter 3: Connectedness and Compactness
#
# - Source span: printed pages 145-186; sections §§23-29.
# - Focus: connected spaces, compact spaces, limit-point compactness, local compactness, and nets.
# - Canonical notebook: [03-connectedness-and-compactness.ipynb](03-connectedness-and-compactness.ipynb)
# - Back to [book index](../00-book-index.ipynb)

# %% [markdown]
# # Chapter 7: Complete Metric Spaces and Function Spaces
#
# - Source span: printed pages 261-291; sections §§43-47.
# - Focus: complete metric spaces, space-filling curves, compactness in metric spaces, compact convergence, and Ascoli's theorem.
# - Canonical notebook: [07-complete-metric-spaces-and-function-spaces.ipynb](07-complete-metric-spaces-and-function-spaces.ipynb)
# - Back to [book index](../00-book-index.ipynb)

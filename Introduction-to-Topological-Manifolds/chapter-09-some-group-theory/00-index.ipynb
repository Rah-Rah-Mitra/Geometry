# %% [markdown]
# # Chapter 9: Some Group Theory
#
# Source span: printed pages `233-250`, PDF pages `251-268`.
#
# Canonical notebook: [`09-some-group-theory.ipynb`](09-some-group-theory.ipynb).
#
# Focus: Free groups, presentations, free products, and free abelian groups.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 4: Connectedness and Compactness
#
# Source span: printed pages `85-126`, PDF pages `103-144`.
#
# Canonical notebook: [`04-connectedness-and-compactness.ipynb`](04-connectedness-and-compactness.ipynb).
#
# Focus: Connectedness, path connectedness, compactness, local compactness, and manifolds with boundary.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

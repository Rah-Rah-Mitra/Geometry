# %% [markdown]
# # Chapter 1: Introduction
#
# Source span: printed pages `1-18`, PDF pages `19-36`.
#
# Canonical notebook: [`01-introduction.ipynb`](01-introduction.ipynb).
#
# Focus: Examples of manifolds, invariants, classification motivation, and homeomorphism intuition.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

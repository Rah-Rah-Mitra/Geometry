# %% [markdown]
# # Chapter 10: The Seifert-Van Kampen Theorem
#
# Source span: printed pages `251-276`, PDF pages `269-294`.
#
# Canonical notebook: [`10-the-seifert-van-kampen-theorem.ipynb`](10-the-seifert-van-kampen-theorem.ipynb).
#
# Focus: Seifert-van Kampen, graphs, CW complexes, and surface group presentations.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Appendix B: Review of Metric Spaces
#
# Source span: printed pages `395-400`, PDF pages `413-418`.
#
# Canonical notebook: [`appendix-b-review-of-metric-spaces.ipynb`](appendix-b-review-of-metric-spaces.ipynb).
#
# Focus: Metric spaces, balls, convergence, continuity, compactness, and complete metric intuition.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Introduction to Topological Manifolds
#
# Standalone visualization-first notebook course.
#
# Source method: user-provided page map plus pdftotext source-span inspection.
#
# | Unit | Title | Printed Pages | PDF Pages | Notebook |
# | --- | --- | ---: | ---: | --- |
# | Chapter 1 | Introduction | 1-18 | 19-36 | [`01-introduction.ipynb`](chapter-01-introduction/01-introduction.ipynb) |
# | Chapter 2 | Topological Spaces | 19-48 | 37-66 | [`02-topological-spaces.ipynb`](chapter-02-topological-spaces/02-topological-spaces.ipynb) |
# | Chapter 3 | New Spaces from Old | 49-84 | 67-102 | [`03-new-spaces-from-old.ipynb`](chapter-03-new-spaces-from-old/03-new-spaces-from-old.ipynb) |
# | Chapter 4 | Connectedness and Compactness | 85-126 | 103-144 | [`04-connectedness-and-compactness.ipynb`](chapter-04-connectedness-and-compactness/04-connectedness-and-compactness.ipynb) |
# | Chapter 5 | Cell Complexes | 127-158 | 145-176 | [`05-cell-complexes.ipynb`](chapter-05-cell-complexes/05-cell-complexes.ipynb) |
# | Chapter 6 | Compact Surfaces | 159-182 | 177-200 | [`06-compact-surfaces.ipynb`](chapter-06-compact-surfaces/06-compact-surfaces.ipynb) |
# | Chapter 7 | Homotopy and the Fundamental Group | 183-216 | 201-234 | [`07-homotopy-and-the-fundamental-group.ipynb`](chapter-07-homotopy-and-the-fundamental-group/07-homotopy-and-the-fundamental-group.ipynb) |
# | Chapter 8 | The Circle | 217-232 | 235-250 | [`08-the-circle.ipynb`](chapter-08-the-circle/08-the-circle.ipynb) |
# | Chapter 9 | Some Group Theory | 233-250 | 251-268 | [`09-some-group-theory.ipynb`](chapter-09-some-group-theory/09-some-group-theory.ipynb) |
# | Chapter 10 | The Seifert-Van Kampen Theorem | 251-276 | 269-294 | [`10-the-seifert-van-kampen-theorem.ipynb`](chapter-10-the-seifert-van-kampen-theorem/10-the-seifert-van-kampen-theorem.ipynb) |
# | Chapter 11 | Covering Maps | 277-306 | 295-324 | [`11-covering-maps.ipynb`](chapter-11-covering-maps/11-covering-maps.ipynb) |
# | Chapter 12 | Group Actions and Covering Maps | 307-338 | 325-356 | [`12-group-actions-and-covering-maps.ipynb`](chapter-12-group-actions-and-covering-maps/12-group-actions-and-covering-maps.ipynb) |
# | Chapter 13 | Homology | 339-380 | 357-398 | [`13-homology.ipynb`](chapter-13-homology/13-homology.ipynb) |
# | Appendix A | Review of Set Theory | 381-394 | 399-412 | [`appendix-a-review-of-set-theory.ipynb`](appendix-a-review-of-set-theory/appendix-a-review-of-set-theory.ipynb) |
# | Appendix B | Review of Metric Spaces | 395-400 | 413-418 | [`appendix-b-review-of-metric-spaces.ipynb`](appendix-b-review-of-metric-spaces/appendix-b-review-of-metric-spaces.ipynb) |
# | Appendix C | Review of Group Theory | 401-406 | 419-424 | [`appendix-c-review-of-group-theory.ipynb`](appendix-c-review-of-group-theory/appendix-c-review-of-group-theory.ipynb) |

# %%
import json
from pathlib import Path
root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
source = json.loads((root / 'source_map.json').read_text(encoding='utf-8'))
print(f"{source['title']}: {len(source['units'])} canonical units")

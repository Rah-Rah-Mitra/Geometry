# %% [markdown]
# # Chapter 12: Group Actions and Covering Maps
#
# Source span: printed pages `307-338`, PDF pages `325-356`.
#
# Canonical notebook: [`12-group-actions-and-covering-maps.ipynb`](12-group-actions-and-covering-maps.ipynb).
#
# Focus: Group actions, covering transformations, classification of coverings, and manifolds as quotients.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

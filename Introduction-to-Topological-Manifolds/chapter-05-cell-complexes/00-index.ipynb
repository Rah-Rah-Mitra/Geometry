# %% [markdown]
# # Chapter 5: Cell Complexes
#
# Source span: printed pages `127-158`, PDF pages `145-176`.
#
# Canonical notebook: [`05-cell-complexes.ipynb`](05-cell-complexes.ipynb).
#
# Focus: CW complexes, attaching maps, weak topology, cell structures, and 1-manifold classification.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

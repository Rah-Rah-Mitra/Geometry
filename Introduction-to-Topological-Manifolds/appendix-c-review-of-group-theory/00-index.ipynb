# %% [markdown]
# # Appendix C: Review of Group Theory
#
# Source span: printed pages `401-406`, PDF pages `419-424`.
#
# Canonical notebook: [`appendix-c-review-of-group-theory.ipynb`](appendix-c-review-of-group-theory.ipynb).
#
# Focus: Groups, homomorphisms, quotients, products, presentations, and group actions needed later.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 10: Transversals and Epsilon Nets
#
# Source span: printed pages `231-264`.
#
# Focus: Transversals, matchings, epsilon nets, VC-dimension, weak epsilon nets, and Hadwiger-Debrunner problems.
#
# Canonical notebook: [`10-transversals-and-epsilon-nets.ipynb`](10-transversals-and-epsilon-nets.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

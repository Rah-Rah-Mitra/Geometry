# %% [markdown]
# # Chapter 7: Lower Envelopes
#
# Source span: printed pages `165-194`.
#
# Focus: Davenport-Schinzel sequences, lower envelope complexity, triangles in space, curves, and algebraic surface patches.
#
# Canonical notebook: [`07-lower-envelopes.ipynb`](07-lower-envelopes.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 1: Convexity
#
# Source span: printed pages `1-16`.
#
# Focus: Affine subspaces, convex sets, separation, Radon lemma, Helly theorem, centerpoint theorem, and ham sandwich theorem.
#
# Canonical notebook: [`01-convexity.ipynb`](01-convexity.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

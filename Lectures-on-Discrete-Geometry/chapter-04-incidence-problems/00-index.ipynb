# %% [markdown]
# # Chapter 4: Incidence Problems
#
# Source span: printed pages `41-76`.
#
# Focus: Incidence formulations, lower bounds, unit distances, crossing numbers, cuttings, and point-line incidences.
#
# Canonical notebook: [`04-incidence-problems.ipynb`](04-incidence-problems.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

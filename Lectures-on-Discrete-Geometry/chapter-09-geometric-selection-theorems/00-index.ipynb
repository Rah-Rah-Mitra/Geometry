# %% [markdown]
# # Chapter 9: Geometric Selection Theorems
#
# Source span: printed pages `207-230`.
#
# Focus: Selection lemmas, order types, same-type lemma, hypergraph regularity, and positive-fraction selection.
#
# Canonical notebook: [`09-geometric-selection-theorems.ipynb`](09-geometric-selection-theorems.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

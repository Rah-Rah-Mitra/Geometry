# %% [markdown]
# # Chapter 6: Number of Faces in Arrangements
#
# Source span: printed pages `125-164`.
#
# Focus: Arrangements, complexity, levels, zones, cuttings, and probabilistic bounds.
#
# Canonical notebook: [`06-number-of-faces-in-arrangements.ipynb`](06-number-of-faces-in-arrangements.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 3: Convex Independent Subsets
#
# Source span: printed pages `29-40`.
#
# Focus: Erdos-Szekeres theorem, Horton sets, and geometric Ramsey examples.
#
# Canonical notebook: [`03-convex-independent-subsets.ipynb`](03-convex-independent-subsets.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

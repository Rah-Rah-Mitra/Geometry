# %% [markdown]
# # Chapter 11: Attempts to Count k-Sets
#
# Source span: printed pages `265-288`.
#
# Focus: k-sets, halving edges, Lovasz lemma, upper bounds, and planar improvements.
#
# Canonical notebook: [`11-attempts-to-count-k-sets.ipynb`](11-attempts-to-count-k-sets.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

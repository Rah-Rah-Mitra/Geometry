# %% [markdown]
# # Chapter 2: Lattices and Minkowski's Theorem
#
# Source span: printed pages `17-28`.
#
# Focus: Minkowski theorem, general lattices, and number-theoretic applications.
#
# Canonical notebook: [`02-lattices-and-minkowski-s-theorem.ipynb`](02-lattices-and-minkowski-s-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

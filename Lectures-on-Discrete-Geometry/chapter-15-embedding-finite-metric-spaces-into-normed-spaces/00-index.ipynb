# %% [markdown]
# # Chapter 15: Embedding Finite Metric Spaces into Normed Spaces
#
# Source span: printed pages `355-375`.
#
# Focus: Approximate embeddings, Johnson-Lindenstrauss flattening, lower bounds, Hamming cube, expanders, and l_infinity and Euclidean embeddings.
#
# Canonical notebook: [`15-embedding-finite-metric-spaces-into-normed.ipynb`](15-embedding-finite-metric-spaces-into-normed.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

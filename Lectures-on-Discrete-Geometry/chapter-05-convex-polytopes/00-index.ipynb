# %% [markdown]
# # Chapter 5: Convex Polytopes
#
# Source span: printed pages `77-124`.
#
# Focus: Geometric duality, H-polytopes, V-polytopes, faces, cyclic polytopes, upper bound theorem, Gale transform, and Voronoi diagrams.
#
# Canonical notebook: [`05-convex-polytopes.ipynb`](05-convex-polytopes.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

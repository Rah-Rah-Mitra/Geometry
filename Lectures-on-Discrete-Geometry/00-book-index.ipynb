# %% [markdown]
# # Lectures on Discrete Geometry
#
# Standalone visualization-first notebook course.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Convexity | 1-16 | [`01-convexity.ipynb`](chapter-01-convexity/01-convexity.ipynb) |
# | Chapter 2 | Lattices and Minkowski's Theorem | 17-28 | [`02-lattices-and-minkowski-s-theorem.ipynb`](chapter-02-lattices-and-minkowski-s-theorem/02-lattices-and-minkowski-s-theorem.ipynb) |
# | Chapter 3 | Convex Independent Subsets | 29-40 | [`03-convex-independent-subsets.ipynb`](chapter-03-convex-independent-subsets/03-convex-independent-subsets.ipynb) |
# | Chapter 4 | Incidence Problems | 41-76 | [`04-incidence-problems.ipynb`](chapter-04-incidence-problems/04-incidence-problems.ipynb) |
# | Chapter 5 | Convex Polytopes | 77-124 | [`05-convex-polytopes.ipynb`](chapter-05-convex-polytopes/05-convex-polytopes.ipynb) |
# | Chapter 6 | Number of Faces in Arrangements | 125-164 | [`06-number-of-faces-in-arrangements.ipynb`](chapter-06-number-of-faces-in-arrangements/06-number-of-faces-in-arrangements.ipynb) |
# | Chapter 7 | Lower Envelopes | 165-194 | [`07-lower-envelopes.ipynb`](chapter-07-lower-envelopes/07-lower-envelopes.ipynb) |
# | Chapter 8 | Intersection Patterns of Convex Sets | 195-206 | [`08-intersection-patterns-of-convex-sets.ipynb`](chapter-08-intersection-patterns-of-convex-sets/08-intersection-patterns-of-convex-sets.ipynb) |
# | Chapter 9 | Geometric Selection Theorems | 207-230 | [`09-geometric-selection-theorems.ipynb`](chapter-09-geometric-selection-theorems/09-geometric-selection-theorems.ipynb) |
# | Chapter 10 | Transversals and Epsilon Nets | 231-264 | [`10-transversals-and-epsilon-nets.ipynb`](chapter-10-transversals-and-epsilon-nets/10-transversals-and-epsilon-nets.ipynb) |
# | Chapter 11 | Attempts to Count k-Sets | 265-288 | [`11-attempts-to-count-k-sets.ipynb`](chapter-11-attempts-to-count-k-sets/11-attempts-to-count-k-sets.ipynb) |
# | Chapter 12 | Two Applications of High-Dimensional Polytopes | 289-310 | [`12-two-applications-of-high-dimensional-polytopes.ipynb`](chapter-12-two-applications-of-high-dimensional-polytopes/12-two-applications-of-high-dimensional-polytopes.ipynb) |
# | Chapter 13 | Volumes in High Dimension | 311-328 | [`13-volumes-in-high-dimension.ipynb`](chapter-13-volumes-in-high-dimension/13-volumes-in-high-dimension.ipynb) |
# | Chapter 14 | Measure Concentration and Almost Spherical Sections | 329-354 | [`14-measure-concentration-and-almost-spherical-sections.ipynb`](chapter-14-measure-concentration-and-almost-spherical-sections/14-measure-concentration-and-almost-spherical-sections.ipynb) |
# | Chapter 15 | Embedding Finite Metric Spaces into Normed Spaces | 355-375 | [`15-embedding-finite-metric-spaces-into-normed.ipynb`](chapter-15-embedding-finite-metric-spaces-into-normed-spaces/15-embedding-finite-metric-spaces-into-normed.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text(encoding='utf-8'))
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Lectures on Discrete Geometry: 15 canonical units

# %% [markdown]
# # Chapter 8: Intersection Patterns of Convex Sets
#
# Source span: printed pages `195-206`.
#
# Focus: Fractional Helly theorem, colorful Caratheodory theorem, and Tverberg theorem.
#
# Canonical notebook: [`08-intersection-patterns-of-convex-sets.ipynb`](08-intersection-patterns-of-convex-sets.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

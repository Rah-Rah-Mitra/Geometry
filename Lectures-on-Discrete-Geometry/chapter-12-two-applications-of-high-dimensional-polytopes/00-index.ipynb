# %% [markdown]
# # Chapter 12: Two Applications of High-Dimensional Polytopes
#
# Source span: printed pages `289-310`.
#
# Focus: Weak perfect graph conjecture, Brunn-Minkowski inequality, and sorting partially ordered sets.
#
# Canonical notebook: [`12-two-applications-of-high-dimensional-polytopes.ipynb`](12-two-applications-of-high-dimensional-polytopes.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

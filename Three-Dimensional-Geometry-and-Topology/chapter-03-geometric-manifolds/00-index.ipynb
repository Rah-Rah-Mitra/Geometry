# %% [markdown]
# # Chapter 3: Geometric Manifolds
#
# Source span: printed pages `109-208`.
#
# Focus: Geometric structures, triangulations, gluings, developing maps, completeness, discrete groups, bundles, connections, contact structures, model geometries, PL manifolds, and smoothings.
#
# Canonical notebook: [`03-geometric-manifolds.ipynb`](03-geometric-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

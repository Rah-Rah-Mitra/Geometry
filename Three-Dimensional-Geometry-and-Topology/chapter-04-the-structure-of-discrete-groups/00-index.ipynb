# %% [markdown]
# # Chapter 4: The Structure of Discrete Groups
#
# Source span: printed pages `209-288`.
#
# Canonical notebook: [`04-the-structure-of-discrete-groups.ipynb`](04-the-structure-of-discrete-groups.ipynb).
#
# Focus: Small generators, Euclidean manifolds, crystallographic groups, elliptic three-manifolds, thick-thin decomposition, Teichmuller space, and fibered geometries.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Three-Dimensional-Geometry-and-Topology

# %% [markdown]
# # Chapter 1: What Is a Manifold
#
# Source span: printed pages `3-42`.
#
# Focus: Polygons and surfaces, hyperbolic surfaces, totality of surfaces, and examples of three-manifolds.
#
# Canonical notebook: [`01-what-is-a-manifold.ipynb`](01-what-is-a-manifold.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Three-Dimensional Geometry and Topology
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | What Is a Manifold | 3-42 | [`01-what-is-a-manifold.ipynb`](chapter-01-what-is-a-manifold/01-what-is-a-manifold.ipynb) |
# | Chapter 2 | Hyperbolic Geometry and Its Friends | 43-108 | [`02-hyperbolic-geometry-and-its-friends.ipynb`](chapter-02-hyperbolic-geometry-and-its-friends/02-hyperbolic-geometry-and-its-friends.ipynb) |
# | Chapter 3 | Geometric Manifolds | 109-208 | [`03-geometric-manifolds.ipynb`](chapter-03-geometric-manifolds/03-geometric-manifolds.ipynb) |
# | Chapter 4 | The Structure of Discrete Groups | 209-288 | [`04-the-structure-of-discrete-groups.ipynb`](chapter-04-the-structure-of-discrete-groups/04-the-structure-of-discrete-groups.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Three-Dimensional Geometry and Topology: 4 canonical units

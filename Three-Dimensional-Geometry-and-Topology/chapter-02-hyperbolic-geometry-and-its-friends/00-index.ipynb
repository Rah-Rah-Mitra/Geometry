# %% [markdown]
# # Chapter 2: Hyperbolic Geometry and Its Friends
#
# Source span: printed pages `43-108`.
#
# Canonical notebook: [`02-hyperbolic-geometry-and-its-friends.ipynb`](02-hyperbolic-geometry-and-its-friends.ipynb).
#
# Focus: Negatively curved surfaces, inversive models, hyperboloid and Klein models, hyperbolic computations, isometries, complex coordinates, and three-sphere geometry.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Three-Dimensional-Geometry-and-Topology

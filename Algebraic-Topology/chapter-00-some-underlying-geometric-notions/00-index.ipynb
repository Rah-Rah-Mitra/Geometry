# %% [markdown]
# # Chapter 0: Some Underlying Geometric Notions
#
# Source span: printed pages `1-20`.
#
# Canonical notebook: [`00-some-underlying-geometric-notions.ipynb`](00-some-underlying-geometric-notions.ipynb).
#
# Focus: CW complexes, quotient spaces, deformation, homotopy, and geometric models for algebraic topology.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Algebraic-Topology

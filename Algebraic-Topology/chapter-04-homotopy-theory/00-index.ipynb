# %% [markdown]
# # Chapter 4: Homotopy Theory
#
# Source span: printed pages `337-518`.
#
# Focus: Homotopy groups, fibrations, obstruction ideas, spectral sequence orientation, and stable phenomena.
#
# Canonical notebook: [`04-homotopy-theory.ipynb`](04-homotopy-theory.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Algebraic Topology
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 0 | Some Underlying Geometric Notions | 1-20 | [`00-some-underlying-geometric-notions.ipynb`](chapter-00-some-underlying-geometric-notions/00-some-underlying-geometric-notions.ipynb) |
# | Chapter 1 | The Fundamental Group | 21-96 | [`01-the-fundamental-group.ipynb`](chapter-01-the-fundamental-group/01-the-fundamental-group.ipynb) |
# | Chapter 2 | Homology | 97-184 | [`02-homology.ipynb`](chapter-02-homology/02-homology.ipynb) |
# | Chapter 3 | Cohomology | 185-336 | [`03-cohomology.ipynb`](chapter-03-cohomology/03-cohomology.ipynb) |
# | Chapter 4 | Homotopy Theory | 337-518 | [`04-homotopy-theory.ipynb`](chapter-04-homotopy-theory/04-homotopy-theory.ipynb) |
# | Appendix A | Appendix | 519-532 | [`appendix-a-appendix.ipynb`](appendix-a-appendix/appendix-a-appendix.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Algebraic Topology: 6 canonical units

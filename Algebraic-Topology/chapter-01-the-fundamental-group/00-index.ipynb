# %% [markdown]
# # Chapter 1: The Fundamental Group
#
# Source span: printed pages `21-96`.
#
# Canonical notebook: [`01-the-fundamental-group.ipynb`](01-the-fundamental-group.ipynb).
#
# Focus: Paths, homotopy, covering spaces, van Kampen, graphs, surfaces, and group presentations.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Algebraic-Topology

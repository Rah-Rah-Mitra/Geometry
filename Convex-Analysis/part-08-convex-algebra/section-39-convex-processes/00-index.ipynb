# %% [markdown]
# # Section 39: Convex Processes
#
# [Back to Part 8 index](../00-part-index.ipynb)
#
# - Canonical notebook: [39-convex-processes.ipynb](39-convex-processes.ipynb)
# - Source span: printed pages 413-424; PDF pages 431-442
# - Artifact subtree: `artifacts/part-08-convex-algebra/section-39-convex-processes`
# - Visual center: A cone-valued process maps one input ray to a wedge of outputs through a convex graph.
# - Check: The graph samples are closed under positive scaling and convex addition.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 38: The Algebra of Bifunctions
#
# [Back to Part 8 index](../00-part-index.ipynb)
#
# - Canonical notebook: [38-algebra-of-bifunctions.ipynb](38-algebra-of-bifunctions.ipynb)
# - Source span: printed pages 401-412; PDF pages 419-430
# - Artifact subtree: `artifacts/part-08-convex-algebra/section-38-algebra-of-bifunctions`
# - Visual center: A small matrix model visualizes the algebraic shape of adding and composing convex bifunction analogues.
# - Check: The displayed matrices satisfy the adjoint-of-composition identity.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Part 8: Convex Algebra
#
# [Back to book index](../00-book-index.ipynb)
#
# - [38. The Algebra of Bifunctions](section-38-algebra-of-bifunctions/00-index.ipynb) - [canonical notebook](section-38-algebra-of-bifunctions/38-algebra-of-bifunctions.ipynb); PDF pages 419-430; A small matrix model visualizes the algebraic shape of adding and composing convex bifunction analogues.
# - [39. Convex Processes](section-39-convex-processes/00-index.ipynb) - [canonical notebook](section-39-convex-processes/39-convex-processes.ipynb); PDF pages 431-442; A cone-valued process maps one input ray to a wedge of outputs through a convex graph.

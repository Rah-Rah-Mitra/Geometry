# %% [markdown]
# # Section 10: Continuity of Convex Functions
#
# [Back to Part 2 index](../00-part-index.ipynb)
#
# - Canonical notebook: [10-continuity-of-convex-functions.ipynb](10-continuity-of-convex-functions.ipynb)
# - Source span: printed pages 82-94; PDF pages 100-112
# - Artifact subtree: `artifacts/part-02-topological-properties/section-10-continuity-of-convex-functions`
# - Visual center: Secant slopes bracket a convex graph and show why interior continuity is forced.
# - Check: Displayed secant slopes are monotone in the sample order.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

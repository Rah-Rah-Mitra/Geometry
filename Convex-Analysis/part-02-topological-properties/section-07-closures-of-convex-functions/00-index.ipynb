# %% [markdown]
# # Section 7: Closures of Convex Functions
#
# [Back to Part 2 index](../00-part-index.ipynb)
#
# - Canonical notebook: [07-closures-of-convex-functions.ipynb](07-closures-of-convex-functions.ipynb)
# - Source span: printed pages 51-59; PDF pages 69-77
# - Artifact subtree: `artifacts/part-02-topological-properties/section-07-closures-of-convex-functions`
# - Visual center: An endpoint gap is closed by moving from an open epigraph boundary to a closed one.
# - Check: The closed function has the same interior samples and adds the missing boundary value.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

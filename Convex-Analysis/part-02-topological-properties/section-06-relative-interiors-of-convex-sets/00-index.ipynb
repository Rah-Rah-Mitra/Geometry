# %% [markdown]
# # Section 6: Relative Interiors of Convex Sets
#
# [Back to Part 2 index](../00-part-index.ipynb)
#
# - Canonical notebook: [06-relative-interiors-of-convex-sets.ipynb](06-relative-interiors-of-convex-sets.ipynb)
# - Source span: printed pages 43-50; PDF pages 61-68
# - Artifact subtree: `artifacts/part-02-topological-properties/section-06-relative-interiors-of-convex-sets`
# - Visual center: A full-dimensional square, an edge, and a singleton separate ambient from relative interior.
# - Check: Relative interior sample points have the expected affine-hull dimension and boundary status.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

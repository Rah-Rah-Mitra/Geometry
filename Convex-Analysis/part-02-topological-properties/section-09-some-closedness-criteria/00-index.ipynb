# %% [markdown]
# # Section 9: Some Closedness Criteria
#
# [Back to Part 2 index](../00-part-index.ipynb)
#
# - Canonical notebook: [09-some-closedness-criteria.ipynb](09-some-closedness-criteria.ipynb)
# - Source span: printed pages 72-81; PDF pages 90-99
# - Artifact subtree: `artifacts/part-02-topological-properties/section-09-some-closedness-criteria`
# - Visual center: A closed epigraph is projected to a nonclosed interval, making the missing limit visible.
# - Check: The projection has infimum zero but no point with projected coordinate zero.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

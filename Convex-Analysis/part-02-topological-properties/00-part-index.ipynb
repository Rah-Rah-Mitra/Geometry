# %% [markdown]
# # Part 2: Topological Properties
#
# [Back to book index](../00-book-index.ipynb)
#
# - [06. Relative Interiors of Convex Sets](section-06-relative-interiors-of-convex-sets/00-index.ipynb) - [canonical notebook](section-06-relative-interiors-of-convex-sets/06-relative-interiors-of-convex-sets.ipynb); PDF pages 61-68; A full-dimensional square, an edge, and a singleton separate ambient from relative interior.
# - [07. Closures of Convex Functions](section-07-closures-of-convex-functions/00-index.ipynb) - [canonical notebook](section-07-closures-of-convex-functions/07-closures-of-convex-functions.ipynb); PDF pages 69-77; An endpoint gap is closed by moving from an open epigraph boundary to a closed one.
# - [08. Recession Cones and Unboundedness](section-08-recession-cones-and-unboundedness/00-index.ipynb) - [canonical notebook](section-08-recession-cones-and-unboundedness/08-recession-cones-and-unboundedness.ipynb); PDF pages 78-89; An unbounded convex region is annotated by every direction in which it can recede.
# - [09. Some Closedness Criteria](section-09-some-closedness-criteria/00-index.ipynb) - [canonical notebook](section-09-some-closedness-criteria/09-some-closedness-criteria.ipynb); PDF pages 90-99; A closed epigraph is projected to a nonclosed interval, making the missing limit visible.
# - [10. Continuity of Convex Functions](section-10-continuity-of-convex-functions/00-index.ipynb) - [canonical notebook](section-10-continuity-of-convex-functions/10-continuity-of-convex-functions.ipynb); PDF pages 100-112; Secant slopes bracket a convex graph and show why interior continuity is forced.

# %% [markdown]
# # Section 8: Recession Cones and Unboundedness
#
# [Back to Part 2 index](../00-part-index.ipynb)
#
# - Canonical notebook: [08-recession-cones-and-unboundedness.ipynb](08-recession-cones-and-unboundedness.ipynb)
# - Source span: printed pages 60-71; PDF pages 78-89
# - Artifact subtree: `artifacts/part-02-topological-properties/section-08-recession-cones-and-unboundedness`
# - Visual center: An unbounded convex region is annotated by every direction in which it can recede.
# - Check: Adding a recession direction keeps sampled points inside the set.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

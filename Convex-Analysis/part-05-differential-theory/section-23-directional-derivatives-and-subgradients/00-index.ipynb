# %% [markdown]
# # Section 23: Directional Derivatives and Subgradients
#
# [Back to Part 5 index](../00-part-index.ipynb)
#
# - Canonical notebook: [23-directional-derivatives-and-subgradients.ipynb](23-directional-derivatives-and-subgradients.ipynb)
# - Source span: printed pages 213-226; PDF pages 231-244
# - Artifact subtree: `artifacts/part-05-differential-theory/section-23-directional-derivatives-and-subgradients`
# - Visual center: The absolute-value cusp displays a full interval of supporting slopes at one point.
# - Check: Every sampled supporting line remains below the convex graph.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 25: Differentiability of Convex Functions
#
# [Back to Part 5 index](../00-part-index.ipynb)
#
# - Canonical notebook: [25-differentiability-of-convex-functions.ipynb](25-differentiability-of-convex-functions.ipynb)
# - Source span: printed pages 241-250; PDF pages 259-268
# - Artifact subtree: `artifacts/part-05-differential-theory/section-25-differentiability-of-convex-functions`
# - Visual center: A smooth quadratic and a kinked absolute-value term separate gradient from subgradient behavior.
# - Check: Central finite differences match the analytic gradient away from the kink.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

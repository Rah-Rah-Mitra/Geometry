# %% [markdown]
# # Part 5: Differential Theory
#
# [Back to book index](../00-book-index.ipynb)
#
# - [23. Directional Derivatives and Subgradients](section-23-directional-derivatives-and-subgradients/00-index.ipynb) - [canonical notebook](section-23-directional-derivatives-and-subgradients/23-directional-derivatives-and-subgradients.ipynb); PDF pages 231-244; The absolute-value cusp displays a full interval of supporting slopes at one point.
# - [24. Differential Continuity and Monotonicity](section-24-differential-continuity-and-monotonicity/00-index.ipynb) - [canonical notebook](section-24-differential-continuity-and-monotonicity/24-differential-continuity-and-monotonicity.ipynb); PDF pages 245-258; A piecewise-linear convex function produces a monotone vertical-jump subgradient graph.
# - [25. Differentiability of Convex Functions](section-25-differentiability-of-convex-functions/00-index.ipynb) - [canonical notebook](section-25-differentiability-of-convex-functions/25-differentiability-of-convex-functions.ipynb); PDF pages 259-268; A smooth quadratic and a kinked absolute-value term separate gradient from subgradient behavior.
# - [26. The Legendre Transformation](section-26-legendre-transformation/00-index.ipynb) - [canonical notebook](section-26-legendre-transformation/26-legendre-transformation.ipynb); PDF pages 269-280; A strictly convex quadratic sends primal positions to slopes and back through the conjugate.

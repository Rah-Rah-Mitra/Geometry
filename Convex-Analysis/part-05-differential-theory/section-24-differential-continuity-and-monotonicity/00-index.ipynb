# %% [markdown]
# # Section 24: Differential Continuity and Monotonicity
#
# [Back to Part 5 index](../00-part-index.ipynb)
#
# - Canonical notebook: [24-differential-continuity-and-monotonicity.ipynb](24-differential-continuity-and-monotonicity.ipynb)
# - Source span: printed pages 227-240; PDF pages 245-258
# - Artifact subtree: `artifacts/part-05-differential-theory/section-24-differential-continuity-and-monotonicity`
# - Visual center: A piecewise-linear convex function produces a monotone vertical-jump subgradient graph.
# - Check: All sampled pairs satisfy the monotonicity inequality.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

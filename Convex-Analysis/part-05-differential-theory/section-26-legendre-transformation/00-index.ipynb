# %% [markdown]
# # Section 26: The Legendre Transformation
#
# [Back to Part 5 index](../00-part-index.ipynb)
#
# - Canonical notebook: [26-legendre-transformation.ipynb](26-legendre-transformation.ipynb)
# - Source span: printed pages 251-262; PDF pages 269-280
# - Artifact subtree: `artifacts/part-05-differential-theory/section-26-legendre-transformation`
# - Visual center: A strictly convex quadratic sends primal positions to slopes and back through the conjugate.
# - Check: The primal gradient and conjugate gradient invert one another on the sample grid.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 2: Convex Sets and Cones
#
# [Back to Part 1 index](../00-part-index.ipynb)
#
# - Canonical notebook: [02-convex-sets-and-cones.ipynb](02-convex-sets-and-cones.ipynb)
# - Source span: printed pages 10-15; PDF pages 28-33
# - Artifact subtree: `artifacts/part-01-basic-concepts/section-02-convex-sets-and-cones`
# - Visual center: Segments inside a convex polygon are compared with cone rays and a half-space cut.
# - Check: Midpoints stay in the convex set, cone sums stay in the cone, and the half-space sign is correct.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 1: Affine Sets
#
# [Back to Part 1 index](../00-part-index.ipynb)
#
# - Canonical notebook: [01-affine-sets.ipynb](01-affine-sets.ipynb)
# - Source span: printed pages 3-9; PDF pages 21-27
# - Artifact subtree: `artifacts/part-01-basic-concepts/section-01-affine-sets`
# - Visual center: A point cloud is extended to its affine hull while a normal vector exposes the hyperplane equation.
# - Check: Affine coefficients add to one and the recovered point lies on the displayed affine hull.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

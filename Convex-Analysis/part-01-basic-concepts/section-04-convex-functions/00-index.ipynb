# %% [markdown]
# # Section 4: Convex Functions
#
# [Back to Part 1 index](../00-part-index.ipynb)
#
# - Canonical notebook: [04-convex-functions.ipynb](04-convex-functions.ipynb)
# - Source span: printed pages 23-31; PDF pages 41-49
# - Artifact subtree: `artifacts/part-01-basic-concepts/section-04-convex-functions`
# - Visual center: A convex curve is taught through its epigraph rather than only through its graph.
# - Check: A sampled Jensen inequality is nonnegative and the epigraph points sit above the curve.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

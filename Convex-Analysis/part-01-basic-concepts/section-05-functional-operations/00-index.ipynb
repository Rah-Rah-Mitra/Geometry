# %% [markdown]
# # Section 5: Functional Operations
#
# [Back to Part 1 index](../00-part-index.ipynb)
#
# - Canonical notebook: [05-functional-operations.ipynb](05-functional-operations.ipynb)
# - Source span: printed pages 32-42; PDF pages 50-60
# - Artifact subtree: `artifacts/part-01-basic-concepts/section-05-functional-operations`
# - Visual center: Pointwise maximum and sum operations are plotted as generators of new convex functions.
# - Check: Midpoint convexity survives the displayed functional operations on the sampled grid.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

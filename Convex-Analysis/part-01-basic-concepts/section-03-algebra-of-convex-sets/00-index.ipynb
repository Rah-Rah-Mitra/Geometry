# %% [markdown]
# # Section 3: The Algebra of Convex Sets
#
# [Back to Part 1 index](../00-part-index.ipynb)
#
# - Canonical notebook: [03-algebra-of-convex-sets.ipynb](03-algebra-of-convex-sets.ipynb)
# - Source span: printed pages 16-22; PDF pages 34-40
# - Artifact subtree: `artifacts/part-01-basic-concepts/section-03-algebra-of-convex-sets`
# - Visual center: Two small convex bodies are added pointwise, then their support values confirm the algebra.
# - Check: A support value of the sum equals the sum of support values in the same direction.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

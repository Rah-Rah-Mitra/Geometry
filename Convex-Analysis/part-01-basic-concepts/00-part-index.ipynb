# %% [markdown]
# # Part 1: Basic Concepts
#
# [Back to book index](../00-book-index.ipynb)
#
# - [01. Affine Sets](section-01-affine-sets/00-index.ipynb) - [canonical notebook](section-01-affine-sets/01-affine-sets.ipynb); PDF pages 21-27; A point cloud is extended to its affine hull while a normal vector exposes the hyperplane equation.
# - [02. Convex Sets and Cones](section-02-convex-sets-and-cones/00-index.ipynb) - [canonical notebook](section-02-convex-sets-and-cones/02-convex-sets-and-cones.ipynb); PDF pages 28-33; Segments inside a convex polygon are compared with cone rays and a half-space cut.
# - [03. The Algebra of Convex Sets](section-03-algebra-of-convex-sets/00-index.ipynb) - [canonical notebook](section-03-algebra-of-convex-sets/03-algebra-of-convex-sets.ipynb); PDF pages 34-40; Two small convex bodies are added pointwise, then their support values confirm the algebra.
# - [04. Convex Functions](section-04-convex-functions/00-index.ipynb) - [canonical notebook](section-04-convex-functions/04-convex-functions.ipynb); PDF pages 41-49; A convex curve is taught through its epigraph rather than only through its graph.
# - [05. Functional Operations](section-05-functional-operations/00-index.ipynb) - [canonical notebook](section-05-functional-operations/05-functional-operations.ipynb); PDF pages 50-60; Pointwise maximum and sum operations are plotted as generators of new convex functions.

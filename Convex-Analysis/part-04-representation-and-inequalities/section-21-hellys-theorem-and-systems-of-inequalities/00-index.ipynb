# %% [markdown]
# # Section 21: Helly's Theorem and Systems of Inequalities
#
# [Back to Part 4 index](../00-part-index.ipynb)
#
# - Canonical notebook: [21-hellys-theorem-and-systems-of-inequalities.ipynb](21-hellys-theorem-and-systems-of-inequalities.ipynb)
# - Source span: printed pages 185-197; PDF pages 203-215
# - Artifact subtree: `artifacts/part-04-representation-and-inequalities/section-21-hellys-theorem-and-systems-of-inequalities`
# - Visual center: Several convex half-planes are inspected through a small witness point and subfamilies.
# - Check: The witness point satisfies every displayed inequality.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

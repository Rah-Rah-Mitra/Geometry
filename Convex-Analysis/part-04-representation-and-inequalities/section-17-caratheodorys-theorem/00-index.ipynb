# %% [markdown]
# # Section 17: Caratheodory's Theorem
#
# [Back to Part 4 index](../00-part-index.ipynb)
#
# - Canonical notebook: [17-caratheodorys-theorem.ipynb](17-caratheodorys-theorem.ipynb)
# - Source span: printed pages 153-161; PDF pages 171-179
# - Artifact subtree: `artifacts/part-04-representation-and-inequalities/section-17-caratheodorys-theorem`
# - Visual center: A point in a planar hull is represented by three vertices rather than by all points.
# - Check: The reduced barycentric coefficients are nonnegative and add to one.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

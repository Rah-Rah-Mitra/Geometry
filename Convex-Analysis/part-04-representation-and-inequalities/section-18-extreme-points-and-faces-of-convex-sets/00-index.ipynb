# %% [markdown]
# # Section 18: Extreme Points and Faces of Convex Sets
#
# [Back to Part 4 index](../00-part-index.ipynb)
#
# - Canonical notebook: [18-extreme-points-and-faces-of-convex-sets.ipynb](18-extreme-points-and-faces-of-convex-sets.ipynb)
# - Source span: printed pages 162-169; PDF pages 180-187
# - Artifact subtree: `artifacts/part-04-representation-and-inequalities/section-18-extreme-points-and-faces-of-convex-sets`
# - Visual center: A support line exposes a face of a polygon and distinguishes vertices from edge interiors.
# - Check: All points on the exposed face share the same support value.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

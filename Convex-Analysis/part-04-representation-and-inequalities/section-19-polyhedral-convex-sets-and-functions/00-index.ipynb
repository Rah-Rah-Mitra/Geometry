# %% [markdown]
# # Section 19: Polyhedral Convex Sets and Functions
#
# [Back to Part 4 index](../00-part-index.ipynb)
#
# - Canonical notebook: [19-polyhedral-convex-sets-and-functions.ipynb](19-polyhedral-convex-sets-and-functions.ipynb)
# - Source span: printed pages 170-178; PDF pages 188-196
# - Artifact subtree: `artifacts/part-04-representation-and-inequalities/section-19-polyhedral-convex-sets-and-functions`
# - Visual center: A max of affine functions is plotted as a polyhedral convex function with active regions.
# - Check: Each sampled function value equals the maximum of its affine pieces.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 20: Some Applications of Polyhedral Convexity
#
# [Back to Part 4 index](../00-part-index.ipynb)
#
# - Canonical notebook: [20-applications-of-polyhedral-convexity.ipynb](20-applications-of-polyhedral-convexity.ipynb)
# - Source span: printed pages 179-184; PDF pages 197-202
# - Artifact subtree: `artifacts/part-04-representation-and-inequalities/section-20-applications-of-polyhedral-convexity`
# - Visual center: A small linear program highlights active inequalities and a vertex certificate.
# - Check: The selected optimum satisfies all inequalities and ties the active constraints.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

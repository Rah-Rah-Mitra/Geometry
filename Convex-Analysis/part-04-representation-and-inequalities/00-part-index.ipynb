# %% [markdown]
# # Part 4: Representation and Inequalities
#
# [Back to book index](../00-book-index.ipynb)
#
# - [17. Caratheodory's Theorem](section-17-caratheodorys-theorem/00-index.ipynb) - [canonical notebook](section-17-caratheodorys-theorem/17-caratheodorys-theorem.ipynb); PDF pages 171-179; A point in a planar hull is represented by three vertices rather than by all points.
# - [18. Extreme Points and Faces of Convex Sets](section-18-extreme-points-and-faces-of-convex-sets/00-index.ipynb) - [canonical notebook](section-18-extreme-points-and-faces-of-convex-sets/18-extreme-points-and-faces-of-convex-sets.ipynb); PDF pages 180-187; A support line exposes a face of a polygon and distinguishes vertices from edge interiors.
# - [19. Polyhedral Convex Sets and Functions](section-19-polyhedral-convex-sets-and-functions/00-index.ipynb) - [canonical notebook](section-19-polyhedral-convex-sets-and-functions/19-polyhedral-convex-sets-and-functions.ipynb); PDF pages 188-196; A max of affine functions is plotted as a polyhedral convex function with active regions.
# - [20. Some Applications of Polyhedral Convexity](section-20-applications-of-polyhedral-convexity/00-index.ipynb) - [canonical notebook](section-20-applications-of-polyhedral-convexity/20-applications-of-polyhedral-convexity.ipynb); PDF pages 197-202; A small linear program highlights active inequalities and a vertex certificate.
# - [21. Helly's Theorem and Systems of Inequalities](section-21-hellys-theorem-and-systems-of-inequalities/00-index.ipynb) - [canonical notebook](section-21-hellys-theorem-and-systems-of-inequalities/21-hellys-theorem-and-systems-of-inequalities.ipynb); PDF pages 203-215; Several convex half-planes are inspected through a small witness point and subfamilies.
# - [22. Linear Inequalities](section-22-linear-inequalities/00-index.ipynb) - [canonical notebook](section-22-linear-inequalities/22-linear-inequalities.ipynb); PDF pages 216-230; A target vector outside a cone is separated by a certificate normal.

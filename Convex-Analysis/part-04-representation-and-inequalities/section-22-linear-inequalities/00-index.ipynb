# %% [markdown]
# # Section 22: Linear Inequalities
#
# [Back to Part 4 index](../00-part-index.ipynb)
#
# - Canonical notebook: [22-linear-inequalities.ipynb](22-linear-inequalities.ipynb)
# - Source span: printed pages 198-212; PDF pages 216-230
# - Artifact subtree: `artifacts/part-04-representation-and-inequalities/section-22-linear-inequalities`
# - Visual center: A target vector outside a cone is separated by a certificate normal.
# - Check: The certificate is nonnegative on cone generators and negative on the rejected target.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

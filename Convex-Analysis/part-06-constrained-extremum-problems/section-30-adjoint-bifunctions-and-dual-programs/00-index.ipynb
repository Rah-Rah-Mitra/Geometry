# %% [markdown]
# # Section 30: Adjoint Bifunctions and Dual Programs
#
# [Back to Part 6 index](../00-part-index.ipynb)
#
# - Canonical notebook: [30-adjoint-bifunctions-and-dual-programs.ipynb](30-adjoint-bifunctions-and-dual-programs.ipynb)
# - Source span: printed pages 307-326; PDF pages 325-344
# - Artifact subtree: `artifacts/part-06-constrained-extremum-problems/section-30-adjoint-bifunctions-and-dual-programs`
# - Visual center: Primal and dual objective curves are paired to make weak duality a visible inequality.
# - Check: Every displayed primal value is no smaller than the paired dual lower bound.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

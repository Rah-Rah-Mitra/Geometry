# %% [markdown]
# # Section 32: The Maximum of a Convex Function
#
# [Back to Part 6 index](../00-part-index.ipynb)
#
# - Canonical notebook: [32-maximum-of-a-convex-function.ipynb](32-maximum-of-a-convex-function.ipynb)
# - Source span: printed pages 342-348; PDF pages 360-366
# - Artifact subtree: `artifacts/part-06-constrained-extremum-problems/section-32-maximum-of-a-convex-function`
# - Visual center: A convex function over a polygon puts its maximum on a vertex rather than in the middle.
# - Check: The maximum over a sampled grid is bounded by the maximum over vertices.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

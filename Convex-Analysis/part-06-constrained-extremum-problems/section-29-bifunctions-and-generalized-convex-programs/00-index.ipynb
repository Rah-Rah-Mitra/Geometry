# %% [markdown]
# # Section 29: Bifunctions and Generalized Convex Programs
#
# [Back to Part 6 index](../00-part-index.ipynb)
#
# - Canonical notebook: [29-bifunctions-and-generalized-convex-programs.ipynb](29-bifunctions-and-generalized-convex-programs.ipynb)
# - Source span: printed pages 291-306; PDF pages 309-324
# - Artifact subtree: `artifacts/part-06-constrained-extremum-problems/section-29-bifunctions-and-generalized-convex-programs`
# - Visual center: A perturbation parameter moves the right-hand side and traces a convex value function.
# - Check: The sampled value curve satisfies midpoint convexity.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

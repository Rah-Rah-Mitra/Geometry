# %% [markdown]
# # Part 6: Constrained Extremum Problems
#
# [Back to book index](../00-book-index.ipynb)
#
# - [27. The Minimum of a Convex Function](section-27-minimum-of-a-convex-function/00-index.ipynb) - [canonical notebook](section-27-minimum-of-a-convex-function/27-minimum-of-a-convex-function.ipynb); PDF pages 281-290; Level sets contract toward the minimizer while the subgradient condition marks optimality.
# - [28. Ordinary Convex Programs and Lagrange Multipliers](section-28-ordinary-convex-programs-and-lagrange-multipliers/00-index.ipynb) - [canonical notebook](section-28-ordinary-convex-programs-and-lagrange-multipliers/28-ordinary-convex-programs-and-lagrange-multipliers.ipynb); PDF pages 291-308; A constrained quadratic minimization shows objective contours balanced by active constraint normals.
# - [29. Bifunctions and Generalized Convex Programs](section-29-bifunctions-and-generalized-convex-programs/00-index.ipynb) - [canonical notebook](section-29-bifunctions-and-generalized-convex-programs/29-bifunctions-and-generalized-convex-programs.ipynb); PDF pages 309-324; A perturbation parameter moves the right-hand side and traces a convex value function.
# - [30. Adjoint Bifunctions and Dual Programs](section-30-adjoint-bifunctions-and-dual-programs/00-index.ipynb) - [canonical notebook](section-30-adjoint-bifunctions-and-dual-programs/30-adjoint-bifunctions-and-dual-programs.ipynb); PDF pages 325-344; Primal and dual objective curves are paired to make weak duality a visible inequality.
# - [31. Fenchel's Duality Theorem](section-31-fenchels-duality-theorem/00-index.ipynb) - [canonical notebook](section-31-fenchels-duality-theorem/31-fenchels-duality-theorem.ipynb); PDF pages 345-359; A quadratic-plus-indicator problem is paired with its dual support calculation.
# - [32. The Maximum of a Convex Function](section-32-maximum-of-a-convex-function/00-index.ipynb) - [canonical notebook](section-32-maximum-of-a-convex-function/32-maximum-of-a-convex-function.ipynb); PDF pages 360-366; A convex function over a polygon puts its maximum on a vertex rather than in the middle.

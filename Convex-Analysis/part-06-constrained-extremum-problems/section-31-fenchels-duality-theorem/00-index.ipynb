# %% [markdown]
# # Section 31: Fenchel's Duality Theorem
#
# [Back to Part 6 index](../00-part-index.ipynb)
#
# - Canonical notebook: [31-fenchels-duality-theorem.ipynb](31-fenchels-duality-theorem.ipynb)
# - Source span: printed pages 327-341; PDF pages 345-359
# - Artifact subtree: `artifacts/part-06-constrained-extremum-problems/section-31-fenchels-duality-theorem`
# - Visual center: A quadratic-plus-indicator problem is paired with its dual support calculation.
# - Check: The selected primal and dual values agree within numerical tolerance.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 28: Ordinary Convex Programs and Lagrange Multipliers
#
# [Back to Part 6 index](../00-part-index.ipynb)
#
# - Canonical notebook: [28-ordinary-convex-programs-and-lagrange-multipliers.ipynb](28-ordinary-convex-programs-and-lagrange-multipliers.ipynb)
# - Source span: printed pages 273-290; PDF pages 291-308
# - Artifact subtree: `artifacts/part-06-constrained-extremum-problems/section-28-ordinary-convex-programs-and-lagrange-multipliers`
# - Visual center: A constrained quadratic minimization shows objective contours balanced by active constraint normals.
# - Check: Stationarity and complementary slackness residuals are near zero for the displayed solution.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

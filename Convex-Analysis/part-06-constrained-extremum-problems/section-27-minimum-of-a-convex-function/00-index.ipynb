# %% [markdown]
# # Section 27: The Minimum of a Convex Function
#
# [Back to Part 6 index](../00-part-index.ipynb)
#
# - Canonical notebook: [27-minimum-of-a-convex-function.ipynb](27-minimum-of-a-convex-function.ipynb)
# - Source span: printed pages 263-272; PDF pages 281-290
# - Artifact subtree: `artifacts/part-06-constrained-extremum-problems/section-27-minimum-of-a-convex-function`
# - Visual center: Level sets contract toward the minimizer while the subgradient condition marks optimality.
# - Check: The sampled minimizer has zero gradient and the smallest displayed objective value.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

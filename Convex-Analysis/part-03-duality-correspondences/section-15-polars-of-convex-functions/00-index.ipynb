# %% [markdown]
# # Section 15: Polars of Convex Functions
#
# [Back to Part 3 index](../00-part-index.ipynb)
#
# - Canonical notebook: [15-polars-of-convex-functions.ipynb](15-polars-of-convex-functions.ipynb)
# - Source span: printed pages 128-139; PDF pages 146-157
# - Artifact subtree: `artifacts/part-03-duality-correspondences/section-15-polars-of-convex-functions`
# - Visual center: The l1 and l-infinity unit balls show how a norm's polar is read geometrically.
# - Check: The dual norm inequality bounds sampled pairings by the product of primal and dual norms.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

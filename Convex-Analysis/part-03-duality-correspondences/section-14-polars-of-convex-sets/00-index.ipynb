# %% [markdown]
# # Section 14: Polars of Convex Sets
#
# [Back to Part 3 index](../00-part-index.ipynb)
#
# - Canonical notebook: [14-polars-of-convex-sets.ipynb](14-polars-of-convex-sets.ipynb)
# - Source span: printed pages 121-127; PDF pages 139-145
# - Artifact subtree: `artifacts/part-03-duality-correspondences/section-14-polars-of-convex-sets`
# - Visual center: A centrally placed convex body is drawn beside its polar body in dual coordinates.
# - Check: Sampled primal-dual dot products stay below the polar threshold.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

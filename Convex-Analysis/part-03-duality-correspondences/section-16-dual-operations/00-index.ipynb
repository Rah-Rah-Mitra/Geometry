# %% [markdown]
# # Section 16: Dual Operations
#
# [Back to Part 3 index](../00-part-index.ipynb)
#
# - Canonical notebook: [16-dual-operations.ipynb](16-dual-operations.ipynb)
# - Source span: printed pages 140-152; PDF pages 158-170
# - Artifact subtree: `artifacts/part-03-duality-correspondences/section-16-dual-operations`
# - Visual center: Two convex functions combine in primal space while the dual view tracks infimal convolution.
# - Check: A grid infimum is no larger than either unshifted summand and keeps convex midpoint behavior.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

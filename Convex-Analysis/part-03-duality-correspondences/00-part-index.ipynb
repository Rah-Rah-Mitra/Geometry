# %% [markdown]
# # Part 3: Duality Correspondences
#
# [Back to book index](../00-book-index.ipynb)
#
# - [11. Separation Theorems](section-11-separation-theorems/00-index.ipynb) - [canonical notebook](section-11-separation-theorems/11-separation-theorems.ipynb); PDF pages 113-119; Two disjoint convex bodies are certified by a signed-distance separating line.
# - [12. Conjugates of Convex Functions](section-12-conjugates-of-convex-functions/00-index.ipynb) - [canonical notebook](section-12-conjugates-of-convex-functions/12-conjugates-of-convex-functions.ipynb); PDF pages 120-129; A quadratic is reconstructed from its supporting affine minorants indexed by slope.
# - [13. Support Functions](section-13-support-functions/00-index.ipynb) - [canonical notebook](section-13-support-functions/13-support-functions.ipynb); PDF pages 130-138; A polygon is scanned by rotating normals and recording the farthest support line.
# - [14. Polars of Convex Sets](section-14-polars-of-convex-sets/00-index.ipynb) - [canonical notebook](section-14-polars-of-convex-sets/14-polars-of-convex-sets.ipynb); PDF pages 139-145; A centrally placed convex body is drawn beside its polar body in dual coordinates.
# - [15. Polars of Convex Functions](section-15-polars-of-convex-functions/00-index.ipynb) - [canonical notebook](section-15-polars-of-convex-functions/15-polars-of-convex-functions.ipynb); PDF pages 146-157; The l1 and l-infinity unit balls show how a norm's polar is read geometrically.
# - [16. Dual Operations](section-16-dual-operations/00-index.ipynb) - [canonical notebook](section-16-dual-operations/16-dual-operations.ipynb); PDF pages 158-170; Two convex functions combine in primal space while the dual view tracks infimal convolution.

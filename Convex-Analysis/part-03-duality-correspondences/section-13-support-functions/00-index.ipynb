# %% [markdown]
# # Section 13: Support Functions
#
# [Back to Part 3 index](../00-part-index.ipynb)
#
# - Canonical notebook: [13-support-functions.ipynb](13-support-functions.ipynb)
# - Source span: printed pages 112-120; PDF pages 130-138
# - Artifact subtree: `artifacts/part-03-duality-correspondences/section-13-support-functions`
# - Visual center: A polygon is scanned by rotating normals and recording the farthest support line.
# - Check: The support value equals the maximum dot product over the sampled vertices.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Section 11: Separation Theorems
#
# [Back to Part 3 index](../00-part-index.ipynb)
#
# - Canonical notebook: [11-separation-theorems.ipynb](11-separation-theorems.ipynb)
# - Source span: printed pages 95-101; PDF pages 113-119
# - Artifact subtree: `artifacts/part-03-duality-correspondences/section-11-separation-theorems`
# - Visual center: Two disjoint convex bodies are certified by a signed-distance separating line.
# - Check: All points of the two bodies have opposite signed margins with a positive gap.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

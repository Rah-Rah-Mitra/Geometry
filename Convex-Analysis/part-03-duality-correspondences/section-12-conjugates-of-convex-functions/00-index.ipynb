# %% [markdown]
# # Section 12: Conjugates of Convex Functions
#
# [Back to Part 3 index](../00-part-index.ipynb)
#
# - Canonical notebook: [12-conjugates-of-convex-functions.ipynb](12-conjugates-of-convex-functions.ipynb)
# - Source span: printed pages 102-111; PDF pages 120-129
# - Artifact subtree: `artifacts/part-03-duality-correspondences/section-12-conjugates-of-convex-functions`
# - Visual center: A quadratic is reconstructed from its supporting affine minorants indexed by slope.
# - Check: Fenchel equality holds at the slope paired with the sampled primal point.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

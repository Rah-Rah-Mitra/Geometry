# %% [markdown]
# # Section 35: Continuity and Differentiability of Saddle-functions
#
# [Back to Part 7 index](../00-part-index.ipynb)
#
# - Canonical notebook: [35-continuity-and-differentiability-of-saddle-functions.ipynb](35-continuity-and-differentiability-of-saddle-functions.ipynb)
# - Source span: printed pages 370-378; PDF pages 388-396
# - Artifact subtree: `artifacts/part-07-saddle-functions-and-minimax-theory/section-35-continuity-and-differentiability-of-saddle-functions`
# - Visual center: A vector field of partial gradients shows monotone behavior in x and antimonotone behavior in y.
# - Check: The sampled partial-gradient pairing has the expected signs.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

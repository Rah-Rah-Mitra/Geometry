# %% [markdown]
# # Section 36: Minimax Problems
#
# [Back to Part 7 index](../00-part-index.ipynb)
#
# - Canonical notebook: [36-minimax-problems.ipynb](36-minimax-problems.ipynb)
# - Source span: printed pages 379-387; PDF pages 397-405
# - Artifact subtree: `artifacts/part-07-saddle-functions-and-minimax-theory/section-36-minimax-problems`
# - Visual center: A convex-concave payoff on a box shows when min max and max min agree.
# - Check: The computed minmax and maximin values agree for the displayed saddle example.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

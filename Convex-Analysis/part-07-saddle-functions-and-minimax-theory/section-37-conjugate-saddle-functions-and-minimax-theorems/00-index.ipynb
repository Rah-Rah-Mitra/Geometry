# %% [markdown]
# # Section 37: Conjugate Saddle-functions and Minimax Theorems
#
# [Back to Part 7 index](../00-part-index.ipynb)
#
# - Canonical notebook: [37-conjugate-saddle-functions-and-minimax-theorems.ipynb](37-conjugate-saddle-functions-and-minimax-theorems.ipynb)
# - Source span: printed pages 388-400; PDF pages 406-418
# - Artifact subtree: `artifacts/part-07-saddle-functions-and-minimax-theory/section-37-conjugate-saddle-functions-and-minimax-theorems`
# - Visual center: A quadratic saddle is transformed through a conjugate pairing and compared with the original.
# - Check: The sampled biconjugate reconstruction matches the original quadratic saddle values.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

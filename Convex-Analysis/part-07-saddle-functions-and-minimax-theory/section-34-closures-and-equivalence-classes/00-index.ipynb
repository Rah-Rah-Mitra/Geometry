# %% [markdown]
# # Section 34: Closures and Equivalence Classes
#
# [Back to Part 7 index](../00-part-index.ipynb)
#
# - Canonical notebook: [34-closures-and-equivalence-classes.ipynb](34-closures-and-equivalence-classes.ipynb)
# - Source span: printed pages 359-369; PDF pages 377-387
# - Artifact subtree: `artifacts/part-07-saddle-functions-and-minimax-theory/section-34-closures-and-equivalence-classes`
# - Visual center: A saddle surface over an open rectangle is compared with its closed boundary extension.
# - Check: Boundary samples match the closure values prescribed by the extension.
#
# The notebook is original course material and should be revised directly for deeper section-specific teaching passes.

# %% [markdown]
# # Part 7: Saddle-Functions and Minimax Theory
#
# [Back to book index](../00-book-index.ipynb)
#
# - [33. Saddle-Functions](section-33-saddle-functions/00-index.ipynb) - [canonical notebook](section-33-saddle-functions/33-saddle-functions.ipynb); PDF pages 367-376; Contours of a convex-concave quadratic display descent in one variable and ascent in another.
# - [34. Closures and Equivalence Classes](section-34-closures-and-equivalence-classes/00-index.ipynb) - [canonical notebook](section-34-closures-and-equivalence-classes/34-closures-and-equivalence-classes.ipynb); PDF pages 377-387; A saddle surface over an open rectangle is compared with its closed boundary extension.
# - [35. Continuity and Differentiability of Saddle-functions](section-35-continuity-and-differentiability-of-saddle-functions/00-index.ipynb) - [canonical notebook](section-35-continuity-and-differentiability-of-saddle-functions/35-continuity-and-differentiability-of-saddle-functions.ipynb); PDF pages 388-396; A vector field of partial gradients shows monotone behavior in x and antimonotone behavior in y.
# - [36. Minimax Problems](section-36-minimax-problems/00-index.ipynb) - [canonical notebook](section-36-minimax-problems/36-minimax-problems.ipynb); PDF pages 397-405; A convex-concave payoff on a box shows when min max and max min agree.
# - [37. Conjugate Saddle-functions and Minimax Theorems](section-37-conjugate-saddle-functions-and-minimax-theorems/00-index.ipynb) - [canonical notebook](section-37-conjugate-saddle-functions-and-minimax-theorems/37-conjugate-saddle-functions-and-minimax-theorems.ipynb); PDF pages 406-418; A quadratic saddle is transformed through a conjugate pairing and compared with the original.

# %% [markdown]
# # Convex Analysis - Visualization-First Notebook Course
#
# This standalone course follows the numbered-section structure of Rockafellar's local PDF. It uses original exposition, synthetic diagrams, numerical checks, and proof-state maps; it does not copy textbook prose or figures.
#
# Source rule: body printed page `p` maps to PDF page `p + 18`.
#
# ## Part 1: Basic Concepts
# - [Part index](part-01-basic-concepts/00-part-index.ipynb)
# - [01. Affine Sets](part-01-basic-concepts/section-01-affine-sets/00-index.ipynb) - [canonical notebook](part-01-basic-concepts/section-01-affine-sets/01-affine-sets.ipynb); printed pages 3-9; affine hulls, translations, hyperplanes, barycentric coordinates.
# - [02. Convex Sets and Cones](part-01-basic-concepts/section-02-convex-sets-and-cones/00-index.ipynb) - [canonical notebook](part-01-basic-concepts/section-02-convex-sets-and-cones/02-convex-sets-and-cones.ipynb); printed pages 10-15; convex combinations, half-spaces, cones, convex hull generation.
# - [03. The Algebra of Convex Sets](part-01-basic-concepts/section-03-algebra-of-convex-sets/00-index.ipynb) - [canonical notebook](part-01-basic-concepts/section-03-algebra-of-convex-sets/03-algebra-of-convex-sets.ipynb); printed pages 16-22; Minkowski sums, scalar multiplication, convex hulls, linear images.
# - [04. Convex Functions](part-01-basic-concepts/section-04-convex-functions/00-index.ipynb) - [canonical notebook](part-01-basic-concepts/section-04-convex-functions/04-convex-functions.ipynb); printed pages 23-31; Jensen inequality, epigraphs, indicators, perspective from sets to functions.
# - [05. Functional Operations](part-01-basic-concepts/section-05-functional-operations/00-index.ipynb) - [canonical notebook](part-01-basic-concepts/section-05-functional-operations/05-functional-operations.ipynb); printed pages 32-42; addition, supremum, infimal projection, perspective, generated examples.
#
# ## Part 2: Topological Properties
# - [Part index](part-02-topological-properties/00-part-index.ipynb)
# - [06. Relative Interiors of Convex Sets](part-02-topological-properties/section-06-relative-interiors-of-convex-sets/00-index.ipynb) - [canonical notebook](part-02-topological-properties/section-06-relative-interiors-of-convex-sets/06-relative-interiors-of-convex-sets.ipynb); printed pages 43-50; relative interior, affine hull, boundary behavior under convex operations.
# - [07. Closures of Convex Functions](part-02-topological-properties/section-07-closures-of-convex-functions/00-index.ipynb) - [canonical notebook](part-02-topological-properties/section-07-closures-of-convex-functions/07-closures-of-convex-functions.ipynb); printed pages 51-59; lower semicontinuity, closed epigraphs, closure of a proper convex function.
# - [08. Recession Cones and Unboundedness](part-02-topological-properties/section-08-recession-cones-and-unboundedness/00-index.ipynb) - [canonical notebook](part-02-topological-properties/section-08-recession-cones-and-unboundedness/08-recession-cones-and-unboundedness.ipynb); printed pages 60-71; directions at infinity, recession cones of sets and functions, growth behavior.
# - [09. Some Closedness Criteria](part-02-topological-properties/section-09-some-closedness-criteria/00-index.ipynb) - [canonical notebook](part-02-topological-properties/section-09-some-closedness-criteria/09-some-closedness-criteria.ipynb); printed pages 72-81; closed convex images, projections, recession obstructions, existence criteria.
# - [10. Continuity of Convex Functions](part-02-topological-properties/section-10-continuity-of-convex-functions/00-index.ipynb) - [canonical notebook](part-02-topological-properties/section-10-continuity-of-convex-functions/10-continuity-of-convex-functions.ipynb); printed pages 82-94; continuity on relative interiors, secant estimates, convergence of convex functions.
#
# ## Part 3: Duality Correspondences
# - [Part index](part-03-duality-correspondences/00-part-index.ipynb)
# - [11. Separation Theorems](part-03-duality-correspondences/section-11-separation-theorems/00-index.ipynb) - [canonical notebook](part-03-duality-correspondences/section-11-separation-theorems/11-separation-theorems.ipynb); printed pages 95-101; proper and strong separation, supporting hyperplanes, half-space certificates.
# - [12. Conjugates of Convex Functions](part-03-duality-correspondences/section-12-conjugates-of-convex-functions/00-index.ipynb) - [canonical notebook](part-03-duality-correspondences/section-12-conjugates-of-convex-functions/12-conjugates-of-convex-functions.ipynb); printed pages 102-111; Fenchel conjugacy, affine minorants, biconjugacy, dual slopes.
# - [13. Support Functions](part-03-duality-correspondences/section-13-support-functions/00-index.ipynb) - [canonical notebook](part-03-duality-correspondences/section-13-support-functions/13-support-functions.ipynb); printed pages 112-120; support functions, exposed faces, domain and level-set support calculations.
# - [14. Polars of Convex Sets](part-03-duality-correspondences/section-14-polars-of-convex-sets/00-index.ipynb) - [canonical notebook](part-03-duality-correspondences/section-14-polars-of-convex-sets/14-polars-of-convex-sets.ipynb); printed pages 121-127; polar sets, cone polarity, closed convex sets containing the origin.
# - [15. Polars of Convex Functions](part-03-duality-correspondences/section-15-polars-of-convex-functions/00-index.ipynb) - [canonical notebook](part-03-duality-correspondences/section-15-polars-of-convex-functions/15-polars-of-convex-functions.ipynb); printed pages 128-139; polar gauges, dual norms, functional polarity, approximation examples.
# - [16. Dual Operations](part-03-duality-correspondences/section-16-dual-operations/00-index.ipynb) - [canonical notebook](part-03-duality-correspondences/section-16-dual-operations/16-dual-operations.ipynb); printed pages 140-152; duality of addition and infimal convolution, closure terms, operation pairs.
#
# ## Part 4: Representation and Inequalities
# - [Part index](part-04-representation-and-inequalities/00-part-index.ipynb)
# - [17. Caratheodory's Theorem](part-04-representation-and-inequalities/section-17-caratheodorys-theorem/00-index.ipynb) - [canonical notebook](part-04-representation-and-inequalities/section-17-caratheodorys-theorem/17-caratheodorys-theorem.ipynb); printed pages 153-161; small convex representations, dimension count, convex hull reduction.
# - [18. Extreme Points and Faces of Convex Sets](part-04-representation-and-inequalities/section-18-extreme-points-and-faces-of-convex-sets/00-index.ipynb) - [canonical notebook](part-04-representation-and-inequalities/section-18-extreme-points-and-faces-of-convex-sets/18-extreme-points-and-faces-of-convex-sets.ipynb); printed pages 162-169; faces, exposed points, extreme directions, tangent hyperplanes.
# - [19. Polyhedral Convex Sets and Functions](part-04-representation-and-inequalities/section-19-polyhedral-convex-sets-and-functions/00-index.ipynb) - [canonical notebook](part-04-representation-and-inequalities/section-19-polyhedral-convex-sets-and-functions/19-polyhedral-convex-sets-and-functions.ipynb); printed pages 170-178; finite half-space descriptions, piecewise-linear functions, polyhedral epigraphs.
# - [20. Some Applications of Polyhedral Convexity](part-04-representation-and-inequalities/section-20-applications-of-polyhedral-convexity/00-index.ipynb) - [canonical notebook](part-04-representation-and-inequalities/section-20-applications-of-polyhedral-convexity/20-applications-of-polyhedral-convexity.ipynb); printed pages 179-184; polyhedral refinements, active constraints, stronger closedness and existence statements.
# - [21. Helly's Theorem and Systems of Inequalities](part-04-representation-and-inequalities/section-21-hellys-theorem-and-systems-of-inequalities/00-index.ipynb) - [canonical notebook](part-04-representation-and-inequalities/section-21-hellys-theorem-and-systems-of-inequalities/21-hellys-theorem-and-systems-of-inequalities.ipynb); printed pages 185-197; finite intersection tests, nonlinear inequalities, Helly dimension logic.
# - [22. Linear Inequalities](part-04-representation-and-inequalities/section-22-linear-inequalities/00-index.ipynb) - [canonical notebook](part-04-representation-and-inequalities/section-22-linear-inequalities/22-linear-inequalities.ipynb); printed pages 198-212; Farkas alternatives, strict and weak inequalities, linear certificates.
#
# ## Part 5: Differential Theory
# - [Part index](part-05-differential-theory/00-part-index.ipynb)
# - [23. Directional Derivatives and Subgradients](part-05-differential-theory/section-23-directional-derivatives-and-subgradients/00-index.ipynb) - [canonical notebook](part-05-differential-theory/section-23-directional-derivatives-and-subgradients/23-directional-derivatives-and-subgradients.ipynb); printed pages 213-226; directional derivatives, subgradient inequality, subdifferential calculus.
# - [24. Differential Continuity and Monotonicity](part-05-differential-theory/section-24-differential-continuity-and-monotonicity/00-index.ipynb) - [canonical notebook](part-05-differential-theory/section-24-differential-continuity-and-monotonicity/24-differential-continuity-and-monotonicity.ipynb); printed pages 227-240; monotonicity of subdifferentials, one-dimensional slope curves, graph closure.
# - [25. Differentiability of Convex Functions](part-05-differential-theory/section-25-differentiability-of-convex-functions/00-index.ipynb) - [canonical notebook](part-05-differential-theory/section-25-differentiability-of-convex-functions/25-differentiability-of-convex-functions.ipynb); printed pages 241-250; almost-everywhere gradients, continuity of gradients, smooth versus nonsmooth points.
# - [26. The Legendre Transformation](part-05-differential-theory/section-26-legendre-transformation/00-index.ipynb) - [canonical notebook](part-05-differential-theory/section-26-legendre-transformation/26-legendre-transformation.ipynb); printed pages 251-262; gradient inversion, conjugate smoothness, strict convexity, dual coordinates.
#
# ## Part 6: Constrained Extremum Problems
# - [Part index](part-06-constrained-extremum-problems/00-part-index.ipynb)
# - [27. The Minimum of a Convex Function](part-06-constrained-extremum-problems/section-27-minimum-of-a-convex-function/00-index.ipynb) - [canonical notebook](part-06-constrained-extremum-problems/section-27-minimum-of-a-convex-function/27-minimum-of-a-convex-function.ipynb); printed pages 263-272; existence of minimizers, recession, level sets, optimality by zero subgradient.
# - [28. Ordinary Convex Programs and Lagrange Multipliers](part-06-constrained-extremum-problems/section-28-ordinary-convex-programs-and-lagrange-multipliers/00-index.ipynb) - [canonical notebook](part-06-constrained-extremum-problems/section-28-ordinary-convex-programs-and-lagrange-multipliers/28-ordinary-convex-programs-and-lagrange-multipliers.ipynb); printed pages 273-290; convex constraints, KKT multipliers, complementary slackness, active normals.
# - [29. Bifunctions and Generalized Convex Programs](part-06-constrained-extremum-problems/section-29-bifunctions-and-generalized-convex-programs/00-index.ipynb) - [canonical notebook](part-06-constrained-extremum-problems/section-29-bifunctions-and-generalized-convex-programs/29-bifunctions-and-generalized-convex-programs.ipynb); printed pages 291-306; convex bifunctions, perturbation functions, generalized multipliers.
# - [30. Adjoint Bifunctions and Dual Programs](part-06-constrained-extremum-problems/section-30-adjoint-bifunctions-and-dual-programs/00-index.ipynb) - [canonical notebook](part-06-constrained-extremum-problems/section-30-adjoint-bifunctions-and-dual-programs/30-adjoint-bifunctions-and-dual-programs.ipynb); printed pages 307-326; adjoints, dual programs, weak duality, saddle certificates.
# - [31. Fenchel's Duality Theorem](part-06-constrained-extremum-problems/section-31-fenchels-duality-theorem/00-index.ipynb) - [canonical notebook](part-06-constrained-extremum-problems/section-31-fenchels-duality-theorem/31-fenchels-duality-theorem.ipynb); printed pages 327-341; Fenchel duality, conjugate sums, exact primal-dual equality, qualification.
# - [32. The Maximum of a Convex Function](part-06-constrained-extremum-problems/section-32-maximum-of-a-convex-function/00-index.ipynb) - [canonical notebook](part-06-constrained-extremum-problems/section-32-maximum-of-a-convex-function/32-maximum-of-a-convex-function.ipynb); printed pages 342-348; maximizing convex functions, extreme points, compact convex domains.
#
# ## Part 7: Saddle-Functions and Minimax Theory
# - [Part index](part-07-saddle-functions-and-minimax-theory/00-part-index.ipynb)
# - [33. Saddle-Functions](part-07-saddle-functions-and-minimax-theory/section-33-saddle-functions/00-index.ipynb) - [canonical notebook](part-07-saddle-functions-and-minimax-theory/section-33-saddle-functions/33-saddle-functions.ipynb); printed pages 349-358; convex-concave functions, saddle points, bifunction correspondence.
# - [34. Closures and Equivalence Classes](part-07-saddle-functions-and-minimax-theory/section-34-closures-and-equivalence-classes/00-index.ipynb) - [canonical notebook](part-07-saddle-functions-and-minimax-theory/section-34-closures-and-equivalence-classes/34-closures-and-equivalence-classes.ipynb); printed pages 359-369; closed saddle-functions, equivalence classes, boundary regularization.
# - [35. Continuity and Differentiability of Saddle-functions](part-07-saddle-functions-and-minimax-theory/section-35-continuity-and-differentiability-of-saddle-functions/00-index.ipynb) - [canonical notebook](part-07-saddle-functions-and-minimax-theory/section-35-continuity-and-differentiability-of-saddle-functions/35-continuity-and-differentiability-of-saddle-functions.ipynb); printed pages 370-378; partial gradients, convex-concave monotonicity, continuity of saddle mappings.
# - [36. Minimax Problems](part-07-saddle-functions-and-minimax-theory/section-36-minimax-problems/00-index.ipynb) - [canonical notebook](part-07-saddle-functions-and-minimax-theory/section-36-minimax-problems/36-minimax-problems.ipynb); printed pages 379-387; minimax values, saddle-points, convex-concave programs, order of optimization.
# - [37. Conjugate Saddle-functions and Minimax Theorems](part-07-saddle-functions-and-minimax-theory/section-37-conjugate-saddle-functions-and-minimax-theorems/00-index.ipynb) - [canonical notebook](part-07-saddle-functions-and-minimax-theory/section-37-conjugate-saddle-functions-and-minimax-theorems/37-conjugate-saddle-functions-and-minimax-theorems.ipynb); printed pages 388-400; saddle conjugacy, inverse bifunctions, minimax theorems, existence.
#
# ## Part 8: Convex Algebra
# - [Part index](part-08-convex-algebra/00-part-index.ipynb)
# - [38. The Algebra of Bifunctions](part-08-convex-algebra/section-38-algebra-of-bifunctions/00-index.ipynb) - [canonical notebook](part-08-convex-algebra/section-38-algebra-of-bifunctions/38-algebra-of-bifunctions.ipynb); printed pages 401-412; addition and composition of bifunctions, adjoints, convex algebra identities.
# - [39. Convex Processes](part-08-convex-algebra/section-39-convex-processes/00-index.ipynb) - [canonical notebook](part-08-convex-algebra/section-39-convex-processes/39-convex-processes.ipynb); printed pages 413-424; set-valued convex processes, graph cones, process images, inverse processes.
#
# ## Inventory
# - [Source map](inventory/source_map.md)
# - [Visualization storyboard](inventory/visual_storyboard.md)

# %%
# geometry-setup:v1
# Machine-managed by scripts/update_notebook_setup.py. Do not edit this cell by hand.

from __future__ import annotations

import json as _geometry_json
import os as _geometry_os
from pathlib import Path as _GeometryPath
import sys as _geometry_sys

GEOMETRY_SETUP = _geometry_json.loads(
    r"""
{
  "colab_url": "https://colab.research.google.com/github/Rah-Rah-Mitra/Geometry/blob/main/Convex-Analysis/00-book-index.ipynb",
  "course_dir": "Convex-Analysis",
  "course_title": "Convex Analysis",
  "github_url": "https://github.com/Rah-Rah-Mitra/Geometry/blob/main/Convex-Analysis/00-book-index.ipynb",
  "jupyterlite": false,
  "marker": "geometry-setup:v1",
  "notebook_kind": "book-index",
  "notebook_path": "Convex-Analysis/00-book-index.ipynb",
  "notebook_title": "Convex Analysis",
  "repository": {
    "branch": "main",
    "name": "Geometry",
    "owner": "Rah-Rah-Mitra",
    "source_url": "https://github.com/Rah-Rah-Mitra/Geometry"
  },
  "requirements": "requirements/algebraic-geometry.txt",
  "runtime_profile": "algebraic_geometry"
}
"""
)


def _geometry_is_colab():
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def _geometry_is_jupyterlite():
    return _geometry_sys.platform == "emscripten" or "pyodide" in _geometry_sys.modules


def _geometry_add_path(path):
    text = str(path)
    if text not in _geometry_sys.path:
        _geometry_sys.path.insert(0, text)


def _geometry_find_repo_root():
    candidates = []
    env_root = _geometry_os.environ.get("GEOMETRY_REPO_ROOT")
    if env_root:
        candidates.append(_GeometryPath(env_root).expanduser())
    candidates.append(_GeometryPath.cwd())
    for start in candidates:
        start = start.resolve()
        for current in (start, *start.parents):
            if (current / "course-manifest.json").exists() and (
                current / "metadata" / "runtime_profiles.yml"
            ).exists():
                return current
    raise RuntimeError(
        "Could not find the Geometry repository root. Start JupyterLab inside the "
        "Geometry checkout or set GEOMETRY_REPO_ROOT."
    )


def _geometry_run(command):
    import subprocess as _geometry_subprocess

    printable = " ".join(str(part) for part in command)
    print(f"+ {printable}")
    _geometry_subprocess.check_call([str(part) for part in command])


def _geometry_requirement_names(requirements_path, seen=None):
    seen = set() if seen is None else seen
    requirements_path = requirements_path.resolve()
    if requirements_path in seen or not requirements_path.exists():
        return []
    seen.add(requirements_path)
    names = []
    for raw_line in requirements_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.split("#", 1)[0].strip()
        if not line:
            continue
        if line.startswith(("-r ", "--requirement ")):
            _, nested = line.split(maxsplit=1)
            names.extend(_geometry_requirement_names(requirements_path.parent / nested, seen))
            continue
        if line.startswith("-"):
            continue
        name = line
        for separator in ("==", ">=", "<=", "~=", "!=", ">", "<", ";"):
            name = name.split(separator, 1)[0]
        name = name.split("[", 1)[0].strip()
        if name:
            names.append(name)
    return sorted(set(names))


def _geometry_missing_requirements(requirements_path):
    import importlib.metadata as _geometry_metadata

    missing = []
    for name in _geometry_requirement_names(requirements_path):
        try:
            _geometry_metadata.distribution(name)
        except _geometry_metadata.PackageNotFoundError:
            missing.append(name)
    return missing


def _geometry_configured_roots(repo_root):
    course_dir = GEOMETRY_SETUP.get("course_dir")
    course_root = repo_root / course_dir if course_dir else repo_root
    return repo_root, course_root


if _geometry_is_jupyterlite():
    if not GEOMETRY_SETUP["jupyterlite"]:
        raise RuntimeError(
            "This Geometry notebook uses runtime profile "
            f"{GEOMETRY_SETUP['runtime_profile']!r}, which is not enabled for "
            "JupyterLite in course-manifest.json. Open it in Colab or local JupyterLab."
        )
    GEOMETRY_REPO_ROOT = _GeometryPath.cwd()
    GEOMETRY_COURSE_ROOT = (
        GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["course_dir"]
        if GEOMETRY_SETUP.get("course_dir")
        else GEOMETRY_REPO_ROOT
    )
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    if GEOMETRY_COURSE_ROOT.exists():
        _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        "Geometry setup: JupyterLite/Pyodide detected; shell, git, and pip steps "
        "were skipped."
    )
elif _geometry_is_colab():
    repository = GEOMETRY_SETUP["repository"]
    repo_url = repository["source_url"].rstrip("/") + ".git"
    branch = repository["branch"]
    GEOMETRY_REPO_ROOT = _GeometryPath(
        _geometry_os.environ.get("GEOMETRY_REPO_ROOT", "/content/Geometry")
    )
    sparse_paths = ["requirements", "metadata", "scripts", "course-manifest.json", "index.ipynb"]
    if GEOMETRY_SETUP.get("course_dir"):
        sparse_paths.append(GEOMETRY_SETUP["course_dir"])
    if not (GEOMETRY_REPO_ROOT / ".git").exists():
        if GEOMETRY_REPO_ROOT.exists() and any(GEOMETRY_REPO_ROOT.iterdir()):
            raise RuntimeError(
                f"{GEOMETRY_REPO_ROOT} exists but is not a git checkout. "
                "Set GEOMETRY_REPO_ROOT to an empty path or remove the directory."
            )
        _geometry_run(
            [
                "git",
                "clone",
                "--filter=blob:none",
                "--no-checkout",
                "--branch",
                branch,
                repo_url,
                GEOMETRY_REPO_ROOT,
            ]
        )
        _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "init", "--cone"])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "set", *sparse_paths])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "checkout", branch])
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-q", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: Colab ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )
else:
    GEOMETRY_REPO_ROOT = _geometry_find_repo_root()
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    missing = _geometry_missing_requirements(requirements_path)
    skip_install = _geometry_os.environ.get("GEOMETRY_SKIP_INSTALL") == "1"
    if missing and skip_install:
        print(
            "Geometry setup: GEOMETRY_SKIP_INSTALL=1, so missing profile packages "
            f"were not installed: {', '.join(missing)}"
        )
    elif missing:
        print(
            "Geometry setup: installing missing profile packages from "
            f"{requirements_path.relative_to(GEOMETRY_REPO_ROOT)}: {', '.join(missing)}"
        )
        _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: local checkout ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )

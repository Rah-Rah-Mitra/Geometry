# %% [markdown]
# # I.1 Basic Concepts
#
# - Canonical notebook: [i-01-basic-concepts.ipynb](i-01-basic-concepts.ipynb)
# - Source span: printed 2-14, PDF 21-33
# - Focus: Build the dictionary from distance to geodesic behavior, then turn angle and length into measurable notebook objects.
#
# ## Concept Route
#
# pseudometric versus metric, geodesic segment and ray, metric graph, Alexandrov upper angle, rectifiable curve

# %%
from pathlib import Path
assert Path('i-01-basic-concepts.ipynb').exists()

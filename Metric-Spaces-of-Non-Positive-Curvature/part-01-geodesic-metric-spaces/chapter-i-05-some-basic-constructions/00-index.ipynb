# %% [markdown]
# # I.5 Some Basic Constructions
#
# - Canonical notebook: [i-05-some-basic-constructions.ipynb](i-05-some-basic-constructions.ipynb)
# - Source span: printed 56-80, PDF 75-99
# - Focus: Assemble new geodesic spaces and record which metric features survive the operation.
#
# ## Concept Route
#
# product metric, metric cone, spherical join, quotient metric, ultralimit

# %%
from pathlib import Path
assert Path('i-05-some-basic-constructions.ipynb').exists()

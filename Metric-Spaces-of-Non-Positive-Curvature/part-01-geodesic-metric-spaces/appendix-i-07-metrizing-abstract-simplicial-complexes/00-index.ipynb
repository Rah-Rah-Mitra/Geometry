# %% [markdown]
# # I.7 Appendix Metrizing Abstract Simplicial Complexes
#
# - Canonical notebook: [appendix-i-07-metrizing-abstract-simplicial-complexes.ipynb](appendix-i-07-metrizing-abstract-simplicial-complexes.ipynb)
# - Source span: printed 123-130, PDF 142-149
# - Focus: Turn combinatorial incidence data into a metric realization without smuggling in a picture.
#
# ## Concept Route
#
# abstract simplex, geometric realization, edge-length assignment, face compatibility, metric realization

# %%
from pathlib import Path
assert Path('appendix-i-07-metrizing-abstract-simplicial-complexes.ipynb').exists()

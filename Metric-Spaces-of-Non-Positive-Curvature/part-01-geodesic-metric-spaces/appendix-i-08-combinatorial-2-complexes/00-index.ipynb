# %% [markdown]
# # I.8 Appendix Combinatorial 2-Complexes
#
# - Canonical notebook: [appendix-i-08-combinatorial-2-complexes.ipynb](appendix-i-08-combinatorial-2-complexes.ipynb)
# - Source span: printed 153-156, PDF 172-175
# - Focus: Represent a group presentation as a two-dimensional space whose loops remember relations.
#
# ## Concept Route
#
# combinatorial 2-complex, attaching word, presentation complex, cellular path, relation loop

# %%
from pathlib import Path
assert Path('appendix-i-08-combinatorial-2-complexes.ipynb').exists()

# %% [markdown]
# # I.8 Group Actions and Quasi-Isometries
#
# - Canonical notebook: [i-08-group-actions-and-quasi-isometries.ipynb](i-08-group-actions-and-quasi-isometries.ipynb)
# - Source span: printed 131-152, PDF 150-171
# - Focus: Translate coarse group data into metric actions and quasi-isometry invariants.
#
# ## Concept Route
#
# isometric group action, fundamental domain, quasi-isometry, ends of a space, growth type

# %%
from pathlib import Path
assert Path('i-08-group-actions-and-quasi-isometries.ipynb').exists()

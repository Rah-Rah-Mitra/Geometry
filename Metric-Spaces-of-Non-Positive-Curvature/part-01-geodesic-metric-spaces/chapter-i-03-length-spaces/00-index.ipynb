# %% [markdown]
# # I.3 Length Spaces
#
# - Canonical notebook: [i-03-length-spaces.ipynb](i-03-length-spaces.ipynb)
# - Source span: printed 32-46, PDF 51-65
# - Focus: Turn curves into distances and separate induced metrics from intrinsic length metrics.
#
# ## Concept Route
#
# length metric, intrinsic distance, properness, Hopf-Rinow principle, covering length metric

# %%
from pathlib import Path
assert Path('i-03-length-spaces.ipynb').exists()

# %% [markdown]
# # I.2 The Model Spaces
#
# - Canonical notebook: [i-02-the-model-spaces.ipynb](i-02-the-model-spaces.ipynb)
# - Source span: printed 15-31, PDF 34-50
# - Focus: Treat E^n, S^n, and H^n as measuring instruments for later CAT(k) comparisons.
#
# ## Concept Route
#
# constant curvature models, spherical distance, hyperbolic distance, comparison triangle, isometry group

# %%
from pathlib import Path
assert Path('i-02-the-model-spaces.ipynb').exists()

# %% [markdown]
# # I.6 More on the Geometry of H^n
#
# - Canonical notebook: [i-06-more-on-hyperbolic-geometry.ipynb](i-06-more-on-hyperbolic-geometry.ipynb)
# - Source span: printed 81-96, PDF 100-115
# - Focus: Compare hyperbolic models so geodesics, boundary points, and isometries can be moved between coordinates.
#
# ## Concept Route
#
# Klein model, Poincare ball, half-space model, Mobius action, hyperbolic isometry

# %%
from pathlib import Path
assert Path('i-06-more-on-hyperbolic-geometry.ipynb').exists()

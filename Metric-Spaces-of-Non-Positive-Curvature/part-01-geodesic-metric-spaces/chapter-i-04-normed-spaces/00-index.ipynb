# %% [markdown]
# # I.4 Normed Spaces
#
# - Canonical notebook: [i-04-normed-spaces.ipynb](i-04-normed-spaces.ipynb)
# - Source span: printed 47-55, PDF 66-74
# - Focus: Use norm balls to see exactly when straight segments are unique geodesics.
#
# ## Concept Route
#
# Hilbert norm, strict convexity, Mazur-Ulam behavior, l^p geometry, parallel geodesics

# %%
from pathlib import Path
assert Path('i-04-normed-spaces.ipynb').exists()

# %% [markdown]
# # I.7 M_k-Polyhedral Complexes
#
# - Canonical notebook: [i-07-mk-polyhedral-complexes.ipynb](i-07-mk-polyhedral-complexes.ipynb)
# - Source span: printed 97-122, PDF 116-141
# - Focus: Make piecewise constant curvature complexes inspectable through cells, links, and local geodesic tests.
#
# ## Concept Route
#
# metric simplex, geometric link, cone neighborhood, cubical complex, barycentric subdivision

# %%
from pathlib import Path
assert Path('i-07-mk-polyhedral-complexes.ipynb').exists()

# %% [markdown]
# # III.Gamma Non-Positive Curvature and Group Theory
#
# - Canonical notebook: [iii-g-non-positive-curvature-and-group-theory.ipynb](iii-g-non-positive-curvature-and-group-theory.ipynb)
# - Source span: printed 438-518, PDF 457-537
# - Focus: Use non-positive curvature to make group-theoretic algorithms and subgroup phenomena geometric.
#
# ## Concept Route
#
# word problem, conjugacy problem, hyperbolic group, semihyperbolic group, subgroup distortion

# %%
from pathlib import Path
assert Path('iii-g-non-positive-curvature-and-group-theory.ipynb').exists()

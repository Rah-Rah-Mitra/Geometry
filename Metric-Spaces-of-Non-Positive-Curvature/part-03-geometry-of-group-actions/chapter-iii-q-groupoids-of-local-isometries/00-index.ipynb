# %% [markdown]
# # III.Q Groupoids of Local Isometries
#
# - Canonical notebook: [iii-q-groupoids-of-local-isometries.ipynb](iii-q-groupoids-of-local-isometries.ipynb)
# - Source span: printed 584-619, PDF 603-638
# - Focus: Use groupoids to encode local isometries, orbifold charts, and developability through lifted geodesics.
#
# ## Concept Route
#
# orbifold chart, etale groupoid, groupoid equivalence, groupoid fundamental group, geodesic lift

# %%
from pathlib import Path
assert Path('iii-q-groupoids-of-local-isometries.ipynb').exists()

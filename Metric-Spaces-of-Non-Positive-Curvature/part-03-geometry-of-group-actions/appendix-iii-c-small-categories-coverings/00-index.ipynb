# %% [markdown]
# # III.C Appendix Fundamental Groups and Coverings of Small Categories
#
# - Canonical notebook: [appendix-iii-c-small-categories-coverings.ipynb](appendix-iii-c-small-categories-coverings.ipynb)
# - Source span: printed 573-583, PDF 592-602
# - Focus: Make category paths, loops, and covering fibers visible enough to support the complexes-of-groups chapter.
#
# ## Concept Route
#
# small category, category path, fundamental group, covering category, fiber monodromy

# %%
from pathlib import Path
assert Path('appendix-iii-c-small-categories-coverings.ipynb').exists()

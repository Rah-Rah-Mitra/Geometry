# %% [markdown]
# # III.H delta-Hyperbolic Spaces
#
# - Canonical notebook: [iii-h-delta-hyperbolic-spaces.ipynb](iii-h-delta-hyperbolic-spaces.ipynb)
# - Source span: printed 398-437, PDF 417-456
# - Focus: Compare negative-curvature large-scale behavior through slim triangles, isoperimetry, and boundary metrics.
#
# ## Concept Route
#
# delta-slim triangle, quasi-geodesic stability, linear isoperimetric inequality, Gromov boundary, visual metric

# %%
from pathlib import Path
assert Path('iii-h-delta-hyperbolic-spaces.ipynb').exists()

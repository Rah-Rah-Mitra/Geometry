# %% [markdown]
# # III.C Complexes of Groups
#
# - Canonical notebook: [iii-c-complexes-of-groups.ipynb](iii-c-complexes-of-groups.ipynb)
# - Source span: printed 519-572, PDF 538-591
# - Focus: Upgrade simple complexes of groups to the full scwol language and follow fundamental groups through developments and coverings.
#
# ## Concept Route
#
# scwol, complex of groups, developability, universal group, local development

# %%
from pathlib import Path
assert Path('iii-c-complexes-of-groups.ipynb').exists()

# %% [markdown]
# # II.9 The Tits Metric and Visibility Spaces
#
# - Canonical notebook: [ii-09-tits-metric-and-visibility.ipynb](ii-09-tits-metric-and-visibility.ipynb)
# - Source span: printed 277-298, PDF 296-317
# - Focus: Put a metric on ideal directions and use it to detect flats, splittings, and visibility behavior.
#
# ## Concept Route
#
# angular metric, Tits metric, CAT(1) boundary, flat sector, visibility space

# %%
from pathlib import Path
assert Path('ii-09-tits-metric-and-visibility.ipynb').exists()

# %% [markdown]
# # II.1 Definitions and Characterizations of CAT(k) Spaces
#
# - Canonical notebook: [ii-01-definitions-and-characterizations.ipynb](ii-01-definitions-and-characterizations.ipynb)
# - Source span: printed 158-168, PDF 177-187
# - Focus: Make the CAT(k) inequality operational by comparing every chord in a geodesic triangle with its model counterpart.
#
# ## Concept Route
#
# comparison triangle, CAT(k) inequality, CN inequality, monotonicity of upper bounds, model diameter restriction

# %%
from pathlib import Path
assert Path('ii-01-definitions-and-characterizations.ipynb').exists()

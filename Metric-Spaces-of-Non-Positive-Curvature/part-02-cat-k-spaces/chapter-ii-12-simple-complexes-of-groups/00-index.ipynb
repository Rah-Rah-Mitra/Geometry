# %% [markdown]
# # II.12 Simple Complexes of Groups
#
# - Canonical notebook: [ii-12-simple-complexes-of-groups.ipynb](ii-12-simple-complexes-of-groups.ipynb)
# - Source span: printed 367-396, PDF 386-415
# - Focus: Encode group stabilizer data over a stratified space and test curvature through the local development.
#
# ## Concept Route
#
# stratified space, strict fundamental domain, simple complex of groups, basic construction, local development

# %%
from pathlib import Path
assert Path('ii-12-simple-complexes-of-groups.ipynb').exists()

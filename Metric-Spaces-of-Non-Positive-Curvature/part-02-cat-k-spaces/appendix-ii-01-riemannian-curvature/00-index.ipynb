# %% [markdown]
# # II.1 Appendix The Curvature of Riemannian Manifolds
#
# - Canonical notebook: [appendix-ii-01-riemannian-curvature.ipynb](appendix-ii-01-riemannian-curvature.ipynb)
# - Source span: printed 169-174, PDF 188-193
# - Focus: Connect the metric CAT language back to sectional curvature without requiring tensor fluency.
#
# ## Concept Route
#
# sectional curvature, Jacobi field intuition, metric comparison, local upper bound, Riemannian example

# %%
from pathlib import Path
assert Path('appendix-ii-01-riemannian-curvature.ipynb').exists()

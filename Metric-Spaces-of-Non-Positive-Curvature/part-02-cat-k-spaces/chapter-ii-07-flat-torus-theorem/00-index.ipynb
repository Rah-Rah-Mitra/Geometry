# %% [markdown]
# # II.7 The Flat Torus Theorem
#
# - Canonical notebook: [ii-07-flat-torus-theorem.ipynb](ii-07-flat-torus-theorem.ipynb)
# - Source span: printed 244-259, PDF 263-278
# - Focus: Show how commuting semisimple isometries carve Euclidean flats out of a CAT(0) action.
#
# ## Concept Route
#
# free abelian action, minset, flat, cocompact action, solvable subgroup theorem

# %%
from pathlib import Path
assert Path('ii-07-flat-torus-theorem.ipynb').exists()

# %% [markdown]
# # II.2 Convexity and Its Consequences
#
# - Canonical notebook: [ii-02-convexity-and-consequences.ipynb](ii-02-convexity-and-consequences.ipynb)
# - Source span: printed 175-183, PDF 194-202
# - Focus: Use CAT(0) convexity to make projection, center, and flatness statements computationally checkable.
#
# ## Concept Route
#
# convex distance function, closed convex projection, circumcenter, flat subspace, metric midpoint inequality

# %%
from pathlib import Path
assert Path('ii-02-convexity-and-consequences.ipynb').exists()

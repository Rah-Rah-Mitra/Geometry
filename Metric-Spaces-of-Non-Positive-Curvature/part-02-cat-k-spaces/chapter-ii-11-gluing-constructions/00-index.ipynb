# %% [markdown]
# # II.11 Gluing Constructions
#
# - Canonical notebook: [ii-11-gluing-constructions.ipynb](ii-11-gluing-constructions.ipynb)
# - Source span: printed 347-366, PDF 366-385
# - Focus: Track when gluing CAT(k) pieces preserves curvature and when a nonconvex seam breaks the comparison test.
#
# ## Concept Route
#
# convex gluing, local isometry gluing, equivariant gluing, non-locally convex seam, truncated hyperbolic piece

# %%
from pathlib import Path
assert Path('ii-11-gluing-constructions.ipynb').exists()

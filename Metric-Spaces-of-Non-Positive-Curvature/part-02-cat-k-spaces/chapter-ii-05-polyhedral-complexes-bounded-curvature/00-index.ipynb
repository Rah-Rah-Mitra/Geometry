# %% [markdown]
# # II.5 M_k-Polyhedral Complexes of Bounded Curvature
#
# - Canonical notebook: [ii-05-polyhedral-complexes-bounded-curvature.ipynb](ii-05-polyhedral-complexes-bounded-curvature.ipynb)
# - Source span: printed 205-227, PDF 224-246
# - Focus: Turn upper curvature in a polyhedral complex into the link condition and then into examples.
#
# ## Concept Route
#
# link condition, flag complex, cubical CAT(0) test, two-dimensional subcomplex, presentation complex

# %%
from pathlib import Path
assert Path('ii-05-polyhedral-complexes-bounded-curvature.ipynb').exists()

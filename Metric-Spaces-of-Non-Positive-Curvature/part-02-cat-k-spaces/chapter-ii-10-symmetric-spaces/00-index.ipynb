# %% [markdown]
# # II.10 Symmetric Spaces
#
# - Canonical notebook: [ii-10-symmetric-spaces.ipynb](ii-10-symmetric-spaces.ipynb)
# - Source span: printed 299-341, PDF 318-360
# - Focus: Use symmetric spaces as high-rank CAT(0) laboratories with flats, Weyl chambers, and building-like boundaries.
#
# ## Concept Route
#
# rank-one hyperbolic space, positive definite matrix space, flat, Weyl chamber, Iwasawa decomposition

# %%
from pathlib import Path
assert Path('ii-10-symmetric-spaces.ipynb').exists()

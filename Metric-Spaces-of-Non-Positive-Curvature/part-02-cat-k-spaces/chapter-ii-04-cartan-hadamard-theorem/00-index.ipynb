# %% [markdown]
# # II.4 The Cartan-Hadamard Theorem
#
# - Canonical notebook: [ii-04-cartan-hadamard-theorem.ipynb](ii-04-cartan-hadamard-theorem.ipynb)
# - Source span: printed 193-204, PDF 212-223
# - Focus: Expose the mechanism that turns local upper curvature bounds into global CAT(k) control on the universal cover.
#
# ## Concept Route
#
# local CAT(k), universal cover, metric patchwork, local isometry, injectivity radius

# %%
from pathlib import Path
assert Path('ii-04-cartan-hadamard-theorem.ipynb').exists()

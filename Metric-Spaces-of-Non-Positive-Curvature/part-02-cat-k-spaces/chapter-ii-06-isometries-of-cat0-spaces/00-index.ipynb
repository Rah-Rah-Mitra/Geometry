# %% [markdown]
# # II.6 Isometries of CAT(0) Spaces
#
# - Canonical notebook: [ii-06-isometries-of-cat0-spaces.ipynb](ii-06-isometries-of-cat0-spaces.ipynb)
# - Source span: printed 228-243, PDF 247-262
# - Focus: Classify isometries by displacement and connect translation behavior to product splitting.
#
# ## Concept Route
#
# displacement function, elliptic isometry, hyperbolic isometry, parabolic isometry, Clifford translation

# %%
from pathlib import Path
assert Path('ii-06-isometries-of-cat0-spaces.ipynb').exists()

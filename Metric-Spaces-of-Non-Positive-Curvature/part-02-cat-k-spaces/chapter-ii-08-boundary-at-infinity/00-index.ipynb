# %% [markdown]
# # II.8 The Boundary at Infinity of a CAT(0) Space
#
# - Canonical notebook: [ii-08-boundary-at-infinity.ipynb](ii-08-boundary-at-infinity.ipynb)
# - Source span: printed 260-276, PDF 279-295
# - Focus: Construct the boundary from geodesic rays and compare cone-topology and horofunction viewpoints.
#
# ## Concept Route
#
# geodesic ray, asymptotic class, cone topology, Busemann function, horoball

# %%
from pathlib import Path
assert Path('ii-08-boundary-at-infinity.ipynb').exists()

# %% [markdown]
# # II.10 Appendix Spherical and Euclidean Buildings
#
# - Canonical notebook: [appendix-ii-10-spherical-and-euclidean-buildings.ipynb](appendix-ii-10-spherical-and-euclidean-buildings.ipynb)
# - Source span: printed 342-346, PDF 361-365
# - Focus: Treat buildings as apartment systems where local chamber combinatorics controls global CAT geometry.
#
# ## Concept Route
#
# apartment, chamber, wall, Weyl group, building atlas

# %%
from pathlib import Path
assert Path('appendix-ii-10-spherical-and-euclidean-buildings.ipynb').exists()

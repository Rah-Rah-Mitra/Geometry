# %% [markdown]
# # Chapter 01: Metric Spaces
#
# Source orientation: printed pages 1-24; source pages 16-39.
#
# Canonical notebook: [01-metric-spaces.ipynb](01-metric-spaces.ipynb)
#
# Metric axioms, examples, topology, Lipschitz maps, completeness, compactness, and Hausdorff dimension.

# %% [markdown]
# # Chapter 1: Metric Spaces
#
# - Source orientation: printed pages 1-24; PDF pages 16-39.
# - Focus: Metric axioms, examples, topology, Lipschitz maps, completeness, compactness, and Hausdorff dimension.
# - Canonical notebook: [01-metric-spaces.ipynb](01-metric-spaces.ipynb)
# - Artifact root: `../artifacts/chapter-01/`
#
# ## Section Starts
#
# - 1.1 Definitions starts on printed page 1 (PDF page 16).
# - 1.2 Examples starts on printed page 3 (PDF page 18).
# - 1.3 Metrics and Topology starts on printed page 7 (PDF page 22).
# - 1.4 Lipschitz Maps starts on printed page 9 (PDF page 24).
# - 1.5 Complete Spaces starts on printed page 10 (PDF page 25).
# - 1.6 Compact Spaces starts on printed page 13 (PDF page 28).
# - 1.7 Hausdorff Measure and Dimension starts on printed page 17 (PDF page 32).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

# %% [markdown]
# # Chapter 06: Curvature of Riemannian Metrics
#
# Source orientation: printed pages 209-240; source pages 224-255.
#
# Canonical notebook: [06-curvature-of-riemannian-metrics.ipynb](06-curvature-of-riemannian-metrics.ipynb)
#
# Coordinate curvature computations, covariant derivative, geodesic and Gaussian curvature, geometric meaning, and comparison theorems.

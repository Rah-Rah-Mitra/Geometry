# %% [markdown]
# # Chapter 6: Curvature of Riemannian Metrics
#
# - Source orientation: printed pages 209-240; PDF pages 224-255.
# - Focus: Coordinate curvature computations, covariant derivative, geodesic and Gaussian curvature, geometric meaning, and comparison theorems.
# - Canonical notebook: [06-curvature-of-riemannian-metrics.ipynb](06-curvature-of-riemannian-metrics.ipynb)
# - Artifact root: `../artifacts/chapter-06/`
#
# ## Section Starts
#
# - 6.1 Motivation: Coordinate Computations starts on printed page 211 (PDF page 226).
# - 6.2 Covariant Derivative starts on printed page 214 (PDF page 229).
# - 6.3 Geodesic and Gaussian Curvatures starts on printed page 221 (PDF page 236).
# - 6.4 Geometric Meaning of Gaussian Curvature starts on printed page 226 (PDF page 241).
# - 6.5 Comparison Theorems starts on printed page 237 (PDF page 252).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

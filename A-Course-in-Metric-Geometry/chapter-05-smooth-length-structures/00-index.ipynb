# %% [markdown]
# # Chapter 5: Smooth Length Structures
#
# - Source orientation: printed pages 135-208; PDF pages 150-223.
# - Focus: Riemannian length, exponential maps, the hyperbolic plane, sub-Riemannian structures, volumes, and Besikovitch inequality.
# - Canonical notebook: [05-smooth-length-structures.ipynb](05-smooth-length-structures.ipynb)
# - Artifact root: `../artifacts/chapter-05/`
#
# ## Section Starts
#
# - 5.1 Riemannian Length Structures starts on printed page 136 (PDF page 151).
# - 5.2 Exponential Map starts on printed page 150 (PDF page 165).
# - 5.3 Hyperbolic Plane starts on printed page 154 (PDF page 169).
# - 5.4 Sub-Riemannian Metric Structures starts on printed page 178 (PDF page 193).
# - 5.5 Riemannian and Finsler Volumes starts on printed page 192 (PDF page 207).
# - 5.6 Besikovitch Inequality starts on printed page 201 (PDF page 216).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

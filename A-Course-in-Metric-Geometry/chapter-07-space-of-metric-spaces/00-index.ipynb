# %% [markdown]
# # Chapter 07: Space of Metric Spaces
#
# Source orientation: printed pages 241-270; source pages 256-285.
#
# Canonical notebook: [07-space-of-metric-spaces.ipynb](07-space-of-metric-spaces.ipynb)
#
# Lipschitz distance, Gromov-Hausdorff distance, convergence, and compact length-space limits.

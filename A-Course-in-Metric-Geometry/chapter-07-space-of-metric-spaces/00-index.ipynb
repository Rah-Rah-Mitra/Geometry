# %% [markdown]
# # Chapter 7: Space of Metric Spaces
#
# - Source orientation: printed pages 241-270; PDF pages 256-285.
# - Focus: Lipschitz distance, Gromov-Hausdorff distance, convergence, and compact length-space limits.
# - Canonical notebook: [07-space-of-metric-spaces.ipynb](07-space-of-metric-spaces.ipynb)
# - Artifact root: `../artifacts/chapter-07/`
#
# ## Section Starts
#
# - 7.1 Examples starts on printed page 242 (PDF page 257).
# - 7.2 Lipschitz Distance starts on printed page 249 (PDF page 264).
# - 7.3 Gromov-Hausdorff Distance starts on printed page 251 (PDF page 266).
# - 7.4 Gromov-Hausdorff Convergence starts on printed page 260 (PDF page 275).
# - 7.5 Convergence of Length Spaces starts on printed page 265 (PDF page 280).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

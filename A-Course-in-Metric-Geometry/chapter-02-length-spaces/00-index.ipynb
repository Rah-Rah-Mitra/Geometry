# %% [markdown]
# # Chapter 2: Length Spaces
#
# - Source orientation: printed pages 25-58; PDF pages 40-73.
# - Focus: Length structures, induced intrinsic metrics, shortest paths, length measure, and speed.
# - Canonical notebook: [02-length-spaces.ipynb](02-length-spaces.ipynb)
# - Artifact root: `../artifacts/chapter-02/`
#
# ## Section Starts
#
# - 2.1 Length Structures starts on printed page 25 (PDF page 40).
# - 2.2 First Examples of Length Structures starts on printed page 30 (PDF page 45).
# - 2.3 Length Structures Induced by Metrics starts on printed page 33 (PDF page 48).
# - 2.4 Characterization of Intrinsic Metrics starts on printed page 38 (PDF page 53).
# - 2.5 Shortest Paths starts on printed page 43 (PDF page 58).
# - 2.6 Length and Hausdorff Measure starts on printed page 53 (PDF page 68).
# - 2.7 Length and Lipschitz Speed starts on printed page 54 (PDF page 69).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

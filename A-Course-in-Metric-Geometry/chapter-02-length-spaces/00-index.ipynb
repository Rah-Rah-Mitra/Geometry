# %% [markdown]
# # Chapter 02: Length Spaces
#
# Source orientation: printed pages 25-58; source pages 40-73.
#
# Canonical notebook: [02-length-spaces.ipynb](02-length-spaces.ipynb)
#
# Length structures, induced intrinsic metrics, shortest paths, length measure, and speed.

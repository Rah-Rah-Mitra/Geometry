# %% [markdown]
# # Chapter 04: Spaces of Bounded Curvature
#
# Source orientation: printed pages 101-134; source pages 116-149.
#
# Canonical notebook: [04-spaces-of-bounded-curvature.ipynb](04-spaces-of-bounded-curvature.ipynb)
#
# Alexandrov-style bounded curvature definitions, examples, angles, distance functions, first variation, globalization, and cones.

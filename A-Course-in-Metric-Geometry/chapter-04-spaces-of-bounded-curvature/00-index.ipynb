# %% [markdown]
# # Chapter 4: Spaces of Bounded Curvature
#
# - Source orientation: printed pages 101-134; PDF pages 116-149.
# - Focus: Alexandrov-style bounded curvature definitions, examples, angles, distance functions, first variation, globalization, and cones.
# - Canonical notebook: [04-spaces-of-bounded-curvature.ipynb](04-spaces-of-bounded-curvature.ipynb)
# - Artifact root: `../artifacts/chapter-04/`
#
# ## Section Starts
#
# - 4.1 Definitions starts on printed page 101 (PDF page 116).
# - 4.2 Examples starts on printed page 109 (PDF page 124).
# - 4.3 Angles in Alexandrov Spaces and Equivalence of Definitions starts on printed page 114 (PDF page 129).
# - 4.4 Analysis of Distance Functions starts on printed page 119 (PDF page 134).
# - 4.5 The First Variation Formula starts on printed page 121 (PDF page 136).
# - 4.6 Nonzero Curvature Bounds and Globalization starts on printed page 126 (PDF page 141).
# - 4.7 Curvature of Cones starts on printed page 131 (PDF page 146).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

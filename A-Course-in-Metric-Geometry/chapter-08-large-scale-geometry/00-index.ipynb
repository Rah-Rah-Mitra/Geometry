# %% [markdown]
# # Chapter 08: Large-scale Geometry
#
# Source orientation: printed pages 271-306; source pages 286-321.
#
# Canonical notebook: [08-large-scale-geometry.ipynb](08-large-scale-geometry.ipynb)
#
# Noncompact limits, tangent and asymptotic cones, quasi-isometries, Gromov hyperbolicity, and periodic metrics.

# %% [markdown]
# # Chapter 8: Large-scale Geometry
#
# - Source orientation: printed pages 271-306; PDF pages 286-321.
# - Focus: Noncompact limits, tangent and asymptotic cones, quasi-isometries, Gromov hyperbolicity, and periodic metrics.
# - Canonical notebook: [08-large-scale-geometry.ipynb](08-large-scale-geometry.ipynb)
# - Artifact root: `../artifacts/chapter-08/`
#
# ## Section Starts
#
# - 8.1 Noncompact Gromov-Hausdorff Limits starts on printed page 271 (PDF page 286).
# - 8.2 Tangent and Asymptotic Cones starts on printed page 275 (PDF page 290).
# - 8.3 Quasi-isometries starts on printed page 277 (PDF page 292).
# - 8.4 Gromov Hyperbolic Spaces starts on printed page 284 (PDF page 299).
# - 8.5 Periodic Metrics starts on printed page 298 (PDF page 313).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

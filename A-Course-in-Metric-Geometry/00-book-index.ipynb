# %% [markdown]
# # A Course in Metric Geometry
#
# Standalone visualization-first notebook course.
#
# - [Chapter 01: Metric Spaces](chapter-01-metric-spaces/00-index.ipynb)
# - [Chapter 02: Length Spaces](chapter-02-length-spaces/00-index.ipynb)
# - [Chapter 03: Constructions](chapter-03-constructions/00-index.ipynb)
# - [Chapter 04: Spaces of Bounded Curvature](chapter-04-spaces-of-bounded-curvature/00-index.ipynb)
# - [Chapter 05: Smooth Length Structures](chapter-05-smooth-length-structures/00-index.ipynb)
# - [Chapter 06: Curvature of Riemannian Metrics](chapter-06-curvature-of-riemannian-metrics/00-index.ipynb)
# - [Chapter 07: Space of Metric Spaces](chapter-07-space-of-metric-spaces/00-index.ipynb)
# - [Chapter 08: Large-scale Geometry](chapter-08-large-scale-geometry/00-index.ipynb)
# - [Chapter 09: Spaces of Curvature Bounded Above](chapter-09-spaces-of-curvature-bounded-above/00-index.ipynb)
# - [Chapter 10: Spaces of Curvature Bounded Below](chapter-10-spaces-of-curvature-bounded-below/00-index.ipynb)

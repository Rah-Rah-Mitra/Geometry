# %% [markdown]
# # A Course in Metric Geometry
#
# This is a standalone visualization-first notebook course for Dmitri Burago, Yuri Burago, and Sergei Ivanov's *A Course in Metric Geometry*. The PDF is used only for source orientation: title, author list, chapter order, page spans, terminology, and concept coverage. The notebooks use original prose, original computational examples, and generated visual artifacts.
#
# Body printed pages map to physical PDF pages by `pdf_page = printed_page + 15`.
#
# ## Chapter Route
#
# | Chapter | Notebook | Printed Pages | PDF Pages | Focus |
# | --- | --- | ---: | ---: | --- |
# | 1 | [Metric Spaces](chapter-01-metric-spaces/01-metric-spaces.ipynb) | 1-24 | 16-39 | Metric axioms, examples, topology, Lipschitz maps, completeness, compactness, and Hausdorff dimension. |
# | 2 | [Length Spaces](chapter-02-length-spaces/02-length-spaces.ipynb) | 25-58 | 40-73 | Length structures, induced intrinsic metrics, shortest paths, length measure, and speed. |
# | 3 | [Constructions](chapter-03-constructions/03-constructions.ipynb) | 59-100 | 74-115 | Gluing, maximal metrics, polyhedral spaces, quotients, coverings, arcwise isometries, products, and cones. |
# | 4 | [Spaces of Bounded Curvature](chapter-04-spaces-of-bounded-curvature/04-spaces-of-bounded-curvature.ipynb) | 101-134 | 116-149 | Alexandrov-style bounded curvature definitions, examples, angles, distance functions, first variation, globalization, and cones. |
# | 5 | [Smooth Length Structures](chapter-05-smooth-length-structures/05-smooth-length-structures.ipynb) | 135-208 | 150-223 | Riemannian length, exponential maps, the hyperbolic plane, sub-Riemannian structures, volumes, and Besikovitch inequality. |
# | 6 | [Curvature of Riemannian Metrics](chapter-06-curvature-of-riemannian-metrics/06-curvature-of-riemannian-metrics.ipynb) | 209-240 | 224-255 | Coordinate curvature computations, covariant derivative, geodesic and Gaussian curvature, geometric meaning, and comparison theorems. |
# | 7 | [Space of Metric Spaces](chapter-07-space-of-metric-spaces/07-space-of-metric-spaces.ipynb) | 241-270 | 256-285 | Lipschitz distance, Gromov-Hausdorff distance, convergence, and compact length-space limits. |
# | 8 | [Large-scale Geometry](chapter-08-large-scale-geometry/08-large-scale-geometry.ipynb) | 271-306 | 286-321 | Noncompact limits, tangent and asymptotic cones, quasi-isometries, Gromov hyperbolicity, and periodic metrics. |
# | 9 | [Spaces of Curvature Bounded Above](chapter-09-spaces-of-curvature-bounded-above/09-spaces-of-curvature-bounded-above.ipynb) | 307-350 | 322-365 | CAT spaces, local properties, Hadamard spaces, fundamental groups, and semi-dispersing billiards. |
# | 10 | [Spaces of Curvature Bounded Below](chapter-10-spaces-of-curvature-bounded-below/10-spaces-of-curvature-bounded-below.ipynb) | 351-404 | 366-419 | CBB definitions, examples, Toponogov, diameter, splitting, dimension, volume, limits, local properties, directions, and tangent cones. |
#
# ## Back Matter
#
# - Bibliography: printed pages 405-408; PDF pages 420-423.
# - Index: printed pages 409-419; PDF pages 424-434.
#
# ## Course Contract
#
# - One canonical notebook per chapter folder plus a local `00-index.ipynb`.
# - Artifacts are saved under `artifacts/chapter-XX/`.
# - Each chapter includes a storyboard, visual artifacts, computational checks, an applied lab, and takeaways.
# - No textbook screenshots, crops, long exercise text, or copied prose are included.

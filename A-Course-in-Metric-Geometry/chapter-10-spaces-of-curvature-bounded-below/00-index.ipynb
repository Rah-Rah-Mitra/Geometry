# %% [markdown]
# # Chapter 10: Spaces of Curvature Bounded Below
#
# Source orientation: printed pages 351-404; source pages 366-419.
#
# Canonical notebook: [10-spaces-of-curvature-bounded-below.ipynb](10-spaces-of-curvature-bounded-below.ipynb)
#
# CBB definitions, examples, Toponogov, diameter, splitting, dimension, volume, limits, local properties, directions, and tangent cones.

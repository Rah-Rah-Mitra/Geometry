# %% [markdown]
# # Chapter 10: Spaces of Curvature Bounded Below
#
# - Source orientation: printed pages 351-404; PDF pages 366-419.
# - Focus: CBB definitions, examples, Toponogov, diameter, splitting, dimension, volume, limits, local properties, directions, and tangent cones.
# - Canonical notebook: [10-spaces-of-curvature-bounded-below.ipynb](10-spaces-of-curvature-bounded-below.ipynb)
# - Artifact root: `../artifacts/chapter-10/`
#
# ## Section Starts
#
# - 10.1 One More Definition starts on printed page 352 (PDF page 367).
# - 10.2 Constructions and Examples starts on printed page 354 (PDF page 369).
# - 10.3 Toponogov's Theorem starts on printed page 360 (PDF page 375).
# - 10.4 Curvature and Diameter starts on printed page 364 (PDF page 379).
# - 10.5 Splitting Theorem starts on printed page 366 (PDF page 381).
# - 10.6 Dimension and Volume starts on printed page 369 (PDF page 384).
# - 10.7 Gromov-Hausdorff Limits starts on printed page 376 (PDF page 391).
# - 10.8 Local Properties starts on printed page 378 (PDF page 393).
# - 10.9 Spaces of Directions and Tangent Cones starts on printed page 390 (PDF page 405).
# - 10.10 Further Information starts on printed page 398 (PDF page 413).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

# %% [markdown]
# # Chapter 09: Spaces of Curvature Bounded Above
#
# Source orientation: printed pages 307-350; source pages 322-365.
#
# Canonical notebook: [09-spaces-of-curvature-bounded-above.ipynb](09-spaces-of-curvature-bounded-above.ipynb)
#
# CAT spaces, local properties, Hadamard spaces, fundamental groups, and semi-dispersing billiards.

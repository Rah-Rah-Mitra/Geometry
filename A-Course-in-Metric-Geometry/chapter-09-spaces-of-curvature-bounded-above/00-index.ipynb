# %% [markdown]
# # Chapter 9: Spaces of Curvature Bounded Above
#
# - Source orientation: printed pages 307-350; PDF pages 322-365.
# - Focus: CAT spaces, local properties, Hadamard spaces, fundamental groups, and semi-dispersing billiards.
# - Canonical notebook: [09-spaces-of-curvature-bounded-above.ipynb](09-spaces-of-curvature-bounded-above.ipynb)
# - Artifact root: `../artifacts/chapter-09/`
#
# ## Section Starts
#
# - 9.1 Definitions and Local Properties starts on printed page 308 (PDF page 323).
# - 9.2 Hadamard Spaces starts on printed page 324 (PDF page 339).
# - 9.3 Fundamental Group of a Nonpositively Curved Space starts on printed page 338 (PDF page 353).
# - 9.4 Example: Semi-dispersing Billiards starts on printed page 341 (PDF page 356).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

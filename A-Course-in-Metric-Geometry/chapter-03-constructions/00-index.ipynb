# %% [markdown]
# # Chapter 03: Constructions
#
# Source orientation: printed pages 59-100; source pages 74-115.
#
# Canonical notebook: [03-constructions.ipynb](03-constructions.ipynb)
#
# Gluing, maximal metrics, polyhedral spaces, quotients, coverings, arcwise isometries, products, and cones.

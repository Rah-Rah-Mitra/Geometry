# %% [markdown]
# # Chapter 3: Constructions
#
# - Source orientation: printed pages 59-100; PDF pages 74-115.
# - Focus: Gluing, maximal metrics, polyhedral spaces, quotients, coverings, arcwise isometries, products, and cones.
# - Canonical notebook: [03-constructions.ipynb](03-constructions.ipynb)
# - Artifact root: `../artifacts/chapter-03/`
#
# ## Section Starts
#
# - 3.1 Locality, Gluing and Maximal Metrics starts on printed page 59 (PDF page 74).
# - 3.2 Polyhedral Spaces starts on printed page 67 (PDF page 82).
# - 3.3 Isometries and Quotients starts on printed page 75 (PDF page 90).
# - 3.4 Local Isometries and Coverings starts on printed page 78 (PDF page 93).
# - 3.5 Arcwise Isometries starts on printed page 86 (PDF page 101).
# - 3.6 Products and Cones starts on printed page 88 (PDF page 103).
#
# This chapter notebook is written to stand alone from the PDF. Use the source only to confirm orientation and terminology, not as a reading dependency.

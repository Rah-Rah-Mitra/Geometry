# %% [markdown]
# # Part IV: Applications of Information Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Machine learning, natural gradient dynamics, signal processing, optimization, and game-score geometry.
#
# ## Chapter 11: Machine Learning
#
# - Chapter index: [chapter-11-machine-learning/00-index.ipynb](chapter-11-machine-learning/00-index.ipynb)
# - Canonical notebook: [11-machine-learning.ipynb](chapter-11-machine-learning/11-machine-learning.ipynb)
# - Source span: printed pp. 231-278; PDF pp. 234-281
# - Focus: Clustering, Voronoi diagrams, robust centers, SVM geometry, kernels, graphical models, mean-field approximation, belief propagation, CCCP, boosting, Bayesian duality, RBMs, and contrastive divergence.
#
# ## Chapter 12: Natural Gradient Learning and Its Dynamics in Singular Regions
#
# - Chapter index: [chapter-12-natural-gradient-and-singular-learning/00-index.ipynb](chapter-12-natural-gradient-and-singular-learning/00-index.ipynb)
# - Canonical notebook: [12-natural-gradient-and-singular-learning.ipynb](chapter-12-natural-gradient-and-singular-learning/12-natural-gradient-and-singular-learning.ipynb)
# - Source span: printed pp. 279-314; PDF pp. 282-317
# - Focus: Natural gradient descent, stochastic learning, Hessian geometry, reinforcement learning, mirror descent, multilayer perceptron singularities, plateau dynamics, and singular statistical models.
#
# ## Chapter 13: Signal Processing and Optimization
#
# - Chapter index: [chapter-13-signal-processing-and-optimization/00-index.ipynb](chapter-13-signal-processing-and-optimization/00-index.ipynb)
# - Canonical notebook: [13-signal-processing-and-optimization.ipynb](chapter-13-signal-processing-and-optimization/13-signal-processing-and-optimization.ipynb)
# - Source span: printed pp. 315-358; PDF pp. 318-361
# - Focus: PCA, ICA, non-negative matrix factorization, sparse signal processing, convex programming, barrier-induced dual geometry, game-score geometry, and Hyvarinen score.

# %% [markdown]
# # Part III: Information Geometry of Statistical Inference
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Asymptotic inference, hidden-variable estimation, semiparametric models, and time-series manifolds.
#
# ## Chapter 07: Asymptotic Theory of Statistical Inference
#
# - Chapter index: [chapter-07-asymptotic-theory-of-statistical-inference/00-index.ipynb](chapter-07-asymptotic-theory-of-statistical-inference/00-index.ipynb)
# - Canonical notebook: [07-asymptotic-theory-of-statistical-inference.ipynb](chapter-07-asymptotic-theory-of-statistical-inference/07-asymptotic-theory-of-statistical-inference.ipynb)
# - Source span: printed pp. 165-177; PDF pp. 173-185
# - Focus: Estimation, exponential and curved exponential families, first- and higher-order asymptotics, and hypothesis testing.
#
# ## Chapter 08: Estimation in the Presence of Hidden Variables
#
# - Chapter index: [chapter-08-hidden-variables-and-em/00-index.ipynb](chapter-08-hidden-variables-and-em/00-index.ipynb)
# - Canonical notebook: [08-hidden-variables-and-em.ipynb](chapter-08-hidden-variables-and-em/08-hidden-variables-and-em.ipynb)
# - Source span: printed pp. 179-189; PDF pp. 186-196
# - Focus: EM as alternating divergence minimization, hidden-variable models, Gaussian mixtures, information loss under data reduction, and misspecification.
#
# ## Chapter 09: Neyman-Scott Problem: Estimating Function and Semiparametric Statistical Model
#
# - Chapter index: [chapter-09-neyman-scott-estimating-functions-semiparametrics/00-index.ipynb](chapter-09-neyman-scott-estimating-functions-semiparametrics/00-index.ipynb)
# - Canonical notebook: [09-neyman-scott-estimating-functions-semiparametrics.ipynb](chapter-09-neyman-scott-estimating-functions-semiparametrics/09-neyman-scott-estimating-functions-semiparametrics.ipynb)
# - Source span: printed pp. 191-213; PDF pp. 197-219
# - Focus: Nuisance parameters, Neyman-Scott behavior, semiparametric models, estimating functions, exponential-case solutions, scale problems, and neural firing examples.
#
# ## Chapter 10: Linear Systems and Time Series
#
# - Chapter index: [chapter-10-linear-systems-and-time-series/00-index.ipynb](chapter-10-linear-systems-and-time-series/00-index.ipynb)
# - Canonical notebook: [10-linear-systems-and-time-series.ipynb](chapter-10-linear-systems-and-time-series/10-linear-systems-and-time-series.ipynb)
# - Source span: printed pp. 215-227; PDF pp. 220-232
# - Focus: Stationary time series, linear systems, finite-dimensional system manifolds, dual system geometry, and AR, MA, and ARMA models.

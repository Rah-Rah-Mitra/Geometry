# %% [markdown]
# # Part I: Geometry of Divergence Functions: Dually Flat Riemannian Structure
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Divergence functions, Bregman geometry, probability families, invariant metrics, alpha geometry, entropy, and matrix-valued extensions.
#
# ## Chapter 01: Manifold, Divergence and Dually Flat Structure
#
# - Chapter index: [chapter-01-manifold-divergence-dually-flat-structure/00-index.ipynb](chapter-01-manifold-divergence-dually-flat-structure/00-index.ipynb)
# - Canonical notebook: [01-manifold-divergence-dually-flat-structure.ipynb](chapter-01-manifold-divergence-dually-flat-structure/01-manifold-divergence-dually-flat-structure.ipynb)
# - Source span: printed pp. 3-30; PDF pp. 20-47
# - Focus: Manifolds, asymmetric divergence, Bregman geometry, Legendre duality, affine coordinates, and generalized Pythagorean projection.
#
# ## Chapter 02: Exponential Families and Mixture Families of Probability Distributions
#
# - Chapter index: [chapter-02-exponential-and-mixture-families/00-index.ipynb](chapter-02-exponential-and-mixture-families/00-index.ipynb)
# - Canonical notebook: [02-exponential-and-mixture-families.ipynb](chapter-02-exponential-and-mixture-families/02-exponential-and-mixture-families.ipynb)
# - Source span: printed pp. 31-50; PDF pp. 48-67
# - Focus: Exponential and mixture families, e-flat and m-flat structures, maximum entropy, mutual information, and maximum likelihood.
#
# ## Chapter 03: Invariant Geometry of Manifold of Probability Distributions
#
# - Chapter index: [chapter-03-invariant-geometry-of-probability-distributions/00-index.ipynb](chapter-03-invariant-geometry-of-probability-distributions/00-index.ipynb)
# - Canonical notebook: [03-invariant-geometry-of-probability-distributions.ipynb](chapter-03-invariant-geometry-of-probability-distributions/03-invariant-geometry-of-probability-distributions.ipynb)
# - Source span: printed pp. 51-70; PDF pp. 68-87
# - Focus: Invariance, coarse graining, sufficient statistics, f-divergences, KL properties, Fisher information, and positive measures.
#
# ## Chapter 04: Alpha-Geometry, Tsallis q-Entropy and Positive-Definite Matrices
#
# - Chapter index: [chapter-04-alpha-geometry-tsallis-entropy-positive-definite-matrices/00-index.ipynb](chapter-04-alpha-geometry-tsallis-entropy-positive-definite-matrices/00-index.ipynb)
# - Canonical notebook: [04-alpha-geometry-tsallis-entropy-positive-definite-matrices.ipynb](chapter-04-alpha-geometry-tsallis-entropy-positive-definite-matrices/04-alpha-geometry-tsallis-entropy-positive-definite-matrices.ipynb)
# - Source span: printed pp. 71-106; PDF pp. 88-123
# - Focus: Alpha geometry, alpha geodesics and projections, Tsallis q-entropy, escort geometry, positive measures, positive-definite matrices, and miscellaneous divergences.

# %% [markdown]
# # Part II: Introduction to Dual Differential Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Differential-geometric foundations and their dual-connection specialization for information manifolds.
#
# ## Chapter 05: Elements of Differential Geometry
#
# - Chapter index: [chapter-05-elements-of-differential-geometry/00-index.ipynb](chapter-05-elements-of-differential-geometry/00-index.ipynb)
# - Canonical notebook: [05-elements-of-differential-geometry.ipynb](chapter-05-elements-of-differential-geometry/05-elements-of-differential-geometry.ipynb)
# - Source span: printed pp. 109-130; PDF pp. 126-147
# - Focus: Manifolds, tangent spaces, metrics, affine connections, tensors, covariant derivatives, geodesics, curvature, Levi-Civita connection, and submanifolds.
#
# ## Chapter 06: Dual Affine Connections and Dually Flat Manifold
#
# - Chapter index: [chapter-06-dual-affine-connections-dually-flat-manifold/00-index.ipynb](chapter-06-dual-affine-connections-dually-flat-manifold/00-index.ipynb)
# - Canonical notebook: [06-dual-affine-connections-dually-flat-manifold.ipynb](chapter-06-dual-affine-connections-dually-flat-manifold/06-dual-affine-connections-dually-flat-manifold.ipynb)
# - Source span: printed pp. 131-161; PDF pp. 141-171
# - Focus: Dual connections, metric and cubic tensors from divergence, alpha geometry, canonical divergence, mixed coordinates, neural firing, integrated information, and input-output economics.

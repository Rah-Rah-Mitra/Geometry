# %% [markdown]
# # Chapter 02: Population Distributions on Special Manifolds
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [02-population-distributions-on-special-manifolds.ipynb](02-population-distributions-on-special-manifolds.ipynb)

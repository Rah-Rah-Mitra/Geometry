# %% [markdown]
# # Chapter 06: Large Sample Asymptotic Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [06-large-sample-asymptotic-theory.ipynb](06-large-sample-asymptotic-theory.ipynb)

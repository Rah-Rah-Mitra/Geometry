# %% [markdown]
# # Chapter 11: Orthogonal Association
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [11-orthogonal-association.ipynb](11-orthogonal-association.ipynb)

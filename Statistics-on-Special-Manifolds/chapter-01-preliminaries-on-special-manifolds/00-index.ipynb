# %% [markdown]
# # Chapter 01: Preliminaries on Special Manifolds
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [01-preliminaries-on-special-manifolds.ipynb](01-preliminaries-on-special-manifolds.ipynb)

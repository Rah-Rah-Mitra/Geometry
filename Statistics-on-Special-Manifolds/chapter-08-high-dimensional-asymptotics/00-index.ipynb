# %% [markdown]
# # Chapter 08: High-Dimensional Asymptotics
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [08-high-dimensional-asymptotics.ipynb](08-high-dimensional-asymptotics.ipynb)

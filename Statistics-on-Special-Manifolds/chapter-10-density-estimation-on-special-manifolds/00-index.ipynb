# %% [markdown]
# # Chapter 10: Density Estimation on Special Manifolds
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [10-density-estimation-on-special-manifolds.ipynb](10-density-estimation-on-special-manifolds.ipynb)

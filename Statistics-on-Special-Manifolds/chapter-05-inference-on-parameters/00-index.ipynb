# %% [markdown]
# # Chapter 05: Inference on Parameters
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [05-inference-on-parameters.ipynb](05-inference-on-parameters.ipynb)

# %% [markdown]
# # Chapter 09: Procrustes Methods and Shape Analysis
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [09-procrustes-methods-and-shape-analysis.ipynb](09-procrustes-methods-and-shape-analysis.ipynb)

# %% [markdown]
# # Appendix 12: Invariant Polynomials with Matrix Arguments
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-12-invariant-polynomials-with-matrix-arguments.ipynb](appendix-12-invariant-polynomials-with-matrix-arguments.ipynb)

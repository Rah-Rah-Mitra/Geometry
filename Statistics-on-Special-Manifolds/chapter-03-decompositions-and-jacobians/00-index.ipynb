# %% [markdown]
# # Chapter 03: Decompositions and Jacobians
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [03-decompositions-and-jacobians.ipynb](03-decompositions-and-jacobians.ipynb)

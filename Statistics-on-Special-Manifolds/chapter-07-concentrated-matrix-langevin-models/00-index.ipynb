# %% [markdown]
# # Chapter 07: Concentrated Matrix Langevin Models
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [07-concentrated-matrix-langevin-models.ipynb](07-concentrated-matrix-langevin-models.ipynb)

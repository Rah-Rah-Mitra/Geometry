# %% [markdown]
# # Chapter 04: Distributional Problems
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [04-distributional-problems.ipynb](04-distributional-problems.ipynb)

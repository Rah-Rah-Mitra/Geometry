# %% [markdown]
# # Chapter 08: Philosophical Implications
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [08-philosophical-implications.ipynb](08-philosophical-implications.ipynb)
# - Source span: printed pages 290-308; PDF pages 308-326
# - Visual center: physical-space models, axiom-choice diagrams, foundations map
# - Artifact topic: `artifacts/chapter-08-philosophical-implications`

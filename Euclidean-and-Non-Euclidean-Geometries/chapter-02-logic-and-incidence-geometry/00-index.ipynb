# %% [markdown]
# # Chapter 02: Logic and Incidence Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [02-logic-and-incidence-geometry.ipynb](02-logic-and-incidence-geometry.ipynb)
# - Source span: printed pages 38-69; PDF pages 56-87
# - Visual center: proof-state diagrams, truth tables, finite incidence/projective/affine models
# - Artifact topic: `artifacts/chapter-02-logic-and-incidence-geometry`

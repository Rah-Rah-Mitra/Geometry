# %% [markdown]
# # Chapter 05: History of the Parallel Postulate
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [05-history-of-the-parallel-postulate.ipynb](05-history-of-the-parallel-postulate.ipynb)
# - Source span: printed pages 148-176; PDF pages 166-194
# - Visual center: historical timeline, hidden assumptions, Saccheri/Lambert quadrilateral lab
# - Artifact topic: `artifacts/chapter-05-history-of-the-parallel-postulate`

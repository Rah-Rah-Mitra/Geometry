# %% [markdown]
# # Chapter 06: Discovery of Non-Euclidean Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [06-discovery-of-non-euclidean-geometry.ipynb](06-discovery-of-non-euclidean-geometry.ipynb)
# - Source span: printed pages 177-222; PDF pages 195-240
# - Visual center: hyperbolic geodesics, angle defect, limiting parallels, similar-triangle rigidity
# - Artifact topic: `artifacts/chapter-06-discovery-of-non-euclidean-geometry`

# %% [markdown]
# # Chapter 01: Euclid's Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [01-euclids-geometry.ipynb](01-euclids-geometry.ipynb)
# - Source span: printed pages 6-37; PDF pages 24-55
# - Visual center: postulates, construction diagrams, diagram ambiguity, parallel-postulate attempts
# - Artifact topic: `artifacts/chapter-01-euclids-geometry`

# %% [markdown]
# # Chapter 03: Hilbert's Axioms
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [03-hilberts-axioms.ipynb](03-hilberts-axioms.ipynb)
# - Source span: printed pages 70-114; PDF pages 88-132
# - Visual center: axiom-family dependency graph, betweenness, congruence, continuity, parallelism
# - Artifact topic: `artifacts/chapter-03-hilberts-axioms`

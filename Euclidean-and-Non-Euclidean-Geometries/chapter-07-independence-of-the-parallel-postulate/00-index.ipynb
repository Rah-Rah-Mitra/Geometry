# %% [markdown]
# # Chapter 07: Independence of the Parallel Postulate
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [07-independence-of-the-parallel-postulate.ipynb](07-independence-of-the-parallel-postulate.ipynb)
# - Source span: printed pages 223-289; PDF pages 241-307
# - Visual center: Beltrami-Klein/Poincare models, inversion, cross-ratio distance, consistency
# - Artifact topic: `artifacts/chapter-07-independence-of-the-parallel-postulate`

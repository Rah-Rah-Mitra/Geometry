# %% [markdown]
# # Chapter 04: Neutral Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [04-neutral-geometry.ipynb](04-neutral-geometry.ipynb)
# - Source span: printed pages 115-147; PDF pages 133-165
# - Visual center: Saccheri-Legendre, angle sums, equivalent parallel postulates
# - Artifact topic: `artifacts/chapter-04-neutral-geometry`

# %% [markdown]
# # Introduction 00: Introduction
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [00-introduction.ipynb](00-introduction.ipynb)
# - Source span: printed pages 1-5; PDF pages 19-23
# - Visual center: parallel problem, Euclidean vs non-Euclidean course map
# - Artifact topic: `artifacts/chapter-00-introduction`

# %% [markdown]
# # Chapter 10: Further Results in Hyperbolic Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [10-further-results-in-hyperbolic-geometry.ipynb](10-further-results-in-hyperbolic-geometry.ipynb)
# - Source span: printed pages 386-437; PDF pages 404-455
# - Visual center: area defect, angle of parallelism, cycles, hyperbolic trig, pseudosphere mesh
# - Artifact topic: `artifacts/chapter-10-further-results-in-hyperbolic-geometry`

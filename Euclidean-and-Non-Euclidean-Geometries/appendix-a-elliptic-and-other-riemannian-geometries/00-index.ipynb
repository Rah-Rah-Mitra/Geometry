# %% [markdown]
# # Appendix A: Elliptic and Other Riemannian Geometries
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [appendix-a-elliptic-and-other-riemannian-geometries.ipynb](appendix-a-elliptic-and-other-riemannian-geometries.ipynb)
# - Source span: printed pages 438-453; PDF pages 456-471
# - Visual center: elliptic/spherical/projective models, curvature, Riemannian metric intuition
# - Artifact topic: `artifacts/appendix-a-elliptic-and-other-riemannian-geometries`

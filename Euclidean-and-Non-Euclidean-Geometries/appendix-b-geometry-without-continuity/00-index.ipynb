# %% [markdown]
# # Appendix B: Geometry Without Continuity
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [appendix-b-geometry-without-continuity.ipynb](appendix-b-geometry-without-continuity.ipynb)
# - Source span: printed pages 454-460; PDF pages 472-478
# - Visual center: finite/non-continuous models, continuity failure examples
# - Artifact topic: `artifacts/appendix-b-geometry-without-continuity`

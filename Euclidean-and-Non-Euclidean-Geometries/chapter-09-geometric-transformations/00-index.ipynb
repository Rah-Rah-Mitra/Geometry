# %% [markdown]
# # Chapter 09: Geometric Transformations
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [09-geometric-transformations.ipynb](09-geometric-transformations.ipynb)
# - Source span: printed pages 309-385; PDF pages 327-403
# - Visual center: groups, reflections, motions, Mobius transformations, symmetry classification
# - Artifact topic: `artifacts/chapter-09-geometric-transformations`

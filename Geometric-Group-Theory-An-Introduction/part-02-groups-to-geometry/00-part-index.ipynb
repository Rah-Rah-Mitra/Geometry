# %% [markdown]
# # Part II: Groups to Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Source span: printed pp. 51-164; PDF pp. 62-175
# - Focus: Cayley graphs, actions, word metrics, and quasi-isometry
#
# ## Units
#
# - [Chapter 03: Cayley Graphs](chapter-03-cayley-graphs/00-index.ipynb) - graph notation, Cayley graph construction, word length, and free groups as trees.
# - [Chapter 04: Group Actions](chapter-04-group-actions/00-index.ipynb) - group actions, orbits, stabilisers, tree actions, ping-pong, and matrix-group applications.
# - [Chapter 05: Quasi-Isometry](chapter-05-quasi-isometry/00-index.ipynb) - coarse equivalence of metric spaces and groups, quasi-geodesics, Svarc-Milnor, and invariants.

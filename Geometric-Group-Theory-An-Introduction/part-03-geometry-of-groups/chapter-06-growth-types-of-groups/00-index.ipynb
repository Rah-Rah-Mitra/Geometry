# %% [markdown]
# # Chapter 06: Growth Types of Groups
#
# [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [06-growth-types-of-groups.ipynb](06-growth-types-of-groups.ipynb)
# - Source span: printed pp. 167-202; PDF pp. 178-213
# - Sections: 6.1-6.4 and 6.E
# - Focus: growth functions, growth types, polynomial growth, nilpotence, and uniform exponential growth
#
# ## Topics
#
# - ball cardinalities in word metrics
# - coarse comparison of growth functions
# - polynomial growth and virtual nilpotence
# - exponential and uniform exponential growth
#
# ## Artifact Root
#
# Generated diagrams, interactive HTML, and check JSON for this unit live under
# `artifacts/chapter-06/`.

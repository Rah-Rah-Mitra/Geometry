# %% [markdown]
# # Part III: Geometry of Groups
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Source span: printed pp. 165-316; PDF pp. 176-327
# - Focus: growth, hyperbolicity, ends, boundaries, and amenability
#
# ## Units
#
# - [Chapter 06: Growth Types of Groups](chapter-06-growth-types-of-groups/00-index.ipynb) - growth functions, growth types, polynomial growth, nilpotence, and uniform exponential growth.
# - [Chapter 07: Hyperbolic Groups](chapter-07-hyperbolic-groups/00-index.ipynb) - Gromov hyperbolicity, quasi-geodesics, hyperbolic graphs, word problem ideas, and negative-curvature consequences.
# - [Chapter 08: Ends and Boundaries](chapter-08-ends-and-boundaries/00-index.ipynb) - ends, Gromov boundaries, free subgroups in hyperbolic groups, and rigidity at infinity.
# - [Chapter 09: Amenable Groups](chapter-09-amenable-groups/00-index.ipynb) - amenability via means, Folner sets, paradoxical decompositions, and quasi-isometry invariance.

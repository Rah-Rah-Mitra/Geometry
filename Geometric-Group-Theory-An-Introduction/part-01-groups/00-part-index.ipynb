# %% [markdown]
# # Part I: Groups
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Source span: printed pp. 7-50; PDF pp. 18-61
# - Focus: algebraic raw material for geometric group theory
#
# ## Units
#
# - [Chapter 02: Generating Groups](chapter-02-generating-groups/00-index.ipynb) - abstract groups, automorphism groups, quotients, generators, relations, free groups, products, and extensions.

# %% [markdown]
# # Part 00: Orientation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Source span: printed pp. 1-6; PDF pp. 12-17
# - Focus: course motivation and the group-to-geometry pipeline
#
# ## Units
#
# - [Chapter 01: Introduction](chapter-01-introduction/00-index.ipynb) - the geometric group theory workflow, Cayley graph intuition, and large-scale invariants.

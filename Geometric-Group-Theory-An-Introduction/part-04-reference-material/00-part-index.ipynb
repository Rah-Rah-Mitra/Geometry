# %% [markdown]
# # Part IV: Reference Material
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Source span: printed pp. 317-352; PDF pp. 328-363
# - Focus: topological and hyperbolic background plus programming tasks
#
# ## Units
#
# - [Appendix A: Reference Material](appendix-a-reference-material/00-index.ipynb) - fundamental groups, covering theory, group cohomology, hyperbolic plane models, and programming tasks.

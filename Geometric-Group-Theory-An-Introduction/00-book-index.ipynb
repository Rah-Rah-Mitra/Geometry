# %% [markdown]
# # Geometric Group Theory: An Introduction - Standalone Notebook Course
#
# This is an original executable notebook course built from the local Clara Loeh PDF as a source map, not as copied text. The notebooks teach geometric group theory through generated Cayley graphs, quasi-isometry experiments, hyperbolic graph diagnostics, growth and amenability checks, and boundary-at-infinity visuals.
#
# ## Source Notes
#
# - The local PDF is used only for source orientation, terminology, and coverage.
# - The PDF has 390 physical pages.
# - Body and back-matter printed pages map to physical PDF pages by pdf_page = printed_page + 11.
# - Front matter occupies physical PDF pages 1-11.
# - No textbook prose, figures, screenshots, page crops, or long exercise text are copied into the course.
#
# ## Parts
#
# - [Part 00: Orientation](part-00-orientation/00-part-index.ipynb) - printed pp. 1-6; PDF pp. 12-17; course motivation and the group-to-geometry pipeline.
# - [Part I: Groups](part-01-groups/00-part-index.ipynb) - printed pp. 7-50; PDF pp. 18-61; algebraic raw material for geometric group theory.
# - [Part II: Groups to Geometry](part-02-groups-to-geometry/00-part-index.ipynb) - printed pp. 51-164; PDF pp. 62-175; Cayley graphs, actions, word metrics, and quasi-isometry.
# - [Part III: Geometry of Groups](part-03-geometry-of-groups/00-part-index.ipynb) - printed pp. 165-316; PDF pp. 176-327; growth, hyperbolicity, ends, boundaries, and amenability.
# - [Part IV: Reference Material](part-04-reference-material/00-part-index.ipynb) - printed pp. 317-352; PDF pp. 328-363; topological and hyperbolic background plus programming tasks.
#
# ## Course Units
#
# - [Chapter 01: Introduction](part-00-orientation/chapter-01-introduction/00-index.ipynb) - [canonical notebook](part-00-orientation/chapter-01-introduction/01-introduction.ipynb); printed pp. 1-6; PDF pp. 12-17; the geometric group theory workflow, Cayley graph intuition, and large-scale invariants.
# - [Chapter 02: Generating Groups](part-01-groups/chapter-02-generating-groups/00-index.ipynb) - [canonical notebook](part-01-groups/chapter-02-generating-groups/02-generating-groups.ipynb); printed pp. 9-50; PDF pp. 20-61; abstract groups, automorphism groups, quotients, generators, relations, free groups, products, and extensions.
# - [Chapter 03: Cayley Graphs](part-02-groups-to-geometry/chapter-03-cayley-graphs/00-index.ipynb) - [canonical notebook](part-02-groups-to-geometry/chapter-03-cayley-graphs/03-cayley-graphs.ipynb); printed pp. 53-74; PDF pp. 64-85; graph notation, Cayley graph construction, word length, and free groups as trees.
# - [Chapter 04: Group Actions](part-02-groups-to-geometry/chapter-04-group-actions/00-index.ipynb) - [canonical notebook](part-02-groups-to-geometry/chapter-04-group-actions/04-group-actions.ipynb); printed pp. 75-114; PDF pp. 86-125; group actions, orbits, stabilisers, tree actions, ping-pong, and matrix-group applications.
# - [Chapter 05: Quasi-Isometry](part-02-groups-to-geometry/chapter-05-quasi-isometry/00-index.ipynb) - [canonical notebook](part-02-groups-to-geometry/chapter-05-quasi-isometry/05-quasi-isometry.ipynb); printed pp. 115-164; PDF pp. 126-175; coarse equivalence of metric spaces and groups, quasi-geodesics, Svarc-Milnor, and invariants.
# - [Chapter 06: Growth Types of Groups](part-03-geometry-of-groups/chapter-06-growth-types-of-groups/00-index.ipynb) - [canonical notebook](part-03-geometry-of-groups/chapter-06-growth-types-of-groups/06-growth-types-of-groups.ipynb); printed pp. 167-202; PDF pp. 178-213; growth functions, growth types, polynomial growth, nilpotence, and uniform exponential growth.
# - [Chapter 07: Hyperbolic Groups](part-03-geometry-of-groups/chapter-07-hyperbolic-groups/00-index.ipynb) - [canonical notebook](part-03-geometry-of-groups/chapter-07-hyperbolic-groups/07-hyperbolic-groups.ipynb); printed pp. 203-256; PDF pp. 214-267; Gromov hyperbolicity, quasi-geodesics, hyperbolic graphs, word problem ideas, and negative-curvature consequences.
# - [Chapter 08: Ends and Boundaries](part-03-geometry-of-groups/chapter-08-ends-and-boundaries/00-index.ipynb) - [canonical notebook](part-03-geometry-of-groups/chapter-08-ends-and-boundaries/08-ends-and-boundaries.ipynb); printed pp. 257-288; PDF pp. 268-299; ends, Gromov boundaries, free subgroups in hyperbolic groups, and rigidity at infinity.
# - [Chapter 09: Amenable Groups](part-03-geometry-of-groups/chapter-09-amenable-groups/00-index.ipynb) - [canonical notebook](part-03-geometry-of-groups/chapter-09-amenable-groups/09-amenable-groups.ipynb); printed pp. 289-316; PDF pp. 300-327; amenability via means, Folner sets, paradoxical decompositions, and quasi-isometry invariance.
# - [Appendix A: Reference Material](part-04-reference-material/appendix-a-reference-material/00-index.ipynb) - [canonical notebook](part-04-reference-material/appendix-a-reference-material/appendix-a-reference-material.ipynb); printed pp. 319-352; PDF pp. 330-363; fundamental groups, covering theory, group cohomology, hyperbolic plane models, and programming tasks.
#
# ## Back Matter Inventory
#
# - Bibliography: printed pp. 353-366; PDF pp. 364-377.
# - Index of notation: printed pp. 367-372; PDF pp. 378-383.
# - Index: printed pp. 373-379; PDF pp. 384-390.
#
# ## Generated Course Assets
#
# - Source map JSON: `artifacts/source-map/checks/source-map.json` and `source-map.json`.
# - Chapter artifacts: `artifacts/chapter-01/` through `artifacts/chapter-09/`.
# - Appendix artifacts: `artifacts/appendix-a/`.
#
# ## Validation
#
# Run the book-local artifact generator, compile check, index builder, notebook audit, visual audit, limited nbclient execution, optional full execution, and `git diff --check -- Geometric-Group-Theory-An-Introduction` from the workspace root.

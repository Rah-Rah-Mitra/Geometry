# %% [markdown]
# # Part I: Circular Statistics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Circular and axial data, circular summaries, circular models, estimation, tests, and non-parametric methods.
#
# ## Chapter 01: Circular Data
#
# - Chapter index: [chapter-01-circular-data/00-index.ipynb](chapter-01-circular-data/00-index.ipynb)
# - Canonical notebook: [01-circular-data.ipynb](chapter-01-circular-data/01-circular-data.ipynb)
# - Source span: printed pp. 1-12; PDF pp. 20-31
# - Focus: Circular and axial observations, faithful displays, and the distinction between wrapping clock data and projecting compass data.
#
# ## Chapter 02: Summary Statistics
#
# - Chapter index: [chapter-02-summary-statistics/00-index.ipynb](chapter-02-summary-statistics/00-index.ipynb)
# - Canonical notebook: [02-summary-statistics.ipynb](chapter-02-summary-statistics/02-summary-statistics.ipynb)
# - Source span: printed pp. 13-24; PDF pp. 32-42
# - Focus: Coordinate-invariant summaries from unit-vector geometry: mean direction, resultant length, circular median, moments, and grouping corrections.
#
# ## Chapter 03: Basic Concepts and Models
#
# - Chapter index: [chapter-03-basic-concepts-and-models/00-index.ipynb](chapter-03-basic-concepts-and-models/00-index.ipynb)
# - Canonical notebook: [03-basic-concepts-and-models.ipynb](chapter-03-basic-concepts-and-models/03-basic-concepts-and-models.ipynb)
# - Source span: printed pp. 25-56; PDF pp. 43-73
# - Focus: Circular distribution functions, characteristic functions, Fourier reconstruction, and model families such as uniform, von Mises, cardioid, wrapped, and projected distributions.
#
# ## Chapter 04: Fundamental Theorems and Distribution Theory
#
# - Chapter index: [chapter-04-fundamental-theorems-and-distribution-theory/00-index.ipynb](chapter-04-fundamental-theorems-and-distribution-theory/00-index.ipynb)
# - Canonical notebook: [04-fundamental-theorems-and-distribution-theory.ipynb](chapter-04-fundamental-theorems-and-distribution-theory/04-fundamental-theorems-and-distribution-theory.ipynb)
# - Source span: printed pp. 57-82; PDF pp. 74-99
# - Focus: Characteristic-function properties, circular limit theorems, resultant distributions, and high-concentration approximations.
#
# ## Chapter 05: Point Estimation
#
# - Chapter index: [chapter-05-point-estimation/00-index.ipynb](chapter-05-point-estimation/00-index.ipynb)
# - Canonical notebook: [05-point-estimation.ipynb](chapter-05-point-estimation/05-point-estimation.ipynb)
# - Source span: printed pp. 83-92; PDF pp. 100-109
# - Focus: Parameter estimation for circular models, especially von Mises concentration, wrapped Cauchy behavior, and mixtures.
#
# ## Chapter 06: Tests of Uniformity and Goodness-of-Fit
#
# - Chapter index: [chapter-06-tests-of-uniformity-and-goodness-of-fit/00-index.ipynb](chapter-06-tests-of-uniformity-and-goodness-of-fit/00-index.ipynb)
# - Canonical notebook: [06-tests-of-uniformity-and-goodness-of-fit.ipynb](chapter-06-tests-of-uniformity-and-goodness-of-fit/06-tests-of-uniformity-and-goodness-of-fit.ipynb)
# - Source span: printed pp. 93-118; PDF pp. 110-135
# - Focus: Graphical uniformity checks, Rayleigh, Kuiper, Watson, spacing, Ajne, Hermans-Rasson, Beran, and probability-integral-transform diagnostics.
#
# ## Chapter 07: Tests on von Mises Distributions
#
# - Chapter index: [chapter-07-tests-on-von-mises-distributions/00-index.ipynb](chapter-07-tests-on-von-mises-distributions/00-index.ipynb)
# - Canonical notebook: [07-tests-on-von-mises-distributions.ipynb](chapter-07-tests-on-von-mises-distributions/07-tests-on-von-mises-distributions.ipynb)
# - Source span: printed pp. 119-144; PDF pp. 136-160
# - Focus: One-sample, two-sample, and multi-sample inference under von Mises assumptions.
#
# ## Chapter 08: Non-parametric Methods
#
# - Chapter index: [chapter-08-non-parametric-methods/00-index.ipynb](chapter-08-non-parametric-methods/00-index.ipynb)
# - Canonical notebook: [08-non-parametric-methods.ipynb](chapter-08-non-parametric-methods/08-non-parametric-methods.ipynb)
# - Source span: printed pp. 145-158; PDF pp. 161-174
# - Focus: Distribution-free circular inference through symmetry, ranks, uniform scores, two-sample comparisons, runs, and q-sample tests.

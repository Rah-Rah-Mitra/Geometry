# %% [markdown]
# # Chapter 04: Fundamental Theorems and Distribution Theory
#
# Source orientation: printed pages 57-82; PDF pages 74-99.
#
# Canonical notebook: [04-fundamental-theorems-and-distribution-theory.ipynb](04-fundamental-theorems-and-distribution-theory.ipynb)
#
# ## Focus
#
# Characteristic-function properties, circular limit theorems, resultant distributions, and high-concentration approximations.
#
# ## Visual Storyboard
#
# - characteristic-function fingerprints
# - random-walk endpoint cloud
# - joint C and S sampling cloud
# - high-concentration tangent-normal approximation
#
# ## Computational Checks
#
# - simulated 2nR^2 approaches a chi-square reference under uniformity
# - E[Rbar^2] is close to 1/n under uniformity
# - approximations improve with kappa
# - resultant simulations preserve unit-vector sums

# %% [markdown]
# # Appendix 03: Spherical Tables
#
# Source orientation: printed pages 381-390; PDF pages 394-403.
#
# Canonical notebook: [appendix-03-spherical-tables.ipynb](appendix-03-spherical-tables.ipynb)
#
# ## Focus
#
# Executable spherical table replacements for Fisher, Watson, resultant, and concentration calculations.
#
# ## Visual Storyboard
#
# - Fisher colatitude cones
# - spherical concentration inversion
# - Watson girdle versus bipolar density
# - resultant critical cloud
#
# ## Computational Checks
#
# - cap probabilities are between zero and one
# - concentration inversion is monotone
# - Watson axial symmetry holds under sign flips
# - resultant thresholds increase with concentration

# %% [markdown]
# # Appendix 01: Special Functions
#
# Source orientation: printed pages 349-352; PDF pages 362-365.
#
# Canonical notebook: [appendix-01-special-functions.ipynb](appendix-01-special-functions.ipynb)
#
# ## Focus
#
# Bessel, modified Bessel, Bessel-ratio, Kummer, and normalizing-constant calculations used throughout directional models.
#
# ## Visual Storyboard
#
# - Bessel-ratio atlas
# - asymptotic error bands
# - Kummer normalizer lab
# - Stiefel integral check
#
# ## Computational Checks
#
# - Bessel ratios are monotone on the plotted range
# - inverse concentration recovers the original resultant
# - asymptotic error decreases in its intended regime
# - normalizers are finite and positive

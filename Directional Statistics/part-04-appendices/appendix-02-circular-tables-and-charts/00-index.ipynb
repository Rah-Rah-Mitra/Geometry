# %% [markdown]
# # Appendix 02: Circular Tables and Charts
#
# Source orientation: printed pages 353-380; PDF pages 366-393.
#
# Canonical notebook: [appendix-02-circular-tables-and-charts.ipynb](appendix-02-circular-tables-and-charts.ipynb)
#
# ## Focus
#
# Executable replacements for circular critical-value and estimation tables.
#
# ## Visual Storyboard
#
# - von Mises tail quantile fan
# - circular concentration inversion
# - uniformity null comparison
# - kappa confidence-band lab
#
# ## Computational Checks
#
# - computed quantiles are ordered
# - A inverse is monotone
# - simulation seeds reproduce critical values
# - confidence bands widen for small samples

# %% [markdown]
# # Part II: Spherical Statistics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Distributions, inference, dependence, regression, and modern methods for directions on spheres.
#
# ## Chapter 09: Distributions on Spheres
#
# - Chapter index: [chapter-09-distributions-on-spheres/00-index.ipynb](chapter-09-distributions-on-spheres/00-index.ipynb)
# - Canonical notebook: [09-distributions-on-spheres.ipynb](chapter-09-distributions-on-spheres/09-distributions-on-spheres.ipynb)
# - Source span: printed pp. 159-192; PDF pp. 175-208
# - Focus: Spherical data, descriptive measures, von Mises-Fisher and axial models, distribution theory, and asymptotics on spheres.
#
# ## Chapter 10: Inference on Spheres
#
# - Chapter index: [chapter-10-inference-on-spheres/00-index.ipynb](chapter-10-inference-on-spheres/00-index.ipynb)
# - Canonical notebook: [10-inference-on-spheres.ipynb](chapter-10-inference-on-spheres/10-inference-on-spheres.ipynb)
# - Source span: printed pp. 193-244; PDF pp. 209-259
# - Focus: Exploratory spherical analysis, parameter estimation, uniformity tests, mean-direction confidence cones, and axial distribution tests.
#
# ## Chapter 11: Correlation and Regression
#
# - Chapter index: [chapter-11-correlation-and-regression/00-index.ipynb](chapter-11-correlation-and-regression/00-index.ipynb)
# - Canonical notebook: [11-correlation-and-regression.ipynb](chapter-11-correlation-and-regression/11-correlation-and-regression.ipynb)
# - Source span: printed pp. 245-266; PDF pp. 260-281
# - Focus: Linear-circular, circular-circular, spherical-spherical dependence, directional regression, bivariate models, and directional time series.
#
# ## Chapter 12: Modern Methodology
#
# - Chapter index: [chapter-12-modern-methodology/00-index.ipynb](chapter-12-modern-methodology/00-index.ipynb)
# - Canonical notebook: [12-modern-methodology.ipynb](chapter-12-modern-methodology/12-modern-methodology.ipynb)
# - Source span: printed pp. 267-282; PDF pp. 282-297
# - Focus: Outliers, robust estimation, bootstrap methods, density estimation, Bayesian ideas, and smoothing for directional data.

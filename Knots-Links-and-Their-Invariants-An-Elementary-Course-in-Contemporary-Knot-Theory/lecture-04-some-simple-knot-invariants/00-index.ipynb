# %% [markdown]
# # Lecture 4: Some Simple Knot Invariants
#
# Source span: printed pages `29-38`.
#
# Focus: Stick number, crossing number, unknotting number, tricolorability, orientable surfaces, Seifert surfaces, and genus.
#
# Canonical notebook: [`04-some-simple-knot-invariants.ipynb`](04-some-simple-knot-invariants.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

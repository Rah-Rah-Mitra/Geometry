# %% [markdown]
# # Lecture 11: The Kontsevich Integrals
#
# Source span: printed pages `95-102`.
#
# Focus: Kontsevich integral for trefoil, configuration-space integral intuition, and finite type invariant encoding.
#
# Canonical notebook: [`11-the-kontsevich-integrals.ipynb`](11-the-kontsevich-integrals.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Lecture 3: The Arithmetic of Knots
#
# Source span: printed pages `21-28`.
#
# Focus: Boxed knots, connected sum, knot semigroup, prime decomposition, and unknotting remarks.
#
# Canonical notebook: [`03-the-arithmetic-of-knots.ipynb`](03-the-arithmetic-of-knots.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

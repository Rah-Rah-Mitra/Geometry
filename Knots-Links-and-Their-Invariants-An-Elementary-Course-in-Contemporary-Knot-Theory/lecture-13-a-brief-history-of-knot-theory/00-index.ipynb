# %% [markdown]
# # Lecture 13: A Brief History of Knot Theory
#
# Source span: printed pages `111-131`.
#
# Focus: Historical development, invariant milestones, and conceptual map of contemporary knot theory.
#
# Canonical notebook: [`13-a-brief-history-of-knot-theory.ipynb`](13-a-brief-history-of-knot-theory.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

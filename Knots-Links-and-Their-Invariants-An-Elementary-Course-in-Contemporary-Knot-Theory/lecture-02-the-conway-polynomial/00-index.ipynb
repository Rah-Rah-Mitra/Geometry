# %% [markdown]
# # Lecture 2: The Conway Polynomial
#
# Source span: printed pages `11-20`.
#
# Focus: Axiomatic Conway polynomial, skein calculations, uniqueness, existence, chirality, orientation reversal, and multiplicativity.
#
# Canonical notebook: [`02-the-conway-polynomial.ipynb`](02-the-conway-polynomial.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Lecture 1: Knots and Links, Reidemeister Moves
#
# Source span: printed pages `1-10`.
#
# Focus: Knot and link diagrams, Reidemeister moves, torus knots, invertibility, and chirality.
#
# Canonical notebook: [`01-knots-and-links-reidemeister-moves.ipynb`](01-knots-and-links-reidemeister-moves.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Lecture 9: Vassiliev Invariants
#
# Source span: printed pages `77-86`.
#
# Focus: Singular knots, one-term and four-term relations, spaces of invariants, chord diagrams, and low-order examples.
#
# Canonical notebook: [`09-vassiliev-invariants.ipynb`](09-vassiliev-invariants.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Lecture 5: The Kauffman Bracket
#
# Source span: printed pages `39-46`.
#
# Focus: States of knot diagrams, Kauffman bracket definition and properties, and invariance defects.
#
# Canonical notebook: [`05-the-kauffman-bracket.ipynb`](05-the-kauffman-bracket.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

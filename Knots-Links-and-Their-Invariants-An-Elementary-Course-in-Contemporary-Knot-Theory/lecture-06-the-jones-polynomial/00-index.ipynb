# %% [markdown]
# # Lecture 6: The Jones Polynomial
#
# Source span: printed pages `47-56`.
#
# Focus: Jones polynomial via Kauffman bracket, axioms, multiplicativity, chirality, reversibility, and knot tables.
#
# Canonical notebook: [`06-the-jones-polynomial.ipynb`](06-the-jones-polynomial.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Lecture 12: Other Important Topics
#
# Source span: printed pages `103-110`.
#
# Focus: Further knot-theoretic topics and relationships among invariants and constructions.
#
# Canonical notebook: [`12-other-important-topics.ipynb`](12-other-important-topics.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

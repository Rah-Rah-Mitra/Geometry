# %% [markdown]
# # Lecture 8: Discriminants and Finite Type Invariants
#
# Source span: printed pages `69-76`.
#
# Focus: Quadratic discriminants, degree of point relative to curve, inertia index, and Gauss linking number.
#
# Canonical notebook: [`08-discriminants-and-finite-type-invariants.ipynb`](08-discriminants-and-finite-type-invariants.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 6: The Hodge Theorem
#
# Source span: printed pages `220-240`.
#
# Focus: Laplace-Beltrami operator, Hodge theorem, calculus estimates, elliptic operators, periodic reduction, and ellipticity.
#
# Canonical notebook: [`06-the-hodge-theorem.ipynb`](06-the-hodge-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

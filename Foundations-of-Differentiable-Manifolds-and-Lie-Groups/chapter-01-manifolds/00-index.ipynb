# %% [markdown]
# # Chapter 1: Manifolds
#
# Source span: printed pages `1-53`.
#
# Canonical notebook: [`01-manifolds.ipynb`](01-manifolds.ipynb).
#
# Focus: Differentiable manifolds, tangent vectors, differentials, submanifolds, inverse and implicit functions, vector fields, distributions, and Frobenius theorem.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Foundations-of-Differentiable-Manifolds-and-Lie-Groups

# %% [markdown]
# # Chapter 3: Lie Groups
#
# Source span: printed pages `82-137`.
#
# Focus: Lie groups, Lie algebras, homomorphisms, subgroups, coverings, exponential map, adjoint representation, and homogeneous manifolds.
#
# Canonical notebook: [`03-lie-groups.ipynb`](03-lie-groups.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 2: Tensors and Differential Forms
#
# Source span: printed pages `54-81`.
#
# Canonical notebook: [`02-tensors-and-differential-forms.ipynb`](02-tensors-and-differential-forms.ipynb).
#
# Focus: Tensor and exterior algebras, tensor fields, differential forms, Lie derivatives, and differential ideals.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Foundations-of-Differentiable-Manifolds-and-Lie-Groups

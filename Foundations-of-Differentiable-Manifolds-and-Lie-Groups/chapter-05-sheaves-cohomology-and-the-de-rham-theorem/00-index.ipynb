# %% [markdown]
# # Chapter 5: Sheaves, Cohomology, and the de Rham Theorem
#
# Source span: printed pages `163-219`.
#
# Focus: Sheaves, cochain complexes, axiomatic sheaf cohomology, classical cohomology theories, de Rham theorem, products, and supports.
#
# Canonical notebook: [`05-sheaves-cohomology-and-the-de-rham.ipynb`](05-sheaves-cohomology-and-the-de-rham.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

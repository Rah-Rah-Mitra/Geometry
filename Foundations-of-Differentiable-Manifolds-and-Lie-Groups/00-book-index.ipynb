# %% [markdown]
# # Foundations of Differentiable Manifolds and Lie Groups
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Manifolds | 1-53 | [`01-manifolds.ipynb`](chapter-01-manifolds/01-manifolds.ipynb) |
# | Chapter 2 | Tensors and Differential Forms | 54-81 | [`02-tensors-and-differential-forms.ipynb`](chapter-02-tensors-and-differential-forms/02-tensors-and-differential-forms.ipynb) |
# | Chapter 3 | Lie Groups | 82-137 | [`03-lie-groups.ipynb`](chapter-03-lie-groups/03-lie-groups.ipynb) |
# | Chapter 4 | Integration on Manifolds | 138-162 | [`04-integration-on-manifolds.ipynb`](chapter-04-integration-on-manifolds/04-integration-on-manifolds.ipynb) |
# | Chapter 5 | Sheaves, Cohomology, and the de Rham Theorem | 163-219 | [`05-sheaves-cohomology-and-the-de-rham.ipynb`](chapter-05-sheaves-cohomology-and-the-de-rham-theorem/05-sheaves-cohomology-and-the-de-rham.ipynb) |
# | Chapter 6 | The Hodge Theorem | 220-259 | [`06-the-hodge-theorem.ipynb`](chapter-06-the-hodge-theorem/06-the-hodge-theorem.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Foundations of Differentiable Manifolds and Lie Groups: 6 canonical units

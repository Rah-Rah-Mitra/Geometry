# %% [markdown]
# # Part III: General Sample Spaces and Shape
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Frames, rotations, Stiefel and Grassmann manifolds, hyperboloids, and landmark shape spaces.
#
# ## Chapter 13: General Sample Spaces
#
# - Chapter index: [chapter-13-general-sample-spaces/00-index.ipynb](chapter-13-general-sample-spaces/00-index.ipynb)
# - Canonical notebook: [13-general-sample-spaces.ipynb](chapter-13-general-sample-spaces/13-general-sample-spaces.ipynb)
# - Source span: printed pp. 283-302; PDF pp. 298-316
# - Focus: Directional statistics on rotations, frames, Stiefel manifolds, Grassmann manifolds, hyperboloids, and general manifolds.
#
# ## Chapter 14: Shape Analysis
#
# - Chapter index: [chapter-14-shape-analysis/00-index.ipynb](chapter-14-shape-analysis/00-index.ipynb)
# - Canonical notebook: [14-shape-analysis.ipynb](chapter-14-shape-analysis/14-shape-analysis.ipynb)
# - Source span: printed pp. 303-348; PDF pp. 317-361
# - Focus: Landmark shape analysis as directional statistics on preshape and shape spaces, including Procrustes means, tangent approximations, and complex directional models.

# %% [markdown]
# # Chapter 14: Shape Analysis
#
# Source orientation: printed pages 303-348; PDF pages 317-361.
#
# Canonical notebook: [14-shape-analysis.ipynb](14-shape-analysis.ipynb)
#
# ## Focus
#
# Landmark shape analysis as directional statistics on preshape and shape spaces, including Procrustes means, tangent approximations, and complex directional models.
#
# ## Visual Storyboard
#
# - landmark invariance pipeline
# - triangle shape sphere
# - Procrustes alignment overlay
# - tangent shape PCA deformation modes
#
# ## Computational Checks
#
# - Helmert rows are orthonormal and remove translation
# - preshape norm equals one
# - Procrustes distance is invariant to similarity transformations
# - tangent coordinates are orthogonal to the mean shape

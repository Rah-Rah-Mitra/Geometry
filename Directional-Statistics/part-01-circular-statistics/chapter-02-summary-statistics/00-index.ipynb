# %% [markdown]
# # Chapter 02: Summary Statistics
#
# Source orientation: printed pages 13-24; PDF pages 32-42.
#
# Canonical notebook: [02-summary-statistics.ipynb](02-summary-statistics.ipynb)
#
# ## Focus
#
# Coordinate-invariant summaries from unit-vector geometry: mean direction, resultant length, circular median, moments, and grouping corrections.
#
# ## Visual Storyboard
#
# - resultant vector construction
# - cut-point failure for the linear mean
# - dispersion curve minimized at the circular mean
# - trigonometric moment dashboard
#
# ## Computational Checks
#
# - sum sin(theta_i - mean) is zero
# - D(mean) equals 1 - R
# - mean direction rotates equivariantly
# - grouping corrections are small for fine bins

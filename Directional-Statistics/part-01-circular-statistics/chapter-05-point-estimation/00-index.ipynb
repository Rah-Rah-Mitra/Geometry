# %% [markdown]
# # Chapter 05: Point Estimation
#
# Source orientation: printed pages 83-92; PDF pages 100-109.
#
# Canonical notebook: [05-point-estimation.ipynb](05-point-estimation.ipynb)
#
# ## Focus
#
# Parameter estimation for circular models, especially von Mises concentration, wrapped Cauchy behavior, and mixtures.
#
# ## Visual Storyboard
#
# - von Mises likelihood surface
# - A(kappa) inverse curve
# - finite-sample concentration bias bands
# - two-component mixture responsibilities
#
# ## Computational Checks
#
# - A(kappa_hat) matches R
# - likelihood gradient is small at the estimate
# - rotation of data rotates mu_hat
# - mixture weights sum to one

# %% [markdown]
# # Appendix 04: Notation
#
# Source orientation: printed pages 391-394; PDF pages 404-406.
#
# Canonical notebook: [appendix-04-notation.ipynb](appendix-04-notation.ipynb)
#
# ## Focus
#
# Executable notation atlas for sample spaces, statistics, model families, special functions, and shape-analysis symbols.
#
# ## Visual Storyboard
#
# - notation dependency map
# - sample-space gallery
# - distribution-family map
# - notation glossary JSON
#
# ## Computational Checks
#
# - all glossary entries have a concept family
# - graph nodes referenced by edges exist
# - sample-space symbols map to notebook chapters
# - JSON glossary is readable

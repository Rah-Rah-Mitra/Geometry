# %% [markdown]
# # Chapter 10: Gauss' Theorema Egregium
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [10-gauss-theorema-egregium.ipynb](10-gauss-theorema-egregium.ipynb)
# - Source span: printed pages 247-269; PDF pages 249-270
# - Sections: 10.1-10.4
# - Artifact topic: `artifacts/chapter-10/`
#
# ## Focus
#
# Proves and applies the intrinsic invariance of Gaussian curvature via Gauss-Codazzi-Mainardi equations, constant curvature surfaces, and geodesic mappings.
#
# ## Topics
#
# - Gauss equations
# - Codazzi-Mainardi equations
# - intrinsic curvature
# - bending without stretching
# - constant curvature coordinates
# - geodesic mappings

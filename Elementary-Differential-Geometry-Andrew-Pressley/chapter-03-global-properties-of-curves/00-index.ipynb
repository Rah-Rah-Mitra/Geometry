# %% [markdown]
# # Chapter 3: Global properties of curves
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [03-global-properties-of-curves.ipynb](03-global-properties-of-curves.ipynb)
# - Source span: printed pages 55-66; PDF pages 64-74
# - Sections: 3.1-3.3
# - Artifact topic: `artifacts/chapter-03/`
#
# ## Focus
#
# Moves from local curve quantities to global statements about simple closed curves, enclosed area, isoperimetry, and the four vertex theorem.
#
# ## Topics
#
# - simple closed curves
# - oriented area and Green-style computation
# - isoperimetric inequality
# - roundness deficit
# - curvature extrema
# - four vertex theorem experiments

# %% [markdown]
# # Appendix A1: Isometries of Euclidean spaces
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [a1-isometries-of-euclidean-spaces.ipynb](a1-isometries-of-euclidean-spaces.ipynb)
# - Source span: printed pages A1; PDF pages 382-389
# - Sections: Appendix 1
# - Artifact topic: `artifacts/appendix-a1/`
#
# ## Focus
#
# Summarizes Euclidean isometries as translations, rotations, reflections, and orthogonal affine maps.
#
# ## Topics
#
# - Euclidean isometries
# - translations
# - orthogonal matrices
# - reflections
# - rotations
# - orientation

# %% [markdown]
# # Chapter 4: Surfaces in three dimensions
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [04-surfaces-in-three-dimensions.ipynb](04-surfaces-in-three-dimensions.ipynb)
# - Source span: printed pages 67-94; PDF pages 75-101
# - Sections: 4.1-4.5
# - Artifact topic: `artifacts/chapter-04/`
#
# ## Focus
#
# Defines surfaces through patches, smoothness, maps, tangent planes, derivatives, normals, and orientability.
#
# ## Topics
#
# - surface patches and atlases
# - smoothness and transition maps
# - smooth maps between surfaces
# - tangent planes from parameter curves
# - surface normals
# - orientability and the Mobius-band obstruction

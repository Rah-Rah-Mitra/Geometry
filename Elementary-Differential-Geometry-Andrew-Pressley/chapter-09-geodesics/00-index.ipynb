# %% [markdown]
# # Chapter 9: Geodesics
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [09-geodesics.ipynb](09-geodesics.ipynb)
# - Source span: printed pages 215-246; PDF pages 218-248
# - Sections: 9.1-9.5
# - Artifact topic: `artifacts/chapter-09/`
#
# ## Focus
#
# Develops geodesics as straightest and shortest surface curves, with equations, surfaces of revolution, Clairaut's theorem, and geodesic coordinates.
#
# ## Topics
#
# - geodesic definition
# - geodesic equations
# - surfaces of revolution
# - Clairaut invariant
# - shortest paths
# - geodesic coordinates

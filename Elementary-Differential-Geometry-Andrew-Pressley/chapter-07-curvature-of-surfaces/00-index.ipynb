# %% [markdown]
# # Chapter 7: Curvature of surfaces
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [07-curvature-of-surfaces.ipynb](07-curvature-of-surfaces.ipynb)
# - Source span: printed pages 159-178; PDF pages 164-182
# - Sections: 7.1-7.4
# - Artifact topic: `artifacts/chapter-07/`
#
# ## Focus
#
# Introduces the second fundamental form, Gauss and Weingarten maps, normal/geodesic curvature, parallel transport, and covariant derivative.
#
# ## Topics
#
# - second fundamental form
# - Gauss map
# - Weingarten map
# - normal curvature
# - geodesic curvature
# - parallel transport
# - covariant derivative

# %% [markdown]
# # Chapter 11: Hyperbolic geometry
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [11-hyperbolic-geometry.ipynb](11-hyperbolic-geometry.ipynb)
# - Source span: printed pages 270-304; PDF pages 271-306
# - Sections: 11.1-11.5
# - Artifact topic: `artifacts/chapter-11/`
#
# ## Focus
#
# Builds hyperbolic geometry through the upper half-plane, isometries, Poincare disk, parallels, Beltrami-Klein model, and cross-ratio distance.
#
# ## Topics
#
# - upper half-plane model
# - hyperbolic isometries
# - Poincare disk model
# - hyperbolic parallels
# - Beltrami-Klein model
# - cross-ratio distance

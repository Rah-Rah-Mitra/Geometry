# %% [markdown]
# # Chapter 8: Gaussian, mean and principal curvatures
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [08-gaussian-mean-and-principal-curvatures.ipynb](08-gaussian-mean-and-principal-curvatures.ipynb)
# - Source span: printed pages 179-214; PDF pages 183-217
# - Sections: 8.1-8.6
# - Artifact topic: `artifacts/chapter-08/`
#
# ## Focus
#
# Extracts Gaussian, mean, and principal curvatures from the shape operator and explores constant curvature, flat, constant mean curvature, and compact surface consequences.
#
# ## Topics
#
# - Gaussian and mean curvature
# - principal curvatures
# - constant Gaussian curvature
# - flat surfaces
# - constant mean curvature
# - compact-surface curvature constraints

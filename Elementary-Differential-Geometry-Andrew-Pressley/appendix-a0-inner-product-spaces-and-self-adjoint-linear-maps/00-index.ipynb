# %% [markdown]
# # Appendix A0: Inner product spaces and self-adjoint linear maps
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [a0-inner-product-spaces-and-self-adjoint-linear-maps.ipynb](a0-inner-product-spaces-and-self-adjoint-linear-maps.ipynb)
# - Source span: printed pages A0; PDF pages 379-381
# - Sections: Appendix 0
# - Artifact topic: `artifacts/appendix-a0/`
#
# ## Focus
#
# Provides the linear-algebra language needed for metrics, self-adjoint maps, eigenvectors, and principal curvature directions.
#
# ## Topics
#
# - inner products
# - orthonormal bases
# - bilinear and quadratic forms
# - self-adjoint maps
# - eigenvectors
# - spectral theorem

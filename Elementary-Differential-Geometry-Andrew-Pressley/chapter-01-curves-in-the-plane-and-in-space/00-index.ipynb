# %% [markdown]
# # Chapter 1: Curves in the plane and in space
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [01-curves-in-the-plane-and-in-space.ipynb](01-curves-in-the-plane-and-in-space.ipynb)
# - Source span: printed pages 1-27; PDF pages 11-37
# - Sections: 1.1-1.5
# - Artifact topic: `artifacts/chapter-01/`
#
# ## Focus
#
# Introduces curves as parametrized paths and level sets, then develops tangent vectors, arc length, reparametrization, closed curves, and regularity.
#
# ## Topics
#
# - parametrized and level curves
# - tangent vectors and regular points
# - arc length and unit-speed parameters
# - reparametrization and singularities
# - closed curves and self-intersections
# - local passage between level and parametrized descriptions

# %% [markdown]
# # Chapter 5: Examples of surfaces
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [05-examples-of-surfaces.ipynb](05-examples-of-surfaces.ipynb)
# - Source span: printed pages 95-120; PDF pages 102-126
# - Sections: 5.1-5.6
# - Artifact topic: `artifacts/chapter-05/`
#
# ## Focus
#
# Catalogs level surfaces, quadrics, ruled surfaces, surfaces of revolution, compact surfaces, triply orthogonal systems, and inverse-function-theorem applications.
#
# ## Topics
#
# - level surfaces
# - quadric classification
# - ruled surfaces
# - surfaces of revolution
# - compact surfaces and genus
# - triply orthogonal systems
# - inverse function theorem as local model control

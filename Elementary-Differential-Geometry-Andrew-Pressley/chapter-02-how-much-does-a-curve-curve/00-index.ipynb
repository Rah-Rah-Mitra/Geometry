# %% [markdown]
# # Chapter 2: How much does a curve curve?
#
# [Back to book index](../00-book-index.ipynb)
#
# - Canonical notebook: [02-how-much-does-a-curve-curve.ipynb](02-how-much-does-a-curve-curve.ipynb)
# - Source span: printed pages 29-54; PDF pages 38-63
# - Sections: 2.1-2.3
# - Artifact topic: `artifacts/chapter-02/`
#
# ## Focus
#
# Builds curvature and torsion for plane and space curves, including signed curvature, osculating circles, Frenet frames, and shape determination.
#
# ## Topics
#
# - curvature of unit-speed curves
# - curvature formulas for arbitrary parameters
# - signed curvature and tangent turning
# - osculating circles and evolutes
# - space curves and torsion
# - Frenet-Serret frame checks

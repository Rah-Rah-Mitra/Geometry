# %% [markdown]
# # Chapter 8: Polyhedra
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [08-polyhedra.ipynb](08-polyhedra.ipynb)
# - Source span: printed pp. 435-480; PDF pp. 447-492
# - Sections: 44-47: regular solids, Euler/Cauchy, semiregular polyhedra, symmetry groups
# - Focus: Studies polyhedra through meshes, Euler characteristic, rigidity intuition, and symmetry diagnostics.
#
# ## Topics
#
# - The regular solids
# - Euler characteristic
# - Cauchy rigidity as edge-face constraint
# - Semiregular polyhedra and symmetry groups
#
# ## Artifact Root
#
# Generated diagrams, interactive HTML, and check JSON for this unit live under
# `artifacts/chapter-08/`.

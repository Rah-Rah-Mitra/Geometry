# %% [markdown]
# # Lecture 24: Reduction
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [24-reduction.ipynb](24-reduction.ipynb)
# - Source span: printed pp. 145-152; physical PDF pp. 159-166
# - Artifact topic: `artifacts/lecture-24`
# - Focus: Explores Noether's principle, elementary reduction, product groups, other levels, and orbifold warnings.
#
# ## Lecture Sections
#
# - Noether principle
# - Elementary reduction
# - Product groups
# - Reduction at other levels
# - Orbifolds
#
# ## Computational Concepts
#
# - Noether conserved quantity
# - product reduction
# - shifted level
# - orbifold quotient
#
# ## Visual Route
#
# conserved level slices and quotient fibers
#
# ## Lab Prompt
#
# Run a toy reduction of C2 by a circle and inspect how different levels change the reduced space.

# %% [markdown]
# # Part IX: Symplectic Reduction
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Marsden-Weinstein-Meyer reduction and conservation principles.
#
# ## Lecture 23: The Marsden-Weinstein-Meyer Theorem
#
# - Chapter index: [lecture-23-the-marsden-weinstein-meyer-theorem/00-index.ipynb](lecture-23-the-marsden-weinstein-meyer-theorem/00-index.ipynb)
# - Canonical notebook: [23-the-marsden-weinstein-meyer-theorem.ipynb](lecture-23-the-marsden-weinstein-meyer-theorem/23-the-marsden-weinstein-meyer-theorem.ipynb)
# - Source span: printed pp. 139-144; physical PDF pp. 153-158
# - Focus: States and proves the main regular-level reduction theorem.
# - Primary visual: level set quotient and dimension count
#
# ## Lecture 24: Reduction
#
# - Chapter index: [lecture-24-reduction/00-index.ipynb](lecture-24-reduction/00-index.ipynb)
# - Canonical notebook: [24-reduction.ipynb](lecture-24-reduction/24-reduction.ipynb)
# - Source span: printed pp. 145-152; physical PDF pp. 159-166
# - Focus: Explores Noether's principle, elementary reduction, product groups, other levels, and orbifold warnings.
# - Primary visual: conserved level slices and quotient fibers

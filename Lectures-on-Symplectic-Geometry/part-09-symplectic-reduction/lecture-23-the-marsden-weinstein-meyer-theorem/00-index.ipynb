# %% [markdown]
# # Lecture 23: The Marsden-Weinstein-Meyer Theorem
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [23-the-marsden-weinstein-meyer-theorem.ipynb](23-the-marsden-weinstein-meyer-theorem.ipynb)
# - Source span: printed pp. 139-144; physical PDF pp. 153-158
# - Artifact topic: `artifacts/lecture-23`
# - Focus: States and proves the main regular-level reduction theorem.
#
# ## Lecture Sections
#
# - Statement
# - Ingredients
# - Proof of the theorem
#
# ## Computational Concepts
#
# - regular value
# - level set
# - group orbit
# - reduced symplectic form
#
# ## Visual Route
#
# level set quotient and dimension count
#
# ## Lab Prompt
#
# Check the dimension formula for a free circle action and identify the kernel directions of the restricted form.

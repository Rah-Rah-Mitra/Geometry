# %% [markdown]
# # Lecture 03: Lagrangian Submanifolds
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [03-lagrangian-submanifolds.ipynb](03-lagrangian-submanifolds.ipynb)
# - Source span: printed pp. 13-19; physical PDF pp. 27-33
# - Artifact topic: `artifacts/lecture-03`
# - Focus: Recasts symplectomorphisms as Lagrangian graphs and explains graphs of closed one-forms in cotangent bundles.
#
# ## Lecture Sections
#
# - Submanifolds
# - Lagrangian submanifolds of T*X
# - Conormal bundles
# - Application to symplectomorphisms
#
# ## Computational Concepts
#
# - Lagrangian condition
# - closed one-form graph
# - conormal bundle
# - twisted product form
#
# ## Visual Route
#
# closed one-form graph and conormal slice
#
# ## Lab Prompt
#
# Check that the graph of df is Lagrangian and that a conormal bundle kills the tautological form.

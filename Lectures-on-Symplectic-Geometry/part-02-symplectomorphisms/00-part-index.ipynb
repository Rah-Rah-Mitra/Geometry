# %% [markdown]
# # Part II: Symplectomorphisms
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Lagrangian submanifolds, generating functions, and recurrence.
#
# ## Lecture 03: Lagrangian Submanifolds
#
# - Chapter index: [lecture-03-lagrangian-submanifolds/00-index.ipynb](lecture-03-lagrangian-submanifolds/00-index.ipynb)
# - Canonical notebook: [03-lagrangian-submanifolds.ipynb](lecture-03-lagrangian-submanifolds/03-lagrangian-submanifolds.ipynb)
# - Source span: printed pp. 13-19; physical PDF pp. 27-33
# - Focus: Recasts symplectomorphisms as Lagrangian graphs and explains graphs of closed one-forms in cotangent bundles.
# - Primary visual: closed one-form graph and conormal slice
#
# ## Lecture 04: Generating Functions
#
# - Chapter index: [lecture-04-generating-functions/00-index.ipynb](lecture-04-generating-functions/00-index.ipynb)
# - Canonical notebook: [04-generating-functions.ipynb](lecture-04-generating-functions/04-generating-functions.ipynb)
# - Source span: printed pp. 20-26; physical PDF pp. 34-40
# - Focus: Uses generating functions to manufacture Lagrangian graphs and hence symplectomorphisms.
# - Primary visual: contours of a generating function and the induced twist map
#
# ## Lecture 05: Recurrence
#
# - Chapter index: [lecture-05-recurrence/00-index.ipynb](lecture-05-recurrence/00-index.ipynb)
# - Canonical notebook: [05-recurrence.ipynb](lecture-05-recurrence/05-recurrence.ipynb)
# - Source span: printed pp. 27-32; physical PDF pp. 41-46
# - Focus: Connects symplectic area preservation with periodic points, billiards, and Poincare recurrence.
# - Primary visual: billiard chords and recurrence histogram

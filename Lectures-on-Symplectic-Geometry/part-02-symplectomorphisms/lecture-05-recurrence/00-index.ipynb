# %% [markdown]
# # Lecture 05: Recurrence
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [05-recurrence.ipynb](05-recurrence.ipynb)
# - Source span: printed pp. 27-32; physical PDF pp. 41-46
# - Artifact topic: `artifacts/lecture-05`
# - Focus: Connects symplectic area preservation with periodic points, billiards, and Poincare recurrence.
#
# ## Lecture Sections
#
# - Periodic points
# - Billiards
# - Poincare recurrence
#
# ## Computational Concepts
#
# - area-preserving map
# - billiard return map
# - recurrence
# - periodic point
#
# ## Visual Route
#
# billiard chords and recurrence histogram
#
# ## Lab Prompt
#
# Simulate a simple area-preserving rotation and estimate first return times to a window.

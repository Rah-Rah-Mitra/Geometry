# %% [markdown]
# # Lecture 04: Generating Functions
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [04-generating-functions.ipynb](04-generating-functions.ipynb)
# - Source span: printed pp. 20-26; physical PDF pp. 34-40
# - Artifact topic: `artifacts/lecture-04`
# - Focus: Uses generating functions to manufacture Lagrangian graphs and hence symplectomorphisms.
#
# ## Lecture Sections
#
# - Constructing symplectomorphisms
# - Method of generating functions
# - Application to geodesic flow
#
# ## Computational Concepts
#
# - twisted graph
# - generating function
# - mixed Hessian
# - geodesic flow
#
# ## Visual Route
#
# contours of a generating function and the induced twist map
#
# ## Lab Prompt
#
# Vary a quadratic generating function and check the symplectic residual of the resulting map.

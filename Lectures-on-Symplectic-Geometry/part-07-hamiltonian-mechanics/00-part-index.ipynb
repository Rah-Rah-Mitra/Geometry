# %% [markdown]
# # Part VII: Hamiltonian Mechanics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Hamiltonian vector fields, variational principles, and Legendre transform.
#
# ## Lecture 18: Hamiltonian Vector Fields
#
# - Chapter index: [lecture-18-hamiltonian-vector-fields/00-index.ipynb](lecture-18-hamiltonian-vector-fields/00-index.ipynb)
# - Canonical notebook: [18-hamiltonian-vector-fields.ipynb](lecture-18-hamiltonian-vector-fields/18-hamiltonian-vector-fields.ipynb)
# - Source span: printed pp. 103-110; physical PDF pp. 117-124
# - Focus: Defines Hamiltonian and symplectic vector fields and connects them to mechanics, brackets, and integrable systems.
# - Primary visual: phase portrait with Hamiltonian level sets
#
# ## Lecture 19: Variational Principles
#
# - Chapter index: [lecture-19-variational-principles/00-index.ipynb](lecture-19-variational-principles/00-index.ipynb)
# - Canonical notebook: [19-variational-principles.ipynb](lecture-19-variational-principles/19-variational-principles.ipynb)
# - Source span: printed pp. 111-118; physical PDF pp. 125-132
# - Focus: Relates equations of motion to least action, Euler-Lagrange equations, and minimizing behavior.
# - Primary visual: path-action comparison and residual plot
#
# ## Lecture 20: Legendre Transform
#
# - Chapter index: [lecture-20-legendre-transform/00-index.ipynb](lecture-20-legendre-transform/00-index.ipynb)
# - Canonical notebook: [20-legendre-transform.ipynb](lecture-20-legendre-transform/20-legendre-transform.ipynb)
# - Source span: printed pp. 119-124; physical PDF pp. 133-138
# - Focus: Uses strict convexity to pass between Lagrangian and Hamiltonian descriptions.
# - Primary visual: convex graph with tangent slopes and dual curve

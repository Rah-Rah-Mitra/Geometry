# %% [markdown]
# # Lecture 18: Hamiltonian Vector Fields
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [18-hamiltonian-vector-fields.ipynb](18-hamiltonian-vector-fields.ipynb)
# - Source span: printed pp. 103-110; physical PDF pp. 117-124
# - Artifact topic: `artifacts/lecture-18`
# - Focus: Defines Hamiltonian and symplectic vector fields and connects them to mechanics, brackets, and integrable systems.
#
# ## Lecture Sections
#
# - Hamiltonian and symplectic vector fields
# - Classical mechanics
# - Brackets
# - Integrable systems
#
# ## Computational Concepts
#
# - Hamiltonian vector field
# - Poisson bracket
# - energy conservation
# - integrable system
#
# ## Visual Route
#
# phase portrait with Hamiltonian level sets
#
# ## Lab Prompt
#
# Integrate the harmonic oscillator and check that the Poisson bracket with its Hamiltonian vanishes.

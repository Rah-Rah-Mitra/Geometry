# %% [markdown]
# # Lecture 19: Variational Principles
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [19-variational-principles.ipynb](19-variational-principles.ipynb)
# - Source span: printed pp. 111-118; physical PDF pp. 125-132
# - Artifact topic: `artifacts/lecture-19`
# - Focus: Relates equations of motion to least action, Euler-Lagrange equations, and minimizing behavior.
#
# ## Lecture Sections
#
# - Equations of motion
# - Principle of least action
# - Variational problems
# - Euler-Lagrange equations
# - Minimizing properties
#
# ## Computational Concepts
#
# - action functional
# - Euler-Lagrange equation
# - geodesic minimizer
# - first variation
#
# ## Visual Route
#
# path-action comparison and residual plot
#
# ## Lab Prompt
#
# Compare nearby polygonal paths and verify that the straight path has zero first-variation residual.

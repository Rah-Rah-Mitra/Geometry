# %% [markdown]
# # Lecture 20: Legendre Transform
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [20-legendre-transform.ipynb](20-legendre-transform.ipynb)
# - Source span: printed pp. 119-124; physical PDF pp. 133-138
# - Artifact topic: `artifacts/lecture-20`
# - Focus: Uses strict convexity to pass between Lagrangian and Hamiltonian descriptions.
#
# ## Lecture Sections
#
# - Strict convexity
# - Legendre transform
# - Application to variational problems
#
# ## Computational Concepts
#
# - strict convexity
# - dual variables
# - Fenchel inequality
# - Hamiltonian from Lagrangian
#
# ## Visual Route
#
# convex graph with tangent slopes and dual curve
#
# ## Lab Prompt
#
# Compute the Legendre transform of a quadratic-plus-quartic model and check Fenchel equality at the matching slope.

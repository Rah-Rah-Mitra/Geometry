# %% [markdown]
# # Lecture 28: Classification of Symplectic Toric Manifolds
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [28-classification-of-symplectic-toric-manifolds.ipynb](28-classification-of-symplectic-toric-manifolds.ipynb)
# - Source span: printed pp. 175-180; physical PDF pp. 189-194
# - Artifact topic: `artifacts/lecture-28`
# - Focus: States Delzant polytopes and the classification theorem for compact symplectic toric manifolds.
#
# ## Lecture Sections
#
# - Delzant polytopes
# - Delzant theorem
# - Sketch of Delzant construction
#
# ## Computational Concepts
#
# - Delzant polytope
# - primitive normal
# - smooth vertex
# - toric classification
#
# ## Visual Route
#
# Delzant polygons with primitive normal checks
#
# ## Lab Prompt
#
# Compute adjacent normal determinants for triangle and square polytopes and flag a nonsmooth corner.

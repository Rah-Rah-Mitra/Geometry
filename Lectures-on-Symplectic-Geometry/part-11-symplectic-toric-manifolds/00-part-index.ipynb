# %% [markdown]
# # Part XI: Symplectic Toric Manifolds
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Delzant classification, construction, and Duistermaat-Heckman variation.
#
# ## Lecture 28: Classification of Symplectic Toric Manifolds
#
# - Chapter index: [lecture-28-classification-of-symplectic-toric-manifolds/00-index.ipynb](lecture-28-classification-of-symplectic-toric-manifolds/00-index.ipynb)
# - Canonical notebook: [28-classification-of-symplectic-toric-manifolds.ipynb](lecture-28-classification-of-symplectic-toric-manifolds/28-classification-of-symplectic-toric-manifolds.ipynb)
# - Source span: printed pp. 175-180; physical PDF pp. 189-194
# - Focus: States Delzant polytopes and the classification theorem for compact symplectic toric manifolds.
# - Primary visual: Delzant polygons with primitive normal checks
#
# ## Lecture 29: Delzant Construction
#
# - Chapter index: [lecture-29-delzant-construction/00-index.ipynb](lecture-29-delzant-construction/00-index.ipynb)
# - Canonical notebook: [29-delzant-construction.ipynb](lecture-29-delzant-construction/29-delzant-construction.ipynb)
# - Source span: printed pp. 181-188; physical PDF pp. 195-202
# - Focus: Builds the toric manifold from a Delzant polytope via a quotient construction.
# - Primary visual: facet inequalities and quotient dimension flow
#
# ## Lecture 30: Duistermaat-Heckman Theorems
#
# - Chapter index: [lecture-30-duistermaat-heckman-theorems/00-index.ipynb](lecture-30-duistermaat-heckman-theorems/00-index.ipynb)
# - Canonical notebook: [30-duistermaat-heckman-theorems.ipynb](lecture-30-duistermaat-heckman-theorems/30-duistermaat-heckman-theorems.ipynb)
# - Source span: printed pp. 189-196; physical PDF pp. 203-210
# - Focus: Describes how reduced symplectic volume varies polynomially with the moment-map level.
# - Primary visual: reduced-volume curve across moment levels

# %% [markdown]
# # Lecture 29: Delzant Construction
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [29-delzant-construction.ipynb](29-delzant-construction.ipynb)
# - Source span: printed pp. 181-188; physical PDF pp. 195-202
# - Artifact topic: `artifacts/lecture-29`
# - Focus: Builds the toric manifold from a Delzant polytope via a quotient construction.
#
# ## Lecture Sections
#
# - Algebraic set-up
# - The zero-level
# - Conclusion of the construction
# - Idea behind the construction
#
# ## Computational Concepts
#
# - facet map
# - kernel torus
# - zero level
# - quotient construction
#
# ## Visual Route
#
# facet inequalities and quotient dimension flow
#
# ## Lab Prompt
#
# Construct the matrix of inward normals for a triangle and verify the quotient dimension count.

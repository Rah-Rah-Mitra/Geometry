# %% [markdown]
# # Lecture 30: Duistermaat-Heckman Theorems
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [30-duistermaat-heckman-theorems.ipynb](30-duistermaat-heckman-theorems.ipynb)
# - Source span: printed pp. 189-196; physical PDF pp. 203-210
# - Artifact topic: `artifacts/lecture-30`
# - Focus: Describes how reduced symplectic volume varies polynomially with the moment-map level.
#
# ## Lecture Sections
#
# - Duistermaat-Heckman polynomial
# - Local form for reduced spaces
# - Variation of symplectic volume
#
# ## Computational Concepts
#
# - reduced volume
# - piecewise polynomial
# - equivariant local form
# - volume variation
#
# ## Visual Route
#
# reduced-volume curve across moment levels
#
# ## Lab Prompt
#
# Compute a CP1/CP2 toy volume density and check its piecewise polynomial behavior.

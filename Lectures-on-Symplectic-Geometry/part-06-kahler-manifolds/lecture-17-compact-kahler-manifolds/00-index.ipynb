# %% [markdown]
# # Lecture 17: Compact Kahler Manifolds
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [17-compact-kahler-manifolds.ipynb](17-compact-kahler-manifolds.ipynb)
# - Source span: printed pp. 96-102; physical PDF pp. 110-116
# - Artifact topic: `artifacts/lecture-17`
# - Focus: Explains Hodge-theoretic restrictions and compares compact Kahler examples with symplectic nonexamples.
#
# ## Lecture Sections
#
# - Hodge theory
# - Immediate topological consequences
# - Compact examples and counterexamples
# - Main Kahler manifolds
#
# ## Computational Concepts
#
# - Hodge diamond
# - Betti parity
# - Kodaira-Thurston contrast
# - projective examples
#
# ## Visual Route
#
# Hodge diamond and topology ledger
#
# ## Lab Prompt
#
# Build small Hodge diamonds and check the evenness constraints they impose on Betti numbers.

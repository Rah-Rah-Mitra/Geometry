# %% [markdown]
# # Lecture 16: Kahler Forms
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [16-kahler-forms.ipynb](16-kahler-forms.ipynb)
# - Source span: printed pp. 88-95; physical PDF pp. 102-109
# - Artifact topic: `artifacts/lecture-16`
# - Focus: Builds Kahler forms from compatible triples and potentials, including the Fubini-Study model.
#
# ## Lecture Sections
#
# - Kahler forms
# - An application
# - Recipe to obtain Kahler forms
# - Local canonical form
#
# ## Computational Concepts
#
# - Kahler form
# - Kahler potential
# - Fubini-Study form
# - local canonical coordinates
#
# ## Visual Route
#
# Kahler potential contours and Fubini-Study density
#
# ## Lab Prompt
#
# Differentiate a radial potential and verify positivity of the associated Hermitian form.

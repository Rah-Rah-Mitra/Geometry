# %% [markdown]
# # Part VI: Kahler Manifolds
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Complex manifolds, Kahler forms, Hodge restrictions, and examples.
#
# ## Lecture 15: Complex Manifolds
#
# - Chapter index: [lecture-15-complex-manifolds/00-index.ipynb](lecture-15-complex-manifolds/00-index.ipynb)
# - Canonical notebook: [15-complex-manifolds.ipynb](lecture-15-complex-manifolds/15-complex-manifolds.ipynb)
# - Source span: printed pp. 81-87; physical PDF pp. 95-101
# - Focus: Moves from almost complex linear algebra to holomorphic charts and differential forms on complex manifolds.
# - Primary visual: two-chart atlas for CP1 and type decomposition
#
# ## Lecture 16: Kahler Forms
#
# - Chapter index: [lecture-16-kahler-forms/00-index.ipynb](lecture-16-kahler-forms/00-index.ipynb)
# - Canonical notebook: [16-kahler-forms.ipynb](lecture-16-kahler-forms/16-kahler-forms.ipynb)
# - Source span: printed pp. 88-95; physical PDF pp. 102-109
# - Focus: Builds Kahler forms from compatible triples and potentials, including the Fubini-Study model.
# - Primary visual: Kahler potential contours and Fubini-Study density
#
# ## Lecture 17: Compact Kahler Manifolds
#
# - Chapter index: [lecture-17-compact-kahler-manifolds/00-index.ipynb](lecture-17-compact-kahler-manifolds/00-index.ipynb)
# - Canonical notebook: [17-compact-kahler-manifolds.ipynb](lecture-17-compact-kahler-manifolds/17-compact-kahler-manifolds.ipynb)
# - Source span: printed pp. 96-102; physical PDF pp. 110-116
# - Focus: Explains Hodge-theoretic restrictions and compares compact Kahler examples with symplectic nonexamples.
# - Primary visual: Hodge diamond and topology ledger

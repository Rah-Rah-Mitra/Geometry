# %% [markdown]
# # Lecture 15: Complex Manifolds
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [15-complex-manifolds.ipynb](15-complex-manifolds.ipynb)
# - Source span: printed pp. 81-87; physical PDF pp. 95-101
# - Artifact topic: `artifacts/lecture-15`
# - Focus: Moves from almost complex linear algebra to holomorphic charts and differential forms on complex manifolds.
#
# ## Lecture Sections
#
# - Complex charts
# - Forms on complex manifolds
# - Differentials
#
# ## Computational Concepts
#
# - holomorphic atlas
# - complex coordinates
# - forms of type
# - complex projective space
#
# ## Visual Route
#
# two-chart atlas for CP1 and type decomposition
#
# ## Lab Prompt
#
# Compute the transition map between stereographic charts and verify holomorphic behavior away from overlap poles.

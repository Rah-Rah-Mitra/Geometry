# %% [markdown]
# # Lecture 21: Actions
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [21-actions.ipynb](21-actions.ipynb)
# - Source span: printed pp. 125-130; physical PDF pp. 139-144
# - Artifact topic: `artifacts/lecture-21`
# - Focus: Introduces one-parameter groups, Lie group actions, symplectic and Hamiltonian actions, and adjoint/coadjoint representations.
#
# ## Lecture Sections
#
# - One-parameter groups
# - Lie groups
# - Smooth actions
# - Symplectic and Hamiltonian actions
# - Adjoint and coadjoint representations
#
# ## Computational Concepts
#
# - group action
# - infinitesimal generator
# - symplectic action
# - coadjoint orbit
#
# ## Visual Route
#
# orbits and infinitesimal generators for a circle action
#
# ## Lab Prompt
#
# Plot a circle action on the plane and check that the infinitesimal generator preserves the standard form.

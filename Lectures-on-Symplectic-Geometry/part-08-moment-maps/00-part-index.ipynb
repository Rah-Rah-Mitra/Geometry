# %% [markdown]
# # Part VIII: Moment Maps
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Group actions, Hamiltonian actions, and first moment-map examples.
#
# ## Lecture 21: Actions
#
# - Chapter index: [lecture-21-actions/00-index.ipynb](lecture-21-actions/00-index.ipynb)
# - Canonical notebook: [21-actions.ipynb](lecture-21-actions/21-actions.ipynb)
# - Source span: printed pp. 125-130; physical PDF pp. 139-144
# - Focus: Introduces one-parameter groups, Lie group actions, symplectic and Hamiltonian actions, and adjoint/coadjoint representations.
# - Primary visual: orbits and infinitesimal generators for a circle action
#
# ## Lecture 22: Hamiltonian Actions
#
# - Chapter index: [lecture-22-hamiltonian-actions/00-index.ipynb](lecture-22-hamiltonian-actions/00-index.ipynb)
# - Canonical notebook: [22-hamiltonian-actions.ipynb](lecture-22-hamiltonian-actions/22-hamiltonian-actions.ipynb)
# - Source span: printed pp. 131-138; physical PDF pp. 145-152
# - Focus: Defines moment and comoment maps, previews reduction, and works through classical Hamiltonian action examples.
# - Primary visual: moment-map fibers for circle and torus actions

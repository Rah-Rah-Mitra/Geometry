# %% [markdown]
# # Lecture 22: Hamiltonian Actions
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [22-hamiltonian-actions.ipynb](22-hamiltonian-actions.ipynb)
# - Source span: printed pp. 131-138; physical PDF pp. 145-152
# - Artifact topic: `artifacts/lecture-22`
# - Focus: Defines moment and comoment maps, previews reduction, and works through classical Hamiltonian action examples.
#
# ## Lecture Sections
#
# - Moment and comoment maps
# - Orbit spaces
# - Preview of reduction
# - Classical examples
#
# ## Computational Concepts
#
# - moment map
# - comoment map
# - orbit space
# - coadjoint orbit example
#
# ## Visual Route
#
# moment-map fibers for circle and torus actions
#
# ## Lab Prompt
#
# Verify d<mu,xi>=i_X omega for the standard circle action on C.

# %% [markdown]
# # Lectures on Symplectic Geometry - Standalone Notebook Edition
#
# This course is an original executable notebook edition organized around the thirty lecture chapters in Ana Cannas da Silva's local PDF. It uses fresh prose, generated diagrams, computational checks, and book-local artifacts. The source PDF stays local and is not redistributed through screenshots or page crops.
#
# Source map: Arabic printed body pages map to physical PDF pages by `physical_pdf_page = printed_page + 14`.
#
# ## Part I: Introduction
#
# Symplectic forms, first examples, and cotangent bundles.
#
# - [Open part index](part-01-introduction/00-part-index.ipynb)
# - [Lecture 01: Symplectic Forms](part-01-introduction/lecture-01-symplectic-forms/00-index.ipynb) - [canonical notebook](part-01-introduction/lecture-01-symplectic-forms/01-symplectic-forms.ipynb); printed pp. 1-6; PDF pp. 15-20; Builds the linear and manifold definition of a symplectic form from skew-symmetric bilinear algebra.
# - [Lecture 02: Symplectic Form on the Cotangent Bundle](part-01-introduction/lecture-02-symplectic-form-on-the-cotangent-bundle/00-index.ipynb) - [canonical notebook](part-01-introduction/lecture-02-symplectic-form-on-the-cotangent-bundle/02-symplectic-form-on-the-cotangent-bundle.ipynb); printed pp. 7-12; PDF pp. 21-26; Introduces the tautological one-form and canonical symplectic form on a cotangent bundle.
#
# ## Part II: Symplectomorphisms
#
# Lagrangian submanifolds, generating functions, and recurrence.
#
# - [Open part index](part-02-symplectomorphisms/00-part-index.ipynb)
# - [Lecture 03: Lagrangian Submanifolds](part-02-symplectomorphisms/lecture-03-lagrangian-submanifolds/00-index.ipynb) - [canonical notebook](part-02-symplectomorphisms/lecture-03-lagrangian-submanifolds/03-lagrangian-submanifolds.ipynb); printed pp. 13-19; PDF pp. 27-33; Recasts symplectomorphisms as Lagrangian graphs and explains graphs of closed one-forms in cotangent bundles.
# - [Lecture 04: Generating Functions](part-02-symplectomorphisms/lecture-04-generating-functions/00-index.ipynb) - [canonical notebook](part-02-symplectomorphisms/lecture-04-generating-functions/04-generating-functions.ipynb); printed pp. 20-26; PDF pp. 34-40; Uses generating functions to manufacture Lagrangian graphs and hence symplectomorphisms.
# - [Lecture 05: Recurrence](part-02-symplectomorphisms/lecture-05-recurrence/00-index.ipynb) - [canonical notebook](part-02-symplectomorphisms/lecture-05-recurrence/05-recurrence.ipynb); printed pp. 27-32; PDF pp. 41-46; Connects symplectic area preservation with periodic points, billiards, and Poincare recurrence.
#
# ## Part III: Local Forms
#
# Isotopies, Moser's method, Darboux normal form, and Weinstein neighborhoods.
#
# - [Open part index](part-03-local-forms/00-part-index.ipynb)
# - [Lecture 06: Preparation for the Local Theory](part-03-local-forms/lecture-06-preparation-for-the-local-theory/00-index.ipynb) - [canonical notebook](part-03-local-forms/lecture-06-preparation-for-the-local-theory/06-preparation-for-the-local-theory.ipynb); printed pp. 33-39; PDF pp. 47-53; Assembles isotopies, vector fields, tubular neighborhoods, and the homotopy formula needed for Moser arguments.
# - [Lecture 07: Moser Theorems](part-03-local-forms/lecture-07-moser-theorems/00-index.ipynb) - [canonical notebook](part-03-local-forms/lecture-07-moser-theorems/07-moser-theorems.ipynb); printed pp. 40-43; PDF pp. 54-57; Develops Moser's trick as a controlled deformation of symplectic forms by solving for a vector field.
# - [Lecture 08: Darboux-Moser-Weinstein Theory](part-03-local-forms/lecture-08-darboux-moser-weinstein-theory/00-index.ipynb) - [canonical notebook](part-03-local-forms/lecture-08-darboux-moser-weinstein-theory/08-darboux-moser-weinstein-theory.ipynb); printed pp. 44-48; PDF pp. 58-62; Proves local symplectic normal forms and relates Lagrangian neighborhoods to cotangent models.
# - [Lecture 09: Weinstein Tubular Neighborhood Theorem](part-03-local-forms/lecture-09-weinstein-tubular-neighborhood-theorem/00-index.ipynb) - [canonical notebook](part-03-local-forms/lecture-09-weinstein-tubular-neighborhood-theorem/09-weinstein-tubular-neighborhood-theorem.ipynb); printed pp. 49-54; PDF pp. 63-68; Applies local models to symplectic tubular neighborhoods, symplectomorphism groups, and fixed points.
#
# ## Part IV: Contact Manifolds
#
# Contact forms, Reeb fields, and symplectization.
#
# - [Open part index](part-04-contact-manifolds/00-part-index.ipynb)
# - [Lecture 10: Contact Forms](part-04-contact-manifolds/lecture-10-contact-forms/00-index.ipynb) - [canonical notebook](part-04-contact-manifolds/lecture-10-contact-forms/10-contact-forms.ipynb); printed pp. 55-60; PDF pp. 69-74; Introduces maximally nonintegrable hyperplane fields and first contact examples.
# - [Lecture 11: Contact Dynamics](part-04-contact-manifolds/lecture-11-contact-dynamics/00-index.ipynb) - [canonical notebook](part-04-contact-manifolds/lecture-11-contact-dynamics/11-contact-dynamics.ipynb); printed pp. 61-64; PDF pp. 75-78; Studies Reeb fields, symplectization, and the dynamical conjectures that motivate contact geometry.
#
# ## Part V: Compatible Almost Complex Structures
#
# Compatible complex structures, triples, and Dolbeault decompositions.
#
# - [Open part index](part-05-compatible-almost-complex-structures/00-part-index.ipynb)
# - [Lecture 12: Almost Complex Structures](part-05-compatible-almost-complex-structures/lecture-12-almost-complex-structures/00-index.ipynb) - [canonical notebook](part-05-compatible-almost-complex-structures/lecture-12-almost-complex-structures/12-almost-complex-structures.ipynb); printed pp. 65-71; PDF pp. 79-85; Compares symplectic, metric, and almost-complex linear structures and the compatibility conditions between them.
# - [Lecture 13: Compatible Triples](part-05-compatible-almost-complex-structures/lecture-13-compatible-triples/00-index.ipynb) - [canonical notebook](part-05-compatible-almost-complex-structures/lecture-13-compatible-triples/13-compatible-triples.ipynb); printed pp. 72-75; PDF pp. 86-89; Packages symplectic forms, metrics, and complex structures into mutually determining compatible triples.
# - [Lecture 14: Dolbeault Theory](part-05-compatible-almost-complex-structures/lecture-14-dolbeault-theory/00-index.ipynb) - [canonical notebook](part-05-compatible-almost-complex-structures/lecture-14-dolbeault-theory/14-dolbeault-theory.ipynb); printed pp. 76-80; PDF pp. 90-94; Introduces type decompositions of forms and the Dolbeault operators for almost complex and complex settings.
#
# ## Part VI: Kahler Manifolds
#
# Complex manifolds, Kahler forms, Hodge restrictions, and examples.
#
# - [Open part index](part-06-kahler-manifolds/00-part-index.ipynb)
# - [Lecture 15: Complex Manifolds](part-06-kahler-manifolds/lecture-15-complex-manifolds/00-index.ipynb) - [canonical notebook](part-06-kahler-manifolds/lecture-15-complex-manifolds/15-complex-manifolds.ipynb); printed pp. 81-87; PDF pp. 95-101; Moves from almost complex linear algebra to holomorphic charts and differential forms on complex manifolds.
# - [Lecture 16: Kahler Forms](part-06-kahler-manifolds/lecture-16-kahler-forms/00-index.ipynb) - [canonical notebook](part-06-kahler-manifolds/lecture-16-kahler-forms/16-kahler-forms.ipynb); printed pp. 88-95; PDF pp. 102-109; Builds Kahler forms from compatible triples and potentials, including the Fubini-Study model.
# - [Lecture 17: Compact Kahler Manifolds](part-06-kahler-manifolds/lecture-17-compact-kahler-manifolds/00-index.ipynb) - [canonical notebook](part-06-kahler-manifolds/lecture-17-compact-kahler-manifolds/17-compact-kahler-manifolds.ipynb); printed pp. 96-102; PDF pp. 110-116; Explains Hodge-theoretic restrictions and compares compact Kahler examples with symplectic nonexamples.
#
# ## Part VII: Hamiltonian Mechanics
#
# Hamiltonian vector fields, variational principles, and Legendre transform.
#
# - [Open part index](part-07-hamiltonian-mechanics/00-part-index.ipynb)
# - [Lecture 18: Hamiltonian Vector Fields](part-07-hamiltonian-mechanics/lecture-18-hamiltonian-vector-fields/00-index.ipynb) - [canonical notebook](part-07-hamiltonian-mechanics/lecture-18-hamiltonian-vector-fields/18-hamiltonian-vector-fields.ipynb); printed pp. 103-110; PDF pp. 117-124; Defines Hamiltonian and symplectic vector fields and connects them to mechanics, brackets, and integrable systems.
# - [Lecture 19: Variational Principles](part-07-hamiltonian-mechanics/lecture-19-variational-principles/00-index.ipynb) - [canonical notebook](part-07-hamiltonian-mechanics/lecture-19-variational-principles/19-variational-principles.ipynb); printed pp. 111-118; PDF pp. 125-132; Relates equations of motion to least action, Euler-Lagrange equations, and minimizing behavior.
# - [Lecture 20: Legendre Transform](part-07-hamiltonian-mechanics/lecture-20-legendre-transform/00-index.ipynb) - [canonical notebook](part-07-hamiltonian-mechanics/lecture-20-legendre-transform/20-legendre-transform.ipynb); printed pp. 119-124; PDF pp. 133-138; Uses strict convexity to pass between Lagrangian and Hamiltonian descriptions.
#
# ## Part VIII: Moment Maps
#
# Group actions, Hamiltonian actions, and first moment-map examples.
#
# - [Open part index](part-08-moment-maps/00-part-index.ipynb)
# - [Lecture 21: Actions](part-08-moment-maps/lecture-21-actions/00-index.ipynb) - [canonical notebook](part-08-moment-maps/lecture-21-actions/21-actions.ipynb); printed pp. 125-130; PDF pp. 139-144; Introduces one-parameter groups, Lie group actions, symplectic and Hamiltonian actions, and adjoint/coadjoint representations.
# - [Lecture 22: Hamiltonian Actions](part-08-moment-maps/lecture-22-hamiltonian-actions/00-index.ipynb) - [canonical notebook](part-08-moment-maps/lecture-22-hamiltonian-actions/22-hamiltonian-actions.ipynb); printed pp. 131-138; PDF pp. 145-152; Defines moment and comoment maps, previews reduction, and works through classical Hamiltonian action examples.
#
# ## Part IX: Symplectic Reduction
#
# Marsden-Weinstein-Meyer reduction and conservation principles.
#
# - [Open part index](part-09-symplectic-reduction/00-part-index.ipynb)
# - [Lecture 23: The Marsden-Weinstein-Meyer Theorem](part-09-symplectic-reduction/lecture-23-the-marsden-weinstein-meyer-theorem/00-index.ipynb) - [canonical notebook](part-09-symplectic-reduction/lecture-23-the-marsden-weinstein-meyer-theorem/23-the-marsden-weinstein-meyer-theorem.ipynb); printed pp. 139-144; PDF pp. 153-158; States and proves the main regular-level reduction theorem.
# - [Lecture 24: Reduction](part-09-symplectic-reduction/lecture-24-reduction/00-index.ipynb) - [canonical notebook](part-09-symplectic-reduction/lecture-24-reduction/24-reduction.ipynb); printed pp. 145-152; PDF pp. 159-166; Explores Noether's principle, elementary reduction, product groups, other levels, and orbifold warnings.
#
# ## Part X: Moment Maps Revisited
#
# Gauge-theoretic moment maps, existence, uniqueness, and convexity.
#
# - [Open part index](part-10-moment-maps-revisited/00-part-index.ipynb)
# - [Lecture 25: Moment Map in Gauge Theory](part-10-moment-maps-revisited/lecture-25-moment-map-in-gauge-theory/00-index.ipynb) - [canonical notebook](part-10-moment-maps-revisited/lecture-25-moment-map-in-gauge-theory/25-moment-map-in-gauge-theory.ipynb); printed pp. 153-161; PDF pp. 167-175; Reinterprets curvature of connections as a moment map for gauge-group action.
# - [Lecture 26: Existence and Uniqueness of Moment Maps](part-10-moment-maps-revisited/lecture-26-existence-and-uniqueness-of-moment-maps/00-index.ipynb) - [canonical notebook](part-10-moment-maps-revisited/lecture-26-existence-and-uniqueness-of-moment-maps/26-existence-and-uniqueness-of-moment-maps.ipynb); printed pp. 162-167; PDF pp. 176-181; Uses Lie algebra cohomology to organize obstructions and uniqueness for moment maps.
# - [Lecture 27: Convexity](part-10-moment-maps-revisited/lecture-27-convexity/00-index.ipynb) - [canonical notebook](part-10-moment-maps-revisited/lecture-27-convexity/27-convexity.ipynb); printed pp. 168-174; PDF pp. 182-188; Presents convexity of moment-map images for torus actions and examples of effective actions.
#
# ## Part XI: Symplectic Toric Manifolds
#
# Delzant classification, construction, and Duistermaat-Heckman variation.
#
# - [Open part index](part-11-symplectic-toric-manifolds/00-part-index.ipynb)
# - [Lecture 28: Classification of Symplectic Toric Manifolds](part-11-symplectic-toric-manifolds/lecture-28-classification-of-symplectic-toric-manifolds/00-index.ipynb) - [canonical notebook](part-11-symplectic-toric-manifolds/lecture-28-classification-of-symplectic-toric-manifolds/28-classification-of-symplectic-toric-manifolds.ipynb); printed pp. 175-180; PDF pp. 189-194; States Delzant polytopes and the classification theorem for compact symplectic toric manifolds.
# - [Lecture 29: Delzant Construction](part-11-symplectic-toric-manifolds/lecture-29-delzant-construction/00-index.ipynb) - [canonical notebook](part-11-symplectic-toric-manifolds/lecture-29-delzant-construction/29-delzant-construction.ipynb); printed pp. 181-188; PDF pp. 195-202; Builds the toric manifold from a Delzant polytope via a quotient construction.
# - [Lecture 30: Duistermaat-Heckman Theorems](part-11-symplectic-toric-manifolds/lecture-30-duistermaat-heckman-theorems/00-index.ipynb) - [canonical notebook](part-11-symplectic-toric-manifolds/lecture-30-duistermaat-heckman-theorems/30-duistermaat-heckman-theorems.ipynb); printed pp. 189-196; PDF pp. 203-210; Describes how reduced symplectic volume varies polynomially with the moment-map level.

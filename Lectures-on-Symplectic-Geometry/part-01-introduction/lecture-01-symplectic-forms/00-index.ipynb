# %% [markdown]
# # Lecture 01: Symplectic Forms
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [01-symplectic-forms.ipynb](01-symplectic-forms.ipynb)
# - Source span: printed pp. 1-6; physical PDF pp. 15-20
# - Artifact topic: `artifacts/lecture-01`
# - Focus: Builds the linear and manifold definition of a symplectic form from skew-symmetric bilinear algebra.
#
# ## Lecture Sections
#
# - Skew-symmetric bilinear maps
# - Symplectic vector spaces
# - Symplectic manifolds
# - Symplectomorphisms
#
# ## Computational Concepts
#
# - standard form for a skew map
# - symplectic basis
# - nondegenerate two-form
# - Darboux chart preview
#
# ## Visual Route
#
# matrix normal form and area-pair basis diagram
#
# ## Lab Prompt
#
# Classify random skew matrices by rank and check when the induced form is nondegenerate.

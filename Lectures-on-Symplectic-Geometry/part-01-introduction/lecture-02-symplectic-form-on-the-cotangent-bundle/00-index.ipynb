# %% [markdown]
# # Lecture 02: Symplectic Form on the Cotangent Bundle
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [02-symplectic-form-on-the-cotangent-bundle.ipynb](02-symplectic-form-on-the-cotangent-bundle.ipynb)
# - Source span: printed pp. 7-12; physical PDF pp. 21-26
# - Artifact topic: `artifacts/lecture-02`
# - Focus: Introduces the tautological one-form and canonical symplectic form on a cotangent bundle.
#
# ## Lecture Sections
#
# - Cotangent bundle
# - Tautological and canonical forms in coordinates
# - Coordinate-free definitions
# - Naturality
#
# ## Computational Concepts
#
# - cotangent coordinates
# - tautological one-form
# - canonical two-form
# - naturality under lifted maps
#
# ## Visual Route
#
# cotangent fibers and canonical-form grid
#
# ## Lab Prompt
#
# Compute alpha and omega on a simple cotangent bundle and verify coordinate-free pullback behavior.

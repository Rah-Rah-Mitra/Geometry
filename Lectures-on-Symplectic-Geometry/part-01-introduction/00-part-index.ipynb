# %% [markdown]
# # Part I: Introduction
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Symplectic forms, first examples, and cotangent bundles.
#
# ## Lecture 01: Symplectic Forms
#
# - Chapter index: [lecture-01-symplectic-forms/00-index.ipynb](lecture-01-symplectic-forms/00-index.ipynb)
# - Canonical notebook: [01-symplectic-forms.ipynb](lecture-01-symplectic-forms/01-symplectic-forms.ipynb)
# - Source span: printed pp. 1-6; physical PDF pp. 15-20
# - Focus: Builds the linear and manifold definition of a symplectic form from skew-symmetric bilinear algebra.
# - Primary visual: matrix normal form and area-pair basis diagram
#
# ## Lecture 02: Symplectic Form on the Cotangent Bundle
#
# - Chapter index: [lecture-02-symplectic-form-on-the-cotangent-bundle/00-index.ipynb](lecture-02-symplectic-form-on-the-cotangent-bundle/00-index.ipynb)
# - Canonical notebook: [02-symplectic-form-on-the-cotangent-bundle.ipynb](lecture-02-symplectic-form-on-the-cotangent-bundle/02-symplectic-form-on-the-cotangent-bundle.ipynb)
# - Source span: printed pp. 7-12; physical PDF pp. 21-26
# - Focus: Introduces the tautological one-form and canonical symplectic form on a cotangent bundle.
# - Primary visual: cotangent fibers and canonical-form grid

# %% [markdown]
# # Lecture 25: Moment Map in Gauge Theory
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [25-moment-map-in-gauge-theory.ipynb](25-moment-map-in-gauge-theory.ipynb)
# - Source span: printed pp. 153-161; physical PDF pp. 167-175
# - Artifact topic: `artifacts/lecture-25`
# - Focus: Reinterprets curvature of connections as a moment map for gauge-group action.
#
# ## Lecture Sections
#
# - Connections on a principal bundle
# - Connection and curvature forms
# - Symplectic structure on the space of connections
# - Action of the gauge group
# - Case of circle bundles
#
# ## Computational Concepts
#
# - connection
# - curvature
# - gauge action
# - moment map as curvature
#
# ## Visual Route
#
# discrete connection grid and curvature cells
#
# ## Lab Prompt
#
# Use a square lattice connection toy model and verify that curvature changes by a boundary term under a gauge shift.

# %% [markdown]
# # Lecture 26: Existence and Uniqueness of Moment Maps
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [26-existence-and-uniqueness-of-moment-maps.ipynb](26-existence-and-uniqueness-of-moment-maps.ipynb)
# - Source span: printed pp. 162-167; physical PDF pp. 176-181
# - Artifact topic: `artifacts/lecture-26`
# - Focus: Uses Lie algebra cohomology to organize obstructions and uniqueness for moment maps.
#
# ## Lecture Sections
#
# - Lie algebras of vector fields
# - Lie algebra cohomology
# - Existence of moment maps
# - Uniqueness of moment maps
#
# ## Computational Concepts
#
# - Lie algebra cocycle
# - Hamiltonian obstruction
# - equivariant moment map
# - constant ambiguity
#
# ## Visual Route
#
# cocycle obstruction ledger
#
# ## Lab Prompt
#
# Compute a small Chevalley-Eilenberg-style coboundary table for an abelian example and check when ambiguity is constant.

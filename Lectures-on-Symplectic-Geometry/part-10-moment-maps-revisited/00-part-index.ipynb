# %% [markdown]
# # Part X: Moment Maps Revisited
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Gauge-theoretic moment maps, existence, uniqueness, and convexity.
#
# ## Lecture 25: Moment Map in Gauge Theory
#
# - Chapter index: [lecture-25-moment-map-in-gauge-theory/00-index.ipynb](lecture-25-moment-map-in-gauge-theory/00-index.ipynb)
# - Canonical notebook: [25-moment-map-in-gauge-theory.ipynb](lecture-25-moment-map-in-gauge-theory/25-moment-map-in-gauge-theory.ipynb)
# - Source span: printed pp. 153-161; physical PDF pp. 167-175
# - Focus: Reinterprets curvature of connections as a moment map for gauge-group action.
# - Primary visual: discrete connection grid and curvature cells
#
# ## Lecture 26: Existence and Uniqueness of Moment Maps
#
# - Chapter index: [lecture-26-existence-and-uniqueness-of-moment-maps/00-index.ipynb](lecture-26-existence-and-uniqueness-of-moment-maps/00-index.ipynb)
# - Canonical notebook: [26-existence-and-uniqueness-of-moment-maps.ipynb](lecture-26-existence-and-uniqueness-of-moment-maps/26-existence-and-uniqueness-of-moment-maps.ipynb)
# - Source span: printed pp. 162-167; physical PDF pp. 176-181
# - Focus: Uses Lie algebra cohomology to organize obstructions and uniqueness for moment maps.
# - Primary visual: cocycle obstruction ledger
#
# ## Lecture 27: Convexity
#
# - Chapter index: [lecture-27-convexity/00-index.ipynb](lecture-27-convexity/00-index.ipynb)
# - Canonical notebook: [27-convexity.ipynb](lecture-27-convexity/27-convexity.ipynb)
# - Source span: printed pp. 168-174; physical PDF pp. 182-188
# - Focus: Presents convexity of moment-map images for torus actions and examples of effective actions.
# - Primary visual: fixed-point images and convex hull

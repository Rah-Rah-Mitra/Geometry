# %% [markdown]
# # Lecture 27: Convexity
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [27-convexity.ipynb](27-convexity.ipynb)
# - Source span: printed pp. 168-174; physical PDF pp. 182-188
# - Artifact topic: `artifacts/lecture-27`
# - Focus: Presents convexity of moment-map images for torus actions and examples of effective actions.
#
# ## Lecture Sections
#
# - Convexity theorem
# - Effective actions
# - Examples
#
# ## Computational Concepts
#
# - Atiyah-Guillemin-Sternberg convexity
# - effective torus action
# - fixed-point image
# - moment polytope
#
# ## Visual Route
#
# fixed-point images and convex hull
#
# ## Lab Prompt
#
# Sample a torus action on CP2 and verify that the moment image lies inside the convex hull of fixed points.

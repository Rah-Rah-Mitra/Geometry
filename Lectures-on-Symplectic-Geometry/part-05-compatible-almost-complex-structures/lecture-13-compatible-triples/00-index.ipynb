# %% [markdown]
# # Lecture 13: Compatible Triples
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [13-compatible-triples.ipynb](13-compatible-triples.ipynb)
# - Source span: printed pp. 72-75; physical PDF pp. 86-89
# - Artifact topic: `artifacts/lecture-13`
# - Focus: Packages symplectic forms, metrics, and complex structures into mutually determining compatible triples.
#
# ## Lecture Sections
#
# - Compatibility
# - Triple of structures
# - First consequences
#
# ## Computational Concepts
#
# - compatible triple
# - Hermitian metric
# - contractible choice
# - orthogonality
#
# ## Visual Route
#
# omega-J-g reconstruction diagram
#
# ## Lab Prompt
#
# Perturb a compatible complex structure and measure whether the induced metric remains symmetric positive.

# %% [markdown]
# # Lecture 14: Dolbeault Theory
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [14-dolbeault-theory.ipynb](14-dolbeault-theory.ipynb)
# - Source span: printed pp. 76-80; physical PDF pp. 90-94
# - Artifact topic: `artifacts/lecture-14`
# - Focus: Introduces type decompositions of forms and the Dolbeault operators for almost complex and complex settings.
#
# ## Lecture Sections
#
# - Splittings
# - Forms of type (l,m)
# - J-holomorphic functions
# - Dolbeault cohomology
#
# ## Computational Concepts
#
# - type decomposition
# - partial and dbar
# - J-holomorphic function
# - Dolbeault cohomology
#
# ## Visual Route
#
# bigraded form lattice with operator arrows
#
# ## Lab Prompt
#
# Use symbolic z and zbar coordinates to check which simple functions are killed by dbar.

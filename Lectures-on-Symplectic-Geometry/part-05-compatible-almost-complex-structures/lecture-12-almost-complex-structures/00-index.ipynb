# %% [markdown]
# # Lecture 12: Almost Complex Structures
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [12-almost-complex-structures.ipynb](12-almost-complex-structures.ipynb)
# - Source span: printed pp. 65-71; physical PDF pp. 79-85
# - Artifact topic: `artifacts/lecture-12`
# - Focus: Compares symplectic, metric, and almost-complex linear structures and the compatibility conditions between them.
#
# ## Lecture Sections
#
# - Three geometries
# - Complex structures on vector spaces
# - Compatible structures
#
# ## Computational Concepts
#
# - almost complex structure
# - J squared equals minus identity
# - compatible metric
# - positive tame form
#
# ## Visual Route
#
# compatibility matrix triangle
#
# ## Lab Prompt
#
# Construct J from the standard symplectic matrix and verify J^2=-I and positive g(u,v)=omega(u,Jv).

# %% [markdown]
# # Part V: Compatible Almost Complex Structures
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Compatible complex structures, triples, and Dolbeault decompositions.
#
# ## Lecture 12: Almost Complex Structures
#
# - Chapter index: [lecture-12-almost-complex-structures/00-index.ipynb](lecture-12-almost-complex-structures/00-index.ipynb)
# - Canonical notebook: [12-almost-complex-structures.ipynb](lecture-12-almost-complex-structures/12-almost-complex-structures.ipynb)
# - Source span: printed pp. 65-71; physical PDF pp. 79-85
# - Focus: Compares symplectic, metric, and almost-complex linear structures and the compatibility conditions between them.
# - Primary visual: compatibility matrix triangle
#
# ## Lecture 13: Compatible Triples
#
# - Chapter index: [lecture-13-compatible-triples/00-index.ipynb](lecture-13-compatible-triples/00-index.ipynb)
# - Canonical notebook: [13-compatible-triples.ipynb](lecture-13-compatible-triples/13-compatible-triples.ipynb)
# - Source span: printed pp. 72-75; physical PDF pp. 86-89
# - Focus: Packages symplectic forms, metrics, and complex structures into mutually determining compatible triples.
# - Primary visual: omega-J-g reconstruction diagram
#
# ## Lecture 14: Dolbeault Theory
#
# - Chapter index: [lecture-14-dolbeault-theory/00-index.ipynb](lecture-14-dolbeault-theory/00-index.ipynb)
# - Canonical notebook: [14-dolbeault-theory.ipynb](lecture-14-dolbeault-theory/14-dolbeault-theory.ipynb)
# - Source span: printed pp. 76-80; physical PDF pp. 90-94
# - Focus: Introduces type decompositions of forms and the Dolbeault operators for almost complex and complex settings.
# - Primary visual: bigraded form lattice with operator arrows

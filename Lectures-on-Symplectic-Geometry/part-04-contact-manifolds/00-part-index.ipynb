# %% [markdown]
# # Part IV: Contact Manifolds
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Contact forms, Reeb fields, and symplectization.
#
# ## Lecture 10: Contact Forms
#
# - Chapter index: [lecture-10-contact-forms/00-index.ipynb](lecture-10-contact-forms/00-index.ipynb)
# - Canonical notebook: [10-contact-forms.ipynb](lecture-10-contact-forms/10-contact-forms.ipynb)
# - Source span: printed pp. 55-60; physical PDF pp. 69-74
# - Focus: Introduces maximally nonintegrable hyperplane fields and first contact examples.
# - Primary visual: contact planes twisting along a curve
#
# ## Lecture 11: Contact Dynamics
#
# - Chapter index: [lecture-11-contact-dynamics/00-index.ipynb](lecture-11-contact-dynamics/00-index.ipynb)
# - Canonical notebook: [11-contact-dynamics.ipynb](lecture-11-contact-dynamics/11-contact-dynamics.ipynb)
# - Source span: printed pp. 61-64; physical PDF pp. 75-78
# - Focus: Studies Reeb fields, symplectization, and the dynamical conjectures that motivate contact geometry.
# - Primary visual: Reeb flow helix and symplectization layer

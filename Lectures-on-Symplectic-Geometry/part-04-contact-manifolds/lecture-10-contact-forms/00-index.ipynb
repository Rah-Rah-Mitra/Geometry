# %% [markdown]
# # Lecture 10: Contact Forms
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [10-contact-forms.ipynb](10-contact-forms.ipynb)
# - Source span: printed pp. 55-60; physical PDF pp. 69-74
# - Artifact topic: `artifacts/lecture-10`
# - Focus: Introduces maximally nonintegrable hyperplane fields and first contact examples.
#
# ## Lecture Sections
#
# - Contact structures
# - Examples
# - First properties
#
# ## Computational Concepts
#
# - contact form
# - contact distribution
# - maximal nonintegrability
# - local normal form
#
# ## Visual Route
#
# contact planes twisting along a curve
#
# ## Lab Prompt
#
# Evaluate alpha wedge d alpha in the standard R3 model and compare it with an integrable plane field.

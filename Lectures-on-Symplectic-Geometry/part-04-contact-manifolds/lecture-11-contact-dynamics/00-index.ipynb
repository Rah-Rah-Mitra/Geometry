# %% [markdown]
# # Lecture 11: Contact Dynamics
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [11-contact-dynamics.ipynb](11-contact-dynamics.ipynb)
# - Source span: printed pp. 61-64; physical PDF pp. 75-78
# - Artifact topic: `artifacts/lecture-11`
# - Focus: Studies Reeb fields, symplectization, and the dynamical conjectures that motivate contact geometry.
#
# ## Lecture Sections
#
# - Reeb vector fields
# - Symplectization
# - Seifert and Weinstein conjectures
#
# ## Computational Concepts
#
# - Reeb vector field
# - symplectization
# - periodic orbit
# - contact energy level
#
# ## Visual Route
#
# Reeb flow helix and symplectization layer
#
# ## Lab Prompt
#
# Compute the Reeb vector field for a standard contact form and plot representative flow lines.

# %% [markdown]
# # Lecture 07: Moser Theorems
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [07-moser-theorems.ipynb](07-moser-theorems.ipynb)
# - Source span: printed pp. 40-43; physical PDF pp. 54-57
# - Artifact topic: `artifacts/lecture-07`
# - Focus: Develops Moser's trick as a controlled deformation of symplectic forms by solving for a vector field.
#
# ## Lecture Sections
#
# - Equivalence of symplectic structures
# - Moser trick
# - Moser local theorem
#
# ## Computational Concepts
#
# - isotopy
# - cohomologous forms
# - Moser vector field
# - volume constraint
#
# ## Visual Route
#
# Moser density interpolation and vector-field arrows
#
# ## Lab Prompt
#
# Interpolate two equal-volume area forms and solve the one-dimensional Moser equation in a toy model.

# %% [markdown]
# # Part III: Local Forms
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Isotopies, Moser's method, Darboux normal form, and Weinstein neighborhoods.
#
# ## Lecture 06: Preparation for the Local Theory
#
# - Chapter index: [lecture-06-preparation-for-the-local-theory/00-index.ipynb](lecture-06-preparation-for-the-local-theory/00-index.ipynb)
# - Canonical notebook: [06-preparation-for-the-local-theory.ipynb](lecture-06-preparation-for-the-local-theory/06-preparation-for-the-local-theory.ipynb)
# - Source span: printed pp. 33-39; physical PDF pp. 47-53
# - Focus: Assembles isotopies, vector fields, tubular neighborhoods, and the homotopy formula needed for Moser arguments.
# - Primary visual: flowbox with normal disk fibers
#
# ## Lecture 07: Moser Theorems
#
# - Chapter index: [lecture-07-moser-theorems/00-index.ipynb](lecture-07-moser-theorems/00-index.ipynb)
# - Canonical notebook: [07-moser-theorems.ipynb](lecture-07-moser-theorems/07-moser-theorems.ipynb)
# - Source span: printed pp. 40-43; physical PDF pp. 54-57
# - Focus: Develops Moser's trick as a controlled deformation of symplectic forms by solving for a vector field.
# - Primary visual: Moser density interpolation and vector-field arrows
#
# ## Lecture 08: Darboux-Moser-Weinstein Theory
#
# - Chapter index: [lecture-08-darboux-moser-weinstein-theory/00-index.ipynb](lecture-08-darboux-moser-weinstein-theory/00-index.ipynb)
# - Canonical notebook: [08-darboux-moser-weinstein-theory.ipynb](lecture-08-darboux-moser-weinstein-theory/08-darboux-moser-weinstein-theory.ipynb)
# - Source span: printed pp. 44-48; physical PDF pp. 58-62
# - Focus: Proves local symplectic normal forms and relates Lagrangian neighborhoods to cotangent models.
# - Primary visual: Darboux deformation ellipses and Lagrangian plane family
#
# ## Lecture 09: Weinstein Tubular Neighborhood Theorem
#
# - Chapter index: [lecture-09-weinstein-tubular-neighborhood-theorem/00-index.ipynb](lecture-09-weinstein-tubular-neighborhood-theorem/00-index.ipynb)
# - Canonical notebook: [09-weinstein-tubular-neighborhood-theorem.ipynb](lecture-09-weinstein-tubular-neighborhood-theorem/09-weinstein-tubular-neighborhood-theorem.ipynb)
# - Source span: printed pp. 49-54; physical PDF pp. 63-68
# - Focus: Applies local models to symplectic tubular neighborhoods, symplectomorphism groups, and fixed points.
# - Primary visual: graph-near-diagonal fixed-point detector

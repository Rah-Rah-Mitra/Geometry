# %% [markdown]
# # Lecture 06: Preparation for the Local Theory
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [06-preparation-for-the-local-theory.ipynb](06-preparation-for-the-local-theory.ipynb)
# - Source span: printed pp. 33-39; physical PDF pp. 47-53
# - Artifact topic: `artifacts/lecture-06`
# - Focus: Assembles isotopies, vector fields, tubular neighborhoods, and the homotopy formula needed for Moser arguments.
#
# ## Lecture Sections
#
# - Isotopies and vector fields
# - Tubular neighborhood theorem
# - Homotopy formula
#
# ## Computational Concepts
#
# - time-dependent vector field
# - tubular neighborhood
# - flow box
# - Cartan homotopy formula
#
# ## Visual Route
#
# flowbox with normal disk fibers
#
# ## Lab Prompt
#
# Numerically compare a finite-flow deformation with the infinitesimal vector field that generates it.

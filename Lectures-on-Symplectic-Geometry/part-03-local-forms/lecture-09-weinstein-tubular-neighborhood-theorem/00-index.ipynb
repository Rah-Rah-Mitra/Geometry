# %% [markdown]
# # Lecture 09: Weinstein Tubular Neighborhood Theorem
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [09-weinstein-tubular-neighborhood-theorem.ipynb](09-weinstein-tubular-neighborhood-theorem.ipynb)
# - Source span: printed pp. 49-54; physical PDF pp. 63-68
# - Artifact topic: `artifacts/lecture-09`
# - Focus: Applies local models to symplectic tubular neighborhoods, symplectomorphism groups, and fixed points.
#
# ## Lecture Sections
#
# - Linear algebra observation
# - Tubular neighborhoods
# - Tangent space to the symplectomorphism group
# - Fixed points of symplectomorphisms
#
# ## Computational Concepts
#
# - symplectic normal bundle
# - graph near diagonal
# - closed one-form tangent model
# - fixed-point intersection
#
# ## Visual Route
#
# graph-near-diagonal fixed-point detector
#
# ## Lab Prompt
#
# Represent a near-identity map by its graph and test when it is Lagrangian in the twisted product.

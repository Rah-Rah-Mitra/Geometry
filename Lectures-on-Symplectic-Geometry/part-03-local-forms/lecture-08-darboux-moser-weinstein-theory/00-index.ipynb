# %% [markdown]
# # Lecture 08: Darboux-Moser-Weinstein Theory
#
# [Back to Part Index](../00-part-index.ipynb) | [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [08-darboux-moser-weinstein-theory.ipynb](08-darboux-moser-weinstein-theory.ipynb)
# - Source span: printed pp. 44-48; physical PDF pp. 58-62
# - Artifact topic: `artifacts/lecture-08`
# - Focus: Proves local symplectic normal forms and relates Lagrangian neighborhoods to cotangent models.
#
# ## Lecture Sections
#
# - Classical Darboux theorem
# - Lagrangian subspaces
# - Weinstein Lagrangian neighborhood theorem
#
# ## Computational Concepts
#
# - Darboux chart
# - Lagrangian subspace
# - cotangent model
# - local normal form
#
# ## Visual Route
#
# Darboux deformation ellipses and Lagrangian plane family
#
# ## Lab Prompt
#
# Track a path of nondegenerate forms and verify that the final chart has the standard matrix.

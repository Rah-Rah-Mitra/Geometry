# %% [markdown]
# # Part I: Qualitative Description of Optimal Transport
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Existence, duality, Wasserstein geometry, displacement interpolation, Monge solvability, and regularity.
#
# ## Chapter 04: Basic properties
#
# - Unit index: [chapter-04-basic-properties/00-index.ipynb](chapter-04-basic-properties/00-index.ipynb)
# - Canonical notebook: [04-basic-properties.ipynb](chapter-04-basic-properties/04-basic-properties.ipynb)
# - Source span: printed pp. 43-50; PDF pp. 65-72
# - Focus: Organize the basic existence theorem around compactness of plans, lower semicontinuity of cost, and tightness.
#
# ## Chapter 05: Cyclical monotonicity and Kantorovich duality
#
# - Unit index: [chapter-05-cyclical-monotonicity-and-kantorovich-duality/00-index.ipynb](chapter-05-cyclical-monotonicity-and-kantorovich-duality/00-index.ipynb)
# - Canonical notebook: [05-cyclical-monotonicity-and-kantorovich-duality.ipynb](chapter-05-cyclical-monotonicity-and-kantorovich-duality/05-cyclical-monotonicity-and-kantorovich-duality.ipynb)
# - Source span: printed pp. 51-92; PDF pp. 73-114
# - Focus: Turn optimality into a finite certificate: no improving cycle and matching dual potentials.
#
# ## Chapter 06: The Wasserstein distances
#
# - Unit index: [chapter-06-the-wasserstein-distances/00-index.ipynb](chapter-06-the-wasserstein-distances/00-index.ipynb)
# - Canonical notebook: [06-the-wasserstein-distances.ipynb](chapter-06-the-wasserstein-distances/06-the-wasserstein-distances.ipynb)
# - Source span: printed pp. 93-112; PDF pp. 115-134
# - Focus: Read Wasserstein distance as a metric on probability measures whose scale depends on both geometry and moments.
#
# ## Chapter 07: Displacement interpolation
#
# - Unit index: [chapter-07-displacement-interpolation/00-index.ipynb](chapter-07-displacement-interpolation/00-index.ipynb)
# - Canonical notebook: [07-displacement-interpolation.ipynb](chapter-07-displacement-interpolation/07-displacement-interpolation.ipynb)
# - Source span: printed pp. 113-162; PDF pp. 135-184
# - Focus: Make geodesics in probability space visible by moving mass along optimal transport rays.
#
# ## Chapter 08: The Monge-Mather shortening principle
#
# - Unit index: [chapter-08-the-monge-mather-shortening-principle/00-index.ipynb](chapter-08-the-monge-mather-shortening-principle/00-index.ipynb)
# - Canonical notebook: [08-the-monge-mather-shortening-principle.ipynb](chapter-08-the-monge-mather-shortening-principle/08-the-monge-mather-shortening-principle.ipynb)
# - Source span: printed pp. 163-204; PDF pp. 185-226
# - Focus: Use shortening as the geometric reason optimal curves do not cross in the wrong way.
#
# ## Chapter 09: Solution of the Monge problem I: Global approach
#
# - Unit index: [chapter-09-solution-of-the-monge-problem-i-global-approach/00-index.ipynb](chapter-09-solution-of-the-monge-problem-i-global-approach/00-index.ipynb)
# - Canonical notebook: [09-solution-of-the-monge-problem-i-global-approach.ipynb](chapter-09-solution-of-the-monge-problem-i-global-approach/09-solution-of-the-monge-problem-i-global-approach.ipynb)
# - Source span: printed pp. 205-214; PDF pp. 227-236
# - Focus: Explain the global strategy for proving that a c-subdifferential is single valued almost everywhere.
#
# ## Chapter 10: Solution of the Monge problem II: Local approach
#
# - Unit index: [chapter-10-solution-of-the-monge-problem-ii-local-approach/00-index.ipynb](chapter-10-solution-of-the-monge-problem-ii-local-approach/00-index.ipynb)
# - Canonical notebook: [10-solution-of-the-monge-problem-ii-local-approach.ipynb](chapter-10-solution-of-the-monge-problem-ii-local-approach/10-solution-of-the-monge-problem-ii-local-approach.ipynb)
# - Source span: printed pp. 215-272; PDF pp. 237-294
# - Focus: Study local hypotheses, especially twist, that let first-order information select a unique transport destination.
#
# ## Chapter 11: The Jacobian equation
#
# - Unit index: [chapter-11-the-jacobian-equation/00-index.ipynb](chapter-11-the-jacobian-equation/00-index.ipynb)
# - Canonical notebook: [11-the-jacobian-equation.ipynb](chapter-11-the-jacobian-equation/11-the-jacobian-equation.ipynb)
# - Source span: printed pp. 273-280; PDF pp. 295-302
# - Focus: Turn mass conservation for a smooth map into a determinant equation that can be checked numerically.
#
# ## Chapter 12: Smoothness
#
# - Unit index: [chapter-12-smoothness/00-index.ipynb](chapter-12-smoothness/00-index.ipynb)
# - Canonical notebook: [12-smoothness.ipynb](chapter-12-smoothness/12-smoothness.ipynb)
# - Source span: printed pp. 281-332; PDF pp. 303-354
# - Focus: Separate existence of a map from smoothness of that map, using cost curvature and singular examples as guides.
#
# ## Chapter 13: Qualitative picture
#
# - Unit index: [chapter-13-qualitative-picture/00-index.ipynb](chapter-13-qualitative-picture/00-index.ipynb)
# - Canonical notebook: [13-qualitative-picture.ipynb](chapter-13-qualitative-picture/13-qualitative-picture.ipynb)
# - Source span: printed pp. 333-352; PDF pp. 355-374
# - Focus: Synthesize Part I into a decision map: which assumptions buy existence, maps, interpolation, and regularity.

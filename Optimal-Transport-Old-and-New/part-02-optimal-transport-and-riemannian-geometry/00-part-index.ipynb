# %% [markdown]
# # Part II: Optimal Transport and Riemannian Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Ricci curvature, Otto calculus, displacement convexity, functional inequalities, and gradient flows.
#
# ## Chapter 14: Ricci curvature
#
# - Unit index: [chapter-14-ricci-curvature/00-index.ipynb](chapter-14-ricci-curvature/00-index.ipynb)
# - Canonical notebook: [14-ricci-curvature.ipynb](chapter-14-ricci-curvature/14-ricci-curvature.ipynb)
# - Source span: printed pp. 357-420; PDF pp. 379-442
# - Focus: Visualize Ricci curvature as averaged geodesic spreading and volume distortion, the curvature signal used later by transport.
#
# ## Chapter 15: Otto calculus
#
# - Unit index: [chapter-15-otto-calculus/00-index.ipynb](chapter-15-otto-calculus/00-index.ipynb)
# - Canonical notebook: [15-otto-calculus.ipynb](chapter-15-otto-calculus/15-otto-calculus.ipynb)
# - Source span: printed pp. 421-434; PDF pp. 443-456
# - Focus: Treat probability densities as a formal Riemannian manifold where tangent vectors are velocity fields.
#
# ## Chapter 16: Displacement convexity I
#
# - Unit index: [chapter-16-displacement-convexity-i/00-index.ipynb](chapter-16-displacement-convexity-i/00-index.ipynb)
# - Canonical notebook: [16-displacement-convexity-i.ipynb](chapter-16-displacement-convexity-i/16-displacement-convexity-i.ipynb)
# - Source span: printed pp. 435-448; PDF pp. 457-470
# - Focus: Study entropy along Wasserstein geodesics as the transport-facing form of lower Ricci curvature.
#
# ## Chapter 17: Displacement convexity II
#
# - Unit index: [chapter-17-displacement-convexity-ii/00-index.ipynb](chapter-17-displacement-convexity-ii/00-index.ipynb)
# - Canonical notebook: [17-displacement-convexity-ii.ipynb](chapter-17-displacement-convexity-ii/17-displacement-convexity-ii.ipynb)
# - Source span: printed pp. 449-492; PDF pp. 471-514
# - Focus: Add dimension-sensitive convexity classes and distortion coefficients to the entropy story.
#
# ## Chapter 18: Volume control
#
# - Unit index: [chapter-18-volume-control/00-index.ipynb](chapter-18-volume-control/00-index.ipynb)
# - Canonical notebook: [18-volume-control.ipynb](chapter-18-volume-control/18-volume-control.ipynb)
# - Source span: printed pp. 493-504; PDF pp. 515-526
# - Focus: Turn curvature information into volume comparison by watching balls and interpolated sets expand.
#
# ## Chapter 19: Density control and local regularity
#
# - Unit index: [chapter-19-density-control-and-local-regularity/00-index.ipynb](chapter-19-density-control-and-local-regularity/00-index.ipynb)
# - Canonical notebook: [19-density-control-and-local-regularity.ipynb](chapter-19-density-control-and-local-regularity/19-density-control-and-local-regularity.ipynb)
# - Source span: printed pp. 505-524; PDF pp. 527-546
# - Focus: Track how upper density bounds propagate along interpolation and why that helps local regularity.
#
# ## Chapter 20: Infinitesimal displacement convexity
#
# - Unit index: [chapter-20-infinitesimal-displacement-convexity/00-index.ipynb](chapter-20-infinitesimal-displacement-convexity/00-index.ipynb)
# - Canonical notebook: [20-infinitesimal-displacement-convexity.ipynb](chapter-20-infinitesimal-displacement-convexity/20-infinitesimal-displacement-convexity.ipynb)
# - Source span: printed pp. 525-544; PDF pp. 547-566
# - Focus: Connect global displacement convexity to infinitesimal second-variation and Gamma2 style checks.
#
# ## Chapter 21: Isoperimetric-type inequalities
#
# - Unit index: [chapter-21-isoperimetric-type-inequalities/00-index.ipynb](chapter-21-isoperimetric-type-inequalities/00-index.ipynb)
# - Canonical notebook: [21-isoperimetric-type-inequalities.ipynb](chapter-21-isoperimetric-type-inequalities/21-isoperimetric-type-inequalities.ipynb)
# - Source span: printed pp. 545-566; PDF pp. 567-588
# - Focus: Use transport and curvature to organize geometric and functional inequalities with boundary-size content.
#
# ## Chapter 22: Concentration inequalities
#
# - Unit index: [chapter-22-concentration-inequalities/00-index.ipynb](chapter-22-concentration-inequalities/00-index.ipynb)
# - Canonical notebook: [22-concentration-inequalities.ipynb](chapter-22-concentration-inequalities/22-concentration-inequalities.ipynb)
# - Source span: printed pp. 567-628; PDF pp. 589-650
# - Focus: Translate transport inequalities into visible tail bounds and concentration profiles.
#
# ## Chapter 23: Gradient flows I
#
# - Unit index: [chapter-23-gradient-flows-i/00-index.ipynb](chapter-23-gradient-flows-i/00-index.ipynb)
# - Canonical notebook: [23-gradient-flows-i.ipynb](chapter-23-gradient-flows-i/23-gradient-flows-i.ipynb)
# - Source span: printed pp. 629-692; PDF pp. 651-714
# - Focus: Build the JKO idea in a finite setting: alternate entropy descent with Wasserstein movement cost.
#
# ## Chapter 24: Gradient flows II: Qualitative properties
#
# - Unit index: [chapter-24-gradient-flows-ii-qualitative-properties/00-index.ipynb](chapter-24-gradient-flows-ii-qualitative-properties/00-index.ipynb)
# - Canonical notebook: [24-gradient-flows-ii-qualitative-properties.ipynb](chapter-24-gradient-flows-ii-qualitative-properties/24-gradient-flows-ii-qualitative-properties.ipynb)
# - Source span: printed pp. 693-718; PDF pp. 715-740
# - Focus: Inspect qualitative properties of metric gradient flows: contraction, comparison, and asymptotic behavior.
#
# ## Chapter 25: Gradient flows III: Functional inequalities
#
# - Unit index: [chapter-25-gradient-flows-iii-functional-inequalities/00-index.ipynb](chapter-25-gradient-flows-iii-functional-inequalities/00-index.ipynb)
# - Canonical notebook: [25-gradient-flows-iii-functional-inequalities.ipynb](chapter-25-gradient-flows-iii-functional-inequalities/25-gradient-flows-iii-functional-inequalities.ipynb)
# - Source span: printed pp. 719-730; PDF pp. 741-752
# - Focus: Read functional inequalities as quantitative decay statements along a gradient flow.

# %% [markdown]
# # Part III: Synthetic Treatment of Ricci Curvature
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Analytic versus synthetic definitions, metric-measure convergence, stability, and weak Ricci bounds.
#
# ## Chapter 26: Analytic and synthetic points of view
#
# - Unit index: [chapter-26-analytic-and-synthetic-points-of-view/00-index.ipynb](chapter-26-analytic-and-synthetic-points-of-view/00-index.ipynb)
# - Canonical notebook: [26-analytic-and-synthetic-points-of-view.ipynb](chapter-26-analytic-and-synthetic-points-of-view/26-analytic-and-synthetic-points-of-view.ipynb)
# - Source span: printed pp. 735-742; PDF pp. 757-764
# - Focus: Contrast analytic tests that are easy to compute with synthetic tests that survive low-regularity limits.
#
# ## Chapter 27: Convergence of metric-measure spaces
#
# - Unit index: [chapter-27-convergence-of-metric-measure-spaces/00-index.ipynb](chapter-27-convergence-of-metric-measure-spaces/00-index.ipynb)
# - Canonical notebook: [27-convergence-of-metric-measure-spaces.ipynb](chapter-27-convergence-of-metric-measure-spaces/27-convergence-of-metric-measure-spaces.ipynb)
# - Source span: printed pp. 743-772; PDF pp. 765-794
# - Focus: Model metric-measure convergence with finite point clouds whose distances and weights approach a limit.
#
# ## Chapter 28: Stability of optimal transport
#
# - Unit index: [chapter-28-stability-of-optimal-transport/00-index.ipynb](chapter-28-stability-of-optimal-transport/00-index.ipynb)
# - Canonical notebook: [28-stability-of-optimal-transport.ipynb](chapter-28-stability-of-optimal-transport/28-stability-of-optimal-transport.ipynb)
# - Source span: printed pp. 773-794; PDF pp. 795-816
# - Focus: Show that transport costs, plans, and interpolations vary continuously under controlled convergence.
#
# ## Chapter 29: Weak Ricci curvature bounds I: Definition and Stability
#
# - Unit index: [chapter-29-weak-ricci-curvature-bounds-i-definition-and-stability/00-index.ipynb](chapter-29-weak-ricci-curvature-bounds-i-definition-and-stability/00-index.ipynb)
# - Canonical notebook: [29-weak-ricci-curvature-bounds-i-definition-and-stability.ipynb](chapter-29-weak-ricci-curvature-bounds-i-definition-and-stability/29-weak-ricci-curvature-bounds-i-definition-and-stability.ipynb)
# - Source span: printed pp. 795-846; PDF pp. 817-868
# - Focus: Present weak Ricci bounds as convexity of entropy-like functionals along Wasserstein geodesics, then test stability.
#
# ## Chapter 30: Weak Ricci curvature bounds II: Geometric and analytic properties
#
# - Unit index: [chapter-30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties/00-index.ipynb](chapter-30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties/00-index.ipynb)
# - Canonical notebook: [30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties.ipynb](chapter-30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties/30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties.ipynb)
# - Source span: printed pp. 847-902; PDF pp. 869-924
# - Focus: Organize consequences of weak Ricci bounds: volume comparison, local-to-global behavior, and analytic inequalities.

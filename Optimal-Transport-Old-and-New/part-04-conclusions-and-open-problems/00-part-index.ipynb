# %% [markdown]
# # Conclusions and Open Problems
#
# [Back to Book Index](../00-book-index.ipynb)
#
# A final research map tying numerical transport, curvature, regularity, and applications together.
#
# ## Conclusions: Conclusions and open problems
#
# - Unit index: [conclusions-and-open-problems/00-index.ipynb](conclusions-and-open-problems/00-index.ipynb)
# - Canonical notebook: [conclusions-and-open-problems.ipynb](conclusions-and-open-problems/conclusions-and-open-problems.ipynb)
# - Source span: printed pp. 903-914; PDF pp. 925-936
# - Focus: Close the course with a research map: numerics, regularity, curvature, dynamics, and applications.

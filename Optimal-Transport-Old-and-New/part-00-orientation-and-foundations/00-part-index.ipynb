# %% [markdown]
# # Orientation and Foundations
#
# [Back to Book Index](../00-book-index.ipynb)
#
# The opening units set up couplings, examples, and the historical move from maps to plans.
#
# ## Introduction: Introduction
#
# - Unit index: [introduction/00-index.ipynb](introduction/00-index.ipynb)
# - Canonical notebook: [introduction.ipynb](introduction/introduction.ipynb)
# - Source span: printed pp. 1-4; PDF pp. 23-26
# - Focus: Build the course map: optimal transport as a bridge between probability, geometry, dynamics, and curvature.
#
# ## Chapter 01: Couplings and changes of variables
#
# - Unit index: [chapter-01-couplings-and-changes-of-variables/00-index.ipynb](chapter-01-couplings-and-changes-of-variables/00-index.ipynb)
# - Canonical notebook: [01-couplings-and-changes-of-variables.ipynb](chapter-01-couplings-and-changes-of-variables/01-couplings-and-changes-of-variables.ipynb)
# - Source span: printed pp. 5-20; PDF pp. 27-42
# - Focus: Make couplings concrete as matrices and maps, then track how mass and Jacobians account for changes of variables.
#
# ## Chapter 02: Three examples of coupling techniques
#
# - Unit index: [chapter-02-three-examples-of-coupling-techniques/00-index.ipynb](chapter-02-three-examples-of-coupling-techniques/00-index.ipynb)
# - Canonical notebook: [02-three-examples-of-coupling-techniques.ipynb](chapter-02-three-examples-of-coupling-techniques/02-three-examples-of-coupling-techniques.ipynb)
# - Source span: printed pp. 21-28; PDF pp. 43-50
# - Focus: Use three small models to see coupling as a proof method: contraction, comparison, and transport-based inequality.
#
# ## Chapter 03: The founding fathers of optimal transport
#
# - Unit index: [chapter-03-the-founding-fathers-of-optimal-transport/00-index.ipynb](chapter-03-the-founding-fathers-of-optimal-transport/00-index.ipynb)
# - Canonical notebook: [03-the-founding-fathers-of-optimal-transport.ipynb](chapter-03-the-founding-fathers-of-optimal-transport/03-the-founding-fathers-of-optimal-transport.ipynb)
# - Source span: printed pp. 29-38; PDF pp. 51-60
# - Focus: Trace the conceptual move from Monge's deterministic map to Kantorovich's relaxed plan and dual variables.

# %% [markdown]
# # Optimal Transport: Old and New
#
# Standalone visualization-first notebook course with original prose, generated diagrams, executable transport examples, and validation checks. The local PDF is used only as a source map.
#
# - [Source map](source-map.md)
# - [Agent instructions](AGENTS.md)
#
# ## Course Map
#
# ## Orientation and Foundations
#
# The opening units set up couplings, examples, and the historical move from maps to plans.
#
# - [Open part index](part-00-orientation-and-foundations/00-part-index.ipynb)
# - [Introduction: Introduction](part-00-orientation-and-foundations/introduction/00-index.ipynb) - [canonical](part-00-orientation-and-foundations/introduction/introduction.ipynb); printed pp. 1-4; PDF pp. 23-26; Build the course map: optimal transport as a bridge between probability, geometry, dynamics, and curvature.
# - [Chapter 01: Couplings and changes of variables](part-00-orientation-and-foundations/chapter-01-couplings-and-changes-of-variables/00-index.ipynb) - [canonical](part-00-orientation-and-foundations/chapter-01-couplings-and-changes-of-variables/01-couplings-and-changes-of-variables.ipynb); printed pp. 5-20; PDF pp. 27-42; Make couplings concrete as matrices and maps, then track how mass and Jacobians account for changes of variables.
# - [Chapter 02: Three examples of coupling techniques](part-00-orientation-and-foundations/chapter-02-three-examples-of-coupling-techniques/00-index.ipynb) - [canonical](part-00-orientation-and-foundations/chapter-02-three-examples-of-coupling-techniques/02-three-examples-of-coupling-techniques.ipynb); printed pp. 21-28; PDF pp. 43-50; Use three small models to see coupling as a proof method: contraction, comparison, and transport-based inequality.
# - [Chapter 03: The founding fathers of optimal transport](part-00-orientation-and-foundations/chapter-03-the-founding-fathers-of-optimal-transport/00-index.ipynb) - [canonical](part-00-orientation-and-foundations/chapter-03-the-founding-fathers-of-optimal-transport/03-the-founding-fathers-of-optimal-transport.ipynb); printed pp. 29-38; PDF pp. 51-60; Trace the conceptual move from Monge's deterministic map to Kantorovich's relaxed plan and dual variables.
#
# ## Part I: Qualitative Description of Optimal Transport
#
# Existence, duality, Wasserstein geometry, displacement interpolation, Monge solvability, and regularity.
#
# - [Open part index](part-01-qualitative-description-of-optimal-transport/00-part-index.ipynb)
# - [Chapter 04: Basic properties](part-01-qualitative-description-of-optimal-transport/chapter-04-basic-properties/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-04-basic-properties/04-basic-properties.ipynb); printed pp. 43-50; PDF pp. 65-72; Organize the basic existence theorem around compactness of plans, lower semicontinuity of cost, and tightness.
# - [Chapter 05: Cyclical monotonicity and Kantorovich duality](part-01-qualitative-description-of-optimal-transport/chapter-05-cyclical-monotonicity-and-kantorovich-duality/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-05-cyclical-monotonicity-and-kantorovich-duality/05-cyclical-monotonicity-and-kantorovich-duality.ipynb); printed pp. 51-92; PDF pp. 73-114; Turn optimality into a finite certificate: no improving cycle and matching dual potentials.
# - [Chapter 06: The Wasserstein distances](part-01-qualitative-description-of-optimal-transport/chapter-06-the-wasserstein-distances/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-06-the-wasserstein-distances/06-the-wasserstein-distances.ipynb); printed pp. 93-112; PDF pp. 115-134; Read Wasserstein distance as a metric on probability measures whose scale depends on both geometry and moments.
# - [Chapter 07: Displacement interpolation](part-01-qualitative-description-of-optimal-transport/chapter-07-displacement-interpolation/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-07-displacement-interpolation/07-displacement-interpolation.ipynb); printed pp. 113-162; PDF pp. 135-184; Make geodesics in probability space visible by moving mass along optimal transport rays.
# - [Chapter 08: The Monge-Mather shortening principle](part-01-qualitative-description-of-optimal-transport/chapter-08-the-monge-mather-shortening-principle/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-08-the-monge-mather-shortening-principle/08-the-monge-mather-shortening-principle.ipynb); printed pp. 163-204; PDF pp. 185-226; Use shortening as the geometric reason optimal curves do not cross in the wrong way.
# - [Chapter 09: Solution of the Monge problem I: Global approach](part-01-qualitative-description-of-optimal-transport/chapter-09-solution-of-the-monge-problem-i-global-approach/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-09-solution-of-the-monge-problem-i-global-approach/09-solution-of-the-monge-problem-i-global-approach.ipynb); printed pp. 205-214; PDF pp. 227-236; Explain the global strategy for proving that a c-subdifferential is single valued almost everywhere.
# - [Chapter 10: Solution of the Monge problem II: Local approach](part-01-qualitative-description-of-optimal-transport/chapter-10-solution-of-the-monge-problem-ii-local-approach/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-10-solution-of-the-monge-problem-ii-local-approach/10-solution-of-the-monge-problem-ii-local-approach.ipynb); printed pp. 215-272; PDF pp. 237-294; Study local hypotheses, especially twist, that let first-order information select a unique transport destination.
# - [Chapter 11: The Jacobian equation](part-01-qualitative-description-of-optimal-transport/chapter-11-the-jacobian-equation/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-11-the-jacobian-equation/11-the-jacobian-equation.ipynb); printed pp. 273-280; PDF pp. 295-302; Turn mass conservation for a smooth map into a determinant equation that can be checked numerically.
# - [Chapter 12: Smoothness](part-01-qualitative-description-of-optimal-transport/chapter-12-smoothness/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-12-smoothness/12-smoothness.ipynb); printed pp. 281-332; PDF pp. 303-354; Separate existence of a map from smoothness of that map, using cost curvature and singular examples as guides.
# - [Chapter 13: Qualitative picture](part-01-qualitative-description-of-optimal-transport/chapter-13-qualitative-picture/00-index.ipynb) - [canonical](part-01-qualitative-description-of-optimal-transport/chapter-13-qualitative-picture/13-qualitative-picture.ipynb); printed pp. 333-352; PDF pp. 355-374; Synthesize Part I into a decision map: which assumptions buy existence, maps, interpolation, and regularity.
#
# ## Part II: Optimal Transport and Riemannian Geometry
#
# Ricci curvature, Otto calculus, displacement convexity, functional inequalities, and gradient flows.
#
# - [Open part index](part-02-optimal-transport-and-riemannian-geometry/00-part-index.ipynb)
# - [Chapter 14: Ricci curvature](part-02-optimal-transport-and-riemannian-geometry/chapter-14-ricci-curvature/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-14-ricci-curvature/14-ricci-curvature.ipynb); printed pp. 357-420; PDF pp. 379-442; Visualize Ricci curvature as averaged geodesic spreading and volume distortion, the curvature signal used later by transport.
# - [Chapter 15: Otto calculus](part-02-optimal-transport-and-riemannian-geometry/chapter-15-otto-calculus/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-15-otto-calculus/15-otto-calculus.ipynb); printed pp. 421-434; PDF pp. 443-456; Treat probability densities as a formal Riemannian manifold where tangent vectors are velocity fields.
# - [Chapter 16: Displacement convexity I](part-02-optimal-transport-and-riemannian-geometry/chapter-16-displacement-convexity-i/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-16-displacement-convexity-i/16-displacement-convexity-i.ipynb); printed pp. 435-448; PDF pp. 457-470; Study entropy along Wasserstein geodesics as the transport-facing form of lower Ricci curvature.
# - [Chapter 17: Displacement convexity II](part-02-optimal-transport-and-riemannian-geometry/chapter-17-displacement-convexity-ii/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-17-displacement-convexity-ii/17-displacement-convexity-ii.ipynb); printed pp. 449-492; PDF pp. 471-514; Add dimension-sensitive convexity classes and distortion coefficients to the entropy story.
# - [Chapter 18: Volume control](part-02-optimal-transport-and-riemannian-geometry/chapter-18-volume-control/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-18-volume-control/18-volume-control.ipynb); printed pp. 493-504; PDF pp. 515-526; Turn curvature information into volume comparison by watching balls and interpolated sets expand.
# - [Chapter 19: Density control and local regularity](part-02-optimal-transport-and-riemannian-geometry/chapter-19-density-control-and-local-regularity/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-19-density-control-and-local-regularity/19-density-control-and-local-regularity.ipynb); printed pp. 505-524; PDF pp. 527-546; Track how upper density bounds propagate along interpolation and why that helps local regularity.
# - [Chapter 20: Infinitesimal displacement convexity](part-02-optimal-transport-and-riemannian-geometry/chapter-20-infinitesimal-displacement-convexity/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-20-infinitesimal-displacement-convexity/20-infinitesimal-displacement-convexity.ipynb); printed pp. 525-544; PDF pp. 547-566; Connect global displacement convexity to infinitesimal second-variation and Gamma2 style checks.
# - [Chapter 21: Isoperimetric-type inequalities](part-02-optimal-transport-and-riemannian-geometry/chapter-21-isoperimetric-type-inequalities/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-21-isoperimetric-type-inequalities/21-isoperimetric-type-inequalities.ipynb); printed pp. 545-566; PDF pp. 567-588; Use transport and curvature to organize geometric and functional inequalities with boundary-size content.
# - [Chapter 22: Concentration inequalities](part-02-optimal-transport-and-riemannian-geometry/chapter-22-concentration-inequalities/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-22-concentration-inequalities/22-concentration-inequalities.ipynb); printed pp. 567-628; PDF pp. 589-650; Translate transport inequalities into visible tail bounds and concentration profiles.
# - [Chapter 23: Gradient flows I](part-02-optimal-transport-and-riemannian-geometry/chapter-23-gradient-flows-i/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-23-gradient-flows-i/23-gradient-flows-i.ipynb); printed pp. 629-692; PDF pp. 651-714; Build the JKO idea in a finite setting: alternate entropy descent with Wasserstein movement cost.
# - [Chapter 24: Gradient flows II: Qualitative properties](part-02-optimal-transport-and-riemannian-geometry/chapter-24-gradient-flows-ii-qualitative-properties/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-24-gradient-flows-ii-qualitative-properties/24-gradient-flows-ii-qualitative-properties.ipynb); printed pp. 693-718; PDF pp. 715-740; Inspect qualitative properties of metric gradient flows: contraction, comparison, and asymptotic behavior.
# - [Chapter 25: Gradient flows III: Functional inequalities](part-02-optimal-transport-and-riemannian-geometry/chapter-25-gradient-flows-iii-functional-inequalities/00-index.ipynb) - [canonical](part-02-optimal-transport-and-riemannian-geometry/chapter-25-gradient-flows-iii-functional-inequalities/25-gradient-flows-iii-functional-inequalities.ipynb); printed pp. 719-730; PDF pp. 741-752; Read functional inequalities as quantitative decay statements along a gradient flow.
#
# ## Part III: Synthetic Treatment of Ricci Curvature
#
# Analytic versus synthetic definitions, metric-measure convergence, stability, and weak Ricci bounds.
#
# - [Open part index](part-03-synthetic-treatment-of-ricci-curvature/00-part-index.ipynb)
# - [Chapter 26: Analytic and synthetic points of view](part-03-synthetic-treatment-of-ricci-curvature/chapter-26-analytic-and-synthetic-points-of-view/00-index.ipynb) - [canonical](part-03-synthetic-treatment-of-ricci-curvature/chapter-26-analytic-and-synthetic-points-of-view/26-analytic-and-synthetic-points-of-view.ipynb); printed pp. 735-742; PDF pp. 757-764; Contrast analytic tests that are easy to compute with synthetic tests that survive low-regularity limits.
# - [Chapter 27: Convergence of metric-measure spaces](part-03-synthetic-treatment-of-ricci-curvature/chapter-27-convergence-of-metric-measure-spaces/00-index.ipynb) - [canonical](part-03-synthetic-treatment-of-ricci-curvature/chapter-27-convergence-of-metric-measure-spaces/27-convergence-of-metric-measure-spaces.ipynb); printed pp. 743-772; PDF pp. 765-794; Model metric-measure convergence with finite point clouds whose distances and weights approach a limit.
# - [Chapter 28: Stability of optimal transport](part-03-synthetic-treatment-of-ricci-curvature/chapter-28-stability-of-optimal-transport/00-index.ipynb) - [canonical](part-03-synthetic-treatment-of-ricci-curvature/chapter-28-stability-of-optimal-transport/28-stability-of-optimal-transport.ipynb); printed pp. 773-794; PDF pp. 795-816; Show that transport costs, plans, and interpolations vary continuously under controlled convergence.
# - [Chapter 29: Weak Ricci curvature bounds I: Definition and Stability](part-03-synthetic-treatment-of-ricci-curvature/chapter-29-weak-ricci-curvature-bounds-i-definition-and-stability/00-index.ipynb) - [canonical](part-03-synthetic-treatment-of-ricci-curvature/chapter-29-weak-ricci-curvature-bounds-i-definition-and-stability/29-weak-ricci-curvature-bounds-i-definition-and-stability.ipynb); printed pp. 795-846; PDF pp. 817-868; Present weak Ricci bounds as convexity of entropy-like functionals along Wasserstein geodesics, then test stability.
# - [Chapter 30: Weak Ricci curvature bounds II: Geometric and analytic properties](part-03-synthetic-treatment-of-ricci-curvature/chapter-30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties/00-index.ipynb) - [canonical](part-03-synthetic-treatment-of-ricci-curvature/chapter-30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties/30-weak-ricci-curvature-bounds-ii-geometric-and-analytic-properties.ipynb); printed pp. 847-902; PDF pp. 869-924; Organize consequences of weak Ricci bounds: volume comparison, local-to-global behavior, and analytic inequalities.
#
# ## Conclusions and Open Problems
#
# A final research map tying numerical transport, curvature, regularity, and applications together.
#
# - [Open part index](part-04-conclusions-and-open-problems/00-part-index.ipynb)
# - [Conclusions: Conclusions and open problems](part-04-conclusions-and-open-problems/conclusions-and-open-problems/00-index.ipynb) - [canonical](part-04-conclusions-and-open-problems/conclusions-and-open-problems/conclusions-and-open-problems.ipynb); printed pp. 903-914; PDF pp. 925-936; Close the course with a research map: numerics, regularity, curvature, dynamics, and applications.

# %%
# geometry-setup:v1
# Machine-managed by scripts/update_notebook_setup.py. Do not edit this cell by hand.

from __future__ import annotations

import json as _geometry_json
import os as _geometry_os
from pathlib import Path as _GeometryPath
import sys as _geometry_sys

GEOMETRY_SETUP = _geometry_json.loads(
    r"""
{
  "colab_url": "https://colab.research.google.com/github/Rah-Rah-Mitra/Geometry/blob/main/Optimal-Transport-Old-and-New/00-book-index.ipynb",
  "course_dir": "Optimal-Transport-Old-and-New",
  "course_title": "Optimal Transport: Old and New",
  "github_url": "https://github.com/Rah-Rah-Mitra/Geometry/blob/main/Optimal-Transport-Old-and-New/00-book-index.ipynb",
  "jupyterlite": false,
  "marker": "geometry-setup:v1",
  "notebook_kind": "book-index",
  "notebook_path": "Optimal-Transport-Old-and-New/00-book-index.ipynb",
  "notebook_title": "Optimal Transport: Old and New",
  "repository": {
    "branch": "main",
    "name": "Geometry",
    "owner": "Rah-Rah-Mitra",
    "source_url": "https://github.com/Rah-Rah-Mitra/Geometry"
  },
  "requirements": "requirements/ml-geometry.txt",
  "runtime_profile": "ml_geometry"
}
"""
)


def _geometry_is_colab():
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def _geometry_is_jupyterlite():
    return _geometry_sys.platform == "emscripten" or "pyodide" in _geometry_sys.modules


def _geometry_add_path(path):
    text = str(path)
    if text not in _geometry_sys.path:
        _geometry_sys.path.insert(0, text)


def _geometry_find_repo_root():
    candidates = []
    env_root = _geometry_os.environ.get("GEOMETRY_REPO_ROOT")
    if env_root:
        candidates.append(_GeometryPath(env_root).expanduser())
    candidates.append(_GeometryPath.cwd())
    for start in candidates:
        start = start.resolve()
        for current in (start, *start.parents):
            if (current / "course-manifest.json").exists() and (
                current / "metadata" / "runtime_profiles.yml"
            ).exists():
                return current
    raise RuntimeError(
        "Could not find the Geometry repository root. Start JupyterLab inside the "
        "Geometry checkout or set GEOMETRY_REPO_ROOT."
    )


def _geometry_run(command):
    import subprocess as _geometry_subprocess

    printable = " ".join(str(part) for part in command)
    print(f"+ {printable}")
    _geometry_subprocess.check_call([str(part) for part in command])


def _geometry_requirement_names(requirements_path, seen=None):
    seen = set() if seen is None else seen
    requirements_path = requirements_path.resolve()
    if requirements_path in seen or not requirements_path.exists():
        return []
    seen.add(requirements_path)
    names = []
    for raw_line in requirements_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.split("#", 1)[0].strip()
        if not line:
            continue
        if line.startswith(("-r ", "--requirement ")):
            _, nested = line.split(maxsplit=1)
            names.extend(_geometry_requirement_names(requirements_path.parent / nested, seen))
            continue
        if line.startswith("-"):
            continue
        name = line
        for separator in ("==", ">=", "<=", "~=", "!=", ">", "<", ";"):
            name = name.split(separator, 1)[0]
        name = name.split("[", 1)[0].strip()
        if name:
            names.append(name)
    return sorted(set(names))


def _geometry_missing_requirements(requirements_path):
    import importlib.metadata as _geometry_metadata

    missing = []
    for name in _geometry_requirement_names(requirements_path):
        try:
            _geometry_metadata.distribution(name)
        except _geometry_metadata.PackageNotFoundError:
            missing.append(name)
    return missing


def _geometry_configured_roots(repo_root):
    course_dir = GEOMETRY_SETUP.get("course_dir")
    course_root = repo_root / course_dir if course_dir else repo_root
    return repo_root, course_root


if _geometry_is_jupyterlite():
    if not GEOMETRY_SETUP["jupyterlite"]:
        raise RuntimeError(
            "This Geometry notebook uses runtime profile "
            f"{GEOMETRY_SETUP['runtime_profile']!r}, which is not enabled for "
            "JupyterLite in course-manifest.json. Open it in Colab or local JupyterLab."
        )
    GEOMETRY_REPO_ROOT = _GeometryPath.cwd()
    GEOMETRY_COURSE_ROOT = (
        GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["course_dir"]
        if GEOMETRY_SETUP.get("course_dir")
        else GEOMETRY_REPO_ROOT
    )
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    if GEOMETRY_COURSE_ROOT.exists():
        _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        "Geometry setup: JupyterLite/Pyodide detected; shell, git, and pip steps "
        "were skipped."
    )
elif _geometry_is_colab():
    repository = GEOMETRY_SETUP["repository"]
    repo_url = repository["source_url"].rstrip("/") + ".git"
    branch = repository["branch"]
    GEOMETRY_REPO_ROOT = _GeometryPath(
        _geometry_os.environ.get("GEOMETRY_REPO_ROOT", "/content/Geometry")
    )
    sparse_paths = ["requirements", "metadata", "scripts", "course-manifest.json", "index.ipynb"]
    if GEOMETRY_SETUP.get("course_dir"):
        sparse_paths.append(GEOMETRY_SETUP["course_dir"])
    if not (GEOMETRY_REPO_ROOT / ".git").exists():
        if GEOMETRY_REPO_ROOT.exists() and any(GEOMETRY_REPO_ROOT.iterdir()):
            raise RuntimeError(
                f"{GEOMETRY_REPO_ROOT} exists but is not a git checkout. "
                "Set GEOMETRY_REPO_ROOT to an empty path or remove the directory."
            )
        _geometry_run(
            [
                "git",
                "clone",
                "--filter=blob:none",
                "--no-checkout",
                "--branch",
                branch,
                repo_url,
                GEOMETRY_REPO_ROOT,
            ]
        )
        _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "init", "--cone"])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "set", *sparse_paths])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "checkout", branch])
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-q", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: Colab ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )
else:
    GEOMETRY_REPO_ROOT = _geometry_find_repo_root()
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    missing = _geometry_missing_requirements(requirements_path)
    skip_install = _geometry_os.environ.get("GEOMETRY_SKIP_INSTALL") == "1"
    if missing and skip_install:
        print(
            "Geometry setup: GEOMETRY_SKIP_INSTALL=1, so missing profile packages "
            f"were not installed: {', '.join(missing)}"
        )
    elif missing:
        print(
            "Geometry setup: installing missing profile packages from "
            f"{requirements_path.relative_to(GEOMETRY_REPO_ROOT)}: {', '.join(missing)}"
        )
        _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: local checkout ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )

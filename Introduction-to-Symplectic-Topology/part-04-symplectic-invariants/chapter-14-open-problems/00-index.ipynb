# %% [markdown]
# # Chapter 14: The chapter lists open questions across structures, symplectomorphisms, Lagrangians, Fano manifolds, Donaldson hypersurfaces, contact geometry, continuous symplectic topology, embeddings, and Euclidean space
#
# - Canonical notebook: `14-open-problems.ipynb`
# - Source span: printed pages 549-573; PDF pages 562-586.
# - Sections: 14.1 Structures, 14.2 Symplectomorphisms, 14.3 Lagrangians and cotangent bundles, 14.4 Fano manifolds, 14.5 Donaldson hypersurfaces, 14.6 Contact geometry, 14.7 Continuous symplectic topology, 14.8 Embeddings, 14.9 Euclidean space.
# - Visual/check: open-problem dependency atlas.
#
# [Open the canonical teaching notebook](14-open-problems.ipynb)

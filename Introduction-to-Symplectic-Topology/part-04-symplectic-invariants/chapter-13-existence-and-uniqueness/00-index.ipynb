# %% [markdown]
# # Chapter 13: The chapter surveys symplectic existence and uniqueness, examples, Taubes-Seiberg-Witten theory, and symplectic four-manifolds
#
# - Canonical notebook: `13-existence-and-uniqueness.ipynb`
# - Source span: printed pages 503-548; PDF pages 516-561.
# - Sections: 13.1 Existence and uniqueness, 13.2 Examples, 13.3 Taubes-Seiberg-Witten theory, 13.4 Symplectic four-manifolds.
# - Visual/check: existence and uniqueness invariant atlas.
#
# [Open the canonical teaching notebook](13-existence-and-uniqueness.ipynb)

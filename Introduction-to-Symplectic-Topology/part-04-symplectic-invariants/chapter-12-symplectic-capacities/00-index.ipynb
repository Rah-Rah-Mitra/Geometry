# %% [markdown]
# # Chapter 12: The chapter treats nonsqueezing, rigidity, Hofer geometry, Hofer-Zehnder capacity, and a variational proof of capacities
#
# - Canonical notebook: `12-symplectic-capacities.ipynb`
# - Source span: printed pages 457-502; PDF pages 470-515.
# - Sections: 12.1 Nonsqueezing and capacities, 12.2 Rigidity, 12.3 Hofer metric, 12.4 Hofer-Zehnder capacity, 12.5 Variational argument.
# - Visual/check: capacity and variational obstruction.
#
# [Open the canonical teaching notebook](12-symplectic-capacities.ipynb)

# %% [markdown]
# # Symplectic Invariants: Part Index
#
# This index collects canonical notebooks for `part-04-symplectic-invariants`.
#
# | Unit | Printed pages | PDF pages | Notebook | Standalone goal |
# | --- | ---: | ---: | --- | --- |
# | Chapter 11 | 417-456 | 430-469 | [11-arnold-conjecture.ipynb](chapter-11-arnold-conjecture/11-arnold-conjecture.ipynb) | Connect Hamiltonian fixed points with Morse/Floer-style lower bounds. |
# | Chapter 12 | 457-502 | 470-515 | [12-symplectic-capacities.ipynb](chapter-12-symplectic-capacities/12-symplectic-capacities.ipynb) | Use capacities as numerical obstructions to symplectic embeddings. |
# | Chapter 13 | 503-548 | 516-561 | [13-existence-and-uniqueness.ipynb](chapter-13-existence-and-uniqueness/13-existence-and-uniqueness.ipynb) | Organize existence and uniqueness questions by the invariants that survive deformation. |
# | Chapter 14 | 549-573 | 562-586 | [14-open-problems.ipynb](chapter-14-open-problems/14-open-problems.ipynb) | Turn open problems into a navigable map of methods, objects, and obstructions. |

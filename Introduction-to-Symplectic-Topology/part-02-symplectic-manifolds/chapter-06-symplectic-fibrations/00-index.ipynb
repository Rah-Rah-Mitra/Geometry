# %% [markdown]
# # Chapter 6: The chapter develops symplectic fibrations, symplectic connections, Hamiltonian holonomy, coupling forms, and Hamiltonian fibrations
#
# - Canonical notebook: `06-symplectic-fibrations.ipynb`
# - Source span: printed pages 252-288; PDF pages 265-301.
# - Sections: 6.1 Symplectic fibrations, 6.2 2-sphere bundles, 6.3 Connections, 6.4 Hamiltonian holonomy and coupling form, 6.5 Hamiltonian fibrations.
# - Visual/check: symplectic fibration holonomy.
#
# [Open the canonical teaching notebook](06-symplectic-fibrations.ipynb)

# %% [markdown]
# # Chapter 5: The chapter studies symplectic group actions, moment maps, quotients, convexity, localization, and links to geometric invariant theory
#
# - Canonical notebook: `05-symplectic-group-actions.ipynb`
# - Source span: printed pages 191-251; PDF pages 204-264.
# - Sections: 5.1 Circle actions, 5.2 Moment maps, 5.3 Examples, 5.4 Symplectic quotients, 5.5 Convexity, 5.6 Localization, 5.7 GIT.
# - Visual/check: moment map and symplectic reduction.
#
# [Open the canonical teaching notebook](05-symplectic-group-actions.ipynb)

# %% [markdown]
# # Chapter 7: The chapter constructs symplectic manifolds through blow-ups, connected sums, telescope constructions, and Donaldson submanifolds
#
# - Canonical notebook: `07-constructing-symplectic-manifolds.ipynb`
# - Source span: printed pages 289-340; PDF pages 302-353.
# - Sections: 7.1 Blowing up and down, 7.2 Connected sums, 7.3 Telescope construction, 7.4 Donaldson submanifolds.
# - Visual/check: symplectic blow-up and construction graph.
#
# [Open the canonical teaching notebook](07-constructing-symplectic-manifolds.ipynb)

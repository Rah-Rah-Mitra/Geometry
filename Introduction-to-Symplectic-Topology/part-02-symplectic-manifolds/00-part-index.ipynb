# %% [markdown]
# # Symplectic Manifolds: Part Index
#
# This index collects canonical notebooks for `part-02-symplectic-manifolds`.
#
# | Unit | Printed pages | PDF pages | Notebook | Standalone goal |
# | --- | ---: | ---: | --- | --- |
# | Chapter 5 | 191-251 | 204-264 | [05-symplectic-group-actions.ipynb](chapter-05-symplectic-group-actions/05-symplectic-group-actions.ipynb) | Make moment maps visible as conserved quantities and convex images of group actions. |
# | Chapter 6 | 252-288 | 265-301 | [06-symplectic-fibrations.ipynb](chapter-06-symplectic-fibrations/06-symplectic-fibrations.ipynb) | See a symplectic fibration as fibers plus a connection whose holonomy remembers Hamiltonian data. |
# | Chapter 7 | 289-340 | 302-353 | [07-constructing-symplectic-manifolds.ipynb](chapter-07-constructing-symplectic-manifolds/07-constructing-symplectic-manifolds.ipynb) | Track how new symplectic manifolds are made by cutting, gluing, and controlled hypersurfaces. |

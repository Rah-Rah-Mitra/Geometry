# %% [markdown]
# # Introduction: The introduction frames symplectic topology as a subject born from mechanics and sharpened by global rigidity, fixed point, and embedding phenomena
#
# - Canonical notebook: `introduction.ipynb`
# - Source span: printed pages 1-8; PDF pages 14-21.
# - Sections: local-to-global transition, Darboux and Moser, Hamiltonian flows, global rigidity questions.
# - Visual/check: global symplectic question map.
#
# [Open the canonical teaching notebook](introduction.ipynb)

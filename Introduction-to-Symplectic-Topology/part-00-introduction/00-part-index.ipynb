# %% [markdown]
# # Orientation: Part Index
#
# This index collects canonical notebooks for `part-00-introduction`.
#
# | Unit | Printed pages | PDF pages | Notebook | Standalone goal |
# | --- | ---: | ---: | --- | --- |
# | Introduction | 1-8 | 14-21 | [introduction.ipynb](introduction/introduction.ipynb) | See why symplectic topology has local normal forms but global invariants. |

# %% [markdown]
# # Chapter 10: The chapter studies the symplectomorphism group, Hamiltonian subgroup, flux homomorphism, Calabi homomorphism, and topology of these groups
#
# - Canonical notebook: `10-group-of-symplectomorphisms.ipynb`
# - Source span: printed pages 385-416; PDF pages 398-429.
# - Sections: 10.1 Basic properties, 10.2 Flux homomorphism, 10.3 Calabi homomorphism, 10.4 Topology of symplectomorphism groups.
# - Visual/check: flux and subgroup structure.
#
# [Open the canonical teaching notebook](10-group-of-symplectomorphisms.ipynb)

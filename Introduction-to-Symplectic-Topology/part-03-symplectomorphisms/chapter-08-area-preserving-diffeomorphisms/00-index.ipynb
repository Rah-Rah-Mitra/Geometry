# %% [markdown]
# # Chapter 8: The chapter treats periodic orbits, the Poincare-Birkhoff theorem, and billiards as concrete two-dimensional symplectic dynamics
#
# - Canonical notebook: `08-area-preserving-diffeomorphisms.ipynb`
# - Source span: printed pages 341-355; PDF pages 354-368.
# - Sections: 8.1 Periodic orbits, 8.2 Poincare-Birkhoff theorem, 8.3 Billiard problem.
# - Visual/check: area-preserving twist map.
#
# [Open the canonical teaching notebook](08-area-preserving-diffeomorphisms.ipynb)

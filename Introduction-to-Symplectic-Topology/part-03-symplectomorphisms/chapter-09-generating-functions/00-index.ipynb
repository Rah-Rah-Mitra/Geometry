# %% [markdown]
# # Chapter 9: The chapter connects generating functions, symplectic action, discrete Hamiltonian mechanics, Hamiltonian symplectomorphisms, and Lagrangian graphs
#
# - Canonical notebook: `09-generating-functions.ipynb`
# - Source span: printed pages 356-384; PDF pages 369-397.
# - Sections: 9.1 Generating functions and symplectic action, 9.2 Discrete Hamiltonian mechanics, 9.3 Hamiltonian symplectomorphisms, 9.4 Lagrangian submanifolds.
# - Visual/check: generating function and discrete action.
#
# [Open the canonical teaching notebook](09-generating-functions.ipynb)

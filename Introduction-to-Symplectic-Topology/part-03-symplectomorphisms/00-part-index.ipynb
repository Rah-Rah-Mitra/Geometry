# %% [markdown]
# # Symplectomorphisms: Part Index
#
# This index collects canonical notebooks for `part-03-symplectomorphisms`.
#
# | Unit | Printed pages | PDF pages | Notebook | Standalone goal |
# | --- | ---: | ---: | --- | --- |
# | Chapter 8 | 341-355 | 354-368 | [08-area-preserving-diffeomorphisms.ipynb](chapter-08-area-preserving-diffeomorphisms/08-area-preserving-diffeomorphisms.ipynb) | Use annulus twist maps as a laboratory for area preservation and forced fixed points. |
# | Chapter 9 | 356-384 | 369-397 | [09-generating-functions.ipynb](chapter-09-generating-functions/09-generating-functions.ipynb) | Read a symplectic map through a scalar generating function and its variational critical points. |
# | Chapter 10 | 385-416 | 398-429 | [10-group-of-symplectomorphisms.ipynb](chapter-10-group-of-symplectomorphisms/10-group-of-symplectomorphisms.ipynb) | Separate symplectic, Hamiltonian, flux, and Calabi information in families of maps. |

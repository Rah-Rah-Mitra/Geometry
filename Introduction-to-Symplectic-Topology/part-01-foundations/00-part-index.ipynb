# %% [markdown]
# # Foundations: Part Index
#
# This index collects canonical notebooks for `part-01-foundations`.
#
# | Unit | Printed pages | PDF pages | Notebook | Standalone goal |
# | --- | ---: | ---: | --- | --- |
# | Chapter 1 | 11-36 | 24-49 | [01-from-classical-to-modern.ipynb](chapter-01-from-classical-to-modern/01-from-classical-to-modern.ipynb) | Derive Hamiltonian motion from action and see the symplectic form preserve phase area. |
# | Chapter 2 | 37-93 | 50-106 | [02-linear-symplectic-geometry.ipynb](chapter-02-linear-symplectic-geometry/02-linear-symplectic-geometry.ipynb) | Recognize the linear algebra that every Darboux chart carries. |
# | Chapter 3 | 94-151 | 107-164 | [03-symplectic-manifolds.ipynb](chapter-03-symplectic-manifolds/03-symplectic-manifolds.ipynb) | Translate the linear form into manifold language and track what Moser and Darboux actually preserve. |
# | Chapter 4 | 152-190 | 165-203 | [04-almost-complex-structures.ipynb](chapter-04-almost-complex-structures/04-almost-complex-structures.ipynb) | Use compatible almost complex structures as a bridge from symplectic forms to complex and holomorphic geometry. |

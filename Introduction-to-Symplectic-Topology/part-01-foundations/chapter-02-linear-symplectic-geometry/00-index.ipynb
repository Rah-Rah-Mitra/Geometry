# %% [markdown]
# # Chapter 2: The chapter builds the standard matrix model, symplectic linear group, Lagrangian planes, compatible complex structures, bundles, and first Chern class
#
# - Canonical notebook: `02-linear-symplectic-geometry.ipynb`
# - Source span: printed pages 37-93; PDF pages 50-106.
# - Sections: 2.1 Symplectic vector spaces, 2.2 The symplectic linear group, 2.3 Lagrangian subspaces, 2.4 Affine nonsqueezing, 2.5 Linear complex structures, 2.6 Bundles, 2.7 First Chern class.
# - Visual/check: linear symplectic form and Lagrangian planes.
#
# [Open the canonical teaching notebook](02-linear-symplectic-geometry.ipynb)

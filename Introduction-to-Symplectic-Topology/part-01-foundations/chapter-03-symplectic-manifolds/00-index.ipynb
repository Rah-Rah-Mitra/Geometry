# %% [markdown]
# # Chapter 3: The chapter defines symplectic manifolds, proves normal-form principles, organizes submanifolds, and introduces contact structures
#
# - Canonical notebook: `03-symplectic-manifolds.ipynb`
# - Source span: printed pages 94-151; PDF pages 107-164.
# - Sections: 3.1 Basic concepts, 3.2 Moser isotopy and Darboux, 3.3 Isotopy extension, 3.4 Submanifolds, 3.5 Contact structures.
# - Visual/check: Moser deformation and contact boundary.
#
# [Open the canonical teaching notebook](03-symplectic-manifolds.ipynb)

# %% [markdown]
# # Chapter 1: The chapter moves from variational mechanics to Hamiltonian vector fields, symplectomorphisms, Poisson brackets, and the first global problems
#
# - Canonical notebook: `01-from-classical-to-modern.ipynb`
# - Source span: printed pages 11-36; PDF pages 24-49.
# - Sections: 1.1 Hamiltonian mechanics, 1.2 The symplectic topology of Euclidean space.
# - Visual/check: Hamiltonian flow on phase space.
#
# [Open the canonical teaching notebook](01-from-classical-to-modern.ipynb)

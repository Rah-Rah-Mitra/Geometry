# %% [markdown]
# # Chapter 4: The chapter explains almost complex structures, integrability, Kahler examples, surfaces, and the first J-holomorphic curve viewpoint
#
# - Canonical notebook: `04-almost-complex-structures.ipynb`
# - Source span: printed pages 152-190; PDF pages 165-203.
# - Sections: 4.1 Almost complex structures, 4.2 Integrability, 4.3 Kahler manifolds, 4.4 Kahler surfaces, 4.5 J-holomorphic curves.
# - Visual/check: compatible J and holomorphic residual.
#
# [Open the canonical teaching notebook](04-almost-complex-structures.ipynb)

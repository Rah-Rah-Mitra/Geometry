# %% [markdown]
# # Introduction to Symplectic Topology
#
# A standalone visualization-first course built from the local McDuff-Salamon PDF. The source is used for structure and topic coverage only; all prose, code, and generated artifacts are original.
#
# ## Course Index
#
# | Unit | Part | Printed pages | PDF pages | Notebook | Visual/check spine |
# | --- | --- | ---: | ---: | --- | --- |
# | Introduction | Orientation | 1-8 | 14-21 | [introduction.ipynb](part-00-introduction/introduction/introduction.ipynb) | global symplectic question map |
# | Chapter 1 | Foundations | 11-36 | 24-49 | [01-from-classical-to-modern.ipynb](part-01-foundations/chapter-01-from-classical-to-modern/01-from-classical-to-modern.ipynb) | Hamiltonian flow on phase space |
# | Chapter 2 | Foundations | 37-93 | 50-106 | [02-linear-symplectic-geometry.ipynb](part-01-foundations/chapter-02-linear-symplectic-geometry/02-linear-symplectic-geometry.ipynb) | linear symplectic form and Lagrangian planes |
# | Chapter 3 | Foundations | 94-151 | 107-164 | [03-symplectic-manifolds.ipynb](part-01-foundations/chapter-03-symplectic-manifolds/03-symplectic-manifolds.ipynb) | Moser deformation and contact boundary |
# | Chapter 4 | Foundations | 152-190 | 165-203 | [04-almost-complex-structures.ipynb](part-01-foundations/chapter-04-almost-complex-structures/04-almost-complex-structures.ipynb) | compatible J and holomorphic residual |
# | Chapter 5 | Symplectic Manifolds | 191-251 | 204-264 | [05-symplectic-group-actions.ipynb](part-02-symplectic-manifolds/chapter-05-symplectic-group-actions/05-symplectic-group-actions.ipynb) | moment map and symplectic reduction |
# | Chapter 6 | Symplectic Manifolds | 252-288 | 265-301 | [06-symplectic-fibrations.ipynb](part-02-symplectic-manifolds/chapter-06-symplectic-fibrations/06-symplectic-fibrations.ipynb) | symplectic fibration holonomy |
# | Chapter 7 | Symplectic Manifolds | 289-340 | 302-353 | [07-constructing-symplectic-manifolds.ipynb](part-02-symplectic-manifolds/chapter-07-constructing-symplectic-manifolds/07-constructing-symplectic-manifolds.ipynb) | symplectic blow-up and construction graph |
# | Chapter 8 | Symplectomorphisms | 341-355 | 354-368 | [08-area-preserving-diffeomorphisms.ipynb](part-03-symplectomorphisms/chapter-08-area-preserving-diffeomorphisms/08-area-preserving-diffeomorphisms.ipynb) | area-preserving twist map |
# | Chapter 9 | Symplectomorphisms | 356-384 | 369-397 | [09-generating-functions.ipynb](part-03-symplectomorphisms/chapter-09-generating-functions/09-generating-functions.ipynb) | generating function and discrete action |
# | Chapter 10 | Symplectomorphisms | 385-416 | 398-429 | [10-group-of-symplectomorphisms.ipynb](part-03-symplectomorphisms/chapter-10-group-of-symplectomorphisms/10-group-of-symplectomorphisms.ipynb) | flux and subgroup structure |
# | Chapter 11 | Symplectic Invariants | 417-456 | 430-469 | [11-arnold-conjecture.ipynb](part-04-symplectic-invariants/chapter-11-arnold-conjecture/11-arnold-conjecture.ipynb) | Arnold fixed-point lower bound |
# | Chapter 12 | Symplectic Invariants | 457-502 | 470-515 | [12-symplectic-capacities.ipynb](part-04-symplectic-invariants/chapter-12-symplectic-capacities/12-symplectic-capacities.ipynb) | capacity and variational obstruction |
# | Chapter 13 | Symplectic Invariants | 503-548 | 516-561 | [13-existence-and-uniqueness.ipynb](part-04-symplectic-invariants/chapter-13-existence-and-uniqueness/13-existence-and-uniqueness.ipynb) | existence and uniqueness invariant atlas |
# | Chapter 14 | Symplectic Invariants | 549-573 | 562-586 | [14-open-problems.ipynb](part-04-symplectic-invariants/chapter-14-open-problems/14-open-problems.ipynb) | open-problem dependency atlas |
# | Appendix A | Appendix A | 574-582 | 587-595 | [appendix-a-smooth-maps.ipynb](appendix-a-smooth-maps/appendix-a-smooth-maps/appendix-a-smooth-maps.ipynb) | smooth extension near corners |
#
# ## Local Course Tools
#
# - `inventory/source-map.md` records page spans and source-use policy.
# - `utils/` contains reusable symplectic computations and artifact helpers.
# - `scripts/` contains inventory, artifact generation, audits, tests, and notebook validation.

# %%
from pathlib import Path
BOOK_ROOT = Path.cwd()
notebooks = [p for p in BOOK_ROOT.rglob('*.ipynb') if 'artifacts' not in p.parts]
artifacts = [p for p in (BOOK_ROOT / 'artifacts').rglob('*') if p.is_file()] if (BOOK_ROOT / 'artifacts').exists() else []
print({'notebook_count': len(notebooks), 'artifact_count': len(artifacts)})

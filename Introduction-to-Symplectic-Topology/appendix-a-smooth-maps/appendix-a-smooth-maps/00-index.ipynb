# %% [markdown]
# # Appendix A: The appendix supplies smooth maps on manifolds with corners, extension lemmas, and a concrete smooth-function construction
#
# - Canonical notebook: `appendix-a-smooth-maps.ipynb`
# - Source span: printed pages 574-582; PDF pages 587-595.
# - Sections: A.1 Smooth functions on manifolds with corners, A.2 Extension, A.3 Smooth-function construction.
# - Visual/check: smooth extension near corners.
#
# [Open the canonical teaching notebook](appendix-a-smooth-maps.ipynb)

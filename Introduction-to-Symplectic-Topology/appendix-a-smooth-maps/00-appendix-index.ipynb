# %% [markdown]
# # Appendix A: Appendix Index
#
# This index collects canonical notebooks for `appendix-a-smooth-maps`.
#
# | Unit | Printed pages | PDF pages | Notebook | Standalone goal |
# | --- | ---: | ---: | --- | --- |
# | Appendix A | 574-582 | 587-595 | [appendix-a-smooth-maps.ipynb](appendix-a-smooth-maps/appendix-a-smooth-maps.ipynb) | Build the smoothing and extension tools that support isotopy and gluing arguments. |

# %% [markdown]
# # Chapter 6: Determinants
#
# - Source span: printed pages 93-108; PDF pages 115-130; sections 6.1-6.5.
# - Focus: Determinantal viewpoint, bracket formulas, Plucker's mu, invariant properties, and Grassmann-Plucker relations.
# - Chapter question: Why do determinants know collinearity, orientation, and projective invariance at the same time?
# - Canonical notebook: [06-determinants.ipynb](06-determinants.ipynb)
#
# ## Visual Spine
#
# - oriented bracket as signed area
# - Plucker mu transformation panel
# - collinearity determinant test
# - Grassmann-Plucker relation check
# - invariant scaling experiment
#
# Back to [book index](../../00-book-index.ipynb).

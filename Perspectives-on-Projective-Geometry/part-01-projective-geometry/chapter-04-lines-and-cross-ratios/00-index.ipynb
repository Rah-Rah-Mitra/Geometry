# %% [markdown]
# # Chapter 4: Lines and Cross-Ratios
#
# - Source span: printed pages 67-78; PDF pages 89-100; sections 4.1-4.4.
# - Focus: Coordinates on a projective line, real projective line charts, cross-ratios, and harmonic quadruples.
# - Chapter question: Which numerical quantity survives when a line is reparametrized projectively?
# - Canonical notebook: [04-lines-and-cross-ratios.ipynb](04-lines-and-cross-ratios.ipynb)
#
# ## Visual Spine
#
# - projective line chart transitions
# - cross-ratio under Mobius maps
# - harmonic point construction
# - infinity crossing on RP1
# - numeric invariance table
#
# Back to [book index](../../00-book-index.ipynb).

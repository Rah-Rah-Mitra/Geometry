# %% [markdown]
# # Chapter 5: Calculating with Points on Lines
#
# - Source span: printed pages 79-92; PDF pages 101-114; sections 5.1-5.7.
# - Focus: Harmonic points, projective scales, reconstructing real numbers, von Staudt constructions, and Pappos arithmetic.
# - Chapter question: How can incidence constructions on a line begin to act like arithmetic?
# - Canonical notebook: [05-calculating-with-points-on-lines.ipynb](05-calculating-with-points-on-lines.ipynb)
#
# ## Visual Spine
#
# - harmonic point as cross-ratio minus one
# - projective scale with three anchors
# - addition and multiplication construction graph
# - field-law dependency diagram
# - Pappos arithmetic check
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Chapter 7: More on Bracket Algebra
#
# - Source span: printed pages 109-126; PDF pages 131-148; sections 7.1-7.5.
# - Focus: Moving between points and determinants, a glimpse of invariant theory, invariant functions, and the bracket algebra.
# - Chapter question: How can algebraic expressions become a language for projective configurations?
# - Canonical notebook: [07-more-on-bracket-algebra.ipynb](07-more-on-bracket-algebra.ipynb)
#
# ## Visual Spine
#
# - points-to-determinants pipeline
# - basis reconstruction diagram
# - invariant monomial weight chart
# - bracket polynomial cancellation graph
# - symbolic sanity checks
#
# Back to [book index](../../00-book-index.ipynb).

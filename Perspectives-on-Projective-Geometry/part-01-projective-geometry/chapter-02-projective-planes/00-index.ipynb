# %% [markdown]
# # Chapter 2: Projective Planes
#
# - Source span: printed pages 35-46; PDF pages 57-68; sections 2.1-2.3.
# - Focus: Perspective drawings, incidence axioms, duality, and the smallest finite projective plane.
# - Chapter question: What changes when points and lines are treated as dual citizens of the same incidence world?
# - Canonical notebook: [02-projective-planes.ipynb](02-projective-planes.ipynb)
#
# ## Visual Spine
#
# - perspective drawing as incidence data
# - projective plane axiom dependency map
# - point-line duality diagram
# - Fano plane incidence table
# - finite-plane sanity checks
#
# Back to [book index](../../00-book-index.ipynb).

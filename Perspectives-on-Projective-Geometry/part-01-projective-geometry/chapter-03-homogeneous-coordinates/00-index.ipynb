# %% [markdown]
# # Chapter 3: Homogeneous Coordinates
#
# - Source span: printed pages 47-66; PDF pages 69-88; sections 3.1-3.7.
# - Focus: RP2 from R3, elements at infinity, joins/meets, duality, transformations, and finite projective planes.
# - Chapter question: How do three coordinates remove the exceptional cases from two-dimensional geometry?
# - Canonical notebook: [03-homogeneous-coordinates.ipynb](03-homogeneous-coordinates.ipynb)
#
# ## Visual Spine
#
# - affine plane embedded in R3
# - points at infinity as limiting rays
# - join and meet via cross product
# - projective transform grid
# - finite-plane coordinate experiment
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Perspectives on Projective Geometry
#
# Standalone visualization-first notebook course. The local PDF is source orientation only.
#
# ## Course Map
#
# - [Chapter 1: Pappos's Theorem](chapter-01-pappos-theorem-nine-proofs-and-three-variations/00-index.ipynb)
#
# ### Part 1: Projective Geometry
#
# [Part index](part-01-projective-geometry/00-part-index.ipynb). Projective planes, homogeneous coordinates, cross-ratios, determinants, and bracket algebra.
#
# - **Chapter 2: Projective Planes** - [index](part-01-projective-geometry/chapter-02-projective-planes/00-index.ipynb); [canonical](part-01-projective-geometry/chapter-02-projective-planes/02-projective-planes.ipynb); sections 2.1-2.3; printed pp. 35-46; PDF pp. 57-68; Perspective drawings, incidence axioms, duality, and the smallest finite projective plane.
# - **Chapter 3: Homogeneous Coordinates** - [index](part-01-projective-geometry/chapter-03-homogeneous-coordinates/00-index.ipynb); [canonical](part-01-projective-geometry/chapter-03-homogeneous-coordinates/03-homogeneous-coordinates.ipynb); sections 3.1-3.7; printed pp. 47-66; PDF pp. 69-88; RP2 from R3, elements at infinity, joins/meets, duality, transformations, and finite projective planes.
# - **Chapter 4: Lines and Cross-Ratios** - [index](part-01-projective-geometry/chapter-04-lines-and-cross-ratios/00-index.ipynb); [canonical](part-01-projective-geometry/chapter-04-lines-and-cross-ratios/04-lines-and-cross-ratios.ipynb); sections 4.1-4.4; printed pp. 67-78; PDF pp. 89-100; Coordinates on a projective line, real projective line charts, cross-ratios, and harmonic quadruples.
# - **Chapter 5: Calculating with Points on Lines** - [index](part-01-projective-geometry/chapter-05-calculating-with-points-on-lines/00-index.ipynb); [canonical](part-01-projective-geometry/chapter-05-calculating-with-points-on-lines/05-calculating-with-points-on-lines.ipynb); sections 5.1-5.7; printed pp. 79-92; PDF pp. 101-114; Harmonic points, projective scales, reconstructing real numbers, von Staudt constructions, and Pappos arithmetic.
# - **Chapter 6: Determinants** - [index](part-01-projective-geometry/chapter-06-determinants/00-index.ipynb); [canonical](part-01-projective-geometry/chapter-06-determinants/06-determinants.ipynb); sections 6.1-6.5; printed pp. 93-108; PDF pp. 115-130; Determinantal viewpoint, bracket formulas, Plucker's mu, invariant properties, and Grassmann-Plucker relations.
# - **Chapter 7: More on Bracket Algebra** - [index](part-01-projective-geometry/chapter-07-more-on-bracket-algebra/00-index.ipynb); [canonical](part-01-projective-geometry/chapter-07-more-on-bracket-algebra/07-more-on-bracket-algebra.ipynb); sections 7.1-7.5; printed pp. 109-126; PDF pp. 131-148; Moving between points and determinants, a glimpse of invariant theory, invariant functions, and the bracket algebra.
#
# ### Part 2: Working and Playing with Geometry
#
# [Part index](part-02-working-and-playing-with-geometry/00-part-index.ipynb). Quadrilateral sets, conics, projective d-space, tensor diagrams, configurations, and theorem proving.
#
# - **Chapter 8: Quadrilateral Sets and Liftings** - [index](part-02-working-and-playing-with-geometry/chapter-08-quadrilateral-sets-and-liftings/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-08-quadrilateral-sets-and-liftings/08-quadrilateral-sets-and-liftings.ipynb); sections 8.1-8.6; printed pp. 129-144; PDF pp. 151-166; Points on a line, quadrilateral sets, symmetry, von Staudt links, slope conditions, and involutions.
# - **Chapter 9: Conics and Their Duals** - [index](part-02-working-and-playing-with-geometry/chapter-09-conics-and-their-duals/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-09-conics-and-their-duals/09-conics-and-their-duals.ipynb); sections 9.1-9.6; printed pp. 145-166; PDF pp. 167-188; Conic equations, polars, tangents, dual quadratic forms, transformations, degenerate conics, and primal-dual pairs.
# - **Chapter 10: Conics and Perspectivity** - [index](part-02-working-and-playing-with-geometry/chapter-10-conics-and-perspectivity/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-10-conics-and-perspectivity/10-conics-and-perspectivity.ipynb); sections 10.1-10.7; printed pp. 167-188; PDF pp. 189-210; Conics through five points, conic cross-ratios, perspective generation, transformations, transfer principles, Pascal and Brianchon.
# - **Chapter 11: Calculating with Conics** - [index](part-02-working-and-playing-with-geometry/chapter-11-calculating-with-conics/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-11-calculating-with-conics/11-calculating-with-conics.ipynb); sections 11.1-11.6; printed pp. 189-208; PDF pp. 211-230; Splitting degenerate conics, branching operations, conic-line intersections, conic-conic intersections, complex numbers, and tangent constraints.
# - **Chapter 12: Projective d-space** - [index](part-02-working-and-playing-with-geometry/chapter-12-projective-d-space/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-12-projective-d-space/12-projective-d-space.ipynb); sections 12.1-12.6; printed pp. 209-226; PDF pp. 231-248; Elements at infinity, homogeneous transformations, points and planes in 3-space, lines in 3-space, and universal join/meet systems.
# - **Chapter 13: Diagram Techniques** - [index](part-02-working-and-playing-with-geometry/chapter-13-diagram-techniques/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-13-diagram-techniques/13-diagram-techniques.ipynb); sections 13.1-13.9; printed pp. 227-246; PDF pp. 249-268; From points, lines, and matrices to tensors, tensor diagrams, transformations, delta tensors, epsilon tensors, and diagrammatic invariants.
# - **Chapter 14: Working with Diagrams** - [index](part-02-working-and-playing-with-geometry/chapter-14-working-with-diagrams/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-14-working-with-diagrams/14-working-with-diagrams.ipynb); sections 14.1-14.8; printed pp. 247-268; PDF pp. 269-290; Trace conditions, Pascal's theorem, closed epsilon cycles, conics, RP3 diagrams, rank-4 epsilon-delta rules, and Plucker coordinates.
# - **Chapter 15: Configurations, Theorems, and Bracket Expressions** - [index](part-02-working-and-playing-with-geometry/chapter-15-configurations-theorems-and-bracket-expressions/00-index.ipynb); [canonical](part-02-working-and-playing-with-geometry/chapter-15-configurations-theorems-and-bracket-expressions/15-configurations-theorems-and-bracket-expressions.ipynb); sections 15.1-15.6; printed pp. 269-294; PDF pp. 291-316; Desargues theorem, binomial proofs, chains and cycles of cross-ratios, Ceva and Menelaus, and glued configurations.
#
# ### Part 3: Measurements
#
# [Part index](part-03-measurements/00-part-index.ipynb). Complex projective line, Euclidean structures, Cayley-Klein geometry, hyperbolic models, and extensions.
#
# - **Chapter 16: Complex Numbers: A Primer** - [index](part-03-measurements/chapter-16-complex-numbers-a-primer/00-index.ipynb); [canonical](part-03-measurements/chapter-16-complex-numbers-a-primer/16-complex-numbers-a-primer.ipynb); sections 16.1-16.5; printed pp. 297-310; PDF pp. 319-332; Historical motivation, the fundamental theorem, geometry of complex numbers, Euler formula, and complex conjugation.
# - **Chapter 17: The Complex Projective Line** - [index](part-03-measurements/chapter-17-the-complex-projective-line/00-index.ipynb); [canonical](part-03-measurements/chapter-17-the-complex-projective-line/17-the-complex-projective-line.ipynb); sections 17.1-17.7; printed pp. 311-328; PDF pp. 333-350; CP1, geometric property tests, projective transformations, inversions, Mobius reflections, Grassmann-Plucker relations, angles, and stereographic projection.
# - **Chapter 18: Euclidean Geometry** - [index](part-03-measurements/chapter-18-euclidean-geometry/00-index.ipynb); [canonical](part-03-measurements/chapter-18-euclidean-geometry/18-euclidean-geometry.ipynb); sections 18.1-18.8; printed pp. 329-348; PDF pp. 351-370; Circular points, cocircularity, robust cross-ratios, Euclidean transformations, theorem translation, angles, Laguerre formula, and distances.
# - **Chapter 19: Euclidean Structures from a Projective Perspective** - [index](part-03-measurements/chapter-19-euclidean-structures-from-a-projective-perspective/00-index.ipynb); [canonical](part-03-measurements/chapter-19-euclidean-structures-from-a-projective-perspective/19-euclidean-structures-from-a-projective-perspective.ipynb); sections 19.1-19.7; printed pp. 349-374; PDF pp. 371-396; Mirror images, angle bisectors, circle centers, conic foci, conic construction from foci, triangle theorems, and hybrid thinking.
# - **Chapter 20: Cayley-Klein Geometries** - [index](part-03-measurements/chapter-20-cayley-klein-geometries/00-index.ipynb); [canonical](part-03-measurements/chapter-20-cayley-klein-geometries/20-cayley-klein-geometries.ipynb); sections 20.1-20.7; printed pp. 375-398; PDF pp. 397-420; I and J revisited, measurements from a conic, nondegenerate and degenerate line measurements, planar Cayley-Klein geometry, and geometry classification.
# - **Chapter 21: Measurements and Transformations** - [index](part-03-measurements/chapter-21-measurements-and-transformations/00-index.ipynb); [canonical](part-03-measurements/chapter-21-measurements-and-transformations/21-measurements-and-transformations.ipynb); sections 21.1-21.6; printed pp. 399-422; PDF pp. 421-444; Measurements versus oriented measurements, transformations, eliminating reference points, comparing measurements, reflections, pole/polar pairs, and rotations.
# - **Chapter 22: Cayley-Klein Geometries at Work** - [index](part-03-measurements/chapter-22-cayley-klein-geometries-at-work/00-index.ipynb); [canonical](part-03-measurements/chapter-22-cayley-klein-geometries-at-work/22-cayley-klein-geometries-at-work.ipynb); sections 22.1-22.5; printed pp. 423-442; PDF pp. 445-464; Orthogonality, constructive versus implicit representations, shared and differing properties, midpoints, angle bisectors, and trigonometry.
# - **Chapter 23: Circles and Cycles** - [index](part-03-measurements/chapter-23-circles-and-cycles/00-index.ipynb); [canonical](part-03-measurements/chapter-23-circles-and-cycles/23-circles-and-cycles.ipynb); sections 23.1-23.5; printed pp. 443-464; PDF pp. 465-486; Circles via distances, relation to the fundamental conic, centers at infinity, organizing principles, and cycles in Galilean geometry.
# - **Chapter 24: Non-Euclidean Geometry: A Historical Interlude** - [index](part-03-measurements/chapter-24-non-euclidean-geometry-a-historical-interlude/00-index.ipynb); [canonical](part-03-measurements/chapter-24-non-euclidean-geometry-a-historical-interlude/24-non-euclidean-geometry-a-historical-interlude.ipynb); sections 24.1-24.6; printed pp. 465-482; PDF pp. 487-504; Inner geometry, Euclid's postulates, Gauss, Bolyai, Lobachevsky, Beltrami, Klein, the Beltrami-Klein model, and Poincare.
# - **Chapter 25: Hyperbolic Geometry** - [index](part-03-measurements/chapter-25-hyperbolic-geometry/00-index.ipynb); [canonical](part-03-measurements/chapter-25-hyperbolic-geometry/25-hyperbolic-geometry.ipynb); sections 25.1-25.6; printed pp. 483-504; PDF pp. 505-526; Hyperbolic staging ground, transformations, angles and boundaries, Poincare disk, CP1 transformations, and distance/angle formulas.
# - **Chapter 26: Selected Topics in Hyperbolic Geometry** - [index](part-03-measurements/chapter-26-selected-topics-in-hyperbolic-geometry/00-index.ipynb); [canonical](part-03-measurements/chapter-26-selected-topics-in-hyperbolic-geometry/26-selected-topics-in-hyperbolic-geometry.ipynb); sections 26.1-26.5; printed pp. 505-524; PDF pp. 527-546; Circles and cycles in the Poincare disk, area and angle defect, Thales and Pythagoras, regular n-gons, and symmetry groups.
# - **Chapter 27: What We Did Not Touch** - [index](part-03-measurements/chapter-27-what-we-did-not-touch/00-index.ipynb); [canonical](part-03-measurements/chapter-27-what-we-did-not-touch/27-what-we-did-not-touch.ipynb); sections 27.1-27.4; printed pp. 525-556; PDF pp. 547-578; Algebraic projective geometry, discrete mathematics, quantum theory, and dynamic projective geometry.
#
# ## Source Notes
#
# Main printed pages map to physical PDF pages by `pdf_page = printed_page + 22`.
# References and the printed index are linked as source orientation, not converted into notebooks.

# %%
# geometry-setup:v1
# Machine-managed by scripts/update_notebook_setup.py. Do not edit this cell by hand.

from __future__ import annotations

import json as _geometry_json
import os as _geometry_os
from pathlib import Path as _GeometryPath
import sys as _geometry_sys

GEOMETRY_SETUP = _geometry_json.loads(
    r"""
{
  "colab_url": "https://colab.research.google.com/github/Rah-Rah-Mitra/Geometry/blob/main/Perspectives-on-Projective-Geometry/00-book-index.ipynb",
  "course_dir": "Perspectives-on-Projective-Geometry",
  "course_title": "Perspectives on Projective Geometry",
  "github_url": "https://github.com/Rah-Rah-Mitra/Geometry/blob/main/Perspectives-on-Projective-Geometry/00-book-index.ipynb",
  "jupyterlite": true,
  "marker": "geometry-setup:v1",
  "notebook_kind": "book-index",
  "notebook_path": "Perspectives-on-Projective-Geometry/00-book-index.ipynb",
  "notebook_title": "Perspectives on Projective Geometry",
  "repository": {
    "branch": "main",
    "name": "Geometry",
    "owner": "Rah-Rah-Mitra",
    "source_url": "https://github.com/Rah-Rah-Mitra/Geometry"
  },
  "requirements": "requirements/classic.txt",
  "runtime_profile": "classic"
}
"""
)


def _geometry_is_colab():
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def _geometry_is_jupyterlite():
    return _geometry_sys.platform == "emscripten" or "pyodide" in _geometry_sys.modules


def _geometry_add_path(path):
    text = str(path)
    if text not in _geometry_sys.path:
        _geometry_sys.path.insert(0, text)


def _geometry_find_repo_root():
    candidates = []
    env_root = _geometry_os.environ.get("GEOMETRY_REPO_ROOT")
    if env_root:
        candidates.append(_GeometryPath(env_root).expanduser())
    candidates.append(_GeometryPath.cwd())
    for start in candidates:
        start = start.resolve()
        for current in (start, *start.parents):
            if (current / "course-manifest.json").exists() and (
                current / "metadata" / "runtime_profiles.yml"
            ).exists():
                return current
    raise RuntimeError(
        "Could not find the Geometry repository root. Start JupyterLab inside the "
        "Geometry checkout or set GEOMETRY_REPO_ROOT."
    )


def _geometry_run(command):
    import subprocess as _geometry_subprocess

    printable = " ".join(str(part) for part in command)
    print(f"+ {printable}")
    _geometry_subprocess.check_call([str(part) for part in command])


def _geometry_requirement_names(requirements_path, seen=None):
    seen = set() if seen is None else seen
    requirements_path = requirements_path.resolve()
    if requirements_path in seen or not requirements_path.exists():
        return []
    seen.add(requirements_path)
    names = []
    for raw_line in requirements_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.split("#", 1)[0].strip()
        if not line:
            continue
        if line.startswith(("-r ", "--requirement ")):
            _, nested = line.split(maxsplit=1)
            names.extend(_geometry_requirement_names(requirements_path.parent / nested, seen))
            continue
        if line.startswith("-"):
            continue
        name = line
        for separator in ("==", ">=", "<=", "~=", "!=", ">", "<", ";"):
            name = name.split(separator, 1)[0]
        name = name.split("[", 1)[0].strip()
        if name:
            names.append(name)
    return sorted(set(names))


def _geometry_missing_requirements(requirements_path):
    import importlib.metadata as _geometry_metadata

    missing = []
    for name in _geometry_requirement_names(requirements_path):
        try:
            _geometry_metadata.distribution(name)
        except _geometry_metadata.PackageNotFoundError:
            missing.append(name)
    return missing


def _geometry_configured_roots(repo_root):
    course_dir = GEOMETRY_SETUP.get("course_dir")
    course_root = repo_root / course_dir if course_dir else repo_root
    return repo_root, course_root


if _geometry_is_jupyterlite():
    if not GEOMETRY_SETUP["jupyterlite"]:
        raise RuntimeError(
            "This Geometry notebook uses runtime profile "
            f"{GEOMETRY_SETUP['runtime_profile']!r}, which is not enabled for "
            "JupyterLite in course-manifest.json. Open it in Colab or local JupyterLab."
        )
    GEOMETRY_REPO_ROOT = _GeometryPath.cwd()
    GEOMETRY_COURSE_ROOT = (
        GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["course_dir"]
        if GEOMETRY_SETUP.get("course_dir")
        else GEOMETRY_REPO_ROOT
    )
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    if GEOMETRY_COURSE_ROOT.exists():
        _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        "Geometry setup: JupyterLite/Pyodide detected; shell, git, and pip steps "
        "were skipped."
    )
elif _geometry_is_colab():
    repository = GEOMETRY_SETUP["repository"]
    repo_url = repository["source_url"].rstrip("/") + ".git"
    branch = repository["branch"]
    GEOMETRY_REPO_ROOT = _GeometryPath(
        _geometry_os.environ.get("GEOMETRY_REPO_ROOT", "/content/Geometry")
    )
    sparse_paths = ["requirements", "metadata", "scripts", "course-manifest.json", "index.ipynb"]
    if GEOMETRY_SETUP.get("course_dir"):
        sparse_paths.append(GEOMETRY_SETUP["course_dir"])
    if not (GEOMETRY_REPO_ROOT / ".git").exists():
        if GEOMETRY_REPO_ROOT.exists() and any(GEOMETRY_REPO_ROOT.iterdir()):
            raise RuntimeError(
                f"{GEOMETRY_REPO_ROOT} exists but is not a git checkout. "
                "Set GEOMETRY_REPO_ROOT to an empty path or remove the directory."
            )
        _geometry_run(
            [
                "git",
                "clone",
                "--filter=blob:none",
                "--no-checkout",
                "--branch",
                branch,
                repo_url,
                GEOMETRY_REPO_ROOT,
            ]
        )
        _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "init", "--cone"])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "set", *sparse_paths])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "checkout", branch])
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-q", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: Colab ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )
else:
    GEOMETRY_REPO_ROOT = _geometry_find_repo_root()
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    missing = _geometry_missing_requirements(requirements_path)
    skip_install = _geometry_os.environ.get("GEOMETRY_SKIP_INSTALL") == "1"
    if missing and skip_install:
        print(
            "Geometry setup: GEOMETRY_SKIP_INSTALL=1, so missing profile packages "
            f"were not installed: {', '.join(missing)}"
        )
    elif missing:
        print(
            "Geometry setup: installing missing profile packages from "
            f"{requirements_path.relative_to(GEOMETRY_REPO_ROOT)}: {', '.join(missing)}"
        )
        _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: local checkout ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )

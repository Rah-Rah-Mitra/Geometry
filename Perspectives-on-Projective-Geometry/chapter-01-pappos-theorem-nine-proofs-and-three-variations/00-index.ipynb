# %% [markdown]
# # Chapter 1: Pappos's Theorem: Nine Proofs and Three Variations
#
# - Source span: printed pages 3-32; PDF pages 25-54; sections 1.1-1.7.
# - Focus: Pappos configurations, projective completion, area and determinant proofs, conic variants, Miquel/cross-ratio lab.
# - Chapter question: How can one incidence theorem reveal projective completion, algebraic proof, and circle geometry at once?
# - Canonical notebook: [01-pappos-theorem-nine-proofs-and-three-variations.ipynb](01-pappos-theorem-nine-proofs-and-three-variations.ipynb)
#
# ## Visual Spine
#
# - Pappos incidence configuration with movable roles
# - parallel limit and line at infinity
# - area-cancellation proof state
# - Miquel and cross-ratio circle lab
# - determinant proof sanity check
#
# Back to [book index](../00-book-index.ipynb).

# %% [markdown]
# # Chapter 13: Diagram Techniques
#
# - Source span: printed pages 227-246; PDF pages 249-268; sections 13.1-13.9.
# - Focus: From points, lines, and matrices to tensors, tensor diagrams, transformations, delta tensors, epsilon tensors, and diagrammatic invariants.
# - Chapter question: How can tensor notation become a manipulable picture of projective algebra?
# - Canonical notebook: [13-diagram-techniques.ipynb](13-diagram-techniques.ipynb)
#
# ## Visual Spine
#
# - matrix-to-tensor diagram legend
# - delta tensor wire identity
# - epsilon tensor orientation node
# - epsilon-delta rewrite move
# - configuration invariant diagram
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Chapter 15: Configurations, Theorems, and Bracket Expressions
#
# - Source span: printed pages 269-294; PDF pages 291-316; sections 15.1-15.6.
# - Focus: Desargues theorem, binomial proofs, chains and cycles of cross-ratios, Ceva and Menelaus, and glued configurations.
# - Chapter question: How do incidence theorems become bracket expressions that can be checked and transformed?
# - Canonical notebook: [15-configurations-theorems-and-bracket-expressions.ipynb](15-configurations-theorems-and-bracket-expressions.ipynb)
#
# ## Visual Spine
#
# - Desargues configuration
# - binomial proof cancellation
# - cross-ratio cycle chain
# - Ceva and Menelaus paired diagram
# - glued configuration dependency graph
#
# Back to [book index](../../00-book-index.ipynb).

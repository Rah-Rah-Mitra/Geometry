# %% [markdown]
# # Chapter 9: Conics and Their Duals
#
# - Source span: printed pages 145-166; PDF pages 167-188; sections 9.1-9.6.
# - Focus: Conic equations, polars, tangents, dual quadratic forms, transformations, degenerate conics, and primal-dual pairs.
# - Chapter question: How does a symmetric matrix turn points, lines, tangents, and duality into one computational system?
# - Canonical notebook: [09-conics-and-their-duals.ipynb](09-conics-and-their-duals.ipynb)
#
# ## Visual Spine
#
# - matrix conic contour
# - polar and tangent construction
# - dual conic envelope
# - projective transform of a conic
# - degenerate conic classification
#
# Back to [book index](../../00-book-index.ipynb).

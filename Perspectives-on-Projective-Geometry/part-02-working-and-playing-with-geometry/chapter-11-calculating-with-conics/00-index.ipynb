# %% [markdown]
# # Chapter 11: Calculating with Conics
#
# - Source span: printed pages 189-208; PDF pages 211-230; sections 11.1-11.6.
# - Focus: Splitting degenerate conics, branching operations, conic-line intersections, conic-conic intersections, complex numbers, and tangent constraints.
# - Chapter question: Where do case distinctions and complex numbers enter when conics become computational objects?
# - Canonical notebook: [11-calculating-with-conics.ipynb](11-calculating-with-conics.ipynb)
#
# ## Visual Spine
#
# - degenerate conic splitting
# - if-operation decision tree
# - line-conic intersection roots
# - two-conic intersection panel
# - complex root interpretation
#
# Back to [book index](../../00-book-index.ipynb).

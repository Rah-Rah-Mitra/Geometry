# %% [markdown]
# # Chapter 14: Working with Diagrams
#
# - Source span: printed pages 247-268; PDF pages 269-290; sections 14.1-14.8.
# - Focus: Trace conditions, Pascal's theorem, closed epsilon cycles, conics, RP3 diagrams, rank-4 epsilon-delta rules, and Plucker coordinates.
# - Chapter question: What proof moves become visible when a formula is treated as a diagram to simplify?
# - Canonical notebook: [14-working-with-diagrams.ipynb](14-working-with-diagrams.ipynb)
#
# ## Visual Spine
#
# - trace condition loop
# - Pascal diagram rewrite
# - closed epsilon cycle
# - rank-four epsilon-delta move
# - tensor versus Plucker comparison
#
# Back to [book index](../../00-book-index.ipynb).

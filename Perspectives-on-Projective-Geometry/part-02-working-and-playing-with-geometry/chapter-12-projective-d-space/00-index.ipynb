# %% [markdown]
# # Chapter 12: Projective d-space
#
# - Source span: printed pages 209-226; PDF pages 231-248; sections 12.1-12.6.
# - Focus: Elements at infinity, homogeneous transformations, points and planes in 3-space, lines in 3-space, and universal join/meet systems.
# - Chapter question: How do joins and meets generalize once the objects are points, planes, and lines in higher dimension?
# - Canonical notebook: [12-projective-d-space.ipynb](12-projective-d-space.ipynb)
#
# ## Visual Spine
#
# - elements at infinity in 3-space
# - point-plane incidence
# - line in RP3 as two-plane data
# - universal join-meet lattice
# - projection sanity check
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Chapter 10: Conics and Perspectivity
#
# - Source span: printed pages 167-188; PDF pages 189-210; sections 10.1-10.7.
# - Focus: Conics through five points, conic cross-ratios, perspective generation, transformations, transfer principles, Pascal and Brianchon.
# - Chapter question: Why does a conic behave like a projective line seen through a moving perspective?
# - Canonical notebook: [10-conics-and-perspectivity.ipynb](10-conics-and-perspectivity.ipynb)
#
# ## Visual Spine
#
# - five-point conic fitting
# - cross-ratio transported along a conic
# - perspective generation sweep
# - Pascal and Brianchon dual diagram
# - Hesse transfer experiment
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Chapter 8: Quadrilateral Sets and Liftings
#
# - Source span: printed pages 129-144; PDF pages 151-166; sections 8.1-8.6.
# - Focus: Points on a line, quadrilateral sets, symmetry, von Staudt links, slope conditions, and involutions.
# - Chapter question: What hidden symmetries appear when four-point line data is lifted into the plane?
# - Canonical notebook: [08-quadrilateral-sets-and-liftings.ipynb](08-quadrilateral-sets-and-liftings.ipynb)
#
# ## Visual Spine
#
# - quadrilateral set on a projective line
# - lifting diagram
# - symmetry orbit panel
# - slope condition experiment
# - involution fixed-pair lab
#
# Back to [book index](../../00-book-index.ipynb).

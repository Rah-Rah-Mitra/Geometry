# %% [markdown]
# # Chapter 17: The Complex Projective Line
#
# - Source span: printed pages 311-328; PDF pages 333-350; sections 17.1-17.7.
# - Focus: CP1, geometric property tests, projective transformations, inversions, Mobius reflections, Grassmann-Plucker relations, angles, and stereographic projection.
# - Chapter question: How does adding the point at infinity turn circles, lines, inversions, and sphere geometry into one picture?
# - Canonical notebook: [17-the-complex-projective-line.ipynb](17-the-complex-projective-line.ipynb)
#
# ## Visual Spine
#
# - CP1 chart with infinity
# - Mobius image of a grid
# - circle inversion and reflection
# - intersection-angle preservation
# - stereographic projection sphere
#
# Back to [book index](../../00-book-index.ipynb).

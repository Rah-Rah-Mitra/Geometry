# %% [markdown]
# # Chapter 18: Euclidean Geometry
#
# - Source span: printed pages 329-348; PDF pages 351-370; sections 18.1-18.8.
# - Focus: Circular points, cocircularity, robust cross-ratios, Euclidean transformations, theorem translation, angles, Laguerre formula, and distances.
# - Chapter question: How do the two circular points let projective geometry recover Euclidean angle and distance?
# - Canonical notebook: [18-euclidean-geometry.ipynb](18-euclidean-geometry.ipynb)
#
# ## Visual Spine
#
# - circular points as conic anchors
# - cocircularity cross-ratio test
# - Euclidean transformation family
# - Laguerre angle formula experiment
# - distance from projective data
#
# Back to [book index](../../00-book-index.ipynb).

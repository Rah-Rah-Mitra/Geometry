# %% [markdown]
# # Chapter 23: Circles and Cycles
#
# - Source span: printed pages 443-464; PDF pages 465-486; sections 23.1-23.5.
# - Focus: Circles via distances, relation to the fundamental conic, centers at infinity, organizing principles, and cycles in Galilean geometry.
# - Chapter question: When distance comes from an absolute conic, what should count as a circle?
# - Canonical notebook: [23-circles-and-cycles.ipynb](23-circles-and-cycles.ipynb)
#
# ## Visual Spine
#
# - distance circle family
# - fundamental conic contact
# - center at infinity limit
# - cycle classification panel
# - Galilean cycle experiment
#
# Back to [book index](../../00-book-index.ipynb).

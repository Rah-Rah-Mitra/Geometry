# %% [markdown]
# # Chapter 19: Euclidean Structures from a Projective Perspective
#
# - Source span: printed pages 349-374; PDF pages 371-396; sections 19.1-19.7.
# - Focus: Mirror images, angle bisectors, circle centers, conic foci, conic construction from foci, triangle theorems, and hybrid thinking.
# - Chapter question: What Euclidean constructions become clearer when the invisible circular points are included?
# - Canonical notebook: [19-euclidean-structures-from-a-projective-perspective.ipynb](19-euclidean-structures-from-a-projective-perspective.ipynb)
#
# ## Visual Spine
#
# - mirror image as projective reflection
# - angle bisector via circular points
# - circle center construction
# - conic foci from complex tangents
# - triangle theorem translation
#
# Back to [book index](../../00-book-index.ipynb).

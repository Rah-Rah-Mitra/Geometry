# %% [markdown]
# # Chapter 20: Cayley-Klein Geometries
#
# - Source span: printed pages 375-398; PDF pages 397-420; sections 20.1-20.7.
# - Focus: I and J revisited, measurements from a conic, nondegenerate and degenerate line measurements, planar Cayley-Klein geometry, and geometry classification.
# - Chapter question: How can one conic decide whether a geometry measures like Euclidean, hyperbolic, elliptic, or degenerate space?
# - Canonical notebook: [20-cayley-klein-geometries.ipynb](20-cayley-klein-geometries.ipynb)
#
# ## Visual Spine
#
# - absolute conic choices
# - cross-ratio line measurement
# - degenerate measurement limit
# - planar Cayley-Klein model
# - geometry census chart
#
# Back to [book index](../../00-book-index.ipynb).

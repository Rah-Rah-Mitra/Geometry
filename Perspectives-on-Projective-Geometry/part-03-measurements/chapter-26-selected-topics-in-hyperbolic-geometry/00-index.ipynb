# %% [markdown]
# # Chapter 26: Selected Topics in Hyperbolic Geometry
#
# - Source span: printed pages 505-524; PDF pages 527-546; sections 26.1-26.5.
# - Focus: Circles and cycles in the Poincare disk, area and angle defect, Thales and Pythagoras, regular n-gons, and symmetry groups.
# - Chapter question: Which Euclidean-looking pictures change their meaning inside the hyperbolic disk?
# - Canonical notebook: [26-selected-topics-in-hyperbolic-geometry.ipynb](26-selected-topics-in-hyperbolic-geometry.ipynb)
#
# ## Visual Spine
#
# - hyperbolic circles, horocycles, and hypercycles
# - area versus angle defect
# - hyperbolic Thales and Pythagoras lab
# - regular polygon construction
# - symmetry group orbit
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Chapter 21: Measurements and Transformations
#
# - Source span: printed pages 399-422; PDF pages 421-444; sections 21.1-21.6.
# - Focus: Measurements versus oriented measurements, transformations, eliminating reference points, comparing measurements, reflections, pole/polar pairs, and rotations.
# - Chapter question: Which transformations preserve a measurement, and how do reflections generate them?
# - Canonical notebook: [21-measurements-and-transformations.ipynb](21-measurements-and-transformations.ipynb)
#
# ## Visual Spine
#
# - oriented measurement comparison
# - absolute-preserving transform
# - reference-point elimination
# - pole-polar reflection
# - two reflections to a rotation
#
# Back to [book index](../../00-book-index.ipynb).

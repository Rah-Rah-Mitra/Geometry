# %% [markdown]
# # Chapter 25: Hyperbolic Geometry
#
# - Source span: printed pages 483-504; PDF pages 505-526; sections 25.1-25.6.
# - Focus: Hyperbolic staging ground, transformations, angles and boundaries, Poincare disk, CP1 transformations, and distance/angle formulas.
# - Chapter question: How do projective and complex tools give two coordinated models of the same hyperbolic plane?
# - Canonical notebook: [25-hyperbolic-geometry.ipynb](25-hyperbolic-geometry.ipynb)
#
# ## Visual Spine
#
# - Klein and Poincare model comparison
# - hyperbolic transformation of boundary points
# - geodesic arcs in the disk
# - angle preservation panel
# - distance cross-ratio heatmap
#
# Back to [book index](../../00-book-index.ipynb).

# %% [markdown]
# # Chapter 27: What We Did Not Touch
#
# - Source span: printed pages 525-556; PDF pages 547-578; sections 27.1-27.4.
# - Focus: Algebraic projective geometry, discrete mathematics, quantum theory, and dynamic projective geometry.
# - Chapter question: Where does projective geometry continue after the main tour ends?
# - Canonical notebook: [27-what-we-did-not-touch.ipynb](27-what-we-did-not-touch.ipynb)
#
# ## Visual Spine
#
# - algebraic geometry branch map
# - discrete projective arrangement
# - quantum-state projective view
# - dynamic geometry branch detour
# - course knowledge graph
#
# Back to [book index](../../00-book-index.ipynb).

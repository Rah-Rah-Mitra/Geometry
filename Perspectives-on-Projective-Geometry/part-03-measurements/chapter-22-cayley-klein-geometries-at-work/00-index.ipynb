# %% [markdown]
# # Chapter 22: Cayley-Klein Geometries at Work
#
# - Source span: printed pages 423-442; PDF pages 445-464; sections 22.1-22.5.
# - Focus: Orthogonality, constructive versus implicit representations, shared and differing properties, midpoints, angle bisectors, and trigonometry.
# - Chapter question: Which familiar constructions survive when the metric is defined by an arbitrary absolute conic?
# - Canonical notebook: [22-cayley-klein-geometries-at-work.ipynb](22-cayley-klein-geometries-at-work.ipynb)
#
# ## Visual Spine
#
# - orthogonality from pole-polar relation
# - constructive versus implicit model
# - midpoint comparison
# - angle bisector families
# - Cayley-Klein trigonometry lab
#
# Back to [book index](../../00-book-index.ipynb).

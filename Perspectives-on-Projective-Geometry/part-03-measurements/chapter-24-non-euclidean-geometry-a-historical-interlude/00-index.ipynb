# %% [markdown]
# # Chapter 24: Non-Euclidean Geometry: A Historical Interlude
#
# - Source span: printed pages 465-482; PDF pages 487-504; sections 24.1-24.6.
# - Focus: Inner geometry, Euclid's postulates, Gauss, Bolyai, Lobachevsky, Beltrami, Klein, the Beltrami-Klein model, and Poincare.
# - Chapter question: How did the search around the parallel postulate become a model-building problem?
# - Canonical notebook: [24-non-euclidean-geometry-a-historical-interlude.ipynb](24-non-euclidean-geometry-a-historical-interlude.ipynb)
#
# ## Visual Spine
#
# - postulate dependency map
# - parallel behavior comparison
# - Beltrami-Klein disk sketch
# - Poincare conformal contrast
# - historical model timeline
#
# Back to [book index](../../00-book-index.ipynb).

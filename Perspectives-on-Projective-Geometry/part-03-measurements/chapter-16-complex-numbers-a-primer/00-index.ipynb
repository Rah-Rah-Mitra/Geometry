# %% [markdown]
# # Chapter 16: Complex Numbers: A Primer
#
# - Source span: printed pages 297-310; PDF pages 319-332; sections 16.1-16.5.
# - Focus: Historical motivation, the fundamental theorem, geometry of complex numbers, Euler formula, and complex conjugation.
# - Chapter question: Why are rotations, roots, and conjugation geometric operations rather than only algebraic syntax?
# - Canonical notebook: [16-complex-numbers-a-primer.ipynb](16-complex-numbers-a-primer.ipynb)
#
# ## Visual Spine
#
# - complex plane as geometry
# - roots as regular polygon
# - Euler rotation sweep
# - conjugation as reflection
# - polynomial root check
#
# Back to [book index](../../00-book-index.ipynb).

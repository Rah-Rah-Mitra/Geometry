# %% [markdown]
# # Chapter 6: Tangent space and nonsingularity, dimension
#
# - Source span: printed pages 101-108; PDF pages 99-106; sections 6.1-6.12 and exercises.
# - Focus: Algebraic tangent spaces, singular loci, dimension, intrinsic tangent definitions, and blowups as local resolution experiments.
# - Canonical notebook: [06-tangent-space-nonsingularity-dimension.ipynb](06-tangent-space-nonsingularity-dimension.ipynb)
# - Artifact root: `../../artifacts/chapter-06` from part folders or `../artifacts/chapter-06` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

# %% [markdown]
# # Chapter 0: Woffle
#
# - Source span: printed pages 11-18; PDF pages 9-16; sections 0.1-0.6 and exercises.
# - Focus: Why polynomial zero sets deserve their own geometry, why functions matter, and how algebra replaces local calculus.
# - Canonical notebook: [00-woffle.ipynb](00-woffle.ipynb)
# - Artifact root: `../../artifacts/chapter-00` from part folders or `../artifacts/chapter-00` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

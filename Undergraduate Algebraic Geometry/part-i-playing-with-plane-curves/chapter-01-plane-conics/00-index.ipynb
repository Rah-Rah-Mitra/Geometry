# %% [markdown]
# # Chapter 1: Plane conics
#
# - Source span: printed pages 19-34; PDF pages 17-32; sections 1.1-1.14 and exercises.
# - Focus: Conics as the first laboratory for projective coordinates, parametrization, intersection counting, and linear systems.
# - Canonical notebook: [01-plane-conics.ipynb](01-plane-conics.ipynb)
# - Artifact root: `../../artifacts/chapter-01` from part folders or `../artifacts/chapter-01` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

# %% [markdown]
# # Part I: Playing with plane curves
#
# Conics and cubics as visual laboratories for projective geometry.
#
# ## Chapters
#
# - Chapter 1: [Plane conics](chapter-01-plane-conics/00-index.ipynb) - Conics as the first laboratory for projective coordinates, parametrization, intersection counting, and linear systems.
# - Chapter 2: [Cubics and the group law](chapter-02-cubics-and-the-group-law/00-index.ipynb) - Singular and smooth cubics, linear systems, the ninth point, chord-tangent addition, and the first appearance of genus.
#
# - Back to [book index](../00-book-index.ipynb)

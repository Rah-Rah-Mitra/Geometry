# %% [markdown]
# # Undergraduate Algebraic Geometry
#
# This is a standalone visualization-first notebook course based on the local PDF only for source orientation. The teaching prose, diagrams, computations, and artifacts are original.
#
# ## Course Map
#
# ### Prologue: Prologue
#
# [Part index](prologue/00-index.ipynb). Motivation and orientation before the main course.
#
# - **Chapter 0: Woffle** - [index](prologue/chapter-00-woffle/00-index.ipynb); [canonical](prologue/chapter-00-woffle/00-woffle.ipynb); printed pp. 11-18; PDF pp. 9-16; Why polynomial zero sets deserve their own geometry, why functions matter, and how algebra replaces local calculus.
#
# ### Part I: Playing with plane curves
#
# [Part index](part-i-playing-with-plane-curves/00-index.ipynb). Conics and cubics as visual laboratories for projective geometry.
#
# - **Chapter 1: Plane conics** - [index](part-i-playing-with-plane-curves/chapter-01-plane-conics/00-index.ipynb); [canonical](part-i-playing-with-plane-curves/chapter-01-plane-conics/01-plane-conics.ipynb); printed pp. 19-34; PDF pp. 17-32; Conics as the first laboratory for projective coordinates, parametrization, intersection counting, and linear systems.
# - **Chapter 2: Cubics and the group law** - [index](part-i-playing-with-plane-curves/chapter-02-cubics-and-the-group-law/00-index.ipynb); [canonical](part-i-playing-with-plane-curves/chapter-02-cubics-and-the-group-law/02-cubics-and-the-group-law.ipynb); printed pp. 35-54; PDF pp. 33-52; Singular and smooth cubics, linear systems, the ninth point, chord-tangent addition, and the first appearance of genus.
#
# ### Part II: The category of affine varieties
#
# [Part index](part-ii-the-category-of-affine-varieties/00-index.ipynb). The algebra-geometry dictionary for affine varieties and their maps.
#
# - **Chapter 3: Affine varieties and the Nullstellensatz** - [index](part-ii-the-category-of-affine-varieties/chapter-03-affine-varieties-and-the-nullstellensatz/00-index.ipynb); [canonical](part-ii-the-category-of-affine-varieties/chapter-03-affine-varieties-and-the-nullstellensatz/03-affine-varieties-and-the-nullstellensatz.ipynb); printed pp. 57-72; PDF pp. 55-70; The affine algebra-geometry dictionary: ideals define loci, loci define radical ideals, and finite generation makes the dictionary computable.
# - **Chapter 4: Functions on varieties** - [index](part-ii-the-category-of-affine-varieties/chapter-04-functions-on-varieties/00-index.ipynb); [canonical](part-ii-the-category-of-affine-varieties/chapter-04-functions-on-varieties/04-functions-on-varieties.ipynb); printed pp. 73-84; PDF pp. 71-82; Coordinate rings, polynomial maps, pullbacks, function fields, rational maps, standard opens, and when maps are actually isomorphisms.
#
# ### Part III: Applications
#
# [Part index](part-iii-applications/00-index.ipynb). Projective geometry, singularities, cubic surfaces, and modern context.
#
# - **Chapter 5: Projective and birational geometry** - [index](part-iii-applications/chapter-05-projective-and-birational-geometry/00-index.ipynb); [canonical](part-iii-applications/chapter-05-projective-and-birational-geometry/05-projective-and-birational-geometry.ipynb); printed pp. 87-100; PDF pp. 85-98; Projective varieties, homogeneous coordinate rings, affine charts, rational maps, birational equivalence, and rational examples.
# - **Chapter 6: Tangent space and nonsingularity, dimension** - [index](part-iii-applications/chapter-06-tangent-space-nonsingularity-dimension/00-index.ipynb); [canonical](part-iii-applications/chapter-06-tangent-space-nonsingularity-dimension/06-tangent-space-nonsingularity-dimension.ipynb); printed pp. 101-108; PDF pp. 99-106; Algebraic tangent spaces, singular loci, dimension, intrinsic tangent definitions, and blowups as local resolution experiments.
# - **Chapter 7: The 27 lines on a cubic surface** - [index](part-iii-applications/chapter-07-the-27-lines-on-a-cubic-surface/00-index.ipynb); [canonical](part-iii-applications/chapter-07-the-27-lines-on-a-cubic-surface/07-the-27-lines-on-a-cubic-surface.ipynb); printed pp. 109-120; PDF pp. 107-118; A classical configuration theorem made visible through lines on a cubic surface, polar forms, rationality, and incidence.
# - **Chapter 8: Final comments** - [index](part-iii-applications/chapter-08-final-comments/00-index.ipynb); [canonical](part-iii-applications/chapter-08-final-comments/08-final-comments.ipynb); printed pp. 121-132; PDF pp. 119-130; A bridge from classical varieties to sheaves, schemes, nilpotents, arithmetic fibers, and the incidence count behind cubic-surface lines.
#
# ## Validation
#
# Run the commands in `AGENTS.md` from the workspace root. Artifacts are generated under `artifacts/` and displayed inline by each canonical notebook.

# %% [markdown]
# # Chapter 3: Affine varieties and the Nullstellensatz
#
# - Source span: printed pages 57-72; PDF pages 55-70; sections 3.1-3.17 and exercises.
# - Focus: The affine algebra-geometry dictionary: ideals define loci, loci define radical ideals, and finite generation makes the dictionary computable.
# - Canonical notebook: [03-affine-varieties-and-the-nullstellensatz.ipynb](03-affine-varieties-and-the-nullstellensatz.ipynb)
# - Artifact root: `../../artifacts/chapter-03` from part folders or `../artifacts/chapter-03` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

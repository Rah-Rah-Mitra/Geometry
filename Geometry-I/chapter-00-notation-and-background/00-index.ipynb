# %% [markdown]
# # Chapter 0: Notation and background
#
# - Source span: printed `1-3`, PDF `13-15`.
# - Artifact topic: `artifacts/chapter-00/`.
# - Canonical notebook: [00-notation-and-background.ipynb](00-notation-and-background.ipynb).
#
# ## Standalone Focus
#
# Sets the vocabulary for sets, algebra, metric spaces, topology, hyperbolic trigonometry, and measure.
#
# ## Concept Map
#
# - set and map notation
# - algebraic structures and linear maps
# - metric balls and distances between sets
# - compactness and topology conventions
# - Lebesgue measure and integration as later tools
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

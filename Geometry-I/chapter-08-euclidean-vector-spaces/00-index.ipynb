# %% [markdown]
# # Chapter 8: Euclidean vector spaces
#
# - Source span: printed `151-199`, PDF `163-211`.
# - Artifact topic: `artifacts/chapter-08/`.
# - Canonical notebook: [08-euclidean-vector-spaces.ipynb](08-euclidean-vector-spaces.ipynb).
#
# ## Standalone Focus
#
# Develops Euclidean vector spaces, orthogonal groups, angles, similarities, quaternions, and conical volume forms.
#
# ## Concept Map
#
# - inner products and orthogonal groups
# - two-dimensional rotations and angles
# - oriented angles and similarities
# - quaternions and orthogonal groups
# - isotropic cones and conical volume forms
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

# %% [markdown]
# # Chapter 9: Euclidean affine spaces
#
# - Source span: printed `200-278`, PDF `212-290`.
# - Artifact topic: `artifacts/chapter-09/`.
# - Canonical notebook: [09-euclidean-affine-spaces.ipynb](09-euclidean-affine-spaces.ipynb).
#
# ## Standalone Focus
#
# Studies rigid motions, plane isometries, similarities, distances, curves, Hausdorff metric, measure, and Steiner symmetrization.
#
# ## Concept Map
#
# - isometries and rigid motions
# - plane isometry structure and generators
# - polygonal billiards
# - distances between sets and points
# - Hausdorff metric, canonical measure, and Steiner symmetrization
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

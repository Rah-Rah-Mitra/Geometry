# %% [markdown]
# # Chapter 5: Affine-projective relationship: applications
#
# - Source span: printed `111-121`, PDF `123-133`.
# - Artifact topic: `artifacts/chapter-05/`.
# - Canonical notebook: [05-affine-projective-relationship-applications.ipynb](05-affine-projective-relationship-applications.ipynb).
#
# ## Standalone Focus
#
# Relates affine space to projective completion, points at infinity, parallelism, and maps that send objects to infinity.
#
# ## Concept Map
#
# - projective completion of an affine space
# - points and hyperplanes at infinity
# - parallelism as incidence at infinity
# - affine and projective subspace relationships
# - applications of sending objects to infinity
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

# %% [markdown]
# # Chapter 3: Barycenters; the universal space
#
# - Source span: printed `67-84`, PDF `79-96`.
# - Artifact topic: `artifacts/chapter-03/`.
# - Canonical notebook: [03-barycenters-the-universal-space.ipynb](03-barycenters-the-universal-space.ipynb).
#
# ## Standalone Focus
#
# Explains affine combination through barycenters, universal affine space, morphisms, and polynomial functions on affine space.
#
# ## Concept Map
#
# - universal space generated by points
# - morphisms and affine universality
# - polynomials on an affine space
# - barycenters and barycentric coordinates
# - relationship with affine maps and subspaces
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

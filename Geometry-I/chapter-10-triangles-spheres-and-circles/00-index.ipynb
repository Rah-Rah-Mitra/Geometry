# %% [markdown]
# # Chapter 10: Triangles, spheres and circles
#
# - Source span: printed `279-330`, PDF `291-342`.
# - Artifact topic: `artifacts/chapter-10/`.
# - Canonical notebook: [10-triangles-spheres-and-circles.ipynb](10-triangles-spheres-and-circles.ipynb).
#
# ## Standalone Focus
#
# Connects triangle geometry, spherical geometry, inversion, circles, circle pencils, tetrahedra, and parataxis.
#
# ## Concept Map
#
# - triangle notation and classical results
# - inequalities and minimum principles
# - polygons and tetrahedra
# - spherical geometry and inversion
# - circle pencils and parataxis
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

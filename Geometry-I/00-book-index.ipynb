# %% [markdown]
# # Geometry I - Standalone Visualization-First Notebook Course
#
# This course is an original executable notebook edition of Marcel Berger's *Geometry I*. The source PDF remains local and is used only for chapter orientation. The notebooks teach with fresh prose, equations, code, generated diagrams, computational checks, and artifacts.
#
# PDF source: `Geometry-I.pdf`. Arabic printed pages follow `pdf_page = printed_page + 12 for Arabic printed body pages`.
#
# ## Course Units
#
# - [Introduction: Introduction](front-matter/introduction/00-index.ipynb) - printed xi-xiii, PDF 10-12.
# - [Chapter 0: Notation and background](chapter-00-notation-and-background/00-index.ipynb) - printed 1-3, PDF 13-15.
# - [Chapter 1: Group actions: examples and applications](chapter-01-group-actions-examples-and-applications/00-index.ipynb) - printed 4-31, PDF 16-43.
# - [Chapter 2: Affine spaces](chapter-02-affine-spaces/00-index.ipynb) - printed 32-66, PDF 44-78.
# - [Chapter 3: Barycenters; the universal space](chapter-03-barycenters-the-universal-space/00-index.ipynb) - printed 67-84, PDF 79-96.
# - [Chapter 4: Projective spaces](chapter-04-projective-spaces/00-index.ipynb) - printed 85-110, PDF 97-122.
# - [Chapter 5: Affine-projective relationship: applications](chapter-05-affine-projective-relationship-applications/00-index.ipynb) - printed 111-121, PDF 123-133.
# - [Chapter 6: Projective lines, cross-ratios, homographies](chapter-06-projective-lines-cross-ratios-homographies/00-index.ipynb) - printed 122-141, PDF 134-153.
# - [Chapter 7: Complexifications](chapter-07-complexifications/00-index.ipynb) - printed 142-150, PDF 154-162.
# - [Chapter 8: Euclidean vector spaces](chapter-08-euclidean-vector-spaces/00-index.ipynb) - printed 151-199, PDF 163-211.
# - [Chapter 9: Euclidean affine spaces](chapter-09-euclidean-affine-spaces/00-index.ipynb) - printed 200-278, PDF 212-290.
# - [Chapter 10: Triangles, spheres and circles](chapter-10-triangles-spheres-and-circles/00-index.ipynb) - printed 279-330, PDF 291-342.
# - [Chapter 11: Convex sets](chapter-11-convex-sets/00-index.ipynb) - printed 331-384, PDF 343-396.
#
# ## Back Matter
#
# - Bibliography: printed 385-400, PDF 397-412.
# - Index of notations: printed 401-404, PDF 413-416.
# - Index: printed 405-427, PDF 417-439.
# - Acknowledgements: printed unprinted, PDF 440.
#
# ## Course Contract
#
# The notebooks stand alone from the PDF and avoid copied prose, long exercise text, screenshots, page crops, and textbook figures. Artifacts are generated under `artifacts/` and are displayed inline by the canonical notebooks.

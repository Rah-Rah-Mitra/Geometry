# %% [markdown]
# # Chapter 1: Group actions: examples and applications
#
# - Source span: printed `4-31`, PDF `16-43`.
# - Artifact topic: `artifacts/chapter-01/`.
# - Canonical notebook: [01-group-actions-examples-and-applications.ipynb](01-group-actions-examples-and-applications.ipynb).
#
# ## Standalone Focus
#
# Uses group actions to organize orbits, stabilizers, tilings, crystallographic groups, and symmetric solids.
#
# ## Concept Map
#
# - actions, faithful actions, and transitivity
# - orbits, stabilizers, and class formulas
# - tilings and crystallographic groups
# - sphere tilings and regular polyhedra
# - symmetry as a computational partition of examples
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

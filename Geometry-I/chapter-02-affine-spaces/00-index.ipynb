# %% [markdown]
# # Chapter 2: Affine spaces
#
# - Source span: printed `32-66`, PDF `44-78`.
# - Artifact topic: `artifacts/chapter-02/`.
# - Canonical notebook: [02-affine-spaces.ipynb](02-affine-spaces.ipynb).
#
# ## Standalone Focus
#
# Builds affine geometry from points, translations, frames, affine maps, subspaces, and classical incidence theorems.
#
# ## Concept Map
#
# - affine points versus free vectors
# - affine frames and coordinates
# - affine morphisms and subspaces
# - Thales, Pappus, and Desargues as incidence tests
# - finite-dimensional real affine spaces
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

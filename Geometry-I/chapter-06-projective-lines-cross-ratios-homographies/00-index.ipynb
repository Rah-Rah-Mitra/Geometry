# %% [markdown]
# # Chapter 6: Projective lines, cross-ratios, homographies
#
# - Source span: printed `122-141`, PDF `134-153`.
# - Artifact topic: `artifacts/chapter-06/`.
# - Canonical notebook: [06-projective-lines-cross-ratios-homographies.ipynb](06-projective-lines-cross-ratios-homographies.ipynb).
#
# ## Standalone Focus
#
# Treats the projective line as the laboratory for cross-ratio, permutations, harmonic division, duality, homographies, and involutions.
#
# ## Concept Map
#
# - definition and computation of cross-ratios
# - permutation action on a cross-ratio
# - harmonic division
# - duality and applications
# - homographies and involutions of a projective line
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

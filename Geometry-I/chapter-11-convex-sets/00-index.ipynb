# %% [markdown]
# # Chapter 11: Convex sets
#
# - Source span: printed `331-384`, PDF `343-396`.
# - Artifact topic: `artifacts/chapter-11/`.
# - Canonical notebook: [11-convex-sets.ipynb](11-convex-sets.ipynb).
#
# ## Standalone Focus
#
# Develops convexity through examples, dimension, topology, separation, supporting hyperplanes, Helly's theorem, and convex functions.
#
# ## Concept Map
#
# - convex set examples and dimension
# - topology of convex sets
# - separation theorems and supporting hyperplanes
# - frontier and Helly theorem applications
# - convex functions and epigraphs
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

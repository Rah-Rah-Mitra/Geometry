# %% [markdown]
# # Chapter 4: Projective spaces
#
# - Source span: printed `85-110`, PDF `97-122`.
# - Artifact topic: `artifacts/chapter-04/`.
# - Canonical notebook: [04-projective-spaces.ipynb](04-projective-spaces.ipynb).
#
# ## Standalone Focus
#
# Introduces projective spaces through charts, topology, bases, morphisms, subspaces, perspective, and aerial photography.
#
# ## Concept Map
#
# - projective points as lines through the origin
# - charts and projective topology
# - projective bases and morphisms
# - subspaces and incidence
# - perspective geometry and camera-like maps
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

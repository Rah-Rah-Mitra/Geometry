# %% [markdown]
# # Chapter 7: Complexifications
#
# - Source span: printed `142-150`, PDF `154-162`.
# - Artifact topic: `artifacts/chapter-07/`.
# - Canonical notebook: [07-complexifications.ipynb](07-complexifications.ipynb).
#
# ## Standalone Focus
#
# Shows how real vector, affine, and projective objects acquire complex companions while preserving functorial structure.
#
# ## Concept Map
#
# - complexification of a real vector space
# - functoriality and complexified morphisms
# - complexification of polynomials
# - subspaces and complexifications
# - affine and projective complexification
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

# %% [markdown]
# # Introduction: Introduction
#
# - Source span: printed `xi-xiii`, PDF `10-12`.
# - Artifact topic: `artifacts/introduction/`.
# - Canonical notebook: [introduction.ipynb](introduction.ipynb).
#
# ## Standalone Focus
#
# Frames geometry as a visual discipline that uses figures, examples, and applications to make abstract structure tangible.
#
# ## Concept Map
#
# - visual reasoning as a working method
# - figures as test benches for definitions
# - examples before abstraction
# - applications as evidence that elementary geometry remains alive
#
# ## Notebook Expectations
#
# The canonical notebook gives original exposition, visual storyboards, generated figures, an applied lab, sanity checks, and takeaways. The PDF is not needed while reading the notebook.

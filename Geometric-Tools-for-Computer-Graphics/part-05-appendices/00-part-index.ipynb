# %% [markdown]
# # Part V: Appendices
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Numerical methods, trigonometric tools, and a formula atlas for common geometric primitives.
#
# ## Appendix A: Numerical Methods
#
# - Chapter index: [appendix-a-numerical-methods/00-index.ipynb](appendix-a-numerical-methods/00-index.ipynb)
# - Canonical notebook: [appendix-a-numerical-methods.ipynb](appendix-a-numerical-methods/appendix-a-numerical-methods.ipynb)
# - Source span: printed pp. 827-922; PDF pp. 874-969
# - Focus: Linear solvers, polynomial systems, decompositions, rotations, root finding, minimization, least-squares fitting, subdivision, and calculus tools.
#
# ## Appendix B: Trigonometry
#
# - Chapter index: [appendix-b-trigonometry/00-index.ipynb](appendix-b-trigonometry/00-index.ipynb)
# - Canonical notebook: [appendix-b-trigonometry.ipynb](appendix-b-trigonometry/appendix-b-trigonometry.ipynb)
# - Source span: printed pp. 923-948; PDF pp. 970-995
# - Focus: Angles, trigonometric functions, identities, laws, inverse branches, derivatives, integrals, and conversion examples.
#
# ## Appendix C: Basic Formulas for Geometric Primitives
#
# - Chapter index: [appendix-c-basic-formulas-for-geometric-primitives/00-index.ipynb](appendix-c-basic-formulas-for-geometric-primitives/00-index.ipynb)
# - Canonical notebook: [appendix-c-basic-formulas-for-geometric-primitives.ipynb](appendix-c-basic-formulas-for-geometric-primitives/appendix-c-basic-formulas-for-geometric-primitives.ipynb)
# - Source span: printed pp. 949-959; PDF pp. 996-1006
# - Focus: Formula atlas for triangles, quadrilaterals, circles, polyhedra, cylinders, cones, spheres, and torus primitives.

# %% [markdown]
# # Part IV: Computational Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# BSP trees, containment, Boolean operations, convex hulls, Delaunay triangulation, partitioning, bounds, area, and volume.
#
# ## Chapter 13: Computational Geometry Topics
#
# - Chapter index: [chapter-13-computational-geometry-topics/00-index.ipynb](chapter-13-computational-geometry-topics/00-index.ipynb)
# - Canonical notebook: [13-computational-geometry-topics.ipynb](chapter-13-computational-geometry-topics/13-computational-geometry-topics.ipynb)
# - Source span: printed pp. 673-826; PDF pp. 720-873
# - Focus: BSP trees, point containment, Boolean operations, convex hulls, Delaunay triangulation, polygon partitioning, minimum bounds, area, and volume.

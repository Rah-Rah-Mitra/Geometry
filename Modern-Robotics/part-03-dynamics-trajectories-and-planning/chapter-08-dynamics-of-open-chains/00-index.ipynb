# %% [markdown]
# # Dynamics of Open Chains
#
# - Canonical notebook: [08-dynamics-of-open-chains.ipynb](08-dynamics-of-open-chains.ipynb)
# - Printed pages: 271-324
# - PDF pages: 289-342
# - Chapter question: How do forces, torques, velocities, and accelerations interact through the robot's configuration?
#
# ## Visual Storyboard
#
# - Main visual focus: mass matrices, Newton-Euler recursion, and task-space inertia
# - Representation: mass eigenvalue and response plots
# - Inspection target: how inertia changes with configuration and coordinates

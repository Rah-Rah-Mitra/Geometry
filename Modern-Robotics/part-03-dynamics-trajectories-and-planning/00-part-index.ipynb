# %% [markdown]
# # Dynamics, Trajectories, and Planning
#
# ## Notebooks
#
# - [Dynamics of Open Chains](chapter-08-dynamics-of-open-chains/08-dynamics-of-open-chains.ipynb) - How do forces, torques, velocities, and accelerations interact through the robot's configuration?
# - [Trajectory Generation](chapter-09-trajectory-generation/09-trajectory-generation.ipynb) - How do we turn geometric waypoints into a smooth, executable time history?
# - [Motion Planning](chapter-10-motion-planning/10-motion-planning.ipynb) - How does a robot find a feasible path through a high-dimensional space with obstacles?

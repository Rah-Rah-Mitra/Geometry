# %% [markdown]
# # Motion Planning
#
# - Canonical notebook: [10-motion-planning.ipynb](10-motion-planning.ipynb)
# - Printed pages: 353-402
# - PDF pages: 371-420
# - Chapter question: How does a robot find a feasible path through a high-dimensional space with obstacles?
#
# ## Visual Storyboard
#
# - Main visual focus: configuration-space obstacles and graph search
# - Representation: grid planner, obstacle field, and sampling intuition
# - Inspection target: how collision constraints turn geometry into search

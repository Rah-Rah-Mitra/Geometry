# %% [markdown]
# # Summary of Useful Formulas
#
# - Canonical notebook: [appendix-a-summary-of-useful-formulas.ipynb](appendix-a-summary-of-useful-formulas.ipynb)
# - Printed pages: 565-574
# - PDF pages: 583-592
# - Chapter question: Which formulas are the course's reusable computational contracts?
#
# ## Visual Storyboard
#
# - Main visual focus: formula dependency and quick checks
# - Representation: formula map with residual checks
# - Inspection target: which identities are safe to reuse and what they preserve

# %% [markdown]
# # Other Representations of Rotations
#
# - Canonical notebook: [appendix-b-other-representations-of-rotations.ipynb](appendix-b-other-representations-of-rotations.ipynb)
# - Printed pages: 575-584
# - PDF pages: 593-602
# - Chapter question: Why do so many rotation coordinates exist, and what does each one trade away?
#
# ## Visual Storyboard
#
# - Main visual focus: Euler angles, roll-pitch-yaw, quaternions, and Cayley parameters
# - Representation: rotation parameter comparison curves
# - Inspection target: where each parameterization is smooth, singular, or redundant

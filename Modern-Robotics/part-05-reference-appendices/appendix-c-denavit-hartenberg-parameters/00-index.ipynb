# %% [markdown]
# # Denavit-Hartenberg Parameters
#
# - Canonical notebook: [appendix-c-denavit-hartenberg-parameters.ipynb](appendix-c-denavit-hartenberg-parameters.ipynb)
# - Printed pages: 585-596
# - PDF pages: 603-614
# - Chapter question: How do D-H parameters encode a serial chain, and when is PoE clearer?
#
# ## Visual Storyboard
#
# - Main visual focus: D-H frames compared with product of exponentials
# - Representation: link-frame assignment and transform comparison
# - Inspection target: how local link conventions differ from screw-axis models

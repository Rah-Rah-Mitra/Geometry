# %% [markdown]
# # Reference Appendices
#
# ## Notebooks
#
# - [Summary of Useful Formulas](appendix-a-summary-of-useful-formulas/appendix-a-summary-of-useful-formulas.ipynb) - Which formulas are the course's reusable computational contracts?
# - [Other Representations of Rotations](appendix-b-other-representations-of-rotations/appendix-b-other-representations-of-rotations.ipynb) - Why do so many rotation coordinates exist, and what does each one trade away?
# - [Denavit-Hartenberg Parameters](appendix-c-denavit-hartenberg-parameters/appendix-c-denavit-hartenberg-parameters.ipynb) - How do D-H parameters encode a serial chain, and when is PoE clearer?
# - [Optimization and Lagrange Multipliers](appendix-d-optimization-and-lagrange-multipliers/appendix-d-optimization-and-lagrange-multipliers.ipynb) - What does a multiplier say geometrically about constrained robot decisions?

# %% [markdown]
# # Optimization and Lagrange Multipliers
#
# - Canonical notebook: [appendix-d-optimization-and-lagrange-multipliers.ipynb](appendix-d-optimization-and-lagrange-multipliers.ipynb)
# - Printed pages: 597-598
# - PDF pages: 615-616
# - Chapter question: What does a multiplier say geometrically about constrained robot decisions?
#
# ## Visual Storyboard
#
# - Main visual focus: constraint gradients and multiplier geometry
# - Representation: level curves and active constraint normals
# - Inspection target: how optimality appears as aligned gradients under constraints

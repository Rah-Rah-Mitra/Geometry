# %% [markdown]
# # Forward Kinematics
#
# - Canonical notebook: [04-forward-kinematics.ipynb](04-forward-kinematics.ipynb)
# - Printed pages: 137-170
# - PDF pages: 155-188
# - Chapter question: How does a list of joint motions become a single end-effector transform?
#
# ## Visual Storyboard
#
# - Main visual focus: product of exponentials for open chains
# - Representation: planar arm and end-effector velocity ellipsoid
# - Inspection target: how screw axes compose into an end-effector pose

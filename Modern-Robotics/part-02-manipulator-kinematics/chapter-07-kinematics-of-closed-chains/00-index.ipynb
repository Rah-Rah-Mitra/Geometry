# %% [markdown]
# # Kinematics of Closed Chains
#
# - Canonical notebook: [07-kinematics-of-closed-chains.ipynb](07-kinematics-of-closed-chains.ipynb)
# - Printed pages: 245-270
# - PDF pages: 263-288
# - Chapter question: How do closed loops change kinematics from composition to constraint solving?
#
# ## Visual Storyboard
#
# - Main visual focus: parallel mechanisms and loop constraints
# - Representation: constraint residual and singular loop geometry
# - Inspection target: how loop closure creates implicit surfaces and singular branches

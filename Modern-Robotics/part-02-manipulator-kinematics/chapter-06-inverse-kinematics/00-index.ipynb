# %% [markdown]
# # Inverse Kinematics
#
# - Canonical notebook: [06-inverse-kinematics.ipynb](06-inverse-kinematics.ipynb)
# - Printed pages: 219-244
# - PDF pages: 237-262
# - Chapter question: How can we solve for joint coordinates when the forward map is nonlinear and sometimes many-to-one?
#
# ## Visual Storyboard
#
# - Main visual focus: analytic and numerical inverse kinematics
# - Representation: iterative endpoint correction
# - Inspection target: how pose error is converted into a joint update and when it stalls

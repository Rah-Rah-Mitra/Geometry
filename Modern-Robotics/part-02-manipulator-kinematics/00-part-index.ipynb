# %% [markdown]
# # Manipulator Kinematics
#
# ## Notebooks
#
# - [Forward Kinematics](chapter-04-forward-kinematics/04-forward-kinematics.ipynb) - How does a list of joint motions become a single end-effector transform?
# - [Velocity Kinematics and Statics](chapter-05-velocity-kinematics-and-statics/05-velocity-kinematics-and-statics.ipynb) - What does the Jacobian say about instantaneous motion, lost directions, and static force balance?
# - [Inverse Kinematics](chapter-06-inverse-kinematics/06-inverse-kinematics.ipynb) - How can we solve for joint coordinates when the forward map is nonlinear and sometimes many-to-one?
# - [Kinematics of Closed Chains](chapter-07-kinematics-of-closed-chains/07-kinematics-of-closed-chains.ipynb) - How do closed loops change kinematics from composition to constraint solving?

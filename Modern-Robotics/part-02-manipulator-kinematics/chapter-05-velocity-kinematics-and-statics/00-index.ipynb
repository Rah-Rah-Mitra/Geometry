# %% [markdown]
# # Velocity Kinematics and Statics
#
# - Canonical notebook: [05-velocity-kinematics-and-statics.ipynb](05-velocity-kinematics-and-statics.ipynb)
# - Printed pages: 171-218
# - PDF pages: 189-236
# - Chapter question: What does the Jacobian say about instantaneous motion, lost directions, and static force balance?
#
# ## Visual Storyboard
#
# - Main visual focus: Jacobians, singularities, statics, and manipulability
# - Representation: Jacobian image and velocity ellipsoid
# - Inspection target: where rank and ellipsoid shape reveal available motion and force directions

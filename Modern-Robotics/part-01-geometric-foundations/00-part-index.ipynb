# %% [markdown]
# # Geometric Foundations
#
# ## Notebooks
#
# - [Preview](chapter-01-preview/01-preview.ipynb) - What does a robot need to know about shape, motion, force, and choice before it can act?
# - [Configuration Space](chapter-02-configuration-space/02-configuration-space.ipynb) - How do joints, loops, and constraints turn a mechanism into a geometric space?
# - [Rigid-Body Motions](chapter-03-rigid-body-motions/03-rigid-body-motions.ipynb) - How can a rigid displacement, a velocity, and a force all be represented without losing frame information?

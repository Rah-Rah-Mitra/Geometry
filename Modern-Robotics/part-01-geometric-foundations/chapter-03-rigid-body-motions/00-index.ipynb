# %% [markdown]
# # Rigid-Body Motions
#
# - Canonical notebook: [03-rigid-body-motions.ipynb](03-rigid-body-motions.ipynb)
# - Printed pages: 59-136
# - PDF pages: 77-154
# - Chapter question: How can a rigid displacement, a velocity, and a force all be represented without losing frame information?
#
# ## Visual Storyboard
#
# - Main visual focus: SO(3), SE(3), twists, screws, and wrenches
# - Representation: 3D frames and screw path
# - Inspection target: how exponentials move frames while preserving rigid distances

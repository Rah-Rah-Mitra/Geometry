# %% [markdown]
# # Preview
#
# - Canonical notebook: [01-preview.ipynb](01-preview.ipynb)
# - Printed pages: 1-10
# - PDF pages: 19-28
# - Chapter question: What does a robot need to know about shape, motion, force, and choice before it can act?
#
# ## Visual Storyboard
#
# - Main visual focus: robotics as geometry plus decisions
# - Representation: course map and workspace sketch
# - Inspection target: how mechanics, planning, and control become one pipeline

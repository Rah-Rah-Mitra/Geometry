# %% [markdown]
# # Configuration Space
#
# - Canonical notebook: [02-configuration-space.ipynb](02-configuration-space.ipynb)
# - Printed pages: 11-58
# - PDF pages: 29-76
# - Chapter question: How do joints, loops, and constraints turn a mechanism into a geometric space?
#
# ## Visual Storyboard
#
# - Main visual focus: configuration spaces, constraints, and workspaces
# - Representation: joint torus heat map and workspace annulus
# - Inspection target: where topology, dimension, and singular constraints become visible

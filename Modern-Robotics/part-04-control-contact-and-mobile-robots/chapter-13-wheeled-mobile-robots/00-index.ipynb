# %% [markdown]
# # Wheeled Mobile Robots
#
# - Canonical notebook: [13-wheeled-mobile-robots.ipynb](13-wheeled-mobile-robots.ipynb)
# - Printed pages: 513-564
# - PDF pages: 531-582
# - Chapter question: How do wheel designs decide which chassis velocities are directly available?
#
# ## Visual Storyboard
#
# - Main visual focus: omnidirectional and nonholonomic mobile bases
# - Representation: unicycle rollout and wheel velocity map
# - Inspection target: how wheel constraints shape reachable velocity and path geometry

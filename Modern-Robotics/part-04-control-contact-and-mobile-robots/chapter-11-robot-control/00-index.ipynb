# %% [markdown]
# # Robot Control
#
# - Canonical notebook: [11-robot-control.ipynb](11-robot-control.ipynb)
# - Printed pages: 403-460
# - PDF pages: 421-478
# - Chapter question: How do feedback laws turn desired motion or contact behavior into stable robot action?
#
# ## Visual Storyboard
#
# - Main visual focus: feedback, force control, impedance, and hybrid control
# - Representation: response plots and projection geometry
# - Inspection target: how error dynamics and task constraints shape closed-loop behavior

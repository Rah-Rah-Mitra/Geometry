# %% [markdown]
# # Control, Contact, and Mobile Robots
#
# ## Notebooks
#
# - [Robot Control](chapter-11-robot-control/11-robot-control.ipynb) - How do feedback laws turn desired motion or contact behavior into stable robot action?
# - [Grasping and Manipulation](chapter-12-grasping-and-manipulation/12-grasping-and-manipulation.ipynb) - What can contacts prevent, permit, or command when a robot touches an object?
# - [Wheeled Mobile Robots](chapter-13-wheeled-mobile-robots/13-wheeled-mobile-robots.ipynb) - How do wheel designs decide which chassis velocities are directly available?

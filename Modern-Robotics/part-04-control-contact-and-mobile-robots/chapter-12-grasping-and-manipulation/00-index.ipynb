# %% [markdown]
# # Grasping and Manipulation
#
# - Canonical notebook: [12-grasping-and-manipulation.ipynb](12-grasping-and-manipulation.ipynb)
# - Printed pages: 461-512
# - PDF pages: 479-530
# - Chapter question: What can contacts prevent, permit, or command when a robot touches an object?
#
# ## Visual Storyboard
#
# - Main visual focus: contact kinematics, friction cones, and closure
# - Representation: friction cone and grasp matrix
# - Inspection target: how contact normals and friction span or fail to span object wrenches

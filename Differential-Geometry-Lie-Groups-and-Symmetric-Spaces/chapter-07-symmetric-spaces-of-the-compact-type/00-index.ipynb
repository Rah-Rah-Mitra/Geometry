# %% [markdown]
# # Chapter 7: Symmetric Spaces of the Compact Type
#
# Source span: printed pages `281-351`.
#
# Focus: Weyl groups, conjugate points, singular sets, compact groups, affine Weyl groups, and rank-one geometry.
#
# Canonical notebook: [`07-symmetric-spaces-of-the-compact-type.ipynb`](07-symmetric-spaces-of-the-compact-type.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

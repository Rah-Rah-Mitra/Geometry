# %% [markdown]
# # Chapter 9: Structure of Semisimple Lie Groups
#
# Source span: printed pages `401-437`.
#
# Focus: Cartan, Iwasawa, Bruhat, rank-one, SU(2,1), Cartan subalgebras, automorphisms, multiplicities, and Jordan decompositions.
#
# Canonical notebook: [`09-structure-of-semisimple-lie-groups.ipynb`](09-structure-of-semisimple-lie-groups.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

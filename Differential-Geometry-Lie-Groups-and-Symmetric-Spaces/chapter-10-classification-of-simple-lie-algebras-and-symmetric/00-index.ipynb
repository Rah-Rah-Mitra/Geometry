# %% [markdown]
# # Chapter 10: Classification of Simple Lie Algebras and Symmetric Spaces
#
# Source span: printed pages `438-458`.
#
# Canonical notebook: [`10-classification-of-simple-lie-algebras-and.ipynb`](10-classification-of-simple-lie-algebras-and.ipynb).
#
# Focus: Classical groups, root systems, Dynkin diagrams, finite-order automorphisms, real forms, and symmetric-space classification.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Geometry-Lie-Groups-and-Symmetric-Spaces

# %% [markdown]
# # Chapter 2: Lie Groups and Lie Algebras
#
# Source span: printed pages `98-154`.
#
# Canonical notebook: [`02-lie-groups-and-lie-algebras.ipynb`](02-lie-groups-and-lie-algebras.ipynb).
#
# Focus: Exponential map, Lie subgroups, transformation groups, coset spaces, adjoint group, semisimple groups, and invariant forms.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Geometry-Lie-Groups-and-Symmetric-Spaces

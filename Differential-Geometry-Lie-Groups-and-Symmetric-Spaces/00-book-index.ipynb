# %% [markdown]
# # Differential Geometry, Lie Groups, and Symmetric Spaces
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Elementary Differential Geometry | 2-97 | [`01-elementary-differential-geometry.ipynb`](chapter-01-elementary-differential-geometry/01-elementary-differential-geometry.ipynb) |
# | Chapter 2 | Lie Groups and Lie Algebras | 98-154 | [`02-lie-groups-and-lie-algebras.ipynb`](chapter-02-lie-groups-and-lie-algebras/02-lie-groups-and-lie-algebras.ipynb) |
# | Chapter 3 | Structure of Semisimple Lie Algebras | 155-197 | [`03-structure-of-semisimple-lie-algebras.ipynb`](chapter-03-structure-of-semisimple-lie-algebras/03-structure-of-semisimple-lie-algebras.ipynb) |
# | Chapter 4 | Symmetric Spaces | 198-228 | [`04-symmetric-spaces.ipynb`](chapter-04-symmetric-spaces/04-symmetric-spaces.ipynb) |
# | Chapter 5 | Decomposition of Symmetric Spaces | 229-251 | [`05-decomposition-of-symmetric-spaces.ipynb`](chapter-05-decomposition-of-symmetric-spaces/05-decomposition-of-symmetric-spaces.ipynb) |
# | Chapter 6 | Symmetric Spaces of the Noncompact Type | 252-280 | [`06-symmetric-spaces-of-the-noncompact-type.ipynb`](chapter-06-symmetric-spaces-of-the-noncompact-type/06-symmetric-spaces-of-the-noncompact-type.ipynb) |
# | Chapter 7 | Symmetric Spaces of the Compact Type | 281-351 | [`07-symmetric-spaces-of-the-compact-type.ipynb`](chapter-07-symmetric-spaces-of-the-compact-type/07-symmetric-spaces-of-the-compact-type.ipynb) |
# | Chapter 8 | Hermitian Symmetric Spaces | 352-400 | [`08-hermitian-symmetric-spaces.ipynb`](chapter-08-hermitian-symmetric-spaces/08-hermitian-symmetric-spaces.ipynb) |
# | Chapter 9 | Structure of Semisimple Lie Groups | 401-437 | [`09-structure-of-semisimple-lie-groups.ipynb`](chapter-09-structure-of-semisimple-lie-groups/09-structure-of-semisimple-lie-groups.ipynb) |
# | Chapter 10 | Classification of Simple Lie Algebras and Symmetric Spaces | 438-458 | [`10-classification-of-simple-lie-algebras-and.ipynb`](chapter-10-classification-of-simple-lie-algebras-and-symmetric/10-classification-of-simple-lie-algebras-and.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Differential Geometry, Lie Groups, and Symmetric Spaces: 10 canonical units

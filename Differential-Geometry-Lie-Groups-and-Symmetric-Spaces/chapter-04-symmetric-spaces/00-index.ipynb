# %% [markdown]
# # Chapter 4: Symmetric Spaces
#
# Source span: printed pages `198-228`.
#
# Focus: Affine locally symmetric spaces, isometry groups, globally symmetric spaces, curvature, compact Lie groups, and Lie triple systems.
#
# Canonical notebook: [`04-symmetric-spaces.ipynb`](04-symmetric-spaces.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

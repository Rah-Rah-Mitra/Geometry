# %% [markdown]
# # Chapter 5: Decomposition of Symmetric Spaces
#
# Source span: printed pages `229-251`.
#
# Canonical notebook: [`05-decomposition-of-symmetric-spaces.ipynb`](05-decomposition-of-symmetric-spaces.ipynb).
#
# Focus: Orthogonal symmetric Lie algebras, duality, sectional curvature, semisimple isometry groups, and rank.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Geometry-Lie-Groups-and-Symmetric-Spaces

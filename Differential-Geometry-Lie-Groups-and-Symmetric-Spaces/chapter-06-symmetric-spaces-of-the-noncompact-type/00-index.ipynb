# %% [markdown]
# # Chapter 6: Symmetric Spaces of the Noncompact Type
#
# Source span: printed pages `252-280`.
#
# Focus: Semisimple group decompositions, maximal compact subgroups, Iwasawa decomposition, nilpotent groups, and global decompositions.
#
# Canonical notebook: [`06-symmetric-spaces-of-the-noncompact-type.ipynb`](06-symmetric-spaces-of-the-noncompact-type.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

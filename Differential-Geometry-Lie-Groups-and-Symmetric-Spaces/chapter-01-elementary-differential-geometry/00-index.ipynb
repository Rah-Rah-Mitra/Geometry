# %% [markdown]
# # Chapter 1: Elementary Differential Geometry
#
# Source span: printed pages `2-97`.
#
# Focus: Manifolds, tensor fields, mappings, affine connections, parallelism, exponential maps, structural equations, and curvature.
#
# Canonical notebook: [`01-elementary-differential-geometry.ipynb`](01-elementary-differential-geometry.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

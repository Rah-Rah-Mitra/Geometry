# %% [markdown]
# # Chapter 3: Structure of Semisimple Lie Algebras
#
# Source span: printed pages `155-197`.
#
# Focus: Lie and Engel theorems, Cartan subalgebras, roots, real forms, Cartan decompositions, and classical examples.
#
# Canonical notebook: [`03-structure-of-semisimple-lie-algebras.ipynb`](03-structure-of-semisimple-lie-algebras.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 8: Hermitian Symmetric Spaces
#
# Source span: printed pages `352-400`.
#
# Focus: Almost complex manifolds, Ricci curvature, bounded domains, Hermitian symmetric spaces, and Cartan-Harish-Chandra representation.
#
# Canonical notebook: [`08-hermitian-symmetric-spaces.ipynb`](08-hermitian-symmetric-spaces.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 01: Experimental Facts
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [01-experimental-facts.ipynb](01-experimental-facts.ipynb)

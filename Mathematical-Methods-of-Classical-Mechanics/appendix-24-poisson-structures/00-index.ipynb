# %% [markdown]
# # Appendix 24: Poisson Structures
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-24-poisson-structures.ipynb](appendix-24-poisson-structures.ipynb)

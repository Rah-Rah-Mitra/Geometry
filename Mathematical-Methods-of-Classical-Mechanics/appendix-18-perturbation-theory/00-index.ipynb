# %% [markdown]
# # Appendix 18: Perturbation Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-18-perturbation-theory.ipynb](appendix-18-perturbation-theory.ipynb)

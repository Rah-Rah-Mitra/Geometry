# %% [markdown]
# # Appendix 26: Additional Mechanical Models
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-26-additional-mechanical-models.ipynb](appendix-26-additional-mechanical-models.ipynb)

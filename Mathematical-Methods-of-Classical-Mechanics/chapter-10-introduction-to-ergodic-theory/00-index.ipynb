# %% [markdown]
# # Chapter 10: Introduction to Ergodic Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [10-introduction-to-ergodic-theory.ipynb](10-introduction-to-ergodic-theory.ipynb)

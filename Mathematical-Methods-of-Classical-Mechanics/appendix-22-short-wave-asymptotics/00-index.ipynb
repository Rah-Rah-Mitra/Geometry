# %% [markdown]
# # Appendix 22: Short-Wave Asymptotics
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-22-short-wave-asymptotics.ipynb](appendix-22-short-wave-asymptotics.ipynb)

# %% [markdown]
# # Chapter 08: Symplectic Manifolds
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [08-symplectic-manifolds.ipynb](08-symplectic-manifolds.ipynb)

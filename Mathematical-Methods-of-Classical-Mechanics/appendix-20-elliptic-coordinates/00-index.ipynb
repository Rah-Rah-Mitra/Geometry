# %% [markdown]
# # Appendix 20: Elliptic Coordinates
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-20-elliptic-coordinates.ipynb](appendix-20-elliptic-coordinates.ipynb)

# %% [markdown]
# # Appendix 21: Adiabatic Invariants
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-21-adiabatic-invariants.ipynb](appendix-21-adiabatic-invariants.ipynb)

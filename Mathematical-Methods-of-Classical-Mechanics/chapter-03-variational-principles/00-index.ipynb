# %% [markdown]
# # Chapter 03: Variational Principles
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [03-variational-principles.ipynb](03-variational-principles.ipynb)

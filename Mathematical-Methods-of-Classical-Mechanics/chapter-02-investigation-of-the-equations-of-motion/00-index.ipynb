# %% [markdown]
# # Chapter 02: Investigation of the Equations of Motion
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [02-investigation-of-the-equations-of-motion.ipynb](02-investigation-of-the-equations-of-motion.ipynb)

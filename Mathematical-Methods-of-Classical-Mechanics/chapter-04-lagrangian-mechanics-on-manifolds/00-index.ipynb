# %% [markdown]
# # Chapter 04: Lagrangian Mechanics on Manifolds
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [04-lagrangian-mechanics-on-manifolds.ipynb](04-lagrangian-mechanics-on-manifolds.ipynb)

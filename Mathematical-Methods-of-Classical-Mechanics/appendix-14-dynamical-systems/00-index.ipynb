# %% [markdown]
# # Appendix 14: Dynamical Systems
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-14-dynamical-systems.ipynb](appendix-14-dynamical-systems.ipynb)

# %% [markdown]
# # Appendix 19: Geometric Theorem
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-19-geometric-theorem.ipynb](appendix-19-geometric-theorem.ipynb)

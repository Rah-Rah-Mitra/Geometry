# %% [markdown]
# # Appendix 13: Differential Forms
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-13-differential-forms.ipynb](appendix-13-differential-forms.ipynb)

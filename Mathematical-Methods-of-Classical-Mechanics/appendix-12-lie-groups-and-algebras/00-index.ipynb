# %% [markdown]
# # Appendix 12: Lie Groups and Algebras
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-12-lie-groups-and-algebras.ipynb](appendix-12-lie-groups-and-algebras.ipynb)

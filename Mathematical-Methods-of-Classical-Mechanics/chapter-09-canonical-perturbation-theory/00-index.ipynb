# %% [markdown]
# # Chapter 09: Canonical Perturbation Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [09-canonical-perturbation-theory.ipynb](09-canonical-perturbation-theory.ipynb)

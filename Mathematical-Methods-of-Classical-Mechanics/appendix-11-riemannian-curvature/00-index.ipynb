# %% [markdown]
# # Appendix 11: Riemannian Curvature
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-11-riemannian-curvature.ipynb](appendix-11-riemannian-curvature.ipynb)

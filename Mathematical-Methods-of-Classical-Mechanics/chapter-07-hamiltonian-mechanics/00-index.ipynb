# %% [markdown]
# # Chapter 07: Hamiltonian Mechanics
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [07-hamiltonian-mechanics.ipynb](07-hamiltonian-mechanics.ipynb)

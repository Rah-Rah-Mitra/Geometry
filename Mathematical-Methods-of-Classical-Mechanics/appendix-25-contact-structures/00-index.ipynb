# %% [markdown]
# # Appendix 25: Contact Structures
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-25-contact-structures.ipynb](appendix-25-contact-structures.ipynb)

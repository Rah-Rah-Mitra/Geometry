# %% [markdown]
# # Appendix 16: Symplectic Structures
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-16-symplectic-structures.ipynb](appendix-16-symplectic-structures.ipynb)

# %% [markdown]
# # Chapter 10: Signal Processing
#
# - Canonical notebook: [10-signal-processing.ipynb](10-signal-processing.ipynb)
# - Printed pages: 205-254
# - Physical PDF pages: 222-271
# - Visual spine: sampling, convolution, filters, Fourier spectra, aliasing
#
# Artifacts for this chapter are stored under `../artifacts/chapter-10/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 14: Physics-Based Rendering
#
# - Canonical notebook: [14-physics-based-rendering.ipynb](14-physics-based-rendering.ipynb)
# - Printed pages: 357-382
# - Physical PDF pages: 374-399
# - Visual spine: radiometry, Fresnel, refraction, BRDFs, rendering equation
#
# Artifacts for this chapter are stored under `../artifacts/chapter-14/` and are generated by the canonical notebook.

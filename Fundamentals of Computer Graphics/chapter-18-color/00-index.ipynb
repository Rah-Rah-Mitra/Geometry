# %% [markdown]
# # Chapter 18: Color
#
# - Canonical notebook: [18-color.ipynb](18-color.ipynb)
# - Printed pages: 503-524
# - Physical PDF pages: 520-541
# - Visual spine: spectra, XYZ/RGB/LAB, gamut, gamma, chromatic adaptation
#
# Artifacts for this chapter are stored under `../artifacts/chapter-18/` and are generated by the canonical notebook.

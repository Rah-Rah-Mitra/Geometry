# %% [markdown]
# # Chapter 23: Visualization
#
# - Canonical notebook: [23-visualization.ipynb](23-visualization.ipynb)
# - Printed pages: 645-680
# - Physical PDF pages: 662-697
# - Visual spine: data/task abstraction, encodings, interaction, reduction, validation
#
# Artifacts for this chapter are stored under `../artifacts/chapter-23/` and are generated by the canonical notebook.

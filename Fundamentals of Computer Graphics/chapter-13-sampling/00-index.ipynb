# %% [markdown]
# # Chapter 13: Sampling
#
# - Canonical notebook: [13-sampling.ipynb](13-sampling.ipynb)
# - Printed pages: 335-356
# - Physical PDF pages: 352-373
# - Visual spine: measures, inverse CDF, rejection, stratification, hemisphere sampling
#
# Artifacts for this chapter are stored under `../artifacts/chapter-13/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 01: Introduction
#
# - Canonical notebook: [01-introduction.ipynb](01-introduction.ipynb)
# - Printed pages: 1-12
# - Physical PDF pages: 18-29
# - Visual spine: graphics map, pipeline, numeric robustness, debug images
#
# Artifacts for this chapter are stored under `../artifacts/chapter-01/` and are generated by the canonical notebook.

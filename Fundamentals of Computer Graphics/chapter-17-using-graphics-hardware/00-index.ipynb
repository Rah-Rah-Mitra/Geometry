# %% [markdown]
# # Chapter 17: Using Graphics Hardware
#
# - Canonical notebook: [17-using-graphics-hardware.ipynb](17-using-graphics-hardware.ipynb)
# - Printed pages: 461-502
# - Physical PDF pages: 478-519
# - Visual spine: mini GPU pipeline, buffers, shaders, depth, textures
#
# Artifacts for this chapter are stored under `../artifacts/chapter-17/` and are generated by the canonical notebook.

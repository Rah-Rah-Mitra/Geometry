# %% [markdown]
# # Chapter 06: Linear Algebra
#
# - Canonical notebook: [06-linear-algebra.ipynb](06-linear-algebra.ipynb)
# - Printed pages: 107-126
# - Physical PDF pages: 124-143
# - Visual spine: determinants, matrix maps, inverse, eigen/SVD geometry
#
# Artifacts for this chapter are stored under `../artifacts/chapter-06/` and are generated by the canonical notebook.

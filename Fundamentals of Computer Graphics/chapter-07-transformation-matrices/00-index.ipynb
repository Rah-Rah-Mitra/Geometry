# %% [markdown]
# # Chapter 07: Transformation Matrices
#
# - Canonical notebook: [07-transformation-matrices.ipynb](07-transformation-matrices.ipynb)
# - Printed pages: 127-156
# - Physical PDF pages: 144-173
# - Visual spine: 2D/3D transforms, homogeneous coordinates, normal transforms
#
# Artifacts for this chapter are stored under `../artifacts/chapter-07/` and are generated by the canonical notebook.

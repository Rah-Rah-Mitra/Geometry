# %% [markdown]
# # Chapter 05: Surface Shading
#
# - Canonical notebook: [05-surface-shading.ipynb](05-surface-shading.ipynb)
# - Printed pages: 97-106
# - Physical PDF pages: 114-123
# - Visual spine: Lambert, point lights, Blinn-Phong, ambient fill
#
# Artifacts for this chapter are stored under `../artifacts/chapter-05/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 09: The Graphics Pipeline
#
# - Canonical notebook: [09-graphics-pipeline.ipynb](09-graphics-pipeline.ipynb)
# - Printed pages: 177-204
# - Physical PDF pages: 194-221
# - Visual spine: rasterization, interpolation, z-buffer, antialiasing, culling
#
# Artifacts for this chapter are stored under `../artifacts/chapter-09/` and are generated by the canonical notebook.

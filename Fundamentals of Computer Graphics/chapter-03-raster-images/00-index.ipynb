# %% [markdown]
# # Chapter 03: Raster Images
#
# - Canonical notebook: [03-raster-images.ipynb](03-raster-images.ipynb)
# - Printed pages: 63-78
# - Physical PDF pages: 80-95
# - Visual spine: pixels, RGB, gamma, quantization, alpha compositing
#
# Artifacts for this chapter are stored under `../artifacts/chapter-03/` and are generated by the canonical notebook.

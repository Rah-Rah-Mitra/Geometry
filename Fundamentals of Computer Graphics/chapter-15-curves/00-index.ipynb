# %% [markdown]
# # Chapter 15: Curves
#
# - Canonical notebook: [15-curves.ipynb](15-curves.ipynb)
# - Printed pages: 383-428
# - Physical PDF pages: 400-445
# - Visual spine: parametrization, continuity, Bezier, B-splines, NURBS
#
# Artifacts for this chapter are stored under `../artifacts/chapter-15/` and are generated by the canonical notebook.

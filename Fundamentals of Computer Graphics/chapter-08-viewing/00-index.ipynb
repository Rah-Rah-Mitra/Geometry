# %% [markdown]
# # Chapter 08: Viewing
#
# - Canonical notebook: [08-viewing.ipynb](08-viewing.ipynb)
# - Printed pages: 157-176
# - Physical PDF pages: 174-193
# - Visual spine: camera basis, projection, frustum, viewport, field of view
#
# Artifacts for this chapter are stored under `../artifacts/chapter-08/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 02: Miscellaneous Math
#
# - Canonical notebook: [02-miscellaneous-math.ipynb](02-miscellaneous-math.ipynb)
# - Printed pages: 13-62
# - Physical PDF pages: 30-79
# - Visual spine: vectors, barycentric coordinates, quadratics, probability, Monte Carlo
#
# Artifacts for this chapter are stored under `../artifacts/chapter-02/` and are generated by the canonical notebook.

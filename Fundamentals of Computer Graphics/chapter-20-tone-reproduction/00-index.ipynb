# %% [markdown]
# # Chapter 20: Tone Reproduction
#
# - Canonical notebook: [20-tone-reproduction.ipynb](20-tone-reproduction.ipynb)
# - Printed pages: 569-594
# - Physical PDF pages: 586-611
# - Visual spine: HDR/LDR, tone curves, local operators, color preservation
#
# Artifacts for this chapter are stored under `../artifacts/chapter-20/` and are generated by the canonical notebook.

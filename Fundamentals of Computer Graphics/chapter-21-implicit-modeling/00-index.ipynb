# %% [markdown]
# # Chapter 21: Implicit Modeling
#
# - Canonical notebook: [21-implicit-modeling.ipynb](21-implicit-modeling.ipynb)
# - Printed pages: 595-622
# - Physical PDF pages: 612-639
# - Visual spine: scalar fields, blends, CSG, warps, marching cubes
#
# Artifacts for this chapter are stored under `../artifacts/chapter-21/` and are generated by the canonical notebook.

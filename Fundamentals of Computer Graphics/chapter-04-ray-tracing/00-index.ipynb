# %% [markdown]
# # Chapter 04: Ray Tracing
#
# - Canonical notebook: [04-ray-tracing.ipynb](04-ray-tracing.ipynb)
# - Printed pages: 79-96
# - Physical PDF pages: 96-113
# - Visual spine: camera rays, intersections, closest hit, shadows, reflection
#
# Artifacts for this chapter are stored under `../artifacts/chapter-04/` and are generated by the canonical notebook.

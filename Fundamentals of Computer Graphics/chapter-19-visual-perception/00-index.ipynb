# %% [markdown]
# # Chapter 19: Visual Perception
#
# - Canonical notebook: [19-visual-perception.ipynb](19-visual-perception.ipynb)
# - Printed pages: 525-568
# - Physical PDF pages: 542-585
# - Visual spine: contrast, illusions, depth cues, motion, picture perception
#
# Artifacts for this chapter are stored under `../artifacts/chapter-19/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 16: Computer Animation
#
# - Canonical notebook: [16-computer-animation.ipynb](16-computer-animation.ipynb)
# - Printed pages: 429-460
# - Physical PDF pages: 446-477
# - Visual spine: keyframes, splines, quaternions, rigs, skinning, particles
#
# Artifacts for this chapter are stored under `../artifacts/chapter-16/` and are generated by the canonical notebook.

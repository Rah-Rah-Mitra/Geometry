# %% [markdown]
# # Chapter 12: Data Structures for Graphics
#
# - Canonical notebook: [12-data-structures-for-graphics.ipynb](12-data-structures-for-graphics.ipynb)
# - Printed pages: 291-334
# - Physical PDF pages: 308-351
# - Visual spine: mesh topology, scene graphs, BVH/kd/BSP, tiled memory
#
# Artifacts for this chapter are stored under `../artifacts/chapter-12/` and are generated by the canonical notebook.

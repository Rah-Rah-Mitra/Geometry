# %% [markdown]
# # Chapter 22: Computer Graphics in Games
#
# - Canonical notebook: [22-computer-graphics-in-games.ipynb](22-computer-graphics-in-games.ipynb)
# - Printed pages: 623-644
# - Physical PDF pages: 640-661
# - Visual spine: frame budgets, LOD, asset pipeline, normal maps, optimization
#
# Artifacts for this chapter are stored under `../artifacts/chapter-22/` and are generated by the canonical notebook.

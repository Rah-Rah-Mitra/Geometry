# %% [markdown]
# # Chapter 11: Texture Mapping
#
# - Canonical notebook: [11-texture-mapping.ipynb](11-texture-mapping.ipynb)
# - Printed pages: 255-290
# - Physical PDF pages: 272-307
# - Visual spine: UVs, perspective-correct lookup, mipmaps, bump/displacement, noise
#
# Artifacts for this chapter are stored under `../artifacts/chapter-11/` and are generated by the canonical notebook.

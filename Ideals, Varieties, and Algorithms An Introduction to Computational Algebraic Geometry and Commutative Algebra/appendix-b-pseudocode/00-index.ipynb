# %% [markdown]
# # Appendix B: Pseudocode
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 607-610; PDF pages 617-619.
#
# Canonical notebook: [appendix-b-pseudocode.ipynb](appendix-b-pseudocode.ipynb)
#
# ## Focus
#
# Inputs, outputs, variables, assignments, loops, branches, and return statements as executable state transitions.
#
# ## Visual Storyboard
#
# - algorithm state-machine legend
# - while-repeat-for flow chart
# - branching decision tree
# - stepper trace table
#
# ## Checks
#
# - each trace state has a determined successor
# - loop guards eventually terminate in the sample
# - return value matches the final state

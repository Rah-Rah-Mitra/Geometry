# %% [markdown]
# # Appendix D: Independent Projects
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 627-636; PDF pages 636-645.
#
# Canonical notebook: [appendix-d-independent-projects.ipynb](appendix-d-independent-projects.ipynb)
#
# ## Focus
#
# A visual project-selection guide that turns suggested project areas into prerequisite maps, deliverable types, and miniature computational storyboards.
#
# ## Visual Storyboard
#
# - project topic network
# - readiness matrix
# - goal-to-project recommender
# - mini-storyboards for dual curves, Sudoku ideals, and toric varieties
#
# ## Checks
#
# - every project card maps to a topic cluster
# - each mini-storyboard has an invariant or computation
# - readiness scores stay in the documented range

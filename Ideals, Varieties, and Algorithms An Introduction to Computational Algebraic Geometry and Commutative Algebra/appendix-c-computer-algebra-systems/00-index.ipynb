# %% [markdown]
# # Appendix C: Computer Algebra Systems
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 611-626; PDF pages 620-635.
#
# Canonical notebook: [appendix-c-computer-algebra-systems.ipynb](appendix-c-computer-algebra-systems.ipynb)
#
# ## Focus
#
# A practical bridge from book algorithms to CAS commands, with local Python/SymPy used for small checks and external CAS tools documented honestly.
#
# ## Visual Storyboard
#
# - CAS capability matrix
# - command comparison cards
# - tool-choice decision tree
# - domain and monomial-order reproducibility panel
#
# ## Checks
#
# - local SymPy commands reproduce small Grobner examples
# - variable order changes leading terms as advertised
# - external-only capabilities are marked optional

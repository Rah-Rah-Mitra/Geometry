# %% [markdown]
# # Chapter 4: The Algebra-Geometry Dictionary
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 177-236; PDF pages 189-248.
#
# Canonical notebook: [04-algebra-geometry-dictionary.ipynb](04-algebra-geometry-dictionary.ipynb)
#
# ## Focus
#
# The Nullstellensatz, radical ideals, ideal operations, Zariski closure, quotients, saturation, irreducibility, prime ideals, and decomposition.
#
# ## Visual Storyboard
#
# - inclusion-reversing I and V dictionary poset
# - radical thickness comparison
# - Rabinowitsch radical membership diagram
# - ideal operation gallery for sums, intersections, and products
# - component decomposition schematic
#
# ## Checks
#
# - augmented ideal test certifies small radical memberships
# - sampled sets match V(I + J) and V(IJ) identities
# - hand-picked decompositions reconstruct original ideals

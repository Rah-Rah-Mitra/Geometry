# %% [markdown]
# # Act II: The Metric
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Act II: The Metric
#
# ## Chapter 04: Mapping Surfaces: The Metric
#
# - Chapter index: [chapter-04-mapping-surfaces-the-metric/00-index.ipynb](chapter-04-mapping-surfaces-the-metric/00-index.ipynb)
# - Canonical notebook: [04-mapping-surfaces-the-metric.ipynb](chapter-04-mapping-surfaces-the-metric/04-mapping-surfaces-the-metric.ipynb)
# - Source span: printed pp. 31-50; PDF pp. 60-79
# - Focus: Develops the metric as the intrinsic data preserved or distorted by maps, with stereographic projection as the main example.
#
# ## Chapter 05: The Pseudosphere and the Hyperbolic Plane
#
# - Chapter index: [chapter-05-the-pseudosphere-and-the-hyperbolic-plane/00-index.ipynb](chapter-05-the-pseudosphere-and-the-hyperbolic-plane/00-index.ipynb)
# - Canonical notebook: [05-the-pseudosphere-and-the-hyperbolic-plane.ipynb](chapter-05-the-pseudosphere-and-the-hyperbolic-plane/05-the-pseudosphere-and-the-hyperbolic-plane.ipynb)
# - Source span: printed pp. 51-64; PDF pp. 80-93
# - Focus: Uses the pseudosphere to connect tractrix geometry, constant negative curvature, and the Poincare models of hyperbolic geometry.
#
# ## Chapter 06: Isometries and Complex Numbers
#
# - Chapter index: [chapter-06-isometries-and-complex-numbers/00-index.ipynb](chapter-06-isometries-and-complex-numbers/00-index.ipynb)
# - Canonical notebook: [06-isometries-and-complex-numbers.ipynb](chapter-06-isometries-and-complex-numbers/06-isometries-and-complex-numbers.ipynb)
# - Source span: printed pp. 65-82; PDF pp. 94-111
# - Focus: Describes isometries of hyperbolic geometry using Mobius transformations and links the metric story to spacetime geometry.
#
# ## Chapter 07: Exercises for Act II
#
# - Chapter index: [chapter-07-exercises-for-act-ii/00-index.ipynb](chapter-07-exercises-for-act-ii/00-index.ipynb)
# - Canonical notebook: [07-exercises-for-act-ii.ipynb](chapter-07-exercises-for-act-ii/07-exercises-for-act-ii.ipynb)
# - Source span: printed pp. 83-93; PDF pp. 112-122
# - Focus: Practice set on metrics, conformal maps, pseudospherical models, Mobius maps, and spacetime geometry.

# %% [markdown]
# # Chapter 04: Mapping Surfaces: The Metric
#
#             Source span: printed pages 31-50; PDF pages 60-79.
#
#             Canonical notebook: [04-mapping-surfaces-the-metric.ipynb](04-mapping-surfaces-the-metric.ipynb)
#
#             ## Focus
#
#             Develops the metric as the intrinsic data preserved or distorted by maps, with stereographic projection as the main example.
#
#             ## Coverage
#
#             - Projective maps from the sphere
# - Metrics for general parametrized surfaces
# - Metric curvature formula as a preview of intrinsic computation
# - Conformal maps and angle preservation
# - Visual complex-analysis intuition
# - Stereographic projection of the sphere
# - Circle preservation and explicit stereographic formulas

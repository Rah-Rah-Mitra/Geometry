# %% [markdown]
# # Chapter 07: Exercises for Act II
#
#             Source span: printed pages 83-93; PDF pages 112-122.
#
#             Canonical notebook: [07-exercises-for-act-ii.ipynb](07-exercises-for-act-ii.ipynb)
#
#             ## Focus
#
#             Practice set on metrics, conformal maps, pseudospherical models, Mobius maps, and spacetime geometry.
#
#             ## Coverage
#
#             - Metric derivations for mapped surfaces
# - Stereographic and conformal-map calculations
# - Pseudosphere and hyperbolic-plane constructions
# - Geodesics in half-plane and disc models
# - Mobius transformation algebra
# - Lorentz and spacetime metric exercises
# - Three-dimensional hyperbolic examples

# %% [markdown]
# # Chapter 05: The Pseudosphere and the Hyperbolic Plane
#
#             Source span: printed pages 51-64; PDF pages 80-93.
#
#             Canonical notebook: [05-the-pseudosphere-and-the-hyperbolic-plane.ipynb](05-the-pseudosphere-and-the-hyperbolic-plane.ipynb)
#
#             ## Focus
#
#             Uses the pseudosphere to connect tractrix geometry, constant negative curvature, and the Poincare models of hyperbolic geometry.
#
#             ## Coverage
#
#             - Beltrami's realization of hyperbolic geometry
# - The tractrix and construction of the pseudosphere
# - Conformal coordinates on the pseudosphere
# - The Beltrami-Poincare half-plane
# - Optical interpretation of hyperbolic geodesics
# - Angle of parallelism in hyperbolic geometry
# - The Beltrami-Poincare disc model

# %% [markdown]
# # Chapter 03: Exercises for Prologue and Act I
#
#             Source span: printed pages 24-28; PDF pages 53-57.
#
#             Canonical notebook: [03-exercises-for-prologue-and-act-i.ipynb](03-exercises-for-prologue-and-act-i.ipynb)
#
#             ## Focus
#
#             Practice set reinforcing ultimate equality, non-Euclidean geometry, and first curvature measurements.
#
#             ## Coverage
#
#             - Newtonian ultimate-equality calculations
# - Pythagorean triples and Euclidean geometry
# - Spherical triangle and tessellation exercises
# - Geodesic construction experiments on surfaces
# - Estimating Gaussian curvature from intrinsic data
# - Comparisons of angular excess across surfaces

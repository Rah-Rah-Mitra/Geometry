# %% [markdown]
# # Act I: The Nature of Space
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Act I: The Nature of Space
#
# ## Chapter 01: Euclidean and Non-Euclidean Geometry
#
# - Chapter index: [chapter-01-euclidean-and-non-euclidean-geometry/00-index.ipynb](chapter-01-euclidean-and-non-euclidean-geometry/00-index.ipynb)
# - Canonical notebook: [01-euclidean-and-non-euclidean-geometry.ipynb](chapter-01-euclidean-and-non-euclidean-geometry/01-euclidean-and-non-euclidean-geometry.ipynb)
# - Source span: printed pp. 3-16; PDF pp. 32-45
# - Focus: Introduces intrinsic geometry by contrasting Euclidean, spherical, and hyperbolic behavior through geodesics and angular excess.
#
# ## Chapter 02: Gaussian Curvature
#
# - Chapter index: [chapter-02-gaussian-curvature/00-index.ipynb](chapter-02-gaussian-curvature/00-index.ipynb)
# - Canonical notebook: [02-gaussian-curvature.ipynb](chapter-02-gaussian-curvature/02-gaussian-curvature.ipynb)
# - Source span: printed pp. 17-23; PDF pp. 46-52
# - Focus: Motivates Gaussian curvature as the local quantity detected by circles, triangles, and the local Gauss-Bonnet theorem.
#
# ## Chapter 03: Exercises for Prologue and Act I
#
# - Chapter index: [chapter-03-exercises-for-prologue-and-act-i/00-index.ipynb](chapter-03-exercises-for-prologue-and-act-i/00-index.ipynb)
# - Canonical notebook: [03-exercises-for-prologue-and-act-i.ipynb](chapter-03-exercises-for-prologue-and-act-i/03-exercises-for-prologue-and-act-i.ipynb)
# - Source span: printed pp. 24-28; PDF pp. 53-57
# - Focus: Practice set reinforcing ultimate equality, non-Euclidean geometry, and first curvature measurements.

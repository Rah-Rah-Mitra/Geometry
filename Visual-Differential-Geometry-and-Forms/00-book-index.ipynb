# %% [markdown]
# # Visual Differential Geometry and Forms - Standalone Notebook Edition
#
# This course is an original executable notebook edition organized around the book's prologue, five acts, and 39 chapters. The notebooks teach the mathematical ideas with fresh prose, derivations, code, generated artifacts, and sanity checks. The source PDF remains local and is not redistributed through notebook outputs.
#
# Body printed pages map to PDF pages by `pdf_page = printed_page + 29`.
#
# ## Prologue
#
# Front Matter
#
# - [Open part index](part-00-prologue/00-part-index.ipynb)
# - [Prologue: Prologue](part-00-prologue/prologue/00-index.ipynb) - [canonical](part-00-prologue/prologue/prologue.ipynb); printed pp. xvii-xxiii; PDF pp. 18-24; Frames the book as a geometric alternative to unilluminating symbolic calculation and explains the five-act structure.
#
# ## Act I: The Nature of Space
#
# Act I: The Nature of Space
#
# - [Open part index](part-01-the-nature-of-space/00-part-index.ipynb)
# - [Chapter 01: Euclidean and Non-Euclidean Geometry](part-01-the-nature-of-space/chapter-01-euclidean-and-non-euclidean-geometry/00-index.ipynb) - [canonical](part-01-the-nature-of-space/chapter-01-euclidean-and-non-euclidean-geometry/01-euclidean-and-non-euclidean-geometry.ipynb); printed pp. 3-16; PDF pp. 32-45; Introduces intrinsic geometry by contrasting Euclidean, spherical, and hyperbolic behavior through geodesics and angular excess.
# - [Chapter 02: Gaussian Curvature](part-01-the-nature-of-space/chapter-02-gaussian-curvature/00-index.ipynb) - [canonical](part-01-the-nature-of-space/chapter-02-gaussian-curvature/02-gaussian-curvature.ipynb); printed pp. 17-23; PDF pp. 46-52; Motivates Gaussian curvature as the local quantity detected by circles, triangles, and the local Gauss-Bonnet theorem.
# - [Chapter 03: Exercises for Prologue and Act I](part-01-the-nature-of-space/chapter-03-exercises-for-prologue-and-act-i/00-index.ipynb) - [canonical](part-01-the-nature-of-space/chapter-03-exercises-for-prologue-and-act-i/03-exercises-for-prologue-and-act-i.ipynb); printed pp. 24-28; PDF pp. 53-57; Practice set reinforcing ultimate equality, non-Euclidean geometry, and first curvature measurements.
#
# ## Act II: The Metric
#
# Act II: The Metric
#
# - [Open part index](part-02-the-metric/00-part-index.ipynb)
# - [Chapter 04: Mapping Surfaces: The Metric](part-02-the-metric/chapter-04-mapping-surfaces-the-metric/00-index.ipynb) - [canonical](part-02-the-metric/chapter-04-mapping-surfaces-the-metric/04-mapping-surfaces-the-metric.ipynb); printed pp. 31-50; PDF pp. 60-79; Develops the metric as the intrinsic data preserved or distorted by maps, with stereographic projection as the main example.
# - [Chapter 05: The Pseudosphere and the Hyperbolic Plane](part-02-the-metric/chapter-05-the-pseudosphere-and-the-hyperbolic-plane/00-index.ipynb) - [canonical](part-02-the-metric/chapter-05-the-pseudosphere-and-the-hyperbolic-plane/05-the-pseudosphere-and-the-hyperbolic-plane.ipynb); printed pp. 51-64; PDF pp. 80-93; Uses the pseudosphere to connect tractrix geometry, constant negative curvature, and the Poincare models of hyperbolic geometry.
# - [Chapter 06: Isometries and Complex Numbers](part-02-the-metric/chapter-06-isometries-and-complex-numbers/00-index.ipynb) - [canonical](part-02-the-metric/chapter-06-isometries-and-complex-numbers/06-isometries-and-complex-numbers.ipynb); printed pp. 65-82; PDF pp. 94-111; Describes isometries of hyperbolic geometry using Mobius transformations and links the metric story to spacetime geometry.
# - [Chapter 07: Exercises for Act II](part-02-the-metric/chapter-07-exercises-for-act-ii/00-index.ipynb) - [canonical](part-02-the-metric/chapter-07-exercises-for-act-ii/07-exercises-for-act-ii.ipynb); printed pp. 83-93; PDF pp. 112-122; Practice set on metrics, conformal maps, pseudospherical models, Mobius maps, and spacetime geometry.
#
# ## Act III: Curvature
#
# Act III: Curvature
#
# - [Open part index](part-03-curvature/00-part-index.ipynb)
# - [Chapter 08: Curvature of Plane Curves](part-03-curvature/chapter-08-curvature-of-plane-curves/00-index.ipynb) - [canonical](part-03-curvature/chapter-08-curvature-of-plane-curves/08-curvature-of-plane-curves.ipynb); printed pp. 97-105; PDF pp. 126-134; Builds plane-curve curvature from physical, geometric, and infinitesimal viewpoints.
# - [Chapter 09: Curves in 3-Space](part-03-curvature/chapter-09-curves-in-3-space/00-index.ipynb) - [canonical](part-03-curvature/chapter-09-curves-in-3-space/09-curves-in-3-space.ipynb); printed pp. 106-108; PDF pp. 135-137; Extends curve curvature to space curves through osculating planes, torsion, and the Frenet-Serret frame.
# - [Chapter 10: The Principal Curvatures of a Surface](part-03-curvature/chapter-10-the-principal-curvatures-of-a-surface/00-index.ipynb) - [canonical](part-03-curvature/chapter-10-the-principal-curvatures-of-a-surface/10-the-principal-curvatures-of-a-surface.ipynb); printed pp. 109-114; PDF pp. 138-143; Introduces normal curvature of surfaces and the principal curvatures that organize all directional curvatures.
# - [Chapter 11: Geodesics and Geodesic Curvature](part-03-curvature/chapter-11-geodesics-and-geodesic-curvature/00-index.ipynb) - [canonical](part-03-curvature/chapter-11-geodesics-and-geodesic-curvature/11-geodesics-and-geodesic-curvature.ipynb); printed pp. 115-129; PDF pp. 144-158; Separates normal and geodesic curvature and develops geodesics on surfaces of revolution through Clairaut and Kepler analogies.
# - [Chapter 12: The Extrinsic Curvature of a Surface](part-03-curvature/chapter-12-the-extrinsic-curvature-of-a-surface/00-index.ipynb) - [canonical](part-03-curvature/chapter-12-the-extrinsic-curvature-of-a-surface/12-the-extrinsic-curvature-of-a-surface.ipynb); printed pp. 130-137; PDF pp. 159-166; Defines extrinsic curvature through the spherical map and explores the local shapes permitted by principal curvature signs.
# - [Chapter 13: Gauss's Theorema Egregium](part-03-curvature/chapter-13-gauss-s-theorema-egregium/00-index.ipynb) - [canonical](part-03-curvature/chapter-13-gauss-s-theorema-egregium/13-gauss-s-theorema-egregium.ipynb); printed pp. 138-142; PDF pp. 167-171; States and motivates Gauss's discovery that Gaussian curvature is intrinsic despite being defined extrinsically.
# - [Chapter 14: The Curvature of a Spike](part-03-curvature/chapter-14-the-curvature-of-a-spike/00-index.ipynb) - [canonical](part-03-curvature/chapter-14-the-curvature-of-a-spike/14-the-curvature-of-a-spike.ipynb); printed pp. 143-148; PDF pp. 172-177; Uses conical and polyhedral spikes to make curvature concentration and intrinsic/extrinsic agreement visible.
# - [Chapter 15: The Shape Operator](part-03-curvature/chapter-15-the-shape-operator/00-index.ipynb) - [canonical](part-03-curvature/chapter-15-the-shape-operator/15-the-shape-operator.ipynb); printed pp. 149-164; PDF pp. 178-193; Packages surface bending into the shape operator and connects its matrix, eigenstructure, and classical fundamental forms.
# - [Chapter 16: Introduction to the Global Gauss-Bonnet Theorem](part-03-curvature/chapter-16-introduction-to-the-global-gauss-bonnet-theorem/00-index.ipynb) - [canonical](part-03-curvature/chapter-16-introduction-to-the-global-gauss-bonnet-theorem/16-introduction-to-the-global-gauss-bonnet-theorem.ipynb); printed pp. 165-174; PDF pp. 194-203; Introduces the global Gauss-Bonnet theorem by linking total curvature to topology and Euler characteristic.
# - [Chapter 17: First (Heuristic) Proof of the Global Gauss-Bonnet Theorem](part-03-curvature/chapter-17-first-heuristic-proof-of-the-global-gauss-bonnet-theorem/00-index.ipynb) - [canonical](part-03-curvature/chapter-17-first-heuristic-proof-of-the-global-gauss-bonnet-theorem/17-first-heuristic-proof-of-the-global-gauss-bonnet-theorem.ipynb); printed pp. 175-182; PDF pp. 204-211; Gives a first visual proof through total curvature of loops and deformed surfaces.
# - [Chapter 18: Second (Angular Excess) Proof of the Global Gauss-Bonnet Theorem](part-03-curvature/chapter-18-second-angular-excess-proof-of-the-global-gauss-bonnet-theorem/00-index.ipynb) - [canonical](part-03-curvature/chapter-18-second-angular-excess-proof-of-the-global-gauss-bonnet-theorem/18-second-angular-excess-proof-of-the-global-gauss-bonnet-theorem.ipynb); printed pp. 183-194; PDF pp. 212-223; Proves global Gauss-Bonnet through triangulations, Euler characteristic, and angular excess bookkeeping.
# - [Chapter 19: Third (Vector Field) Proof of the Global Gauss-Bonnet Theorem](part-03-curvature/chapter-19-third-vector-field-proof-of-the-global-gauss-bonnet-theorem/00-index.ipynb) - [canonical](part-03-curvature/chapter-19-third-vector-field-proof-of-the-global-gauss-bonnet-theorem/19-third-vector-field-proof-of-the-global-gauss-bonnet-theorem.ipynb); printed pp. 195-218; PDF pp. 224-247; Derives global Gauss-Bonnet from vector-field indices, Poincare-Hopf, and the geometry of singularities.
# - [Chapter 20: Exercises for Act III](part-03-curvature/chapter-20-exercises-for-act-iii/00-index.ipynb) - [canonical](part-03-curvature/chapter-20-exercises-for-act-iii/20-exercises-for-act-iii.ipynb); printed pp. 219-227; PDF pp. 248-256; Practice set on curve curvature, surface curvature, shape operators, Gauss-Bonnet, and vector-field topology.
#
# ## Act IV: Parallel Transport
#
# Act IV: Parallel Transport
#
# - [Open part index](part-04-parallel-transport/00-part-index.ipynb)
# - [Chapter 21: An Historical Puzzle](part-04-parallel-transport/chapter-21-an-historical-puzzle/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-21-an-historical-puzzle/21-an-historical-puzzle.ipynb); printed pp. 231-232; PDF pp. 260-261; Motivates parallel transport through the historical gap between Einstein's 1915 field equation and Levi-Civita's 1917 concept.
# - [Chapter 22: Extrinsic Constructions](part-04-parallel-transport/chapter-22-extrinsic-constructions/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-22-extrinsic-constructions/22-extrinsic-constructions.ipynb); printed pp. 233-239; PDF pp. 262-268; Builds parallel transport extrinsically by projecting motion into the surface and by physical transport analogies.
# - [Chapter 23: Intrinsic Constructions](part-04-parallel-transport/chapter-23-intrinsic-constructions/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-23-intrinsic-constructions/23-intrinsic-constructions.ipynb); printed pp. 240-244; PDF pp. 269-273; Recasts parallel transport intrinsically using geodesic constructions and the covariant derivative.
# - [Chapter 24: Holonomy](part-04-parallel-transport/chapter-24-holonomy/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-24-holonomy/24-holonomy.ipynb); printed pp. 245-251; PDF pp. 274-280; Shows that curvature can be detected by the angle picked up when vectors are parallel transported around loops.
# - [Chapter 25: An Intuitive Geometric Proof of the Theorema Egregium](part-04-parallel-transport/chapter-25-an-intuitive-geometric-proof-of-the-theorema-egregium/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-25-an-intuitive-geometric-proof-of-the-theorema-egregium/25-an-intuitive-geometric-proof-of-the-theorema-egregium.ipynb); printed pp. 252-256; PDF pp. 281-285; Explains the Theorema Egregium through the way the spherical map preserves parallel transport and holonomy.
# - [Chapter 26: Fourth (Holonomy) Proof of the Global Gauss-Bonnet Theorem](part-04-parallel-transport/chapter-26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem/26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem.ipynb); printed pp. 257-260; PDF pp. 286-289; Uses holonomy to give an intrinsic proof of global Gauss-Bonnet.
# - [Chapter 27: Geometric Proof of the Metric Curvature Formula](part-04-parallel-transport/chapter-27-geometric-proof-of-the-metric-curvature-formula/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-27-geometric-proof-of-the-metric-curvature-formula/27-geometric-proof-of-the-metric-curvature-formula.ipynb); printed pp. 261-268; PDF pp. 290-297; Proves the metric curvature formula geometrically by interpreting holonomy as circulation in a map.
# - [Chapter 28: Curvature as a Force between Neighbouring Geodesics](part-04-parallel-transport/chapter-28-curvature-as-a-force-between-neighbouring-geodesics/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-28-curvature-as-a-force-between-neighbouring-geodesics/28-curvature-as-a-force-between-neighbouring-geodesics.ipynb); printed pp. 269-279; PDF pp. 298-308; Interprets curvature dynamically through geodesic deviation and the Jacobi equation.
# - [Chapter 29: Riemann's Curvature](part-04-parallel-transport/chapter-29-riemann-s-curvature/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-29-riemann-s-curvature/29-riemann-s-curvature.ipynb); printed pp. 280-306; PDF pp. 309-335; Generalizes surface curvature to n-manifolds through parallel transport, the Riemann tensor, sectional curvature, Jacobi fields, and Ricci curvature.
# - [Chapter 30: Einstein's Curved Spacetime](part-04-parallel-transport/chapter-30-einstein-s-curved-spacetime/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-30-einstein-s-curved-spacetime/30-einstein-s-curved-spacetime.ipynb); printed pp. 307-333; PDF pp. 336-362; Gives a geometric introduction to general relativity as curvature of spacetime caused by matter and energy.
# - [Chapter 31: Exercises for Act IV](part-04-parallel-transport/chapter-31-exercises-for-act-iv/00-index.ipynb) - [canonical](part-04-parallel-transport/chapter-31-exercises-for-act-iv/31-exercises-for-act-iv.ipynb); printed pp. 334-341; PDF pp. 363-370; Practice set on parallel transport, holonomy, curvature formulas, Jacobi fields, Riemann curvature, and relativity.
#
# ## Act V: Forms
#
# Act V: Forms
#
# - [Open part index](part-05-forms/00-part-index.ipynb)
# - [Chapter 32: 1-Forms](part-05-forms/chapter-32-1-forms/00-index.ipynb) - [canonical](part-05-forms/chapter-32-1-forms/32-1-forms.ipynb); printed pp. 345-359; PDF pp. 374-388; Introduces 1-forms as covectors that measure vectors, with geometric examples from work, gradients, and basis forms.
# - [Chapter 33: Tensors](part-05-forms/chapter-33-tensors/00-index.ipynb) - [canonical](part-05-forms/chapter-33-tensors/33-tensors.ipynb); printed pp. 360-369; PDF pp. 389-398; Develops tensors by valence, components, tensor products, contractions, metric duality, and symmetry.
# - [Chapter 34: 2-Forms](part-05-forms/chapter-34-2-forms/00-index.ipynb) - [canonical](part-05-forms/chapter-34-2-forms/34-2-forms.ipynb); printed pp. 370-385; PDF pp. 399-414; Builds 2-forms as oriented area-measuring objects and relates them to wedge products, flux, and electromagnetic forms.
# - [Chapter 35: 3-Forms](part-05-forms/chapter-35-3-forms/00-index.ipynb) - [canonical](part-05-forms/chapter-35-3-forms/35-3-forms.ipynb); printed pp. 386-391; PDF pp. 415-420; Extends wedge products to volume-measuring 3-forms and clarifies dimension-dependent behavior.
# - [Chapter 36: Differentiation](part-05-forms/chapter-36-differentiation/00-index.ipynb) - [canonical](part-05-forms/chapter-36-differentiation/36-differentiation.ipynb); printed pp. 392-403; PDF pp. 421-432; Introduces the exterior derivative and shows how it unifies differential operations in vector calculus and physics.
# - [Chapter 37: Integration](part-05-forms/chapter-37-integration/00-index.ipynb) - [canonical](part-05-forms/chapter-37-integration/37-integration.ipynb); printed pp. 404-429; PDF pp. 433-458; Develops integration of forms and the generalized Stokes theorem, then connects it to vector calculus, complex analysis, and de Rham cohomology.
# - [Chapter 38: Differential Geometry via Forms](part-05-forms/chapter-38-differential-geometry-via-forms/00-index.ipynb) - [canonical](part-05-forms/chapter-38-differential-geometry-via-forms/38-differential-geometry-via-forms.ipynb); printed pp. 430-464; PDF pp. 459-493; Applies Cartan's exterior calculus to differential geometry, recovering curvature formulas and extending them to n-manifolds and Schwarzschild spacetime.
# - [Chapter 39: Exercises for Act V](part-05-forms/chapter-39-exercises-for-act-v/00-index.ipynb) - [canonical](part-05-forms/chapter-39-exercises-for-act-v/39-exercises-for-act-v.ipynb); printed pp. 465-474; PDF pp. 494-503; Practice set on forms, tensors, exterior calculus, integration theorems, cohomology, and Cartan's geometric machinery.

# %%
# geometry-setup:v1
# Machine-managed by scripts/update_notebook_setup.py. Do not edit this cell by hand.

from __future__ import annotations

import json as _geometry_json
import os as _geometry_os
from pathlib import Path as _GeometryPath
import sys as _geometry_sys

GEOMETRY_SETUP = _geometry_json.loads(
    r"""
{
  "colab_url": "https://colab.research.google.com/github/Rah-Rah-Mitra/Geometry/blob/main/Visual-Differential-Geometry-and-Forms/00-book-index.ipynb",
  "course_dir": "Visual-Differential-Geometry-and-Forms",
  "course_title": "Visual Differential Geometry and Forms",
  "github_url": "https://github.com/Rah-Rah-Mitra/Geometry/blob/main/Visual-Differential-Geometry-and-Forms/00-book-index.ipynb",
  "jupyterlite": true,
  "marker": "geometry-setup:v1",
  "notebook_kind": "book-index",
  "notebook_path": "Visual-Differential-Geometry-and-Forms/00-book-index.ipynb",
  "notebook_title": "Visual Differential Geometry and Forms",
  "repository": {
    "branch": "main",
    "name": "Geometry",
    "owner": "Rah-Rah-Mitra",
    "source_url": "https://github.com/Rah-Rah-Mitra/Geometry"
  },
  "requirements": "requirements/classic.txt",
  "runtime_profile": "classic"
}
"""
)


def _geometry_is_colab():
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def _geometry_is_jupyterlite():
    return _geometry_sys.platform == "emscripten" or "pyodide" in _geometry_sys.modules


def _geometry_add_path(path):
    text = str(path)
    if text not in _geometry_sys.path:
        _geometry_sys.path.insert(0, text)


def _geometry_find_repo_root():
    candidates = []
    env_root = _geometry_os.environ.get("GEOMETRY_REPO_ROOT")
    if env_root:
        candidates.append(_GeometryPath(env_root).expanduser())
    candidates.append(_GeometryPath.cwd())
    for start in candidates:
        start = start.resolve()
        for current in (start, *start.parents):
            if (current / "course-manifest.json").exists() and (
                current / "metadata" / "runtime_profiles.yml"
            ).exists():
                return current
    raise RuntimeError(
        "Could not find the Geometry repository root. Start JupyterLab inside the "
        "Geometry checkout or set GEOMETRY_REPO_ROOT."
    )


def _geometry_run(command):
    import subprocess as _geometry_subprocess

    printable = " ".join(str(part) for part in command)
    print(f"+ {printable}")
    _geometry_subprocess.check_call([str(part) for part in command])


def _geometry_requirement_names(requirements_path, seen=None):
    seen = set() if seen is None else seen
    requirements_path = requirements_path.resolve()
    if requirements_path in seen or not requirements_path.exists():
        return []
    seen.add(requirements_path)
    names = []
    for raw_line in requirements_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.split("#", 1)[0].strip()
        if not line:
            continue
        if line.startswith(("-r ", "--requirement ")):
            _, nested = line.split(maxsplit=1)
            names.extend(_geometry_requirement_names(requirements_path.parent / nested, seen))
            continue
        if line.startswith("-"):
            continue
        name = line
        for separator in ("==", ">=", "<=", "~=", "!=", ">", "<", ";"):
            name = name.split(separator, 1)[0]
        name = name.split("[", 1)[0].strip()
        if name:
            names.append(name)
    return sorted(set(names))


def _geometry_missing_requirements(requirements_path):
    import importlib.metadata as _geometry_metadata

    missing = []
    for name in _geometry_requirement_names(requirements_path):
        try:
            _geometry_metadata.distribution(name)
        except _geometry_metadata.PackageNotFoundError:
            missing.append(name)
    return missing


def _geometry_configured_roots(repo_root):
    course_dir = GEOMETRY_SETUP.get("course_dir")
    course_root = repo_root / course_dir if course_dir else repo_root
    return repo_root, course_root


if _geometry_is_jupyterlite():
    if not GEOMETRY_SETUP["jupyterlite"]:
        raise RuntimeError(
            "This Geometry notebook uses runtime profile "
            f"{GEOMETRY_SETUP['runtime_profile']!r}, which is not enabled for "
            "JupyterLite in course-manifest.json. Open it in Colab or local JupyterLab."
        )
    GEOMETRY_REPO_ROOT = _GeometryPath.cwd()
    GEOMETRY_COURSE_ROOT = (
        GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["course_dir"]
        if GEOMETRY_SETUP.get("course_dir")
        else GEOMETRY_REPO_ROOT
    )
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    if GEOMETRY_COURSE_ROOT.exists():
        _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        "Geometry setup: JupyterLite/Pyodide detected; shell, git, and pip steps "
        "were skipped."
    )
elif _geometry_is_colab():
    repository = GEOMETRY_SETUP["repository"]
    repo_url = repository["source_url"].rstrip("/") + ".git"
    branch = repository["branch"]
    GEOMETRY_REPO_ROOT = _GeometryPath(
        _geometry_os.environ.get("GEOMETRY_REPO_ROOT", "/content/Geometry")
    )
    sparse_paths = ["requirements", "metadata", "scripts", "course-manifest.json", "index.ipynb"]
    if GEOMETRY_SETUP.get("course_dir"):
        sparse_paths.append(GEOMETRY_SETUP["course_dir"])
    if not (GEOMETRY_REPO_ROOT / ".git").exists():
        if GEOMETRY_REPO_ROOT.exists() and any(GEOMETRY_REPO_ROOT.iterdir()):
            raise RuntimeError(
                f"{GEOMETRY_REPO_ROOT} exists but is not a git checkout. "
                "Set GEOMETRY_REPO_ROOT to an empty path or remove the directory."
            )
        _geometry_run(
            [
                "git",
                "clone",
                "--filter=blob:none",
                "--no-checkout",
                "--branch",
                branch,
                repo_url,
                GEOMETRY_REPO_ROOT,
            ]
        )
        _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "init", "--cone"])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "set", *sparse_paths])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "checkout", branch])
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-q", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: Colab ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )
else:
    GEOMETRY_REPO_ROOT = _geometry_find_repo_root()
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    missing = _geometry_missing_requirements(requirements_path)
    skip_install = _geometry_os.environ.get("GEOMETRY_SKIP_INSTALL") == "1"
    if missing and skip_install:
        print(
            "Geometry setup: GEOMETRY_SKIP_INSTALL=1, so missing profile packages "
            f"were not installed: {', '.join(missing)}"
        )
    elif missing:
        print(
            "Geometry setup: installing missing profile packages from "
            f"{requirements_path.relative_to(GEOMETRY_REPO_ROOT)}: {', '.join(missing)}"
        )
        _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: local checkout ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )

# %% [markdown]
# # Chapter 25: An Intuitive Geometric Proof of the Theorema Egregium
#
#             Source span: printed pages 252-256; PDF pages 281-285.
#
#             Canonical notebook: [25-an-intuitive-geometric-proof-of-the-theorema-egregium.ipynb](25-an-intuitive-geometric-proof-of-the-theorema-egregium.ipynb)
#
#             ## Focus
#
#             Explains the Theorema Egregium through the way the spherical map preserves parallel transport and holonomy.
#
#             ## Coverage
#
#             - Recap of curvature and spherical-map notation
# - Story of the preceding curvature constructions
# - Parallel transport under the spherical map
# - Gauss's beautiful theorem revisited
# - Intrinsic explanation of the Theorema Egregium
# - Holonomy as the bridge between extrinsic and intrinsic curvature

# %% [markdown]
# # Chapter 31: Exercises for Act IV
#
#             Source span: printed pages 334-341; PDF pages 363-370.
#
#             Canonical notebook: [31-exercises-for-act-iv.ipynb](31-exercises-for-act-iv.ipynb)
#
#             ## Focus
#
#             Practice set on parallel transport, holonomy, curvature formulas, Jacobi fields, Riemann curvature, and relativity.
#
#             ## Coverage
#
#             - Extrinsic and intrinsic parallel-transport constructions
# - General local Gauss-Bonnet exercises
# - Holonomy and curvature computations
# - Metric curvature formula derivations
# - Jacobi equation and geodesic deviation
# - Riemann tensor identities and symmetries
# - Einstein tensor and relativity applications

# %% [markdown]
# # Chapter 24: Holonomy
#
#             Source span: printed pages 245-251; PDF pages 274-280.
#
#             Canonical notebook: [24-holonomy.ipynb](24-holonomy.ipynb)
#
#             ## Focus
#
#             Shows that curvature can be detected by the angle picked up when vectors are parallel transported around loops.
#
#             ## Coverage
#
#             - Holonomy on the sphere
# - Geodesic triangles and angular excess
# - Holonomy of general geodesic triangles
# - Additivity of holonomy over regions
# - Hyperbolic-plane examples
# - Curvature as infinitesimal rotational failure

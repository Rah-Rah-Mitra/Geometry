# %% [markdown]
# # Chapter 22: Extrinsic Constructions
#
#             Source span: printed pages 233-239; PDF pages 262-268.
#
#             Canonical notebook: [22-extrinsic-constructions.ipynb](22-extrinsic-constructions.ipynb)
#
#             ## Focus
#
#             Builds parallel transport extrinsically by projecting motion into the surface and by physical transport analogies.
#
#             ## Coverage
#
#             - Projecting vectors back into the tangent surface
# - Transport along curves embedded in space
# - Geodesics as curves with self-parallel tangents
# - Parallel transport along geodesics
# - Potato-peeler transport model
# - Extrinsic intuition for a later intrinsic definition

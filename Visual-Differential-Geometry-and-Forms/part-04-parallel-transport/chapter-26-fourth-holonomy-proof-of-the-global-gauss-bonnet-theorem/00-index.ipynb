# %% [markdown]
# # Chapter 26: Fourth (Holonomy) Proof of the Global Gauss-Bonnet Theorem
#
#             Source span: printed pages 257-260; PDF pages 286-289.
#
#             Canonical notebook: [26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem.ipynb](26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem.ipynb)
#
#             ## Focus
#
#             Uses holonomy to give an intrinsic proof of global Gauss-Bonnet.
#
#             ## Coverage
#
#             - Holonomy as accumulated curvature
# - The issue of open-curve holonomy
# - Closing curves by comparing endpoints
# - Hopf's intrinsic proof strategy
# - Global Gauss-Bonnet without extrinsic spherical maps
# - Parallel transport as the organizing mechanism

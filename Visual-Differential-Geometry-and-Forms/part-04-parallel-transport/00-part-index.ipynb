# %% [markdown]
# # Act IV: Parallel Transport
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Act IV: Parallel Transport
#
# ## Chapter 21: An Historical Puzzle
#
# - Chapter index: [chapter-21-an-historical-puzzle/00-index.ipynb](chapter-21-an-historical-puzzle/00-index.ipynb)
# - Canonical notebook: [21-an-historical-puzzle.ipynb](chapter-21-an-historical-puzzle/21-an-historical-puzzle.ipynb)
# - Source span: printed pp. 231-232; PDF pp. 260-261
# - Focus: Motivates parallel transport through the historical gap between Einstein's 1915 field equation and Levi-Civita's 1917 concept.
#
# ## Chapter 22: Extrinsic Constructions
#
# - Chapter index: [chapter-22-extrinsic-constructions/00-index.ipynb](chapter-22-extrinsic-constructions/00-index.ipynb)
# - Canonical notebook: [22-extrinsic-constructions.ipynb](chapter-22-extrinsic-constructions/22-extrinsic-constructions.ipynb)
# - Source span: printed pp. 233-239; PDF pp. 262-268
# - Focus: Builds parallel transport extrinsically by projecting motion into the surface and by physical transport analogies.
#
# ## Chapter 23: Intrinsic Constructions
#
# - Chapter index: [chapter-23-intrinsic-constructions/00-index.ipynb](chapter-23-intrinsic-constructions/00-index.ipynb)
# - Canonical notebook: [23-intrinsic-constructions.ipynb](chapter-23-intrinsic-constructions/23-intrinsic-constructions.ipynb)
# - Source span: printed pp. 240-244; PDF pp. 269-273
# - Focus: Recasts parallel transport intrinsically using geodesic constructions and the covariant derivative.
#
# ## Chapter 24: Holonomy
#
# - Chapter index: [chapter-24-holonomy/00-index.ipynb](chapter-24-holonomy/00-index.ipynb)
# - Canonical notebook: [24-holonomy.ipynb](chapter-24-holonomy/24-holonomy.ipynb)
# - Source span: printed pp. 245-251; PDF pp. 274-280
# - Focus: Shows that curvature can be detected by the angle picked up when vectors are parallel transported around loops.
#
# ## Chapter 25: An Intuitive Geometric Proof of the Theorema Egregium
#
# - Chapter index: [chapter-25-an-intuitive-geometric-proof-of-the-theorema-egregium/00-index.ipynb](chapter-25-an-intuitive-geometric-proof-of-the-theorema-egregium/00-index.ipynb)
# - Canonical notebook: [25-an-intuitive-geometric-proof-of-the-theorema-egregium.ipynb](chapter-25-an-intuitive-geometric-proof-of-the-theorema-egregium/25-an-intuitive-geometric-proof-of-the-theorema-egregium.ipynb)
# - Source span: printed pp. 252-256; PDF pp. 281-285
# - Focus: Explains the Theorema Egregium through the way the spherical map preserves parallel transport and holonomy.
#
# ## Chapter 26: Fourth (Holonomy) Proof of the Global Gauss-Bonnet Theorem
#
# - Chapter index: [chapter-26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem/00-index.ipynb](chapter-26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem/00-index.ipynb)
# - Canonical notebook: [26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem.ipynb](chapter-26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem/26-fourth-holonomy-proof-of-the-global-gauss-bonnet-theorem.ipynb)
# - Source span: printed pp. 257-260; PDF pp. 286-289
# - Focus: Uses holonomy to give an intrinsic proof of global Gauss-Bonnet.
#
# ## Chapter 27: Geometric Proof of the Metric Curvature Formula
#
# - Chapter index: [chapter-27-geometric-proof-of-the-metric-curvature-formula/00-index.ipynb](chapter-27-geometric-proof-of-the-metric-curvature-formula/00-index.ipynb)
# - Canonical notebook: [27-geometric-proof-of-the-metric-curvature-formula.ipynb](chapter-27-geometric-proof-of-the-metric-curvature-formula/27-geometric-proof-of-the-metric-curvature-formula.ipynb)
# - Source span: printed pp. 261-268; PDF pp. 290-297
# - Focus: Proves the metric curvature formula geometrically by interpreting holonomy as circulation in a map.
#
# ## Chapter 28: Curvature as a Force between Neighbouring Geodesics
#
# - Chapter index: [chapter-28-curvature-as-a-force-between-neighbouring-geodesics/00-index.ipynb](chapter-28-curvature-as-a-force-between-neighbouring-geodesics/00-index.ipynb)
# - Canonical notebook: [28-curvature-as-a-force-between-neighbouring-geodesics.ipynb](chapter-28-curvature-as-a-force-between-neighbouring-geodesics/28-curvature-as-a-force-between-neighbouring-geodesics.ipynb)
# - Source span: printed pp. 269-279; PDF pp. 298-308
# - Focus: Interprets curvature dynamically through geodesic deviation and the Jacobi equation.
#
# ## Chapter 29: Riemann's Curvature
#
# - Chapter index: [chapter-29-riemann-s-curvature/00-index.ipynb](chapter-29-riemann-s-curvature/00-index.ipynb)
# - Canonical notebook: [29-riemann-s-curvature.ipynb](chapter-29-riemann-s-curvature/29-riemann-s-curvature.ipynb)
# - Source span: printed pp. 280-306; PDF pp. 309-335
# - Focus: Generalizes surface curvature to n-manifolds through parallel transport, the Riemann tensor, sectional curvature, Jacobi fields, and Ricci curvature.
#
# ## Chapter 30: Einstein's Curved Spacetime
#
# - Chapter index: [chapter-30-einstein-s-curved-spacetime/00-index.ipynb](chapter-30-einstein-s-curved-spacetime/00-index.ipynb)
# - Canonical notebook: [30-einstein-s-curved-spacetime.ipynb](chapter-30-einstein-s-curved-spacetime/30-einstein-s-curved-spacetime.ipynb)
# - Source span: printed pp. 307-333; PDF pp. 336-362
# - Focus: Gives a geometric introduction to general relativity as curvature of spacetime caused by matter and energy.
#
# ## Chapter 31: Exercises for Act IV
#
# - Chapter index: [chapter-31-exercises-for-act-iv/00-index.ipynb](chapter-31-exercises-for-act-iv/00-index.ipynb)
# - Canonical notebook: [31-exercises-for-act-iv.ipynb](chapter-31-exercises-for-act-iv/31-exercises-for-act-iv.ipynb)
# - Source span: printed pp. 334-341; PDF pp. 363-370
# - Focus: Practice set on parallel transport, holonomy, curvature formulas, Jacobi fields, Riemann curvature, and relativity.

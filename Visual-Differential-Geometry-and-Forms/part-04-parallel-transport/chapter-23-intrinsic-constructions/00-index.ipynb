# %% [markdown]
# # Chapter 23: Intrinsic Constructions
#
#             Source span: printed pages 240-244; PDF pages 269-273.
#
#             Canonical notebook: [23-intrinsic-constructions.ipynb](23-intrinsic-constructions.ipynb)
#
#             ## Focus
#
#             Recasts parallel transport intrinsically using geodesic constructions and the covariant derivative.
#
#             ## Coverage
#
#             - Parallel transport via infinitesimal geodesic moves
# - Intrinsic construction without ambient space
# - The covariant derivative as intrinsic change
# - Comparison with ordinary derivatives
# - How transported vectors remain tangent
# - Preparation for holonomy and curvature

# %% [markdown]
# # Chapter 09: Curves in 3-Space
#
#             Source span: printed pages 106-108; PDF pages 135-137.
#
#             Canonical notebook: [09-curves-in-3-space.ipynb](09-curves-in-3-space.ipynb)
#
#             ## Focus
#
#             Extends curve curvature to space curves through osculating planes, torsion, and the Frenet-Serret frame.
#
#             ## Coverage
#
#             - Osculating plane of a twisting curve
# - Torsion as rotation of the osculating plane
# - Tangent, normal, and binormal vectors
# - Curvature vector for unit-speed motion
# - Physical straw-and-wire model of the Frenet frame
# - Frenet-Serret equations as frame rotation

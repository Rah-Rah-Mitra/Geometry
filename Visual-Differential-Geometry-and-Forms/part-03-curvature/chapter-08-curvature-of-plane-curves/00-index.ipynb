# %% [markdown]
# # Chapter 08: Curvature of Plane Curves
#
#             Source span: printed pages 97-105; PDF pages 126-134.
#
#             Canonical notebook: [08-curvature-of-plane-curves.ipynb](08-curvature-of-plane-curves.ipynb)
#
#             ## Focus
#
#             Builds plane-curve curvature from physical, geometric, and infinitesimal viewpoints.
#
#             ## Coverage
#
#             - Curvature as force needed to bend motion
# - The circle of curvature
# - Newton's curvature formula
# - Curvature as rate of tangent turning
# - Arc-length parametrization and unit tangent motion
# - The tractrix as a worked example

# %% [markdown]
# # Chapter 12: The Extrinsic Curvature of a Surface
#
#             Source span: printed pages 130-137; PDF pages 159-166.
#
#             Canonical notebook: [12-the-extrinsic-curvature-of-a-surface.ipynb](12-the-extrinsic-curvature-of-a-surface.ipynb)
#
#             ## Focus
#
#             Defines extrinsic curvature through the spherical map and explores the local shapes permitted by principal curvature signs.
#
#             ## Coverage
#
#             - The Gauss or spherical map
# - Area distortion under the spherical map
# - Extrinsic curvature as product of principal curvatures
# - Elliptic, hyperbolic, parabolic, and planar points
# - Possible local surface shapes
# - Relation between sign of curvature and surface bending

# %% [markdown]
# # Chapter 13: Gauss's Theorema Egregium
#
#             Source span: printed pages 138-142; PDF pages 167-171.
#
#             Canonical notebook: [13-gauss-s-theorema-egregium.ipynb](13-gauss-s-theorema-egregium.ipynb)
#
#             ## Focus
#
#             States and motivates Gauss's discovery that Gaussian curvature is intrinsic despite being defined extrinsically.
#
#             ## Coverage
#
#             - Gauss's 1816 beautiful theorem
# - Gauss's 1827 Theorema Egregium
# - Intrinsic invariance of Gaussian curvature
# - Curvature preserved by bending without stretching
# - Consequences for maps and surface deformation
# - Historical importance of the theorem

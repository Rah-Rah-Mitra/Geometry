# %% [markdown]
# # Chapter 18: Second (Angular Excess) Proof of the Global Gauss-Bonnet Theorem
#
#             Source span: printed pages 183-194; PDF pages 212-223.
#
#             Canonical notebook: [18-second-angular-excess-proof-of-the-global-gauss-bonnet-theorem.ipynb](18-second-angular-excess-proof-of-the-global-gauss-bonnet-theorem.ipynb)
#
#             ## Focus
#
#             Proves global Gauss-Bonnet through triangulations, Euler characteristic, and angular excess bookkeeping.
#
#             ## Coverage
#
#             - Euler characteristic as V - E + F
# - Euler's polyhedral formula
# - Cauchy's proof by flattening polyhedra
# - Polygonal nets and their Euler characteristic
# - Legendre's proof of the polyhedral formula
# - Adding handles and changing genus
# - Angular-excess proof of global Gauss-Bonnet

# %% [markdown]
# # Chapter 11: Geodesics and Geodesic Curvature
#
#             Source span: printed pages 115-129; PDF pages 144-158.
#
#             Canonical notebook: [11-geodesics-and-geodesic-curvature.ipynb](11-geodesics-and-geodesic-curvature.ipynb)
#
#             ## Focus
#
#             Separates normal and geodesic curvature and develops geodesics on surfaces of revolution through Clairaut and Kepler analogies.
#
#             ## Coverage
#
#             - Geodesic curvature versus normal curvature
# - Meusnier's theorem
# - Geodesics as intrinsically straight curves
# - Intrinsic and extrinsic measurements of geodesic curvature
# - Sticky-tape construction revisited
# - Clairaut's theorem on surfaces of revolution
# - Kepler's second law and hyperbolic geodesics

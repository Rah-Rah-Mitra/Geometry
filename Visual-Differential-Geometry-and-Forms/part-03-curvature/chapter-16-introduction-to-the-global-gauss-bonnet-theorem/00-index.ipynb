# %% [markdown]
# # Chapter 16: Introduction to the Global Gauss-Bonnet Theorem
#
#             Source span: printed pages 165-174; PDF pages 194-203.
#
#             Canonical notebook: [16-introduction-to-the-global-gauss-bonnet-theorem.ipynb](16-introduction-to-the-global-gauss-bonnet-theorem.ipynb)
#
#             ## Focus
#
#             Introduces the global Gauss-Bonnet theorem by linking total curvature to topology and Euler characteristic.
#
#             ## Coverage
#
#             - Basic topology and statement of the theorem
# - Total curvature of spheres and tori
# - Genus and surface classification intuition
# - Pancake, bagel, and bridge visualizations
# - Topological degree of the spherical map
# - Historical framing of the theorem

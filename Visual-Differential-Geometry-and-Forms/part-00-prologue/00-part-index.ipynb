# %% [markdown]
# # Prologue
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Front Matter
#
# ## Prologue: Prologue
#
# - Chapter index: [prologue/00-index.ipynb](prologue/00-index.ipynb)
# - Canonical notebook: [prologue.ipynb](prologue/prologue.ipynb)
# - Source span: printed pp. xvii-xxiii; PDF pp. 18-24
# - Focus: Frames the book as a geometric alternative to unilluminating symbolic calculation and explains the five-act structure.

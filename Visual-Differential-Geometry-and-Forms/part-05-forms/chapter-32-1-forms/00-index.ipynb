# %% [markdown]
# # Chapter 32: 1-Forms
#
#             Source span: printed pages 345-359; PDF pages 374-388.
#
#             Canonical notebook: [32-1-forms.ipynb](32-1-forms.ipynb)
#
#             ## Focus
#
#             Introduces 1-forms as covectors that measure vectors, with geometric examples from work, gradients, and basis forms.
#
#             ## Coverage
#
#             - Definition and visualization of a 1-form
# - Gravitational work as a 1-form
# - Topographic maps and gradient 1-forms
# - Row vectors and Dirac bras
# - Basis 1-forms and components
# - The differential df as a 1-form
# - Geometric addition of 1-forms

# %% [markdown]
# # Chapter 34: 2-Forms
#
#             Source span: printed pages 370-385; PDF pages 399-414.
#
#             Canonical notebook: [34-2-forms.ipynb](34-2-forms.ipynb)
#
#             ## Focus
#
#             Builds 2-forms as oriented area-measuring objects and relates them to wedge products, flux, and electromagnetic forms.
#
#             ## Coverage
#
#             - Definition of 2-forms and p-forms
# - Area 2-form as core example
# - Wedge product of 1-forms
# - Polar-coordinate area form
# - Basis 2-forms and projection areas
# - Flux forms in three dimensions
# - Vector product versus wedge product
# - Faraday and Maxwell electromagnetic 2-forms

# %% [markdown]
# # Chapter 36: Differentiation
#
#             Source span: printed pages 392-403; PDF pages 421-432.
#
#             Canonical notebook: [36-differentiation.ipynb](36-differentiation.ipynb)
#
#             ## Focus
#
#             Introduces the exterior derivative and shows how it unifies differential operations in vector calculus and physics.
#
#             ## Coverage
#
#             - Exterior derivative of 1-forms
# - Exterior derivative of 2-forms and p-forms
# - Leibniz rule for forms
# - Closed and exact forms
# - The fundamental identity d squared equals zero
# - Cauchy-Riemann equations via forms
# - Gradient, curl, and divergence in form language
# - Maxwell's equations

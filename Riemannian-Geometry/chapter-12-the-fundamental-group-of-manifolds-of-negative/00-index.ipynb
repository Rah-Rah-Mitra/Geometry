# %% [markdown]
# # Chapter 12: The Fundamental Group of Manifolds of Negative Curvature
#
# Source span: printed pages `253-264`.
#
# Focus: Closed geodesics, Preissmann theorem, and topology of negative curvature.
#
# Canonical notebook: [`12-the-fundamental-group-of-manifolds-of.ipynb`](12-the-fundamental-group-of-manifolds-of.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

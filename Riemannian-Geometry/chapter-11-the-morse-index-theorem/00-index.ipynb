# %% [markdown]
# # Chapter 11: The Morse Index Theorem
#
# Source span: printed pages `242-252`.
#
# Focus: Index form, index theorem, and geodesic variation structure.
#
# Canonical notebook: [`11-the-morse-index-theorem.ipynb`](11-the-morse-index-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

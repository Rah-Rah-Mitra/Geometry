# %% [markdown]
# # Riemannian Geometry
#
# Standalone visualization-first notebook course.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 0 | Differentiable Manifolds | 1-34 | [`00-differentiable-manifolds.ipynb`](chapter-00-differentiable-manifolds/00-differentiable-manifolds.ipynb) |
# | Chapter 1 | Riemannian Metrics | 35-47 | [`01-riemannian-metrics.ipynb`](chapter-01-riemannian-metrics/01-riemannian-metrics.ipynb) |
# | Chapter 2 | Affine Connections; Riemannian Connections | 48-59 | [`02-affine-connections-riemannian-connections.ipynb`](chapter-02-affine-connections-riemannian-connections/02-affine-connections-riemannian-connections.ipynb) |
# | Chapter 3 | Geodesics; Convex Neighborhoods | 60-87 | [`03-geodesics-convex-neighborhoods.ipynb`](chapter-03-geodesics-convex-neighborhoods/03-geodesics-convex-neighborhoods.ipynb) |
# | Chapter 4 | Curvature | 88-109 | [`04-curvature.ipynb`](chapter-04-curvature/04-curvature.ipynb) |
# | Chapter 5 | Jacobi Fields | 110-123 | [`05-jacobi-fields.ipynb`](chapter-05-jacobi-fields/05-jacobi-fields.ipynb) |
# | Chapter 6 | Isometric Immersions | 124-143 | [`06-isometric-immersions.ipynb`](chapter-06-isometric-immersions/06-isometric-immersions.ipynb) |
# | Chapter 7 | Complete Manifolds; Hopf-Rinow and Hadamard Theorems | 144-154 | [`07-complete-manifolds-hopf-rinow-and-hadamard.ipynb`](chapter-07-complete-manifolds-hopf-rinow-and-hadamard-theorems/07-complete-manifolds-hopf-rinow-and-hadamard.ipynb) |
# | Chapter 8 | Spaces of Constant Curvature | 155-190 | [`08-spaces-of-constant-curvature.ipynb`](chapter-08-spaces-of-constant-curvature/08-spaces-of-constant-curvature.ipynb) |
# | Chapter 9 | Variations of Energy | 191-209 | [`09-variations-of-energy.ipynb`](chapter-09-variations-of-energy/09-variations-of-energy.ipynb) |
# | Chapter 10 | The Rauch Comparison Theorem | 210-241 | [`10-the-rauch-comparison-theorem.ipynb`](chapter-10-the-rauch-comparison-theorem/10-the-rauch-comparison-theorem.ipynb) |
# | Chapter 11 | The Morse Index Theorem | 242-252 | [`11-the-morse-index-theorem.ipynb`](chapter-11-the-morse-index-theorem/11-the-morse-index-theorem.ipynb) |
# | Chapter 12 | The Fundamental Group of Manifolds of Negative Curvature | 253-264 | [`12-the-fundamental-group-of-manifolds-of.ipynb`](chapter-12-the-fundamental-group-of-manifolds-of-negative/12-the-fundamental-group-of-manifolds-of.ipynb) |
# | Chapter 13 | The Sphere Theorem | 265-285 | [`13-the-sphere-theorem.ipynb`](chapter-13-the-sphere-theorem/13-the-sphere-theorem.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text(encoding='utf-8'))
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Riemannian Geometry: 14 canonical units

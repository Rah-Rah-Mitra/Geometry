# %% [markdown]
# # Chapter 6: Isometric Immersions
#
# Source span: printed pages `124-143`.
#
# Focus: Second fundamental form, fundamental equations, and immersion geometry.
#
# Canonical notebook: [`06-isometric-immersions.ipynb`](06-isometric-immersions.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

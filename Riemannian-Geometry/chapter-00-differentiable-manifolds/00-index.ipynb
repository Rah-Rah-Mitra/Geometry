# %% [markdown]
# # Chapter 0: Differentiable Manifolds
#
# Source span: printed pages `1-34`.
#
# Focus: Differentiable manifolds, tangent spaces, immersions, embeddings, examples, orientation, vector fields, brackets, and topology.
#
# Canonical notebook: [`00-differentiable-manifolds.ipynb`](00-differentiable-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 1: Riemannian Metrics
#
# Source span: printed pages `35-47`.
#
# Focus: Riemannian metrics, length, distance, and basic metric structures on manifolds.
#
# Canonical notebook: [`01-riemannian-metrics.ipynb`](01-riemannian-metrics.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

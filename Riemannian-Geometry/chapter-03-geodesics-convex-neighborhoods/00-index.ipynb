# %% [markdown]
# # Chapter 3: Geodesics; Convex Neighborhoods
#
# Source span: printed pages `60-87`.
#
# Focus: Geodesic flow, minimizing properties, exponential map, and convex neighborhoods.
#
# Canonical notebook: [`03-geodesics-convex-neighborhoods.ipynb`](03-geodesics-convex-neighborhoods.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

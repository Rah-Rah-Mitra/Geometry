# %% [markdown]
# # Chapter 9: Variations of Energy
#
# Source span: printed pages `191-209`.
#
# Focus: First and second variation of energy, Bonnet-Myers theorem, and Synge-Weinstein theorem.
#
# Canonical notebook: [`09-variations-of-energy.ipynb`](09-variations-of-energy.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

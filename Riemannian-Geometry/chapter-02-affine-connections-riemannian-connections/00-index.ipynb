# %% [markdown]
# # Chapter 2: Affine Connections; Riemannian Connections
#
# Source span: printed pages `48-59`.
#
# Focus: Affine connections, Riemannian connections, covariant derivatives, torsion, and compatibility.
#
# Canonical notebook: [`02-affine-connections-riemannian-connections.ipynb`](02-affine-connections-riemannian-connections.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

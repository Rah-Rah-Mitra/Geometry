# %% [markdown]
# # Chapter 8: Spaces of Constant Curvature
#
# Source span: printed pages `155-190`.
#
# Focus: Cartan metric determination, hyperbolic space, space forms, and hyperbolic isometries.
#
# Canonical notebook: [`08-spaces-of-constant-curvature.ipynb`](08-spaces-of-constant-curvature.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

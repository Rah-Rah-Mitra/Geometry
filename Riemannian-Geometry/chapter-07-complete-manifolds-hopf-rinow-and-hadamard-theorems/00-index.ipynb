# %% [markdown]
# # Chapter 7: Complete Manifolds; Hopf-Rinow and Hadamard Theorems
#
# Source span: printed pages `144-154`.
#
# Focus: Completeness, Hopf-Rinow theorem, Hadamard theorem, and global consequences.
#
# Canonical notebook: [`07-complete-manifolds-hopf-rinow-and-hadamard.ipynb`](07-complete-manifolds-hopf-rinow-and-hadamard.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

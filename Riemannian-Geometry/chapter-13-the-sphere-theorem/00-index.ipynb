# %% [markdown]
# # Chapter 13: The Sphere Theorem
#
# Source span: printed pages `265-285`.
#
# Focus: Cut locus, injectivity radius estimates, sphere theorem, and further developments.
#
# Canonical notebook: [`13-the-sphere-theorem.ipynb`](13-the-sphere-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

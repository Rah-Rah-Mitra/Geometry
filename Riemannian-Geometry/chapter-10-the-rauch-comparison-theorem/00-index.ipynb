# %% [markdown]
# # Chapter 10: The Rauch Comparison Theorem
#
# Source span: printed pages `210-241`.
#
# Focus: Rauch theorem, index lemma applications, focal points, and comparison extensions.
#
# Canonical notebook: [`10-the-rauch-comparison-theorem.ipynb`](10-the-rauch-comparison-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

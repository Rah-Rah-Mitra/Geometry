# %% [markdown]
# # Appendix B: Transcendental Methods
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 438-448; PDF pages 453-463.
#
# Canonical notebook: [appendix-b-transcendental-methods.ipynb](appendix-b-transcendental-methods.ipynb)
#
# ## Focus
#
# The bridge from algebraic varieties over the complex numbers to analytic spaces, comparison theorems, Kahler geometry, and the exponential sequence.
#
# ## Section Map
#
# - Section 1: The Associated Complex Analytic Space (printed p. 438; PDF p. 453)
# - Section 2: Comparison of the Algebraic and Analytic Categories (printed p. 440; PDF p. 455)
# - Section 3: When is a Compact Complex Manifold Algebraic? (printed p. 441; PDF p. 456)
# - Section 4: Kahler Manifolds (printed p. 445; PDF p. 460)
# - Section 5: The Exponential Sequence (printed p. 446; PDF p. 461)
#
# ## Visual Storyboard
#
# - Algebraic-to-analytic comparison ladder
# - Sheaf comparison square for coherent data
# - Kahler form local matrix positivity panel
# - Exponential sequence winding-and-Chern-class diagram
#
# ## Checks
#
# - transition from additive to multiplicative cocycle respects exponentiation in a toy cover
# - Hermitian sample matrix is positive definite
# - first Chern class ledger is integral in the toy example
# - analytic and algebraic section dimensions are matched in a finite model
#
# ## Chapter Terms
#
# - complex analytic space
# - GAGA
# - Kahler manifold
# - exponential sequence
# - Chern class

# %%
from pathlib import Path
notebook = Path('appendix-b-transcendental-methods.ipynb')
artifact_root = Path('../artifacts/appendix-b')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

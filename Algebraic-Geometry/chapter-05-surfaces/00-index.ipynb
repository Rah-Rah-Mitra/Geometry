# %% [markdown]
# # Chapter V: Surfaces
#
# Source orientation: printed pages 356-423; source pages 371-438.
#
# Canonical notebook: [05-surfaces.ipynb](05-surfaces.ipynb)
#
# Nonsingular projective surfaces through intersection forms, ruled surfaces, blowups, cubic-surface incidence, birational transformations, and classification invariants.

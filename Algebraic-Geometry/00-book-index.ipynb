# %% [markdown]
# # Algebraic Geometry
#
# Author: Robin Hartshorne. Series: Graduate Texts in Mathematics 52.
#
# This is a standalone visualization-first notebook course with original prose, generated diagrams, interactive HTML artifacts, exact symbolic checks, and local audit scripts. The local PDF is used only for source orientation and is not reproduced.
#
# ## Course Map
#
# - [Chapter I: Varieties](chapter-01-varieties/00-index.ipynb) - [canonical](chapter-01-varieties/01-varieties.ipynb); printed pp. 1-59; PDF pp. 16-74; Classical varieties as solution sets, the algebra-geometry dictionary, Zariski topology, rational maps, blowups, tangent spaces, and degree.
# - [Chapter II: Schemes](chapter-02-schemes/00-index.ipynb) - [canonical](chapter-02-schemes/02-schemes.ipynb); printed pp. 60-200; PDF pp. 75-215; Schemes as locally ringed spaces assembled from affine spectra, with nilpotents, generic points, sheaves, morphisms, divisors, differentials, and formal neighborhoods.
# - [Chapter III: Cohomology](chapter-03-cohomology/00-index.ipynb) - [canonical](chapter-03-cohomology/03-cohomology.ipynb); printed pp. 201-292; PDF pp. 216-307; Cohomology as a measurement of failed gluing, then as a computational engine for projective space, duality, direct images, semicontinuity, flatness, and smoothness.
# - [Chapter IV: Curves](chapter-04-curves/00-index.ipynb) - [canonical](chapter-04-curves/04-curves.ipynb); printed pp. 293-355; PDF pp. 308-370; Nonsingular projective curves through divisors, Riemann-Roch, finite maps, ramification, elliptic group law, canonical maps, and projective models.
# - [Chapter V: Surfaces](chapter-05-surfaces/00-index.ipynb) - [canonical](chapter-05-surfaces/05-surfaces.ipynb); printed pp. 356-423; PDF pp. 371-438; Nonsingular projective surfaces through intersection forms, ruled surfaces, blowups, cubic-surface incidence, birational transformations, and classification invariants.
# - [Appendix A: Intersection Theory](appendix-a-intersection-theory/00-index.ipynb) - [canonical](appendix-a-intersection-theory/appendix-a-intersection-theory.ipynb); printed pp. 424-437; PDF pp. 439-452; Intersection theory beyond surfaces: cycles, rational equivalence, Chow rings, Chern classes, and Riemann-Roch as a structured accounting system.
# - [Appendix B: Transcendental Methods](appendix-b-transcendental-methods/00-index.ipynb) - [canonical](appendix-b-transcendental-methods/appendix-b-transcendental-methods.ipynb); printed pp. 438-448; PDF pp. 453-463; The bridge from algebraic varieties over the complex numbers to analytic spaces, comparison theorems, Kahler geometry, and the exponential sequence.
# - [Appendix C: The Weil Conjectures](appendix-c-weil-conjectures/00-index.ipynb) - [canonical](appendix-c-weil-conjectures/appendix-c-weil-conjectures.ipynb); printed pp. 449-458; PDF pp. 464-473; Finite-field point counting, zeta functions, cohomological explanations, Frobenius eigenvalues, and the shape of the Weil conjectures.
#
# ## Source Map Notes
#
# - PDF spans are 1-based physical PDF pages.
# - The source PDF has 511 physical pages.
# - Main-matter printed page 1 is PDF page 16, so printed page n maps to PDF page n + 15.
# - Notebook prose, examples, diagrams, exercises, and artifacts are original and do not copy the source.
#
# ## Auxiliary Source Apparatus
#
# - Introduction: printed xiii-xvi; PDF pp. 11-15.
# - Bibliography: printed 459-469; PDF pp. 474-484.
# - Results from Algebra: printed 470-471; PDF pp. 485-486.
# - Glossary of Notations: printed 472-477; PDF pp. 487-492.
# - Index: printed 478-end; PDF pp. 493-511.

# %%
from pathlib import Path
root = Path.cwd()
notebooks = [
    root / 'chapter-01-varieties' / '01-varieties.ipynb',
    root / 'chapter-02-schemes' / '02-schemes.ipynb',
    root / 'chapter-03-cohomology' / '03-cohomology.ipynb',
    root / 'chapter-04-curves' / '04-curves.ipynb',
    root / 'chapter-05-surfaces' / '05-surfaces.ipynb',
    root / 'appendix-a-intersection-theory' / 'appendix-a-intersection-theory.ipynb',
    root / 'appendix-b-transcendental-methods' / 'appendix-b-transcendental-methods.ipynb',
    root / 'appendix-c-weil-conjectures' / 'appendix-c-weil-conjectures.ipynb',
]
missing = [path for path in notebooks if not path.exists()]
assert not missing, missing
len(notebooks)

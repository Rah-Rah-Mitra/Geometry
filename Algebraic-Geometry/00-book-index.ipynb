# %% [markdown]
# # Algebraic Geometry
#
# Standalone visualization-first notebook course.
#
# - [Chapter I: Varieties](chapter-01-varieties/00-index.ipynb)
# - [Chapter II: Schemes](chapter-02-schemes/00-index.ipynb)
# - [Chapter III: Cohomology](chapter-03-cohomology/00-index.ipynb)
# - [Chapter IV: Curves](chapter-04-curves/00-index.ipynb)
# - [Chapter V: Surfaces](chapter-05-surfaces/00-index.ipynb)
# - [Appendix A: Intersection Theory](appendix-a-intersection-theory/00-index.ipynb)
# - [Appendix B: Transcendental Methods](appendix-b-transcendental-methods/00-index.ipynb)
# - [Appendix C: The Weil Conjectures](appendix-c-weil-conjectures/00-index.ipynb)

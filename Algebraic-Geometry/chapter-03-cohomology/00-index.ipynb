# %% [markdown]
# # Chapter III: Cohomology
#
# Source orientation: printed pages 201-292; source pages 216-307.
#
# Canonical notebook: [03-cohomology.ipynb](03-cohomology.ipynb)
#
# Cohomology as a measurement of failed gluing, then as a computational engine for projective space, duality, direct images, semicontinuity, flatness, and smoothness.

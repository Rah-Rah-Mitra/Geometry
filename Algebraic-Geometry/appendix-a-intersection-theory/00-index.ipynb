# %% [markdown]
# # Appendix A: Intersection Theory
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 424-437; PDF pages 439-452.
#
# Canonical notebook: [appendix-a-intersection-theory.ipynb](appendix-a-intersection-theory.ipynb)
#
# ## Focus
#
# Intersection theory beyond surfaces: cycles, rational equivalence, Chow rings, Chern classes, and Riemann-Roch as a structured accounting system.
#
# ## Section Map
#
# - Section 1: Intersection Theory (printed p. 425; PDF p. 440)
# - Section 2: Properties of the Chow Ring (printed p. 428; PDF p. 443)
# - Section 3: Chern Classes (printed p. 429; PDF p. 444)
# - Section 4: The Riemann-Roch Theorem (printed p. 431; PDF p. 446)
# - Section 5: Complements and Generalizations (printed p. 434; PDF p. 449)
#
# ## Visual Storyboard
#
# - Cycle dimension ladder and push-pull bookkeeping
# - Chow ring multiplication table for projective space
# - Chern class total-polynomial dashboard
# - Riemann-Roch term ledger for a line bundle
#
# ## Checks
#
# - projective-space Chow relation truncates powers above dimension
# - Chern classes multiply in short exact sequence examples
# - top-degree extraction matches intersection number
# - Euler characteristic ledger matches a sample Hilbert polynomial
#
# ## Chapter Terms
#
# - cycle
# - Chow ring
# - Chern class
# - Riemann-Roch
# - intersection product

# %%
from pathlib import Path
notebook = Path('appendix-a-intersection-theory.ipynb')
artifact_root = Path('../artifacts/appendix-a')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

# %% [markdown]
# # Appendix C: The Weil Conjectures
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 449-458; PDF pages 464-473.
#
# Canonical notebook: [appendix-c-weil-conjectures.ipynb](appendix-c-weil-conjectures.ipynb)
#
# ## Focus
#
# Finite-field point counting, zeta functions, cohomological explanations, Frobenius eigenvalues, and the shape of the Weil conjectures.
#
# ## Section Map
#
# - Section 1: The Zeta Function and the Weil Conjectures (printed p. 449; PDF p. 464)
# - Section 2: History of Work on the Weil Conjectures (printed p. 451; PDF p. 466)
# - Section 3: The l-adic Cohomology (printed p. 453; PDF p. 468)
# - Section 4: Cohomological Interpretation of the Weil Conjectures (printed p. 454; PDF p. 469)
#
# ## Visual Storyboard
#
# - Finite-field point-count table for projective examples
# - Zeta function coefficient dashboard
# - Frobenius eigenvalue circle schematic
# - Cohomological trace formula dependency graph
#
# ## Checks
#
# - P1 over Fq has q+1 projective points
# - sample curve point counts feed the zeta exponential coefficients
# - reciprocal-root magnitudes are marked against the expected weight
# - trace formula signs match cohomological degree in the toy model
#
# ## Chapter Terms
#
# - finite field
# - zeta function
# - Weil conjectures
# - Frobenius
# - l-adic cohomology
# - trace formula

# %%
from pathlib import Path
notebook = Path('appendix-c-weil-conjectures.ipynb')
artifact_root = Path('../artifacts/appendix-c')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

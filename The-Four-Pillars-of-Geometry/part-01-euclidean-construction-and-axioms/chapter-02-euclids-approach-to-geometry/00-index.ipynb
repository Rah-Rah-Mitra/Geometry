# %% [markdown]
# # Chapter 2: Euclid's approach to geometry
#
# - Source span: printed pages 20-45; PDF pages 30-55; sections 2.1-2.9.
# - Focus: Parallel axiom, congruence, area dissection, Pythagorean theorem, Thales theorem, circle angles, regular pentagon construction.
# - Chapter question: How do angle, congruence, and area cooperate to make Euclid's theorems feel inevitable rather than memorized?
# - Canonical notebook: [euclids-approach-to-geometry.ipynb](euclids-approach-to-geometry.ipynb)
#
# ## Visual spine
#
# - parallel axiom angle cases
# - triangle and polygon angle sums
# - area-preserving shear
# - Pythagorean area chain
# - circle angles and pentagon
#
# Back to [book index](../../00-book-index.ipynb).

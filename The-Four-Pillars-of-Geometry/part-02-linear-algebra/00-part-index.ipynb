# %% [markdown]
# # Part 2: Linear algebra
#
# Coordinates and vectors turn geometric claims into equations, dot products, matrices, and invariant checks.
#
# ## Chapters
#
# - Chapter 3: [Coordinates](chapter-03-coordinates/00-index.ipynb) - Number line/plane, line equations, distances, circle-line intersections, angle/slope, isometry classifier, three-reflections theorem.
# - Chapter 4: [Vectors and Euclidean spaces](chapter-04-vectors-and-euclidean-spaces/00-index.ipynb) - Vector operations, linear independence, centroids, inner products, Cauchy-Schwarz, triangle inequality, rotations via matrices and complex numbers.
#
# Back to [book index](../00-book-index.ipynb).

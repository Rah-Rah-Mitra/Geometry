# %% [markdown]
# # Chapter 4: Vectors and Euclidean spaces
#
# - Source span: printed pages 65-87; PDF pages 75-97; sections 4.1-4.8.
# - Focus: Vector operations, linear independence, centroids, inner products, Cauchy-Schwarz, triangle inequality, rotations via matrices and complex numbers.
# - Chapter question: How do vectors let us treat length, angle, midpoint, and rotation as portable operations in any dimension?
# - Canonical notebook: [vectors-and-euclidean-spaces.ipynb](vectors-and-euclidean-spaces.ipynb)
#
# ## Visual spine
#
# - parallelogram rule
# - scalar dilation and direction
# - centroids as averages
# - inner product geometry
# - rotation matrix and complex multiplication
#
# Back to [book index](../../00-book-index.ipynb).

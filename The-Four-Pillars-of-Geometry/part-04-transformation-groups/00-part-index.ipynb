# %% [markdown]
# # Part 4: Transformation groups
#
# Geometries as spaces with groups of transformations, including spherical, projective, quaternionic, and hyperbolic models.
#
# ## Chapters
#
# - Chapter 7: [Transformations](chapter-07-transformations/00-index.ipynb) - Isometry groups, affine/vector transformations, projective-line maps, spherical geometry, rotations, quaternions, finite rotation groups, S^3 and RP^3.
# - Chapter 8: [Non-Euclidean geometry](chapter-08-non-euclidean-geometry/00-index.ipynb) - Upper-half-plane/disk models, Mobius transformations, reflections, hyperbolic geodesics, distance heatmaps, conformal grids, reflection factorizations.
#
# Back to [book index](../00-book-index.ipynb).

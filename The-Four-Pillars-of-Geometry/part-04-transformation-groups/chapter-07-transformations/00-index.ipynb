# %% [markdown]
# # Chapter 7: Transformations
#
# - Source span: printed pages 143-173; PDF pages 153-183; sections 7.1-7.9.
# - Focus: Isometry groups, affine/vector transformations, projective-line maps, spherical geometry, rotations, quaternions, finite rotation groups, S^3 and RP^3.
# - Chapter question: If a geometry is known by its transformations, which quantities are each transformation group protecting?
# - Canonical notebook: [transformations.ipynb](transformations.ipynb)
#
# ## Visual spine
#
# - group invariants map
# - plane isometry composition
# - linear grid deformation
# - sphere and great-circle rotations
# - quaternion rotation cover
#
# Back to [book index](../../00-book-index.ipynb).

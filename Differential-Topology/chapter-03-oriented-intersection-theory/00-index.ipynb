# %% [markdown]
# # Chapter 3: Oriented Intersection Theory
#
# Source span: printed pages `94-150`.
#
# Canonical notebook: [`03-oriented-intersection-theory.ipynb`](03-oriented-intersection-theory.ipynb).
#
# Focus: Orientation, oriented intersection number, Lefschetz fixed point theorem, vector fields, Poincare-Hopf, Hopf degree, and Euler characteristic.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Topology

# %% [markdown]
# # Chapter 1: Manifolds and Smooth Maps
#
# Source span: printed pages `1-56`.
#
# Focus: Definitions, derivatives, inverse function theorem, immersions, submersions, transversality, homotopy, Sard theorem, and embeddings.
#
# Canonical notebook: [`01-manifolds-and-smooth-maps.ipynb`](01-manifolds-and-smooth-maps.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

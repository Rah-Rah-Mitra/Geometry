# %% [markdown]
# # Differential Topology
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Manifolds and Smooth Maps | 1-56 | [`01-manifolds-and-smooth-maps.ipynb`](chapter-01-manifolds-and-smooth-maps/01-manifolds-and-smooth-maps.ipynb) |
# | Chapter 2 | Transversality and Intersection | 57-93 | [`02-transversality-and-intersection.ipynb`](chapter-02-transversality-and-intersection/02-transversality-and-intersection.ipynb) |
# | Chapter 3 | Oriented Intersection Theory | 94-150 | [`03-oriented-intersection-theory.ipynb`](chapter-03-oriented-intersection-theory/03-oriented-intersection-theory.ipynb) |
# | Chapter 4 | Integration on Manifolds | 151-201 | [`04-integration-on-manifolds.ipynb`](chapter-04-integration-on-manifolds/04-integration-on-manifolds.ipynb) |
# | Appendix 1 | Measure Zero and Sard's Theorem | 202-207 | [`appendix-1-measure-zero-and-sard-s.ipynb`](appendix-1-measure-zero-and-sard-s-theorem/appendix-1-measure-zero-and-sard-s.ipynb) |
# | Appendix 2 | Classification of Compact One-Manifolds | 208-211 | [`appendix-2-classification-of-compact-one-manifolds.ipynb`](appendix-2-classification-of-compact-one-manifolds/appendix-2-classification-of-compact-one-manifolds.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Differential Topology: 6 canonical units

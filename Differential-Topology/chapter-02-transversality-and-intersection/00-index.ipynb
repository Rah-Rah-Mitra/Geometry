# %% [markdown]
# # Chapter 2: Transversality and Intersection
#
# Source span: printed pages `57-93`.
#
# Canonical notebook: [`02-transversality-and-intersection.ipynb`](02-transversality-and-intersection.ipynb).
#
# Focus: Manifolds with boundary, one-manifolds, mod 2 intersection, winding numbers, Jordan-Brouwer, and Borsuk-Ulam.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Topology

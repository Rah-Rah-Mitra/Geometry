# %% [markdown]
# # Appendix 2: Classification of Compact One-Manifolds
#
# Source span: printed pages `208-228`.
#
# Focus: Compact one-manifold classification via interval and circle models.
#
# Canonical notebook: [`appendix-2-classification-of-compact-one-manifolds.ipynb`](appendix-2-classification-of-compact-one-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

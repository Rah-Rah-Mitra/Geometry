# %% [markdown]
# # Chapter 4: Integration on Manifolds
#
# Source span: printed pages `151-201`.
#
# Canonical notebook: [`04-integration-on-manifolds.ipynb`](04-integration-on-manifolds.ipynb).
#
# Focus: Exterior algebra, differential forms, integration, exterior derivative, form cohomology, Stokes theorem, mappings, and Gauss-Bonnet.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Topology

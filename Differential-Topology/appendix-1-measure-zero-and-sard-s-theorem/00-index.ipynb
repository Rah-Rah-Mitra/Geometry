# %% [markdown]
# # Appendix 1: Measure Zero and Sard's Theorem
#
# Source span: printed pages `202-207`.
#
# Focus: Measure-zero sets, Sard theorem proof scaffolding, and critical value diagnostics.
#
# Canonical notebook: [`appendix-1-measure-zero-and-sard-s.ipynb`](appendix-1-measure-zero-and-sard-s.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

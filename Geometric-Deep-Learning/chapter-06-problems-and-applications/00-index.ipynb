# %% [markdown]
# # Chapter 06: Problems and Applications
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [06-problems-and-applications.ipynb](06-problems-and-applications.ipynb)
# - Printed pages: 102-113
# - Physical PDF pages: 106-117
# - Sections: 6
# - Focus: Chemistry, proteins, recommenders, traffic, vision, games, language/audio, healthcare, physics, and VR/AR.
# - Visual spine: application atlas with invariant/equivariant checks for every domain
#
# Artifacts generated by this chapter live under `artifacts/chapter-06/`.

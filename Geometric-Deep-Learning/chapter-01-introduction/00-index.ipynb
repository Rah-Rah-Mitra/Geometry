# %% [markdown]
# # Chapter 01: Introduction
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [01-introduction.ipynb](01-introduction.ipynb)
# - Printed pages: 4
# - Physical PDF pages: 8
# - Sections: 1
# - Focus: Representation learning, structured data, symmetry preview, and the GDL design loop.
# - Visual spine: ambient vs structured samples, symmetry action gallery, equivariance mini-lab, blueprint taxonomy
#
# Artifacts generated by this chapter live under `artifacts/chapter-01/`.

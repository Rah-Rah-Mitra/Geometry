# %% [markdown]
# # Chapter 04: Geometric Domains: the 5 Gs
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [04-geometric-domains-the-5-gs.ipynb](04-geometric-domains-the-5-gs.ipynb)
# - Printed pages: 30-67
# - Physical PDF pages: 34-71
# - Sections: 4.1-4.6
# - Focus: Graphs/sets, grids, groups, manifolds/geodesics, gauges/bundles, and meshes.
# - Visual spine: 5G atlas, graph equivariance, circulant grids, finite groups, sphere transport, mesh Laplacians
#
# Artifacts generated by this chapter live under `artifacts/chapter-04/`.

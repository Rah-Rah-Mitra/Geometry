# %% [markdown]
# # Chapter 05: Geometric Deep Learning Models
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [05-geometric-deep-learning-models.ipynb](05-geometric-deep-learning-models.ipynb)
# - Printed pages: 68-101
# - Physical PDF pages: 72-105
# - Sections: 5.1-5.8
# - Focus: CNNs, group CNNs, GNNs, sets/Transformers, E(3) message passing, mesh CNNs, and RNN/LSTM.
# - Visual spine: CNN filters, group convolutions, GNN flavors, Transformers, E(3) messages, mesh gauges, RNN gates
#
# Artifacts generated by this chapter live under `artifacts/chapter-05/`.

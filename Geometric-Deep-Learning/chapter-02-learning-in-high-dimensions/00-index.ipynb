# %% [markdown]
# # Chapter 02: Learning in High Dimensions
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [02-learning-in-high-dimensions.ipynb](02-learning-in-high-dimensions.ipynb)
# - Printed pages: 5-8
# - Physical PDF pages: 9-12
# - Sections: 2.1-2.2
# - Focus: Interpolation, regularity, implicit bias, Lipschitz fill distance, and covering growth.
# - Visual spine: interpolants, regularity, implicit minimum norm, covering explosion, projection priors
#
# Artifacts generated by this chapter live under `artifacts/chapter-02/`.

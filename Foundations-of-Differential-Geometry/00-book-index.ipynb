# %% [markdown]
# # Foundations of Differential Geometry
#
# Standalone visualization-first notebook course.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Differentiable Manifolds | 1-62 | [`01-differentiable-manifolds.ipynb`](volume-01/chapter-01-differentiable-manifolds/01-differentiable-manifolds.ipynb) |
# | Chapter 2 | Theory of Connections | 63-112 | [`02-theory-of-connections.ipynb`](volume-01/chapter-02-theory-of-connections/02-theory-of-connections.ipynb) |
# | Chapter 3 | Linear and Affine Connections | 113-153 | [`03-linear-and-affine-connections.ipynb`](volume-01/chapter-03-linear-and-affine-connections/03-linear-and-affine-connections.ipynb) |
# | Chapter 4 | Riemannian Connections | 154-197 | [`04-riemannian-connections.ipynb`](volume-01/chapter-04-riemannian-connections/04-riemannian-connections.ipynb) |
# | Chapter 5 | Curvature and Space Forms | 198-224 | [`05-curvature-and-space-forms.ipynb`](volume-01/chapter-05-curvature-and-space-forms/05-curvature-and-space-forms.ipynb) |
# | Chapter 6 | Transformations | 225-266 | [`06-transformations.ipynb`](volume-01/chapter-06-transformations/06-transformations.ipynb) |
# | Appendix 1 | Ordinary Linear Differential Equations | 267-268 | [`appendix-1-ordinary-linear-differential-equations.ipynb`](volume-01/appendix-1-ordinary-linear-differential-equations/appendix-1-ordinary-linear-differential-equations.ipynb) |
# | Appendix 2 | Connected Locally Compact Metric Spaces are Separable | 269-271 | [`appendix-2-connected-locally-compact-metric-spaces.ipynb`](volume-01/appendix-2-connected-locally-compact-metric-spaces-are-separable/appendix-2-connected-locally-compact-metric-spaces.ipynb) |
# | Appendix 3 | Partition of Unity | 272-274 | [`appendix-3-partition-of-unity.ipynb`](volume-01/appendix-3-partition-of-unity/appendix-3-partition-of-unity.ipynb) |
# | Appendix 4 | Arcwise Connected Subgroups of Lie Groups | 275-276 | [`appendix-4-arcwise-connected-subgroups-of-lie.ipynb`](volume-01/appendix-4-arcwise-connected-subgroups-of-lie-groups/appendix-4-arcwise-connected-subgroups-of-lie.ipynb) |
# | Appendix 5 | Irreducible Subgroups of O(n) | 277-280 | [`appendix-5-irreducible-subgroups-of-o-n.ipynb`](volume-01/appendix-5-irreducible-subgroups-of-o-n/appendix-5-irreducible-subgroups-of-o-n.ipynb) |
# | Appendix 6 | Green's Theorem | 281-283 | [`appendix-6-green-s-theorem.ipynb`](volume-01/appendix-6-green-s-theorem/appendix-6-green-s-theorem.ipynb) |
# | Appendix 7 | Factorization Lemma | 284-304 | [`appendix-7-factorization-lemma.ipynb`](volume-01/appendix-7-factorization-lemma/appendix-7-factorization-lemma.ipynb) |
# | Chapter 7 | Submanifolds | 1-62 | [`07-submanifolds.ipynb`](volume-02/chapter-07-submanifolds/07-submanifolds.ipynb) |
# | Chapter 8 | Variations of the Length Integral | 63-113 | [`08-variations-of-the-length-integral.ipynb`](volume-02/chapter-08-variations-of-the-length-integral/08-variations-of-the-length-integral.ipynb) |
# | Chapter 9 | Complex Manifolds | 114-185 | [`09-complex-manifolds.ipynb`](volume-02/chapter-09-complex-manifolds/09-complex-manifolds.ipynb) |
# | Chapter 10 | Homogeneous Spaces | 186-221 | [`10-homogeneous-spaces.ipynb`](volume-02/chapter-10-homogeneous-spaces/10-homogeneous-spaces.ipynb) |
# | Chapter 11 | Symmetric Spaces | 222-292 | [`11-symmetric-spaces.ipynb`](volume-02/chapter-11-symmetric-spaces/11-symmetric-spaces.ipynb) |
# | Chapter 12 | Characteristic Classes | 293-320 | [`12-characteristic-classes.ipynb`](volume-02/chapter-12-characteristic-classes/12-characteristic-classes.ipynb) |
# | Appendix 8 | Integrable Real Analytic Almost Complex Structures | 321-324 | [`appendix-8-integrable-real-analytic-almost-complex.ipynb`](volume-02/appendix-8-integrable-real-analytic-almost-complex-structures/appendix-8-integrable-real-analytic-almost-complex.ipynb) |
# | Appendix 9 | Definitions and Facts on Lie Algebras | 325-345 | [`appendix-9-definitions-and-facts-on-lie.ipynb`](volume-02/appendix-9-definitions-and-facts-on-lie-algebras/appendix-9-definitions-and-facts-on-lie.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text(encoding='utf-8'))
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Foundations of Differential Geometry: 21 canonical units

# %% [markdown]
# # Appendix 3: Partition of Unity
#
# Source span: printed pages `272-274`.
#
# Focus: Partition of unity construction and its role in globalizing local differential-geometric data.
#
# Canonical notebook: [`appendix-3-partition-of-unity.ipynb`](appendix-3-partition-of-unity.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

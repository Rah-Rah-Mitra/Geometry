# %% [markdown]
# # Chapter 3: Linear and Affine Connections
#
# Source span: printed pages `113-153`.
#
# Focus: Vector bundle connections, linear and affine connections, developments, curvature, torsion, geodesics, coordinates, normal coordinates, and holonomy.
#
# Canonical notebook: [`03-linear-and-affine-connections.ipynb`](03-linear-and-affine-connections.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

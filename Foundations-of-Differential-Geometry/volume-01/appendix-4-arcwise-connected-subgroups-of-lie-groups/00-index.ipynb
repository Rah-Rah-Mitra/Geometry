# %% [markdown]
# # Appendix 4: Arcwise Connected Subgroups of Lie Groups
#
# Source span: printed pages `275-276`.
#
# Focus: Lie subgroup connectivity lemma used in holonomy and transformation theory.
#
# Canonical notebook: [`appendix-4-arcwise-connected-subgroups-of-lie.ipynb`](appendix-4-arcwise-connected-subgroups-of-lie.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 4: Riemannian Connections
#
# Source span: printed pages `154-197`.
#
# Focus: Riemannian metrics, Levi-Civita connections, normal coordinates, convex neighborhoods, completeness, holonomy, and de Rham decomposition.
#
# Canonical notebook: [`04-riemannian-connections.ipynb`](04-riemannian-connections.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

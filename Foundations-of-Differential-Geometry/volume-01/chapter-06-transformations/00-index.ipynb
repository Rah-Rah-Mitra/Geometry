# %% [markdown]
# # Chapter 6: Transformations
#
# Source span: printed pages `225-266`.
#
# Focus: Affine transformations, infinitesimal affine transformations, isometries, Ricci tensor, extension of local isomorphisms, and equivalence problems.
#
# Canonical notebook: [`06-transformations.ipynb`](06-transformations.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Appendix 7: Factorization Lemma
#
# Source span: printed pages `284-304`.
#
# Focus: Local factorization arguments for maps, bundles, and equivalence problems.
#
# Canonical notebook: [`appendix-7-factorization-lemma.ipynb`](appendix-7-factorization-lemma.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

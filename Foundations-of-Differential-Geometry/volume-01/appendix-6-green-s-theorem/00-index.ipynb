# %% [markdown]
# # Appendix 6: Green's Theorem
#
# Source span: printed pages `281-283`.
#
# Focus: Green theorem scaffold for integration and curvature identities.
#
# Canonical notebook: [`appendix-6-green-s-theorem.ipynb`](appendix-6-green-s-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

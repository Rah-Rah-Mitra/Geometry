# %% [markdown]
# # Appendix 2: Connected Locally Compact Metric Spaces are Separable
#
# Source span: printed pages `269-271`.
#
# Focus: Separability lemma supporting manifold countability and local compactness arguments.
#
# Canonical notebook: [`appendix-2-connected-locally-compact-metric-spaces.ipynb`](appendix-2-connected-locally-compact-metric-spaces.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

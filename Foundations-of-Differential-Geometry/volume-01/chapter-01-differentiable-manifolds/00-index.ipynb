# %% [markdown]
# # Chapter 1: Differentiable Manifolds
#
# Source span: printed pages `1-62`.
#
# Focus: Pseudogroups, differentiable manifolds, tensor algebras, tensor fields, Lie groups, and fibre bundles.
#
# Canonical notebook: [`01-differentiable-manifolds.ipynb`](01-differentiable-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

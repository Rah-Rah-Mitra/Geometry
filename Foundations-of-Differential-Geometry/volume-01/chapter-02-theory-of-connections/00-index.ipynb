# %% [markdown]
# # Chapter 2: Theory of Connections
#
# Source span: printed pages `63-112`.
#
# Focus: Principal fibre bundle connections, existence, parallelism, holonomy, curvature forms, reductions, invariant connections, and flatness.
#
# Canonical notebook: [`02-theory-of-connections.ipynb`](02-theory-of-connections.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

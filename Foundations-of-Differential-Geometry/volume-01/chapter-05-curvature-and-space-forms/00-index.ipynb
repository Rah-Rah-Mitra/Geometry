# %% [markdown]
# # Chapter 5: Curvature and Space Forms
#
# Source span: printed pages `198-224`.
#
# Focus: Algebraic curvature, sectional curvature, spaces of constant curvature, flat affine and Riemannian connections.
#
# Canonical notebook: [`05-curvature-and-space-forms.ipynb`](05-curvature-and-space-forms.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

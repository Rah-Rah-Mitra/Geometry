# %% [markdown]
# # Appendix 1: Ordinary Linear Differential Equations
#
# Source span: printed pages `267-268`.
#
# Focus: Linear ODE foundations for connections, parallel transport, and local existence arguments.
#
# Canonical notebook: [`appendix-1-ordinary-linear-differential-equations.ipynb`](appendix-1-ordinary-linear-differential-equations.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

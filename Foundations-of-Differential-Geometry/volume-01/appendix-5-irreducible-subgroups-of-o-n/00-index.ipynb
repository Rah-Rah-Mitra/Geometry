# %% [markdown]
# # Appendix 5: Irreducible Subgroups of O(n)
#
# Source span: printed pages `277-280`.
#
# Focus: Irreducible orthogonal representations and holonomy decomposition examples.
#
# Canonical notebook: [`appendix-5-irreducible-subgroups-of-o-n.ipynb`](appendix-5-irreducible-subgroups-of-o-n.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

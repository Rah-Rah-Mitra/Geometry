# %% [markdown]
# # Chapter 10: Homogeneous Spaces
#
# Source span: printed pages `186-221`.
#
# Focus: Invariant affine connections, reductive homogeneous spaces, invariant metrics, holonomy, de Rham decomposition, and invariant almost complex structures.
#
# Canonical notebook: [`10-homogeneous-spaces.ipynb`](10-homogeneous-spaces.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

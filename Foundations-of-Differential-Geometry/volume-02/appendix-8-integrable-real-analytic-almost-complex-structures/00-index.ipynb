# %% [markdown]
# # Appendix 8: Integrable Real Analytic Almost Complex Structures
#
# Source span: printed pages `321-324`.
#
# Focus: Real analytic integrability support for almost complex structures.
#
# Canonical notebook: [`appendix-8-integrable-real-analytic-almost-complex.ipynb`](appendix-8-integrable-real-analytic-almost-complex.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 7: Submanifolds
#
# Source span: printed pages `1-62`.
#
# Focus: Frame bundles, Gauss maps, second fundamental form, Gauss-Codazzi equations, hypersurfaces, rigidity, and totally geodesic submanifolds.
#
# Canonical notebook: [`07-submanifolds.ipynb`](07-submanifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

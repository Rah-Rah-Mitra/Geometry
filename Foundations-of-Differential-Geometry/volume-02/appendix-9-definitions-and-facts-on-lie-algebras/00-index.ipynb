# %% [markdown]
# # Appendix 9: Definitions and Facts on Lie Algebras
#
# Source span: printed pages `325-345`.
#
# Focus: Lie algebra background supporting homogeneous and symmetric space chapters.
#
# Canonical notebook: [`appendix-9-definitions-and-facts-on-lie.ipynb`](appendix-9-definitions-and-facts-on-lie.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

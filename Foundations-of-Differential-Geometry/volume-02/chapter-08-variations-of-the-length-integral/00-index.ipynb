# %% [markdown]
# # Chapter 8: Variations of the Length Integral
#
# Source span: printed pages `63-113`.
#
# Focus: Jacobi fields, conjugate points, comparison theorem, second variation, Morse index theorem, cut loci, nonpositive curvature, and fixed points.
#
# Canonical notebook: [`08-variations-of-the-length-integral.ipynb`](08-variations-of-the-length-integral.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

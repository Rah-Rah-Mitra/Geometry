# %% [markdown]
# # Chapter 12: Characteristic Classes
#
# Source span: printed pages `293-320`.
#
# Focus: Weil homomorphism, invariant polynomials, Chern classes, Pontrjagin classes, Euler classes, and Chern-Weil formulas.
#
# Canonical notebook: [`12-characteristic-classes.ipynb`](12-characteristic-classes.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

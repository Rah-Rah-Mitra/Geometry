# %% [markdown]
# # Chapter 11: Symmetric Spaces
#
# Source span: printed pages `222-292`.
#
# Focus: Affine and Riemannian symmetric spaces, canonical connections, totally geodesic submanifolds, symmetric Lie algebras, duality, examples, and classification outline.
#
# Canonical notebook: [`11-symmetric-spaces.ipynb`](11-symmetric-spaces.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 1: Preliminary Notions
#
# - Source orientation: printed pages 1-16; PDF pages 16-31; sections 1.1-1.3.
# - Focus: Axioms, models, equivalence relations, and functions.
# - Canonical notebook: [01-preliminary-notions.ipynb](01-preliminary-notions.ipynb)
# - Artifact root: `../artifacts/chapter-01/`
#
# This chapter notebook is written to stand alone from the scanned textbook. Use the PDF only to confirm source orientation, not as a reading dependency.

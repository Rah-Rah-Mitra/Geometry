# %% [markdown]
# # Geometry: A Metric Approach with Models
#
# This is a standalone visualization-first notebook course. The scanned PDF is used only for source orientation: title, chapter order, page spans, definitions, and exercises. The notebooks use original prose, original computational examples, and generated visual artifacts.
#
# Body printed pages map to physical PDF pages by `pdf_page = printed_page + 15`.
#
# The frontmatter note on computers and hyperbolic geometry is treated as motivation for the course design: the notebooks make the model calculations and graphical experiments executable with the modern shared geometry stack.
#
# ## Chapter Route
#
# | Chapter | Notebook | Printed Pages | PDF Pages | Focus |
# | --- | --- | ---: | ---: | --- |
# | 1 | [Preliminary Notions](chapter-01-preliminary-notions/01-preliminary-notions.ipynb) | 1-16 | 16-31 | Axioms, models, equivalence relations, and functions. |
# | 2 | [Incidence and Metric Geometry](chapter-02-incidence-and-metric-geometry/02-incidence-and-metric-geometry.ipynb) | 17-41 | 32-56 | Incidence models, metric geometry, and special coordinate systems. |
# | 3 | [Betweenness and Elementary Figures](chapter-03-betweenness-and-elementary-figures/03-betweenness-and-elementary-figures.ipynb) | 42-62 | 57-77 | Alternative Cartesian descriptions, betweenness, segments, rays, angles, and triangles. |
# | 4 | [Plane Separation](chapter-04-plane-separation/04-plane-separation.ipynb) | 63-89 | 78-104 | Plane separation, Pasch geometries, interiors, crossbar theorem, and convex quadrilaterals. |
# | 5 | [Angle Measure](chapter-05-angle-measure/05-angle-measure.ipynb) | 90-123 | 105-138 | Angle measure, Molton plane, perpendicularity, angle congruence, and Poincare angle measure. |
# | 6 | [Neutral Geometry](chapter-06-neutral-geometry/06-neutral-geometry.ipynb) | 124-168 | 139-183 | SAS, triangle congruence, exterior angle theorem, right triangles, circles and tangent lines, and synthetic proof flow. |
# | 7 | [The Theory of Parallels](chapter-07-the-theory-of-parallels/07-the-theory-of-parallels.ipynb) | 169-195 | 184-210 | Parallel lines, Saccheri quadrilaterals, and the critical function. |
# | 8 | [Hyperbolic Geometry](chapter-08-hyperbolic-geometry/08-hyperbolic-geometry.ipynb) | 196-223 | 211-238 | Asymptotic rays, triangle defect, and distance between parallel lines. |
# | 9 | [Euclidean Geometry](chapter-09-euclidean-geometry/09-euclidean-geometry.ipynb) | 224-247 | 239-262 | Equivalent forms of the Euclidean parallel postulate, similarity theory, and classical Euclidean theorems. |
# | 10 | [Area](chapter-10-area/10-area.ipynb) | 248-284 | 263-299 | Area functions, Euclidean area, hyperbolic area, and Bolyai's theorem. |
# | 11 | [The Theory of Isometries](chapter-11-the-theory-of-isometries/11-the-theory-of-isometries.ipynb) | 285-358 | 300-373 | Collineations, Klein and Poincare disk models, reflections, pencils, cycles, double reflections, classification, and isometry groups. |
#
# ## Course Contract
#
# - One canonical notebook per chapter folder plus a local `00-index.ipynb`.
# - Artifacts are saved under `artifacts/chapter-XX/`.
# - Each chapter includes a storyboard, visual artifacts, computational checks, an applied lab, and takeaways.
# - No textbook screenshots, crops, long exercise text, or copied prose are included.

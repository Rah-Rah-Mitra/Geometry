# %% [markdown]
# # Chapter 7: The Theory of Parallels
#
# - Source orientation: printed pages 169-195; PDF pages 184-210; sections 7.1-7.3.
# - Focus: Parallel lines, Saccheri quadrilaterals, and the critical function.
# - Canonical notebook: [07-the-theory-of-parallels.ipynb](07-the-theory-of-parallels.ipynb)
# - Artifact root: `../artifacts/chapter-07/`
#
# This chapter notebook is written to stand alone from the scanned textbook. Use the PDF only to confirm source orientation, not as a reading dependency.

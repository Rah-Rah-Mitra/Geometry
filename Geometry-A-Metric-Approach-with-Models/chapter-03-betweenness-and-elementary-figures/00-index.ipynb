# %% [markdown]
# # Chapter 3: Betweenness and Elementary Figures
#
# - Source orientation: printed pages 42-62; PDF pages 57-77; sections 3.1-3.4.
# - Focus: Alternative Cartesian descriptions, betweenness, segments, rays, angles, and triangles.
# - Canonical notebook: [03-betweenness-and-elementary-figures.ipynb](03-betweenness-and-elementary-figures.ipynb)
# - Artifact root: `../artifacts/chapter-03/`
#
# This chapter notebook is written to stand alone from the scanned textbook. Use the PDF only to confirm source orientation, not as a reading dependency.

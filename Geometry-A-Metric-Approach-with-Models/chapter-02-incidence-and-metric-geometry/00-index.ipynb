# %% [markdown]
# # Chapter 2: Incidence and Metric Geometry
#
# - Source orientation: printed pages 17-41; PDF pages 32-56; sections 2.1-2.3.
# - Focus: Incidence models, metric geometry, and special coordinate systems.
# - Canonical notebook: [02-incidence-and-metric-geometry.ipynb](02-incidence-and-metric-geometry.ipynb)
# - Artifact root: `../artifacts/chapter-02/`
#
# This chapter notebook is written to stand alone from the scanned textbook. Use the PDF only to confirm source orientation, not as a reading dependency.

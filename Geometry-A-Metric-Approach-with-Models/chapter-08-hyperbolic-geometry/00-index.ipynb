# %% [markdown]
# # Chapter 8: Hyperbolic Geometry
#
# - Source orientation: printed pages 196-223; PDF pages 211-238; sections 8.1-8.3.
# - Focus: Asymptotic rays, triangle defect, and distance between parallel lines.
# - Canonical notebook: [08-hyperbolic-geometry.ipynb](08-hyperbolic-geometry.ipynb)
# - Artifact root: `../artifacts/chapter-08/`
#
# This chapter notebook is written to stand alone from the scanned textbook. Use the PDF only to confirm source orientation, not as a reading dependency.

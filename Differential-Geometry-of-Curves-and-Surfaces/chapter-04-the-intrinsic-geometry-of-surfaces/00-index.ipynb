# %% [markdown]
# # Chapter 04: The Intrinsic Geometry of Surfaces
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [04-the-intrinsic-geometry-of-surfaces.ipynb](04-the-intrinsic-geometry-of-surfaces.ipynb)
# - Source span: printed pp. 220-320; PDF pp. 236-336
# - Sections: 4-1 through 4-7 plus appendix
# - Focus: isometries, conformal maps, compatibility equations, geodesics, parallel transport, Gauss-Bonnet, and exponential maps
#
# ## Topics
#
# - intrinsic data versus extrinsic embeddings
# - Christoffel symbols and compatibility
# - geodesics and parallel transport
# - Gauss-Bonnet and exponential coordinates
#
# ## Artifact Root
#
# Generated diagrams, interactive HTML, and check JSON for this unit live under
# `artifacts/chapter-04/`.

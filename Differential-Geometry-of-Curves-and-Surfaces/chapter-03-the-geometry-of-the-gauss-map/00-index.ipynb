# %% [markdown]
# # Chapter 03: The Geometry of the Gauss Map
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [03-the-geometry-of-the-gauss-map.ipynb](03-the-geometry-of-the-gauss-map.ipynb)
# - Source span: printed pp. 136-219; PDF pp. 152-235
# - Sections: 3-1 through 3-5 plus appendix
# - Focus: Gauss map, shape operator, curvatures, vector fields, ruled surfaces, and minimal surfaces
#
# ## Topics
#
# - normal maps as curvature sensors
# - shape operator and principal curvature directions
# - Gaussian and mean curvature in coordinates
# - ruled and minimal surface examples
#
# ## Artifact Root
#
# Generated diagrams, interactive HTML, and check JSON for this unit live under
# `artifacts/chapter-03/`.

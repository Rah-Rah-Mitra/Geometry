# %% [markdown]
# # Geometry Course Atlas
#
# Welcome to a visualization-first geometry curriculum built from executable Jupyter notebooks. Each course folder is a self-contained study path with original prose, generated diagrams, computational experiments, artifacts, and checks.
#
# [![Launch Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Rah-Rah-Mitra/Geometry/main?urlpath=lab/tree/index.ipynb)
#
# Binder sessions are temporary. You can run and edit notebooks freely, but files you create or change inside Binder will disappear when the session ends unless you download them or move the work into your own copy of the repository.

# %% [markdown]
# ## First Run Check
#
# Run the cell below after Binder starts. It checks the main course dependencies and confirms that every book-level course index is present.

# %%
from pathlib import Path
import importlib
import platform
import sys

COURSE_INDEXES = [
    "A-Course-in-Metric-Geometry/00-book-index.ipynb",
    "A-Mathematical-Introduction-to-Robotic-Manipulation/00-book-index.ipynb",
    "Algebraic-Geometry/00-book-index.ipynb",
    "Algebraic-Topology/00-book-index.ipynb",
    "An-Introduction-to-Contact-Topology/00-book-index.ipynb",
    "An-Introduction-to-Manifolds/00-book-index.ipynb",
    "Basic-Topology/00-book-index.ipynb",
    "Complex-Geometry-An-Introduction/00-book-index.ipynb",
    "Computational-Geometry-Algorithms-and-Applications/00-book-index.ipynb",
    "Computational-Geometry-in-C/00-book-index.ipynb",
    "Computational-Topology-An-Introduction/00-book-index.ipynb",
    "Convex-Analysis/00-book-index.ipynb",
    "Differential-Forms-in-Algebraic-Topology/00-book-index.ipynb",
    "Differential-Geometry-From-Elastic-Curves-to-Willmore-Surfaces/00-book-index.ipynb",
    "Differential-Geometry-Lie-Groups-and-Symmetric-Spaces/00-book-index.ipynb",
    "Differential-Geometry-of-Curves-and-Surfaces/00-book-index.ipynb",
    "Differential-Topology/00-book-index.ipynb",
    "Directional-Statistics/00-book-index.ipynb",
    "Discrete-and-Computational-Geometry/00-book-index.ipynb",
    "Einstein-Manifolds/00-book-index.ipynb",
    "Elementary-Differential-Geometry-Andrew-Pressley/00-book-index.ipynb",
    "Elementary-Differential-Geometry-Barrett-ONeill/00-book-index.ipynb",
    "Euclid-and-Beyond/00-book-index.ipynb",
    "Euclidean-and-Non-Euclidean-Geometries/00-book-index.ipynb",
    "Foundations-of-Differentiable-Manifolds-and-Lie-Groups/00-book-index.ipynb",
    "Foundations-of-Differential-Geometry/00-book-index.ipynb",
    "Fundamentals-of-Computer-Graphics/00-book-index.ipynb",
    "Geometric-Algebra-for-Computer-Science/00-book-index.ipynb",
    "Geometric-Deep-Learning/00-book-index.ipynb",
    "Geometric-Group-Theory-An-Introduction/00-book-index.ipynb",
    "Geometric-Measure-Theory/00-book-index.ipynb",
    "Geometric-Tools-for-Computer-Graphics/00-book-index.ipynb",
    "Geometry-A-Metric-Approach-with-Models/00-book-index.ipynb",
    "Geometry-I/00-book-index.ipynb",
    "Geometry-II/00-book-index.ipynb",
    "Geometry-with-an-Introduction-to-Cosmic-Topology/00-book-index.ipynb",
    "Hodge-Theory-and-Complex-Algebraic-Geometry/00-book-index.ipynb",
    "Ideals-Varieties-and-Algorithms-An-Introduction-to-Computational-Algebraic-Geometry-and-Commutative-Algebra/00-book-index.ipynb",
    "Information-Geometry-and-Its-Applications/00-book-index.ipynb",
    "Introduction-to-Geometry/00-book-index.ipynb",
    "Introduction-to-Riemannian-Manifolds/00-book-index.ipynb",
    "Introduction-to-Smooth-Manifolds/00-book-index.ipynb",
    "Introduction-to-Symplectic-Topology/00-book-index.ipynb",
    "Introduction-to-Topological-Manifolds/00-book-index.ipynb",
    "J-Holomorphic-Curves-and-Symplectic-Topology/00-book-index.ipynb",
    "Knots-Links-and-Their-Invariants-An-Elementary-Course-in-Contemporary-Knot-Theory/00-book-index.ipynb",
    "Lectures-on-Discrete-Geometry/00-book-index.ipynb",
    "Lectures-on-Symplectic-Geometry/00-book-index.ipynb",
    "Mathematical-Foundations-of-Geometric-Deep-Learning/00-book-index.ipynb",
    "Mathematical-Methods-of-Classical-Mechanics/00-book-index.ipynb",
    "Methods-of-Information-Geometry/00-book-index.ipynb",
    "Metric-Spaces-of-Non-Positive-Curvature/00-book-index.ipynb",
    "Modern-Robotics/00-book-index.ipynb",
    "Multiple-View-Geometry-in-Computer-Vision/00-book-index.ipynb",
    "Nonparametric-Inference-on-Manifolds-with-Applications-to-Shape-Spaces/00-book-index.ipynb",
    "Optimal-Transport-Old-and-New/00-book-index.ipynb",
    "Perspectives-on-Projective-Geometry/00-book-index.ipynb",
    "Principles-of-Algebraic-Geometry/00-book-index.ipynb",
    "Riemannian-Geometry/00-book-index.ipynb",
    "Statistics-on-Special-Manifolds/00-book-index.ipynb",
    "The-Four-Pillars-of-Geometry/00-book-index.ipynb",
    "Three-Dimensional-Geometry-and-Topology/00-book-index.ipynb",
    "Topology/00-book-index.ipynb",
    "Undergraduate-Algebraic-Geometry/00-book-index.ipynb",
    "Visual-Differential-Geometry-and-Forms/00-book-index.ipynb",
]

MODULES = {
    "Jupyter widgets": "ipywidgets",
    "Matplotlib": "matplotlib",
    "NumPy": "numpy",
    "SciPy": "scipy",
    "SymPy": "sympy",
    "pandas": "pandas",
    "Plotly": "plotly",
    "NetworkX": "networkx",
    "Pillow": "PIL",
    "scikit-image": "skimage",
    "scikit-learn": "sklearn",
    "statsmodels": "statsmodels",
    "Shapely": "shapely",
    "trimesh": "trimesh",
    "GUDHI": "gudhi",
    "Ripser": "ripser",
    "Persim": "persim",
    "OpenCV": "cv2",
    "pyRiemann": "pyriemann",
    "GeomLoss": "geomloss",
    "POT": "ot",
    "PyVista": "pyvista",
    "PyTorch": "torch",
}

missing_indexes = [path for path in COURSE_INDEXES if not Path(path).exists()]
missing_modules = []
versions = {}
for label, module_name in MODULES.items():
    try:
        module = importlib.import_module(module_name)
    except Exception as exc:
        missing_modules.append(f"{label} ({module_name}): {exc!r}")
    else:
        versions[label] = getattr(module, "__version__", "imported")

print(f"Python: {sys.version.split()[0]} on {platform.platform()}")
print(f"Course indexes found: {len(COURSE_INDEXES) - len(missing_indexes)} / {len(COURSE_INDEXES)}")
print(f"Dependency imports found: {len(MODULES) - len(missing_modules)} / {len(MODULES)}")
for label in sorted(versions):
    print(f"  {label}: {versions[label]}")

if missing_indexes or missing_modules:
    details = []
    if missing_indexes:
        details.append("Missing course indexes:\n" + "\n".join(missing_indexes))
    if missing_modules:
        details.append("Missing imports:\n" + "\n".join(missing_modules))
    raise RuntimeError("\n\n".join(details))

print("Geometry course environment is ready.")

# %% [markdown]
# ## Suggested Journeys
#
# These tracks are not prerequisites written in stone. They are good first routes through a large atlas.
#
# ### Foundations and Classical Geometry
# - [The Four Pillars of Geometry](The-Four-Pillars-of-Geometry/00-book-index.ipynb)
# - [Introduction to Geometry](Introduction-to-Geometry/00-book-index.ipynb)
# - [Geometry I](Geometry-I/00-book-index.ipynb)
# - [Geometry II](Geometry-II/00-book-index.ipynb)
# - [Euclid and Beyond](Euclid-and-Beyond/00-book-index.ipynb)
# - [Euclidean and Non-Euclidean Geometries](Euclidean-and-Non-Euclidean-Geometries/00-book-index.ipynb)
# - [Geometry: A Metric Approach with Models](Geometry-A-Metric-Approach-with-Models/00-book-index.ipynb)
#
# ### Topology, Manifolds, and Curvature
# - [Basic Topology](Basic-Topology/00-book-index.ipynb)
# - [Topology](Topology/00-book-index.ipynb)
# - [Introduction to Topological Manifolds](Introduction-to-Topological-Manifolds/00-book-index.ipynb)
# - [Introduction to Smooth Manifolds](Introduction-to-Smooth-Manifolds/00-book-index.ipynb)
# - [Visual Differential Geometry and Forms](Visual-Differential-Geometry-and-Forms/00-book-index.ipynb)
# - [Differential Topology](Differential-Topology/00-book-index.ipynb)
# - [Algebraic Topology](Algebraic-Topology/00-book-index.ipynb)
#
# ### Computational Geometry, Graphics, Vision, and Robotics
# - [Computational Geometry: Algorithms and Applications](Computational-Geometry-Algorithms-and-Applications/00-book-index.ipynb)
# - [Discrete and Computational Geometry](Discrete-and-Computational-Geometry/00-book-index.ipynb)
# - [Computational Geometry in C](Computational-Geometry-in-C/00-book-index.ipynb)
# - [Geometric Tools for Computer Graphics](Geometric-Tools-for-Computer-Graphics/00-book-index.ipynb)
# - [Fundamentals of Computer Graphics](Fundamentals-of-Computer-Graphics/00-book-index.ipynb)
# - [Multiple View Geometry in Computer Vision](Multiple-View-Geometry-in-Computer-Vision/00-book-index.ipynb)
# - [A Mathematical Introduction to Robotic Manipulation](A-Mathematical-Introduction-to-Robotic-Manipulation/00-book-index.ipynb)
# - [Modern Robotics](Modern-Robotics/00-book-index.ipynb)
#
# ### Graduate Geometry Branches
# - [Introduction to Riemannian Manifolds](Introduction-to-Riemannian-Manifolds/00-book-index.ipynb)
# - [Riemannian Geometry](Riemannian-Geometry/00-book-index.ipynb)
# - [A Course in Metric Geometry](A-Course-in-Metric-Geometry/00-book-index.ipynb)
# - [Metric Spaces of Non-Positive Curvature](Metric-Spaces-of-Non-Positive-Curvature/00-book-index.ipynb)
# - [Algebraic Geometry](Algebraic-Geometry/00-book-index.ipynb)
# - [Hodge Theory and Complex Algebraic Geometry](Hodge-Theory-and-Complex-Algebraic-Geometry/00-book-index.ipynb)
# - [Lectures on Symplectic Geometry](Lectures-on-Symplectic-Geometry/00-book-index.ipynb)
# - [An Introduction to Contact Topology](An-Introduction-to-Contact-Topology/00-book-index.ipynb)
#
# ### Geometry for Data, Statistics, and Machine Learning
# - [Mathematical Foundations of Geometric Deep Learning](Mathematical-Foundations-of-Geometric-Deep-Learning/00-book-index.ipynb)
# - [Geometric Deep Learning](Geometric-Deep-Learning/00-book-index.ipynb)
# - [Directional Statistics](Directional-Statistics/00-book-index.ipynb)
# - [Statistics on Special Manifolds](Statistics-on-Special-Manifolds/00-book-index.ipynb)
# - [Information Geometry and Its Applications](Information-Geometry-and-Its-Applications/00-book-index.ipynb)
# - [Methods of Information Geometry](Methods-of-Information-Geometry/00-book-index.ipynb)
# - [Nonparametric Inference on Manifolds](Nonparametric-Inference-on-Manifolds-with-Applications-to-Shape-Spaces/00-book-index.ipynb)
# - [Optimal Transport: Old and New](Optimal-Transport-Old-and-New/00-book-index.ipynb)

# %% [markdown]
# ## Full Course Atlas
#
# | Course | Entrance |
# | --- | --- |
# | A Course in Metric Geometry | [open](A-Course-in-Metric-Geometry/00-book-index.ipynb) |
# | A Mathematical Introduction to Robotic Manipulation | [open](A-Mathematical-Introduction-to-Robotic-Manipulation/00-book-index.ipynb) |
# | Algebraic Geometry | [open](Algebraic-Geometry/00-book-index.ipynb) |
# | Algebraic Topology | [open](Algebraic-Topology/00-book-index.ipynb) |
# | An Introduction to Contact Topology | [open](An-Introduction-to-Contact-Topology/00-book-index.ipynb) |
# | An Introduction to Manifolds | [open](An-Introduction-to-Manifolds/00-book-index.ipynb) |
# | Basic Topology | [open](Basic-Topology/00-book-index.ipynb) |
# | Complex Geometry: An Introduction | [open](Complex-Geometry-An-Introduction/00-book-index.ipynb) |
# | Computational Geometry: Algorithms and Applications | [open](Computational-Geometry-Algorithms-and-Applications/00-book-index.ipynb) |
# | Computational Geometry in C | [open](Computational-Geometry-in-C/00-book-index.ipynb) |
# | Computational Topology: An Introduction | [open](Computational-Topology-An-Introduction/00-book-index.ipynb) |
# | Convex Analysis | [open](Convex-Analysis/00-book-index.ipynb) |
# | Differential Forms in Algebraic Topology | [open](Differential-Forms-in-Algebraic-Topology/00-book-index.ipynb) |
# | Differential Geometry: From Elastic Curves to Willmore Surfaces | [open](Differential-Geometry-From-Elastic-Curves-to-Willmore-Surfaces/00-book-index.ipynb) |
# | Differential Geometry: Lie Groups and Symmetric Spaces | [open](Differential-Geometry-Lie-Groups-and-Symmetric-Spaces/00-book-index.ipynb) |
# | Differential Geometry of Curves and Surfaces | [open](Differential-Geometry-of-Curves-and-Surfaces/00-book-index.ipynb) |
# | Differential Topology | [open](Differential-Topology/00-book-index.ipynb) |
# | Directional Statistics | [open](Directional-Statistics/00-book-index.ipynb) |
# | Discrete and Computational Geometry | [open](Discrete-and-Computational-Geometry/00-book-index.ipynb) |
# | Einstein Manifolds | [open](Einstein-Manifolds/00-book-index.ipynb) |
# | Elementary Differential Geometry: Andrew Pressley | [open](Elementary-Differential-Geometry-Andrew-Pressley/00-book-index.ipynb) |
# | Elementary Differential Geometry: Barrett O'Neill | [open](Elementary-Differential-Geometry-Barrett-ONeill/00-book-index.ipynb) |
# | Euclid and Beyond | [open](Euclid-and-Beyond/00-book-index.ipynb) |
# | Euclidean and Non-Euclidean Geometries | [open](Euclidean-and-Non-Euclidean-Geometries/00-book-index.ipynb) |
# | Foundations of Differentiable Manifolds and Lie Groups | [open](Foundations-of-Differentiable-Manifolds-and-Lie-Groups/00-book-index.ipynb) |
# | Foundations of Differential Geometry | [open](Foundations-of-Differential-Geometry/00-book-index.ipynb) |
# | Fundamentals of Computer Graphics | [open](Fundamentals-of-Computer-Graphics/00-book-index.ipynb) |
# | Geometric Algebra for Computer Science | [open](Geometric-Algebra-for-Computer-Science/00-book-index.ipynb) |
# | Geometric Deep Learning | [open](Geometric-Deep-Learning/00-book-index.ipynb) |
# | Geometric Group Theory: An Introduction | [open](Geometric-Group-Theory-An-Introduction/00-book-index.ipynb) |
# | Geometric Measure Theory | [open](Geometric-Measure-Theory/00-book-index.ipynb) |
# | Geometric Tools for Computer Graphics | [open](Geometric-Tools-for-Computer-Graphics/00-book-index.ipynb) |
# | Geometry: A Metric Approach with Models | [open](Geometry-A-Metric-Approach-with-Models/00-book-index.ipynb) |
# | Geometry I | [open](Geometry-I/00-book-index.ipynb) |
# | Geometry II | [open](Geometry-II/00-book-index.ipynb) |
# | Geometry with an Introduction to Cosmic Topology | [open](Geometry-with-an-Introduction-to-Cosmic-Topology/00-book-index.ipynb) |
# | Hodge Theory and Complex Algebraic Geometry | [open](Hodge-Theory-and-Complex-Algebraic-Geometry/00-book-index.ipynb) |
# | Ideals, Varieties, and Algorithms | [open](Ideals-Varieties-and-Algorithms-An-Introduction-to-Computational-Algebraic-Geometry-and-Commutative-Algebra/00-book-index.ipynb) |
# | Information Geometry and Its Applications | [open](Information-Geometry-and-Its-Applications/00-book-index.ipynb) |
# | Introduction to Geometry | [open](Introduction-to-Geometry/00-book-index.ipynb) |
# | Introduction to Riemannian Manifolds | [open](Introduction-to-Riemannian-Manifolds/00-book-index.ipynb) |
# | Introduction to Smooth Manifolds | [open](Introduction-to-Smooth-Manifolds/00-book-index.ipynb) |
# | Introduction to Symplectic Topology | [open](Introduction-to-Symplectic-Topology/00-book-index.ipynb) |
# | Introduction to Topological Manifolds | [open](Introduction-to-Topological-Manifolds/00-book-index.ipynb) |
# | J-Holomorphic Curves and Symplectic Topology | [open](J-Holomorphic-Curves-and-Symplectic-Topology/00-book-index.ipynb) |
# | Knots, Links, and Their Invariants | [open](Knots-Links-and-Their-Invariants-An-Elementary-Course-in-Contemporary-Knot-Theory/00-book-index.ipynb) |
# | Lectures on Discrete Geometry | [open](Lectures-on-Discrete-Geometry/00-book-index.ipynb) |
# | Lectures on Symplectic Geometry | [open](Lectures-on-Symplectic-Geometry/00-book-index.ipynb) |
# | Mathematical Foundations of Geometric Deep Learning | [open](Mathematical-Foundations-of-Geometric-Deep-Learning/00-book-index.ipynb) |
# | Mathematical Methods of Classical Mechanics | [open](Mathematical-Methods-of-Classical-Mechanics/00-book-index.ipynb) |
# | Methods of Information Geometry | [open](Methods-of-Information-Geometry/00-book-index.ipynb) |
# | Metric Spaces of Non-Positive Curvature | [open](Metric-Spaces-of-Non-Positive-Curvature/00-book-index.ipynb) |
# | Modern Robotics | [open](Modern-Robotics/00-book-index.ipynb) |
# | Multiple View Geometry in Computer Vision | [open](Multiple-View-Geometry-in-Computer-Vision/00-book-index.ipynb) |
# | Nonparametric Inference on Manifolds | [open](Nonparametric-Inference-on-Manifolds-with-Applications-to-Shape-Spaces/00-book-index.ipynb) |
# | Optimal Transport: Old and New | [open](Optimal-Transport-Old-and-New/00-book-index.ipynb) |
# | Perspectives on Projective Geometry | [open](Perspectives-on-Projective-Geometry/00-book-index.ipynb) |
# | Principles of Algebraic Geometry | [open](Principles-of-Algebraic-Geometry/00-book-index.ipynb) |
# | Riemannian Geometry | [open](Riemannian-Geometry/00-book-index.ipynb) |
# | Statistics on Special Manifolds | [open](Statistics-on-Special-Manifolds/00-book-index.ipynb) |
# | The Four Pillars of Geometry | [open](The-Four-Pillars-of-Geometry/00-book-index.ipynb) |
# | Three-Dimensional Geometry and Topology | [open](Three-Dimensional-Geometry-and-Topology/00-book-index.ipynb) |
# | Topology | [open](Topology/00-book-index.ipynb) |
# | Undergraduate Algebraic Geometry | [open](Undergraduate-Algebraic-Geometry/00-book-index.ipynb) |
# | Visual Differential Geometry and Forms | [open](Visual-Differential-Geometry-and-Forms/00-book-index.ipynb) |

# %% [markdown]
# # Chapter 7: The 27 lines on a cubic surface
#
# - Source span: printed pages 109-120; PDF pages 107-118; sections 7.1-7.7 and exercises.
# - Focus: A classical configuration theorem made visible through lines on a cubic surface, polar forms, rationality, and incidence.
# - Canonical notebook: [07-the-27-lines-on-a-cubic-surface.ipynb](07-the-27-lines-on-a-cubic-surface.ipynb)
# - Artifact root: `../../artifacts/chapter-07` from part folders or `../artifacts/chapter-07` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

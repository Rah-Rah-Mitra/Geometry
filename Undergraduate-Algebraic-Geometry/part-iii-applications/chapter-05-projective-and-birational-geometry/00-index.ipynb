# %% [markdown]
# # Chapter 5: Projective and birational geometry
#
# - Source span: printed pages 87-100; PDF pages 85-98; sections 5.0-5.11 and exercises.
# - Focus: Projective varieties, homogeneous coordinate rings, affine charts, rational maps, birational equivalence, and rational examples.
# - Canonical notebook: [05-projective-and-birational-geometry.ipynb](05-projective-and-birational-geometry.ipynb)
# - Artifact root: `../../artifacts/chapter-05` from part folders or `../artifacts/chapter-05` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

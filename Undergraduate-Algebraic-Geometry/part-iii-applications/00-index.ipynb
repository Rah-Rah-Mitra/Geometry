# %% [markdown]
# # Part III: Applications
#
# Projective geometry, singularities, cubic surfaces, and modern context.
#
# ## Chapters
#
# - Chapter 5: [Projective and birational geometry](chapter-05-projective-and-birational-geometry/00-index.ipynb) - Projective varieties, homogeneous coordinate rings, affine charts, rational maps, birational equivalence, and rational examples.
# - Chapter 6: [Tangent space and nonsingularity, dimension](chapter-06-tangent-space-nonsingularity-dimension/00-index.ipynb) - Algebraic tangent spaces, singular loci, dimension, intrinsic tangent definitions, and blowups as local resolution experiments.
# - Chapter 7: [The 27 lines on a cubic surface](chapter-07-the-27-lines-on-a-cubic-surface/00-index.ipynb) - A classical configuration theorem made visible through lines on a cubic surface, polar forms, rationality, and incidence.
# - Chapter 8: [Final comments](chapter-08-final-comments/00-index.ipynb) - A bridge from classical varieties to sheaves, schemes, nilpotents, arithmetic fibers, and the incidence count behind cubic-surface lines.
#
# - Back to [book index](../00-book-index.ipynb)

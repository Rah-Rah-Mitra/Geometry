# %% [markdown]
# # Prologue: Prologue
#
# Motivation and orientation before the main course.
#
# ## Chapters
#
# - Chapter 0: [Woffle](chapter-00-woffle/00-index.ipynb) - Why polynomial zero sets deserve their own geometry, why functions matter, and how algebra replaces local calculus.
#
# - Back to [book index](../00-book-index.ipynb)

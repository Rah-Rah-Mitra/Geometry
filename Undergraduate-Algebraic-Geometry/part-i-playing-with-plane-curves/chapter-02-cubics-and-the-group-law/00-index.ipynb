# %% [markdown]
# # Chapter 2: Cubics and the group law
#
# - Source span: printed pages 35-54; PDF pages 33-52; sections 2.1-2.16 and exercises.
# - Focus: Singular and smooth cubics, linear systems, the ninth point, chord-tangent addition, and the first appearance of genus.
# - Canonical notebook: [02-cubics-and-the-group-law.ipynb](02-cubics-and-the-group-law.ipynb)
# - Artifact root: `../../artifacts/chapter-02` from part folders or `../artifacts/chapter-02` from the prologue path.
# - Back to [book index](../../00-book-index.ipynb)

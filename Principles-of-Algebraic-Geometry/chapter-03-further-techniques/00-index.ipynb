# %% [markdown]
# # Chapter 03: Further Techniques
#
# **Source span.** Printed pages 364-468; PDF pages 379-483.
#
# **Canonical notebook.** [03-further-techniques.ipynb](03-further-techniques.ipynb)
#
# **Artifact root.** `../artifacts/chapter-03`
#
# ## Section Map
#
# - Printed p. 366 / PDF p. 381: Distributions and Currents
# - Printed p. 366 / PDF p. 381: Definitions; Residue Formulas
# - Printed p. 373 / PDF p. 388: Smoothing and Regularity
# - Printed p. 382 / PDF p. 397: Cohomology of Currents
# - Printed p. 385 / PDF p. 400: Applications of Currents to Complex Analysis
# - Printed p. 385 / PDF p. 400: Currents Associated to Analytic Varieties
# - Printed p. 392 / PDF p. 407: Intersection Numbers of Analytic Varieties
# - Printed p. 395 / PDF p. 410: The Levi Extension and Proper Mapping Theorems
# - Printed p. 400 / PDF p. 415: Chern Classes
# - Printed p. 400 / PDF p. 415: Definitions
# - Printed p. 409 / PDF p. 424: The Gauss Bonnet Formulas
# - Printed p. 416 / PDF p. 431: Remarks Concerning Chern Classes of Holomorphic Vector Bundles
# - Printed p. 419 / PDF p. 434: Fixed-Point and Residue Formulas
# - Printed p. 419 / PDF p. 434: The Lefschetz Fixed-Point Formula
# - Printed p. 422 / PDF p. 437: The Holomorphic Lefschetz Fixed-Point Formula
# - Printed p. 426 / PDF p. 441: The Bott Residue Formula
# - Printed p. 435 / PDF p. 450: The General Hirzebruch-Riemann-Roch Formula
# - Printed p. 438 / PDF p. 453: Spectral Sequences and Applications
# - Printed p. 438 / PDF p. 453: Spectral Sequences of Filtered and Bigraded Complexes
# - Printed p. 445 / PDF p. 460: Hypercohomology
# - Printed p. 454 / PDF p. 469: Differentials of the Second Kind
# - Printed p. 462 / PDF p. 477: The Leray Spectral Sequence
#
# Use this index as a navigation map only. The chapter notebook contains the original standalone lesson, visuals, and checks.

# %%
from pathlib import Path
notebook = Path('03-further-techniques.ipynb')
artifact_root = Path('../artifacts/chapter-03')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

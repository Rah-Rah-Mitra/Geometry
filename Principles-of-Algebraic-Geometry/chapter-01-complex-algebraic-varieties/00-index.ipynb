# %% [markdown]
# # Chapter 01: Complex Algebraic Varieties
#
# **Source span.** Printed pages 128-211; PDF pages 143-226.
#
# **Canonical notebook.** [01-complex-algebraic-varieties.ipynb](01-complex-algebraic-varieties.ipynb)
#
# **Artifact root.** `../artifacts/chapter-01`
#
# ## Section Map
#
# - Printed p. 129 / PDF p. 144: Divisors and Line Bundles
# - Printed p. 129 / PDF p. 144: Divisors
# - Printed p. 132 / PDF p. 147: Line Bundles
# - Printed p. 139 / PDF p. 154: Chern Classes of Line Bundles
# - Printed p. 148 / PDF p. 163: Some Vanishing Theorems and Corollaries
# - Printed p. 148 / PDF p. 163: The Kodaira Vanishing Theorem
# - Printed p. 156 / PDF p. 171: The Lefschetz Theorem on Hyperplane Sections
# - Printed p. 159 / PDF p. 174: Theorem B
# - Printed p. 161 / PDF p. 176: The Lefschetz Theorem on (1,1)-classes
# - Printed p. 164 / PDF p. 179: Algebraic Varieties
# - Printed p. 164 / PDF p. 179: Analytic and Algebraic Varieties
# - Printed p. 171 / PDF p. 186: Degree of a Variety
# - Printed p. 175 / PDF p. 190: Tangent Spaces to Algebraic Varieties
# - Printed p. 176 / PDF p. 191: The Kodaira Embedding Theorem
# - Printed p. 176 / PDF p. 191: Line Bundles and Maps to Projective Space
# - Printed p. 182 / PDF p. 197: Blowing Up
# - Printed p. 189 / PDF p. 204: Proof of the Kodaira Theorem
# - Printed p. 193 / PDF p. 208: Grassmannians
# - Printed p. 193 / PDF p. 208: Definitions
# - Printed p. 194 / PDF p. 209: The Cell Decomposition
# - Printed p. 197 / PDF p. 212: The Schubert Calculus
# - Printed p. 207 / PDF p. 222: Universal Bundles
# - Printed p. 209 / PDF p. 224: The Plucker Embedding
#
# Use this index as a navigation map only. The chapter notebook contains the original standalone lesson, visuals, and checks.

# %%
from pathlib import Path
notebook = Path('01-complex-algebraic-varieties.ipynb')
artifact_root = Path('../artifacts/chapter-01')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

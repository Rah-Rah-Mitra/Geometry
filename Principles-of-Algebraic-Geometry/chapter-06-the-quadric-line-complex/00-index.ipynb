# %% [markdown]
# # Chapter 06: The Quadric Line Complex
#
# **Source span.** Printed pages 733-804; PDF pages 748-819.
#
# **Canonical notebook.** [06-the-quadric-line-complex.ipynb](06-the-quadric-line-complex.ipynb)
#
# **Artifact root.** `../artifacts/chapter-06`
#
# ## Section Map
#
# - Printed p. 734 / PDF p. 749: Preliminaries: Quadrics
# - Printed p. 734 / PDF p. 749: Rank of a Quadric
# - Printed p. 735 / PDF p. 750: Linear Spaces on Quadrics
# - Printed p. 741 / PDF p. 756: Linear Systems of Quadrics
# - Printed p. 746 / PDF p. 761: Lines on Linear Systems of Quadrics
# - Printed p. 749 / PDF p. 764: The Problem of Five Conies
# - Printed p. 756 / PDF p. 771: The Quadric Line Complex: Introduction
# - Printed p. 756 / PDF p. 771: Geometry of the Grassmannian G(2,4)
# - Printed p. 759 / PDF p. 774: Line Complexes
# - Printed p. 762 / PDF p. 777: The Quadric Line Complex and Associated Kummer Surface I
# - Printed p. 767 / PDF p. 782: Singular Lines of the Quadric Line Complex
# - Printed p. 773 / PDF p. 788: Two Configurations
# - Printed p. 778 / PDF p. 793: Lines on the Quadric Line Complex
# - Printed p. 778 / PDF p. 793: The Variety of Lines on the Quadric Line Complex
# - Printed p. 780 / PDF p. 795: Curves on the Variety of Lines
# - Printed p. 784 / PDF p. 799: Two Configurations Revisited
# - Printed p. 787 / PDF p. 802: The Group Law
# - Printed p. 791 / PDF p. 806: The Quadric Line Complex: Reprise
# - Printed p. 791 / PDF p. 806: The Quadric Line Complex and Associated Kummer Surface II
# - Printed p. 796 / PDF p. 811: Rationality of the Quadric Line Complex
#
# Use this index as a navigation map only. The chapter notebook contains the original standalone lesson, visuals, and checks.

# %%
from pathlib import Path
notebook = Path('06-the-quadric-line-complex.ipynb')
artifact_root = Path('../artifacts/chapter-06')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

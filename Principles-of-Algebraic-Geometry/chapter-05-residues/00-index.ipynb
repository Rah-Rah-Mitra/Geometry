# %% [markdown]
# # Chapter 05: Residues
#
# **Source span.** Printed pages 647-732; PDF pages 662-747.
#
# **Canonical notebook.** [05-residues.ipynb](05-residues.ipynb)
#
# **Artifact root.** `../artifacts/chapter-05`
#
# ## Section Map
#
# - Printed p. 649 / PDF p. 664: Elementary Properties of Residues
# - Printed p. 649 / PDF p. 664: Definition and Cohomological Interpretation
# - Printed p. 655 / PDF p. 670: The Global Residue Theorem
# - Printed p. 656 / PDF p. 671: The Transformation Law and Local Duality
# - Printed p. 662 / PDF p. 677: Applications of Residues
# - Printed p. 662 / PDF p. 677: Intersection Numbers
# - Printed p. 667 / PDF p. 682: Finite Holomorphic Mappings
# - Printed p. 670 / PDF p. 685: Applications to Plane Projective Geometry
# - Printed p. 678 / PDF p. 693: Rudiments of Commutative and Homological Algebra with Applications
# - Printed p. 678 / PDF p. 693: Commutative Algebra
# - Printed p. 682 / PDF p. 697: Homological Algebra
# - Printed p. 687 / PDF p. 702: The Koszul Complex and Applications
# - Printed p. 695 / PDF p. 710: A Brief Tour Through Coherent Sheaves
# - Printed p. 705 / PDF p. 720: Global Duality
# - Printed p. 705 / PDF p. 720: Global Ext
# - Printed p. 707 / PDF p. 722: Explanation of the General Global Duality Theorem
# - Printed p. 708 / PDF p. 723: Global Ext and Vector Fields with Isolated Zeros
# - Printed p. 712 / PDF p. 727: Global Duality and Superabundance of Points on a Surface
# - Printed p. 722 / PDF p. 737: Extensions of Modules
# - Printed p. 726 / PDF p. 741: Points on a Surface and Rank-Two Vector Bundles
# - Printed p. 729 / PDF p. 744: Residues and Vector Bundles
#
# Use this index as a navigation map only. The chapter notebook contains the original standalone lesson, visuals, and checks.

# %%
from pathlib import Path
notebook = Path('05-residues.ipynb')
artifact_root = Path('../artifacts/chapter-05')
assert notebook.exists()
assert artifact_root.exists()
(notebook, artifact_root)

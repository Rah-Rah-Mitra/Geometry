# %% [markdown]
# # Principles of Algebraic Geometry
#
# Author: Phillip Griffiths and Joseph Harris
#
# This is the book-level index for the visualization-first notebook course. Each canonical chapter notebook is source-grounded, original in prose and code, and backed by local artifact checks.
#
# | Chapter | Title | Printed pages | PDF pages | Notebook | Artifact topic |
# |---|---|---:|---:|---|---|
# | Chapter 00 | Foundational Material | 1-127 | 16-142 | [00-foundational-material.ipynb](chapter-00-foundational-material/00-foundational-material.ipynb) | `chapter-00` |
# | Chapter 01 | Complex Algebraic Varieties | 128-211 | 143-226 | [01-complex-algebraic-varieties.ipynb](chapter-01-complex-algebraic-varieties/01-complex-algebraic-varieties.ipynb) | `chapter-01` |
# | Chapter 02 | Riemann Surfaces and Algebraic Curves | 212-363 | 227-378 | [02-riemann-surfaces-and-algebraic-curves.ipynb](chapter-02-riemann-surfaces-and-algebraic-curves/02-riemann-surfaces-and-algebraic-curves.ipynb) | `chapter-02` |
# | Chapter 03 | Further Techniques | 364-468 | 379-483 | [03-further-techniques.ipynb](chapter-03-further-techniques/03-further-techniques.ipynb) | `chapter-03` |
# | Chapter 04 | Surfaces | 469-646 | 484-661 | [04-surfaces.ipynb](chapter-04-surfaces/04-surfaces.ipynb) | `chapter-04` |
# | Chapter 05 | Residues | 647-732 | 662-747 | [05-residues.ipynb](chapter-05-residues/05-residues.ipynb) | `chapter-05` |
# | Chapter 06 | The Quadric Line Complex | 733-804 | 748-819 | [06-the-quadric-line-complex.ipynb](chapter-06-the-quadric-line-complex/06-the-quadric-line-complex.ipynb) | `chapter-06` |

# %%
from pathlib import Path
root = Path.cwd()
notebooks = [
    root / 'chapter-00-foundational-material' / '00-foundational-material.ipynb',
    root / 'chapter-01-complex-algebraic-varieties' / '01-complex-algebraic-varieties.ipynb',
    root / 'chapter-02-riemann-surfaces-and-algebraic-curves' / '02-riemann-surfaces-and-algebraic-curves.ipynb',
    root / 'chapter-03-further-techniques' / '03-further-techniques.ipynb',
    root / 'chapter-04-surfaces' / '04-surfaces.ipynb',
    root / 'chapter-05-residues' / '05-residues.ipynb',
    root / 'chapter-06-the-quadric-line-complex' / '06-the-quadric-line-complex.ipynb',
]
missing = [path for path in notebooks if not path.exists()]
assert not missing, missing
len(notebooks)

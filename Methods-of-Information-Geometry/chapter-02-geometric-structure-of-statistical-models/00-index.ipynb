# %% [markdown]
# # Chapter 02: The geometric structure of statistical models
#
# Canonical notebook: [02-geometric-structure-of-statistical-models.ipynb](02-geometric-structure-of-statistical-models.ipynb).
#
# Source span: printed pp. 25-50; physical DjVu pp. 34-59.
#
# Focus terms: statistical model, Fisher metric, alpha-connection, Chentsov, simplex, alpha-family.
#
# Statistical models, Fisher metric, alpha-connection, Chentsov invariance, probability simplex geometry, alpha-affine manifolds, and alpha-families.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-02-geometric-structure-of-statistical-models' / '02-geometric-structure-of-statistical-models.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

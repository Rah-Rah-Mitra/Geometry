# %% [markdown]
# # Chapter 08: Miscellaneous topics
#
# Canonical notebook: [08-miscellaneous-topics.ipynb](08-miscellaneous-topics.ipynb).
#
# Source span: printed pp. 167-180; physical DjVu pp. 176-189.
#
# Focus terms: convex analysis, gradient flow, neuro-manifold, Lie group, transformation model, open problems.
#
# Convex analysis, linear programming, gradient flows, neuro-manifolds, nonlinear systems, Lie groups, transformation models, and mathematical problems posed by information geometry.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-08-miscellaneous-topics' / '08-miscellaneous-topics.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

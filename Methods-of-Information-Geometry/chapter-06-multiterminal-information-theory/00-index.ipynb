# %% [markdown]
# # Chapter 06: Multiterminal information theory and statistical inference
#
# Canonical notebook: [06-multiterminal-information-theory.ipynb](06-multiterminal-information-theory.ipynb).
#
# Source span: printed pp. 133-144; physical DjVu pp. 142-153.
#
# Focus terms: multiterminal information, zero-rate testing, zero-rate estimation, mutual information, projection.
#
# Multiterminal information, zero-rate testing, zero-rate estimation, and inference for general multiterminal information.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-06-multiterminal-information-theory' / '06-multiterminal-information-theory.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

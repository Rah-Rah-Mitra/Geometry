# %% [markdown]
# # Chapter 03: Dual connections
#
# Canonical notebook: [03-dual-connections.ipynb](03-dual-connections.ipynb).
#
# Source span: printed pp. 51-80; physical DjVu pp. 60-89.
#
# Focus terms: dual connection, divergence, dually flat, canonical divergence, exponential family, triangular relation.
#
# Duality of connections, divergences as contrast functions, dually flat spaces, canonical divergence, exponential-family duality, alpha-affine duality, mutually dual foliations, and the triangular relation.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-03-dual-connections' / '03-dual-connections.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

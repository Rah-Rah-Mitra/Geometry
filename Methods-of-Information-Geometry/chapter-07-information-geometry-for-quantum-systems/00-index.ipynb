# %% [markdown]
# # Chapter 07: Information geometry for quantum systems
#
# Canonical notebook: [07-information-geometry-for-quantum-systems.ipynb](07-information-geometry-for-quantum-systems.ipynb).
#
# Source span: printed pp. 145-166; physical DjVu pp. 154-175.
#
# Focus terms: quantum state, density matrix, quantum divergence, generalized covariance, quantum estimation.
#
# Quantum state space, geometry induced by quantum divergences, geometry from generalized covariance, and applications to quantum estimation theory.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-07-information-geometry-for-quantum-systems' / '07-information-geometry-for-quantum-systems.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

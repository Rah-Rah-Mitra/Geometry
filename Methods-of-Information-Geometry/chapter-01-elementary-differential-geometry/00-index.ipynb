# %% [markdown]
# # Chapter 01: Elementary differential geometry
#
# Canonical notebook: [01-elementary-differential-geometry.ipynb](01-elementary-differential-geometry.ipynb).
#
# Source span: printed pp. 1-24; physical DjVu pp. 10-33.
#
# Focus terms: tangent space, metric, affine connection, flatness, autoparallel, curvature.
#
# Differentiable manifolds, tangent spaces, vector and tensor fields, Riemannian metrics, affine connections, flatness, autoparallel submanifolds, projected connections, embedding curvature, and the Riemannian connection.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-01-elementary-differential-geometry' / '01-elementary-differential-geometry.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

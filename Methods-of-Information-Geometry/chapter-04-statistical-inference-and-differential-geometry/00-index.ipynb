# %% [markdown]
# # Chapter 04: Statistical inference and differential geometry
#
# Canonical notebook: [04-statistical-inference-and-differential-geometry.ipynb](04-statistical-inference-and-differential-geometry.ipynb).
#
# Source span: printed pp. 81-114; physical DjVu pp. 90-123.
#
# Focus terms: estimation, observed point, curved exponential family, efficiency, asymptotics, fiber bundle.
#
# Independent-observation inference, observed points, exponential and curved exponential families, consistency, first-order efficiency, higher-order asymptotics, tests, estimating functions, and fiber-bundle viewpoints.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-04-statistical-inference-and-differential-geometry' / '04-statistical-inference-and-differential-geometry.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

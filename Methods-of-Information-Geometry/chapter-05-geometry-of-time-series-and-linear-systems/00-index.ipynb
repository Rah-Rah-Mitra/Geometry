# %% [markdown]
# # Chapter 05: The geometry of time series and linear systems
#
# Canonical notebook: [05-geometry-of-time-series-and-linear-systems.ipynb](05-geometry-of-time-series-and-linear-systems.ipynb).
#
# Source span: printed pp. 115-132; physical DjVu pp. 124-141.
#
# Focus terms: time series, linear system, spectrum, Fisher metric, alpha-connection, stable feedback.
#
# System and time-series spaces, Fisher metric and alpha-connection on system space, finite-dimensional model geometry, stable systems, and stable feedback.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'Methods of Information Geometry.djvu').exists())
expected = BOOK_ROOT / 'chapter-05-geometry-of-time-series-and-linear-systems' / '05-geometry-of-time-series-and-linear-systems.ipynb'
assert expected.exists(), expected
print(expected.relative_to(BOOK_ROOT))

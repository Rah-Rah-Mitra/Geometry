# %% [markdown]
# # Chapter 16: Simplex Range Searching
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [16-simplex-range-searching.ipynb](16-simplex-range-searching.ipynb)
# - Source span: printed pages 335-356; PDF pages 346-367
# - Visual center: partition trees, multi-level partition trees, cutting trees, simplex queries
# - Artifact topic: `artifacts/chapter-16`

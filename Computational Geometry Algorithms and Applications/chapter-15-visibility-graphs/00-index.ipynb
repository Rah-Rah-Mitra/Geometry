# %% [markdown]
# # Chapter 15: Visibility Graphs
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [15-visibility-graphs.ipynb](15-visibility-graphs.ipynb)
# - Source span: printed pages 323-334; PDF pages 334-345
# - Visual center: shortest paths, visibility graph construction, translating polygonal robots
# - Artifact topic: `artifacts/chapter-15`

# %% [markdown]
# # Chapter 04: Linear Programming
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [04-linear-programming.ipynb](04-linear-programming.ipynb)
# - Source span: printed pages 63-94; PDF pages 74-105
# - Visual center: half-plane intersection, randomized incremental LP, unbounded cases, smallest disks
# - Artifact topic: `artifacts/chapter-04`

# %% [markdown]
# # Chapter 13: Robot Motion Planning
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [13-robot-motion-planning.ipynb](13-robot-motion-planning.ipynb)
# - Source span: printed pages 283-306; PDF pages 294-317
# - Visual center: work space, configuration space, Minkowski sums, translational and rotational planning
# - Artifact topic: `artifacts/chapter-13`

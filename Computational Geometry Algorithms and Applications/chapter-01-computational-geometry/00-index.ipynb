# %% [markdown]
# # Chapter 01: Computational Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [01-computational-geometry.ipynb](01-computational-geometry.ipynb)
# - Source span: printed pages 1-18; PDF pages 12-29
# - Visual center: convex hulls, orientation predicates, degeneracy, robustness, application map
# - Artifact topic: `artifacts/chapter-01`

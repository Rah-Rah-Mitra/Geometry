# %% [markdown]
# # Chapter 09: Delaunay Triangulations
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [09-delaunay-triangulations.ipynb](09-delaunay-triangulations.ipynb)
# - Source span: printed pages 191-218; PDF pages 202-229
# - Visual center: planar triangulations, Delaunay empty circle property, lifting, randomized construction
# - Artifact topic: `artifacts/chapter-09`

# %% [markdown]
# # Chapter 03: Polygon Triangulation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [03-polygon-triangulation.ipynb](03-polygon-triangulation.ipynb)
# - Source span: printed pages 45-62; PDF pages 56-73
# - Visual center: art-gallery theorem, monotone decomposition, stack triangulation
# - Artifact topic: `artifacts/chapter-03`

# %% [markdown]
# # Chapter 06: Point Location
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [06-point-location.ipynb](06-point-location.ipynb)
# - Source span: printed pages 121-146; PDF pages 132-157
# - Visual center: trapezoidal maps, randomized incremental construction, search DAG, degeneracies
# - Artifact topic: `artifacts/chapter-06`

# %% [markdown]
# # Chapter 02: Line Segment Intersection
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [02-line-segment-intersection.ipynb](02-line-segment-intersection.ipynb)
# - Source span: printed pages 19-44; PDF pages 30-55
# - Visual center: sweep line events, output sensitivity, event queue, status order, DCEL overlay
# - Artifact topic: `artifacts/chapter-02`

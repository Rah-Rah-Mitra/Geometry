# %% [markdown]
# # Chapter 11: Convex Hulls
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [11-convex-hulls.ipynb](11-convex-hulls.ipynb)
# - Source span: printed pages 243-258; PDF pages 254-269
# - Visual center: 3D convex hull complexity, randomized incremental hulls, half-space and Voronoi links
# - Artifact topic: `artifacts/chapter-11`

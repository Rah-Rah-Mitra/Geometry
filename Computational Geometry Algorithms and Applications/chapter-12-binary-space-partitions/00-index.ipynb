# %% [markdown]
# # Chapter 12: Binary Space Partitions
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [12-binary-space-partitions.ipynb](12-binary-space-partitions.ipynb)
# - Source span: printed pages 259-282; PDF pages 270-293
# - Visual center: BSP trees, painter ordering, segment splitting, low-density scenes
# - Artifact topic: `artifacts/chapter-12`

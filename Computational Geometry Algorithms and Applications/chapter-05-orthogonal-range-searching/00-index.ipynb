# %% [markdown]
# # Chapter 05: Orthogonal Range Searching
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [05-orthogonal-range-searching.ipynb](05-orthogonal-range-searching.ipynb)
# - Source span: printed pages 95-120; PDF pages 106-131
# - Visual center: 1D range searching, kd-trees, range trees, higher dimensions, fractional cascading
# - Artifact topic: `artifacts/chapter-05`

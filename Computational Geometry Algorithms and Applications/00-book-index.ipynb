# %% [markdown]
# # Computational Geometry Algorithms and Applications - Standalone Notebook Course
#
# This original visualization-first course follows the 16-chapter structure of the third edition. Generated artifacts live under `artifacts/chapter-XX`.
#
# Body printed pages map to PDF pages by `pdf_page = printed_page + 11`.
#
# - [Chapter 01: Computational Geometry](chapter-01-computational-geometry/00-index.ipynb) - [canonical notebook](chapter-01-computational-geometry/01-computational-geometry.ipynb); printed pages 1-18; convex hulls, orientation predicates, degeneracy, robustness, application map.
# - [Chapter 02: Line Segment Intersection](chapter-02-line-segment-intersection/00-index.ipynb) - [canonical notebook](chapter-02-line-segment-intersection/02-line-segment-intersection.ipynb); printed pages 19-44; sweep line events, output sensitivity, event queue, status order, DCEL overlay.
# - [Chapter 03: Polygon Triangulation](chapter-03-polygon-triangulation/00-index.ipynb) - [canonical notebook](chapter-03-polygon-triangulation/03-polygon-triangulation.ipynb); printed pages 45-62; art-gallery theorem, monotone decomposition, stack triangulation.
# - [Chapter 04: Linear Programming](chapter-04-linear-programming/00-index.ipynb) - [canonical notebook](chapter-04-linear-programming/04-linear-programming.ipynb); printed pages 63-94; half-plane intersection, randomized incremental LP, unbounded cases, smallest disks.
# - [Chapter 05: Orthogonal Range Searching](chapter-05-orthogonal-range-searching/00-index.ipynb) - [canonical notebook](chapter-05-orthogonal-range-searching/05-orthogonal-range-searching.ipynb); printed pages 95-120; 1D range searching, kd-trees, range trees, higher dimensions, fractional cascading.
# - [Chapter 06: Point Location](chapter-06-point-location/00-index.ipynb) - [canonical notebook](chapter-06-point-location/06-point-location.ipynb); printed pages 121-146; trapezoidal maps, randomized incremental construction, search DAG, degeneracies.
# - [Chapter 07: Voronoi Diagrams](chapter-07-voronoi-diagrams/00-index.ipynb) - [canonical notebook](chapter-07-voronoi-diagrams/07-voronoi-diagrams.ipynb); printed pages 147-172; Voronoi cells, Fortune sweep intuition, line-segment sites, farthest-point diagrams.
# - [Chapter 08: Arrangements and Duality](chapter-08-arrangements-and-duality/00-index.ipynb) - [canonical notebook](chapter-08-arrangements-and-duality/08-arrangements-and-duality.ipynb); printed pages 173-190; line arrangements, point-line duality, levels, discrepancy.
# - [Chapter 09: Delaunay Triangulations](chapter-09-delaunay-triangulations/00-index.ipynb) - [canonical notebook](chapter-09-delaunay-triangulations/09-delaunay-triangulations.ipynb); printed pages 191-218; planar triangulations, Delaunay empty circle property, lifting, randomized construction.
# - [Chapter 10: More Geometric Data Structures](chapter-10-more-geometric-data-structures/00-index.ipynb) - [canonical notebook](chapter-10-more-geometric-data-structures/10-more-geometric-data-structures.ipynb); printed pages 219-242; interval trees, priority search trees, segment trees, stabbing/window queries.
# - [Chapter 11: Convex Hulls](chapter-11-convex-hulls/00-index.ipynb) - [canonical notebook](chapter-11-convex-hulls/11-convex-hulls.ipynb); printed pages 243-258; 3D convex hull complexity, randomized incremental hulls, half-space and Voronoi links.
# - [Chapter 12: Binary Space Partitions](chapter-12-binary-space-partitions/00-index.ipynb) - [canonical notebook](chapter-12-binary-space-partitions/12-binary-space-partitions.ipynb); printed pages 259-282; BSP trees, painter ordering, segment splitting, low-density scenes.
# - [Chapter 13: Robot Motion Planning](chapter-13-robot-motion-planning/00-index.ipynb) - [canonical notebook](chapter-13-robot-motion-planning/13-robot-motion-planning.ipynb); printed pages 283-306; work space, configuration space, Minkowski sums, translational and rotational planning.
# - [Chapter 14: Quadtrees](chapter-14-quadtrees/00-index.ipynb) - [canonical notebook](chapter-14-quadtrees/14-quadtrees.ipynb); printed pages 307-322; uniform and non-uniform meshes, quadtrees for points, balanced refinement.
# - [Chapter 15: Visibility Graphs](chapter-15-visibility-graphs/00-index.ipynb) - [canonical notebook](chapter-15-visibility-graphs/15-visibility-graphs.ipynb); printed pages 323-334; shortest paths, visibility graph construction, translating polygonal robots.
# - [Chapter 16: Simplex Range Searching](chapter-16-simplex-range-searching/00-index.ipynb) - [canonical notebook](chapter-16-simplex-range-searching/16-simplex-range-searching.ipynb); printed pages 335-356; partition trees, multi-level partition trees, cutting trees, simplex queries.

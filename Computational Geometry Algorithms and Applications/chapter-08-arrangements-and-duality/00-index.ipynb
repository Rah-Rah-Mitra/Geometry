# %% [markdown]
# # Chapter 08: Arrangements and Duality
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [08-arrangements-and-duality.ipynb](08-arrangements-and-duality.ipynb)
# - Source span: printed pages 173-190; PDF pages 184-201
# - Visual center: line arrangements, point-line duality, levels, discrepancy
# - Artifact topic: `artifacts/chapter-08`

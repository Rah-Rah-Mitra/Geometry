# %% [markdown]
# # Chapter 10: More Geometric Data Structures
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [10-more-geometric-data-structures.ipynb](10-more-geometric-data-structures.ipynb)
# - Source span: printed pages 219-242; PDF pages 230-253
# - Visual center: interval trees, priority search trees, segment trees, stabbing/window queries
# - Artifact topic: `artifacts/chapter-10`

# %% [markdown]
# # Chapter 14: Quadtrees
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [14-quadtrees.ipynb](14-quadtrees.ipynb)
# - Source span: printed pages 307-322; PDF pages 318-333
# - Visual center: uniform and non-uniform meshes, quadtrees for points, balanced refinement
# - Artifact topic: `artifacts/chapter-14`

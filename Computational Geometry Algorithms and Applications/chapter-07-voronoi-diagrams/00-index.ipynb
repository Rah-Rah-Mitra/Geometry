# %% [markdown]
# # Chapter 07: Voronoi Diagrams
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [07-voronoi-diagrams.ipynb](07-voronoi-diagrams.ipynb)
# - Source span: printed pages 147-172; PDF pages 158-183
# - Visual center: Voronoi cells, Fortune sweep intuition, line-segment sites, farthest-point diagrams
# - Artifact topic: `artifacts/chapter-07`

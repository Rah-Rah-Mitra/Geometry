# %% [markdown]
# # Chapter 5: Intersection and Union of Subspaces
#
# Printed-page anchor in the textbook: pp. 125-140. The notebook here is original, executable study material for the same conceptual territory, with PDF heading verification, numerical checks, and saved visual artifacts.
#
# ## Notebook Map
#
# - [05 Intersection and Union of Subspaces](05-intersection-and-union-of-subspaces.ipynb)
#
# ## Chapter Coverage
#
# - meet and join as incidence operations on blades and coordinate subspaces
# - outer factorization and the role of common blade factors
# - sign conventions, argument order, and orientation-sensitive meets
# - mostly-linear behavior inside a fixed join, including degeneracy signals
# - quantitative meet magnitude as a sine-like attitude measure
# - covariance of meet and join under invertible linear transformations
# - offset subspaces through homogeneous coordinates
# - floating-point behavior near parallelism and other join changes
# - interactive line-plane and homogeneous line-meet visuals
#
# ## Generated Artifacts
#
# - `D:/Geometry/artifacts/chapter-05/pdf/heading-audit.json`
# - `D:/Geometry/artifacts/chapter-05/checks/final-sanity-checks.json`
# - `D:/Geometry/artifacts/chapter-05/plots/mostly-linear-meet.png`
# - `D:/Geometry/artifacts/chapter-05/plots/quantitative-meet.png`
# - `D:/Geometry/artifacts/chapter-05/interactive/line-plane-intersection.html`
# - `D:/Geometry/artifacts/chapter-05/interactive/homogeneous-line-meet.html`

# %% [markdown]
# ## Study Strategy
#
# Run the notebook top to bottom once, then revisit the sign, mostly-linear, and floating-point sections with changed inputs. The most important habit in this chapter is to keep the chosen join visible while interpreting the meet.

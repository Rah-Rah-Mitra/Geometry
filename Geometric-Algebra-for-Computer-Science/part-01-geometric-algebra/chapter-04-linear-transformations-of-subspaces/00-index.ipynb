# %% [markdown]
# # Chapter 4: Linear Transformations of Subspaces
#
# Printed-page span verified from the textbook PDF: pp. 99-123, with p. 125 starting Chapter 5. The requested pp. 99-124 range includes no additional Chapter 4 text on p. 124 in this PDF copy. The notebook here is original, executable study material for the same conceptual territory.
#
# ## Notebook Map
#
# - [Linear Transformations of Subspaces](04-linear-transformations-of-subspaces.ipynb)
#
# ## Chapter Coverage
#
# - vector linear maps and their linearity checks
# - outermorphisms as grade-aware transformations of blades
# - determinants as top-grade signed-volume scaling
# - adjoints and transformed scalar products
# - transformed contractions and the inverse-adjoint correction
# - dual transformations and normal-vector behavior
# - matrix representations of outermorphisms by exterior powers
# - projection and normal-vector programming labs
# - interactive SVG/widget visuals and invariant checks

# %% [markdown]
# ## Study Strategy
#
# Run the standalone notebook once from top to bottom, then revisit the widget cells. The fastest way to build intuition is to change one transform parameter at a time and watch which invariants survive unchanged.

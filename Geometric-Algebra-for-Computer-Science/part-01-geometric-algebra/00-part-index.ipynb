# %% [markdown]
# # Part I: Geometric Algebra
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Each entry links to the chapter or appendix index and directly to the canonical authored notebook.
#
# ## Chapter 01: Why Geometric Algebra?
#
# - Index: [chapter-01-why-geometric-algebra](chapter-01-why-geometric-algebra/00-index.ipynb)
# - Canonical notebook: [01-why-geometric-algebra.ipynb](chapter-01-why-geometric-algebra/01-why-geometric-algebra.ipynb)
# - Source span: pp. 1-22
# - Focus: motivation, constructions, transformations, invariants
#
# ## Chapter 02: Spanning Oriented Subspaces
#
# - Index: [chapter-02-spanning-oriented-subspaces](chapter-02-spanning-oriented-subspaces/00-index.ipynb)
# - Canonical notebook: [02-spanning-oriented-subspaces.ipynb](chapter-02-spanning-oriented-subspaces/02-spanning-oriented-subspaces.ipynb)
# - Source span: pp. 23-64
# - Focus: outer products, blades, Grassmann algebra, programming labs
#
# ## Chapter 03: Metric Products of Subspaces
#
# - Index: [chapter-03-metric-products-of-subspaces](chapter-03-metric-products-of-subspaces/00-index.ipynb)
# - Canonical notebook: [03-metric-products-of-subspaces.ipynb](chapter-03-metric-products-of-subspaces/03-metric-products-of-subspaces.ipynb)
# - Source span: pp. 65-98
# - Focus: metrics, contractions, duality, projections, reciprocal frames
#
# ## Chapter 04: Linear Transformations of Subspaces
#
# - Index: [chapter-04-linear-transformations-of-subspaces](chapter-04-linear-transformations-of-subspaces/00-index.ipynb)
# - Canonical notebook: [04-linear-transformations-of-subspaces.ipynb](chapter-04-linear-transformations-of-subspaces/04-linear-transformations-of-subspaces.ipynb)
# - Source span: pp. 99-124
# - Focus: outermorphisms, determinants, adjoints, transformed products
#
# ## Chapter 05: Intersection and Union of Subspaces
#
# - Index: [chapter-05-intersection-and-union-of-subspaces](chapter-05-intersection-and-union-of-subspaces/00-index.ipynb)
# - Canonical notebook: [05-intersection-and-union-of-subspaces.ipynb](chapter-05-intersection-and-union-of-subspaces/05-intersection-and-union-of-subspaces.ipynb)
# - Source span: pp. 125-140
# - Focus: meet, join, signs, linearity, homogeneous offsets
#
# ## Chapter 06: The Fundamental Product of Geometric Algebra
#
# - Index: [chapter-06-the-fundamental-product-of-geometric-algebra](chapter-06-the-fundamental-product-of-geometric-algebra/00-index.ipynb)
# - Canonical notebook: [06-the-fundamental-product-of-geometric-algebra.ipynb](chapter-06-the-fundamental-product-of-geometric-algebra/06-the-fundamental-product-of-geometric-algebra.ipynb)
# - Source span: pp. 141-166
# - Focus: geometric product, division, projection, reflection, Gram-Schmidt
#
# ## Chapter 07: Orthogonal Transformations as Versors
#
# - Index: [chapter-07-orthogonal-transformations-as-versors](chapter-07-orthogonal-transformations-as-versors/00-index.ipynb)
# - Canonical notebook: [07-rotations-rotors-and-versors.ipynb](chapter-07-orthogonal-transformations-as-versors/07-rotations-rotors-and-versors.ipynb)
# - Source span: pp. 167-212
# - Focus: reflections, rotors, 4pi sense, composition, exponentials, versors
#
# ## Chapter 08: Geometric Differentiation
#
# - Index: [chapter-08-geometric-differentiation](chapter-08-geometric-differentiation/00-index.ipynb)
# - Canonical notebook: [08-geometric-differentiation.ipynb](chapter-08-geometric-differentiation/08-geometric-differentiation.ipynb)
# - Source span: pp. 213-244
# - Focus: commutators, parametric/scalar/directional/vector derivatives

# %%
# geometry-setup:v1
# Machine-managed by scripts/update_notebook_setup.py. Do not edit this cell by hand.

from __future__ import annotations

import json as _geometry_json
import os as _geometry_os
from pathlib import Path as _GeometryPath
import sys as _geometry_sys

GEOMETRY_SETUP = _geometry_json.loads(
    r"""
{
  "colab_url": "https://colab.research.google.com/github/Rah-Rah-Mitra/Geometry/blob/main/Geometric-Algebra-for-Computer-Science/part-01-geometric-algebra/00-part-index.ipynb",
  "course_dir": "Geometric-Algebra-for-Computer-Science",
  "course_title": "Geometric Algebra for Computer Science",
  "github_url": "https://github.com/Rah-Rah-Mitra/Geometry/blob/main/Geometric-Algebra-for-Computer-Science/part-01-geometric-algebra/00-part-index.ipynb",
  "jupyterlite": false,
  "marker": "geometry-setup:v1",
  "notebook_kind": "part-index",
  "notebook_path": "Geometric-Algebra-for-Computer-Science/part-01-geometric-algebra/00-part-index.ipynb",
  "notebook_title": "Part I: Geometric Algebra",
  "repository": {
    "branch": "main",
    "name": "Geometry",
    "owner": "Rah-Rah-Mitra",
    "source_url": "https://github.com/Rah-Rah-Mitra/Geometry"
  },
  "requirements": "requirements/graphics.txt",
  "runtime_profile": "graphics"
}
"""
)


def _geometry_is_colab():
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def _geometry_is_jupyterlite():
    return _geometry_sys.platform == "emscripten" or "pyodide" in _geometry_sys.modules


def _geometry_add_path(path):
    text = str(path)
    if text not in _geometry_sys.path:
        _geometry_sys.path.insert(0, text)


def _geometry_find_repo_root():
    candidates = []
    env_root = _geometry_os.environ.get("GEOMETRY_REPO_ROOT")
    if env_root:
        candidates.append(_GeometryPath(env_root).expanduser())
    candidates.append(_GeometryPath.cwd())
    for start in candidates:
        start = start.resolve()
        for current in (start, *start.parents):
            if (current / "course-manifest.json").exists() and (
                current / "metadata" / "runtime_profiles.yml"
            ).exists():
                return current
    raise RuntimeError(
        "Could not find the Geometry repository root. Start JupyterLab inside the "
        "Geometry checkout or set GEOMETRY_REPO_ROOT."
    )


def _geometry_run(command):
    import subprocess as _geometry_subprocess

    printable = " ".join(str(part) for part in command)
    print(f"+ {printable}")
    _geometry_subprocess.check_call([str(part) for part in command])


def _geometry_requirement_names(requirements_path, seen=None):
    seen = set() if seen is None else seen
    requirements_path = requirements_path.resolve()
    if requirements_path in seen or not requirements_path.exists():
        return []
    seen.add(requirements_path)
    names = []
    for raw_line in requirements_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.split("#", 1)[0].strip()
        if not line:
            continue
        if line.startswith(("-r ", "--requirement ")):
            _, nested = line.split(maxsplit=1)
            names.extend(_geometry_requirement_names(requirements_path.parent / nested, seen))
            continue
        if line.startswith("-"):
            continue
        name = line
        for separator in ("==", ">=", "<=", "~=", "!=", ">", "<", ";"):
            name = name.split(separator, 1)[0]
        name = name.split("[", 1)[0].strip()
        if name:
            names.append(name)
    return sorted(set(names))


def _geometry_missing_requirements(requirements_path):
    import importlib.metadata as _geometry_metadata

    missing = []
    for name in _geometry_requirement_names(requirements_path):
        try:
            _geometry_metadata.distribution(name)
        except _geometry_metadata.PackageNotFoundError:
            missing.append(name)
    return missing


def _geometry_configured_roots(repo_root):
    course_dir = GEOMETRY_SETUP.get("course_dir")
    course_root = repo_root / course_dir if course_dir else repo_root
    return repo_root, course_root


if _geometry_is_jupyterlite():
    if not GEOMETRY_SETUP["jupyterlite"]:
        raise RuntimeError(
            "This Geometry notebook uses runtime profile "
            f"{GEOMETRY_SETUP['runtime_profile']!r}, which is not enabled for "
            "JupyterLite in course-manifest.json. Open it in Colab or local JupyterLab."
        )
    GEOMETRY_REPO_ROOT = _GeometryPath.cwd()
    GEOMETRY_COURSE_ROOT = (
        GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["course_dir"]
        if GEOMETRY_SETUP.get("course_dir")
        else GEOMETRY_REPO_ROOT
    )
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    if GEOMETRY_COURSE_ROOT.exists():
        _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        "Geometry setup: JupyterLite/Pyodide detected; shell, git, and pip steps "
        "were skipped."
    )
elif _geometry_is_colab():
    repository = GEOMETRY_SETUP["repository"]
    repo_url = repository["source_url"].rstrip("/") + ".git"
    branch = repository["branch"]
    GEOMETRY_REPO_ROOT = _GeometryPath(
        _geometry_os.environ.get("GEOMETRY_REPO_ROOT", "/content/Geometry")
    )
    sparse_paths = ["requirements", "metadata", "scripts", "course-manifest.json", "index.ipynb"]
    if GEOMETRY_SETUP.get("course_dir"):
        sparse_paths.append(GEOMETRY_SETUP["course_dir"])
    if not (GEOMETRY_REPO_ROOT / ".git").exists():
        if GEOMETRY_REPO_ROOT.exists() and any(GEOMETRY_REPO_ROOT.iterdir()):
            raise RuntimeError(
                f"{GEOMETRY_REPO_ROOT} exists but is not a git checkout. "
                "Set GEOMETRY_REPO_ROOT to an empty path or remove the directory."
            )
        _geometry_run(
            [
                "git",
                "clone",
                "--filter=blob:none",
                "--no-checkout",
                "--branch",
                branch,
                repo_url,
                GEOMETRY_REPO_ROOT,
            ]
        )
        _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "init", "--cone"])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "set", *sparse_paths])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "checkout", branch])
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-q", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: Colab ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )
else:
    GEOMETRY_REPO_ROOT = _geometry_find_repo_root()
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    missing = _geometry_missing_requirements(requirements_path)
    skip_install = _geometry_os.environ.get("GEOMETRY_SKIP_INSTALL") == "1"
    if missing and skip_install:
        print(
            "Geometry setup: GEOMETRY_SKIP_INSTALL=1, so missing profile packages "
            f"were not installed: {', '.join(missing)}"
        )
    elif missing:
        print(
            "Geometry setup: installing missing profile packages from "
            f"{requirements_path.relative_to(GEOMETRY_REPO_ROOT)}: {', '.join(missing)}"
        )
        _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: local checkout ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )

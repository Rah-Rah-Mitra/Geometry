# %% [markdown]
# # Chapter 7: Orthogonal Transformations as Versors
#
# Printed-page anchor in the textbook: pp. 167-212. The workspace PDF span was verified by headings as PDF pages 197-242.
#
# ## Notebook Map
#
# - [07 Rotations, Rotors, and Versors](07-rotations-rotors-and-versors.ipynb)
#
# This replacement notebook is standalone and covers reflections, double reflections, rotors, 4pi sense, composition, complex and quaternion links, exponential/logarithmic rotor forms, interpolation, subspaces as operators, versors, and a real-vector Julia fractal example. Generated figures and checks are saved under `artifacts/chapter-07`.

# %% [markdown]
# ## Study Strategy
#
# Run the notebook from top to bottom once, then revisit the saved Plotly artifacts. The most important habit is to test every transformation as an operator: check preserved norms, compare products before and after transformation, and watch whether a rotor sign represents a path choice rather than a different final vector position.

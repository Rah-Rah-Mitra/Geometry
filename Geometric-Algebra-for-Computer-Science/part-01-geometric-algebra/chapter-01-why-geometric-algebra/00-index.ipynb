# %% [markdown]
# # Chapter 1: Why Geometric Algebra?
#
# Printed-page anchor in the textbook: Chapter 1, pp. 1-19 in the available PDF text extraction, with the requested pp. 1-22 range checked and Chapter 2 beginning at p. 23.
#
# ## Canonical Notebook
#
# - [01 - Why Geometric Algebra?](01-why-geometric-algebra.ipynb)
#
# This notebook is the standalone Chapter 1 study path. It includes original prose, a translation guide, a route map, interactive Plotly artifacts, worked examples, and executable sanity checks.

# %% [markdown]
# ## Study Strategy
#
# Start with the translation guide, then run every code cell in order. The plots are designed to be inspected interactively: rotate the 3-D views, use the rotation slider, and compare plane reflection with sphere inversion. Treat the sanity-check cell as the chapter contract; if you change the handles, the invariants should still explain what changed.

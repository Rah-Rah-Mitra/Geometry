# %% [markdown]
# # Chapter 2: Spanning Oriented Subspaces
#
# Printed-page span in the textbook: pp. 23-64. In the local PDF this corresponds to PDF pages 55-96; PDF page 97 begins Chapter 3.
#
# ## Notebook Map
#
# - [02 Spanning Oriented Subspaces](02-spanning-oriented-subspaces.ipynb)
#
# ## Chapter Coverage
#
# - Vector spaces as modeling spaces
# - Oriented line elements, bivectors, and trivectors
# - Outer-product antisymmetry, associativity, and grade raising
# - Scalars as grade-zero blades
# - Bivector ratios for linear equations and planar line intersections
# - Direct homogeneous subspace representation and containment
# - Blades, k-vectors, multivectors, and Grassmann algebra
# - Reversion and grade involution
# - Drawing bivectors, backface culling, and singularity detection labs
# - Final invariant checks saved under `artifacts/chapter-02/checks`

# %% [markdown]
# ## Study Strategy
#
# Read the prose cells first, then re-run the code cells after perturbing the input vectors. The chapter becomes much less mysterious when the invariants survive: self-wedges vanish, orientation signs flip predictably, and containment tests stay zero for the right geometric reason.

# %% [markdown]
# # Chapter 6: The Fundamental Product of Geometric Algebra
#
# Printed-page anchor in the textbook: pp. 141-166. The replacement notebook here is original, executable study material for the same conceptual territory.
#
# ## Notebook Map
#
# - [06 The Fundamental Product of Geometric Algebra](06-the-fundamental-product-of-geometric-algebra.ipynb)
#
# ## Chapter Coverage
#
# - vector geometric product
# - symmetry and antisymmetry in vector products
# - basis-vector rules for the geometric product
# - dividing by a vector
# - ratios of vectors as operators
# - geometric product of multivectors
# - retrieving outer products and contractions by grade selection
# - projection, rejection, and reflection by blade division
# - Gram-Schmidt orthogonalization as a blade-division lab

# %% [markdown]
# ## Study Strategy
#
# Work through the replacement notebook from top to bottom, then revisit the interactive cells with changed inputs. The final cell writes a quality-gate and sanity-check report into `artifacts/chapter-06/checks`.

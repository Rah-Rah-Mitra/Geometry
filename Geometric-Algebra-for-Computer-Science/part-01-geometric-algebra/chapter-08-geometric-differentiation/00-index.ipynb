# %% [markdown]
# # Chapter 8: Geometric Differentiation
#
# Printed-page span audited in the textbook PDF: pp. 213-244. The extractable Chapter 8 text in this scan runs through p. 241, followed by the next chapter opening on p. 245.
#
# ## Notebook Map
#
# - [08 Geometric Differentiation](08-geometric-differentiation.ipynb)
#
# ## Chapter Coverage
#
# - geometrical changes by orthogonal transformations
# - transformational changes and the commutator product
# - rotor-induced changes and changes of transformations
# - parametric and scalar differentiation
# - directional differentiation and vector inversion
# - tilting a mirror as a local rotor calculation
# - vector differentiation and elementary vector-derivative checks
# - multivector differentiation by blade-coordinate perturbation
# - spherical projection and tangent-space derivatives

# %% [markdown]
# ## Study Strategy
#
# Run the standalone notebook from top to bottom. The saved artifacts in `artifacts/chapter-08` are part of the study path: each one records a finite-difference check, a figure, or the source-heading audit for the chapter.

# %% [markdown]
# # Geometric Algebra for Computer Science - Standalone Notebook Edition
#
#                 This generated course is an original, executable companion and study replacement organized around the textbook's chapter structure. It does not copy the textbook prose; it teaches the concepts with fresh explanations, code checks, artifacts, and solution notebooks.
#
#                 ## Geometric Algebra
#
# - [Chapter 01: Why Geometric Algebra?](part-01-geometric-algebra/chapter-01-why-geometric-algebra/00-index.ipynb)
# - [Chapter 02: Spanning Oriented Subspaces](part-01-geometric-algebra/chapter-02-spanning-oriented-subspaces/00-index.ipynb)
# - [Chapter 03: Metric Products of Subspaces](part-01-geometric-algebra/chapter-03-metric-products-of-subspaces/00-index.ipynb)
# - [Chapter 04: Linear Transformations of Subspaces](part-01-geometric-algebra/chapter-04-linear-transformations-of-subspaces/00-index.ipynb)
# - [Chapter 05: Intersection and Union of Subspaces](part-01-geometric-algebra/chapter-05-intersection-and-union-of-subspaces/00-index.ipynb)
# - [Chapter 06: The Fundamental Product of Geometric Algebra](part-01-geometric-algebra/chapter-06-the-fundamental-product-of-geometric-algebra/00-index.ipynb)
# - [Chapter 07: Orthogonal Transformations as Versors](part-01-geometric-algebra/chapter-07-orthogonal-transformations-as-versors/00-index.ipynb)
# - [Chapter 08: Geometric Differentiation](part-01-geometric-algebra/chapter-08-geometric-differentiation/00-index.ipynb)
# ## Models of Geometry
#
# - [Chapter 09: Modeling Geometries](part-02-models-of-geometry/chapter-09-modeling-geometries/00-index.ipynb)
# - [Chapter 10: The Vector Space Model: The Algebra of Directions](part-02-models-of-geometry/chapter-10-the-vector-space-model-the-algebra-of-directions/00-index.ipynb)
# - [Chapter 11: The Homogeneous Model](part-02-models-of-geometry/chapter-11-the-homogeneous-model/00-index.ipynb)
# - [Chapter 12: Applications of the Homogeneous Model](part-02-models-of-geometry/chapter-12-applications-of-the-homogeneous-model/00-index.ipynb)
# - [Chapter 13: The Conformal Model: Operational Euclidean Geometry](part-02-models-of-geometry/chapter-13-the-conformal-model-operational-euclidean-geometry/00-index.ipynb)
# - [Chapter 14: New Primitives for Euclidean Geometry](part-02-models-of-geometry/chapter-14-new-primitives-for-euclidean-geometry/00-index.ipynb)
# - [Chapter 15: Constructions in Euclidean Geometry](part-02-models-of-geometry/chapter-15-constructions-in-euclidean-geometry/00-index.ipynb)
# - [Chapter 16: Conformal Operators](part-02-models-of-geometry/chapter-16-conformal-operators/00-index.ipynb)
# - [Chapter 17: Operational Models for Geometries](part-02-models-of-geometry/chapter-17-operational-models-for-geometries/00-index.ipynb)
# ## Implementing Geometric Algebra
#
# - [Chapter 18: Implementation Issues](part-03-implementation/chapter-18-implementation-issues/00-index.ipynb)
# - [Chapter 19: Basis Blades and Operations](part-03-implementation/chapter-19-basis-blades-and-operations/00-index.ipynb)
# - [Chapter 20: The Linear Products and Operations](part-03-implementation/chapter-20-the-linear-products-and-operations/00-index.ipynb)
# - [Chapter 21: Fundamental Algorithms for Nonlinear Products](part-03-implementation/chapter-21-fundamental-algorithms-for-nonlinear-products/00-index.ipynb)
# - [Chapter 22: Specializing the Structure for Efficiency](part-03-implementation/chapter-22-specializing-the-structure-for-efficiency/00-index.ipynb)
# - [Chapter 23: Using the Geometry in a Ray-Tracing Application](part-03-implementation/chapter-23-using-the-geometry-in-a-ray-tracing-application/00-index.ipynb)
#
#                 ## Appendices
#
#                 - [Appendix A: Metrics and Null Vectors](part-04-appendices/appendix-a-metrics-and-null-vectors/00-index.ipynb)
# - [Appendix B: Contractions and Other Inner Products](part-04-appendices/appendix-b-contractions-and-other-inner-products/00-index.ipynb)
# - [Appendix C: Subspace Products Retrieved](part-04-appendices/appendix-c-subspace-products-retrieved/00-index.ipynb)
# - [Appendix D: Common Equations](part-04-appendices/appendix-d-common-equations/00-index.ipynb)
#
#                 ## Local Conventions
#
#                 - Shared algebra code lives in `utils.ga`.
#                 - Generated artifacts are written under `artifacts/book-ga-cs`.
#                 - Each chapter folder has concept notebooks plus `exercises-and-solutions.ipynb`.

# %% [markdown]
# # Geometric Algebra for Computer Science - Standalone Notebook Edition
#
# This is an original, executable notebook course organized around the textbook's 23 chapters and four appendices. It is written as a study replacement in the practical sense: the notebooks explain the concepts in fresh prose, derive the working formulas, generate their own diagrams and artifacts, and finish with executable checks. The textbook PDF is not redistributed in the repository.
#
# ## How To Use This Course
#
# - Start with the canonical notebook in each chapter folder; each chapter also has a local `00-index.ipynb` with page-span notes and artifact pointers.
# - Run notebooks top to bottom. Generated figures and checks are written under this book's `artifacts/chapter-XX` and `artifacts/appendices` folders.
# - Shared inspectable code lives under this book's `utils` package, including `utils.ga` and chapter-specific helper modules.
# - The notebooks use original explanations and paraphrased problem framing; they avoid copied textbook prose, page scans, and long verbatim passages.
#
# ## Part I: Geometric Algebra
#
# - [Open Part I: Geometric Algebra Index](part-01-geometric-algebra/00-part-index.ipynb)
# - [Chapter 01: Why Geometric Algebra?](part-01-geometric-algebra/chapter-01-why-geometric-algebra/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-01-why-geometric-algebra/01-why-geometric-algebra.ipynb); pp. 1-22; motivation, constructions, transformations, invariants
# - [Chapter 02: Spanning Oriented Subspaces](part-01-geometric-algebra/chapter-02-spanning-oriented-subspaces/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-02-spanning-oriented-subspaces/02-spanning-oriented-subspaces.ipynb); pp. 23-64; outer products, blades, Grassmann algebra, programming labs
# - [Chapter 03: Metric Products of Subspaces](part-01-geometric-algebra/chapter-03-metric-products-of-subspaces/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-03-metric-products-of-subspaces/03-metric-products-of-subspaces.ipynb); pp. 65-98; metrics, contractions, duality, projections, reciprocal frames
# - [Chapter 04: Linear Transformations of Subspaces](part-01-geometric-algebra/chapter-04-linear-transformations-of-subspaces/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-04-linear-transformations-of-subspaces/04-linear-transformations-of-subspaces.ipynb); pp. 99-124; outermorphisms, determinants, adjoints, transformed products
# - [Chapter 05: Intersection and Union of Subspaces](part-01-geometric-algebra/chapter-05-intersection-and-union-of-subspaces/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-05-intersection-and-union-of-subspaces/05-intersection-and-union-of-subspaces.ipynb); pp. 125-140; meet, join, signs, linearity, homogeneous offsets
# - [Chapter 06: The Fundamental Product of Geometric Algebra](part-01-geometric-algebra/chapter-06-the-fundamental-product-of-geometric-algebra/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-06-the-fundamental-product-of-geometric-algebra/06-the-fundamental-product-of-geometric-algebra.ipynb); pp. 141-166; geometric product, division, projection, reflection, Gram-Schmidt
# - [Chapter 07: Orthogonal Transformations as Versors](part-01-geometric-algebra/chapter-07-orthogonal-transformations-as-versors/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-07-orthogonal-transformations-as-versors/07-rotations-rotors-and-versors.ipynb); pp. 167-212; reflections, rotors, 4pi sense, composition, exponentials, versors
# - [Chapter 08: Geometric Differentiation](part-01-geometric-algebra/chapter-08-geometric-differentiation/00-index.ipynb) - [canonical notebook](part-01-geometric-algebra/chapter-08-geometric-differentiation/08-geometric-differentiation.ipynb); pp. 213-244; commutators, parametric/scalar/directional/vector derivatives
#
# ## Part II: Models of Geometry
#
# - [Open Part II: Models of Geometry Index](part-02-models-of-geometry/00-part-index.ipynb)
# - [Chapter 09: Modeling Geometries](part-02-models-of-geometry/chapter-09-modeling-geometries/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-09-modeling-geometries/09-modeling-geometries.ipynb); pp. 245-246; model-selection bridge and geometry workflows
# - [Chapter 10: The Vector Space Model: The Algebra of Directions](part-02-models-of-geometry/chapter-10-the-vector-space-model-the-algebra-of-directions/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-10-the-vector-space-model-the-algebra-of-directions/10-vector-space-model-algebra-of-directions.ipynb); pp. 247-270; directions, angular relationships, interpolation, point groups
# - [Chapter 11: The Homogeneous Model](part-02-models-of-geometry/chapter-11-the-homogeneous-model/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-11-the-homogeneous-model/11-the-homogeneous-model.ipynb); pp. 271-326; points, flats, incidence, cross ratios, conics, perspective
# - [Chapter 12: Applications of the Homogeneous Model](part-02-models-of-geometry/chapter-12-applications-of-the-homogeneous-model/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-12-applications-of-the-homogeneous-model/12-applications-of-the-homogeneous-model.ipynb); pp. 327-354; Plucker lines, camera geometry, epipolar constraints, reconstruction
# - [Chapter 13: The Conformal Model: Operational Euclidean Geometry](part-02-models-of-geometry/chapter-13-the-conformal-model-operational-euclidean-geometry/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-13-the-conformal-model-operational-euclidean-geometry/13-conformal-model-operational-euclidean-geometry.ipynb); pp. 355-396; null embedding, probes, flats, motors, screw interpolation
# - [Chapter 14: New Primitives for Euclidean Geometry](part-02-models-of-geometry/chapter-14-new-primitives-for-euclidean-geometry/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-14-new-primitives-for-euclidean-geometry/14-new-primitives-for-euclidean-geometry.ipynb); pp. 397-436; rounds, tangents, paraboloids, Voronoi, fitting, kinematics
# - [Chapter 15: Constructions in Euclidean Geometry](part-02-models-of-geometry/chapter-15-constructions-in-euclidean-geometry/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-15-constructions-in-euclidean-geometry/15-constructions-in-euclidean-geometry.ipynb); pp. 437-464; incidence, meet/plunge, tangents, factorization, affine combinations
# - [Chapter 16: Conformal Operators](part-02-models-of-geometry/chapter-16-conformal-operators/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-16-conformal-operators/16-conformal-operators.ipynb); pp. 465-496; inversion, spherical reflection, translations, loxodromes, non-Euclidean models
# - [Chapter 17: Operational Models for Geometries](part-02-models-of-geometry/chapter-17-operational-models-for-geometries/00-index.ipynb) - [canonical notebook](part-02-models-of-geometry/chapter-17-operational-models-for-geometries/17-operational-models-for-geometries.ipynb); pp. 497-502; model synthesis and implementation decision workflow
#
# ## Part III: Implementation
#
# - [Open Part III: Implementation Index](part-03-implementation/00-part-index.ipynb)
# - [Chapter 18: Implementation Issues](part-03-implementation/chapter-18-implementation-issues/00-index.ipynb) - [canonical notebook](part-03-implementation/chapter-18-implementation-issues/18-implementation-issues.ipynb); pp. 503-510; implementation levels, matrices, dense/sparse and symbolic/numeric tradeoffs
# - [Chapter 19: Basis Blades and Operations](part-03-implementation/chapter-19-basis-blades-and-operations/00-index.ipynb) - [canonical notebook](part-03-implementation/chapter-19-basis-blades-and-operations/19-basis-blades-and-operations.ipynb); pp. 511-520; bitmap blades, signs, basis products, nonorthogonal metrics
# - [Chapter 20: The Linear Products and Operations](part-03-implementation/chapter-20-the-linear-products-and-operations/00-index.ipynb) - [canonical notebook](part-03-implementation/chapter-20-the-linear-products-and-operations/20-the-linear-products-and-operations.ipynb); pp. 521-528; linear products as matrices, sparse operations, contractions
# - [Chapter 21: Fundamental Algorithms for Nonlinear Products](part-03-implementation/chapter-21-fundamental-algorithms-for-nonlinear-products/00-index.ipynb) - [canonical notebook](part-03-implementation/chapter-21-fundamental-algorithms-for-nonlinear-products/21-fundamental-algorithms-for-nonlinear-products.ipynb); pp. 529-540; inverses, factorization, delta product, robust meet/join
# - [Chapter 22: Specializing the Structure for Efficiency](part-03-implementation/chapter-22-specializing-the-structure-for-efficiency/00-index.ipynb) - [canonical notebook](part-03-implementation/chapter-22-specializing-the-structure-for-efficiency/22-specializing-the-structure-for-efficiency.ipynb); pp. 541-556; specialization, code generation, optimized kernels, benchmarks
# - [Chapter 23: Using the Geometry in a Ray-Tracing Application](part-03-implementation/chapter-23-using-the-geometry-in-a-ray-tracing-application/00-index.ipynb) - [canonical notebook](part-03-implementation/chapter-23-using-the-geometry-in-a-ray-tracing-application/23-ray-tracing-with-conformal-geometry.ipynb); pp. 557-584; meshes, rays, BSP, intersections, shading, mini render
#
# ## Part IV: Appendices
#
# - [Open Part IV: Appendices Index](part-04-appendices/00-part-index.ipynb)
# - [Appendix A: Metrics and Null Vectors](part-04-appendices/appendix-a-metrics-and-null-vectors/00-index.ipynb) - [canonical notebook](part-04-appendices/appendix-a-metrics-and-null-vectors/appendix-a-metrics-and-null-vectors.ipynb); pp. 585-588; metrics, signatures, null vectors, degeneracy checks
# - [Appendix B: Contractions and Other Inner Products](part-04-appendices/appendix-b-contractions-and-other-inner-products/00-index.ipynb) - [canonical notebook](part-04-appendices/appendix-b-contractions-and-other-inner-products/appendix-b-contractions-and-other-inner-products.ipynb); pp. 589-596; contraction conventions, grade behavior, projection tests
# - [Appendix C: Subspace Products Retrieved](part-04-appendices/appendix-c-subspace-products-retrieved/00-index.ipynb) - [canonical notebook](part-04-appendices/appendix-c-subspace-products-retrieved/appendix-c-subspace-products-retrieved.ipynb); pp. 597-602; grade selection identities and product retrieval
# - [Appendix D: Common Equations](part-04-appendices/appendix-d-common-equations/00-index.ipynb) - [canonical notebook](part-04-appendices/appendix-d-common-equations/appendix-d-common-equations.ipynb); pp. 603-608; executable formula sheet and sign checks

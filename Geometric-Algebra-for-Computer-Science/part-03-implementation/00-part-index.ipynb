# %% [markdown]
# # Part III: Implementation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Each entry links to the chapter or appendix index and directly to the canonical authored notebook.
#
# ## Chapter 18: Implementation Issues
#
# - Index: [chapter-18-implementation-issues](chapter-18-implementation-issues/00-index.ipynb)
# - Canonical notebook: [18-implementation-issues.ipynb](chapter-18-implementation-issues/18-implementation-issues.ipynb)
# - Source span: pp. 503-510
# - Focus: implementation levels, matrices, dense/sparse and symbolic/numeric tradeoffs
#
# ## Chapter 19: Basis Blades and Operations
#
# - Index: [chapter-19-basis-blades-and-operations](chapter-19-basis-blades-and-operations/00-index.ipynb)
# - Canonical notebook: [19-basis-blades-and-operations.ipynb](chapter-19-basis-blades-and-operations/19-basis-blades-and-operations.ipynb)
# - Source span: pp. 511-520
# - Focus: bitmap blades, signs, basis products, nonorthogonal metrics
#
# ## Chapter 20: The Linear Products and Operations
#
# - Index: [chapter-20-the-linear-products-and-operations](chapter-20-the-linear-products-and-operations/00-index.ipynb)
# - Canonical notebook: [20-the-linear-products-and-operations.ipynb](chapter-20-the-linear-products-and-operations/20-the-linear-products-and-operations.ipynb)
# - Source span: pp. 521-528
# - Focus: linear products as matrices, sparse operations, contractions
#
# ## Chapter 21: Fundamental Algorithms for Nonlinear Products
#
# - Index: [chapter-21-fundamental-algorithms-for-nonlinear-products](chapter-21-fundamental-algorithms-for-nonlinear-products/00-index.ipynb)
# - Canonical notebook: [21-fundamental-algorithms-for-nonlinear-products.ipynb](chapter-21-fundamental-algorithms-for-nonlinear-products/21-fundamental-algorithms-for-nonlinear-products.ipynb)
# - Source span: pp. 529-540
# - Focus: inverses, factorization, delta product, robust meet/join
#
# ## Chapter 22: Specializing the Structure for Efficiency
#
# - Index: [chapter-22-specializing-the-structure-for-efficiency](chapter-22-specializing-the-structure-for-efficiency/00-index.ipynb)
# - Canonical notebook: [22-specializing-the-structure-for-efficiency.ipynb](chapter-22-specializing-the-structure-for-efficiency/22-specializing-the-structure-for-efficiency.ipynb)
# - Source span: pp. 541-556
# - Focus: specialization, code generation, optimized kernels, benchmarks
#
# ## Chapter 23: Using the Geometry in a Ray-Tracing Application
#
# - Index: [chapter-23-using-the-geometry-in-a-ray-tracing-application](chapter-23-using-the-geometry-in-a-ray-tracing-application/00-index.ipynb)
# - Canonical notebook: [23-ray-tracing-with-conformal-geometry.ipynb](chapter-23-using-the-geometry-in-a-ray-tracing-application/23-ray-tracing-with-conformal-geometry.ipynb)
# - Source span: pp. 557-584
# - Focus: meshes, rays, BSP, intersections, shading, mini render

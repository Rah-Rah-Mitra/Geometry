# %% [markdown]
# # Chapter 19: Basis Blades and Operations
#
# This chapter folder now uses one authored, standalone, executable notebook.

# %% [markdown]
# ## Canonical Notebook
#
# - [19-basis-blades-and-operations.ipynb](19-basis-blades-and-operations.ipynb)
#
# The notebook covers bitmap basis-blade encoding, grade and sign logic, swap parity, outer and geometric products, orthogonal and nonorthogonal metric behavior, sparse multivector distribution, implementation pitfalls, artifact generation, and final sanity checks.

# %% [markdown]
# ## Source Span Audit
#
# Printed pages 511-520 were requested as authoritative. In this PDF, `pdftotext` extraction maps printed pages 511-519 to PDF pages 533-541. PDF page 542 begins printed page 521, so printed page 520 is a blank or otherwise unextracted interchapter page.

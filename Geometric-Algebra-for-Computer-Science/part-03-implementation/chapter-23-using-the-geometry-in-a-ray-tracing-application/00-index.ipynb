# %% [markdown]
# # Chapter 23: Using the Geometry in a Ray-Tracing Application
#
#             Printed-page anchor in the textbook: p. 557. The notebooks here are original, executable study material for the same conceptual territory.
#
#             ## Notebook Map
#
#             - [01 Ray Tracing Basics](01-ray-tracing-basics.ipynb)
# - [02 Modeling The Scene](02-modeling-the-scene.ipynb)
# - [03 Ray Model Intersection](03-ray-model-intersection.ipynb)
# - [Exercises And Solutions](exercises-and-solutions.ipynb)
#
#             ## Chapter Coverage
#
#             - ray-tracing basics
# - the ray-tracing algorithm
# - representing meshes
# - modeling the scene
# - scene transformations and user controls
# - representation and spawning of rays
# - ray-model intersection
# - reflection, refraction, and shading
# - evaluating performance and clarity

# %% [markdown]
# ## Study Strategy
#
# Work through the concept notebooks in order, then use the solutions notebook as an active recall pass. Re-run the code cells after changing inputs; most of the geometry becomes clearer when invariants survive small perturbations.

# %% [markdown]
# # Chapter 23: Using The Geometry In A Ray-Tracing Application
#
# This folder contains one authored, standalone, executable notebook replacing the shallow generated Chapter 23 set.
#
# ## Notebook
#
# - [23-ray-tracing-with-conformal-geometry.ipynb](23-ray-tracing-with-conformal-geometry.ipynb)
#
# ## Verified Source Span
#
# The PDF extraction was checked before writing. Printed page 557 maps to PDF page 577, and printed page 581 maps to PDF page 601. The PDF then starts Appendix A on printed page 585 / PDF page 602, so this file has no extractable printed pages 582-584 between Chapter 23 and the appendix. The notebook treats the requested printed pp. 557-584 as the authoritative chapter neighborhood and uses original exposition rather than copied textbook prose.

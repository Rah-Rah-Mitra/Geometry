# %% [markdown]
# # Chapter 21: Fundamental Algorithms for Nonlinear Products
#
# Printed-page anchor in the textbook: pp. 529-540. Verified extraction span: PDF pages 549-560 in `Geometric Algebra for Computer Science.pdf`. The notebook in this folder is original, executable study material and does not copy textbook prose or exercises.
#
# ## Canonical Notebook
#
# - `21-fundamental-algorithms-for-nonlinear-products.ipynb`
#
# ## What To Look For
#
# Run the canonical notebook from top to bottom. It covers versor and multivector inverses, blade and versor factorization checks, the delta product, numerical thresholds, and meet/join algorithms. Generated figures and JSON reports are written under `artifacts/chapter-21/`.

# %% [markdown]
# ## Study Strategy
#
# Start with the translation guide, then run every code cell. The final sanity cell is the quality gate: it asserts algebraic invariants and verifies that all Chapter 21 artifacts exist in the expected artifact directory.

# %% [markdown]
# # Chapter 22: Specializing The Structure For Efficiency
#
# This chapter folder has been consolidated into one authored, standalone notebook in the seed style. The source orientation was verified against the local PDF before writing: printed pages 541-556 map to PDF pages 561-576, and PDF page 577 starts Chapter 23.
#
# ## Notebook
#
# - [22 - Specializing The Structure For Efficiency](22-specializing-the-structure-for-efficiency.ipynb)
#
# ## Artifacts
#
# Running the notebook writes durable outputs under `artifacts/chapter-22/`, including algebra specifications, generated-kernel text, storage-layout visuals, outermorphism checks, nonlinear convergence plots, benchmark data, and an artifact manifest.

# %% [markdown]
# ## Study Strategy
#
# Read the notebook from top to bottom once, then rerun the code cells after changing a specialized type or benchmark sample count. The useful questions are: which coordinates became known zeros, which constants survived into the generated kernel, and where does a generic fallback remain necessary?

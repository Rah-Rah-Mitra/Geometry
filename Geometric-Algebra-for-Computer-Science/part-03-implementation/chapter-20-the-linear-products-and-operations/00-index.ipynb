# %% [markdown]
# # Chapter 20: The Linear Products and Operations
#
# This folder now contains one canonical, standalone notebook for Chapter 20:
#
# - [20-the-linear-products-and-operations.ipynb](20-the-linear-products-and-operations.ipynb)
#
# The notebook is an authored replacement for the generated concept notebooks that previously lived here. It covers linear products as matrices, product tables, sparse operations, grade projections, left and right contraction matrices, non-diagonal metrics, and implementation sanity checks.
#
# Source span verified before authoring: printed pages 521-527 map to physical PDF pages 542-548. Printed page 528 has no extractable Chapter 20 text in this PDF copy; physical PDF page 549 begins Chapter 21 at printed page 529. The notebook writes this audit to `artifacts/chapter-20/checks/source-page-audit.json` when executed.

# %% [markdown]
# ## Study Route
#
# 1. Start with the translation guide and basis-order table.
# 2. Run the unary-operation cells to see grade projections and sign matrices.
# 3. Inspect the geometric product table and product matrix for a mixed-grade `A`.
# 4. Compare geometric, outer, left contraction, and right contraction sparsity patterns.
# 5. Work through the non-diagonal metric and sparse-list labs.
# 6. Finish by running the sanity and artifact gates.

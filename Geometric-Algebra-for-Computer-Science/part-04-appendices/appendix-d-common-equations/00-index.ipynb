# %% [markdown]
# # Appendix D: Common Equations
#
# Printed-page source span: pp. 603-608. This folder now has one canonical authored notebook:
#
# - [Common Equations](appendix-d-common-equations.ipynb)
#
# Focus: curated executable formula sheet.
#
# Artifacts generated by execution are written under `D:/Geometry/artifacts/appendices/appendix-d`.

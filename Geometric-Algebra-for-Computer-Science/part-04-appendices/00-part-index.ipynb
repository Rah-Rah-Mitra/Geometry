# %% [markdown]
# # Part IV: Appendices
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Each entry links to the chapter or appendix index and directly to the canonical authored notebook.
#
# ## Appendix A: Metrics and Null Vectors
#
# - Index: [appendix-a-metrics-and-null-vectors](appendix-a-metrics-and-null-vectors/00-index.ipynb)
# - Canonical notebook: [appendix-a-metrics-and-null-vectors.ipynb](appendix-a-metrics-and-null-vectors/appendix-a-metrics-and-null-vectors.ipynb)
# - Source span: pp. 585-588
# - Focus: metrics, signatures, null vectors, degeneracy checks
#
# ## Appendix B: Contractions and Other Inner Products
#
# - Index: [appendix-b-contractions-and-other-inner-products](appendix-b-contractions-and-other-inner-products/00-index.ipynb)
# - Canonical notebook: [appendix-b-contractions-and-other-inner-products.ipynb](appendix-b-contractions-and-other-inner-products/appendix-b-contractions-and-other-inner-products.ipynb)
# - Source span: pp. 589-596
# - Focus: contraction conventions, grade behavior, projection tests
#
# ## Appendix C: Subspace Products Retrieved
#
# - Index: [appendix-c-subspace-products-retrieved](appendix-c-subspace-products-retrieved/00-index.ipynb)
# - Canonical notebook: [appendix-c-subspace-products-retrieved.ipynb](appendix-c-subspace-products-retrieved/appendix-c-subspace-products-retrieved.ipynb)
# - Source span: pp. 597-602
# - Focus: grade selection identities and product retrieval
#
# ## Appendix D: Common Equations
#
# - Index: [appendix-d-common-equations](appendix-d-common-equations/00-index.ipynb)
# - Canonical notebook: [appendix-d-common-equations.ipynb](appendix-d-common-equations/appendix-d-common-equations.ipynb)
# - Source span: pp. 603-608
# - Focus: executable formula sheet and sign checks

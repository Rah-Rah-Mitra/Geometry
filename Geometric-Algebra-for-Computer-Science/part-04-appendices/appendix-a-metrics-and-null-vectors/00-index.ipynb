# %% [markdown]
# # Appendix A: Metrics and Null Vectors
#
# Printed-page source span: pp. 585-588. This folder now has one canonical authored notebook:
#
# - [Metrics and Null Vectors](appendix-a-metrics-and-null-vectors.ipynb)
#
# Focus: metrics, signatures, null vectors, degeneracy checks.
#
# Artifacts generated by execution are written under `D:/Geometry/artifacts/appendices/appendix-a`.

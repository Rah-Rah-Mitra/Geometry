# %% [markdown]
# # Appendix B: Contractions and Other Inner Products
#
# Printed-page source span: pp. 589-596. This folder now has one canonical authored notebook:
#
# - [Contractions and Other Inner Products](appendix-b-contractions-and-other-inner-products.ipynb)
#
# Focus: contractions, dot/Hestenes conventions, grade behavior, projection tests.
#
# Artifacts generated by execution are written under `D:/Geometry/artifacts/appendices/appendix-b`.

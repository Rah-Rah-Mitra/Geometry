# %% [markdown]
# # Appendix C: Subspace Products Retrieved
#
# Printed-page source span: pp. 597-602. This folder now has one canonical authored notebook:
#
# - [Subspace Products Retrieved](appendix-c-subspace-products-retrieved.ipynb)
#
# Focus: grade selection identities and geometric-product retrieval.
#
# Artifacts generated by execution are written under `D:/Geometry/artifacts/appendices/appendix-c`.

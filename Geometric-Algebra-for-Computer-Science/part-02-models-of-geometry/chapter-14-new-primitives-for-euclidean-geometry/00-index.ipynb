# %% [markdown]
# # Chapter 14: New Primitives for Euclidean Geometry
#
#             Printed-page anchor in the textbook: p. 397. The notebooks here are original, executable study material for the same conceptual territory.
#
#             ## Notebook Map
#
#             - [01 Dual Rounds And Direct Rounds](01-dual-rounds-and-direct-rounds.ipynb)
# - [02 Tangents As Intersections Of Touching Rounds](02-tangents-as-intersections-of-touching-rounds.ipynb)
# - [03 Intersections Of Circles And Spheres](03-intersections-of-circles-and-spheres.ipynb)
# - [04 Inner Product As Distance Measure](04-inner-product-as-distance-measure.ipynb)
# - [Exercises And Solutions](exercises-and-solutions.ipynb)
#
#             ## Chapter Coverage
#
#             - dual rounds and direct rounds
# - point pairs, circles, and spheres
# - tangents as intersections of touching rounds
# - the representative paraboloid
# - intersections of circles and spheres
# - Voronoi diagrams
# - inner product as distance measure
# - sphere fitting and robot-arm kinematics

# %% [markdown]
# ## Study Strategy
#
# Work through the concept notebooks in order, then use the solutions notebook as an active recall pass. Re-run the code cells after changing inputs; most of the geometry becomes clearer when invariants survive small perturbations.

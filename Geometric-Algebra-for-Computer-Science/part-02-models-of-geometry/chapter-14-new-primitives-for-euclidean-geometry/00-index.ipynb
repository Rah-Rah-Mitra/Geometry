# %% [markdown]
# # Chapter 14: New Primitives for Euclidean Geometry
#
# Canonical notebook:
#
# - [14-new-primitives-for-euclidean-geometry.ipynb](14-new-primitives-for-euclidean-geometry.ipynb)
#
# This chapter notebook is an original, executable study replacement for the textbook span verified as printed pages 397-436, PDF pages 424-463. It covers rounds, dual sphere probes, direct point-pair/circle/sphere recovery, tangents, the representative paraboloid, Voronoi and power diagrams, sphere fitting, and kinematics applications.

# %% [markdown]
# ## Study Strategy
#
# Run the canonical notebook from top to bottom once, then revisit the applied lab cells with changed point coordinates, radii, and link lengths. The final cell asserts geometry invariants and checks that all artifacts were written under `artifacts/chapter-14`.

# %% [markdown]
# # Chapter 15: Constructions in Euclidean Geometry
#
# Printed-page anchor in the textbook: pp. 437-464. Verified PDF extraction span: PDF pages 464-491, with PDF page 463 ending Chapter 14 and PDF page 492 starting Chapter 16.
#
# ## Notebook Map
#
# - [15 - Constructions in Euclidean Geometry](15-constructions-in-euclidean-geometry.ipynb)
#
# ## Chapter Coverage
#
# - incidence and coincidence with conformal point, sphere, and plane probes
# - meet of spheres and the plunge viewpoint
# - real, tangent, and imaginary intersection cases
# - tangents without differentiating
# - carrier planes, surrounding spheres, and round factorization
# - affine combinations of conformal points and flat points
# - Euclidean projection, contour-circle construction, and a Voronoi cell lab
# - final invariant checks and artifact existence checks

# %% [markdown]
# ## Study Strategy
#
# Run the canonical notebook top to bottom once, then change the handles in the construction cells. The useful habit is to make the pictures move while the residual checks stay small.

# %% [markdown]
# # Chapter 9: Modeling Geometries
#
# Printed-page span in the textbook: pp. 245-246 (PDF pages 272-273 in the local file). The visible heading checked for this bridge chapter is `9 MODELING GEOMETRIES`.
#
# ## Notebook Map
#
# - [09 Modeling Geometries](09-modeling-geometries.ipynb)
#
# ## Chapter Coverage
#
# - why model choice is part of geometric-algebra practice
# - representational space, metric, embedding, and de-embedding
# - native operations in vector-space, homogeneous, and conformal models
# - how Chapters 10-17 fit together across Part II
# - executable checks for incidence, distance, transformation invariants, and saved artifacts

# %% [markdown]
# ## Study Strategy
#
# Read this as the bridge into Part II. The notebook is intentionally standalone: it explains how to decide whether a model is suitable before the later chapters specialize the vector-space, homogeneous, conformal, and operational cases.

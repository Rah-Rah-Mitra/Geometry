# %% [markdown]
# # Chapter 12: Applications of the Homogeneous Model
#
#             Printed-page anchor in the textbook: p. 327. The notebooks here are original, executable study material for the same conceptual territory.
#
#             ## Notebook Map
#
#             - [01 Homogeneous Plucker Coordinates In 3 D](01-homogeneous-plucker-coordinates-in-3-d.ipynb)
# - [02 Planes Of Rays Generated By Line Observations](02-planes-of-rays-generated-by-line-observations.ipynb)
# - [03 Crossing Line Programming Examples](03-crossing-line-programming-examples.ipynb)
# - [Exercises And Solutions](exercises-and-solutions.ipynb)
#
#             ## Chapter Coverage
#
#             - homogeneous Plucker coordinates in 3-D
# - pinhole camera geometry
# - the epipolar constraint
# - planes of rays generated by line observations
# - motion-capture reconstruction
# - OpenGL transformation examples
# - crossing-line programming examples

# %% [markdown]
# ## Study Strategy
#
# Work through the concept notebooks in order, then use the solutions notebook as an active recall pass. Re-run the code cells after changing inputs; most of the geometry becomes clearer when invariants survive small perturbations.

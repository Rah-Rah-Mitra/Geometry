# %% [markdown]
# # Chapter 12: Applications of the Homogeneous Model
#
# Printed-page span verified from the local PDF: pp. 327-354. This chapter folder now uses one deeper standalone notebook rather than several shallow generated stubs.
#
# ## Notebook Map
#
# - [12 Applications of the Homogeneous Model](12-applications-of-the-homogeneous-model.ipynb)
#
# ## Chapter Coverage
#
# - homogeneous Plucker coordinates in 3-D
# - pinhole camera geometry
# - the epipolar constraint
# - ray planes from line observations
# - motion-capture reconstruction
# - OpenGL-style homogeneous transforms
# - crossing-line programming lab
#
# ## Generated Artifacts
#
# Notebook execution writes heading audits, invariant checks, and figures to `artifacts/chapter-12/`.

# %% [markdown]
# # Chapter 17: Operational Models for Geometries
#
# Printed-page source envelope checked against the local PDF: intended printed pp. 497-502;
# extractable Chapter 17 text appears on PDF pages 523-525, printed pp. 497-499, with
# Chapter 18 beginning on PDF page 526 / printed p. 503.
#
# ## Notebook Map
#
# - [17 - Operational Models for Geometries](17-operational-models-for-geometries.ipynb)
#
# ## Chapter Coverage
#
# - Operational model synthesis and covariance checks
# - Representational space versus physical space
# - Vector-space, homogeneous, and conformal model choice
# - Supported operators, invariant tests, and implementation workflow

# %% [markdown]
# ## Study Strategy
#
# Read the translation guide, run each visual cell, then change the workload weights in the
# decision lab. The fastest way to internalize this chapter is to watch the selected model
# change when the required operators change.

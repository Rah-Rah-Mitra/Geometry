# %% [markdown]
# # Chapter 10: The Vector Space Model: The Algebra of Directions
#
# Printed-page span in the textbook: pp. 247-270. In this local PDF, that corresponds to PDF pages 274-297.
#
# ## Notebook Map
#
# - [10 Vector Space Model: Algebra of Directions](10-vector-space-model-algebra-of-directions.ipynb)
#
# ## Chapter Coverage
#
# - directions as the natural vector-space model
# - angular relationships in planar and spherical geometry
# - spherical triangles and their cosine-law checks
# - 3-D rotors, logarithms, and interpolation
# - crystallographic point groups as finite direction symmetries
# - noisy rotor estimation
# - external camera calibration from direction observations
# - the limits of treating locations as directions

# %% [markdown]
# ## Study Strategy
#
# Read the page audit first, then run the notebook from top to bottom. The saved figures and JSON checks in `artifacts/chapter-10` are part of the lesson: they make the direction model visible, and they give concrete invariants to perturb when testing your understanding.

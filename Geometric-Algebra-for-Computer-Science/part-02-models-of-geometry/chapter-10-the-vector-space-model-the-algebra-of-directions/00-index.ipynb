# %% [markdown]
# # Chapter 10: The Vector Space Model: The Algebra of Directions
#
#             Printed-page anchor in the textbook: p. 247. The notebooks here are original, executable study material for the same conceptual territory.
#
#             ## Notebook Map
#
#             - [01 Directions As The Natural Vector Space Model](01-directions-as-the-natural-vector-space-model.ipynb)
# - [02 Spherical Triangles](02-spherical-triangles.ipynb)
# - [03 Crystallography Point Groups](03-crystallography-point-groups.ipynb)
# - [Exercises And Solutions](exercises-and-solutions.ipynb)
#
#             ## Chapter Coverage
#
#             - directions as the natural vector-space model
# - angular relationships between vectors and bivectors
# - spherical triangles
# - rotors and rotation interpolation
# - crystallography point groups
# - external camera calibration

# %% [markdown]
# ## Study Strategy
#
# Work through the concept notebooks in order, then use the solutions notebook as an active recall pass. Re-run the code cells after changing inputs; most of the geometry becomes clearer when invariants survive small perturbations.

# %% [markdown]
# # Chapter 13: The Conformal Model: Operational Euclidean Geometry
#
# Printed-page span checked for this notebook: pp. 355-396. In the local PDF extraction, this corresponds to extractor pages 382-423. The heading audit is saved at `artifacts/chapter-13/pdf-probe/heading-audit.json`.
#
# ## Notebook Map
#
# - [13 Conformal Model: Operational Euclidean Geometry](13-conformal-model-operational-euclidean-geometry.ipynb)
#
# ## Coverage
#
# - conformal metric and the `[e1, e2, e3, no, ni]` null basis
# - null embedding of Euclidean points and distance recovery from inner products
# - vector probes for points, planes, and spheres
# - Euclidean versor actions as conformal metric-preserving maps that fix infinity
# - flats and directions through Plucker-style coordinate shadows of conformal blades
# - general planar reflection and reflection invariants
# - motors, screw motion, logarithm-style interpolation, and frame paths
# - differential planar reflection for a rotating offset mirror
# - final numerical sanity checks and saved Plotly artifacts

# %% [markdown]
# ## Study Strategy
#
# Run the standalone notebook top to bottom. The final cell asserts the quality gate: at least 2,500 markdown words, at least 10 code cells, several saved Plotly HTML artifacts, and numerical checks for the conformal metric, distance identity, infinity preservation, reflections, screw interpolation, and differential reflection.

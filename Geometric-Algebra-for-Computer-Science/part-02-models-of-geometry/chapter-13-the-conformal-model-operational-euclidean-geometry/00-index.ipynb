# %% [markdown]
# # Chapter 13: The Conformal Model: Operational Euclidean Geometry
#
#             Printed-page anchor in the textbook: p. 355. The notebooks here are original, executable study material for the same conceptual territory.
#
#             ## Notebook Map
#
#             - [01 Representational Space And Conformal Metric](01-representational-space-and-conformal-metric.ipynb)
# - [02 Flat Elements In The Conformal Model](02-flat-elements-in-the-conformal-model.ipynb)
# - [03 Translations Rotations And Motors](03-translations-rotations-and-motors.ipynb)
# - [04 Logarithms Of Rigid Body Motions](04-logarithms-of-rigid-body-motions.ipynb)
# - [Exercises And Solutions](exercises-and-solutions.ipynb)
#
#             ## Chapter Coverage
#
#             - representational space and conformal metric
# - null vectors and embedded Euclidean points
# - flat elements in the conformal model
# - planar reflection and Euclidean transformations
# - translations, rotations, and motors
# - Chasles screw motion
# - logarithms of rigid body motions
# - rigid-body interpolation examples

# %% [markdown]
# ## Study Strategy
#
# Work through the concept notebooks in order, then use the solutions notebook as an active recall pass. Re-run the code cells after changing inputs; most of the geometry becomes clearer when invariants survive small perturbations.

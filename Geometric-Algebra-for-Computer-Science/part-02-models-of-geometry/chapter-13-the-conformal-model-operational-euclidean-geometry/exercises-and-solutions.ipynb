# %% [markdown]
# # Chapter 13: The Conformal Model: Operational Euclidean Geometry - Exercises and Solutions
#
#             These are original exercises that cover the chapter's drill, structural, and programming themes without reproducing the book's copyrighted problem text.
#
#             ## Problems
#
#             1. Reconstruct the idea of representational space and conformal metric in your own notation, then identify one invariant that should survive a valid computation.
# 2. Reconstruct the idea of null vectors and embedded Euclidean points in your own notation, then identify one invariant that should survive a valid computation.
# 3. Reconstruct the idea of flat elements in the conformal model in your own notation, then identify one invariant that should survive a valid computation.
# 4. Reconstruct the idea of planar reflection and Euclidean transformations in your own notation, then identify one invariant that should survive a valid computation.
# 5. Reconstruct the idea of translations, rotations, and motors in your own notation, then identify one invariant that should survive a valid computation.
#
#             6. Programming check: write a minimal numerical test that would fail if the main algebraic identity of this chapter were implemented with the wrong sign or grade.
#
#             7. Synthesis: explain how this chapter changes the way a programmer should design geometry code.

# %%
from pathlib import Path
import sys

import numpy as np

PROJECT_ROOT = Path.cwd()
for candidate in (Path.cwd(), *Path.cwd().parents):
    if (candidate / "utils" / "ga").exists():
        PROJECT_ROOT = candidate
        break

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from utils.artifacts import save_json
from utils.ga import (
    Algebra,
    conformal_distance_squared,
    conformal_inner,
    conformal_point,
    homogeneous_line,
    homogeneous_point,
    intersect_homogeneous_lines,
    normalize_homogeneous_point,
    plucker_line,
    ray_sphere_intersection,
    rotation_matrix,
    unit_rotor,
)

np.set_printoptions(precision=4, suppress=True)
ARTIFACT_ROOT = PROJECT_ROOT / "artifacts" / "book-ga-cs"
ARTIFACT_TOPIC = "chapter-13"
print(PROJECT_ROOT)

# %% [markdown]
# ## Worked Solutions
#
#             **Solution 1.** For representational space and conformal metric, the useful invariant is the quantity or relationship that the representation was designed to preserve. Express the object as a blade or model element, apply only grade-respecting operations, and verify the result by checking either a norm, an incidence equation, a recovered grade, or an operator identity.
#
# **Solution 2.** For null vectors and embedded Euclidean points, the useful invariant is the quantity or relationship that the representation was designed to preserve. Express the object as a blade or model element, apply only grade-respecting operations, and verify the result by checking either a norm, an incidence equation, a recovered grade, or an operator identity.
#
# **Solution 3.** For flat elements in the conformal model, the useful invariant is the quantity or relationship that the representation was designed to preserve. Express the object as a blade or model element, apply only grade-respecting operations, and verify the result by checking either a norm, an incidence equation, a recovered grade, or an operator identity.
#
# **Solution 4.** For planar reflection and Euclidean transformations, the useful invariant is the quantity or relationship that the representation was designed to preserve. Express the object as a blade or model element, apply only grade-respecting operations, and verify the result by checking either a norm, an incidence equation, a recovered grade, or an operator identity.
#
# **Solution 5.** For translations, rotations, and motors, the useful invariant is the quantity or relationship that the representation was designed to preserve. Express the object as a blade or model element, apply only grade-respecting operations, and verify the result by checking either a norm, an incidence equation, a recovered grade, or an operator identity.
#
#             **Programming solution.** The cell below chooses a compact invariant for this chapter and asserts it directly. Replace the input vectors or model points to create additional tests.

# %%
a = np.array([0.0, 0.0, 0.0])
b = np.array([3.0, 4.0, 0.0])
assert abs(conformal_distance_squared(a, b) - 25.0) < 1e-9
print({"distance_squared": conformal_distance_squared(a, b), "inner": conformal_inner(conformal_point(a), conformal_point(b))})

# %% [markdown]
# ## Synthesis Solution
#
# The programming lesson is to stop scattering special cases across unrelated data structures. Chapter 13 asks us to encode the geometry so that the central operation of the chapter carries the meaning: spanning, measuring, transforming, intersecting, differentiating, modeling, or implementing. Once that operation is reliable, application code becomes shorter and easier to test because it checks geometric invariants instead of coordinate folklore.

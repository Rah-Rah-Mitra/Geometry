# %% [markdown]
# # Chapter 16: Conformal Operators
#
# Printed-page anchor in the textbook: pp. 465-496. PDF extraction was verified before authoring: printed page 465 begins on PDF page 492, and the extractable Chapter 16 span ends on PDF page 522 before Chapter 17 begins on PDF page 523.
#
# ## Canonical Notebook
#
# - [16 Conformal Operators](16-conformal-operators.ipynb)
#
# This chapter folder has been consolidated to one authored, executable notebook plus this index. The notebook writes Plotly and Matplotlib artifacts under `../../../../artifacts/chapter-16/` and finishes with invariant checks and artifact-existence assertions.

# %% [markdown]
# ## Study Strategy
#
# Read the translation guide first, then run the notebook from top to bottom. The most useful experiments are changing the inversion sphere, the scaling factor, the translation vector, and the loxodrome growth rate. The final sanity cell should continue to pass after reasonable parameter changes; if it does not, the failed invariant usually tells you which geometric promise was broken.

# %% [markdown]
# # Chapter 11: The Homogeneous Model
#
# Printed-page span verified from the local PDF: pp. 271-326, corresponding to PDF pages 298-353. This chapter folder now uses one seed-style standalone notebook that covers the full heading sequence with original prose, executable examples, saved artifacts, and final sanity checks.
#
# ## Notebook Map
#
# - [11-the-homogeneous-model.ipynb](11-the-homogeneous-model.ipynb) - homogeneous representation space; finite and infinite points; flats as blades; direct and dual representations; incidence; transformations; parameterized constructions; metric-product cautions; cross ratios; conics; and perspective projection.
#
# ## Generated Artifacts
#
# Notebook runs save figures and JSON checks under `artifacts/chapter-11/`, including heading verification, representation-space diagrams, incidence figures, transformation checks, cross-ratio and conic plots, perspective projection, and final sanity-check metadata.
#
# ## Study Strategy
#
# Run the notebook top to bottom once, then revisit the final sanity checks after editing any construction. The most useful habit in this chapter is to ask whether an array is being used as a spanning object, a dual equation, or a projective representative whose scale is irrelevant.

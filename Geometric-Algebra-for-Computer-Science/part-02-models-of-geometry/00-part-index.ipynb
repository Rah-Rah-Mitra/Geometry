# %% [markdown]
# # Part II: Models of Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Each entry links to the chapter or appendix index and directly to the canonical authored notebook.
#
# ## Chapter 09: Modeling Geometries
#
# - Index: [chapter-09-modeling-geometries](chapter-09-modeling-geometries/00-index.ipynb)
# - Canonical notebook: [09-modeling-geometries.ipynb](chapter-09-modeling-geometries/09-modeling-geometries.ipynb)
# - Source span: pp. 245-246
# - Focus: model-selection bridge and geometry workflows
#
# ## Chapter 10: The Vector Space Model: The Algebra of Directions
#
# - Index: [chapter-10-the-vector-space-model-the-algebra-of-directions](chapter-10-the-vector-space-model-the-algebra-of-directions/00-index.ipynb)
# - Canonical notebook: [10-vector-space-model-algebra-of-directions.ipynb](chapter-10-the-vector-space-model-the-algebra-of-directions/10-vector-space-model-algebra-of-directions.ipynb)
# - Source span: pp. 247-270
# - Focus: directions, angular relationships, interpolation, point groups
#
# ## Chapter 11: The Homogeneous Model
#
# - Index: [chapter-11-the-homogeneous-model](chapter-11-the-homogeneous-model/00-index.ipynb)
# - Canonical notebook: [11-the-homogeneous-model.ipynb](chapter-11-the-homogeneous-model/11-the-homogeneous-model.ipynb)
# - Source span: pp. 271-326
# - Focus: points, flats, incidence, cross ratios, conics, perspective
#
# ## Chapter 12: Applications of the Homogeneous Model
#
# - Index: [chapter-12-applications-of-the-homogeneous-model](chapter-12-applications-of-the-homogeneous-model/00-index.ipynb)
# - Canonical notebook: [12-applications-of-the-homogeneous-model.ipynb](chapter-12-applications-of-the-homogeneous-model/12-applications-of-the-homogeneous-model.ipynb)
# - Source span: pp. 327-354
# - Focus: Plucker lines, camera geometry, epipolar constraints, reconstruction
#
# ## Chapter 13: The Conformal Model: Operational Euclidean Geometry
#
# - Index: [chapter-13-the-conformal-model-operational-euclidean-geometry](chapter-13-the-conformal-model-operational-euclidean-geometry/00-index.ipynb)
# - Canonical notebook: [13-conformal-model-operational-euclidean-geometry.ipynb](chapter-13-the-conformal-model-operational-euclidean-geometry/13-conformal-model-operational-euclidean-geometry.ipynb)
# - Source span: pp. 355-396
# - Focus: null embedding, probes, flats, motors, screw interpolation
#
# ## Chapter 14: New Primitives for Euclidean Geometry
#
# - Index: [chapter-14-new-primitives-for-euclidean-geometry](chapter-14-new-primitives-for-euclidean-geometry/00-index.ipynb)
# - Canonical notebook: [14-new-primitives-for-euclidean-geometry.ipynb](chapter-14-new-primitives-for-euclidean-geometry/14-new-primitives-for-euclidean-geometry.ipynb)
# - Source span: pp. 397-436
# - Focus: rounds, tangents, paraboloids, Voronoi, fitting, kinematics
#
# ## Chapter 15: Constructions in Euclidean Geometry
#
# - Index: [chapter-15-constructions-in-euclidean-geometry](chapter-15-constructions-in-euclidean-geometry/00-index.ipynb)
# - Canonical notebook: [15-constructions-in-euclidean-geometry.ipynb](chapter-15-constructions-in-euclidean-geometry/15-constructions-in-euclidean-geometry.ipynb)
# - Source span: pp. 437-464
# - Focus: incidence, meet/plunge, tangents, factorization, affine combinations
#
# ## Chapter 16: Conformal Operators
#
# - Index: [chapter-16-conformal-operators](chapter-16-conformal-operators/00-index.ipynb)
# - Canonical notebook: [16-conformal-operators.ipynb](chapter-16-conformal-operators/16-conformal-operators.ipynb)
# - Source span: pp. 465-496
# - Focus: inversion, spherical reflection, translations, loxodromes, non-Euclidean models
#
# ## Chapter 17: Operational Models for Geometries
#
# - Index: [chapter-17-operational-models-for-geometries](chapter-17-operational-models-for-geometries/00-index.ipynb)
# - Canonical notebook: [17-operational-models-for-geometries.ipynb](chapter-17-operational-models-for-geometries/17-operational-models-for-geometries.ipynb)
# - Source span: pp. 497-502
# - Focus: model synthesis and implementation decision workflow

# %% [markdown]
# # Chapter 16: Projective Conics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [16-projective-conics.ipynb](16-projective-conics.ipynb)
# - Source span: printed Volume II pages 170-217; PDF pages 179-226
# - Visual center: parametrized conics, cross-ratios, Pascal, homographies, Bezout, pencils
# - Artifact topic: `artifacts/chapter-16`

# %% [markdown]
# # Chapter 20: The Space of Spheres
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [20-the-space-of-spheres.ipynb](20-the-space-of-spheres.ipynb)
# - Source span: printed Volume II pages 349-362; PDF pages 358-371
# - Visual center: generalized spheres, sphere quadratic form, orthogonality, intersections, pencils, circular group
# - Artifact topic: `artifacts/chapter-20`

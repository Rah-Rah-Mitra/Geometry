# %% [markdown]
# # Chapter 15: Affine Quadrics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [15-affine-quadrics.ipynb](15-affine-quadrics.ipynb)
# - Source span: printed Volume II pages 146-169; PDF pages 155-178
# - Visual center: affine classification, real and complex quadrics, topology, polarity, Euclidean models
# - Artifact topic: `artifacts/chapter-15`

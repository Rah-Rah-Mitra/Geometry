# %% [markdown]
# # Geometry II - Visualization-First Notebook Course
#
# This original standalone course follows Volume II of Marcel Berger's *Geometry II* and covers Chapters 12-20. The notebooks are designed to teach without requiring the PDF open.
#
# Generated artifacts live under `artifacts/chapter-XX`. The source map uses `pdf_page = printed_volume_ii_page + 9`.
#
# - [Chapter 12: Polytopes; Compact Convex Sets](chapter-12-polytopes-compact-convex-sets/00-index.ipynb) - [canonical notebook](chapter-12-polytopes-compact-convex-sets/12-polytopes-compact-convex-sets.ipynb); printed pages 1-85; PDF pages 10-94; convex hulls, regular polytopes, Euler characteristic, Cauchy rigidity, approximation, isoperimetry.
# - [Chapter 13: Quadratic Forms](chapter-13-quadratic-forms/00-index.ipynb) - [canonical notebook](chapter-13-quadratic-forms/13-quadratic-forms.ipynb); printed pages 86-115; PDF pages 95-124; signatures, isotropic cones, radicals, orthogonalization, Witt decomposition, reflections.
# - [Chapter 14: Projective Quadrics](chapter-14-projective-quadrics/00-index.ipynb) - [canonical notebook](chapter-14-projective-quadrics/14-projective-quadrics.ipynb); printed pages 116-145; PDF pages 125-154; homogeneous quadrics, pencils, topology, polarity, tangent geometry, projective actions.
# - [Chapter 15: Affine Quadrics](chapter-15-affine-quadrics/00-index.ipynb) - [canonical notebook](chapter-15-affine-quadrics/15-affine-quadrics.ipynb); printed pages 146-169; PDF pages 155-178; affine classification, real and complex quadrics, topology, polarity, Euclidean models.
# - [Chapter 16: Projective Conics](chapter-16-projective-conics/00-index.ipynb) - [canonical notebook](chapter-16-projective-conics/16-projective-conics.ipynb); printed pages 170-217; PDF pages 179-226; parametrized conics, cross-ratios, Pascal, homographies, Bezout, pencils.
# - [Chapter 17: Euclidean Conics](chapter-17-euclidean-conics/00-index.ipynb) - [canonical notebook](chapter-17-euclidean-conics/17-euclidean-conics.ipynb); printed pages 218-254; PDF pages 227-263; metric conics, focal/directrix views, cyclic points, tangential pencils, ellipses and hyperbolas.
# - [Chapter 18: The Sphere for Its Own Sake](chapter-18-the-sphere-for-its-own-sake/00-index.ipynb) - [canonical notebook](chapter-18-the-sphere-for-its-own-sake/18-the-sphere-for-its-own-sake.ipynb); printed pages 255-317; PDF pages 264-326; charts, projections, measure, intrinsic metric, spherical triangles, Clifford parallelism, Mobius group.
# - [Chapter 19: Elliptic and Hyperbolic Geometry](chapter-19-elliptic-and-hyperbolic-geometry/00-index.ipynb) - [canonical notebook](chapter-19-elliptic-and-hyperbolic-geometry/19-elliptic-and-hyperbolic-geometry.ipynb); printed pages 318-348; PDF pages 327-357; elliptic geometry, projective and ball models, Poincare disk, distances, isometries.
# - [Chapter 20: The Space of Spheres](chapter-20-the-space-of-spheres/00-index.ipynb) - [canonical notebook](chapter-20-the-space-of-spheres/20-the-space-of-spheres.ipynb); printed pages 349-362; PDF pages 358-371; generalized spheres, sphere quadratic form, orthogonality, intersections, pencils, circular group.

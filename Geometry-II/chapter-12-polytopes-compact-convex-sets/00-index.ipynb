# %% [markdown]
# # Chapter 12: Polytopes; Compact Convex Sets
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [12-polytopes-compact-convex-sets.ipynb](12-polytopes-compact-convex-sets.ipynb)
# - Source span: printed Volume II pages 1-85; PDF pages 10-94
# - Visual center: convex hulls, regular polytopes, Euler characteristic, Cauchy rigidity, approximation, isoperimetry
# - Artifact topic: `artifacts/chapter-12`

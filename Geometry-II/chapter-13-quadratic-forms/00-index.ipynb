# %% [markdown]
# # Chapter 13: Quadratic Forms
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [13-quadratic-forms.ipynb](13-quadratic-forms.ipynb)
# - Source span: printed Volume II pages 86-115; PDF pages 95-124
# - Visual center: signatures, isotropic cones, radicals, orthogonalization, Witt decomposition, reflections
# - Artifact topic: `artifacts/chapter-13`

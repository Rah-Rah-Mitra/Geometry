# %% [markdown]
# # Chapter 18: The Sphere for Its Own Sake
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [18-the-sphere-for-its-own-sake.ipynb](18-the-sphere-for-its-own-sake.ipynb)
# - Source span: printed Volume II pages 255-317; PDF pages 264-326
# - Visual center: charts, projections, measure, intrinsic metric, spherical triangles, Clifford parallelism, Mobius group
# - Artifact topic: `artifacts/chapter-18`

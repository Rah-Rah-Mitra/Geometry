# %% [markdown]
# # Chapter 14: Projective Quadrics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [14-projective-quadrics.ipynb](14-projective-quadrics.ipynb)
# - Source span: printed Volume II pages 116-145; PDF pages 125-154
# - Visual center: homogeneous quadrics, pencils, topology, polarity, tangent geometry, projective actions
# - Artifact topic: `artifacts/chapter-14`

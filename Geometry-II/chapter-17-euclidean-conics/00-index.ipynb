# %% [markdown]
# # Chapter 17: Euclidean Conics
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [17-euclidean-conics.ipynb](17-euclidean-conics.ipynb)
# - Source span: printed Volume II pages 218-254; PDF pages 227-263
# - Visual center: metric conics, focal/directrix views, cyclic points, tangential pencils, ellipses and hyperbolas
# - Artifact topic: `artifacts/chapter-17`

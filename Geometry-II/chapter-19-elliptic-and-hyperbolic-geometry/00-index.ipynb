# %% [markdown]
# # Chapter 19: Elliptic and Hyperbolic Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# - Canonical notebook: [19-elliptic-and-hyperbolic-geometry.ipynb](19-elliptic-and-hyperbolic-geometry.ipynb)
# - Source span: printed Volume II pages 318-348; PDF pages 327-357
# - Visual center: elliptic geometry, projective and ball models, Poincare disk, distances, isometries
# - Artifact topic: `artifacts/chapter-19`

# %% [markdown]
# # Chapter 7: Invariant Theory of Finite Groups
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 351-392; PDF pages 362-402.
#
# Canonical notebook: [07-invariant-theory-of-finite-groups.ipynb](07-invariant-theory-of-finite-groups.ipynb)
#
# ## Focus
#
# Symmetric polynomials, finite matrix groups, Reynolds averaging, invariant generators, relations among generators, and orbit-space geometry.
#
# ## Visual Storyboard
#
# - symmetric reduction lattice
# - root-permutation and discriminant orbit display
# - finite group orbit gallery
# - Reynolds operator averaging table
# - relation variety for quotient coordinates
#
# ## Checks
#
# - candidate invariants are fixed by group generators
# - Reynolds operator is idempotent in small examples
# - relations among generators vanish after substitution

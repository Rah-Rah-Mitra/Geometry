# %% [markdown]
# # Chapter 8: Projective Algebraic Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 393-476; PDF pages 403-486.
#
# Canonical notebook: [08-projective-algebraic-geometry.ipynb](08-projective-algebraic-geometry.ipynb)
#
# ## Focus
#
# Projective space, homogeneous ideals, projective varieties, closures, projective elimination, quadrics, Plucker coordinates, and Bezout's theorem.
#
# ## Visual Storyboard
#
# - projective chart atlas and line at infinity
# - homogenization and affine closure comparison
# - affine cone dictionary
# - quadric rank and ruling display
# - Bezout and Pascal determinant lab
#
# ## Checks
#
# - homogeneous scaling law is exact
# - chart transition round-trips recover coordinates
# - Plucker and Pascal determinant relations vanish

# %% [markdown]
# # Chapter 9: The Dimension of a Variety
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 477-546; PDF pages 487-556.
#
# Canonical notebook: [09-dimension-of-a-variety.ipynb](09-dimension-of-a-variety.ipynb)
#
# ## Focus
#
# Monomial ideal varieties, Hilbert functions, leading ideals, dimension, algebraic independence, nonsingularity, tangent spaces, and tangent cones.
#
# ## Visual Storyboard
#
# - coordinate subspace union for a monomial ideal
# - exponent-lattice complement and Hilbert growth
# - leading ideal comparison
# - dimension rule panel
# - tangent cone secant-line zoom
#
# ## Checks
#
# - monomial complement counts match Hilbert samples
# - dimension from leading ideal agrees with sampled growth
# - Jacobian rank and tangent cone equations match examples

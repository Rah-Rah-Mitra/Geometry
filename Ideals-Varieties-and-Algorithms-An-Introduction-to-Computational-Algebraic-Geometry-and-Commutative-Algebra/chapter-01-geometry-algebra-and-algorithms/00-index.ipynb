# %% [markdown]
# # Chapter 1: Geometry, Algebra, and Algorithms
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 1-48; PDF pages 16-62.
#
# Canonical notebook: [01-geometry-algebra-and-algorithms.ipynb](01-geometry-algebra-and-algorithms.ipynb)
#
# ## Focus
#
# Polynomials as functions, affine varieties as solution sets, ideals as algebraic containers, and one-variable algorithms as the first computational model.
#
# ## Visual Storyboard
#
# - monomial exponent lattice and total degree bands
# - finite-field truth table versus infinite-field sampling
# - affine variety gallery with residual contours and surfaces
# - parametrization and implicit equation comparison
# - Euclidean algorithm trace for one-variable ideals
#
# ## Checks
#
# - polynomial evaluation residuals vanish on sampled varieties
# - finite-field zero-function table is exact
# - division identity f = qg + r is verified symbolically

# %% [markdown]
# # Chapter 3: Elimination Theory
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 121-176; PDF pages 134-188.
#
# Canonical notebook: [03-elimination-theory.ipynb](03-elimination-theory.ipynb)
#
# ## Focus
#
# Elimination ideals, extension of partial solutions, geometric projection, implicitization, singularities, envelopes, and resultants.
#
# ## Visual Storyboard
#
# - elimination solution tree from one coordinate back to all coordinates
# - extension-failure fiber diagram
# - projection closure and missing-point plot
# - implicitization lab for parametrized curves and surfaces
# - Sylvester matrix heat map for resultants
#
# ## Checks
#
# - eliminated polynomials vanish on projected samples
# - parametrized samples satisfy recovered implicit equations
# - resultant is zero exactly when specialized polynomials share a root

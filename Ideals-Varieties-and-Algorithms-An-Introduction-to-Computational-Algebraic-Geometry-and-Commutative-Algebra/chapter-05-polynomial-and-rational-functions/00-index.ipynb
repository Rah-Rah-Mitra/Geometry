# %% [markdown]
# # Chapter 5: Polynomial and Rational Functions on a Variety
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 237-296; PDF pages 249-308.
#
# Canonical notebook: [05-polynomial-and-rational-functions.ipynb](05-polynomial-and-rational-functions.ipynb)
#
# ## Focus
#
# Polynomial maps, quotient rings, coordinate rings, standard representatives, rational functions, relative finiteness, and Noether normalization.
#
# ## Visual Storyboard
#
# - tangent-surface polynomial map
# - same-function representatives modulo an ideal
# - zero divisors on reducible varieties
# - standard monomial quotient basis
# - finite-fiber normalization projection
#
# ## Checks
#
# - Grobner reductions agree for representatives modulo I
# - zero-divisor product vanishes on the union
# - rational inverse compositions agree on dense open samples

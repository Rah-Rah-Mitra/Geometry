# %% [markdown]
# # Chapter 6: Robotics and Automatic Geometric Theorem Proving
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Source orientation: printed pages 297-350; PDF pages 309-361.
#
# Canonical notebook: [06-robotics-and-theorem-proving.ipynb](06-robotics-and-theorem-proving.ipynb)
#
# ## Focus
#
# Robot joint spaces, forward and inverse kinematics, polynomialized trigonometry, motion planning branches, geometric theorem proving, and Wu's method.
#
# ## Visual Storyboard
#
# - joint-space dashboard for revolute and prismatic coordinates
# - forward kinematics arm animation frame
# - polynomialized sine-cosine constraints
# - inverse-kinematics solution branches
# - theorem-proving dependency graph
#
# ## Checks
#
# - matrix products match forward kinematic formulas
# - inverse solutions satisfy target and unit-circle constraints
# - Grobner remainder certifies a small geometric conclusion

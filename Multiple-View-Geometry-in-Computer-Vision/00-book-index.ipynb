# %% [markdown]
# # Multiple View Geometry in Computer Vision
#
# This is a standalone visualization-first notebook course with original prose, executable examples, generated diagrams, computational experiments, and sanity checks. The local PDF is used only for source orientation and is not reproduced in the notebooks.
#
# Source-page convention: printed page 1 is PDF page 19, so `pdf_page = printed_page + 18`.
#
# ## Opening Chapter
#
# - [Chapter 01: Introduction: A Tour of Multiple View Geometry](chapter-01-introduction-a-tour-of-multiple-view-geometry/00-index.ipynb) - [canonical](chapter-01-introduction-a-tour-of-multiple-view-geometry/01-introduction-a-tour-of-multiple-view-geometry.ipynb); printed pp. 1-22; PDF pp. 19-40; Projection, ambiguity, transfer, Euclidean upgrade, and the full multiple-view reconstruction arc.
#
# ## Part 0: The Background: Projective Geometry, Transformations and Estimation
#
# Projective 2D/3D geometry, homographies, numerical estimation, and error analysis.
#
# - [Open part index](part-00-background-projective-geometry-transformations-and-estimation/00-part-index.ipynb)
# - [Chapter 02: Projective Geometry and Transformations of 2D](part-00-background-projective-geometry-transformations-and-estimation/chapter-02-projective-geometry-and-transformations-of-2d/00-index.ipynb) - [canonical](part-00-background-projective-geometry-transformations-and-estimation/chapter-02-projective-geometry-and-transformations-of-2d/02-projective-geometry-and-transformations-of-2d.ipynb); printed pp. 25-64; PDF pp. 43-82; Points, lines, conics, homographies, transformation hierarchy, rectification, and metric recovery in the projective plane.
# - [Chapter 03: Projective Geometry and Transformations of 3D](part-00-background-projective-geometry-transformations-and-estimation/chapter-03-projective-geometry-and-transformations-of-3d/00-index.ipynb) - [canonical](part-00-background-projective-geometry-transformations-and-estimation/chapter-03-projective-geometry-and-transformations-of-3d/03-projective-geometry-and-transformations-of-3d.ipynb); printed pp. 65-86; PDF pp. 83-104; Projective 3D points, planes, lines, quadrics, twisted cubics, the plane at infinity, and the absolute conic.
# - [Chapter 04: Estimation: 2D Projective Transformations](part-00-background-projective-geometry-transformations-and-estimation/chapter-04-estimation-2d-projective-transformations/00-index.ipynb) - [canonical](part-00-background-projective-geometry-transformations-and-estimation/chapter-04-estimation-2d-projective-transformations/04-estimation-2d-projective-transformations.ipynb); printed pp. 87-131; PDF pp. 105-149; DLT homography estimation, geometric and statistical costs, normalization, iterative refinement, robust estimation, and automatic matching.
# - [Chapter 05: Algorithm Evaluation and Error Analysis](part-00-background-projective-geometry-transformations-and-estimation/chapter-05-algorithm-evaluation-and-error-analysis/00-index.ipynb) - [canonical](part-00-background-projective-geometry-transformations-and-estimation/chapter-05-algorithm-evaluation-and-error-analysis/05-algorithm-evaluation-and-error-analysis.ipynb); printed pp. 132-150; PDF pp. 150-168; Performance bounds, covariance propagation, Monte Carlo covariance, and empirical evaluation of geometric estimators.
#
# ## Part I: Camera Geometry and Single View Geometry
#
# Camera matrices, calibration, distortion, vanishing geometry, and single-view measurement.
#
# - [Open part index](part-01-camera-geometry-and-single-view-geometry/00-part-index.ipynb)
# - [Chapter 06: Camera Models](part-01-camera-geometry-and-single-view-geometry/chapter-06-camera-models/00-index.ipynb) - [canonical](part-01-camera-geometry-and-single-view-geometry/chapter-06-camera-models/06-camera-models.ipynb); printed pp. 153-177; PDF pp. 171-195; Finite cameras, projective cameras, affine cameras, intrinsic/extrinsic factorization, and alternative camera models.
# - [Chapter 07: Computation of the Camera Matrix P](part-01-camera-geometry-and-single-view-geometry/chapter-07-computation-of-the-camera-matrix-p/00-index.ipynb) - [canonical](part-01-camera-geometry-and-single-view-geometry/chapter-07-computation-of-the-camera-matrix-p/07-computation-of-the-camera-matrix-p.ipynb); printed pp. 178-194; PDF pp. 196-212; Camera resectioning from 3D-2D correspondences, geometric error, constrained calibration, and radial distortion.
# - [Chapter 08: More Single View Geometry](part-01-camera-geometry-and-single-view-geometry/chapter-08-more-single-view-geometry/00-index.ipynb) - [canonical](part-01-camera-geometry-and-single-view-geometry/chapter-08-more-single-view-geometry/08-more-single-view-geometry.ipynb); printed pp. 195-236; PDF pp. 213-254; Projection of planes, lines, conics, quadrics, silhouettes, vanishing points, the image of the absolute conic, and single-view reconstruction.
#
# ## Part II: Two-View Geometry
#
# Epipolar geometry, the fundamental matrix, triangulation, homographies, rectification, and affine stereo.
#
# - [Open part index](part-02-two-view-geometry/00-part-index.ipynb)
# - [Chapter 09: Epipolar Geometry and the Fundamental Matrix](part-02-two-view-geometry/chapter-09-epipolar-geometry-and-the-fundamental-matrix/00-index.ipynb) - [canonical](part-02-two-view-geometry/chapter-09-epipolar-geometry-and-the-fundamental-matrix/09-epipolar-geometry-and-the-fundamental-matrix.ipynb); printed pp. 239-261; PDF pp. 257-279; Epipolar geometry, the fundamental matrix, special motions, epipoles, camera retrieval, and the essential matrix.
# - [Chapter 10: 3D Reconstruction of Cameras and Structure](part-02-two-view-geometry/chapter-10-3d-reconstruction-of-cameras-and-structure/00-index.ipynb) - [canonical](part-02-two-view-geometry/chapter-10-3d-reconstruction-of-cameras-and-structure/10-3d-reconstruction-of-cameras-and-structure.ipynb); printed pp. 262-278; PDF pp. 280-296; Projective reconstruction, reconstruction ambiguity, the projective reconstruction theorem, and stratified upgrade.
# - [Chapter 11: Computation of the Fundamental Matrix F](part-02-two-view-geometry/chapter-11-computation-of-the-fundamental-matrix-f/00-index.ipynb) - [canonical](part-02-two-view-geometry/chapter-11-computation-of-the-fundamental-matrix-f/11-computation-of-the-fundamental-matrix-f.ipynb); printed pp. 279-309; PDF pp. 297-327; Normalized eight-point estimation, algebraic minimization, geometric distance, robust computation, degeneracies, envelopes, and rectification.
# - [Chapter 12: Structure Computation](part-02-two-view-geometry/chapter-12-structure-computation/00-index.ipynb) - [canonical](part-02-two-view-geometry/chapter-12-structure-computation/12-structure-computation.ipynb); printed pp. 310-324; PDF pp. 328-342; Linear triangulation, geometric error, Sampson correction, optimal correction, uncertainty, and line reconstruction.
# - [Chapter 13: Scene Planes and Homographies](part-02-two-view-geometry/chapter-13-scene-planes-and-homographies/00-index.ipynb) - [canonical](part-02-two-view-geometry/chapter-13-scene-planes-and-homographies/13-scene-planes-and-homographies.ipynb); printed pp. 325-343; PDF pp. 343-361; Plane-induced homographies, recovering planes, F from a plane homography, parallax, and the infinite homography.
# - [Chapter 14: Affine Epipolar Geometry](part-02-two-view-geometry/chapter-14-affine-epipolar-geometry/00-index.ipynb) - [canonical](part-02-two-view-geometry/chapter-14-affine-epipolar-geometry/14-affine-epipolar-geometry.ipynb); printed pp. 344-362; PDF pp. 362-380; Affine cameras, affine fundamental matrix estimation, triangulation, affine reconstruction, bas-relief ambiguity, and motion recovery.
#
# ## Part III: Three-View Geometry
#
# The trifocal tensor, point and line transfer, three-view constraints, and tensor estimation.
#
# - [Open part index](part-03-three-view-geometry/00-part-index.ipynb)
# - [Chapter 15: The Trifocal Tensor](part-03-three-view-geometry/chapter-15-the-trifocal-tensor/00-index.ipynb) - [canonical](part-03-three-view-geometry/chapter-15-the-trifocal-tensor/15-the-trifocal-tensor.ipynb); printed pp. 365-390; PDF pp. 383-408; The geometric basis of the trifocal tensor, tensor notation, transfer, and three-view fundamental matrices.
# - [Chapter 16: Computation of the Trifocal Tensor T](part-03-three-view-geometry/chapter-16-computation-of-the-trifocal-tensor-t/00-index.ipynb) - [canonical](part-03-three-view-geometry/chapter-16-computation-of-the-trifocal-tensor-t/16-computation-of-the-trifocal-tensor-t.ipynb); printed pp. 391-408; PDF pp. 409-426; Linear, algebraic, geometric, and robust estimation of the trifocal tensor from point and line correspondences.
#
# ## Part IV: N-View Geometry
#
# Multiple-view tensors, factorization, bundle adjustment, auto-calibration, duality, cheirality, and degeneracies.
#
# - [Open part index](part-04-n-view-geometry/00-part-index.ipynb)
# - [Chapter 17: N-Linearities and Multiple View Tensors](part-04-n-view-geometry/chapter-17-n-linearities-and-multiple-view-tensors/00-index.ipynb) - [canonical](part-04-n-view-geometry/chapter-17-n-linearities-and-multiple-view-tensors/17-n-linearities-and-multiple-view-tensors.ipynb); printed pp. 411-433; PDF pp. 429-451; Bilinear, trilinear, and quadrilinear relations; plane intersections; counting arguments; independent equations; and equation choice.
# - [Chapter 18: N-View Computational Methods](part-04-n-view-geometry/chapter-18-n-view-computational-methods/00-index.ipynb) - [canonical](part-04-n-view-geometry/chapter-18-n-view-computational-methods/18-n-view-computational-methods.ipynb); printed pp. 434-457; PDF pp. 452-475; Bundle adjustment, affine factorization, non-rigid factorization, projective factorization, plane-based reconstruction, and sequences.
# - [Chapter 19: Auto-Calibration](part-04-n-view-geometry/chapter-19-auto-calibration/00-index.ipynb) - [canonical](part-04-n-view-geometry/chapter-19-auto-calibration/19-auto-calibration.ipynb); printed pp. 458-501; PDF pp. 476-519; Algebraic auto-calibration, the absolute dual quadric, Kruppa equations, stratified solutions, rotating cameras, planar motion, turntables, and stereo rigs.
# - [Chapter 20: Duality](part-04-n-view-geometry/chapter-20-duality/00-index.ipynb) - [canonical](part-04-n-view-geometry/chapter-20-duality/20-duality.ipynb); printed pp. 502-514; PDF pp. 520-532; Carlsson-Weinshall duality and reduced reconstruction through the exchange of point and camera roles.
# - [Chapter 21: Cheirality](part-04-n-view-geometry/chapter-21-cheirality/00-index.ipynb) - [canonical](part-04-n-view-geometry/chapter-21-cheirality/21-cheirality.ipynb); printed pp. 515-532; PDF pp. 533-550; Quasi-affine transformations, front/back camera tests, visible point sets, cheiral inequalities, third-view visibility, and depth ordering.
# - [Chapter 22: Degenerate Configurations](part-04-n-view-geometry/chapter-22-degenerate-configurations/00-index.ipynb) - [canonical](part-04-n-view-geometry/chapter-22-degenerate-configurations/22-degenerate-configurations.ipynb); printed pp. 533-560; PDF pp. 551-578; Degeneracies in camera resectioning, two-view and three-view reconstruction, critical surfaces, and ambiguous configurations.
#
# ## Part V: Appendices
#
# Tensor notation, statistics, parameter estimation, matrix decompositions, least squares, iterative methods, and special homographies.
#
# - [Open part index](part-05-appendices/00-part-index.ipynb)
# - [Appendix 01: Tensor Notation](part-05-appendices/appendix-01-tensor-notation/00-index.ipynb) - [canonical](part-05-appendices/appendix-01-tensor-notation/a01-tensor-notation.ipynb); printed pp. 562-564; PDF pp. 580-582; Covariant and contravariant indices, basis changes, contractions, the epsilon tensor, and trifocal tensor notation.
# - [Appendix 02: Gaussian and Chi-square Distributions](part-05-appendices/appendix-02-gaussian-normal-and-chi2-distributions/00-index.ipynb) - [canonical](part-05-appendices/appendix-02-gaussian-normal-and-chi2-distributions/a02-gaussian-normal-and-chi2-distributions.ipynb); printed pp. 565-567; PDF pp. 583-585; Gaussian measurement models, covariance, Mahalanobis distance, confidence gates, and chi-square diagnostics.
# - [Appendix 03: Parameter Estimation](part-05-appendices/appendix-03-parameter-estimation/00-index.ipynb) - [canonical](part-05-appendices/appendix-03-parameter-estimation/a03-parameter-estimation.ipynb); printed pp. 568-577; PDF pp. 586-595; Bias, variance, maximum likelihood, posterior estimation, Fisher information, and Cramer-Rao style bounds.
# - [Appendix 04: Matrix Properties and Decompositions](part-05-appendices/appendix-04-matrix-properties-and-decompositions/00-index.ipynb) - [canonical](part-05-appendices/appendix-04-matrix-properties-and-decompositions/a04-matrix-properties-and-decompositions.ipynb); printed pp. 578-587; PDF pp. 596-605; Rank, nullspaces, eigenstructure, SVD, Cholesky, QR/RQ, Schur, and matrix identities used by MVG algorithms.
# - [Appendix 05: Least-squares Minimization](part-05-appendices/appendix-05-least-squares-minimization/00-index.ipynb) - [canonical](part-05-appendices/appendix-05-least-squares-minimization/a05-least-squares-minimization.ipynb); printed pp. 588-596; PDF pp. 606-614; Linear least squares, normal equations, total least squares, weighted least squares, constrained systems, and sparse symmetric equations.
# - [Appendix 06: Iterative Estimation Methods](part-05-appendices/appendix-06-iterative-estimation-methods/00-index.ipynb) - [canonical](part-05-appendices/appendix-06-iterative-estimation-methods/a06-iterative-estimation-methods.ipynb); printed pp. 597-627; PDF pp. 615-645; Newton, Gauss-Newton, Levenberg-Marquardt, sparse systems, robust costs, rotations, homogeneous vectors, and constrained parameterizations.
# - [Appendix 07: Some Special Plane Projective Transformations](part-05-appendices/appendix-07-some-special-plane-projective-transformations/00-index.ipynb) - [canonical](part-05-appendices/appendix-07-some-special-plane-projective-transformations/a07-some-special-plane-projective-transformations.ipynb); printed pp. 628-633; PDF pp. 646-651; Conjugate rotations, homologies, elations, affinities, and special eigenstructure of plane projective transformations.

# %%
# geometry-setup:v1
# Machine-managed by scripts/update_notebook_setup.py. Do not edit this cell by hand.

from __future__ import annotations

import json as _geometry_json
import os as _geometry_os
from pathlib import Path as _GeometryPath
import sys as _geometry_sys

GEOMETRY_SETUP = _geometry_json.loads(
    r"""
{
  "colab_url": "https://colab.research.google.com/github/Rah-Rah-Mitra/Geometry/blob/main/Multiple-View-Geometry-in-Computer-Vision/00-book-index.ipynb",
  "course_dir": "Multiple-View-Geometry-in-Computer-Vision",
  "course_title": "Multiple View Geometry in Computer Vision",
  "github_url": "https://github.com/Rah-Rah-Mitra/Geometry/blob/main/Multiple-View-Geometry-in-Computer-Vision/00-book-index.ipynb",
  "jupyterlite": false,
  "marker": "geometry-setup:v1",
  "notebook_kind": "book-index",
  "notebook_path": "Multiple-View-Geometry-in-Computer-Vision/00-book-index.ipynb",
  "notebook_title": "Multiple View Geometry in Computer Vision",
  "repository": {
    "branch": "main",
    "name": "Geometry",
    "owner": "Rah-Rah-Mitra",
    "source_url": "https://github.com/Rah-Rah-Mitra/Geometry"
  },
  "requirements": "requirements/graphics.txt",
  "runtime_profile": "graphics"
}
"""
)


def _geometry_is_colab():
    try:
        import google.colab  # type: ignore  # noqa: F401
        return True
    except Exception:
        return False


def _geometry_is_jupyterlite():
    return _geometry_sys.platform == "emscripten" or "pyodide" in _geometry_sys.modules


def _geometry_add_path(path):
    text = str(path)
    if text not in _geometry_sys.path:
        _geometry_sys.path.insert(0, text)


def _geometry_find_repo_root():
    candidates = []
    env_root = _geometry_os.environ.get("GEOMETRY_REPO_ROOT")
    if env_root:
        candidates.append(_GeometryPath(env_root).expanduser())
    candidates.append(_GeometryPath.cwd())
    for start in candidates:
        start = start.resolve()
        for current in (start, *start.parents):
            if (current / "course-manifest.json").exists() and (
                current / "metadata" / "runtime_profiles.yml"
            ).exists():
                return current
    raise RuntimeError(
        "Could not find the Geometry repository root. Start JupyterLab inside the "
        "Geometry checkout or set GEOMETRY_REPO_ROOT."
    )


def _geometry_run(command):
    import subprocess as _geometry_subprocess

    printable = " ".join(str(part) for part in command)
    print(f"+ {printable}")
    _geometry_subprocess.check_call([str(part) for part in command])


def _geometry_requirement_names(requirements_path, seen=None):
    seen = set() if seen is None else seen
    requirements_path = requirements_path.resolve()
    if requirements_path in seen or not requirements_path.exists():
        return []
    seen.add(requirements_path)
    names = []
    for raw_line in requirements_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.split("#", 1)[0].strip()
        if not line:
            continue
        if line.startswith(("-r ", "--requirement ")):
            _, nested = line.split(maxsplit=1)
            names.extend(_geometry_requirement_names(requirements_path.parent / nested, seen))
            continue
        if line.startswith("-"):
            continue
        name = line
        for separator in ("==", ">=", "<=", "~=", "!=", ">", "<", ";"):
            name = name.split(separator, 1)[0]
        name = name.split("[", 1)[0].strip()
        if name:
            names.append(name)
    return sorted(set(names))


def _geometry_missing_requirements(requirements_path):
    import importlib.metadata as _geometry_metadata

    missing = []
    for name in _geometry_requirement_names(requirements_path):
        try:
            _geometry_metadata.distribution(name)
        except _geometry_metadata.PackageNotFoundError:
            missing.append(name)
    return missing


def _geometry_configured_roots(repo_root):
    course_dir = GEOMETRY_SETUP.get("course_dir")
    course_root = repo_root / course_dir if course_dir else repo_root
    return repo_root, course_root


if _geometry_is_jupyterlite():
    if not GEOMETRY_SETUP["jupyterlite"]:
        raise RuntimeError(
            "This Geometry notebook uses runtime profile "
            f"{GEOMETRY_SETUP['runtime_profile']!r}, which is not enabled for "
            "JupyterLite in course-manifest.json. Open it in Colab or local JupyterLab."
        )
    GEOMETRY_REPO_ROOT = _GeometryPath.cwd()
    GEOMETRY_COURSE_ROOT = (
        GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["course_dir"]
        if GEOMETRY_SETUP.get("course_dir")
        else GEOMETRY_REPO_ROOT
    )
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    if GEOMETRY_COURSE_ROOT.exists():
        _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        "Geometry setup: JupyterLite/Pyodide detected; shell, git, and pip steps "
        "were skipped."
    )
elif _geometry_is_colab():
    repository = GEOMETRY_SETUP["repository"]
    repo_url = repository["source_url"].rstrip("/") + ".git"
    branch = repository["branch"]
    GEOMETRY_REPO_ROOT = _GeometryPath(
        _geometry_os.environ.get("GEOMETRY_REPO_ROOT", "/content/Geometry")
    )
    sparse_paths = ["requirements", "metadata", "scripts", "course-manifest.json", "index.ipynb"]
    if GEOMETRY_SETUP.get("course_dir"):
        sparse_paths.append(GEOMETRY_SETUP["course_dir"])
    if not (GEOMETRY_REPO_ROOT / ".git").exists():
        if GEOMETRY_REPO_ROOT.exists() and any(GEOMETRY_REPO_ROOT.iterdir()):
            raise RuntimeError(
                f"{GEOMETRY_REPO_ROOT} exists but is not a git checkout. "
                "Set GEOMETRY_REPO_ROOT to an empty path or remove the directory."
            )
        _geometry_run(
            [
                "git",
                "clone",
                "--filter=blob:none",
                "--no-checkout",
                "--branch",
                branch,
                repo_url,
                GEOMETRY_REPO_ROOT,
            ]
        )
        _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "init", "--cone"])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "sparse-checkout", "set", *sparse_paths])
    _geometry_run(["git", "-C", GEOMETRY_REPO_ROOT, "checkout", branch])
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-q", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: Colab ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )
else:
    GEOMETRY_REPO_ROOT = _geometry_find_repo_root()
    requirements_path = GEOMETRY_REPO_ROOT / GEOMETRY_SETUP["requirements"]
    missing = _geometry_missing_requirements(requirements_path)
    skip_install = _geometry_os.environ.get("GEOMETRY_SKIP_INSTALL") == "1"
    if missing and skip_install:
        print(
            "Geometry setup: GEOMETRY_SKIP_INSTALL=1, so missing profile packages "
            f"were not installed: {', '.join(missing)}"
        )
    elif missing:
        print(
            "Geometry setup: installing missing profile packages from "
            f"{requirements_path.relative_to(GEOMETRY_REPO_ROOT)}: {', '.join(missing)}"
        )
        _geometry_run([_geometry_sys.executable, "-m", "pip", "install", "-r", requirements_path])
    GEOMETRY_REPO_ROOT, GEOMETRY_COURSE_ROOT = _geometry_configured_roots(GEOMETRY_REPO_ROOT)
    _geometry_os.chdir(GEOMETRY_COURSE_ROOT if GEOMETRY_COURSE_ROOT.exists() else GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_REPO_ROOT)
    _geometry_add_path(GEOMETRY_COURSE_ROOT)
    GEOMETRY_RUNTIME_PROFILE = GEOMETRY_SETUP["runtime_profile"]
    print(
        f"Geometry setup: local checkout ready at {_GeometryPath.cwd()} "
        f"with profile {GEOMETRY_RUNTIME_PROFILE!r}."
    )

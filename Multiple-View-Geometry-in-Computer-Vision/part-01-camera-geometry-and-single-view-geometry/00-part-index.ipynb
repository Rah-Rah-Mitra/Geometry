# %% [markdown]
# # Part I: Camera Geometry and Single View Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Camera matrices, calibration, distortion, vanishing geometry, and single-view measurement.
#
# ## Chapter 06: Camera Models
#
# - Chapter index: [chapter-06-camera-models/00-index.ipynb](chapter-06-camera-models/00-index.ipynb)
# - Canonical notebook: [06-camera-models.ipynb](chapter-06-camera-models/06-camera-models.ipynb)
# - Source span: printed pp. 153-177; PDF pp. 171-195
# - Focus: Finite cameras, projective cameras, affine cameras, intrinsic/extrinsic factorization, and alternative camera models.
#
# ## Chapter 07: Computation of the Camera Matrix P
#
# - Chapter index: [chapter-07-computation-of-the-camera-matrix-p/00-index.ipynb](chapter-07-computation-of-the-camera-matrix-p/00-index.ipynb)
# - Canonical notebook: [07-computation-of-the-camera-matrix-p.ipynb](chapter-07-computation-of-the-camera-matrix-p/07-computation-of-the-camera-matrix-p.ipynb)
# - Source span: printed pp. 178-194; PDF pp. 196-212
# - Focus: Camera resectioning from 3D-2D correspondences, geometric error, constrained calibration, and radial distortion.
#
# ## Chapter 08: More Single View Geometry
#
# - Chapter index: [chapter-08-more-single-view-geometry/00-index.ipynb](chapter-08-more-single-view-geometry/00-index.ipynb)
# - Canonical notebook: [08-more-single-view-geometry.ipynb](chapter-08-more-single-view-geometry/08-more-single-view-geometry.ipynb)
# - Source span: printed pp. 195-236; PDF pp. 213-254
# - Focus: Projection of planes, lines, conics, quadrics, silhouettes, vanishing points, the image of the absolute conic, and single-view reconstruction.

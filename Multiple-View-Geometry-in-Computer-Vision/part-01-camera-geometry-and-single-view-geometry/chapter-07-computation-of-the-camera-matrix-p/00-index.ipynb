# %% [markdown]
# # Chapter 07: Computation of the Camera Matrix P
#
# Source orientation: printed pages 178-194; PDF pages 196-212.
#
# Canonical notebook: [07-computation-of-the-camera-matrix-p.ipynb](07-computation-of-the-camera-matrix-p.ipynb)
#
# ## Focus
#
# Camera resectioning from 3D-2D correspondences, geometric error, constrained calibration, and radial distortion.
#
# ## Visual Storyboard
#
# - calibration target projection
# - camera resection residual vectors
# - distortion and undistortion grid
# - restricted-camera parameter panel
#
# ## Computational Checks
#
# - estimated P reprojects calibration points with low RMSE
# - radial correction reduces curved residual structure
# - camera center remains finite for a finite camera
# - constrained estimates preserve their intended parameter restrictions

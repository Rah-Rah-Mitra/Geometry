# %% [markdown]
# # Appendix 02: Gaussian and Chi-square Distributions
#
# Source orientation: printed pages 565-567; PDF pages 583-585.
#
# Canonical notebook: [a02-gaussian-normal-and-chi2-distributions.ipynb](a02-gaussian-normal-and-chi2-distributions.ipynb)
#
# ## Focus
#
# Gaussian measurement models, covariance, Mahalanobis distance, confidence gates, and chi-square diagnostics.
#
# ## Visual Storyboard
#
# - covariance ellipse field
# - Mahalanobis distance contours
# - chi-square confidence gates
# - sample coverage dashboard
#
# ## Computational Checks
#
# - sample covariance is positive semidefinite
# - Mahalanobis distances follow the expected distribution roughly
# - confidence gates contain the planned fraction of samples
# - whitening produces nearly identity covariance

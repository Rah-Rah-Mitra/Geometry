# %% [markdown]
# # Part V: Appendices
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Tensor notation, statistics, parameter estimation, matrix decompositions, least squares, iterative methods, and special homographies.
#
# ## Appendix 01: Tensor Notation
#
# - Chapter index: [appendix-01-tensor-notation/00-index.ipynb](appendix-01-tensor-notation/00-index.ipynb)
# - Canonical notebook: [a01-tensor-notation.ipynb](appendix-01-tensor-notation/a01-tensor-notation.ipynb)
# - Source span: printed pp. 562-564; PDF pp. 580-582
# - Focus: Covariant and contravariant indices, basis changes, contractions, the epsilon tensor, and trifocal tensor notation.
#
# ## Appendix 02: Gaussian and Chi-square Distributions
#
# - Chapter index: [appendix-02-gaussian-normal-and-chi2-distributions/00-index.ipynb](appendix-02-gaussian-normal-and-chi2-distributions/00-index.ipynb)
# - Canonical notebook: [a02-gaussian-normal-and-chi2-distributions.ipynb](appendix-02-gaussian-normal-and-chi2-distributions/a02-gaussian-normal-and-chi2-distributions.ipynb)
# - Source span: printed pp. 565-567; PDF pp. 583-585
# - Focus: Gaussian measurement models, covariance, Mahalanobis distance, confidence gates, and chi-square diagnostics.
#
# ## Appendix 03: Parameter Estimation
#
# - Chapter index: [appendix-03-parameter-estimation/00-index.ipynb](appendix-03-parameter-estimation/00-index.ipynb)
# - Canonical notebook: [a03-parameter-estimation.ipynb](appendix-03-parameter-estimation/a03-parameter-estimation.ipynb)
# - Source span: printed pp. 568-577; PDF pp. 586-595
# - Focus: Bias, variance, maximum likelihood, posterior estimation, Fisher information, and Cramer-Rao style bounds.
#
# ## Appendix 04: Matrix Properties and Decompositions
#
# - Chapter index: [appendix-04-matrix-properties-and-decompositions/00-index.ipynb](appendix-04-matrix-properties-and-decompositions/00-index.ipynb)
# - Canonical notebook: [a04-matrix-properties-and-decompositions.ipynb](appendix-04-matrix-properties-and-decompositions/a04-matrix-properties-and-decompositions.ipynb)
# - Source span: printed pp. 578-587; PDF pp. 596-605
# - Focus: Rank, nullspaces, eigenstructure, SVD, Cholesky, QR/RQ, Schur, and matrix identities used by MVG algorithms.
#
# ## Appendix 05: Least-squares Minimization
#
# - Chapter index: [appendix-05-least-squares-minimization/00-index.ipynb](appendix-05-least-squares-minimization/00-index.ipynb)
# - Canonical notebook: [a05-least-squares-minimization.ipynb](appendix-05-least-squares-minimization/a05-least-squares-minimization.ipynb)
# - Source span: printed pp. 588-596; PDF pp. 606-614
# - Focus: Linear least squares, normal equations, total least squares, weighted least squares, constrained systems, and sparse symmetric equations.
#
# ## Appendix 06: Iterative Estimation Methods
#
# - Chapter index: [appendix-06-iterative-estimation-methods/00-index.ipynb](appendix-06-iterative-estimation-methods/00-index.ipynb)
# - Canonical notebook: [a06-iterative-estimation-methods.ipynb](appendix-06-iterative-estimation-methods/a06-iterative-estimation-methods.ipynb)
# - Source span: printed pp. 597-627; PDF pp. 615-645
# - Focus: Newton, Gauss-Newton, Levenberg-Marquardt, sparse systems, robust costs, rotations, homogeneous vectors, and constrained parameterizations.
#
# ## Appendix 07: Some Special Plane Projective Transformations
#
# - Chapter index: [appendix-07-some-special-plane-projective-transformations/00-index.ipynb](appendix-07-some-special-plane-projective-transformations/00-index.ipynb)
# - Canonical notebook: [a07-some-special-plane-projective-transformations.ipynb](appendix-07-some-special-plane-projective-transformations/a07-some-special-plane-projective-transformations.ipynb)
# - Source span: printed pp. 628-633; PDF pp. 646-651
# - Focus: Conjugate rotations, homologies, elations, affinities, and special eigenstructure of plane projective transformations.

# %% [markdown]
# # Part III: Three-View Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# The trifocal tensor, point and line transfer, three-view constraints, and tensor estimation.
#
# ## Chapter 15: The Trifocal Tensor
#
# - Chapter index: [chapter-15-the-trifocal-tensor/00-index.ipynb](chapter-15-the-trifocal-tensor/00-index.ipynb)
# - Canonical notebook: [15-the-trifocal-tensor.ipynb](chapter-15-the-trifocal-tensor/15-the-trifocal-tensor.ipynb)
# - Source span: printed pp. 365-390; PDF pp. 383-408
# - Focus: The geometric basis of the trifocal tensor, tensor notation, transfer, and three-view fundamental matrices.
#
# ## Chapter 16: Computation of the Trifocal Tensor T
#
# - Chapter index: [chapter-16-computation-of-the-trifocal-tensor-t/00-index.ipynb](chapter-16-computation-of-the-trifocal-tensor-t/00-index.ipynb)
# - Canonical notebook: [16-computation-of-the-trifocal-tensor-t.ipynb](chapter-16-computation-of-the-trifocal-tensor-t/16-computation-of-the-trifocal-tensor-t.ipynb)
# - Source span: printed pp. 391-408; PDF pp. 409-426
# - Focus: Linear, algebraic, geometric, and robust estimation of the trifocal tensor from point and line correspondences.

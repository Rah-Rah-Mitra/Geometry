# %% [markdown]
# # Chapter 16: Computation of the Trifocal Tensor T
#
# Source orientation: printed pages 391-408; PDF pages 409-426.
#
# Canonical notebook: [16-computation-of-the-trifocal-tensor-t.ipynb](16-computation-of-the-trifocal-tensor-t.ipynb)
#
# ## Focus
#
# Linear, algebraic, geometric, and robust estimation of the trifocal tensor from point and line correspondences.
#
# ## Visual Storyboard
#
# - triplet correspondence lab
# - transfer-error landscape
# - robust tensor inlier plot
# - normalization effect panel
#
# ## Computational Checks
#
# - linear tensor residuals decrease with normalization
# - robust fitting rejects high-transfer-error triplets
# - estimated transfer points land near observations
# - geometric refinement improves the median transfer error

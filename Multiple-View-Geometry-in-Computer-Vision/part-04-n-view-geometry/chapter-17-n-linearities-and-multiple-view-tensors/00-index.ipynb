# %% [markdown]
# # Chapter 17: N-Linearities and Multiple View Tensors
#
# Source orientation: printed pages 411-433; PDF pages 429-451.
#
# Canonical notebook: [17-n-linearities-and-multiple-view-tensors.ipynb](17-n-linearities-and-multiple-view-tensors.ipynb)
#
# ## Focus
#
# Bilinear, trilinear, and quadrilinear relations; plane intersections; counting arguments; independent equations; and equation choice.
#
# ## Visual Storyboard
#
# - tensor ladder diagram
# - determinant block relations
# - degree-of-freedom calculator
# - independent-equation graph
#
# ## Computational Checks
#
# - counted degrees of freedom match the synthetic parameterization
# - selected determinants vanish on consistent tracks
# - rank drops identify redundant equations
# - equation subsets preserve the same reconstruction residual

# %% [markdown]
# # Part IV: N-View Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Multiple-view tensors, factorization, bundle adjustment, auto-calibration, duality, cheirality, and degeneracies.
#
# ## Chapter 17: N-Linearities and Multiple View Tensors
#
# - Chapter index: [chapter-17-n-linearities-and-multiple-view-tensors/00-index.ipynb](chapter-17-n-linearities-and-multiple-view-tensors/00-index.ipynb)
# - Canonical notebook: [17-n-linearities-and-multiple-view-tensors.ipynb](chapter-17-n-linearities-and-multiple-view-tensors/17-n-linearities-and-multiple-view-tensors.ipynb)
# - Source span: printed pp. 411-433; PDF pp. 429-451
# - Focus: Bilinear, trilinear, and quadrilinear relations; plane intersections; counting arguments; independent equations; and equation choice.
#
# ## Chapter 18: N-View Computational Methods
#
# - Chapter index: [chapter-18-n-view-computational-methods/00-index.ipynb](chapter-18-n-view-computational-methods/00-index.ipynb)
# - Canonical notebook: [18-n-view-computational-methods.ipynb](chapter-18-n-view-computational-methods/18-n-view-computational-methods.ipynb)
# - Source span: printed pp. 434-457; PDF pp. 452-475
# - Focus: Bundle adjustment, affine factorization, non-rigid factorization, projective factorization, plane-based reconstruction, and sequences.
#
# ## Chapter 19: Auto-Calibration
#
# - Chapter index: [chapter-19-auto-calibration/00-index.ipynb](chapter-19-auto-calibration/00-index.ipynb)
# - Canonical notebook: [19-auto-calibration.ipynb](chapter-19-auto-calibration/19-auto-calibration.ipynb)
# - Source span: printed pp. 458-501; PDF pp. 476-519
# - Focus: Algebraic auto-calibration, the absolute dual quadric, Kruppa equations, stratified solutions, rotating cameras, planar motion, turntables, and stereo rigs.
#
# ## Chapter 20: Duality
#
# - Chapter index: [chapter-20-duality/00-index.ipynb](chapter-20-duality/00-index.ipynb)
# - Canonical notebook: [20-duality.ipynb](chapter-20-duality/20-duality.ipynb)
# - Source span: printed pp. 502-514; PDF pp. 520-532
# - Focus: Carlsson-Weinshall duality and reduced reconstruction through the exchange of point and camera roles.
#
# ## Chapter 21: Cheirality
#
# - Chapter index: [chapter-21-cheirality/00-index.ipynb](chapter-21-cheirality/00-index.ipynb)
# - Canonical notebook: [21-cheirality.ipynb](chapter-21-cheirality/21-cheirality.ipynb)
# - Source span: printed pp. 515-532; PDF pp. 533-550
# - Focus: Quasi-affine transformations, front/back camera tests, visible point sets, cheiral inequalities, third-view visibility, and depth ordering.
#
# ## Chapter 22: Degenerate Configurations
#
# - Chapter index: [chapter-22-degenerate-configurations/00-index.ipynb](chapter-22-degenerate-configurations/00-index.ipynb)
# - Canonical notebook: [22-degenerate-configurations.ipynb](chapter-22-degenerate-configurations/22-degenerate-configurations.ipynb)
# - Source span: printed pp. 533-560; PDF pp. 551-578
# - Focus: Degeneracies in camera resectioning, two-view and three-view reconstruction, critical surfaces, and ambiguous configurations.

# %% [markdown]
# # Chapter 20: Duality
#
# Source orientation: printed pages 502-514; PDF pages 520-532.
#
# Canonical notebook: [20-duality.ipynb](20-duality.ipynb)
#
# ## Focus
#
# Carlsson-Weinshall duality and reduced reconstruction through the exchange of point and camera roles.
#
# ## Visual Storyboard
#
# - point-camera dual swap
# - incidence bipartite graph
# - reduced reconstruction panel
# - dual residual comparison
#
# ## Computational Checks
#
# - dual incidence matrices have matching zero patterns
# - primal and dual residuals agree on synthetic data
# - reduced variables reproduce the target measurements
# - graph connectivity predicts recoverable components

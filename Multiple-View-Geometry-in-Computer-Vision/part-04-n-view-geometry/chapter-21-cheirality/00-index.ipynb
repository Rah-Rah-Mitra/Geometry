# %% [markdown]
# # Chapter 21: Cheirality
#
# Source orientation: printed pages 515-532; PDF pages 533-550.
#
# Canonical notebook: [21-cheirality.ipynb](21-cheirality.ipynb)
#
# ## Focus
#
# Quasi-affine transformations, front/back camera tests, visible point sets, cheiral inequalities, third-view visibility, and depth ordering.
#
# ## Visual Storyboard
#
# - depth-sign viewer
# - cheiral half-space plot
# - third-view visibility map
# - quasi-affine transformation panel
#
# ## Computational Checks
#
# - visible points have positive projective depth
# - cheiral inequalities are feasible for the selected reconstruction
# - quasi-affine transforms preserve depth signs
# - third-view predictions match the synthetic visibility mask

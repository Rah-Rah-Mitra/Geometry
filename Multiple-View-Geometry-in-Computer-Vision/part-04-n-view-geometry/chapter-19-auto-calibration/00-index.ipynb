# %% [markdown]
# # Chapter 19: Auto-Calibration
#
# Source orientation: printed pages 458-501; PDF pages 476-519.
#
# Canonical notebook: [19-auto-calibration.ipynb](19-auto-calibration.ipynb)
#
# ## Focus
#
# Algebraic auto-calibration, the absolute dual quadric, Kruppa equations, stratified solutions, rotating cameras, planar motion, turntables, and stereo rigs.
#
# ## Visual Storyboard
#
# - calibration constraint accumulator
# - absolute dual quadric viewer
# - Kruppa constraint sketch
# - rotating-camera calibration panel
#
# ## Computational Checks
#
# - recovered K has positive diagonal entries
# - calibration constraints reduce algebraic residuals
# - DAQ candidates have the expected signature pattern
# - rotation-only constraints agree across images

# %% [markdown]
# # Chapter 22: Degenerate Configurations
#
# Source orientation: printed pages 533-560; PDF pages 551-578.
#
# Canonical notebook: [22-degenerate-configurations.ipynb](22-degenerate-configurations.ipynb)
#
# ## Focus
#
# Degeneracies in camera resectioning, two-view and three-view reconstruction, critical surfaces, and ambiguous configurations.
#
# ## Visual Storyboard
#
# - critical-surface gallery
# - rank-nullity dashboard
# - two-view degeneracy scene
# - three-view ambiguity panel
#
# ## Computational Checks
#
# - design matrices lose rank in degenerate layouts
# - nullspace dimension increases for critical configurations
# - alternative reconstructions share similar reprojection error
# - diagnostics flag the degenerate sample before final estimation

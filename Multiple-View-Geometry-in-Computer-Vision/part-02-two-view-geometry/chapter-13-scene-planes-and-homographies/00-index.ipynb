# %% [markdown]
# # Chapter 13: Scene Planes and Homographies
#
# Source orientation: printed pages 325-343; PDF pages 343-361.
#
# Canonical notebook: [13-scene-planes-and-homographies.ipynb](13-scene-planes-and-homographies.ipynb)
#
# ## Focus
#
# Plane-induced homographies, recovering planes, F from a plane homography, parallax, and the infinite homography.
#
# ## Visual Storyboard
#
# - plane transfer field
# - parallax vector plot
# - F-from-H consistency diagram
# - infinite homography comparison
#
# ## Computational Checks
#
# - planar points transfer with low homography residual
# - off-plane parallax is nonzero and epipolar
# - F reconstructed from H satisfies point constraints
# - H infinity agrees with the rotation-induced transfer

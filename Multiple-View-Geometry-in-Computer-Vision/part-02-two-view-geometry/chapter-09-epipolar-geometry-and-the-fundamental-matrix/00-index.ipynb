# %% [markdown]
# # Chapter 09: Epipolar Geometry and the Fundamental Matrix
#
# Source orientation: printed pages 239-261; PDF pages 257-279.
#
# Canonical notebook: [09-epipolar-geometry-and-the-fundamental-matrix.ipynb](09-epipolar-geometry-and-the-fundamental-matrix.ipynb)
#
# ## Focus
#
# Epipolar geometry, the fundamental matrix, special motions, epipoles, camera retrieval, and the essential matrix.
#
# ## Visual Storyboard
#
# - two-camera epipolar fan
# - moving-point epiline widget sketch
# - F and E singular value panel
# - camera retrieval diagram
#
# ## Computational Checks
#
# - x2 transpose F x1 is near zero
# - F has rank two
# - epipoles lie in the left and right nullspaces
# - essential matrix singular values occur as a repeated pair and zero

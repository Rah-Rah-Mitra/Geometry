# %% [markdown]
# # Chapter 10: 3D Reconstruction of Cameras and Structure
#
# Source orientation: printed pages 262-278; PDF pages 280-296.
#
# Canonical notebook: [10-3d-reconstruction-of-cameras-and-structure.ipynb](10-3d-reconstruction-of-cameras-and-structure.ipynb)
#
# ## Focus
#
# Projective reconstruction, reconstruction ambiguity, the projective reconstruction theorem, and stratified upgrade.
#
# ## Visual Storyboard
#
# - projective ambiguity warp
# - stratified reconstruction ladder
# - camera and point reconstruction scene
# - reprojection-invariance dashboard
#
# ## Computational Checks
#
# - transformed cameras and points keep identical image projections
# - reprojection error remains low after projective warps
# - affine upgrade fixes a plane at infinity
# - metric upgrade restores Euclidean angle checks

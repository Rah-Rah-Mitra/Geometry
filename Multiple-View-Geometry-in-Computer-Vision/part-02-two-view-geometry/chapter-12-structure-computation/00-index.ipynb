# %% [markdown]
# # Chapter 12: Structure Computation
#
# Source orientation: printed pages 310-324; PDF pages 328-342.
#
# Canonical notebook: [12-structure-computation.ipynb](12-structure-computation.ipynb)
#
# ## Focus
#
# Linear triangulation, geometric error, Sampson correction, optimal correction, uncertainty, and line reconstruction.
#
# ## Visual Storyboard
#
# - skew-ray closest approach
# - linear versus optimal triangulation
# - uncertainty ellipsoid
# - line reconstruction from image lines
#
# ## Computational Checks
#
# - triangulated points reproject to both images
# - ray angle predicts depth uncertainty
# - refinement lowers geometric reprojection error
# - estimated covariance is positive semidefinite

# %% [markdown]
# # Chapter 14: Affine Epipolar Geometry
#
# Source orientation: printed pages 344-362; PDF pages 362-380.
#
# Canonical notebook: [14-affine-epipolar-geometry.ipynb](14-affine-epipolar-geometry.ipynb)
#
# ## Focus
#
# Affine cameras, affine fundamental matrix estimation, triangulation, affine reconstruction, bas-relief ambiguity, and motion recovery.
#
# ## Visual Storyboard
#
# - orthographic two-camera scene
# - affine epipolar line family
# - bas-relief ambiguity slider sketch
# - affine triangulation panel
#
# ## Computational Checks
#
# - affine epipolar residuals are linear in image coordinates
# - parallel epipolar lines share a direction
# - bas-relief transformed points preserve affine reprojections
# - recovered motion satisfies the affine camera equations

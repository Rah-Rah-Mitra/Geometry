# %% [markdown]
# # Part II: Two-View Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Epipolar geometry, the fundamental matrix, triangulation, homographies, rectification, and affine stereo.
#
# ## Chapter 09: Epipolar Geometry and the Fundamental Matrix
#
# - Chapter index: [chapter-09-epipolar-geometry-and-the-fundamental-matrix/00-index.ipynb](chapter-09-epipolar-geometry-and-the-fundamental-matrix/00-index.ipynb)
# - Canonical notebook: [09-epipolar-geometry-and-the-fundamental-matrix.ipynb](chapter-09-epipolar-geometry-and-the-fundamental-matrix/09-epipolar-geometry-and-the-fundamental-matrix.ipynb)
# - Source span: printed pp. 239-261; PDF pp. 257-279
# - Focus: Epipolar geometry, the fundamental matrix, special motions, epipoles, camera retrieval, and the essential matrix.
#
# ## Chapter 10: 3D Reconstruction of Cameras and Structure
#
# - Chapter index: [chapter-10-3d-reconstruction-of-cameras-and-structure/00-index.ipynb](chapter-10-3d-reconstruction-of-cameras-and-structure/00-index.ipynb)
# - Canonical notebook: [10-3d-reconstruction-of-cameras-and-structure.ipynb](chapter-10-3d-reconstruction-of-cameras-and-structure/10-3d-reconstruction-of-cameras-and-structure.ipynb)
# - Source span: printed pp. 262-278; PDF pp. 280-296
# - Focus: Projective reconstruction, reconstruction ambiguity, the projective reconstruction theorem, and stratified upgrade.
#
# ## Chapter 11: Computation of the Fundamental Matrix F
#
# - Chapter index: [chapter-11-computation-of-the-fundamental-matrix-f/00-index.ipynb](chapter-11-computation-of-the-fundamental-matrix-f/00-index.ipynb)
# - Canonical notebook: [11-computation-of-the-fundamental-matrix-f.ipynb](chapter-11-computation-of-the-fundamental-matrix-f/11-computation-of-the-fundamental-matrix-f.ipynb)
# - Source span: printed pp. 279-309; PDF pp. 297-327
# - Focus: Normalized eight-point estimation, algebraic minimization, geometric distance, robust computation, degeneracies, envelopes, and rectification.
#
# ## Chapter 12: Structure Computation
#
# - Chapter index: [chapter-12-structure-computation/00-index.ipynb](chapter-12-structure-computation/00-index.ipynb)
# - Canonical notebook: [12-structure-computation.ipynb](chapter-12-structure-computation/12-structure-computation.ipynb)
# - Source span: printed pp. 310-324; PDF pp. 328-342
# - Focus: Linear triangulation, geometric error, Sampson correction, optimal correction, uncertainty, and line reconstruction.
#
# ## Chapter 13: Scene Planes and Homographies
#
# - Chapter index: [chapter-13-scene-planes-and-homographies/00-index.ipynb](chapter-13-scene-planes-and-homographies/00-index.ipynb)
# - Canonical notebook: [13-scene-planes-and-homographies.ipynb](chapter-13-scene-planes-and-homographies/13-scene-planes-and-homographies.ipynb)
# - Source span: printed pp. 325-343; PDF pp. 343-361
# - Focus: Plane-induced homographies, recovering planes, F from a plane homography, parallax, and the infinite homography.
#
# ## Chapter 14: Affine Epipolar Geometry
#
# - Chapter index: [chapter-14-affine-epipolar-geometry/00-index.ipynb](chapter-14-affine-epipolar-geometry/00-index.ipynb)
# - Canonical notebook: [14-affine-epipolar-geometry.ipynb](chapter-14-affine-epipolar-geometry/14-affine-epipolar-geometry.ipynb)
# - Source span: printed pp. 344-362; PDF pp. 362-380
# - Focus: Affine cameras, affine fundamental matrix estimation, triangulation, affine reconstruction, bas-relief ambiguity, and motion recovery.

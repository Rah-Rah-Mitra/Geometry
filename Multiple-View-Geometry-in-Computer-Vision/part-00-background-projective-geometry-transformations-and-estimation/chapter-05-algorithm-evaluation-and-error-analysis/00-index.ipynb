# %% [markdown]
# # Chapter 05: Algorithm Evaluation and Error Analysis
#
# Source orientation: printed pages 132-150; PDF pages 150-168.
#
# Canonical notebook: [05-algorithm-evaluation-and-error-analysis.ipynb](05-algorithm-evaluation-and-error-analysis.ipynb)
#
# ## Focus
#
# Performance bounds, covariance propagation, Monte Carlo covariance, and empirical evaluation of geometric estimators.
#
# ## Visual Storyboard
#
# - error ellipse field
# - noise sweep dashboard
# - Monte Carlo covariance cloud
# - bias-variance comparison
#
# ## Computational Checks
#
# - sample covariance is positive semidefinite
# - empirical coverage roughly matches the requested confidence gate
# - RMSE grows with injected noise
# - Monte Carlo means stay close to the noiseless estimate

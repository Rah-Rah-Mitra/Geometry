# %% [markdown]
# # Chapter 04: Estimation: 2D Projective Transformations
#
# Source orientation: printed pages 87-131; PDF pages 105-149.
#
# Canonical notebook: [04-estimation-2d-projective-transformations.ipynb](04-estimation-2d-projective-transformations.ipynb)
#
# ## Focus
#
# DLT homography estimation, geometric and statistical costs, normalization, iterative refinement, robust estimation, and automatic matching.
#
# ## Visual Storyboard
#
# - noisy correspondence homography
# - normalization condition-number heatmap
# - RANSAC inlier map
# - cost-function comparison panel
#
# ## Computational Checks
#
# - DLT residual decreases after normalization
# - estimated H is scale normalized
# - RANSAC inlier count exceeds the outlier count
# - geometric reprojection error is lower than the raw algebraic baseline

# %% [markdown]
# # Part 0: The Background: Projective Geometry, Transformations and Estimation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Projective 2D/3D geometry, homographies, numerical estimation, and error analysis.
#
# ## Chapter 02: Projective Geometry and Transformations of 2D
#
# - Chapter index: [chapter-02-projective-geometry-and-transformations-of-2d/00-index.ipynb](chapter-02-projective-geometry-and-transformations-of-2d/00-index.ipynb)
# - Canonical notebook: [02-projective-geometry-and-transformations-of-2d.ipynb](chapter-02-projective-geometry-and-transformations-of-2d/02-projective-geometry-and-transformations-of-2d.ipynb)
# - Source span: printed pp. 25-64; PDF pp. 43-82
# - Focus: Points, lines, conics, homographies, transformation hierarchy, rectification, and metric recovery in the projective plane.
#
# ## Chapter 03: Projective Geometry and Transformations of 3D
#
# - Chapter index: [chapter-03-projective-geometry-and-transformations-of-3d/00-index.ipynb](chapter-03-projective-geometry-and-transformations-of-3d/00-index.ipynb)
# - Canonical notebook: [03-projective-geometry-and-transformations-of-3d.ipynb](chapter-03-projective-geometry-and-transformations-of-3d/03-projective-geometry-and-transformations-of-3d.ipynb)
# - Source span: printed pp. 65-86; PDF pp. 83-104
# - Focus: Projective 3D points, planes, lines, quadrics, twisted cubics, the plane at infinity, and the absolute conic.
#
# ## Chapter 04: Estimation: 2D Projective Transformations
#
# - Chapter index: [chapter-04-estimation-2d-projective-transformations/00-index.ipynb](chapter-04-estimation-2d-projective-transformations/00-index.ipynb)
# - Canonical notebook: [04-estimation-2d-projective-transformations.ipynb](chapter-04-estimation-2d-projective-transformations/04-estimation-2d-projective-transformations.ipynb)
# - Source span: printed pp. 87-131; PDF pp. 105-149
# - Focus: DLT homography estimation, geometric and statistical costs, normalization, iterative refinement, robust estimation, and automatic matching.
#
# ## Chapter 05: Algorithm Evaluation and Error Analysis
#
# - Chapter index: [chapter-05-algorithm-evaluation-and-error-analysis/00-index.ipynb](chapter-05-algorithm-evaluation-and-error-analysis/00-index.ipynb)
# - Canonical notebook: [05-algorithm-evaluation-and-error-analysis.ipynb](chapter-05-algorithm-evaluation-and-error-analysis/05-algorithm-evaluation-and-error-analysis.ipynb)
# - Source span: printed pp. 132-150; PDF pp. 150-168
# - Focus: Performance bounds, covariance propagation, Monte Carlo covariance, and empirical evaluation of geometric estimators.

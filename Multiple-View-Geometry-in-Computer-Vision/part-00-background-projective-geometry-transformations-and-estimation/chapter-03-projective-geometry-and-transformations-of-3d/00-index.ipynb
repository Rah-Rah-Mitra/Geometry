# %% [markdown]
# # Chapter 03: Projective Geometry and Transformations of 3D
#
# Source orientation: printed pages 65-86; PDF pages 83-104.
#
# Canonical notebook: [03-projective-geometry-and-transformations-of-3d.ipynb](03-projective-geometry-and-transformations-of-3d.ipynb)
#
# ## Focus
#
# Projective 3D points, planes, lines, quadrics, twisted cubics, the plane at infinity, and the absolute conic.
#
# ## Visual Storyboard
#
# - 3D incidence viewer
# - skew-line and Plucker relation demo
# - quadric slicing scene
# - absolute conic upgrade sketch
#
# ## Computational Checks
#
# - plane-point incidence vanishes for sampled points
# - line coordinates satisfy the Plucker quadratic relation
# - quadric samples satisfy the implicit equation
# - metric directions obey the absolute conic orthogonality test

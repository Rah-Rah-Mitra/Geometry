# %% [markdown]
# # Chapter 02: Projective Geometry and Transformations of 2D
#
# Source orientation: printed pages 25-64; PDF pages 43-82.
#
# Canonical notebook: [02-projective-geometry-and-transformations-of-2d.ipynb](02-projective-geometry-and-transformations-of-2d.ipynb)
#
# ## Focus
#
# Points, lines, conics, homographies, transformation hierarchy, rectification, and metric recovery in the projective plane.
#
# ## Visual Storyboard
#
# - homography grid deformation
# - vanishing line and affine rectification
# - conic pole-polar diagram
# - transformation hierarchy panel
#
# ## Computational Checks
#
# - line-point incidence is scale invariant
# - lines transform by inverse transpose
# - cross-ratios remain stable under homographies
# - rectified parallel lines meet on the recovered line at infinity

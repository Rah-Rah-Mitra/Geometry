# %% [markdown]
# # Chapter 07: Topological Persistence
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [07-topological-persistence.ipynb](07-topological-persistence.ipynb)

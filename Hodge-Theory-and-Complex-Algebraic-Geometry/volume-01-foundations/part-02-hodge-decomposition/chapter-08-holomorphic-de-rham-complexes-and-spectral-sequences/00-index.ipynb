# %% [markdown]
# # 8. Holomorphic de Rham Complexes and Spectral Sequences
#
# Canonical notebook: [08-holomorphic-de-rham-complexes-and-spectral-sequences.ipynb](08-holomorphic-de-rham-complexes-and-spectral-sequences.ipynb)
#
# Source span: volume 1, printed pages 184-216, PDF pages 196-228.
#
# Artifacts: `artifacts/volume-01/v1-c08`.

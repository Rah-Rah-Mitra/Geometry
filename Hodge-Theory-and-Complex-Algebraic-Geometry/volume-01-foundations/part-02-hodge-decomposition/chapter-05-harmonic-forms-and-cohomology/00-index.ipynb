# %% [markdown]
# # 5. Harmonic Forms and Cohomology
#
# Canonical notebook: [05-harmonic-forms-and-cohomology.ipynb](05-harmonic-forms-and-cohomology.ipynb)
#
# Source span: volume 1, printed pages 117-136, PDF pages 129-148.
#
# Artifacts: `artifacts/volume-01/v1-c05`.

# %% [markdown]
# # 7. Hodge Structures and Polarisations
#
# Canonical notebook: [07-hodge-structures-and-polarisations.ipynb](07-hodge-structures-and-polarisations.ipynb)
#
# Source span: volume 1, printed pages 156-183, PDF pages 168-195.
#
# Artifacts: `artifacts/volume-01/v1-c07`.

# %% [markdown]
# # 6. The Case of Kahler Manifolds
#
# Canonical notebook: [06-the-case-of-kahler-manifolds.ipynb](06-the-case-of-kahler-manifolds.ipynb)
#
# Source span: volume 1, printed pages 137-155, PDF pages 149-167.
#
# Artifacts: `artifacts/volume-01/v1-c06`.

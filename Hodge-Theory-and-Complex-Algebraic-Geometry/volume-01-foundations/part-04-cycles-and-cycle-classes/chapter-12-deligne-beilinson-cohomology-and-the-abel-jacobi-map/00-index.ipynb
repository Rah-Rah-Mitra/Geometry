# %% [markdown]
# # 12. Deligne-Beilinson Cohomology and the Abel-Jacobi Map
#
# Canonical notebook: [12-deligne-beilinson-cohomology-and-the-abel-jacobi-map.ipynb](12-deligne-beilinson-cohomology-and-the-abel-jacobi-map.ipynb)
#
# Source span: volume 1, printed pages 290-314, PDF pages 302-326.
#
# Artifacts: `artifacts/volume-01/v1-c12`.

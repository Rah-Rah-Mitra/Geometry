# %% [markdown]
# # 11. Hodge Classes
#
# Canonical notebook: [11-hodge-classes.ipynb](11-hodge-classes.ipynb)
#
# Source span: volume 1, printed pages 263-289, PDF pages 275-301.
#
# Artifacts: `artifacts/volume-01/v1-c11`.

# %% [markdown]
# # 10. Variations of Hodge Structure
#
# Canonical notebook: [10-variations-of-hodge-structure.ipynb](10-variations-of-hodge-structure.ipynb)
#
# Source span: volume 1, printed pages 239-260, PDF pages 251-272.
#
# Artifacts: `artifacts/volume-01/v1-c10`.

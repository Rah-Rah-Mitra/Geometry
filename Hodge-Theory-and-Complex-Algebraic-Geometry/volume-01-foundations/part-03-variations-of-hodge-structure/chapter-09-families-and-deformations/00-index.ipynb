# %% [markdown]
# # 9. Families and Deformations
#
# Canonical notebook: [09-families-and-deformations.ipynb](09-families-and-deformations.ipynb)
#
# Source span: volume 1, printed pages 219-238, PDF pages 231-250.
#
# Artifacts: `artifacts/volume-01/v1-c09`.

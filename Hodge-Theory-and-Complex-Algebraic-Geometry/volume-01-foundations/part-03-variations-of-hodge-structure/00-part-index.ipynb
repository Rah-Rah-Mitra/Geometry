# %% [markdown]
# # Variations of Hodge Structure
#
# ## Variations of Hodge Structure
#
# - [9. Families and Deformations](chapter-09-families-and-deformations/09-families-and-deformations.ipynb)
# - [10. Variations of Hodge Structure](chapter-10-variations-of-hodge-structure/10-variations-of-hodge-structure.ipynb)

# %% [markdown]
# # 0. Introduction
#
# Canonical notebook: [00-introduction.ipynb](00-introduction.ipynb)
#
# Source span: volume 1, printed pages 1-18, PDF pages 13-30.
#
# Artifacts: `artifacts/volume-01/v1-c00`.

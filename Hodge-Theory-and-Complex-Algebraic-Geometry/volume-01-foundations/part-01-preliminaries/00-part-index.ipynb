# %% [markdown]
# # Preliminaries
#
# ## Preliminaries
#
# - [1. Holomorphic Functions of Many Variables](chapter-01-holomorphic-functions-of-many-variables/01-holomorphic-functions-of-many-variables.ipynb)
# - [2. Complex Manifolds](chapter-02-complex-manifolds/02-complex-manifolds.ipynb)
# - [3. Kahler Metrics](chapter-03-kahler-metrics/03-kahler-metrics.ipynb)
# - [4. Sheaves and Cohomology](chapter-04-sheaves-and-cohomology/04-sheaves-and-cohomology.ipynb)

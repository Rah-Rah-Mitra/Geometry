# %% [markdown]
# # 2. Complex Manifolds
#
# Canonical notebook: [02-complex-manifolds.ipynb](02-complex-manifolds.ipynb)
#
# Source span: volume 1, printed pages 38-62, PDF pages 50-74.
#
# Artifacts: `artifacts/volume-01/v1-c02`.

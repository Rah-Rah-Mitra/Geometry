# %% [markdown]
# # 4. Sheaves and Cohomology
#
# Canonical notebook: [04-sheaves-and-cohomology.ipynb](04-sheaves-and-cohomology.ipynb)
#
# Source span: volume 1, printed pages 83-114, PDF pages 95-126.
#
# Artifacts: `artifacts/volume-01/v1-c04`.

# %% [markdown]
# # 1. Holomorphic Functions of Many Variables
#
# Canonical notebook: [01-holomorphic-functions-of-many-variables.ipynb](01-holomorphic-functions-of-many-variables.ipynb)
#
# Source span: volume 1, printed pages 21-37, PDF pages 33-49.
#
# Artifacts: `artifacts/volume-01/v1-c01`.

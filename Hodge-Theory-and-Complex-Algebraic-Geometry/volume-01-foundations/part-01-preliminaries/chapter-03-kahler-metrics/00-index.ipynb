# %% [markdown]
# # 3. Kahler Metrics
#
# Canonical notebook: [03-kahler-metrics.ipynb](03-kahler-metrics.ipynb)
#
# Source span: volume 1, printed pages 63-82, PDF pages 75-94.
#
# Artifacts: `artifacts/volume-01/v1-c03`.

# %% [markdown]
# # 9. Chow Groups
#
# Canonical notebook: [09-chow-groups.ipynb](09-chow-groups.ipynb)
#
# Source span: volume 2, printed pages 245-277, PDF pages 257-289.
#
# Artifacts: `artifacts/volume-02/v2-c09`.

# %% [markdown]
# # 11. The Bloch Conjecture and its Generalisations
#
# Canonical notebook: [11-the-bloch-conjecture-and-its-generalisations.ipynb](11-the-bloch-conjecture-and-its-generalisations.ipynb)
#
# Source span: volume 2, printed pages 307-342, PDF pages 319-354.
#
# Artifacts: `artifacts/volume-02/v2-c11`.

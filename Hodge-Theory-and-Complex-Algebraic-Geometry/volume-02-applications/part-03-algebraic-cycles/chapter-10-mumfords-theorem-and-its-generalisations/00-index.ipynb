# %% [markdown]
# # 10. Mumford's Theorem and its Generalisations
#
# Canonical notebook: [10-mumfords-theorem-and-its-generalisations.ipynb](10-mumfords-theorem-and-its-generalisations.ipynb)
#
# Source span: volume 2, printed pages 278-306, PDF pages 290-318.
#
# Artifacts: `artifacts/volume-02/v2-c10`.

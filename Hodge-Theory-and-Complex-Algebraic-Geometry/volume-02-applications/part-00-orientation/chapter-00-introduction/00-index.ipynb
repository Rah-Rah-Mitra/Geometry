# %% [markdown]
# # 0. Introduction
#
# Canonical notebook: [00-introduction.ipynb](00-introduction.ipynb)
#
# Source span: volume 2, printed pages 1-16, PDF pages 13-28.
#
# Artifacts: `artifacts/volume-02/v2-c00`.

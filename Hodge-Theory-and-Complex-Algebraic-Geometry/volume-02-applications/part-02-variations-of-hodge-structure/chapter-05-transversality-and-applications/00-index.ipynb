# %% [markdown]
# # 5. Transversality and Applications
#
# Canonical notebook: [05-transversality-and-applications.ipynb](05-transversality-and-applications.ipynb)
#
# Source span: volume 2, printed pages 129-155, PDF pages 141-167.
#
# Artifacts: `artifacts/volume-02/v2-c05`.

# %% [markdown]
# # Variations of Hodge Structure
#
# ## Variations of Hodge Structure
#
# - [5. Transversality and Applications](chapter-05-transversality-and-applications/05-transversality-and-applications.ipynb)
# - [6. Hodge Filtration of Hypersurfaces](chapter-06-hodge-filtration-of-hypersurfaces/06-hodge-filtration-of-hypersurfaces.ipynb)
# - [7. Normal Functions and Infinitesimal Invariants](chapter-07-normal-functions-and-infinitesimal-invariants/07-normal-functions-and-infinitesimal-invariants.ipynb)
# - [8. Nori's Work](chapter-08-noris-work/08-noris-work.ipynb)

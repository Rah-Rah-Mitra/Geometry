# %% [markdown]
# # 7. Normal Functions and Infinitesimal Invariants
#
# Canonical notebook: [07-normal-functions-and-infinitesimal-invariants.ipynb](07-normal-functions-and-infinitesimal-invariants.ipynb)
#
# Source span: volume 2, printed pages 188-214, PDF pages 200-226.
#
# Artifacts: `artifacts/volume-02/v2-c07`.

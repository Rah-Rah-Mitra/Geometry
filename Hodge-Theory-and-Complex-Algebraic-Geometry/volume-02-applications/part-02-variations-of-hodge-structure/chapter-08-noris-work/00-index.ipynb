# %% [markdown]
# # 8. Nori's Work
#
# Canonical notebook: [08-noris-work.ipynb](08-noris-work.ipynb)
#
# Source span: volume 2, printed pages 215-242, PDF pages 227-254.
#
# Artifacts: `artifacts/volume-02/v2-c08`.

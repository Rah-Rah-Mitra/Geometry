# %% [markdown]
# # 6. Hodge Filtration of Hypersurfaces
#
# Canonical notebook: [06-hodge-filtration-of-hypersurfaces.ipynb](06-hodge-filtration-of-hypersurfaces.ipynb)
#
# Source span: volume 2, printed pages 156-187, PDF pages 168-199.
#
# Artifacts: `artifacts/volume-02/v2-c06`.

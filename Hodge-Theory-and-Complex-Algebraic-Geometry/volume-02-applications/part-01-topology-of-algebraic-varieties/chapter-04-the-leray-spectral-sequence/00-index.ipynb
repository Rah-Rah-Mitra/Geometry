# %% [markdown]
# # 4. The Leray Spectral Sequence
#
# Canonical notebook: [04-the-leray-spectral-sequence.ipynb](04-the-leray-spectral-sequence.ipynb)
#
# Source span: volume 2, printed pages 98-126, PDF pages 110-138.
#
# Artifacts: `artifacts/volume-02/v2-c04`.

# %% [markdown]
# # The Topology of Algebraic Varieties
#
# ## The Topology of Algebraic Varieties
#
# - [1. The Lefschetz Theorem on Hyperplane Sections](chapter-01-the-lefschetz-theorem-on-hyperplane-sections/01-the-lefschetz-theorem-on-hyperplane-sections.ipynb)
# - [2. Lefschetz Pencils](chapter-02-lefschetz-pencils/02-lefschetz-pencils.ipynb)
# - [3. Monodromy](chapter-03-monodromy/03-monodromy.ipynb)
# - [4. The Leray Spectral Sequence](chapter-04-the-leray-spectral-sequence/04-the-leray-spectral-sequence.ipynb)

# %% [markdown]
# # 2. Lefschetz Pencils
#
# Canonical notebook: [02-lefschetz-pencils.ipynb](02-lefschetz-pencils.ipynb)
#
# Source span: volume 2, printed pages 41-66, PDF pages 53-78.
#
# Artifacts: `artifacts/volume-02/v2-c02`.

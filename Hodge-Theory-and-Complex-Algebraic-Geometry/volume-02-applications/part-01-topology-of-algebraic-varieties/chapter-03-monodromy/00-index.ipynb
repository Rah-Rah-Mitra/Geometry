# %% [markdown]
# # 3. Monodromy
#
# Canonical notebook: [03-monodromy.ipynb](03-monodromy.ipynb)
#
# Source span: volume 2, printed pages 67-97, PDF pages 79-109.
#
# Artifacts: `artifacts/volume-02/v2-c03`.

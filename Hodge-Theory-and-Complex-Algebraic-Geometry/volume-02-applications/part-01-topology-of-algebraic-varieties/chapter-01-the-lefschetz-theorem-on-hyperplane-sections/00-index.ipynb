# %% [markdown]
# # 1. The Lefschetz Theorem on Hyperplane Sections
#
# Canonical notebook: [01-the-lefschetz-theorem-on-hyperplane-sections.ipynb](01-the-lefschetz-theorem-on-hyperplane-sections.ipynb)
#
# Source span: volume 2, printed pages 19-40, PDF pages 31-52.
#
# Artifacts: `artifacts/volume-02/v2-c01`.

# %% [markdown]
# # Part II: Multifingered Manipulation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Contact, grasp maps, force closure, rolling contact, hand dynamics, and tendon actuation.
#
# ## Chapter 05: Multifingered Hand Kinematics
#
# - Chapter index: [chapter-05-multifingered-hand-kinematics/00-index.ipynb](chapter-05-multifingered-hand-kinematics/00-index.ipynb)
# - Canonical notebook: [05-multifingered-hand-kinematics.ipynb](chapter-05-multifingered-hand-kinematics/05-multifingered-hand-kinematics.ipynb)
# - Source span: printed pp. 211-264; PDF pp. 229-282
# - Focus: contacts, grasp maps, force closure, grasp planning, rolling contact
#
# ## Chapter 06: Hand Dynamics and Control
#
# - Chapter index: [chapter-06-hand-dynamics-and-control/00-index.ipynb](chapter-06-hand-dynamics-and-control/00-index.ipynb)
# - Canonical notebook: [06-hand-dynamics-and-control.ipynb](chapter-06-hand-dynamics-and-control/06-hand-dynamics-and-control.ipynb)
# - Source span: printed pp. 265-316; PDF pp. 283-334
# - Focus: Pfaffian constraints, d'Alembert projection, internal forces, tendon actuation, hierarchy

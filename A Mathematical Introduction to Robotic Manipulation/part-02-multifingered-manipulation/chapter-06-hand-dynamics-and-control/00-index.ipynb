# %% [markdown]
# # Chapter 06: Hand Dynamics and Control
#
# [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [06-hand-dynamics-and-control.ipynb](06-hand-dynamics-and-control.ipynb)
# - Source orientation: printed pp. 265-316; PDF pp. 283-334
# - Artifact topic: `artifacts/chapter-06`
# - Focus: Pfaffian constraints, d'Alembert projection, internal forces, tendon actuation, hierarchy
#
# The notebook is written to stand alone: definitions, computations, generated visuals, labs, checks, and takeaways are inside the canonical notebook.

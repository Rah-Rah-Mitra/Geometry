# %% [markdown]
# # Chapter 03: Manipulator Kinematics
#
# [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [03-manipulator-kinematics.ipynb](03-manipulator-kinematics.ipynb)
# - Source orientation: printed pp. 81-154; PDF pp. 99-172
# - Artifact topic: `artifacts/chapter-03`
# - Focus: product of exponentials, inverse kinematics, Jacobians, singularities, manipulability
#
# The notebook is written to stand alone: definitions, computations, generated visuals, labs, checks, and takeaways are inside the canonical notebook.

# %% [markdown]
# # Part I: Foundations and Single-Robot Manipulation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Rigid motion, serial manipulator kinematics, dynamics, and feedback control.
#
# ## Chapter 01: Introduction
#
# - Chapter index: [chapter-01-introduction/00-index.ipynb](chapter-01-introduction/00-index.ipynb)
# - Canonical notebook: [01-introduction.ipynb](chapter-01-introduction/01-introduction.ipynb)
# - Source span: printed pp. 1-18; PDF pp. 19-36
# - Focus: robotics history, manipulation taxonomy, course dependency map, degrees of freedom
#
# ## Chapter 02: Rigid Body Motion
#
# - Chapter index: [chapter-02-rigid-body-motion/00-index.ipynb](chapter-02-rigid-body-motion/00-index.ipynb)
# - Canonical notebook: [02-rigid-body-motion.ipynb](chapter-02-rigid-body-motion/02-rigid-body-motion.ipynb)
# - Source span: printed pp. 19-80; PDF pp. 37-98
# - Focus: SO(3), SE(3), homogeneous transforms, twists, screws, wrenches, reciprocal screws
#
# ## Chapter 03: Manipulator Kinematics
#
# - Chapter index: [chapter-03-manipulator-kinematics/00-index.ipynb](chapter-03-manipulator-kinematics/00-index.ipynb)
# - Canonical notebook: [03-manipulator-kinematics.ipynb](chapter-03-manipulator-kinematics/03-manipulator-kinematics.ipynb)
# - Source span: printed pp. 81-154; PDF pp. 99-172
# - Focus: product of exponentials, inverse kinematics, Jacobians, singularities, manipulability
#
# ## Chapter 04: Robot Dynamics and Control
#
# - Chapter index: [chapter-04-robot-dynamics-and-control/00-index.ipynb](chapter-04-robot-dynamics-and-control/00-index.ipynb)
# - Canonical notebook: [04-robot-dynamics-and-control.ipynb](chapter-04-robot-dynamics-and-control/04-robot-dynamics-and-control.ipynb)
# - Source span: printed pp. 155-210; PDF pp. 173-228
# - Focus: Lagrangian dynamics, open-chain structure, Lyapunov stability, tracking, constrained control

# %% [markdown]
# # Appendix B: A Mathematica Package for Screw Calculus
#
# [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [appendix-b-a-mathematica-package-for-screw-calculus.ipynb](appendix-b-a-mathematica-package-for-screw-calculus.ipynb)
# - Source orientation: printed pp. 435-440; PDF pp. 453-458
# - Artifact topic: `artifacts/appendix-b`
# - Focus: Python screw-calculus equivalents for the historical Mathematica API
#
# The notebook is written to stand alone: definitions, computations, generated visuals, labs, checks, and takeaways are inside the canonical notebook.

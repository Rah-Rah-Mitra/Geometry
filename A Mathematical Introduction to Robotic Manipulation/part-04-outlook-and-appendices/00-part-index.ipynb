# %% [markdown]
# # Part IV: Outlook and Appendices
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Applications outlook, Lie-group foundations, and a Python screw-calculus reference.
#
# ## Chapter 09: Future Prospects
#
# - Chapter index: [chapter-09-future-prospects/00-index.ipynb](chapter-09-future-prospects/00-index.ipynb)
# - Canonical notebook: [09-future-prospects.ipynb](chapter-09-future-prospects/09-future-prospects.ipynb)
# - Source span: printed pp. 395-402; PDF pp. 413-420
# - Focus: hazardous environments, surgery, microrobotics, scale laws, teleoperation latency
#
# ## Appendix A: Lie Groups and Robot Kinematics
#
# - Chapter index: [appendix-a-lie-groups-and-robot-kinematics/00-index.ipynb](appendix-a-lie-groups-and-robot-kinematics/00-index.ipynb)
# - Canonical notebook: [appendix-a-lie-groups-and-robot-kinematics.ipynb](appendix-a-lie-groups-and-robot-kinematics/appendix-a-lie-groups-and-robot-kinematics.ipynb)
# - Source span: printed pp. 403-434; PDF pp. 421-452
# - Focus: manifolds, Lie groups, Lie algebras, SE(3), adjoints, invariant volume
#
# ## Appendix B: A Mathematica Package for Screw Calculus
#
# - Chapter index: [appendix-b-a-mathematica-package-for-screw-calculus/00-index.ipynb](appendix-b-a-mathematica-package-for-screw-calculus/00-index.ipynb)
# - Canonical notebook: [appendix-b-a-mathematica-package-for-screw-calculus.ipynb](appendix-b-a-mathematica-package-for-screw-calculus/appendix-b-a-mathematica-package-for-screw-calculus.ipynb)
# - Source span: printed pp. 435-440; PDF pp. 453-458
# - Focus: Python screw-calculus equivalents for the historical Mathematica API

# %% [markdown]
# # Appendix A: Lie Groups and Robot Kinematics
#
# [Back to Book Index](../../00-book-index.ipynb)
#
# - Canonical notebook: [appendix-a-lie-groups-and-robot-kinematics.ipynb](appendix-a-lie-groups-and-robot-kinematics.ipynb)
# - Source orientation: printed pp. 403-434; PDF pp. 421-452
# - Artifact topic: `artifacts/appendix-a`
# - Focus: manifolds, Lie groups, Lie algebras, SE(3), adjoints, invariant volume
#
# The notebook is written to stand alone: definitions, computations, generated visuals, labs, checks, and takeaways are inside the canonical notebook.

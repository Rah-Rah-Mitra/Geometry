# %% [markdown]
# # Part III: Nonholonomic Systems
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Distributions, Lie brackets, controllability, steering, chained forms, and geometric phase.
#
# ## Chapter 07: Nonholonomic Behavior in Robotic Systems
#
# - Chapter index: [chapter-07-nonholonomic-behavior-in-robotic-systems/00-index.ipynb](chapter-07-nonholonomic-behavior-in-robotic-systems/00-index.ipynb)
# - Canonical notebook: [07-nonholonomic-behavior-in-robotic-systems.ipynb](chapter-07-nonholonomic-behavior-in-robotic-systems/07-nonholonomic-behavior-in-robotic-systems.ipynb)
# - Source span: printed pp. 317-354; PDF pp. 335-372
# - Focus: Pfaffian distributions, Lie brackets, Frobenius theorem, controllability, Hall bases
#
# ## Chapter 08: Nonholonomic Motion Planning
#
# - Chapter index: [chapter-08-nonholonomic-motion-planning/00-index.ipynb](chapter-08-nonholonomic-motion-planning/00-index.ipynb)
# - Canonical notebook: [08-nonholonomic-motion-planning.ipynb](chapter-08-nonholonomic-motion-planning/08-nonholonomic-motion-planning.ipynb)
# - Source span: printed pp. 355-394; PDF pp. 373-412
# - Focus: sinusoidal steering, chained forms, optimal steering, BCH words, dynamic finger repositioning

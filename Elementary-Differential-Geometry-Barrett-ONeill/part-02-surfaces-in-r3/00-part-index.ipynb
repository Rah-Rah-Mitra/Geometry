# %% [markdown]
# # Part II: Surfaces in R3
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Surface calculus, shape operators, curvature, local isometry, and total curvature for embedded surfaces.
#
# ## Chapter 04: Calculus on a Surface
#
# - Chapter index: [chapter-04-calculus-on-a-surface/00-index.ipynb](chapter-04-calculus-on-a-surface/00-index.ipynb)
# - Canonical notebook: [04-calculus-on-a-surface.ipynb](chapter-04-calculus-on-a-surface/04-calculus-on-a-surface.ipynb)
# - Source span: printed pp. 130-201; PDF pp. 145-216
# - Focus: Surface patches, tangent planes, forms, pullbacks, integration, Stokes, topology, and the manifold viewpoint.
#
# ## Chapter 05: Shape Operators
#
# - Chapter index: [chapter-05-shape-operators/00-index.ipynb](chapter-05-shape-operators/00-index.ipynb)
# - Canonical notebook: [05-shape-operators.ipynb](chapter-05-shape-operators/05-shape-operators.ipynb)
# - Source span: printed pp. 202-262; PDF pp. 217-277
# - Focus: The shape operator as normal turning, principal curvatures, Gaussian and mean curvature, special curves, and computational formulas.
#
# ## Chapter 06: Geometry of Surfaces in R3
#
# - Chapter index: [chapter-06-geometry-of-surfaces-in-r3/00-index.ipynb](chapter-06-geometry-of-surfaces-in-r3/00-index.ipynb)
# - Canonical notebook: [06-geometry-of-surfaces-in-r3.ipynb](chapter-06-geometry-of-surfaces-in-r3/06-geometry-of-surfaces-in-r3.ipynb)
# - Source span: printed pp. 263-320; PDF pp. 278-335
# - Focus: Fundamental equations, intrinsic versus extrinsic geometry, local isometry, Theorema Egregium, orientation, total curvature, and congruence.

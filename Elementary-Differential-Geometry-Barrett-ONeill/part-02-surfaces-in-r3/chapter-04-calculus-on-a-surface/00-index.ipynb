# %% [markdown]
# # Chapter 04: Calculus on a Surface
#
# Source orientation: printed pages 130-201; PDF pages 145-216.
#
# Canonical notebook: [04-calculus-on-a-surface.ipynb](04-calculus-on-a-surface.ipynb)
#
# ## Focus
#
# Surface patches, tangent planes, forms, pullbacks, integration, Stokes, topology, and the manifold viewpoint.
#
# ## Sections
#
# - surfaces in R3
# - patch computations
# - surface tangent vectors
# - forms on a surface
# - surface mappings
# - integration
# - topology
# - manifolds
#
# ## Visual Storyboard
#
# - surface and non-surface local model gallery
# - patch partials, tangent plane, and normal field
# - Stokes and winding-number laboratory
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

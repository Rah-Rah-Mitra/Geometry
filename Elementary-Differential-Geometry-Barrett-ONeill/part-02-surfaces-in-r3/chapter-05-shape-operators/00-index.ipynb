# %% [markdown]
# # Chapter 05: Shape Operators
#
# Source orientation: printed pages 202-262; PDF pages 217-277.
#
# Canonical notebook: [05-shape-operators.ipynb](05-shape-operators.ipynb)
#
# ## Focus
#
# The shape operator as normal turning, principal curvatures, Gaussian and mean curvature, special curves, and computational formulas.
#
# ## Sections
#
# - shape operator
# - normal curvature
# - Gaussian curvature
# - computational techniques
# - implicit case
# - special curves
# - surfaces of revolution
#
# ## Visual Storyboard
#
# - normal-turning picture for a patch
# - Euler normal-curvature polar plot
# - surface of revolution and ruled-surface lab
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

# %% [markdown]
# # Chapter 06: Geometry of Surfaces in R3
#
# Source orientation: printed pages 263-320; PDF pages 278-335.
#
# Canonical notebook: [06-geometry-of-surfaces-in-r3.ipynb](06-geometry-of-surfaces-in-r3.ipynb)
#
# ## Focus
#
# Fundamental equations, intrinsic versus extrinsic geometry, local isometry, Theorema Egregium, orientation, total curvature, and congruence.
#
# ## Sections
#
# - fundamental equations
# - form computations
# - global theorems
# - isometries
# - intrinsic geometry
# - orthogonal coordinates
# - orientation
# - total curvature
# - congruence
#
# ## Visual Storyboard
#
# - adapted frames on model surfaces
# - plane-to-cylinder local isometry
# - Gauss-map signed-area and total-curvature balance
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

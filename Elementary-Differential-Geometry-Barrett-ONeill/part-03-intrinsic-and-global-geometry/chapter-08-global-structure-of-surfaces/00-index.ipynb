# %% [markdown]
# # Chapter 08: Global Structure of Surfaces
#
# Source orientation: printed pages 388-450; PDF pages 403-465.
#
# Canonical notebook: [08-global-structure-of-surfaces.ipynb](08-global-structure-of-surfaces.ipynb)
#
# ## Focus
#
# Completeness, minimizing geodesics, conjugate points, covering surfaces, constant-curvature models, Bonnet, Hadamard, and global curvature control.
#
# ## Sections
#
# - length-minimizing geodesics
# - complete surfaces
# - conjugate points
# - covering surfaces
# - inner-product preserving maps
# - constant curvature
# - Bonnet and Hadamard
#
# ## Visual Storyboard
#
# - geodesic polar disks and Jacobi stretching
# - covering-map lift diagram
# - constant-curvature comparison
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

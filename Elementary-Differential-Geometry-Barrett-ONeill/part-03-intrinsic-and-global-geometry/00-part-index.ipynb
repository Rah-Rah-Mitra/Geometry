# %% [markdown]
# # Part III: Intrinsic and Global Geometry
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Riemannian surfaces, geodesics, Gauss-Bonnet, covering surfaces, and global curvature theorems.
#
# ## Chapter 07: Riemannian Geometry
#
# - Chapter index: [chapter-07-riemannian-geometry/00-index.ipynb](chapter-07-riemannian-geometry/00-index.ipynb)
# - Canonical notebook: [07-riemannian-geometry.ipynb](chapter-07-riemannian-geometry/07-riemannian-geometry.ipynb)
# - Source span: printed pp. 321-387; PDF pp. 336-402
# - Focus: Intrinsic metric surfaces, curvature from connection forms, geodesics, Clairaut coordinates, Gauss-Bonnet, and vector-field indices.
#
# ## Chapter 08: Global Structure of Surfaces
#
# - Chapter index: [chapter-08-global-structure-of-surfaces/00-index.ipynb](chapter-08-global-structure-of-surfaces/00-index.ipynb)
# - Canonical notebook: [08-global-structure-of-surfaces.ipynb](chapter-08-global-structure-of-surfaces/08-global-structure-of-surfaces.ipynb)
# - Source span: printed pp. 388-450; PDF pp. 403-465
# - Focus: Completeness, minimizing geodesics, conjugate points, covering surfaces, constant-curvature models, Bonnet, Hadamard, and global curvature control.

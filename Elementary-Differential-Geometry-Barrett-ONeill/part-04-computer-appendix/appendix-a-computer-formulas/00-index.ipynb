# %% [markdown]
# # Appendix A: Computer Formulas in Python
#
# Source orientation: printed pages 451-466; PDF pages 466-481.
#
# Canonical notebook: [appendix-a-computer-formulas.ipynb](appendix-a-computer-formulas.ipynb)
#
# ## Focus
#
# Modern Python, SymPy, NumPy, SciPy, Matplotlib, and Plotly equivalents for the book appendix formulas.
#
# ## Sections
#
# - Python fundamentals
# - curves
# - surfaces
# - plots
# - differential equations
#
# ## Visual Storyboard
#
# - curve formula dashboard
# - surface formula dashboard
# - ODE reconstruction laboratory
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

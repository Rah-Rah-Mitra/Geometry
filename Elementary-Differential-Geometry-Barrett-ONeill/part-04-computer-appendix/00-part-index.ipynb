# %% [markdown]
# # Part IV: Computer Appendix
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Python equivalents of the book appendix formulas for curves, surfaces, plotting, and numerical ODEs.
#
# ## Appendix A: Computer Formulas in Python
#
# - Chapter index: [appendix-a-computer-formulas/00-index.ipynb](appendix-a-computer-formulas/00-index.ipynb)
# - Canonical notebook: [appendix-a-computer-formulas.ipynb](appendix-a-computer-formulas/appendix-a-computer-formulas.ipynb)
# - Source span: printed pp. 451-466; PDF pp. 466-481
# - Focus: Modern Python, SymPy, NumPy, SciPy, Matplotlib, and Plotly equivalents for the book appendix formulas.

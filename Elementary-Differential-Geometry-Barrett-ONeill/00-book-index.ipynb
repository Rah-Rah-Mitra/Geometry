# %% [markdown]
# # Elementary Differential Geometry: Barrett O'Neill
#
# This is a standalone visualization-first notebook course with original prose, executable examples, generated diagrams, interactive artifacts, and sanity checks. The local PDF is used only for source orientation and is not reproduced in the notebooks.
#
# ## Course Map
#
# ## Part 0: Orientation
#
# Course orientation, notation, and the computational viewpoint used throughout the notebooks.
#
# - [Open part index](part-00-orientation/00-part-index.ipynb)
# - [Introduction: How to Use This Visualization Course](part-00-orientation/introduction/00-index.ipynb) - [canonical](part-00-orientation/introduction/00-how-to-use-this-course.ipynb); printed pp. 1-2; PDF pp. 16-17; A compact bridge from the book orientation to this standalone computational course.
#
# ## Part I: Foundations
#
# Euclidean calculus, frame fields, rigid motion, and congruence of curves.
#
# - [Open part index](part-01-foundations/00-part-index.ipynb)
# - [Chapter 01: Calculus on Euclidean Space](part-01-foundations/chapter-01-calculus-on-euclidean-space/00-index.ipynb) - [canonical](part-01-foundations/chapter-01-calculus-on-euclidean-space/01-calculus-on-euclidean-space.ipynb); printed pp. 3-42; PDF pp. 18-57; Coordinate functions, tangent vectors, vector fields, differential forms, curves, and tangent maps in Euclidean space.
# - [Chapter 02: Frame Fields](part-01-foundations/chapter-02-frame-fields/00-index.ipynb) - [canonical](part-01-foundations/chapter-02-frame-fields/02-frame-fields.ipynb); printed pp. 43-99; PDF pp. 58-114; Moving orthonormal frames, Frenet data, covariant derivatives, connection forms, dual forms, and structural equations in R3.
# - [Chapter 03: Euclidean Geometry](part-01-foundations/chapter-03-euclidean-geometry/00-index.ipynb) - [canonical](part-01-foundations/chapter-03-euclidean-geometry/03-euclidean-geometry.ipynb); printed pp. 100-129; PDF pp. 115-144; Rigid motions, orientation, tangent maps of isometries, and congruence certificates for curves.
#
# ## Part II: Surfaces in R3
#
# Surface calculus, shape operators, curvature, local isometry, and total curvature for embedded surfaces.
#
# - [Open part index](part-02-surfaces-in-r3/00-part-index.ipynb)
# - [Chapter 04: Calculus on a Surface](part-02-surfaces-in-r3/chapter-04-calculus-on-a-surface/00-index.ipynb) - [canonical](part-02-surfaces-in-r3/chapter-04-calculus-on-a-surface/04-calculus-on-a-surface.ipynb); printed pp. 130-201; PDF pp. 145-216; Surface patches, tangent planes, forms, pullbacks, integration, Stokes, topology, and the manifold viewpoint.
# - [Chapter 05: Shape Operators](part-02-surfaces-in-r3/chapter-05-shape-operators/00-index.ipynb) - [canonical](part-02-surfaces-in-r3/chapter-05-shape-operators/05-shape-operators.ipynb); printed pp. 202-262; PDF pp. 217-277; The shape operator as normal turning, principal curvatures, Gaussian and mean curvature, special curves, and computational formulas.
# - [Chapter 06: Geometry of Surfaces in R3](part-02-surfaces-in-r3/chapter-06-geometry-of-surfaces-in-r3/00-index.ipynb) - [canonical](part-02-surfaces-in-r3/chapter-06-geometry-of-surfaces-in-r3/06-geometry-of-surfaces-in-r3.ipynb); printed pp. 263-320; PDF pp. 278-335; Fundamental equations, intrinsic versus extrinsic geometry, local isometry, Theorema Egregium, orientation, total curvature, and congruence.
#
# ## Part III: Intrinsic and Global Geometry
#
# Riemannian surfaces, geodesics, Gauss-Bonnet, covering surfaces, and global curvature theorems.
#
# - [Open part index](part-03-intrinsic-and-global-geometry/00-part-index.ipynb)
# - [Chapter 07: Riemannian Geometry](part-03-intrinsic-and-global-geometry/chapter-07-riemannian-geometry/00-index.ipynb) - [canonical](part-03-intrinsic-and-global-geometry/chapter-07-riemannian-geometry/07-riemannian-geometry.ipynb); printed pp. 321-387; PDF pp. 336-402; Intrinsic metric surfaces, curvature from connection forms, geodesics, Clairaut coordinates, Gauss-Bonnet, and vector-field indices.
# - [Chapter 08: Global Structure of Surfaces](part-03-intrinsic-and-global-geometry/chapter-08-global-structure-of-surfaces/00-index.ipynb) - [canonical](part-03-intrinsic-and-global-geometry/chapter-08-global-structure-of-surfaces/08-global-structure-of-surfaces.ipynb); printed pp. 388-450; PDF pp. 403-465; Completeness, minimizing geodesics, conjugate points, covering surfaces, constant-curvature models, Bonnet, Hadamard, and global curvature control.
#
# ## Part IV: Computer Appendix
#
# Python equivalents of the book appendix formulas for curves, surfaces, plotting, and numerical ODEs.
#
# - [Open part index](part-04-computer-appendix/00-part-index.ipynb)
# - [Appendix A: Computer Formulas in Python](part-04-computer-appendix/appendix-a-computer-formulas/00-index.ipynb) - [canonical](part-04-computer-appendix/appendix-a-computer-formulas/appendix-a-computer-formulas.ipynb); printed pp. 451-466; PDF pp. 466-481; Modern Python, SymPy, NumPy, SciPy, Matplotlib, and Plotly equivalents for the book appendix formulas.

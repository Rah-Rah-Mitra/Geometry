# %% [markdown]
# # Chapter 01: Calculus on Euclidean Space
#
# Source orientation: printed pages 3-42; PDF pages 18-57.
#
# Canonical notebook: [01-calculus-on-euclidean-space.ipynb](01-calculus-on-euclidean-space.ipynb)
#
# ## Focus
#
# Coordinate functions, tangent vectors, vector fields, differential forms, curves, and tangent maps in Euclidean space.
#
# ## Sections
#
# - Euclidean space
# - tangent vectors
# - directional derivatives
# - curves in R3
# - forms
# - mappings
# - summary
#
# ## Visual Storyboard
#
# - coordinate grid with tangent vector arrows
# - directional derivative finite-difference probe
# - form and tangent-map dashboard
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

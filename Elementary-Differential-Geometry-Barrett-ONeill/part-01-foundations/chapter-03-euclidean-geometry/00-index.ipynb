# %% [markdown]
# # Chapter 03: Euclidean Geometry
#
# Source orientation: printed pages 100-129; PDF pages 115-144.
#
# Canonical notebook: [03-euclidean-geometry.ipynb](03-euclidean-geometry.ipynb)
#
# ## Focus
#
# Rigid motions, orientation, tangent maps of isometries, and congruence certificates for curves.
#
# ## Sections
#
# - isometries of R3
# - tangent maps
# - orientation
# - Euclidean geometry
# - congruence of curves
#
# ## Visual Storyboard
#
# - tetrahedron moved by F(p)=a+Cp
# - orientation sign dashboard
# - reflected helix curvature and torsion comparison
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

# %% [markdown]
# # Chapter 02: Frame Fields
#
# Source orientation: printed pages 43-99; PDF pages 58-114.
#
# Canonical notebook: [02-frame-fields.ipynb](02-frame-fields.ipynb)
#
# ## Focus
#
# Moving orthonormal frames, Frenet data, covariant derivatives, connection forms, dual forms, and structural equations in R3.
#
# ## Sections
#
# - dot product
# - curves
# - Frenet formulas
# - arbitrary-speed curves
# - covariant derivatives
# - frame fields
# - connection forms
# - structural equations
#
# ## Visual Storyboard
#
# - attitude matrix and oriented frame triads
# - helix with T, N, B vectors
# - connection-form and structural-equation residual table
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

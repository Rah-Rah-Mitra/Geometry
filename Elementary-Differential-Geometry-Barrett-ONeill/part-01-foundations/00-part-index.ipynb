# %% [markdown]
# # Part I: Foundations
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Euclidean calculus, frame fields, rigid motion, and congruence of curves.
#
# ## Chapter 01: Calculus on Euclidean Space
#
# - Chapter index: [chapter-01-calculus-on-euclidean-space/00-index.ipynb](chapter-01-calculus-on-euclidean-space/00-index.ipynb)
# - Canonical notebook: [01-calculus-on-euclidean-space.ipynb](chapter-01-calculus-on-euclidean-space/01-calculus-on-euclidean-space.ipynb)
# - Source span: printed pp. 3-42; PDF pp. 18-57
# - Focus: Coordinate functions, tangent vectors, vector fields, differential forms, curves, and tangent maps in Euclidean space.
#
# ## Chapter 02: Frame Fields
#
# - Chapter index: [chapter-02-frame-fields/00-index.ipynb](chapter-02-frame-fields/00-index.ipynb)
# - Canonical notebook: [02-frame-fields.ipynb](chapter-02-frame-fields/02-frame-fields.ipynb)
# - Source span: printed pp. 43-99; PDF pp. 58-114
# - Focus: Moving orthonormal frames, Frenet data, covariant derivatives, connection forms, dual forms, and structural equations in R3.
#
# ## Chapter 03: Euclidean Geometry
#
# - Chapter index: [chapter-03-euclidean-geometry/00-index.ipynb](chapter-03-euclidean-geometry/00-index.ipynb)
# - Canonical notebook: [03-euclidean-geometry.ipynb](chapter-03-euclidean-geometry/03-euclidean-geometry.ipynb)
# - Source span: printed pp. 100-129; PDF pp. 115-144
# - Focus: Rigid motions, orientation, tangent maps of isometries, and congruence certificates for curves.

# %% [markdown]
# # Part 0: Orientation
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Course orientation, notation, and the computational viewpoint used throughout the notebooks.
#
# ## Introduction: How to Use This Visualization Course
#
# - Chapter index: [introduction/00-index.ipynb](introduction/00-index.ipynb)
# - Canonical notebook: [00-how-to-use-this-course.ipynb](introduction/00-how-to-use-this-course.ipynb)
# - Source span: printed pp. 1-2; PDF pp. 16-17
# - Focus: A compact bridge from the book orientation to this standalone computational course.

# %% [markdown]
# # Introduction: How to Use This Visualization Course
#
# Source orientation: printed pages 1-2; PDF pages 16-17.
#
# Canonical notebook: [00-how-to-use-this-course.ipynb](00-how-to-use-this-course.ipynb)
#
# ## Focus
#
# A compact bridge from the book orientation to this standalone computational course.
#
# ## Sections
#
# - functions and notation
# - sets and maps
# - course route
#
# ## Visual Storyboard
#
# - course dependency map from Euclidean calculus to global surface structure
# - objects-to-computations translation table
# - interactive route through curves, surfaces, forms, and geodesics
#
# ## Checks
#
# - artifact files exist and are nonempty
# - core symbolic identities have zero residual
# - core numerical diagnostics stay inside tolerance

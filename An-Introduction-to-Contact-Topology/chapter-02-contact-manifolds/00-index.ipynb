# %% [markdown]
# # Chapter 2: Contact Manifolds
#
# Source orientation: printed pages 51-92; source pages 69-110.
#
# Canonical notebook: [02-contact-manifolds.ipynb](02-contact-manifolds.ipynb)
#
# Builds the local and deformation toolkit: examples, flows that preserve contact data, Darboux normal form, and neighborhood models.

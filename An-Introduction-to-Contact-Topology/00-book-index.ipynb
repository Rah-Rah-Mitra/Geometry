# %% [markdown]
# # An Introduction to Contact Topology
#
# Standalone visualization-first notebook course.
#
# - [Chapter 1: Facets of Contact Geometry](chapter-01-facets-of-contact-geometry/00-index.ipynb)
# - [Chapter 2: Contact Manifolds](chapter-02-contact-manifolds/00-index.ipynb)
# - [Chapter 3: Knots in Contact 3-Manifolds](chapter-03-knots-in-contact-3-manifolds/00-index.ipynb)
# - [Chapter 4: Contact Structures on 3-Manifolds](chapter-04-contact-structures-on-3-manifolds/00-index.ipynb)
# - [Chapter 5: Symplectic Fillings and Convexity](chapter-05-symplectic-fillings-and-convexity/00-index.ipynb)
# - [Chapter 6: Contact Surgery](chapter-06-contact-surgery/00-index.ipynb)
# - [Chapter 7: Further Constructions of Contact Manifolds](chapter-07-further-constructions-of-contact-manifolds/00-index.ipynb)
# - [Chapter 8: Contact Structures on 5-Manifolds](chapter-08-contact-structures-on-5-manifolds/00-index.ipynb)
# - [Appendix A: The Generalised Poincare Lemma](appendix-a-generalised-poincare-lemma/00-index.ipynb)
# - [Appendix B: Time-Dependent Vector Fields](appendix-b-time-dependent-vector-fields/00-index.ipynb)

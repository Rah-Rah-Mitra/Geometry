# %% [markdown]
# # Chapter 6: Contact Surgery
#
# Source orientation: printed pages 286-331; source pages 304-349.
#
# Canonical notebook: [06-contact-surgery.ipynb](06-contact-surgery.ipynb)
#
# Treats surgery as controlled replacement data: framings, handles, Legendrian coefficients, Dehn slopes, and filling consequences.

# %% [markdown]
# # Chapter 8: Contact Structures on 5-Manifolds
#
# Source orientation: printed pages 366-400; source pages 384-418.
#
# Canonical notebook: [08-contact-structures-on-5-manifolds.ipynb](08-contact-structures-on-5-manifolds.ipynb)
#
# Turns the surgery and obstruction-theory application into computable bookkeeping for almost contact data and simply connected 5-manifold decompositions.

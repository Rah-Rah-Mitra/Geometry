# %% [markdown]
# # Chapter 1: Facets of Contact Geometry
#
# Source orientation: printed pages 1-50; source pages 19-68.
#
# Canonical notebook: [01-facets-of-contact-geometry.ipynb](01-facets-of-contact-geometry.ipynb)
#
# Turns the opening survey into a laboratory for contact planes, Reeb directions, contact elements, and Legendre-style transformations.

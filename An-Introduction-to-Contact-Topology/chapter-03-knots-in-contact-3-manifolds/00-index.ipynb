# %% [markdown]
# # Chapter 3: Knots in Contact 3-Manifolds
#
# Source orientation: printed pages 93-129; source pages 111-147.
#
# Canonical notebook: [03-knots-in-contact-3-manifolds.ipynb](03-knots-in-contact-3-manifolds.ipynb)
#
# Makes Legendrian and transverse knot data visible through fronts, projections, linking, and the classical tb/rotation/self-linking invariants.

# %% [markdown]
# # Appendix B: Time-Dependent Vector Fields
#
# Source orientation: printed pages 404-407; source pages 422-425.
#
# Canonical notebook: [appendix-b-time-dependent-vector-fields.ipynb](appendix-b-time-dependent-vector-fields.ipynb)
#
# Supplies the calculus used by Moser and Gray arguments: evolving flows, pullbacks, and Lie derivative identities.

# %% [markdown]
# # Chapter 5: Symplectic Fillings and Convexity
#
# Source orientation: printed pages 268-285; source pages 286-303.
#
# Canonical notebook: [05-symplectic-fillings-and-convexity.ipynb](05-symplectic-fillings-and-convexity.ipynb)
#
# Connects contact boundaries to symplectic interiors, Liouville collars, cobordism arrows, and Levi positivity.

# %% [markdown]
# # Chapter 7: Further Constructions of Contact Manifolds
#
# Source orientation: printed pages 332-365; source pages 350-383.
#
# Canonical notebook: [07-further-constructions-of-contact-manifolds.ipynb](07-further-constructions-of-contact-manifolds.ipynb)
#
# Compares construction recipes that manufacture contact manifolds from algebraic links, circle bundles, open books, sums, covers, plumbing, and reduction.

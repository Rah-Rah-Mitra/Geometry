# %% [markdown]
# # Chapter 4: Contact Structures on 3-Manifolds
#
# Source orientation: printed pages 130-267; source pages 148-285.
#
# Canonical notebook: [04-contact-structures-on-3-manifolds.ipynb](04-contact-structures-on-3-manifolds.ipynb)
#
# Organizes the large 3-dimensional chapter around visible plane-field moves, surface foliations, dividing sets, overtwisted disks, and classification logic.

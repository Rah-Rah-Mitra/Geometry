# %% [markdown]
# # Appendix A: The Generalised Poincare Lemma
#
# Source orientation: printed pages 401-403; source pages 419-421.
#
# Canonical notebook: [appendix-a-generalised-poincare-lemma.ipynb](appendix-a-generalised-poincare-lemma.ipynb)
#
# Makes the homotopy-operator proof visible as radial contraction plus an exactness check for closed forms.

# %% [markdown]
# # Chapter 2: The Cech-de Rham Complex
#
# Source span: printed pages `89-153`.
#
# Canonical notebook: [`02-the-cech-de-rham-complex.ipynb`](02-the-cech-de-rham-complex.ipynb).
#
# Focus: Good covers, double complexes, Cech cohomology, sphere bundles, Euler classes, and tic-tac-toe arguments.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Forms-in-Algebraic-Topology

# %% [markdown]
# # Chapter 4: Characteristic Classes
#
# Source span: printed pages `266-286`.
#
# Focus: Chern-Weil intuition, Stiefel-Whitney, Chern, Pontrjagin, Euler classes, and classifying examples.
#
# Canonical notebook: [`04-characteristic-classes.ipynb`](04-characteristic-classes.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

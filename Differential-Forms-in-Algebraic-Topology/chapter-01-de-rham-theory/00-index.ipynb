# %% [markdown]
# # Chapter 1: De Rham Theory
#
# Source span: printed pages `13-88`.
#
# Canonical notebook: [`01-de-rham-theory.ipynb`](01-de-rham-theory.ipynb).
#
# Focus: de Rham complexes, Mayer-Vietoris, orientation, integration, Poincare lemmas, Thom class, and duality.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Forms-in-Algebraic-Topology

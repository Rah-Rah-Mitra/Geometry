# %% [markdown]
# # Differential Forms in Algebraic Topology
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | De Rham Theory | 13-88 | [`01-de-rham-theory.ipynb`](chapter-01-de-rham-theory/01-de-rham-theory.ipynb) |
# | Chapter 2 | The Cech-de Rham Complex | 89-153 | [`02-the-cech-de-rham-complex.ipynb`](chapter-02-the-cech-de-rham-complex/02-the-cech-de-rham-complex.ipynb) |
# | Chapter 3 | Spectral Sequences and Applications | 154-265 | [`03-spectral-sequences-and-applications.ipynb`](chapter-03-spectral-sequences-and-applications/03-spectral-sequences-and-applications.ipynb) |
# | Chapter 4 | Characteristic Classes | 266-286 | [`04-characteristic-classes.ipynb`](chapter-04-characteristic-classes/04-characteristic-classes.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Differential Forms in Algebraic Topology: 4 canonical units

# %% [markdown]
# # Chapter 3: Spectral Sequences and Applications
#
# Source span: printed pages `154-265`.
#
# Canonical notebook: [`03-spectral-sequences-and-applications.ipynb`](03-spectral-sequences-and-applications.ipynb).
#
# Focus: Filtered complexes, spectral sequence pages, transgression, Gysin sequences, and cohomological applications.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Differential-Forms-in-Algebraic-Topology

# %% [markdown]
# # Chapter 04: Tools for Complex Manifolds
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [04-tools-for-complex-manifolds.ipynb](04-tools-for-complex-manifolds.ipynb)

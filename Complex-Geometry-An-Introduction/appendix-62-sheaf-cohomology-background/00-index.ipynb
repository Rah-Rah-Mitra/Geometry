# %% [markdown]
# # Appendix 62: Sheaf Cohomology Background
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-62-sheaf-cohomology-background.ipynb](appendix-62-sheaf-cohomology-background.ipynb)

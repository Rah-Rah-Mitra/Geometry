# %% [markdown]
# # Appendix 33: Basic Notions for Hodge Theory
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-33-basic-notions-for-hodge-theory.ipynb](appendix-33-basic-notions-for-hodge-theory.ipynb)

# %% [markdown]
# # Chapter 02: Complex Manifolds and Vector Bundles
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [02-complex-manifolds-and-vector-bundles.ipynb](02-complex-manifolds-and-vector-bundles.ipynb)

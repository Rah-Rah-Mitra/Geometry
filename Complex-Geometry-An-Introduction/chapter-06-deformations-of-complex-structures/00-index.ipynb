# %% [markdown]
# # Chapter 06: Deformations of Complex Structures
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [06-deformations-of-complex-structures.ipynb](06-deformations-of-complex-structures.ipynb)

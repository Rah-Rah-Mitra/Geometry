# %% [markdown]
# # Chapter 01: Local Theory of Holomorphic Functions
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [01-local-theory-of-holomorphic-functions.ipynb](01-local-theory-of-holomorphic-functions.ipynb)

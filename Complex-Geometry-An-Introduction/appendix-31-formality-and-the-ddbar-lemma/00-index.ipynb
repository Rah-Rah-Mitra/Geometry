# %% [markdown]
# # Appendix 31: Formality and the ddbar Lemma
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-31-formality-and-the-ddbar-lemma.ipynb](appendix-31-formality-and-the-ddbar-lemma.ipynb)

# %% [markdown]
# # Appendix 41: Complex and Riemannian Geometry
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-41-complex-and-riemannian-geometry.ipynb](appendix-41-complex-and-riemannian-geometry.ipynb)

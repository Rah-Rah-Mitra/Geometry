# %% [markdown]
# # Appendix 32: Hodge Structures
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-32-hodge-structures.ipynb](appendix-32-hodge-structures.ipynb)

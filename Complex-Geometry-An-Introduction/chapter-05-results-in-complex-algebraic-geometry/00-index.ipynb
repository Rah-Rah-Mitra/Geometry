# %% [markdown]
# # Chapter 05: Results in Complex Algebraic Geometry
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [05-results-in-complex-algebraic-geometry.ipynb](05-results-in-complex-algebraic-geometry.ipynb)

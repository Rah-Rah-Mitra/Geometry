# %% [markdown]
# # Appendix 61: Deformation Background
#
# Source orientation: printed pages verify; source pages verify.
#
# Canonical notebook: [appendix-61-deformation-background.ipynb](appendix-61-deformation-background.ipynb)

# %% [markdown]
# # Discrete and Computational Geometry
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Polygons | 1-37 | [`01-polygons.ipynb`](chapter-01-polygons/01-polygons.ipynb) |
# | Chapter 2 | Convex Hulls | 38-64 | [`02-convex-hulls.ipynb`](chapter-02-convex-hulls/02-convex-hulls.ipynb) |
# | Chapter 3 | Triangulations | 65-106 | [`03-triangulations.ipynb`](chapter-03-triangulations/03-triangulations.ipynb) |
# | Chapter 4 | Voronoi Diagrams | 107-135 | [`04-voronoi-diagrams.ipynb`](chapter-04-voronoi-diagrams/04-voronoi-diagrams.ipynb) |
# | Chapter 5 | Shape Recovery | 136-169 | [`05-shape-recovery.ipynb`](chapter-05-shape-recovery/05-shape-recovery.ipynb) |
# | Chapter 6 | Polygonal Chains | 170-198 | [`06-polygonal-chains.ipynb`](chapter-06-polygonal-chains/06-polygonal-chains.ipynb) |
# | Chapter 7 | Polyhedra | 199-252 | [`07-polyhedra.ipynb`](chapter-07-polyhedra/07-polyhedra.ipynb) |
# | Appendix A | Computational Complexity | 253-258 | [`appendix-a-computational-complexity.ipynb`](appendix-a-computational-complexity/appendix-a-computational-complexity.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Discrete and Computational Geometry: 8 canonical units

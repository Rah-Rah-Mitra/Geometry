# %% [markdown]
# # Chapter 4: Voronoi Diagrams
#
# Source span: printed pages `107-135`.
#
# Focus: Voronoi cells, Delaunay duality, nearest neighbors, and geometric partitions.
#
# Canonical notebook: [`04-voronoi-diagrams.ipynb`](04-voronoi-diagrams.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

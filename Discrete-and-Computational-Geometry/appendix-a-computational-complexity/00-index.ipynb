# %% [markdown]
# # Appendix A: Computational Complexity
#
# Source span: printed pages `253-273`.
#
# Focus: Asymptotic analysis, reductions, algorithm classes, and geometric algorithm complexity.
#
# Canonical notebook: [`appendix-a-computational-complexity.ipynb`](appendix-a-computational-complexity.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

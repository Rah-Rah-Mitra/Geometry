# %% [markdown]
# # Chapter 6: Polygonal Chains
#
# Source span: printed pages `170-198`.
#
# Focus: Linkages, chains, configuration spaces, unfolding, and motion constraints.
#
# Canonical notebook: [`06-polygonal-chains.ipynb`](06-polygonal-chains.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

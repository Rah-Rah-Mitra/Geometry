# %% [markdown]
# # Geometry with an Introduction to Cosmic Topology
#
# This is a standalone visualization-first notebook course. The notebooks use the local PDF only as source orientation for structure and concepts; the teaching prose, diagrams, computations, and artifacts are original.
#
# ## Course Map
#
# - **Chapter 1: An Invitation to Geometry** - [index](chapter-01-an-invitation-to-geometry/00-index.ipynb); [canonical](chapter-01-an-invitation-to-geometry/01-an-invitation-to-geometry.ipynb); printed pp. 1-14; PDF pp. 11-24; Local measurement, global shape, finite boundaryless surfaces, and the first split between Euclidean, hyperbolic, and elliptic behavior.
# - **Chapter 2: The Complex Plane** - [index](chapter-02-the-complex-plane/00-index.ipynb); [canonical](chapter-02-the-complex-plane/02-the-complex-plane.ipynb); printed pp. 15-28; PDF pp. 25-38; Complex numbers as the computational coordinate system for the geometries that follow.
# - **Chapter 3: Transformations** - [index](chapter-03-transformations/00-index.ipynb); [canonical](chapter-03-transformations/03-transformations.ipynb); printed pp. 29-70; PDF pp. 39-80; Inversions, clines, the extended plane, and Mobius transformations as the machinery for non-Euclidean geometry.
# - **Chapter 4: Geometry** - [index](chapter-04-geometry/00-index.ipynb); [canonical](chapter-04-geometry/04-geometry.ipynb); printed pp. 71-80; PDF pp. 81-90; The Erlangen program: a geometry is a space together with a transformation group and its invariants.
# - **Chapter 5: Hyperbolic Geometry** - [index](chapter-05-hyperbolic-geometry/00-index.ipynb); [canonical](chapter-05-hyperbolic-geometry/05-hyperbolic-geometry.ipynb); printed pp. 81-120; PDF pp. 91-130; The Poincare disk and upper half-plane models, hyperbolic geodesics, measurement, area, and triangle defect.
# - **Chapter 6: Elliptic Geometry** - [index](chapter-06-elliptic-geometry/00-index.ipynb); [canonical](chapter-06-elliptic-geometry/06-elliptic-geometry.ipynb); printed pp. 121-144; PDF pp. 131-154; Elliptic geometry from the sphere, stereographic projection, antipodal identification, and projective disk measurement.
# - **Chapter 7: Geometry on Surfaces** - [index](chapter-07-geometry-on-surfaces/00-index.ipynb); [canonical](chapter-07-geometry-on-surfaces/07-geometry-on-surfaces.ipynb); printed pp. 145-194; PDF pp. 155-204; Curvature scales, the unified family (X_k, G_k), surface topology, Gauss-Bonnet, quotient spaces, and Dirichlet domains.
# - **Chapter 8: Cosmic Topology** - [index](chapter-08-cosmic-topology/00-index.ipynb); [canonical](chapter-08-cosmic-topology/08-cosmic-topology.ipynb); printed pp. 195-220; PDF pp. 205-230; Three-dimensional candidate universes, cosmic crystallography, circles in the sky, and density-parameter evidence.
# - **Appendix A: Appendix A: List of Symbols** - [index](appendix-a-list-of-symbols/00-index.ipynb); [canonical](appendix-a-list-of-symbols/appendix-a-list-of-symbols.ipynb); printed pp. 221-222; PDF pp. 231-232; A compact computational glossary for the symbols used across the course.
#
# ## Validation
#
# Run the commands in `AGENTS.md` from the workspace root. Artifacts are generated under `artifacts/` and displayed inline by each canonical notebook.

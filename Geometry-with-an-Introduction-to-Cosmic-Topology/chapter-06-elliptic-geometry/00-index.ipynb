# %% [markdown]
# # Chapter 6: Elliptic Geometry
#
# - Source span: printed pages 121-144; PDF pages 131-154; sections 6.1-6.4.
# - Focus: Elliptic geometry from the sphere, stereographic projection, antipodal identification, and projective disk measurement.
# - Canonical notebook: [06-elliptic-geometry.ipynb](06-elliptic-geometry.ipynb)
# - Back to [book index](../00-book-index.ipynb)

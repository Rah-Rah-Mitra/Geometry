# %% [markdown]
# # Appendix A: Appendix A: List of Symbols
#
# - Source span: printed pages 221-222; PDF pages 231-232; sections Appendix A.
# - Focus: A compact computational glossary for the symbols used across the course.
# - Canonical notebook: [appendix-a-list-of-symbols.ipynb](appendix-a-list-of-symbols.ipynb)
# - Back to [book index](../00-book-index.ipynb)

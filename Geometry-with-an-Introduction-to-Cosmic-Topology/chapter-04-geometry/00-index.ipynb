# %% [markdown]
# # Chapter 4: Geometry
#
# - Source span: printed pages 71-80; PDF pages 81-90; sections 4.1-4.2.
# - Focus: The Erlangen program: a geometry is a space together with a transformation group and its invariants.
# - Canonical notebook: [04-geometry.ipynb](04-geometry.ipynb)
# - Back to [book index](../00-book-index.ipynb)

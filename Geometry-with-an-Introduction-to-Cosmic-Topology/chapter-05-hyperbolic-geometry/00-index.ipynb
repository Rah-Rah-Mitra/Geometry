# %% [markdown]
# # Chapter 5: Hyperbolic Geometry
#
# - Source span: printed pages 81-120; PDF pages 91-130; sections 5.1-5.5.
# - Focus: The Poincare disk and upper half-plane models, hyperbolic geodesics, measurement, area, and triangle defect.
# - Canonical notebook: [05-hyperbolic-geometry.ipynb](05-hyperbolic-geometry.ipynb)
# - Back to [book index](../00-book-index.ipynb)

# %% [markdown]
# # Chapter 8: Cosmic Topology
#
# - Source span: printed pages 195-220; PDF pages 205-230; sections 8.1-8.4.
# - Focus: Three-dimensional candidate universes, cosmic crystallography, circles in the sky, and density-parameter evidence.
# - Canonical notebook: [08-cosmic-topology.ipynb](08-cosmic-topology.ipynb)
# - Back to [book index](../00-book-index.ipynb)

# %% [markdown]
# # Chapter 7: Geometry on Surfaces
#
# - Source span: printed pages 145-194; PDF pages 155-204; sections 7.1-7.7.
# - Focus: Curvature scales, the unified family (X_k, G_k), surface topology, Gauss-Bonnet, quotient spaces, and Dirichlet domains.
# - Canonical notebook: [07-geometry-on-surfaces.ipynb](07-geometry-on-surfaces.ipynb)
# - Back to [book index](../00-book-index.ipynb)

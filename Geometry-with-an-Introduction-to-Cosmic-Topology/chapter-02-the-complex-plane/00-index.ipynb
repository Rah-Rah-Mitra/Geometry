# %% [markdown]
# # Chapter 2: The Complex Plane
#
# - Source span: printed pages 15-28; PDF pages 25-38; sections 2.1-2.4.
# - Focus: Complex numbers as the computational coordinate system for the geometries that follow.
# - Canonical notebook: [02-the-complex-plane.ipynb](02-the-complex-plane.ipynb)
# - Back to [book index](../00-book-index.ipynb)

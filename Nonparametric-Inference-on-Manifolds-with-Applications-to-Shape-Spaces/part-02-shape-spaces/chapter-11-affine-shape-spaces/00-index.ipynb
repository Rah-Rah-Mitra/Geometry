# %% [markdown]
# # 11. Affine shape spaces A Sigma_km

# %% [markdown]
# Canonical notebook: [11-affine-shape-spaces.ipynb](11-affine-shape-spaces.ipynb)
#
# Source span: printed pp. 135-146; physical PDF pp. 150-161.
#
# Focus: Affine normalization, rank conditions, and digit-like landmark examples where similarity information is intentionally discarded.

# %% [markdown]
# Concept route: affine orbit, rank, normalization, classification, landmark covariance.
#
# Library route: numpy, matplotlib, scikit-learn.
#
# Core artifacts: `affine-normalization-grid.png`, `digit-shape-affine-features.png`.

# %% [markdown]
# # 10. Stiefel manifolds V_k,m

# %% [markdown]
# Canonical notebook: [10-stiefel-manifolds.ipynb](10-stiefel-manifolds.ipynb)
#
# Source span: printed pp. 130-134; physical PDF pp. 145-149.
#
# Focus: Orthogonal frames as manifold data, projection onto Stiefel constraints, and extrinsic mean diagnostics.

# %% [markdown]
# Concept route: orthonormal frame, polar projection, tangent residual, extrinsic mean.
#
# Library route: numpy, matplotlib, scipy.
#
# Core artifacts: `stiefel-frame-projection.png`, `orthogonality-residuals.png`.

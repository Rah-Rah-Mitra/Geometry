# %% [markdown]
# # 08. The planar shape space Sigma_k2

# %% [markdown]
# Canonical notebook: [08-planar-shape-space.ipynb](08-planar-shape-space.ipynb)
#
# Source span: printed pp. 87-109; physical PDF pp. 102-124.
#
# Focus: Complex projective planar shape space, intrinsic and extrinsic means, size-and-shape, and two-sample inference.

# %% [markdown]
# Concept route: complex preshape, CP space, Veronese embedding, Procrustes mean, bootstrap.
#
# Library route: geomstats, matplotlib, plotly.
#
# Core artifacts: `planar-shape-sphere.png`, `procrustes-bootstrap.png`.

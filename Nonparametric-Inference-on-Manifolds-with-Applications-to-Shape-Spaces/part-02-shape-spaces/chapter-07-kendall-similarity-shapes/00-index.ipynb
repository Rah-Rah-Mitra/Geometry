# %% [markdown]
# # 07. Kendall similarity shape spaces

# %% [markdown]
# Canonical notebook: [07-kendall-similarity-shapes.ipynb](07-kendall-similarity-shapes.ipynb)
#
# Source span: printed pp. 82-86; physical PDF pp. 97-101.
#
# Focus: Preshape spheres, rotation quotients, horizontal directions, and geodesic distance on similarity shapes.

# %% [markdown]
# Concept route: preshape sphere, rotation quotient, horizontal tangent, Procrustes distance.
#
# Library route: numpy, matplotlib, plotly.
#
# Core artifacts: `preshape-sphere-orbits.png`, `kendall-geodesic.html`.

# %% [markdown]
# # 12. Real projective spaces and projective shape spaces

# %% [markdown]
# Canonical notebook: [12-projective-shape-spaces.ipynb](12-projective-shape-spaces.ipynb)
#
# Source span: printed pp. 147-155; physical PDF pp. 162-170.
#
# Focus: Projective points as lines through the origin, antipodal quotients, and extrinsic analysis on real projective space.

# %% [markdown]
# Concept route: real projective space, antipodal quotient, projective distance, projective shape.
#
# Library route: geomstats, matplotlib, plotly.
#
# Core artifacts: `projective-antipodal-quotient.png`, `projective-distance-field.html`.

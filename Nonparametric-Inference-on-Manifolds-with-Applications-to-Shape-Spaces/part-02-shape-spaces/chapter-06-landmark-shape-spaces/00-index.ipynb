# %% [markdown]
# # 06. Landmark-based shape spaces

# %% [markdown]
# Canonical notebook: [06-landmark-shape-spaces.ipynb](06-landmark-shape-spaces.ipynb)
#
# Source span: printed pp. 77-81; physical PDF pp. 92-96.
#
# Focus: The landmark pipeline from labeled configurations to quotient spaces under increasingly large transformation groups.

# %% [markdown]
# Concept route: k-ads, centering, scale, group orbit, shape manifold.
#
# Library route: matplotlib, numpy.
#
# Core artifacts: `landmark-normalization-pipeline.png`, `group-orbit-comparison.png`.

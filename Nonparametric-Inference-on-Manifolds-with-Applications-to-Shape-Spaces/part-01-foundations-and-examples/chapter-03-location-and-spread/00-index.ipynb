# %% [markdown]
# # 03. Location and spread on metric spaces

# %% [markdown]
# Canonical notebook: [03-location-and-spread.ipynb](03-location-and-spread.ipynb)
#
# Source span: printed pp. 21-35; physical PDF pp. 36-50.
#
# Focus: Frechet functions, metric variation, sample means, and asymptotic behavior before smooth structure is assumed.

# %% [markdown]
# Concept route: Frechet function, metric variation, sample mean set, circle example, bootstrap.
#
# Library route: numpy, scipy, matplotlib.
#
# Core artifacts: `metric-frechet-landscape.png`, `circle-bootstrap-bands.png`.

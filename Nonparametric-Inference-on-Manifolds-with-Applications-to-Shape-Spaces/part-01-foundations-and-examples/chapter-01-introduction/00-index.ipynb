# %% [markdown]
# # 01. Introduction

# %% [markdown]
# Canonical notebook: [01-introduction.ipynb](01-introduction.ipynb)
#
# Source span: printed pp. 1-7; physical PDF pp. 16-22.
#
# Focus: Why landmark data lead to quotient manifolds and why Frechet means are the main statistical object.

# %% [markdown]
# Concept route: landmarks, transformation groups, extrinsic versus intrinsic distance, two-sample mean testing.
#
# Library route: matplotlib, networkx.
#
# Core artifacts: `shape-inference-roadmap.png`, `quotient-ladder.png`.

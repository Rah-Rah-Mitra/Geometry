# %% [markdown]
# # 05. Intrinsic analysis on manifolds

# %% [markdown]
# Canonical notebook: [05-intrinsic-analysis.ipynb](05-intrinsic-analysis.ipynb)
#
# Source span: printed pp. 57-76; physical PDF pp. 72-91.
#
# Focus: Geodesic-distance Frechet means, log-map coordinates, cut-locus caveats, and bootstrap inference on spheres.

# %% [markdown]
# Concept route: geodesic distance, intrinsic mean, log map, cut locus, two-sample tests.
#
# Library route: geomstats, matplotlib, scipy.
#
# Core artifacts: `intrinsic-mean-iteration.png`, `log-map-bootstrap-cloud.png`.

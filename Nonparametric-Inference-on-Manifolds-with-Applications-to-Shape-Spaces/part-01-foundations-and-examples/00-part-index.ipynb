# %% [markdown]
# # Foundations, examples, and Frechet inference

# %% [markdown]
# | Unit | Notebook | Focus |
# | --- | --- | --- |
# | 01 | [Introduction](chapter-01-introduction/01-introduction.ipynb) | Why landmark data lead to quotient manifolds and why Frechet means are the main statistical object. |
# | 02 | [Examples](chapter-02-examples/02-examples.ipynb) | A visual gallery of directional and shape-data examples that will reappear as computational laboratories. |
# | 03 | [Location and spread on metric spaces](chapter-03-location-and-spread/03-location-and-spread.ipynb) | Frechet functions, metric variation, sample means, and asymptotic behavior before smooth structure is assumed. |
# | 04 | [Extrinsic analysis on manifolds](chapter-04-extrinsic-analysis/04-extrinsic-analysis.ipynb) | Embedding a manifold, averaging in the ambient space, and projecting back with tangent covariance diagnostics. |
# | 05 | [Intrinsic analysis on manifolds](chapter-05-intrinsic-analysis/05-intrinsic-analysis.ipynb) | Geodesic-distance Frechet means, log-map coordinates, cut-locus caveats, and bootstrap inference on spheres. |

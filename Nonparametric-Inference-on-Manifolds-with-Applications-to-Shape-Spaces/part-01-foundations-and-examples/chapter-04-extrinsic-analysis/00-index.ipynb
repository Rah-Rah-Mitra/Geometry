# %% [markdown]
# # 04. Extrinsic analysis on manifolds

# %% [markdown]
# Canonical notebook: [04-extrinsic-analysis.ipynb](04-extrinsic-analysis.ipynb)
#
# Source span: printed pp. 36-56; physical PDF pp. 51-71.
#
# Focus: Embedding a manifold, averaging in the ambient space, and projecting back with tangent covariance diagnostics.

# %% [markdown]
# Concept route: embedding, projection, extrinsic mean, extrinsic covariance, equivariance.
#
# Library route: geomstats, matplotlib, numpy.
#
# Core artifacts: `sphere-extrinsic-projection.png`, `extrinsic-covariance-ellipse.png`.

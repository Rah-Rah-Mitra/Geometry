# %% [markdown]
# # 02. Examples

# %% [markdown]
# Canonical notebook: [02-examples.ipynb](02-examples.ipynb)
#
# Source span: printed pp. 8-20; physical PDF pp. 23-35.
#
# Focus: A visual gallery of directional and shape-data examples that will reappear as computational laboratories.

# %% [markdown]
# Concept route: circle data, sphere data, planar shapes, affine shapes, reflection shapes.
#
# Library route: matplotlib, plotly.
#
# Core artifacts: `application-gallery.png`, `sphere-observations.html`.

# %% [markdown]
# # Nonparametric Bayes methods on manifolds

# %% [markdown]
# | Unit | Notebook | Focus |
# | --- | --- | --- |
# | 13 | [Nonparametric Bayes inference on manifolds](chapter-13-bayes-inference/13-bayes-inference.ipynb) | Density estimation, posterior consistency intuition, and manifold mixture computation with spherical and SPD examples. |
# | 14 | [Nonparametric Bayes regression, classification, and testing](chapter-14-bayes-regression-classification-testing/14-bayes-regression-classification-testing.ipynb) | Mixture-of-kernels regression, classification probabilities, and posterior testing as geometry-aware predictive workflows. |

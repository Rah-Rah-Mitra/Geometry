# %% [markdown]
# # 13. Nonparametric Bayes inference on manifolds

# %% [markdown]
# Canonical notebook: [13-bayes-inference.ipynb](13-bayes-inference.ipynb)
#
# Source span: printed pp. 156-181; physical PDF pp. 171-196.
#
# Focus: Density estimation, posterior consistency intuition, and manifold mixture computation with spherical and SPD examples.

# %% [markdown]
# Concept route: metric support, kernel mixture, Dirichlet process, posterior computation, classification.
#
# Library route: pyriemann, matplotlib, scipy, numpy.
#
# Core artifacts: `manifold-density-mixture.png`, `spd-riemannian-mean.png`.

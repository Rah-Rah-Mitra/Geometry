# %% [markdown]
# # 14. Nonparametric Bayes regression, classification, and testing

# %% [markdown]
# Canonical notebook: [14-bayes-regression-classification-testing.ipynb](14-bayes-regression-classification-testing.ipynb)
#
# Source span: printed pp. 182-208; physical PDF pp. 197-223.
#
# Focus: Mixture-of-kernels regression, classification probabilities, and posterior testing as geometry-aware predictive workflows.

# %% [markdown]
# Concept route: product kernels, regression, classification, Bayes testing, posterior predictive checks.
#
# Library route: matplotlib, scipy, numpy.
#
# Core artifacts: `manifold-kernel-classifier.png`, `posterior-test-calibration.png`.

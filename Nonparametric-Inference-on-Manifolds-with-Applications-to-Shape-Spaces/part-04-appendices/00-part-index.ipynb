# %% [markdown]
# # Differentiable, Riemannian, Dirichlet, and parametric background

# %% [markdown]
# | Unit | Notebook | Focus |
# | --- | --- | --- |
# | A | [Differentiable manifolds](appendix-a-differentiable-manifolds/appendix-a-differentiable-manifolds.ipynb) | An executable atlas for charts, tangent vectors, immersions, submersions, and quotient-map intuition. |
# | B | [Riemannian manifolds](appendix-b-riemannian-manifolds/appendix-b-riemannian-manifolds.ipynb) | Metrics, geodesics, exponential and logarithm maps, curvature intuition, and SPD comparison checks. |
# | C | [Dirichlet processes](appendix-c-dirichlet-processes/appendix-c-dirichlet-processes.ipynb) | Stick-breaking, Polya urns, random discrete measures, and why DP mixtures adapt to manifold support. |
# | D | [Parametric models on S_d and Sigma_k2](appendix-d-parametric-models/appendix-d-parametric-models.ipynb) | Parametric sphere and planar-shape models used as baselines for the nonparametric methods. |

# %% [markdown]
# # C. Dirichlet processes

# %% [markdown]
# Canonical notebook: [appendix-c-dirichlet-processes.ipynb](appendix-c-dirichlet-processes.ipynb)
#
# Source span: printed pp. 218-224; physical PDF pp. 233-239.
#
# Focus: Stick-breaking, Polya urns, random discrete measures, and why DP mixtures adapt to manifold support.

# %% [markdown]
# Concept route: stick breaking, Polya urn, base measure, random measure, posterior update.
#
# Library route: numpy, matplotlib, scipy.
#
# Core artifacts: `stick-breaking-measure.png`, `polya-urn-clusters.png`.

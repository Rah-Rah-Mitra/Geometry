# %% [markdown]
# # B. Riemannian manifolds

# %% [markdown]
# Canonical notebook: [appendix-b-riemannian-manifolds.ipynb](appendix-b-riemannian-manifolds.ipynb)
#
# Source span: printed pp. 214-217; physical PDF pp. 229-232.
#
# Focus: Metrics, geodesics, exponential and logarithm maps, curvature intuition, and SPD comparison checks.

# %% [markdown]
# Concept route: metric tensor, geodesic, exponential map, logarithm map, curvature.
#
# Library route: geomstats, pyriemann, matplotlib.
#
# Core artifacts: `riemannian-exp-log-map.png`, `spd-geodesic-comparison.png`.

# %% [markdown]
# # D. Parametric models on S_d and Sigma_k2

# %% [markdown]
# Canonical notebook: [appendix-d-parametric-models.ipynb](appendix-d-parametric-models.ipynb)
#
# Source span: printed pp. 225-228; physical PDF pp. 240-243.
#
# Focus: Parametric sphere and planar-shape models used as baselines for the nonparametric methods.

# %% [markdown]
# Concept route: von Mises-Fisher, axial models, planar shape model, normalizing constant.
#
# Library route: geomstats, matplotlib, scipy.
#
# Core artifacts: `sphere-parametric-family.png`, `shape-space-parametric-baseline.png`.

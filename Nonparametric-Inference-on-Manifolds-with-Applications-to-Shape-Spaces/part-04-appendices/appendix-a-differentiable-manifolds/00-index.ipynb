# %% [markdown]
# # A. Differentiable manifolds

# %% [markdown]
# Canonical notebook: [appendix-a-differentiable-manifolds.ipynb](appendix-a-differentiable-manifolds.ipynb)
#
# Source span: printed pp. 209-213; physical PDF pp. 224-228.
#
# Focus: An executable atlas for charts, tangent vectors, immersions, submersions, and quotient-map intuition.

# %% [markdown]
# Concept route: chart, tangent vector, immersion, submersion, quotient.
#
# Library route: matplotlib, sympy.
#
# Core artifacts: `atlas-transition-map.png`, `tangent-pushforward.png`.

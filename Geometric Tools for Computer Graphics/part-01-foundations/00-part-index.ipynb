# %% [markdown]
# # Part I: Foundations
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Numerical robustness, linear algebra, vector algebra, affine frames, and transformations.
#
# ## Chapter 01: Introduction
#
# - Chapter index: [chapter-01-introduction/00-index.ipynb](chapter-01-introduction/00-index.ipynb)
# - Canonical notebook: [01-introduction.ipynb](chapter-01-introduction/01-introduction.ipynb)
# - Source span: printed pp. 1-8; PDF pp. 48-55
# - Focus: Floating-point failure modes, parameter-domain search, robust predicates, and the shared pattern behind geometric queries.
#
# ## Chapter 02: Matrices and Linear Systems
#
# - Chapter index: [chapter-02-matrices-and-linear-systems/00-index.ipynb](chapter-02-matrices-and-linear-systems/00-index.ipynb)
# - Canonical notebook: [02-matrices-and-linear-systems.ipynb](chapter-02-matrices-and-linear-systems/02-matrices-and-linear-systems.ipynb)
# - Source span: printed pp. 9-62; PDF pp. 56-109
# - Focus: Linear maps, row reduction, rank, determinants, eigenspaces, Euclidean inner products, and least-squares fitting.
#
# ## Chapter 03: Vector Algebra
#
# - Chapter index: [chapter-03-vector-algebra/00-index.ipynb](chapter-03-vector-algebra/00-index.ipynb)
# - Canonical notebook: [03-vector-algebra.ipynb](chapter-03-vector-algebra/03-vector-algebra.ipynb)
# - Source span: printed pp. 63-108; PDF pp. 110-155
# - Focus: Affine and vector-space distinction, frames, orientation, barycentric coordinates, simplexes, and geometric operations.
#
# ## Chapter 04: Matrices, Vector Algebra, and Transformations
#
# - Chapter index: [chapter-04-matrices-vector-algebra-and-transformations/00-index.ipynb](chapter-04-matrices-vector-algebra-and-transformations/00-index.ipynb)
# - Canonical notebook: [04-matrices-vector-algebra-and-transformations.ipynb](chapter-04-matrices-vector-algebra-and-transformations/04-matrices-vector-algebra-and-transformations.ipynb)
# - Source span: printed pp. 109-170; PDF pp. 156-217
# - Focus: Homogeneous point/vector representation, affine transformations, projections, change of basis, and normal-vector transforms.

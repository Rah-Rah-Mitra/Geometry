# %% [markdown]
# # Part III: 3D Geometric Tools
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Spatial primitives, meshes, quadrics, surfaces, 3D distance, 3D intersection, and projection tools.
#
# ## Chapter 09: Geometric Primitives in 3D
#
# - Chapter index: [chapter-09-geometric-primitives-in-3d/00-index.ipynb](chapter-09-geometric-primitives-in-3d/00-index.ipynb)
# - Canonical notebook: [09-geometric-primitives-in-3d.ipynb](chapter-09-geometric-primitives-in-3d/09-geometric-primitives-in-3d.ipynb)
# - Source span: printed pp. 325-364; PDF pp. 372-411
# - Focus: Lines, rays, segments, planes, planar components, meshes, polyhedra, quadrics, torus, curves, and surfaces.
#
# ## Chapter 10: Distance in 3D
#
# - Chapter index: [chapter-10-distance-in-3d/00-index.ipynb](chapter-10-distance-in-3d/00-index.ipynb)
# - Canonical notebook: [10-distance-in-3d.ipynb](chapter-10-distance-in-3d/10-distance-in-3d.ipynb)
# - Source span: printed pp. 365-480; PDF pp. 412-527
# - Focus: Point, line, ray, segment, triangle, rectangle, box, polyhedron, quadric, curve, surface, and geodesic distances.
#
# ## Chapter 11: Intersection in 3D
#
# - Chapter index: [chapter-11-intersection-in-3d/00-index.ipynb](chapter-11-intersection-in-3d/00-index.ipynb)
# - Canonical notebook: [11-intersection-in-3d.ipynb](chapter-11-intersection-in-3d/11-intersection-in-3d.ipynb)
# - Source span: printed pp. 481-662; PDF pp. 528-709
# - Focus: Intersection tests for linear components, planes, triangles, polyhedra, quadrics, polynomial surfaces, bounding boxes, cylinders, and torus.
#
# ## Chapter 12: Miscellaneous 3D Problems
#
# - Chapter index: [chapter-12-miscellaneous-3d-problems/00-index.ipynb](chapter-12-miscellaneous-3d-problems/00-index.ipynb)
# - Canonical notebook: [12-miscellaneous-3d-problems.ipynb](chapter-12-miscellaneous-3d-problems/12-miscellaneous-3d-problems.ipynb)
# - Source span: printed pp. 663-672; PDF pp. 710-719
# - Focus: Projection of points and vectors onto planes, line-plane angles, plane-plane angles, and planes through geometric constraints.

# %% [markdown]
# # Chapter 05: Geometric Primitives in 2D
#
# Source orientation: printed pages 171-188; PDF pages 218-235.
#
# Canonical notebook: [05-geometric-primitives-in-2d.ipynb](05-geometric-primitives-in-2d.ipynb)
#
# ## Focus
#
# Line, ray, segment, triangle, rectangle, polygon, conic, Bezier, B-spline, and NURBS representations.
#
# ## Visual Storyboard
#
# - implicit versus parametric line forms
# - polygon classification gallery
# - conic level sets
# - Bezier and B-spline control polygon comparison
#
# ## Computational Checks
#
# - points sampled from a parametric line satisfy the implicit equation
# - polygon signed area reports orientation
# - Bezier endpoints match the first and last control points
# - curve bounding boxes contain sampled points

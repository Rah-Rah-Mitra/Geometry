# %% [markdown]
# # Chapter 9: Integral Curves and Flows
#
# Source span: printed pages `205-248`.
#
# Focus: Integral curves, flows, flowouts, manifolds with boundary, Lie derivatives, commuting fields, time-dependent fields, and first-order PDEs.
#
# Canonical notebook: [`09-integral-curves-and-flows.ipynb`](09-integral-curves-and-flows.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Appendix B: Review of Linear Algebra
#
# Source span: printed pages `617-641`.
#
# Canonical notebook: [`appendix-b-review-of-linear-algebra.ipynb`](appendix-b-review-of-linear-algebra.ipynb).
#
# Focus: Vector spaces, linear maps, determinant, inner products, norms, products, and direct sums.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

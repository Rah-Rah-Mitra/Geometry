# %% [markdown]
# # Chapter 18: The de Rham Theorem
#
# Source span: printed pages `467-489`.
#
# Canonical notebook: [`18-the-de-rham-theorem.ipynb`](18-the-de-rham-theorem.ipynb).
#
# Focus: Singular homology and cohomology, smooth singular homology, and de Rham theorem.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

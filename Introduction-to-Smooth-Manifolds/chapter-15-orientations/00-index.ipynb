# %% [markdown]
# # Chapter 15: Orientations
#
# Source span: printed pages `377-399`.
#
# Canonical notebook: [`15-orientations.ipynb`](15-orientations.ipynb).
#
# Focus: Orientations of vector spaces and manifolds, Riemannian volume form, and covering maps.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

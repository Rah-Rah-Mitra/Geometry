# %% [markdown]
# # Chapter 16: Integration on Manifolds
#
# Source span: printed pages `400-439`.
#
# Canonical notebook: [`16-integration-on-manifolds.ipynb`](16-integration-on-manifolds.ipynb).
#
# Focus: Volume measurement, integration of forms, Stokes theorem, corners, Riemannian integration, and densities.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

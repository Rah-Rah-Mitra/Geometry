# %% [markdown]
# # Chapter 20: The Exponential Map
#
# Source span: printed pages `515-539`.
#
# Focus: One-parameter subgroups, exponential map, closed subgroup theorem, infinitesimal generators, Lie correspondence, and normal subgroups.
#
# Canonical notebook: [`20-the-exponential-map.ipynb`](20-the-exponential-map.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 3: Tangent Vectors
#
# Source span: printed pages `50-76`.
#
# Canonical notebook: [`03-tangent-vectors.ipynb`](03-tangent-vectors.ipynb).
#
# Focus: Tangent vectors, differentials, coordinates, tangent bundle, curve velocities, and functorial views.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

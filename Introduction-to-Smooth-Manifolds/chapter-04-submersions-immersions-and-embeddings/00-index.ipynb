# %% [markdown]
# # Chapter 4: Submersions, Immersions, and Embeddings
#
# Source span: printed pages `77-97`.
#
# Focus: Constant rank maps, embeddings, submersions, smooth covering maps, and local normal forms.
#
# Canonical notebook: [`04-submersions-immersions-and-embeddings.ipynb`](04-submersions-immersions-and-embeddings.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 14: Differential Forms
#
# Source span: printed pages `349-376`.
#
# Canonical notebook: [`14-differential-forms.ipynb`](14-differential-forms.ipynb).
#
# Focus: Alternating tensors, forms on manifolds, exterior derivatives, and examples.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

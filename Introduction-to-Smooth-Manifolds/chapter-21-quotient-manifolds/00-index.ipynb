# %% [markdown]
# # Chapter 21: Quotient Manifolds
#
# Source span: printed pages `540-563`.
#
# Focus: Group action quotients, covering manifolds, homogeneous spaces, and Lie-theory applications.
#
# Canonical notebook: [`21-quotient-manifolds.ipynb`](21-quotient-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

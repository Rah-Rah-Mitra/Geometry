# %% [markdown]
# # Appendix D: Review of Differential Equations
#
# Source span: printed pages `663-683`.
#
# Focus: ODE existence, uniqueness, flows, and differential equation background for smooth manifolds.
#
# Canonical notebook: [`appendix-d-review-of-differential-equations.ipynb`](appendix-d-review-of-differential-equations.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

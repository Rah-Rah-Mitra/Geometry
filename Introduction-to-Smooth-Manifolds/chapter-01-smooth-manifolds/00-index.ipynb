# %% [markdown]
# # Chapter 1: Smooth Manifolds
#
# Source span: printed pages `1-31`.
#
# Focus: Topological manifolds, smooth structures, examples, and manifolds with boundary.
#
# Canonical notebook: [`01-smooth-manifolds.ipynb`](01-smooth-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

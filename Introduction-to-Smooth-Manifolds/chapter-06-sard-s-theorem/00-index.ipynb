# %% [markdown]
# # Chapter 6: Sard's Theorem
#
# Source span: printed pages `125-149`.
#
# Focus: Measure zero, Sard theorem, Whitney embedding and approximation, and transversality.
#
# Canonical notebook: [`06-sard-s-theorem.ipynb`](06-sard-s-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

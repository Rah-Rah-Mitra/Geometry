# %% [markdown]
# # Chapter 10: Vector Bundles
#
# Source span: printed pages `249-271`.
#
# Focus: Vector bundles, sections, bundle homomorphisms, subbundles, and fiber bundles.
#
# Canonical notebook: [`10-vector-bundles.ipynb`](10-vector-bundles.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

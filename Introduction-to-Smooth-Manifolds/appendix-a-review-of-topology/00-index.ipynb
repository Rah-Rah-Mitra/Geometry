# %% [markdown]
# # Appendix A: Review of Topology
#
# Source span: printed pages `596-616`.
#
# Focus: Topological spaces, subspaces, products, quotients, connectedness, compactness, homotopy, fundamental group, and coverings.
#
# Canonical notebook: [`appendix-a-review-of-topology.ipynb`](appendix-a-review-of-topology.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 22: Symplectic Manifolds
#
# Source span: printed pages `564-595`.
#
# Canonical notebook: [`22-symplectic-manifolds.ipynb`](22-symplectic-manifolds.ipynb).
#
# Focus: Symplectic tensors, symplectic structures, Darboux theorem, Hamiltonian vector fields, contact structures, and nonlinear first-order PDEs.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

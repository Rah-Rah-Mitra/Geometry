# %% [markdown]
# # Appendix C: Review of Calculus
#
# Source span: printed pages `642-662`.
#
# Focus: Multivariable calculus, derivatives, inverse function theorem, and local analytic tools.
#
# Canonical notebook: [`appendix-c-review-of-calculus.ipynb`](appendix-c-review-of-calculus.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

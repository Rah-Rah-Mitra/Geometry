# %% [markdown]
# # Introduction to Smooth Manifolds
#
# Standalone visualization-first notebook course.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Smooth Manifolds | 1-31 | [`01-smooth-manifolds.ipynb`](chapter-01-smooth-manifolds/01-smooth-manifolds.ipynb) |
# | Chapter 2 | Smooth Maps | 32-49 | [`02-smooth-maps.ipynb`](chapter-02-smooth-maps/02-smooth-maps.ipynb) |
# | Chapter 3 | Tangent Vectors | 50-76 | [`03-tangent-vectors.ipynb`](chapter-03-tangent-vectors/03-tangent-vectors.ipynb) |
# | Chapter 4 | Submersions, Immersions, and Embeddings | 77-97 | [`04-submersions-immersions-and-embeddings.ipynb`](chapter-04-submersions-immersions-and-embeddings/04-submersions-immersions-and-embeddings.ipynb) |
# | Chapter 5 | Submanifolds | 98-124 | [`05-submanifolds.ipynb`](chapter-05-submanifolds/05-submanifolds.ipynb) |
# | Chapter 6 | Sard's Theorem | 125-149 | [`06-sard-s-theorem.ipynb`](chapter-06-sard-s-theorem/06-sard-s-theorem.ipynb) |
# | Chapter 7 | Lie Groups | 150-173 | [`07-lie-groups.ipynb`](chapter-07-lie-groups/07-lie-groups.ipynb) |
# | Chapter 8 | Vector Fields | 174-204 | [`08-vector-fields.ipynb`](chapter-08-vector-fields/08-vector-fields.ipynb) |
# | Chapter 9 | Integral Curves and Flows | 205-248 | [`09-integral-curves-and-flows.ipynb`](chapter-09-integral-curves-and-flows/09-integral-curves-and-flows.ipynb) |
# | Chapter 10 | Vector Bundles | 249-271 | [`10-vector-bundles.ipynb`](chapter-10-vector-bundles/10-vector-bundles.ipynb) |
# | Chapter 11 | The Cotangent Bundle | 272-303 | [`11-the-cotangent-bundle.ipynb`](chapter-11-the-cotangent-bundle/11-the-cotangent-bundle.ipynb) |
# | Chapter 12 | Tensors | 304-326 | [`12-tensors.ipynb`](chapter-12-tensors/12-tensors.ipynb) |
# | Chapter 13 | Riemannian Metrics | 327-348 | [`13-riemannian-metrics.ipynb`](chapter-13-riemannian-metrics/13-riemannian-metrics.ipynb) |
# | Chapter 14 | Differential Forms | 349-376 | [`14-differential-forms.ipynb`](chapter-14-differential-forms/14-differential-forms.ipynb) |
# | Chapter 15 | Orientations | 377-399 | [`15-orientations.ipynb`](chapter-15-orientations/15-orientations.ipynb) |
# | Chapter 16 | Integration on Manifolds | 400-439 | [`16-integration-on-manifolds.ipynb`](chapter-16-integration-on-manifolds/16-integration-on-manifolds.ipynb) |
# | Chapter 17 | De Rham Cohomology | 440-466 | [`17-de-rham-cohomology.ipynb`](chapter-17-de-rham-cohomology/17-de-rham-cohomology.ipynb) |
# | Chapter 18 | The de Rham Theorem | 467-489 | [`18-the-de-rham-theorem.ipynb`](chapter-18-the-de-rham-theorem/18-the-de-rham-theorem.ipynb) |
# | Chapter 19 | Distributions and Foliations | 490-514 | [`19-distributions-and-foliations.ipynb`](chapter-19-distributions-and-foliations/19-distributions-and-foliations.ipynb) |
# | Chapter 20 | The Exponential Map | 515-539 | [`20-the-exponential-map.ipynb`](chapter-20-the-exponential-map/20-the-exponential-map.ipynb) |
# | Chapter 21 | Quotient Manifolds | 540-563 | [`21-quotient-manifolds.ipynb`](chapter-21-quotient-manifolds/21-quotient-manifolds.ipynb) |
# | Chapter 22 | Symplectic Manifolds | 564-595 | [`22-symplectic-manifolds.ipynb`](chapter-22-symplectic-manifolds/22-symplectic-manifolds.ipynb) |
# | Appendix A | Review of Topology | 596-616 | [`appendix-a-review-of-topology.ipynb`](appendix-a-review-of-topology/appendix-a-review-of-topology.ipynb) |
# | Appendix B | Review of Linear Algebra | 617-641 | [`appendix-b-review-of-linear-algebra.ipynb`](appendix-b-review-of-linear-algebra/appendix-b-review-of-linear-algebra.ipynb) |
# | Appendix C | Review of Calculus | 642-662 | [`appendix-c-review-of-calculus.ipynb`](appendix-c-review-of-calculus/appendix-c-review-of-calculus.ipynb) |
# | Appendix D | Review of Differential Equations | 663-683 | [`appendix-d-review-of-differential-equations.ipynb`](appendix-d-review-of-differential-equations/appendix-d-review-of-differential-equations.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text(encoding='utf-8'))
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Introduction to Smooth Manifolds: 26 canonical units

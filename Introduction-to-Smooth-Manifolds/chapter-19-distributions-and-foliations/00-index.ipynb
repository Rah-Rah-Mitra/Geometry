# %% [markdown]
# # Chapter 19: Distributions and Foliations
#
# Source span: printed pages `490-514`.
#
# Canonical notebook: [`19-distributions-and-foliations.ipynb`](19-distributions-and-foliations.ipynb).
#
# Focus: Distributions, involutivity, Frobenius theorem, foliations, Lie subgroups, and overdetermined PDEs.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

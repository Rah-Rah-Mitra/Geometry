# %% [markdown]
# # Chapter 13: Riemannian Metrics
#
# Source span: printed pages `327-348`.
#
# Canonical notebook: [`13-riemannian-metrics.ipynb`](13-riemannian-metrics.ipynb).
#
# Focus: Riemannian manifolds, distance function, tangent-cotangent isomorphism, and pseudo-Riemannian metrics.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

# %% [markdown]
# # Chapter 17: De Rham Cohomology
#
# Source span: printed pages `440-466`.
#
# Canonical notebook: [`17-de-rham-cohomology.ipynb`](17-de-rham-cohomology.ipynb).
#
# Focus: de Rham groups, homotopy invariance, Mayer-Vietoris, degree theory, and proof scaffolding.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

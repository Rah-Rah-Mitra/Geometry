# %% [markdown]
# # Chapter 11: The Cotangent Bundle
#
# Source span: printed pages `272-303`.
#
# Focus: Covectors, differential of a function, pullbacks, line integrals, and conservative covector fields.
#
# Canonical notebook: [`11-the-cotangent-bundle.ipynb`](11-the-cotangent-bundle.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

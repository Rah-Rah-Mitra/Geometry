# %% [markdown]
# # Chapter 5: Submanifolds
#
# Source span: printed pages `98-124`.
#
# Canonical notebook: [`05-submanifolds.ipynb`](05-submanifolds.ipynb).
#
# Focus: Embedded and immersed submanifolds, map restriction, tangent spaces, and boundary submanifolds.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Introduction-to-Smooth-Manifolds

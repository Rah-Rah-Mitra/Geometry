# %% [markdown]
# # Chapter 15: Absolute Geometry
#
# Canonical notebook: [15-absolute-geometry.ipynb](15-absolute-geometry.ipynb)
#
# Source orientation: printed pages 263-286, PDF pages 281-304.
#
# Focus: congruence, parallelism, isometry, finite rotation groups, finite isometry groups, geometrical crystallography, polyhedral kaleidoscopes, and discrete groups generated by inversions.
#
# Visual spine: axiom comparison diagrams, finite rotation groups, reflection domains, Coxeter-style mirrors, and inversion-generated orbits.

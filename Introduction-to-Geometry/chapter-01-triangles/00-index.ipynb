# %% [markdown]
# # Chapter 01: Triangles
#
# Canonical notebook: [01-triangles.ipynb](01-triangles.ipynb)
#
# Source orientation: printed pages 3-25, PDF pages 21-43.
#
# Focus: Euclid, primitive concepts, congruence, medians and centroid, incenter, circumcenter, Euler line, nine-point circle, extremum problems, and Morley-style angle trisectors.
#
# Visual spine: triangle centers, Euler line, nine-point circle, cevians, angle bisectors, and inspection of invariants.

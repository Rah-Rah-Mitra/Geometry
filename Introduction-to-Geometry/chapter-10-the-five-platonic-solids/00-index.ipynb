# %% [markdown]
# # Chapter 10: The Five Platonic Solids
#
# Canonical notebook: [10-the-five-platonic-solids.ipynb](10-the-five-platonic-solids.ipynb)
#
# Source orientation: printed pages 148-159, PDF pages 166-177.
#
# Focus: pyramids, prisms, antiprisms, drawings and models, Euler formula, radii and angles, and reciprocal polyhedra.
#
# Visual spine: wireframe solids, vertex-edge-face counts, dual pairs, radius comparisons, and Euler characteristic checks.

# %% [markdown]
# # Chapter 19: Differential Geometry of Surfaces
#
# Canonical notebook: [19-differential-geometry-of-surfaces.ipynb](19-differential-geometry-of-surfaces.ipynb)
#
# Source orientation: printed pages 342-365, PDF pages 360-383.
#
# Focus: two-parameter surface patches, directions on a surface, normal curvature, principal curvatures, principal directions, umbilics, Dupin and Liouville theorems, and Dupin indicatrix.
#
# Visual spine: surface parameter grids, normals, curvature maps, principal direction fields, indicatrices, and umbilic diagnostics.

# %% [markdown]
# # Chapter 08: Coordinates
#
# Canonical notebook: [08-coordinates.ipynb](08-coordinates.ipynb)
#
# Source orientation: printed pages 107-134, PDF pages 125-152.
#
# Focus: Cartesian coordinates, polar coordinates, circles, conics, tangent, arc length, area, hyperbolic functions, equiangular spiral, and three dimensions.
#
# Visual spine: coordinate grids, conic level sets, polar curves, tangent and area approximations, and 3D coordinate frames.

# %% [markdown]
# # Chapter 04: Two-Dimensional Crystallography
#
# Canonical notebook: [04-two-dimensional-crystallography.ipynb](04-two-dimensional-crystallography.ipynb)
#
# Source orientation: printed pages 50-66, PDF pages 68-84.
#
# Focus: lattices, Dirichlet regions, general lattice symmetry, Escher-style motifs, six brick patterns, crystallographic restriction, tessellations, and collinear-point problems.
#
# Visual spine: lattice bases, Dirichlet cells, wallpaper-style motifs, rotation orders, and tiling adjacency.

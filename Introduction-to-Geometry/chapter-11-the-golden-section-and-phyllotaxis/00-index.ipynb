# %% [markdown]
# # Chapter 11: The Golden Section and Phyllotaxis
#
# Canonical notebook: [11-the-golden-section-and-phyllotaxis.ipynb](11-the-golden-section-and-phyllotaxis.ipynb)
#
# Source orientation: printed pages 160-174, PDF pages 178-192.
#
# Focus: extreme and mean ratio, divine proportion, golden spiral, Fibonacci numbers, and phyllotaxis.
#
# Visual spine: golden rectangles, logarithmic spirals, Fibonacci approximants, and sunflower point sets.

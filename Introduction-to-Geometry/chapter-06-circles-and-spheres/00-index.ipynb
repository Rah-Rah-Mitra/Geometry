# %% [markdown]
# # Chapter 06: Circles and Spheres
#
# Canonical notebook: [06-circles-and-spheres.ipynb](06-circles-and-spheres.ipynb)
#
# Source orientation: printed pages 77-95, PDF pages 95-113.
#
# Focus: circle inversion, orthogonal circles, inversions of lines and circles, inverse plane, coaxal circles, Apollonius circles, circle-preserving transformations, sphere inversion, and the elliptic plane.
#
# Visual spine: inversion grids, orthogonal circle pencils, coaxal families, Apollonius loci, and stereographic intuition.

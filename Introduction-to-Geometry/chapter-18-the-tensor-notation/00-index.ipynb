# %% [markdown]
# # Chapter 18: The Tensor Notation
#
# Canonical notebook: [18-the-tensor-notation.ipynb](18-the-tensor-notation.ipynb)
#
# Source orientation: printed pages 328-341, PDF pages 346-359.
#
# Focus: dual bases, fundamental tensor, reciprocal lattices, critical lattice of a sphere, general coordinates, and alternating symbol.
#
# Visual spine: dual basis arrows, metric ellipses, reciprocal lattice cells, coordinate mesh deformation, and determinant orientation checks.

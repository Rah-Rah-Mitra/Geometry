# %% [markdown]
# # Chapter 07: Isometry and Similarity in Euclidean Space
#
# Canonical notebook: [07-isometry-and-similarity-in-euclidean-space.ipynb](07-isometry-and-similarity-in-euclidean-space.ipynb)
#
# Source orientation: printed pages 96-106, PDF pages 114-124.
#
# Focus: direct and opposite spatial isometries, central inversion, rotations and translations, products of reflections, twists, dilative rotations, and sphere-preserving transformations.
#
# Visual spine: 3D frames, screw motions, reflection planes, twist traces, and projected spatial orbits.

# %% [markdown]
# # Chapter 09: Complex Numbers
#
# Canonical notebook: [09-complex-numbers.ipynb](09-complex-numbers.ipynb)
#
# Source orientation: printed pages 135-147, PDF pages 153-165.
#
# Focus: rational and real numbers, Argand diagrams, modulus and amplitude, Euler formula, roots of equations, and conformal transformations.
#
# Visual spine: complex multiplication, roots of unity, phase-amplitude diagrams, and simple conformal maps.

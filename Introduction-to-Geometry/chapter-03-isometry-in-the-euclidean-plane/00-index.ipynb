# %% [markdown]
# # Chapter 03: Isometry in the Euclidean Plane
#
# Canonical notebook: [03-isometry-in-the-euclidean-plane.ipynb](03-isometry-in-the-euclidean-plane.ipynb)
#
# Source orientation: printed pages 39-49, PDF pages 57-67.
#
# Focus: direct and opposite isometries, translations, glide reflections, half-turns, reflection products, and strip patterns.
#
# Visual spine: motion trails for translations, rotations, reflections, glide reflections, and products of mirror lines.

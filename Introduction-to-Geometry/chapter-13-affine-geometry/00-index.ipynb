# %% [markdown]
# # Chapter 13: Affine Geometry
#
# Canonical notebook: [13-affine-geometry.ipynb](13-affine-geometry.ipynb)
#
# Source orientation: printed pages 191-228, PDF pages 209-246.
#
# Focus: parallelism, Desargues axiom, dilatations, affinities, equiaffinities, lattices, vectors and centroids, barycentric coordinates, affine space, and three-dimensional lattices.
#
# Visual spine: affine grids, barycentric coordinates, centroid preservation, lattice deformation, and area-scale checks.

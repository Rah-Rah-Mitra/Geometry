# %% [markdown]
# # Chapter 14: Projective Geometry
#
# Canonical notebook: [14-projective-geometry.ipynb](14-projective-geometry.ipynb)
#
# Source orientation: printed pages 229-262, PDF pages 247-280.
#
# Focus: projective-plane axioms, projective coordinates, Desargues theorem, quadrangular and harmonic sets, projectivities, collineations, correlations, conics, projective space, and Euclidean space.
#
# Visual spine: perspective projection, points at infinity, cross-ratio experiments, Desargues configurations, and conic projectivities.

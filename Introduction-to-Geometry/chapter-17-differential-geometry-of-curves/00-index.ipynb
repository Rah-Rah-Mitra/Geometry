# %% [markdown]
# # Chapter 17: Differential Geometry of Curves
#
# Canonical notebook: [17-differential-geometry-of-curves.ipynb](17-differential-geometry-of-curves.ipynb)
#
# Source orientation: printed pages 307-327, PDF pages 325-345.
#
# Focus: vectors in Euclidean space, vector functions, curvature, evolutes, involutes, catenary, tractrix, twisted curves, circular helix, general helix, and concho-spiral.
#
# Visual spine: parametric curves, velocity and curvature vectors, Frenet frames, evolute traces, helices, and curvature profiles.

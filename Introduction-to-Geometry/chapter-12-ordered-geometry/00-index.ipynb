# %% [markdown]
# # Chapter 12: Ordered Geometry
#
# Canonical notebook: [12-ordered-geometry.ipynb](12-ordered-geometry.ipynb)
#
# Source orientation: printed pages 175-190, PDF pages 193-208.
#
# Focus: extracting geometries from Euclid, intermediacy, collinear point problems, planes and hyperplanes, continuity, and parallelism.
#
# Visual spine: betweenness, separation by lines and planes, convex hulls, order-preserving maps, and parallel axiom experiments.

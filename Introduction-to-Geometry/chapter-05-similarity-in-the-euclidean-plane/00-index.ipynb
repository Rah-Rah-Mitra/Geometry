# %% [markdown]
# # Chapter 05: Similarity in the Euclidean Plane
#
# Canonical notebook: [05-similarity-in-the-euclidean-plane.ipynb](05-similarity-in-the-euclidean-plane.ipynb)
#
# Source orientation: printed pages 67-76, PDF pages 85-94.
#
# Focus: dilation, centers of similitude, nine-point center, invariant point of a similarity, direct similarity, and opposite similarity.
#
# Visual spine: scale maps, spiral similarities, fixed points, homothety centers, and nested images.

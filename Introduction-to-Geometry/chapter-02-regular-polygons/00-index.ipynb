# %% [markdown]
# # Chapter 02: Regular Polygons
#
# Canonical notebook: [02-regular-polygons.ipynb](02-regular-polygons.ipynb)
#
# Source orientation: printed pages 26-38, PDF pages 44-56.
#
# Focus: cyclotomy, angle trisection, isometry, symmetry groups, products of reflections, kaleidoscopes, and star polygons.
#
# Visual spine: regular n-gons, star polygons, reflection axes, rotation orbits, and group composition tables.

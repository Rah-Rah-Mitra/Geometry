# %% [markdown]
# # Chapter 20: Geodesics
#
# Canonical notebook: [20-geodesics.ipynb](20-geodesics.ipynb)
#
# Source orientation: printed pages 366-378, PDF pages 384-396.
#
# Focus: theorema egregium, differential equations for geodesics, integral curvature of geodesic triangles, Euler-Poincare characteristic, constant-curvature surfaces, angle of parallelism, and pseudosphere.
#
# Visual spine: geodesic traces, triangle curvature budget, constant-curvature comparisons, pseudosphere meridians, and numerical path checks.

# %% [markdown]
# # Chapter 16: Hyperbolic Geometry
#
# Canonical notebook: [16-hyperbolic-geometry.ipynb](16-hyperbolic-geometry.ipynb)
#
# Source orientation: printed pages 287-306, PDF pages 305-324.
#
# Focus: Euclidean and hyperbolic parallel axioms, consistency, angle of parallelism, finiteness of triangles, area defect, equidistant curves, Poincare half-plane model, horospheres, and Euclidean interpretation.
#
# Visual spine: Poincare disk and half-plane geodesics, angle defect, horocycles, equidistant curves, and model-to-model maps.

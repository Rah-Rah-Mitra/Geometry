# %% [markdown]
# # Part III: Appendices
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Technical smoothness tools and a historical concept map used as navigation aids.
#
# ## Appendix A: Some Technicalities
#
# - Chapter index: [appendix-a-some-technicalities/00-index.ipynb](appendix-a-some-technicalities/00-index.ipynb)
# - Canonical notebook: [appendix-a-some-technicalities.ipynb](appendix-a-some-technicalities/appendix-a-some-technicalities.ipynb)
# - Source span: printed pp. 193-196; PDF pp. 194-197
# - Focus: Smooth maps on closed domains, support, bump functions, and smooth cutoffs.
#
# ## Appendix B: Timeline
#
# - Chapter index: [appendix-b-timeline/00-index.ipynb](appendix-b-timeline/00-index.ipynb)
# - Canonical notebook: [appendix-b-timeline.ipynb](appendix-b-timeline/appendix-b-timeline.ipynb)
# - Source span: printed pp. 197-198; PDF pp. 198-199
# - Focus: A navigable timeline connecting elastic curves, surface theory, topology, variational calculus, and Willmore surfaces.

# %% [markdown]
# # Part I: Curves
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Parametrized curves, arclength, variation, elastic curves, normal transport, torsion, and filament flow.
#
# ## Chapter 01: Curves in Rn
#
# - Chapter index: [chapter-01-curves-in-rn/00-index.ipynb](chapter-01-curves-in-rn/00-index.ipynb)
# - Canonical notebook: [01-curves-in-rn.ipynb](chapter-01-curves-in-rn/01-curves-in-rn.ipynb)
# - Source span: printed pp. 3-11; PDF pp. 13-21
# - Focus: Regular parametrized curves, reparametrization, length, arclength, unit tangent, and bending energy.
#
# ## Chapter 02: Variations of Curves
#
# - Chapter index: [chapter-02-variations-of-curves/00-index.ipynb](chapter-02-variations-of-curves/00-index.ipynb)
# - Canonical notebook: [02-variations-of-curves.ipynb](chapter-02-variations-of-curves/02-variations-of-curves.ipynb)
# - Source span: printed pp. 13-27; PDF pp. 22-37
# - Focus: One-parameter curve families, variational vector fields, first variation, constrained criticality, and elastica.
#
# ## Chapter 03: Curves in R2
#
# - Chapter index: [chapter-03-curves-in-r2/00-index.ipynb](chapter-03-curves-in-r2/00-index.ipynb)
# - Canonical notebook: [03-curves-in-r2.ipynb](chapter-03-curves-in-r2/03-curves-in-r2.ipynb)
# - Source span: printed pp. 29-45; PDF pp. 38-55
# - Focus: Signed curvature, sector area, planar elastica, tangent winding, and regular homotopy.
#
# ## Chapter 04: Parallel Normal Fields
#
# - Chapter index: [chapter-04-parallel-normal-fields/00-index.ipynb](chapter-04-parallel-normal-fields/00-index.ipynb)
# - Canonical notebook: [04-parallel-normal-fields.ipynb](chapter-04-parallel-normal-fields/04-parallel-normal-fields.ipynb)
# - Source span: printed pp. 47-57; PDF pp. 56-66
# - Focus: Parallel normal transport, curvature functions, and reconstruction of curves from normal-plane data.
#
# ## Chapter 05: Curves in R3
#
# - Chapter index: [chapter-05-curves-in-r3/00-index.ipynb](chapter-05-curves-in-r3/00-index.ipynb)
# - Canonical notebook: [05-curves-in-r3.ipynb](chapter-05-curves-in-r3/05-curves-in-r3.ipynb)
# - Source span: printed pp. 59-85; PDF pp. 67-92
# - Focus: Total torsion, elastic space curves, vortex filament flow, framed curves, twist energy, and Frenet-normal limitations.

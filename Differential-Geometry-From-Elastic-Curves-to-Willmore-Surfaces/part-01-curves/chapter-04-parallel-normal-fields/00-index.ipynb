# %% [markdown]
# # Chapter 04: Parallel Normal Fields
#
# Source orientation: printed pages 47-57; PDF pages 56-66.
#
# Canonical notebook: [04-parallel-normal-fields.ipynb](04-parallel-normal-fields.ipynb)
#
# ## Focus
#
# Parallel normal transport, curvature functions, and reconstruction of curves from normal-plane data.
#
# ## Visual Storyboard
#
# - transported normal frames on a helix
# - Gram determinant and orthogonality traces
# - normal-plane curvature trace
# - reconstruction dictionary for curvature data
#
# ## Checks
#
# - frame remains orthonormal
# - transported normal is perpendicular to tangent
# - determinant stays positive
# - rigid alignment residual is small

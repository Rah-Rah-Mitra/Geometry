# %% [markdown]
# # Chapter 02: Variations of Curves
#
# Source orientation: printed pages 13-27; PDF pages 22-37.
#
# Canonical notebook: [02-variations-of-curves.ipynb](02-variations-of-curves.ipynb)
#
# ## Focus
#
# One-parameter curve families, variational vector fields, first variation, constrained criticality, and elastica.
#
# ## Visual Storyboard
#
# - ribbon of nearby curves
# - speed variation residual
# - commutator panel for d/dt and d/ds
# - pendulum tangent path and integrated elastica
#
# ## Checks
#
# - mixed partials commute for smooth tests
# - finite differences match variation integrals
# - boundary terms vanish for bump support
# - elastic ODE residual stays small

# %% [markdown]
# # Chapter 06: Surfaces and Riemannian Geometry
#
# Source orientation: printed pages 87-103; PDF pages 94-110.
#
# Canonical notebook: [06-surfaces-and-riemannian-geometry.ipynb](06-surfaces-and-riemannian-geometry.ipynb)
#
# ## Focus
#
# Parametrized surfaces, tangent spaces, induced metrics, area forms, metric rotation, and isometry.
#
# ## Visual Storyboard
#
# - pushforward grid and tangent arrows
# - metric ellipses across a patch
# - area/J parallelogram
# - isometry lab for flat/developable examples
#
# ## Checks
#
# - metric matrices are positive definite
# - area equals sqrt(EG-F^2)
# - J squared is minus identity
# - matched examples preserve metric coefficients

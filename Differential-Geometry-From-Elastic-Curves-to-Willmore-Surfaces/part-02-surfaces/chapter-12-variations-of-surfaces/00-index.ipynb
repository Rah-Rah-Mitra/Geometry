# %% [markdown]
# # Chapter 12: Variations of Surfaces
#
# Source orientation: printed pages 161-179; PDF pages 164-182.
#
# Canonical notebook: [12-variations-of-surfaces.ipynb](12-variations-of-surfaces.ipynb)
#
# ## Focus
#
# Surface vector calculus, one-parameter surface families, curvature variation, area variation, volume variation, minimal and CMC surfaces.
#
# ## Visual Storyboard
#
# - surface vector-calculus dashboard
# - variation decomposition panel
# - first area variation plot
# - cone volume and CMC comparison
#
# ## Checks
#
# - divergence theorem residual is small
# - normal bump finite difference matches area variation
# - minimal examples have small H
# - sphere has constant H for volume constraint

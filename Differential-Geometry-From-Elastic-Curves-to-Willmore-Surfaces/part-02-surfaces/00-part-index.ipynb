# %% [markdown]
# # Part II: Surfaces
#
# [Back to Book Index](../00-book-index.ipynb)
#
# Parametrized surfaces, forms and integration, curvature, connections, global curvature, closed surfaces, variations, and Willmore energy.
#
# ## Chapter 06: Surfaces and Riemannian Geometry
#
# - Chapter index: [chapter-06-surfaces-and-riemannian-geometry/00-index.ipynb](chapter-06-surfaces-and-riemannian-geometry/00-index.ipynb)
# - Canonical notebook: [06-surfaces-and-riemannian-geometry.ipynb](chapter-06-surfaces-and-riemannian-geometry/06-surfaces-and-riemannian-geometry.ipynb)
# - Source span: printed pp. 87-103; PDF pp. 94-110
# - Focus: Parametrized surfaces, tangent spaces, induced metrics, area forms, metric rotation, and isometry.
#
# ## Chapter 07: Integration and Stokes' Theorem
#
# - Chapter index: [chapter-07-integration-and-stokes-theorem/00-index.ipynb](chapter-07-integration-and-stokes-theorem/00-index.ipynb)
# - Canonical notebook: [07-integration-and-stokes-theorem.ipynb](chapter-07-integration-and-stokes-theorem/07-integration-and-stokes-theorem.ipynb)
# - Source span: printed pp. 105-115; PDF pp. 111-121
# - Focus: Integration on surfaces and curves, one-forms, two-forms, pullback, boundary orientation, and Stokes' theorem.
#
# ## Chapter 08: Curvature
#
# - Chapter index: [chapter-08-curvature/00-index.ipynb](chapter-08-curvature/00-index.ipynb)
# - Canonical notebook: [08-curvature.ipynb](chapter-08-curvature/08-curvature.ipynb)
# - Source span: printed pp. 117-129; PDF pp. 122-134
# - Focus: Unit normal, shape operator, principal curvature, mean curvature, Gaussian curvature, umbilics, and Gauss-map area.
#
# ## Chapter 09: Levi-Civita Connection
#
# - Chapter index: [chapter-09-levi-civita-connection/00-index.ipynb](chapter-09-levi-civita-connection/00-index.ipynb)
# - Canonical notebook: [09-levi-civita-connection.ipynb](chapter-09-levi-civita-connection/09-levi-civita-connection.ipynb)
# - Source span: printed pp. 131-137; PDF pp. 135-142
# - Focus: Tangential differentiation, Levi-Civita connection, Gauss and Codazzi equations, and Theorema Egregium.
#
# ## Chapter 10: Total Gaussian Curvature
#
# - Chapter index: [chapter-10-total-gaussian-curvature/00-index.ipynb](chapter-10-total-gaussian-curvature/00-index.ipynb)
# - Canonical notebook: [10-total-gaussian-curvature.ipynb](chapter-10-total-gaussian-curvature/10-total-gaussian-curvature.ipynb)
# - Source span: printed pp. 139-149; PDF pp. 143-153
# - Focus: Curves on surfaces, total Gaussian curvature, Gauss-Bonnet, and parallel transport holonomy.
#
# ## Chapter 11: Closed Surfaces
#
# - Chapter index: [chapter-11-closed-surfaces/00-index.ipynb](chapter-11-closed-surfaces/00-index.ipynb)
# - Canonical notebook: [11-closed-surfaces.ipynb](chapter-11-closed-surfaces/11-closed-surfaces.ipynb)
# - Source span: printed pp. 151-160; PDF pp. 154-163
# - Focus: Boundary gluing, oriented and non-oriented closed surfaces, orientation covers, genus, and total curvature.
#
# ## Chapter 12: Variations of Surfaces
#
# - Chapter index: [chapter-12-variations-of-surfaces/00-index.ipynb](chapter-12-variations-of-surfaces/00-index.ipynb)
# - Canonical notebook: [12-variations-of-surfaces.ipynb](chapter-12-variations-of-surfaces/12-variations-of-surfaces.ipynb)
# - Source span: printed pp. 161-179; PDF pp. 164-182
# - Focus: Surface vector calculus, one-parameter surface families, curvature variation, area variation, volume variation, minimal and CMC surfaces.
#
# ## Chapter 13: Willmore Surfaces
#
# - Chapter index: [chapter-13-willmore-surfaces/00-index.ipynb](chapter-13-willmore-surfaces/00-index.ipynb)
# - Canonical notebook: [13-willmore-surfaces.ipynb](chapter-13-willmore-surfaces/13-willmore-surfaces.ipynb)
# - Source span: printed pp. 181-191; PDF pp. 183-193
# - Focus: Willmore functional, Willmore equation, energy offsets, cylinder examples, and inversion invariance.

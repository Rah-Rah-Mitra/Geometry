# %% [markdown]
# # Chapter 10: Total Gaussian Curvature
#
# Source orientation: printed pages 139-149; PDF pages 143-153.
#
# Canonical notebook: [10-total-gaussian-curvature.ipynb](10-total-gaussian-curvature.ipynb)
#
# ## Focus
#
# Curves on surfaces, total Gaussian curvature, Gauss-Bonnet, and parallel transport holonomy.
#
# ## Visual Storyboard
#
# - curve classifiers on a surface
# - Gauss-Bonnet accounting bars
# - parallel transport ODE loop
# - holonomy-curvature comparison
#
# ## Checks
#
# - test frames remain orthonormal
# - hemisphere integral approaches 2*pi
# - annulus boundary terms cancel in flat case
# - transport preserves tangent vector length

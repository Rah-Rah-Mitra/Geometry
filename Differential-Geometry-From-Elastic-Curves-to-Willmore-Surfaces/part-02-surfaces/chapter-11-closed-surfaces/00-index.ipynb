# %% [markdown]
# # Chapter 11: Closed Surfaces
#
# Source orientation: printed pages 151-160; PDF pages 154-163.
#
# Canonical notebook: [11-closed-surfaces.ipynb](11-closed-surfaces.ipynb)
#
# ## Focus
#
# Boundary gluing, oriented and non-oriented closed surfaces, orientation covers, genus, and total curvature.
#
# ## Visual Storyboard
#
# - boundary pairing graph
# - torus and Klein gluing contrast
# - orientation-cover diagram
# - genus calculator panel
#
# ## Checks
#
# - pairing map is an involution
# - orientation signs match the selected model
# - genus formula matches examples
# - Euler characteristic predicts total curvature target

# %% [markdown]
# # Chapter 08: Curvature
#
# Source orientation: printed pages 117-129; PDF pages 122-134.
#
# Canonical notebook: [08-curvature.ipynb](08-curvature.ipynb)
#
# ## Focus
#
# Unit normal, shape operator, principal curvature, mean curvature, Gaussian curvature, umbilics, and Gauss-map area.
#
# ## Visual Storyboard
#
# - normal orientation on a surface patch
# - shape-operator gallery
# - directional curvature polar plot
# - Gauss-map area panel
#
# ## Checks
#
# - normal is unit and perpendicular to partials
# - shape operator is self-adjoint for the metric
# - H and K match trace and determinant
# - sphere has constant positive curvature

# %% [markdown]
# # Appendix B: Review of Tensors
#
# Source span: printed pages `391-406`.
#
# Focus: Tensors, tensor bundles, differential forms, integration, and densities.
#
# Canonical notebook: [`appendix-b-review-of-tensors.ipynb`](appendix-b-review-of-tensors.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

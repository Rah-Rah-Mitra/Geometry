# %% [markdown]
# # Chapter 1: What Is Curvature
#
# Source span: printed pages `1-8`.
#
# Focus: Informal curvature motivation, classification theorems, local-to-global theorems, surfaces, and higher-dimensional curvature intuition.
#
# Canonical notebook: [`01-what-is-curvature.ipynb`](01-what-is-curvature.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 6: Geodesics and Distance
#
# Source span: printed pages `151-192`.
#
# Focus: Minimizing curves, normal neighborhoods, completeness, distance functions, and semigeodesic coordinates.
#
# Canonical notebook: [`06-geodesics-and-distance.ipynb`](06-geodesics-and-distance.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

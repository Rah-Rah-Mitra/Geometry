# %% [markdown]
# # Appendix C: Review of Lie Groups
#
# Source span: printed pages `407-427`.
#
# Focus: Definitions, Lie algebras, and group actions on manifolds.
#
# Canonical notebook: [`appendix-c-review-of-lie-groups.ipynb`](appendix-c-review-of-lie-groups.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

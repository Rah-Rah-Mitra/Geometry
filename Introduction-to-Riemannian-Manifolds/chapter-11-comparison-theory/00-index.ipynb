# %% [markdown]
# # Chapter 11: Comparison Theory
#
# Source span: printed pages `319-344`.
#
# Focus: Jacobi fields, Hessians, Riccati equations, sectional and Ricci curvature comparisons, and volume and diameter bounds.
#
# Canonical notebook: [`11-comparison-theory.ipynb`](11-comparison-theory.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

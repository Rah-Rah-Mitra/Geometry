# %% [markdown]
# # Chapter 4: Connections
#
# Source span: printed pages `85-114`.
#
# Focus: Differentiating vector fields, vector bundle connections, covariant derivatives, geodesics, parallel transport, and pullback connections.
#
# Canonical notebook: [`04-connections.ipynb`](04-connections.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

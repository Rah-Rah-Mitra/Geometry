# %% [markdown]
# # Appendix A: Review of Smooth Manifolds
#
# Source span: printed pages `371-390`.
#
# Focus: Topological preliminaries, smooth maps, tangent vectors, submanifolds, vector bundles, vector fields, and covering maps.
#
# Canonical notebook: [`appendix-a-review-of-smooth-manifolds.ipynb`](appendix-a-review-of-smooth-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

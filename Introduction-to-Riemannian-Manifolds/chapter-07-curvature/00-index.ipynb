# %% [markdown]
# # Chapter 7: Curvature
#
# Source span: printed pages `193-224`.
#
# Focus: Curvature tensor, flat manifolds, symmetries, Ricci identities, Ricci and scalar curvature, Weyl tensor, and conformal change.
#
# Canonical notebook: [`07-curvature.ipynb`](07-curvature.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 12: Curvature and Topology
#
# Source span: printed pages `345-370`.
#
# Focus: Constant curvature, nonpositive curvature, positive curvature, Killing-Hopf, Cartan-Hadamard, Myers, Synge, and topology consequences.
#
# Canonical notebook: [`12-curvature-and-topology.ipynb`](12-curvature-and-topology.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

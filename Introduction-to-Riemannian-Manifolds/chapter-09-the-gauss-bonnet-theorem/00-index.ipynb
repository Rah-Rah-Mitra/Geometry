# %% [markdown]
# # Chapter 9: The Gauss-Bonnet Theorem
#
# Source span: printed pages `263-282`.
#
# Focus: Plane geometry, Gauss-Bonnet formula, compact surface theorem, and curvature-topology relation.
#
# Canonical notebook: [`09-the-gauss-bonnet-theorem.ipynb`](09-the-gauss-bonnet-theorem.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

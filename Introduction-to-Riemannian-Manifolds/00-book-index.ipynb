# %% [markdown]
# # Introduction to Riemannian Manifolds
#
# Standalone visualization-first notebook course.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | What Is Curvature | 1-8 | [`01-what-is-curvature.ipynb`](chapter-01-what-is-curvature/01-what-is-curvature.ipynb) |
# | Chapter 2 | Riemannian Metrics | 9-54 | [`02-riemannian-metrics.ipynb`](chapter-02-riemannian-metrics/02-riemannian-metrics.ipynb) |
# | Chapter 3 | Model Riemannian Manifolds | 55-84 | [`03-model-riemannian-manifolds.ipynb`](chapter-03-model-riemannian-manifolds/03-model-riemannian-manifolds.ipynb) |
# | Chapter 4 | Connections | 85-114 | [`04-connections.ipynb`](chapter-04-connections/04-connections.ipynb) |
# | Chapter 5 | The Levi-Civita Connection | 115-150 | [`05-the-levi-civita-connection.ipynb`](chapter-05-the-levi-civita-connection/05-the-levi-civita-connection.ipynb) |
# | Chapter 6 | Geodesics and Distance | 151-192 | [`06-geodesics-and-distance.ipynb`](chapter-06-geodesics-and-distance/06-geodesics-and-distance.ipynb) |
# | Chapter 7 | Curvature | 193-224 | [`07-curvature.ipynb`](chapter-07-curvature/07-curvature.ipynb) |
# | Chapter 8 | Riemannian Submanifolds | 225-262 | [`08-riemannian-submanifolds.ipynb`](chapter-08-riemannian-submanifolds/08-riemannian-submanifolds.ipynb) |
# | Chapter 9 | The Gauss-Bonnet Theorem | 263-282 | [`09-the-gauss-bonnet-theorem.ipynb`](chapter-09-the-gauss-bonnet-theorem/09-the-gauss-bonnet-theorem.ipynb) |
# | Chapter 10 | Jacobi Fields | 283-318 | [`10-jacobi-fields.ipynb`](chapter-10-jacobi-fields/10-jacobi-fields.ipynb) |
# | Chapter 11 | Comparison Theory | 319-344 | [`11-comparison-theory.ipynb`](chapter-11-comparison-theory/11-comparison-theory.ipynb) |
# | Chapter 12 | Curvature and Topology | 345-370 | [`12-curvature-and-topology.ipynb`](chapter-12-curvature-and-topology/12-curvature-and-topology.ipynb) |
# | Appendix A | Review of Smooth Manifolds | 371-390 | [`appendix-a-review-of-smooth-manifolds.ipynb`](appendix-a-review-of-smooth-manifolds/appendix-a-review-of-smooth-manifolds.ipynb) |
# | Appendix B | Review of Tensors | 391-406 | [`appendix-b-review-of-tensors.ipynb`](appendix-b-review-of-tensors/appendix-b-review-of-tensors.ipynb) |
# | Appendix C | Review of Lie Groups | 407-427 | [`appendix-c-review-of-lie-groups.ipynb`](appendix-c-review-of-lie-groups/appendix-c-review-of-lie-groups.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text(encoding='utf-8'))
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Introduction to Riemannian Manifolds: 15 canonical units

# %% [markdown]
# # Chapter 8: Riemannian Submanifolds
#
# Source span: printed pages `225-262`.
#
# Focus: Second fundamental form, hypersurfaces, Euclidean hypersurfaces, sectional curvature, and submanifold calculations.
#
# Canonical notebook: [`08-riemannian-submanifolds.ipynb`](08-riemannian-submanifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

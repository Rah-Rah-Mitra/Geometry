# %% [markdown]
# # Chapter 10: Jacobi Fields
#
# Source span: printed pages `283-318`.
#
# Focus: Jacobi equation, computations, conjugate points, second variation, cut points, and local symmetric spaces.
#
# Canonical notebook: [`10-jacobi-fields.ipynb`](10-jacobi-fields.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

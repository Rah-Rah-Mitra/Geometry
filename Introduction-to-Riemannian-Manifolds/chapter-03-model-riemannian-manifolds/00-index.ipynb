# %% [markdown]
# # Chapter 3: Model Riemannian Manifolds
#
# Source span: printed pages `55-84`.
#
# Focus: Symmetries, Euclidean spaces, spheres, hyperbolic spaces, invariant Lie group metrics, homogeneous spaces, and pseudo-Riemannian models.
#
# Canonical notebook: [`03-model-riemannian-manifolds.ipynb`](03-model-riemannian-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

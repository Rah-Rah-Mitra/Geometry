# %% [markdown]
# # Chapter 5: The Levi-Civita Connection
#
# Source span: printed pages `115-150`.
#
# Focus: Tangential connection, abstract Levi-Civita connection, exponential map, normal neighborhoods, Fermi coordinates, model-space geodesics, and geometries.
#
# Canonical notebook: [`05-the-levi-civita-connection.ipynb`](05-the-levi-civita-connection.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

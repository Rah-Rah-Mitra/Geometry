# %% [markdown]
# # Chapter 2: Riemannian Metrics
#
# Source span: printed pages `9-54`.
#
# Focus: Metric definitions, constructions, distances, pseudo-Riemannian metrics, and generalizations.
#
# Canonical notebook: [`02-riemannian-metrics.ipynb`](02-riemannian-metrics.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

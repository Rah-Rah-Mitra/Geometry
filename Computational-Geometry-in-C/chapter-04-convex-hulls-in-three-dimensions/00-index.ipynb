# %% [markdown]
# # Chapter 4: Convex Hulls in Three Dimensions
#
# Source span: printed pages `101-154`.
#
# Focus: Polyhedra, 3D hull algorithms, boundary representations, randomized incremental hulls, and higher dimensions.
#
# Canonical notebook: [`04-convex-hulls-in-three-dimensions.ipynb`](04-convex-hulls-in-three-dimensions.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

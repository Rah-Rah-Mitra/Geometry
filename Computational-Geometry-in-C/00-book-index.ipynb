# %% [markdown]
# # Computational Geometry in C
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Polygon Triangulation | 1-43 | [`01-polygon-triangulation.ipynb`](chapter-01-polygon-triangulation/01-polygon-triangulation.ipynb) |
# | Chapter 2 | Polygon Partitioning | 44-62 | [`02-polygon-partitioning.ipynb`](chapter-02-polygon-partitioning/02-polygon-partitioning.ipynb) |
# | Chapter 3 | Convex Hulls in Two Dimensions | 63-100 | [`03-convex-hulls-in-two-dimensions.ipynb`](chapter-03-convex-hulls-in-two-dimensions/03-convex-hulls-in-two-dimensions.ipynb) |
# | Chapter 4 | Convex Hulls in Three Dimensions | 101-154 | [`04-convex-hulls-in-three-dimensions.ipynb`](chapter-04-convex-hulls-in-three-dimensions/04-convex-hulls-in-three-dimensions.ipynb) |
# | Chapter 5 | Voronoi Diagrams | 155-192 | [`05-voronoi-diagrams.ipynb`](chapter-05-voronoi-diagrams/05-voronoi-diagrams.ipynb) |
# | Chapter 6 | Arrangements | 193-219 | [`06-arrangements.ipynb`](chapter-06-arrangements/06-arrangements.ipynb) |
# | Chapter 7 | Search and Intersection | 220-293 | [`07-search-and-intersection.ipynb`](chapter-07-search-and-intersection/07-search-and-intersection.ipynb) |
# | Chapter 8 | Motion Planning | 294-346 | [`08-motion-planning.ipynb`](chapter-08-motion-planning/08-motion-planning.ipynb) |
# | Chapter 9 | Sources | 347-367 | [`09-sources.ipynb`](chapter-09-sources/09-sources.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# Computational Geometry in C: 9 canonical units

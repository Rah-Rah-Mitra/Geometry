# %% [markdown]
# # Chapter 8: Motion Planning
#
# Source span: printed pages `294-346`.
#
# Focus: Shortest paths, disk and polygon translation, ladder motion, robot arms, configuration spaces, and separability.
#
# Canonical notebook: [`08-motion-planning.ipynb`](08-motion-planning.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

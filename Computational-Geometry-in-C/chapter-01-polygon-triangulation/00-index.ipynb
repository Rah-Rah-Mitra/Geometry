# %% [markdown]
# # Chapter 1: Polygon Triangulation
#
# Source span: printed pages `1-43`.
#
# Focus: Art gallery theorems, polygon area, segment intersection, ears, and triangulation implementation.
#
# Canonical notebook: [`01-polygon-triangulation.ipynb`](01-polygon-triangulation.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

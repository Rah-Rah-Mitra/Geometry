# %% [markdown]
# # Chapter 6: Arrangements
#
# Source span: printed pages `193-219`.
#
# Canonical notebook: [`06-arrangements.ipynb`](06-arrangements.ipynb).
#
# Focus: Line arrangements, combinatorics, incremental construction, duality, higher-order Voronoi diagrams, and applications.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Computational-Geometry-in-C

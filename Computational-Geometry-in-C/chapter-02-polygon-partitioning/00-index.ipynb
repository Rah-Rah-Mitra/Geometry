# %% [markdown]
# # Chapter 2: Polygon Partitioning
#
# Source span: printed pages `44-62`.
#
# Canonical notebook: [`02-polygon-partitioning.ipynb`](02-polygon-partitioning.ipynb).
#
# Focus: Monotone partitioning, trapezoidalization, mountains, linear triangulation, and convex partitioning.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Computational-Geometry-in-C

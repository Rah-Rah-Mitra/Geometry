# %% [markdown]
# # Chapter 7: Search and Intersection
#
# Source span: printed pages `220-293`.
#
# Focus: Segment, triangle, polygon, polyhedron, convex polygon intersection, point location, and extremal queries.
#
# Canonical notebook: [`07-search-and-intersection.ipynb`](07-search-and-intersection.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

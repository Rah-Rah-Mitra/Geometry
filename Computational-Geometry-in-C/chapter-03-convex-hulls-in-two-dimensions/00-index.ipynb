# %% [markdown]
# # Chapter 3: Convex Hulls in Two Dimensions
#
# Source span: printed pages `63-100`.
#
# Canonical notebook: [`03-convex-hulls-in-two-dimensions.ipynb`](03-convex-hulls-in-two-dimensions.ipynb).
#
# Focus: Convexity, extreme points, gift wrapping, QuickHull, Graham scan, lower bounds, and divide-and-conquer.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Computational-Geometry-in-C

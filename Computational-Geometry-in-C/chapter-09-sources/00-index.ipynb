# %% [markdown]
# # Chapter 9: Sources
#
# Source span: printed pages `347-367`.
#
# Canonical notebook: [`09-sources.ipynb`](09-sources.ipynb).
#
# Focus: Bibliographies, FAQs, textbooks, monographs, journals, and conference resources mapped as a computational geometry reading graph.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Computational-Geometry-in-C

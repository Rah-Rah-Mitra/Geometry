# %% [markdown]
# # Chapter 5: Voronoi Diagrams
#
# Source span: printed pages `155-192`.
#
# Canonical notebook: [`05-voronoi-diagrams.ipynb`](05-voronoi-diagrams.ipynb).
#
# Focus: Voronoi cells, Delaunay triangulations, algorithms, medial axis, hull lifting, and arrangements.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# Computational-Geometry-in-C

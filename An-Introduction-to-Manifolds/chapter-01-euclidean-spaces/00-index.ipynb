# %% [markdown]
# # Chapter 1: Euclidean Spaces
#
# Source span: printed pages `3-47`.
#
# Canonical notebook: [`01-euclidean-spaces.ipynb`](01-euclidean-spaces.ipynb).
#
# Focus: Smooth functions, derivations, tangent vectors, exterior algebra, and differential forms on Euclidean space.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# An-Introduction-to-Manifolds

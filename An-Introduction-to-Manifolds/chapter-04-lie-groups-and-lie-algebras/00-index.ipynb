# %% [markdown]
# # Chapter 4: Lie Groups and Lie Algebras
#
# Source span: printed pages `164-189`.
#
# Canonical notebook: [`04-lie-groups-and-lie-algebras.ipynb`](04-lie-groups-and-lie-algebras.ipynb).
#
# Focus: Matrix Lie groups, Lie subgroups, matrix exponential, determinant differential, left-invariant vector fields, Lie algebras, brackets, and Lie algebra homomorphisms.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# An-Introduction-to-Manifolds

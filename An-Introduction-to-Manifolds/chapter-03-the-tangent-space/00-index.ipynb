# %% [markdown]
# # Chapter 3: The Tangent Space
#
# Source span: printed pages `86-163`.
#
# Canonical notebook: [`03-the-tangent-space.ipynb`](03-the-tangent-space.ipynb).
#
# Focus: Tangent spaces, differentials, submanifolds, rank theorems, tangent bundles, partitions of unity, vector fields, flows, Lie brackets, and pushforwards.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# An-Introduction-to-Manifolds

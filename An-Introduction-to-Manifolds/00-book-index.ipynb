# %% [markdown]
# # An Introduction to Manifolds
#
# Standalone visualization-first notebook course. Source method: pdftotext table-of-contents extraction.
#
# | Unit | Title | Printed Pages | Notebook |
# | --- | --- | ---: | --- |
# | Chapter 1 | Euclidean Spaces | 3-47 | [`01-euclidean-spaces.ipynb`](chapter-01-euclidean-spaces/01-euclidean-spaces.ipynb) |
# | Chapter 2 | Manifolds | 48-85 | [`02-manifolds.ipynb`](chapter-02-manifolds/02-manifolds.ipynb) |
# | Chapter 3 | The Tangent Space | 86-163 | [`03-the-tangent-space.ipynb`](chapter-03-the-tangent-space/03-the-tangent-space.ipynb) |
# | Chapter 4 | Lie Groups and Lie Algebras | 164-189 | [`04-lie-groups-and-lie-algebras.ipynb`](chapter-04-lie-groups-and-lie-algebras/04-lie-groups-and-lie-algebras.ipynb) |
# | Chapter 5 | Differential Forms | 190-235 | [`05-differential-forms.ipynb`](chapter-05-differential-forms/05-differential-forms.ipynb) |
# | Chapter 6 | Integration | 236-273 | [`06-integration.ipynb`](chapter-06-integration/06-integration.ipynb) |
# | Chapter 7 | De Rham Theory | 274-316 | [`07-de-rham-theory.ipynb`](chapter-07-de-rham-theory/07-de-rham-theory.ipynb) |

# %%
import json
from pathlib import Path
source = json.loads((Path.cwd() / 'source_map.json').read_text()) if (Path.cwd() / 'source_map.json').exists() else json.loads((Path.cwd().parent / 'source_map.json').read_text())
print(f"{source['title']}: {len(source['units'])} canonical units")
# Out:
# An Introduction to Manifolds: 7 canonical units

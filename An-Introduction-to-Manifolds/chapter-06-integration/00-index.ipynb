# %% [markdown]
# # Chapter 6: Integration
#
# Source span: printed pages `236-273`.
#
# Canonical notebook: [`06-integration.ipynb`](06-integration.ipynb).
#
# Focus: Orientations, manifolds with boundary, boundary orientation, integration of forms, Stokes theorem, line integrals, and Green's theorem.

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)
# Out:
# An-Introduction-to-Manifolds

# %% [markdown]
# # Chapter 5: Differential Forms
#
# Source span: printed pages `185-250`.
#
# Focus: Forms on manifolds, pullbacks, exterior derivative, interior product, and Lie derivative.
#
# Canonical notebook: [`05-differential-forms.ipynb`](05-differential-forms.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

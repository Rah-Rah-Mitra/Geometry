# %% [markdown]
# # Chapter 7: De Rham Theory
#
# Source span: printed pages `319-339`.
#
# Focus: Closed and exact forms, Mayer-Vietoris, homotopy invariance, degree, and de Rham cohomology.
#
# Canonical notebook: [`07-de-rham-theory.ipynb`](07-de-rham-theory.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 3: Relativity
#
# Source span: printed pages `94-115`.
#
# Focus: Einstein field equation, tidal stresses, curvature normal forms, Schwarzschild metric, orbits, light bending, Kruskal extension, and singularity theorems.
#
# Canonical notebook: [`03-relativity.ipynb`](03-relativity.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

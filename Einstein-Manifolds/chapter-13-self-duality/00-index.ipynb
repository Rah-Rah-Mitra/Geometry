# %% [markdown]
# # Chapter 13: Self-Duality
#
# Source span: printed pages `369-395`.
#
# Focus: Self-dual four-manifolds, half-conformally flat manifolds, Penrose construction, reverse Penrose construction, and Einstein applications.
#
# Canonical notebook: [`13-self-duality.ipynb`](13-self-duality.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

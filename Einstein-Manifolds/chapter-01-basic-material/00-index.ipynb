# %% [markdown]
# # Chapter 1: Basic Material
#
# Source span: printed pages `20-65`.
#
# Focus: Connections, pseudo-Riemannian manifolds, Killing fields, Einstein manifolds, curvature decompositions, Laplacians, conformal change, and variations.
#
# Canonical notebook: [`01-basic-material.ipynb`](01-basic-material.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

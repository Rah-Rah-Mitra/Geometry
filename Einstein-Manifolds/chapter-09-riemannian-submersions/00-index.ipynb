# %% [markdown]
# # Chapter 9: Riemannian Submersions
#
# Source span: printed pages `235-277`.
#
# Focus: ONeill tensors, curvature formulas, canonical variation, homogeneous Einstein applications, warped products, and examples.
#
# Canonical notebook: [`09-riemannian-submersions.ipynb`](09-riemannian-submersions.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

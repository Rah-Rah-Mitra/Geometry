# %% [markdown]
# # Chapter 6: Einstein Manifolds and Topology
#
# Source span: printed pages `154-176`.
#
# Focus: Dimension two, three and four cases, fundamental group, spinorial obstruction, and Cheeger-Gromoll theorem.
#
# Canonical notebook: [`06-einstein-manifolds-and-topology.ipynb`](06-einstein-manifolds-and-topology.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

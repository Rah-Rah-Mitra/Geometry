# %% [markdown]
# # Chapter 16: Generalizations of the Einstein Condition
#
# Source span: printed pages `432-455`.
#
# Focus: Natural linear conditions on covariant derivatives of Ricci tensors, Codazzi tensors, harmonic Weyl tensor, and harmonic curvature.
#
# Canonical notebook: [`16-generalizations-of-the-einstein-condition.ipynb`](16-generalizations-of-the-einstein-condition.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

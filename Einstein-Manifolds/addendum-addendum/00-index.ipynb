# %% [markdown]
# # Addendum: Addendum
#
# Source span: printed pages `471-491`.
#
# Focus: Later examples: infinitely many Einstein constants, G2 and Spin(7) holonomy metrics, and inhomogeneous Kahler-Einstein metrics.
#
# Canonical notebook: [`addendum-addendum.ipynb`](addendum-addendum.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 15: A Report on the Non-Compact Case
#
# Source span: printed pages `422-431`.
#
# Focus: Nonhomogeneous Einstein metrics, bundle constructions, and bounded domains of holomorphy.
#
# Canonical notebook: [`15-a-report-on-the-non-compact.ipynb`](15-a-report-on-the-non-compact.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

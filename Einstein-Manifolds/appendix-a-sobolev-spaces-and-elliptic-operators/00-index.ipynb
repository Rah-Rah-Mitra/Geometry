# %% [markdown]
# # Appendix A: Sobolev Spaces and Elliptic Operators
#
# Source span: printed pages `456-470`.
#
# Focus: Holder spaces, Sobolev spaces, embedding theorems, elliptic operators, adjoints, symbols, estimates, and regularity.
#
# Canonical notebook: [`appendix-a-sobolev-spaces-and-elliptic-operators.ipynb`](appendix-a-sobolev-spaces-and-elliptic-operators.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 14: Quaternion-Kahler Manifolds
#
# Source span: printed pages `396-421`.
#
# Focus: Hyperkahler manifolds, quaternion-Kahler structures, twistor spaces, symmetric examples, and applications.
#
# Canonical notebook: [`14-quaternion-kahler-manifolds.ipynb`](14-quaternion-kahler-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

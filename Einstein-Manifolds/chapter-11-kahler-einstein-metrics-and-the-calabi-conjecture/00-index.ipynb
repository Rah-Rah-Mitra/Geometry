# %% [markdown]
# # Chapter 11: Kahler-Einstein Metrics and the Calabi Conjecture
#
# Source span: printed pages `318-339`.
#
# Focus: Kahler-Einstein metrics, Aubin-Calabi-Yau theorems, positive first Chern class, and extremal metrics.
#
# Canonical notebook: [`11-kahler-einstein-metrics-and-the-calabi.ipynb`](11-kahler-einstein-metrics-and-the-calabi.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

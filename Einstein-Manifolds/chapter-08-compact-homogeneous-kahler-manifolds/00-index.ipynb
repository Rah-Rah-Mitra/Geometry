# %% [markdown]
# # Chapter 8: Compact Homogeneous Kahler Manifolds
#
# Source span: printed pages `208-234`.
#
# Focus: Adjoint orbits, canonical complex structures, invariant Ricci forms, KKS symplectic forms, Kahler metrics, and examples.
#
# Canonical notebook: [`08-compact-homogeneous-kahler-manifolds.ipynb`](08-compact-homogeneous-kahler-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 5: Ricci Curvature as a Partial Differential Equation
#
# Source span: printed pages `137-153`.
#
# Focus: Pointwise solvability, local obstructions, local Einstein metric construction, regularity, analyticity, and uniqueness and nonexistence.
#
# Canonical notebook: [`05-ricci-curvature-as-a-partial-differential.ipynb`](05-ricci-curvature-as-a-partial-differential.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 2: Basic Material Continued: Kahler Manifolds
#
# Source span: printed pages `66-93`.
#
# Focus: Complex manifolds, Hermitian and Kahler metrics, Ricci form, Chern classes, Hodge theory, and Calabi-Futaki theorem.
#
# Canonical notebook: [`02-basic-material-continued-kahler-manifolds.ipynb`](02-basic-material-continued-kahler-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 10: Holonomy Groups
#
# Source span: printed pages `278-317`.
#
# Focus: Definitions, parallel tensors, products, curvature, symmetric spaces, Berger-style structure, nonsimply connected cases, and Lorentzian manifolds.
#
# Canonical notebook: [`10-holonomy-groups.ipynb`](10-holonomy-groups.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

# %% [markdown]
# # Chapter 12: The Moduli Space of Einstein Structures
#
# Source span: printed pages `340-368`.
#
# Focus: Surfaces, flat manifolds, infinitesimal deformations, formal integrability, premoduli spaces, Einstein constants, rigidity, and K3 examples.
#
# Canonical notebook: [`12-the-moduli-space-of-einstein-structures.ipynb`](12-the-moduli-space-of-einstein-structures.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

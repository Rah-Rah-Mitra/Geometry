# %% [markdown]
# # Chapter 7: Homogeneous Riemannian Manifolds
#
# Source span: printed pages `177-207`.
#
# Focus: Homogeneous metrics, curvature, homogeneous Einstein examples, symmetric spaces, and standard homogeneous models.
#
# Canonical notebook: [`07-homogeneous-riemannian-manifolds.ipynb`](07-homogeneous-riemannian-manifolds.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

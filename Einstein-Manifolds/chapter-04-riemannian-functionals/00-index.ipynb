# %% [markdown]
# # Chapter 4: Riemannian Functionals
#
# Source span: printed pages `116-136`.
#
# Focus: Total scalar curvature, constant scalar curvature metrics, scalar curvature map, quadratic functionals, and variational properties.
#
# Canonical notebook: [`04-riemannian-functionals.ipynb`](04-riemannian-functionals.ipynb).

# %%
from pathlib import Path
BOOK_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'source_map.json').exists())
print(BOOK_ROOT.name)

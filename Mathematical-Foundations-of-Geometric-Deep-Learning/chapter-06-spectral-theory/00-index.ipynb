# %% [markdown]
# # Chapter 06: Spectral Theory
#
# - Canonical notebook: [06-spectral-theory.ipynb](06-spectral-theory.ipynb)
# - PDF pages: 55-64
# - Visual spine: eigen-directions, self-adjoint spectra, Laplacian eigenfunctions, Fourier Gram matrices, SVD, Parseval, heat flow, graph Laplacian bridge
#
# Artifacts for this chapter are stored under `../artifacts/chapter-06/` and are generated by the canonical notebook.

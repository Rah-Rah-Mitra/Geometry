# %% [markdown]
# # Chapter 03: Vector Calculus
#
# - Canonical notebook: [03-vector-calculus.ipynb](03-vector-calculus.ipynb)
# - PDF pages: 26-36
# - Visual spine: Lipschitz/smoothness gallery, scalar/vector fields, gradients, Jacobians, integrals, divergence/flux, Laplacian, loss landscapes, backprop graph
#
# Artifacts for this chapter are stored under `../artifacts/chapter-03/` and are generated by the canonical notebook.

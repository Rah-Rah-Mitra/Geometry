# %% [markdown]
# # Chapter 07: Graph Theory
#
# - Canonical notebook: [07-graph-theory.ipynb](07-graph-theory.ipynb)
# - PDF pages: 65-77
# - Visual spine: graph anatomy, adjacency/degree matrices, graph distances, graph families, geometric graphs, homophily, permutations, homomorphisms, Laplacians, graph Fourier modes, message passing
#
# Artifacts for this chapter are stored under `../artifacts/chapter-07/` and are generated by the canonical notebook.

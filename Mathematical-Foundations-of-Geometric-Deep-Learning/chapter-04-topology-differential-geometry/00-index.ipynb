# %% [markdown]
# # Chapter 04: Topological Foundations and Differential Geometry
#
# - Canonical notebook: [04-topology-differential-geometry.ipynb](04-topology-differential-geometry.ipynb)
# - PDF pages: 37-50
# - Visual spine: open sets, continuity via preimages, homeomorphism/homotopy, Euler characteristic, geodesics, charts, tangent spaces, exp/log maps, gauges, manifold hypothesis
#
# Artifacts for this chapter are stored under `../artifacts/chapter-04/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 05: Functional Analysis
#
# - Canonical notebook: [05-functional-analysis.ipynb](05-functional-analysis.ipynb)
# - PDF pages: 51-54
# - Visual spine: Cauchy sequences, completeness gaps, Banach/Hilbert geometry, function bases, orthonormal reconstruction, operators, adjoints, functionals
#
# Artifacts for this chapter are stored under `../artifacts/chapter-05/` and are generated by the canonical notebook.

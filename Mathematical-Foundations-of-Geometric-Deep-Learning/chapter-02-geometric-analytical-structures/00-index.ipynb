# %% [markdown]
# # Chapter 02: Geometric and Analytical Structures
#
# - Canonical notebook: [02-geometric-analytical-structures.ipynb](02-geometric-analytical-structures.ipynb)
# - PDF pages: 20-25
# - Visual spine: norm balls, induced metrics, pseudometric/quasi-metric examples, Hausdorff distance, proximity graphs, projections, Gram-Schmidt, attention scaling
#
# Artifacts for this chapter are stored under `../artifacts/chapter-02/` and are generated by the canonical notebook.

# %% [markdown]
# # Chapter 01: Algebraic Structures and Mathematics before Numbers
#
# - Canonical notebook: [01-algebraic-structures.ipynb](01-algebraic-structures.ipynb)
# - PDF pages: 4-19
# - Visual spine: sets, maps, power sets, Cartesian products, finite groups, Cayley graphs, actions, invariance/equivariance, tensor notation, einsum checks
#
# Artifacts for this chapter are stored under `../artifacts/chapter-01/` and are generated by the canonical notebook.
